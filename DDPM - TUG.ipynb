# %%
generating_class = 'TUG'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-02-01 06:11:33.498466: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-01 06:11:33.518941: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-02-01 06:11:34.246480: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.249392: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.249410: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-02-01 06:11:34.258752: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.258786: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.258795: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.377861: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.377889: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.377895: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-02-01 06:11:34.377911: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-01 06:11:34.377927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738390317.513742     583 service.cc:145] XLA service 0x7ff020004950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738390317.513780     583 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-02-01 06:11:58.332567: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738390319.041861     583 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-02-01 06:12:00.470211: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738390322.493383     740 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738390322.498789     751 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738390322.607995     739 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738390322.634345     749 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738390323.061472     745 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738390323.114997     742 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738390323.116761     743 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738390323.213300     751 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738390323.332928     764 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738390323.439063     749 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738390324.042674     749 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738390324.069703     740 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738390324.080409     766 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738390324.085170     739 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738390324.118143     762 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738390324.145281     764 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738390324.280582     764 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738390324.332022     768 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738390324.464321     741 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738390324.472177     756 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738390324.594627     748 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738390324.607431     760 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738390324.687074     747 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738390324.702356     750 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738390324.760832     753 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738390325.115019     756 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738390325.131666     757 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738390325.167078     743 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738390325.232704     748 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738390325.242154     762 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738390325.290913     752 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738390325.371496     755 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738390325.438933     764 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738390352.704367     583 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738390352.752074     583 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 67s 68ms/step - loss: 0.2439
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0351
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0312
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0265
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0264
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0255
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0252
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0249
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0232
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0231
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0253
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0232
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0222
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0219
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0233
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0222
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0213
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0214
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0217
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0216
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0228
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0224
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0217
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0214
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0221
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0209
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0214
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0207
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0210
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0214
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0216
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0213
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0214
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0215
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0205
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0209
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0211
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0203
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0195
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0207
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0196
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0205
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0203
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0207
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0198
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0208
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0203
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0206
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0204
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0203
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0209
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0200
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0189
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0199
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0195
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0198
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0205
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0203
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0208
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0209
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0203
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0199
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0201
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0192
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0198
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0208
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0197
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0209
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0205
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0204
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0191
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - loss: 0.0185
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 327/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 328/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 346/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 347/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 348/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 349/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 350/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 351/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 352/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 353/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 354/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 355/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 356/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 357/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 358/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 359/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 360/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 361/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 362/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 363/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 364/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 365/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 366/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 367/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 368/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 369/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 370/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 371/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 372/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 373/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 374/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 375/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 376/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 377/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 378/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 379/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 380/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 381/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 382/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 383/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 384/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 385/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 386/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 387/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 388/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 389/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 390/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 391/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 392/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 393/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 394/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 395/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 396/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 397/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 398/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 399/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 400/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 401/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 402/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 403/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 404/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 405/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 406/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 407/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 408/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 409/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 410/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 411/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 412/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 413/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 414/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 415/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 416/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 417/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 418/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 419/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 420/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 421/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 422/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 423/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 424/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 425/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 426/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 427/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 428/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 429/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 430/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 431/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 432/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 433/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 434/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 435/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 436/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 437/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 438/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 439/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 440/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 441/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 442/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 443/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 444/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 445/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 446/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0171
# Epoch 447/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 448/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 449/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 450/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 451/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 452/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 453/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 454/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 455/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 456/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 457/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 458/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 459/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 460/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 461/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0171
# Epoch 462/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 463/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 464/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 465/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 466/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 467/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 468/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 469/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 470/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 471/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 472/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 473/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 474/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 475/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 476/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 477/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 478/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 479/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 480/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 481/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 482/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 483/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 484/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 485/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 486/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 487/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 488/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 489/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 490/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 491/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 492/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 493/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 494/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 495/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 496/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 497/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 498/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 499/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 500/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# INFO:tensorflow:Assets written to: DDPM-GI/TUG/GERADOR/assets
# INFO:tensorflow:Assets written to: DDPM-GI/TUG/GERADOR/assets

# %%
import os
from IPython.display import clear_output
import time

num_img = 5400
output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    ini = time.time()
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    fim = time.time()
    tim = fim - ini
    timt = (tim * t) / 3600
    print("Faltam %d iterações" % (t))
    print("A iteração atual levou %d segundos" % (tim))
    print("Faltam %.2f horas" % (timt))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 20
#      18 ini = time.time()
#      19 tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
# ---> 20 pred_noise = ema_network.predict(
#      21     [samples, tt], verbose=0, batch_size=1
#      22 )
#      23 samples = gdf_util.p_sample(
#      24     pred_noise, samples, tt, clip_denoised=True
#      25 )
#      26 fim = time.time()
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:510, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     508 callbacks.on_predict_batch_begin(step)
#     509 data = get_data(iterator)
# --> 510 batch_outputs = self.predict_function(data)
#     511 outputs = append_to_outputs(batch_outputs, outputs)
#     512 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: TUG0.png -> DDPM-F64x4/TUG/TUG0.png
# Processado: TUG1.png -> DDPM-F64x4/TUG/TUG1.png
# Processado: TUG10.png -> DDPM-F64x4/TUG/TUG10.png
# Processado: TUG100.png -> DDPM-F64x4/TUG/TUG100.png
# Processado: TUG1000.png -> DDPM-F64x4/TUG/TUG1000.png
# Processado: TUG1001.png -> DDPM-F64x4/TUG/TUG1001.png
# Processado: TUG1002.png -> DDPM-F64x4/TUG/TUG1002.png
# Processado: TUG1003.png -> DDPM-F64x4/TUG/TUG1003.png
# Processado: TUG1004.png -> DDPM-F64x4/TUG/TUG1004.png
# Processado: TUG1005.png -> DDPM-F64x4/TUG/TUG1005.png
# Processado: TUG1006.png -> DDPM-F64x4/TUG/TUG1006.png
# Processado: TUG1007.png -> DDPM-F64x4/TUG/TUG1007.png
# Processado: TUG1008.png -> DDPM-F64x4/TUG/TUG1008.png
# Processado: TUG1009.png -> DDPM-F64x4/TUG/TUG1009.png
# Processado: TUG101.png -> DDPM-F64x4/TUG/TUG101.png
# Processado: TUG1010.png -> DDPM-F64x4/TUG/TUG1010.png
# Processado: TUG1011.png -> DDPM-F64x4/TUG/TUG1011.png
# Processado: TUG1012.png -> DDPM-F64x4/TUG/TUG1012.png
# Processado: TUG1013.png -> DDPM-F64x4/TUG/TUG1013.png
# Processado: TUG1014.png -> DDPM-F64x4/TUG/TUG1014.png
# Processado: TUG1015.png -> DDPM-F64x4/TUG/TUG1015.png
# Processado: TUG1016.png -> DDPM-F64x4/TUG/TUG1016.png
# Processado: TUG1017.png -> DDPM-F64x4/TUG/TUG1017.png
# Processado: TUG1018.png -> DDPM-F64x4/TUG/TUG1018.png
# Processado: TUG1019.png -> DDPM-F64x4/TUG/TUG1019.png
# Processado: TUG102.png -> DDPM-F64x4/TUG/TUG102.png
# Processado: TUG1020.png -> DDPM-F64x4/TUG/TUG1020.png
# Processado: TUG1021.png -> DDPM-F64x4/TUG/TUG1021.png
# Processado: TUG1022.png -> DDPM-F64x4/TUG/TUG1022.png
# Processado: TUG1023.png -> DDPM-F64x4/TUG/TUG1023.png
# Processado: TUG1024.png -> DDPM-F64x4/TUG/TUG1024.png
# Processado: TUG1025.png -> DDPM-F64x4/TUG/TUG1025.png
# Processado: TUG1026.png -> DDPM-F64x4/TUG/TUG1026.png
# Processado: TUG1027.png -> DDPM-F64x4/TUG/TUG1027.png
# Processado: TUG1028.png -> DDPM-F64x4/TUG/TUG1028.png
# Processado: TUG1029.png -> DDPM-F64x4/TUG/TUG1029.png
# Processado: TUG103.png -> DDPM-F64x4/TUG/TUG103.png
# Processado: TUG1030.png -> DDPM-F64x4/TUG/TUG1030.png
# Processado: TUG1031.png -> DDPM-F64x4/TUG/TUG1031.png
# Processado: TUG1032.png -> DDPM-F64x4/TUG/TUG1032.png
# Processado: TUG1033.png -> DDPM-F64x4/TUG/TUG1033.png
# Processado: TUG1034.png -> DDPM-F64x4/TUG/TUG1034.png
# Processado: TUG1035.png -> DDPM-F64x4/TUG/TUG1035.png
# Processado: TUG1036.png -> DDPM-F64x4/TUG/TUG1036.png
# Processado: TUG1037.png -> DDPM-F64x4/TUG/TUG1037.png
# Processado: TUG1038.png -> DDPM-F64x4/TUG/TUG1038.png
# Processado: TUG1039.png -> DDPM-F64x4/TUG/TUG1039.png
# Processado: TUG104.png -> DDPM-F64x4/TUG/TUG104.png
# Processado: TUG1040.png -> DDPM-F64x4/TUG/TUG1040.png
# Processado: TUG1041.png -> DDPM-F64x4/TUG/TUG1041.png
# Processado: TUG1042.png -> DDPM-F64x4/TUG/TUG1042.png
# Processado: TUG1043.png -> DDPM-F64x4/TUG/TUG1043.png
# Processado: TUG1044.png -> DDPM-F64x4/TUG/TUG1044.png
# Processado: TUG1045.png -> DDPM-F64x4/TUG/TUG1045.png
# Processado: TUG1046.png -> DDPM-F64x4/TUG/TUG1046.png
# Processado: TUG1047.png -> DDPM-F64x4/TUG/TUG1047.png
# Processado: TUG1048.png -> DDPM-F64x4/TUG/TUG1048.png
# Processado: TUG1049.png -> DDPM-F64x4/TUG/TUG1049.png
# Processado: TUG105.png -> DDPM-F64x4/TUG/TUG105.png
# Processado: TUG1050.png -> DDPM-F64x4/TUG/TUG1050.png
# Processado: TUG1051.png -> DDPM-F64x4/TUG/TUG1051.png
# Processado: TUG1052.png -> DDPM-F64x4/TUG/TUG1052.png
# Processado: TUG1053.png -> DDPM-F64x4/TUG/TUG1053.png
# Processado: TUG1054.png -> DDPM-F64x4/TUG/TUG1054.png
# Processado: TUG1055.png -> DDPM-F64x4/TUG/TUG1055.png
# Processado: TUG1056.png -> DDPM-F64x4/TUG/TUG1056.png
# Processado: TUG1057.png -> DDPM-F64x4/TUG/TUG1057.png
# Processado: TUG1058.png -> DDPM-F64x4/TUG/TUG1058.png
# Processado: TUG1059.png -> DDPM-F64x4/TUG/TUG1059.png
# Processado: TUG106.png -> DDPM-F64x4/TUG/TUG106.png
# Processado: TUG1060.png -> DDPM-F64x4/TUG/TUG1060.png
# Processado: TUG1061.png -> DDPM-F64x4/TUG/TUG1061.png
# Processado: TUG1062.png -> DDPM-F64x4/TUG/TUG1062.png
# Processado: TUG1063.png -> DDPM-F64x4/TUG/TUG1063.png
# Processado: TUG1064.png -> DDPM-F64x4/TUG/TUG1064.png
# Processado: TUG1065.png -> DDPM-F64x4/TUG/TUG1065.png
# Processado: TUG1066.png -> DDPM-F64x4/TUG/TUG1066.png
# Processado: TUG1067.png -> DDPM-F64x4/TUG/TUG1067.png
# Processado: TUG1068.png -> DDPM-F64x4/TUG/TUG1068.png
# Processado: TUG1069.png -> DDPM-F64x4/TUG/TUG1069.png
# Processado: TUG107.png -> DDPM-F64x4/TUG/TUG107.png
# Processado: TUG1070.png -> DDPM-F64x4/TUG/TUG1070.png
# Processado: TUG1071.png -> DDPM-F64x4/TUG/TUG1071.png
# Processado: TUG1072.png -> DDPM-F64x4/TUG/TUG1072.png
# Processado: TUG1073.png -> DDPM-F64x4/TUG/TUG1073.png
# Processado: TUG1074.png -> DDPM-F64x4/TUG/TUG1074.png
# Processado: TUG1075.png -> DDPM-F64x4/TUG/TUG1075.png
# Processado: TUG1076.png -> DDPM-F64x4/TUG/TUG1076.png
# Processado: TUG1077.png -> DDPM-F64x4/TUG/TUG1077.png
# Processado: TUG1078.png -> DDPM-F64x4/TUG/TUG1078.png
# Processado: TUG1079.png -> DDPM-F64x4/TUG/TUG1079.png
# Processado: TUG108.png -> DDPM-F64x4/TUG/TUG108.png
# Processado: TUG1080.png -> DDPM-F64x4/TUG/TUG1080.png
# Processado: TUG1081.png -> DDPM-F64x4/TUG/TUG1081.png
# Processado: TUG1082.png -> DDPM-F64x4/TUG/TUG1082.png
# Processado: TUG1083.png -> DDPM-F64x4/TUG/TUG1083.png
# Processado: TUG1084.png -> DDPM-F64x4/TUG/TUG1084.png
# Processado: TUG1085.png -> DDPM-F64x4/TUG/TUG1085.png
# Processado: TUG1086.png -> DDPM-F64x4/TUG/TUG1086.png
# Processado: TUG1087.png -> DDPM-F64x4/TUG/TUG1087.png
# Processado: TUG1088.png -> DDPM-F64x4/TUG/TUG1088.png
# Processado: TUG1089.png -> DDPM-F64x4/TUG/TUG1089.png
# Processado: TUG109.png -> DDPM-F64x4/TUG/TUG109.png
# Processado: TUG1090.png -> DDPM-F64x4/TUG/TUG1090.png
# Processado: TUG1091.png -> DDPM-F64x4/TUG/TUG1091.png
# Processado: TUG1092.png -> DDPM-F64x4/TUG/TUG1092.png
# Processado: TUG1093.png -> DDPM-F64x4/TUG/TUG1093.png
# Processado: TUG1094.png -> DDPM-F64x4/TUG/TUG1094.png
# Processado: TUG1095.png -> DDPM-F64x4/TUG/TUG1095.png
# Processado: TUG1096.png -> DDPM-F64x4/TUG/TUG1096.png
# Processado: TUG1097.png -> DDPM-F64x4/TUG/TUG1097.png
# Processado: TUG1098.png -> DDPM-F64x4/TUG/TUG1098.png
# Processado: TUG1099.png -> DDPM-F64x4/TUG/TUG1099.png
# Processado: TUG11.png -> DDPM-F64x4/TUG/TUG11.png
# Processado: TUG110.png -> DDPM-F64x4/TUG/TUG110.png
# Processado: TUG1100.png -> DDPM-F64x4/TUG/TUG1100.png
# Processado: TUG1101.png -> DDPM-F64x4/TUG/TUG1101.png
# Processado: TUG1102.png -> DDPM-F64x4/TUG/TUG1102.png
# Processado: TUG1103.png -> DDPM-F64x4/TUG/TUG1103.png
# Processado: TUG1104.png -> DDPM-F64x4/TUG/TUG1104.png
# Processado: TUG1105.png -> DDPM-F64x4/TUG/TUG1105.png
# Processado: TUG1106.png -> DDPM-F64x4/TUG/TUG1106.png
# Processado: TUG1107.png -> DDPM-F64x4/TUG/TUG1107.png
# Processado: TUG1108.png -> DDPM-F64x4/TUG/TUG1108.png
# Processado: TUG1109.png -> DDPM-F64x4/TUG/TUG1109.png
# Processado: TUG111.png -> DDPM-F64x4/TUG/TUG111.png
# Processado: TUG1110.png -> DDPM-F64x4/TUG/TUG1110.png
# Processado: TUG1111.png -> DDPM-F64x4/TUG/TUG1111.png
# Processado: TUG1112.png -> DDPM-F64x4/TUG/TUG1112.png
# Processado: TUG1113.png -> DDPM-F64x4/TUG/TUG1113.png
# Processado: TUG1114.png -> DDPM-F64x4/TUG/TUG1114.png
# Processado: TUG1115.png -> DDPM-F64x4/TUG/TUG1115.png
# Processado: TUG1116.png -> DDPM-F64x4/TUG/TUG1116.png
# Processado: TUG1117.png -> DDPM-F64x4/TUG/TUG1117.png
# Processado: TUG1118.png -> DDPM-F64x4/TUG/TUG1118.png
# Processado: TUG1119.png -> DDPM-F64x4/TUG/TUG1119.png
# Processado: TUG112.png -> DDPM-F64x4/TUG/TUG112.png
# Processado: TUG1120.png -> DDPM-F64x4/TUG/TUG1120.png
# Processado: TUG1121.png -> DDPM-F64x4/TUG/TUG1121.png
# Processado: TUG1122.png -> DDPM-F64x4/TUG/TUG1122.png
# Processado: TUG1123.png -> DDPM-F64x4/TUG/TUG1123.png
# Processado: TUG1124.png -> DDPM-F64x4/TUG/TUG1124.png
# Processado: TUG1125.png -> DDPM-F64x4/TUG/TUG1125.png
# Processado: TUG1126.png -> DDPM-F64x4/TUG/TUG1126.png
# Processado: TUG1127.png -> DDPM-F64x4/TUG/TUG1127.png
# Processado: TUG1128.png -> DDPM-F64x4/TUG/TUG1128.png
# Processado: TUG1129.png -> DDPM-F64x4/TUG/TUG1129.png
# Processado: TUG113.png -> DDPM-F64x4/TUG/TUG113.png
# Processado: TUG1130.png -> DDPM-F64x4/TUG/TUG1130.png
# Processado: TUG1131.png -> DDPM-F64x4/TUG/TUG1131.png
# Processado: TUG1132.png -> DDPM-F64x4/TUG/TUG1132.png
# Processado: TUG1133.png -> DDPM-F64x4/TUG/TUG1133.png
# Processado: TUG1134.png -> DDPM-F64x4/TUG/TUG1134.png
# Processado: TUG1135.png -> DDPM-F64x4/TUG/TUG1135.png
# Processado: TUG1136.png -> DDPM-F64x4/TUG/TUG1136.png
# Processado: TUG1137.png -> DDPM-F64x4/TUG/TUG1137.png
# Processado: TUG1138.png -> DDPM-F64x4/TUG/TUG1138.png
# Processado: TUG1139.png -> DDPM-F64x4/TUG/TUG1139.png
# Processado: TUG114.png -> DDPM-F64x4/TUG/TUG114.png
# Processado: TUG1140.png -> DDPM-F64x4/TUG/TUG1140.png
# Processado: TUG1141.png -> DDPM-F64x4/TUG/TUG1141.png
# Processado: TUG1142.png -> DDPM-F64x4/TUG/TUG1142.png
# Processado: TUG1143.png -> DDPM-F64x4/TUG/TUG1143.png
# Processado: TUG1144.png -> DDPM-F64x4/TUG/TUG1144.png
# Processado: TUG1145.png -> DDPM-F64x4/TUG/TUG1145.png
# Processado: TUG1146.png -> DDPM-F64x4/TUG/TUG1146.png
# Processado: TUG1147.png -> DDPM-F64x4/TUG/TUG1147.png
# Processado: TUG1148.png -> DDPM-F64x4/TUG/TUG1148.png
# Processado: TUG1149.png -> DDPM-F64x4/TUG/TUG1149.png
# Processado: TUG115.png -> DDPM-F64x4/TUG/TUG115.png
# Processado: TUG1150.png -> DDPM-F64x4/TUG/TUG1150.png
# Processado: TUG1151.png -> DDPM-F64x4/TUG/TUG1151.png
# Processado: TUG1152.png -> DDPM-F64x4/TUG/TUG1152.png
# Processado: TUG1153.png -> DDPM-F64x4/TUG/TUG1153.png
# Processado: TUG1154.png -> DDPM-F64x4/TUG/TUG1154.png
# Processado: TUG1155.png -> DDPM-F64x4/TUG/TUG1155.png
# Processado: TUG1156.png -> DDPM-F64x4/TUG/TUG1156.png
# Processado: TUG1157.png -> DDPM-F64x4/TUG/TUG1157.png
# Processado: TUG1158.png -> DDPM-F64x4/TUG/TUG1158.png
# Processado: TUG1159.png -> DDPM-F64x4/TUG/TUG1159.png
# Processado: TUG116.png -> DDPM-F64x4/TUG/TUG116.png
# Processado: TUG1160.png -> DDPM-F64x4/TUG/TUG1160.png
# Processado: TUG1161.png -> DDPM-F64x4/TUG/TUG1161.png
# Processado: TUG1162.png -> DDPM-F64x4/TUG/TUG1162.png
# Processado: TUG1163.png -> DDPM-F64x4/TUG/TUG1163.png
# Processado: TUG1164.png -> DDPM-F64x4/TUG/TUG1164.png
# Processado: TUG1165.png -> DDPM-F64x4/TUG/TUG1165.png
# Processado: TUG1166.png -> DDPM-F64x4/TUG/TUG1166.png
# Processado: TUG1167.png -> DDPM-F64x4/TUG/TUG1167.png
# Processado: TUG1168.png -> DDPM-F64x4/TUG/TUG1168.png
# Processado: TUG1169.png -> DDPM-F64x4/TUG/TUG1169.png
# Processado: TUG117.png -> DDPM-F64x4/TUG/TUG117.png
# Processado: TUG1170.png -> DDPM-F64x4/TUG/TUG1170.png
# Processado: TUG1171.png -> DDPM-F64x4/TUG/TUG1171.png
# Processado: TUG1172.png -> DDPM-F64x4/TUG/TUG1172.png
# Processado: TUG1173.png -> DDPM-F64x4/TUG/TUG1173.png
# Processado: TUG1174.png -> DDPM-F64x4/TUG/TUG1174.png
# Processado: TUG1175.png -> DDPM-F64x4/TUG/TUG1175.png
# Processado: TUG1176.png -> DDPM-F64x4/TUG/TUG1176.png
# Processado: TUG1177.png -> DDPM-F64x4/TUG/TUG1177.png
# Processado: TUG1178.png -> DDPM-F64x4/TUG/TUG1178.png
# Processado: TUG1179.png -> DDPM-F64x4/TUG/TUG1179.png
# Processado: TUG118.png -> DDPM-F64x4/TUG/TUG118.png
# Processado: TUG1180.png -> DDPM-F64x4/TUG/TUG1180.png
# Processado: TUG1181.png -> DDPM-F64x4/TUG/TUG1181.png
# Processado: TUG1182.png -> DDPM-F64x4/TUG/TUG1182.png
# Processado: TUG1183.png -> DDPM-F64x4/TUG/TUG1183.png
# Processado: TUG1184.png -> DDPM-F64x4/TUG/TUG1184.png
# Processado: TUG1185.png -> DDPM-F64x4/TUG/TUG1185.png
# Processado: TUG1186.png -> DDPM-F64x4/TUG/TUG1186.png
# Processado: TUG1187.png -> DDPM-F64x4/TUG/TUG1187.png
# Processado: TUG1188.png -> DDPM-F64x4/TUG/TUG1188.png
# Processado: TUG1189.png -> DDPM-F64x4/TUG/TUG1189.png
# Processado: TUG119.png -> DDPM-F64x4/TUG/TUG119.png
# Processado: TUG1190.png -> DDPM-F64x4/TUG/TUG1190.png
# Processado: TUG1191.png -> DDPM-F64x4/TUG/TUG1191.png
# Processado: TUG1192.png -> DDPM-F64x4/TUG/TUG1192.png
# Processado: TUG1193.png -> DDPM-F64x4/TUG/TUG1193.png
# Processado: TUG1194.png -> DDPM-F64x4/TUG/TUG1194.png
# Processado: TUG1195.png -> DDPM-F64x4/TUG/TUG1195.png
# Processado: TUG1196.png -> DDPM-F64x4/TUG/TUG1196.png
# Processado: TUG1197.png -> DDPM-F64x4/TUG/TUG1197.png
# Processado: TUG1198.png -> DDPM-F64x4/TUG/TUG1198.png
# Processado: TUG1199.png -> DDPM-F64x4/TUG/TUG1199.png
# Processado: TUG12.png -> DDPM-F64x4/TUG/TUG12.png
# Processado: TUG120.png -> DDPM-F64x4/TUG/TUG120.png
# Processado: TUG1200.png -> DDPM-F64x4/TUG/TUG1200.png
# Processado: TUG1201.png -> DDPM-F64x4/TUG/TUG1201.png
# Processado: TUG1202.png -> DDPM-F64x4/TUG/TUG1202.png
# Processado: TUG1203.png -> DDPM-F64x4/TUG/TUG1203.png
# Processado: TUG1204.png -> DDPM-F64x4/TUG/TUG1204.png
# Processado: TUG1205.png -> DDPM-F64x4/TUG/TUG1205.png
# Processado: TUG1206.png -> DDPM-F64x4/TUG/TUG1206.png
# Processado: TUG1207.png -> DDPM-F64x4/TUG/TUG1207.png
# Processado: TUG1208.png -> DDPM-F64x4/TUG/TUG1208.png
# Processado: TUG1209.png -> DDPM-F64x4/TUG/TUG1209.png
# Processado: TUG121.png -> DDPM-F64x4/TUG/TUG121.png
# Processado: TUG1210.png -> DDPM-F64x4/TUG/TUG1210.png
# Processado: TUG1211.png -> DDPM-F64x4/TUG/TUG1211.png
# Processado: TUG1212.png -> DDPM-F64x4/TUG/TUG1212.png
# Processado: TUG1213.png -> DDPM-F64x4/TUG/TUG1213.png
# Processado: TUG1214.png -> DDPM-F64x4/TUG/TUG1214.png
# Processado: TUG1215.png -> DDPM-F64x4/TUG/TUG1215.png
# Processado: TUG1216.png -> DDPM-F64x4/TUG/TUG1216.png
# Processado: TUG1217.png -> DDPM-F64x4/TUG/TUG1217.png
# Processado: TUG1218.png -> DDPM-F64x4/TUG/TUG1218.png
# Processado: TUG1219.png -> DDPM-F64x4/TUG/TUG1219.png
# Processado: TUG122.png -> DDPM-F64x4/TUG/TUG122.png
# Processado: TUG1220.png -> DDPM-F64x4/TUG/TUG1220.png
# Processado: TUG1221.png -> DDPM-F64x4/TUG/TUG1221.png
# Processado: TUG1222.png -> DDPM-F64x4/TUG/TUG1222.png
# Processado: TUG1223.png -> DDPM-F64x4/TUG/TUG1223.png
# Processado: TUG1224.png -> DDPM-F64x4/TUG/TUG1224.png
# Processado: TUG1225.png -> DDPM-F64x4/TUG/TUG1225.png
# Processado: TUG1226.png -> DDPM-F64x4/TUG/TUG1226.png
# Processado: TUG1227.png -> DDPM-F64x4/TUG/TUG1227.png
# Processado: TUG1228.png -> DDPM-F64x4/TUG/TUG1228.png
# Processado: TUG1229.png -> DDPM-F64x4/TUG/TUG1229.png
# Processado: TUG123.png -> DDPM-F64x4/TUG/TUG123.png
# Processado: TUG1230.png -> DDPM-F64x4/TUG/TUG1230.png
# Processado: TUG1231.png -> DDPM-F64x4/TUG/TUG1231.png
# Processado: TUG1232.png -> DDPM-F64x4/TUG/TUG1232.png
# Processado: TUG1233.png -> DDPM-F64x4/TUG/TUG1233.png
# Processado: TUG1234.png -> DDPM-F64x4/TUG/TUG1234.png
# Processado: TUG1235.png -> DDPM-F64x4/TUG/TUG1235.png
# Processado: TUG1236.png -> DDPM-F64x4/TUG/TUG1236.png
# Processado: TUG1237.png -> DDPM-F64x4/TUG/TUG1237.png
# Processado: TUG1238.png -> DDPM-F64x4/TUG/TUG1238.png
# Processado: TUG1239.png -> DDPM-F64x4/TUG/TUG1239.png
# Processado: TUG124.png -> DDPM-F64x4/TUG/TUG124.png
# Processado: TUG1240.png -> DDPM-F64x4/TUG/TUG1240.png
# Processado: TUG1241.png -> DDPM-F64x4/TUG/TUG1241.png
# Processado: TUG1242.png -> DDPM-F64x4/TUG/TUG1242.png
# Processado: TUG1243.png -> DDPM-F64x4/TUG/TUG1243.png
# Processado: TUG1244.png -> DDPM-F64x4/TUG/TUG1244.png
# Processado: TUG1245.png -> DDPM-F64x4/TUG/TUG1245.png
# Processado: TUG1246.png -> DDPM-F64x4/TUG/TUG1246.png
# Processado: TUG1247.png -> DDPM-F64x4/TUG/TUG1247.png
# Processado: TUG1248.png -> DDPM-F64x4/TUG/TUG1248.png
# Processado: TUG1249.png -> DDPM-F64x4/TUG/TUG1249.png
# Processado: TUG125.png -> DDPM-F64x4/TUG/TUG125.png
# Processado: TUG1250.png -> DDPM-F64x4/TUG/TUG1250.png
# Processado: TUG1251.png -> DDPM-F64x4/TUG/TUG1251.png
# Processado: TUG1252.png -> DDPM-F64x4/TUG/TUG1252.png
# Processado: TUG1253.png -> DDPM-F64x4/TUG/TUG1253.png
# Processado: TUG1254.png -> DDPM-F64x4/TUG/TUG1254.png
# Processado: TUG1255.png -> DDPM-F64x4/TUG/TUG1255.png
# Processado: TUG1256.png -> DDPM-F64x4/TUG/TUG1256.png
# Processado: TUG1257.png -> DDPM-F64x4/TUG/TUG1257.png
# Processado: TUG1258.png -> DDPM-F64x4/TUG/TUG1258.png
# Processado: TUG1259.png -> DDPM-F64x4/TUG/TUG1259.png
# Processado: TUG126.png -> DDPM-F64x4/TUG/TUG126.png
# Processado: TUG1260.png -> DDPM-F64x4/TUG/TUG1260.png
# Processado: TUG1261.png -> DDPM-F64x4/TUG/TUG1261.png
# Processado: TUG1262.png -> DDPM-F64x4/TUG/TUG1262.png
# Processado: TUG1263.png -> DDPM-F64x4/TUG/TUG1263.png
# Processado: TUG1264.png -> DDPM-F64x4/TUG/TUG1264.png
# Processado: TUG1265.png -> DDPM-F64x4/TUG/TUG1265.png
# Processado: TUG1266.png -> DDPM-F64x4/TUG/TUG1266.png
# Processado: TUG1267.png -> DDPM-F64x4/TUG/TUG1267.png
# Processado: TUG1268.png -> DDPM-F64x4/TUG/TUG1268.png
# Processado: TUG1269.png -> DDPM-F64x4/TUG/TUG1269.png
# Processado: TUG127.png -> DDPM-F64x4/TUG/TUG127.png
# Processado: TUG1270.png -> DDPM-F64x4/TUG/TUG1270.png
# Processado: TUG1271.png -> DDPM-F64x4/TUG/TUG1271.png
# Processado: TUG1272.png -> DDPM-F64x4/TUG/TUG1272.png
# Processado: TUG1273.png -> DDPM-F64x4/TUG/TUG1273.png
# Processado: TUG1274.png -> DDPM-F64x4/TUG/TUG1274.png
# Processado: TUG1275.png -> DDPM-F64x4/TUG/TUG1275.png
# Processado: TUG1276.png -> DDPM-F64x4/TUG/TUG1276.png
# Processado: TUG1277.png -> DDPM-F64x4/TUG/TUG1277.png
# Processado: TUG1278.png -> DDPM-F64x4/TUG/TUG1278.png
# Processado: TUG1279.png -> DDPM-F64x4/TUG/TUG1279.png
# Processado: TUG128.png -> DDPM-F64x4/TUG/TUG128.png
# Processado: TUG1280.png -> DDPM-F64x4/TUG/TUG1280.png
# Processado: TUG1281.png -> DDPM-F64x4/TUG/TUG1281.png
# Processado: TUG1282.png -> DDPM-F64x4/TUG/TUG1282.png
# Processado: TUG1283.png -> DDPM-F64x4/TUG/TUG1283.png
# Processado: TUG1284.png -> DDPM-F64x4/TUG/TUG1284.png
# Processado: TUG1285.png -> DDPM-F64x4/TUG/TUG1285.png
# Processado: TUG1286.png -> DDPM-F64x4/TUG/TUG1286.png
# Processado: TUG1287.png -> DDPM-F64x4/TUG/TUG1287.png
# Processado: TUG1288.png -> DDPM-F64x4/TUG/TUG1288.png
# Processado: TUG1289.png -> DDPM-F64x4/TUG/TUG1289.png
# Processado: TUG129.png -> DDPM-F64x4/TUG/TUG129.png
# Processado: TUG1290.png -> DDPM-F64x4/TUG/TUG1290.png
# Processado: TUG1291.png -> DDPM-F64x4/TUG/TUG1291.png
# Processado: TUG1292.png -> DDPM-F64x4/TUG/TUG1292.png
# Processado: TUG1293.png -> DDPM-F64x4/TUG/TUG1293.png
# Processado: TUG1294.png -> DDPM-F64x4/TUG/TUG1294.png
# Processado: TUG1295.png -> DDPM-F64x4/TUG/TUG1295.png
# Processado: TUG1296.png -> DDPM-F64x4/TUG/TUG1296.png
# Processado: TUG1297.png -> DDPM-F64x4/TUG/TUG1297.png
# Processado: TUG1298.png -> DDPM-F64x4/TUG/TUG1298.png
# Processado: TUG1299.png -> DDPM-F64x4/TUG/TUG1299.png
# Processado: TUG13.png -> DDPM-F64x4/TUG/TUG13.png
# Processado: TUG130.png -> DDPM-F64x4/TUG/TUG130.png
# Processado: TUG1300.png -> DDPM-F64x4/TUG/TUG1300.png
# Processado: TUG1301.png -> DDPM-F64x4/TUG/TUG1301.png
# Processado: TUG1302.png -> DDPM-F64x4/TUG/TUG1302.png
# Processado: TUG1303.png -> DDPM-F64x4/TUG/TUG1303.png
# Processado: TUG1304.png -> DDPM-F64x4/TUG/TUG1304.png
# Processado: TUG1305.png -> DDPM-F64x4/TUG/TUG1305.png
# Processado: TUG1306.png -> DDPM-F64x4/TUG/TUG1306.png
# Processado: TUG1307.png -> DDPM-F64x4/TUG/TUG1307.png
# Processado: TUG1308.png -> DDPM-F64x4/TUG/TUG1308.png
# Processado: TUG1309.png -> DDPM-F64x4/TUG/TUG1309.png
# Processado: TUG131.png -> DDPM-F64x4/TUG/TUG131.png
# Processado: TUG1310.png -> DDPM-F64x4/TUG/TUG1310.png
# Processado: TUG1311.png -> DDPM-F64x4/TUG/TUG1311.png
# Processado: TUG1312.png -> DDPM-F64x4/TUG/TUG1312.png
# Processado: TUG1313.png -> DDPM-F64x4/TUG/TUG1313.png
# Processado: TUG1314.png -> DDPM-F64x4/TUG/TUG1314.png
# Processado: TUG1315.png -> DDPM-F64x4/TUG/TUG1315.png
# Processado: TUG1316.png -> DDPM-F64x4/TUG/TUG1316.png
# Processado: TUG1317.png -> DDPM-F64x4/TUG/TUG1317.png
# Processado: TUG1318.png -> DDPM-F64x4/TUG/TUG1318.png
# Processado: TUG1319.png -> DDPM-F64x4/TUG/TUG1319.png
# Processado: TUG132.png -> DDPM-F64x4/TUG/TUG132.png
# Processado: TUG1320.png -> DDPM-F64x4/TUG/TUG1320.png
# Processado: TUG1321.png -> DDPM-F64x4/TUG/TUG1321.png
# Processado: TUG1322.png -> DDPM-F64x4/TUG/TUG1322.png
# Processado: TUG1323.png -> DDPM-F64x4/TUG/TUG1323.png
# Processado: TUG1324.png -> DDPM-F64x4/TUG/TUG1324.png
# Processado: TUG1325.png -> DDPM-F64x4/TUG/TUG1325.png
# Processado: TUG1326.png -> DDPM-F64x4/TUG/TUG1326.png
# Processado: TUG1327.png -> DDPM-F64x4/TUG/TUG1327.png
# Processado: TUG1328.png -> DDPM-F64x4/TUG/TUG1328.png
# Processado: TUG1329.png -> DDPM-F64x4/TUG/TUG1329.png
# Processado: TUG133.png -> DDPM-F64x4/TUG/TUG133.png
# Processado: TUG1330.png -> DDPM-F64x4/TUG/TUG1330.png
# Processado: TUG1331.png -> DDPM-F64x4/TUG/TUG1331.png
# Processado: TUG1332.png -> DDPM-F64x4/TUG/TUG1332.png
# Processado: TUG1333.png -> DDPM-F64x4/TUG/TUG1333.png
# Processado: TUG1334.png -> DDPM-F64x4/TUG/TUG1334.png
# Processado: TUG1335.png -> DDPM-F64x4/TUG/TUG1335.png
# Processado: TUG1336.png -> DDPM-F64x4/TUG/TUG1336.png
# Processado: TUG1337.png -> DDPM-F64x4/TUG/TUG1337.png
# Processado: TUG1338.png -> DDPM-F64x4/TUG/TUG1338.png
# Processado: TUG1339.png -> DDPM-F64x4/TUG/TUG1339.png
# Processado: TUG134.png -> DDPM-F64x4/TUG/TUG134.png
# Processado: TUG1340.png -> DDPM-F64x4/TUG/TUG1340.png
# Processado: TUG1341.png -> DDPM-F64x4/TUG/TUG1341.png
# Processado: TUG1342.png -> DDPM-F64x4/TUG/TUG1342.png
# Processado: TUG1343.png -> DDPM-F64x4/TUG/TUG1343.png
# Processado: TUG1344.png -> DDPM-F64x4/TUG/TUG1344.png
# Processado: TUG1345.png -> DDPM-F64x4/TUG/TUG1345.png
# Processado: TUG1346.png -> DDPM-F64x4/TUG/TUG1346.png
# Processado: TUG1347.png -> DDPM-F64x4/TUG/TUG1347.png
# Processado: TUG1348.png -> DDPM-F64x4/TUG/TUG1348.png
# Processado: TUG1349.png -> DDPM-F64x4/TUG/TUG1349.png
# Processado: TUG135.png -> DDPM-F64x4/TUG/TUG135.png
# Processado: TUG1350.png -> DDPM-F64x4/TUG/TUG1350.png
# Processado: TUG1351.png -> DDPM-F64x4/TUG/TUG1351.png
# Processado: TUG1352.png -> DDPM-F64x4/TUG/TUG1352.png
# Processado: TUG1353.png -> DDPM-F64x4/TUG/TUG1353.png
# Processado: TUG1354.png -> DDPM-F64x4/TUG/TUG1354.png
# Processado: TUG1355.png -> DDPM-F64x4/TUG/TUG1355.png
# Processado: TUG1356.png -> DDPM-F64x4/TUG/TUG1356.png
# Processado: TUG1357.png -> DDPM-F64x4/TUG/TUG1357.png
# Processado: TUG1358.png -> DDPM-F64x4/TUG/TUG1358.png
# Processado: TUG1359.png -> DDPM-F64x4/TUG/TUG1359.png
# Processado: TUG136.png -> DDPM-F64x4/TUG/TUG136.png
# Processado: TUG1360.png -> DDPM-F64x4/TUG/TUG1360.png
# Processado: TUG1361.png -> DDPM-F64x4/TUG/TUG1361.png
# Processado: TUG1362.png -> DDPM-F64x4/TUG/TUG1362.png
# Processado: TUG1363.png -> DDPM-F64x4/TUG/TUG1363.png
# Processado: TUG1364.png -> DDPM-F64x4/TUG/TUG1364.png
# Processado: TUG1365.png -> DDPM-F64x4/TUG/TUG1365.png
# Processado: TUG1366.png -> DDPM-F64x4/TUG/TUG1366.png
# Processado: TUG1367.png -> DDPM-F64x4/TUG/TUG1367.png
# Processado: TUG1368.png -> DDPM-F64x4/TUG/TUG1368.png
# Processado: TUG1369.png -> DDPM-F64x4/TUG/TUG1369.png
# Processado: TUG137.png -> DDPM-F64x4/TUG/TUG137.png
# Processado: TUG1370.png -> DDPM-F64x4/TUG/TUG1370.png
# Processado: TUG1371.png -> DDPM-F64x4/TUG/TUG1371.png
# Processado: TUG1372.png -> DDPM-F64x4/TUG/TUG1372.png
# Processado: TUG1373.png -> DDPM-F64x4/TUG/TUG1373.png
# Processado: TUG1374.png -> DDPM-F64x4/TUG/TUG1374.png
# Processado: TUG1375.png -> DDPM-F64x4/TUG/TUG1375.png
# Processado: TUG1376.png -> DDPM-F64x4/TUG/TUG1376.png
# Processado: TUG1377.png -> DDPM-F64x4/TUG/TUG1377.png
# Processado: TUG1378.png -> DDPM-F64x4/TUG/TUG1378.png
# Processado: TUG1379.png -> DDPM-F64x4/TUG/TUG1379.png
# Processado: TUG138.png -> DDPM-F64x4/TUG/TUG138.png
# Processado: TUG1380.png -> DDPM-F64x4/TUG/TUG1380.png
# Processado: TUG1381.png -> DDPM-F64x4/TUG/TUG1381.png
# Processado: TUG1382.png -> DDPM-F64x4/TUG/TUG1382.png
# Processado: TUG1383.png -> DDPM-F64x4/TUG/TUG1383.png
# Processado: TUG1384.png -> DDPM-F64x4/TUG/TUG1384.png
# Processado: TUG1385.png -> DDPM-F64x4/TUG/TUG1385.png
# Processado: TUG1386.png -> DDPM-F64x4/TUG/TUG1386.png
# Processado: TUG1387.png -> DDPM-F64x4/TUG/TUG1387.png
# Processado: TUG1388.png -> DDPM-F64x4/TUG/TUG1388.png
# Processado: TUG1389.png -> DDPM-F64x4/TUG/TUG1389.png
# Processado: TUG139.png -> DDPM-F64x4/TUG/TUG139.png
# Processado: TUG1390.png -> DDPM-F64x4/TUG/TUG1390.png
# Processado: TUG1391.png -> DDPM-F64x4/TUG/TUG1391.png
# Processado: TUG1392.png -> DDPM-F64x4/TUG/TUG1392.png
# Processado: TUG1393.png -> DDPM-F64x4/TUG/TUG1393.png
# Processado: TUG1394.png -> DDPM-F64x4/TUG/TUG1394.png
# Processado: TUG1395.png -> DDPM-F64x4/TUG/TUG1395.png
# Processado: TUG1396.png -> DDPM-F64x4/TUG/TUG1396.png
# Processado: TUG1397.png -> DDPM-F64x4/TUG/TUG1397.png
# Processado: TUG1398.png -> DDPM-F64x4/TUG/TUG1398.png
# Processado: TUG1399.png -> DDPM-F64x4/TUG/TUG1399.png
# Processado: TUG14.png -> DDPM-F64x4/TUG/TUG14.png
# Processado: TUG140.png -> DDPM-F64x4/TUG/TUG140.png
# Processado: TUG1400.png -> DDPM-F64x4/TUG/TUG1400.png
# Processado: TUG1401.png -> DDPM-F64x4/TUG/TUG1401.png
# Processado: TUG1402.png -> DDPM-F64x4/TUG/TUG1402.png
# Processado: TUG1403.png -> DDPM-F64x4/TUG/TUG1403.png
# Processado: TUG1404.png -> DDPM-F64x4/TUG/TUG1404.png
# Processado: TUG1405.png -> DDPM-F64x4/TUG/TUG1405.png
# Processado: TUG1406.png -> DDPM-F64x4/TUG/TUG1406.png
# Processado: TUG1407.png -> DDPM-F64x4/TUG/TUG1407.png
# Processado: TUG1408.png -> DDPM-F64x4/TUG/TUG1408.png
# Processado: TUG1409.png -> DDPM-F64x4/TUG/TUG1409.png
# Processado: TUG141.png -> DDPM-F64x4/TUG/TUG141.png
# Processado: TUG1410.png -> DDPM-F64x4/TUG/TUG1410.png
# Processado: TUG1411.png -> DDPM-F64x4/TUG/TUG1411.png
# Processado: TUG1412.png -> DDPM-F64x4/TUG/TUG1412.png
# Processado: TUG1413.png -> DDPM-F64x4/TUG/TUG1413.png
# Processado: TUG1414.png -> DDPM-F64x4/TUG/TUG1414.png
# Processado: TUG1415.png -> DDPM-F64x4/TUG/TUG1415.png
# Processado: TUG1416.png -> DDPM-F64x4/TUG/TUG1416.png
# Processado: TUG1417.png -> DDPM-F64x4/TUG/TUG1417.png
# Processado: TUG1418.png -> DDPM-F64x4/TUG/TUG1418.png
# Processado: TUG1419.png -> DDPM-F64x4/TUG/TUG1419.png
# Processado: TUG142.png -> DDPM-F64x4/TUG/TUG142.png
# Processado: TUG1420.png -> DDPM-F64x4/TUG/TUG1420.png
# Processado: TUG1421.png -> DDPM-F64x4/TUG/TUG1421.png
# Processado: TUG1422.png -> DDPM-F64x4/TUG/TUG1422.png
# Processado: TUG1423.png -> DDPM-F64x4/TUG/TUG1423.png
# Processado: TUG1424.png -> DDPM-F64x4/TUG/TUG1424.png
# Processado: TUG1425.png -> DDPM-F64x4/TUG/TUG1425.png
# Processado: TUG1426.png -> DDPM-F64x4/TUG/TUG1426.png
# Processado: TUG1427.png -> DDPM-F64x4/TUG/TUG1427.png
# Processado: TUG1428.png -> DDPM-F64x4/TUG/TUG1428.png
# Processado: TUG1429.png -> DDPM-F64x4/TUG/TUG1429.png
# Processado: TUG143.png -> DDPM-F64x4/TUG/TUG143.png
# Processado: TUG1430.png -> DDPM-F64x4/TUG/TUG1430.png
# Processado: TUG1431.png -> DDPM-F64x4/TUG/TUG1431.png
# Processado: TUG1432.png -> DDPM-F64x4/TUG/TUG1432.png
# Processado: TUG1433.png -> DDPM-F64x4/TUG/TUG1433.png
# Processado: TUG1434.png -> DDPM-F64x4/TUG/TUG1434.png
# Processado: TUG1435.png -> DDPM-F64x4/TUG/TUG1435.png
# Processado: TUG1436.png -> DDPM-F64x4/TUG/TUG1436.png
# Processado: TUG1437.png -> DDPM-F64x4/TUG/TUG1437.png
# Processado: TUG1438.png -> DDPM-F64x4/TUG/TUG1438.png
# Processado: TUG1439.png -> DDPM-F64x4/TUG/TUG1439.png
# Processado: TUG144.png -> DDPM-F64x4/TUG/TUG144.png
# Processado: TUG1440.png -> DDPM-F64x4/TUG/TUG1440.png
# Processado: TUG1441.png -> DDPM-F64x4/TUG/TUG1441.png
# Processado: TUG1442.png -> DDPM-F64x4/TUG/TUG1442.png
# Processado: TUG1443.png -> DDPM-F64x4/TUG/TUG1443.png
# Processado: TUG1444.png -> DDPM-F64x4/TUG/TUG1444.png
# Processado: TUG1445.png -> DDPM-F64x4/TUG/TUG1445.png
# Processado: TUG1446.png -> DDPM-F64x4/TUG/TUG1446.png
# Processado: TUG1447.png -> DDPM-F64x4/TUG/TUG1447.png
# Processado: TUG1448.png -> DDPM-F64x4/TUG/TUG1448.png
# Processado: TUG1449.png -> DDPM-F64x4/TUG/TUG1449.png
# Processado: TUG145.png -> DDPM-F64x4/TUG/TUG145.png
# Processado: TUG1450.png -> DDPM-F64x4/TUG/TUG1450.png
# Processado: TUG1451.png -> DDPM-F64x4/TUG/TUG1451.png
# Processado: TUG1452.png -> DDPM-F64x4/TUG/TUG1452.png
# Processado: TUG1453.png -> DDPM-F64x4/TUG/TUG1453.png
# Processado: TUG1454.png -> DDPM-F64x4/TUG/TUG1454.png
# Processado: TUG1455.png -> DDPM-F64x4/TUG/TUG1455.png
# Processado: TUG1456.png -> DDPM-F64x4/TUG/TUG1456.png
# Processado: TUG1457.png -> DDPM-F64x4/TUG/TUG1457.png
# Processado: TUG1458.png -> DDPM-F64x4/TUG/TUG1458.png
# Processado: TUG1459.png -> DDPM-F64x4/TUG/TUG1459.png
# Processado: TUG146.png -> DDPM-F64x4/TUG/TUG146.png
# Processado: TUG1460.png -> DDPM-F64x4/TUG/TUG1460.png
# Processado: TUG1461.png -> DDPM-F64x4/TUG/TUG1461.png
# Processado: TUG1462.png -> DDPM-F64x4/TUG/TUG1462.png
# Processado: TUG1463.png -> DDPM-F64x4/TUG/TUG1463.png
# Processado: TUG1464.png -> DDPM-F64x4/TUG/TUG1464.png
# Processado: TUG1465.png -> DDPM-F64x4/TUG/TUG1465.png
# Processado: TUG1466.png -> DDPM-F64x4/TUG/TUG1466.png
# Processado: TUG1467.png -> DDPM-F64x4/TUG/TUG1467.png
# Processado: TUG1468.png -> DDPM-F64x4/TUG/TUG1468.png
# Processado: TUG1469.png -> DDPM-F64x4/TUG/TUG1469.png
# Processado: TUG147.png -> DDPM-F64x4/TUG/TUG147.png
# Processado: TUG1470.png -> DDPM-F64x4/TUG/TUG1470.png
# Processado: TUG1471.png -> DDPM-F64x4/TUG/TUG1471.png
# Processado: TUG1472.png -> DDPM-F64x4/TUG/TUG1472.png
# Processado: TUG1473.png -> DDPM-F64x4/TUG/TUG1473.png
# Processado: TUG1474.png -> DDPM-F64x4/TUG/TUG1474.png
# Processado: TUG1475.png -> DDPM-F64x4/TUG/TUG1475.png
# Processado: TUG1476.png -> DDPM-F64x4/TUG/TUG1476.png
# Processado: TUG1477.png -> DDPM-F64x4/TUG/TUG1477.png
# Processado: TUG1478.png -> DDPM-F64x4/TUG/TUG1478.png
# Processado: TUG1479.png -> DDPM-F64x4/TUG/TUG1479.png
# Processado: TUG148.png -> DDPM-F64x4/TUG/TUG148.png
# Processado: TUG1480.png -> DDPM-F64x4/TUG/TUG1480.png
# Processado: TUG1481.png -> DDPM-F64x4/TUG/TUG1481.png
# Processado: TUG1482.png -> DDPM-F64x4/TUG/TUG1482.png
# Processado: TUG1483.png -> DDPM-F64x4/TUG/TUG1483.png
# Processado: TUG1484.png -> DDPM-F64x4/TUG/TUG1484.png
# Processado: TUG1485.png -> DDPM-F64x4/TUG/TUG1485.png
# Processado: TUG1486.png -> DDPM-F64x4/TUG/TUG1486.png
# Processado: TUG1487.png -> DDPM-F64x4/TUG/TUG1487.png
# Processado: TUG1488.png -> DDPM-F64x4/TUG/TUG1488.png
# Processado: TUG1489.png -> DDPM-F64x4/TUG/TUG1489.png
# Processado: TUG149.png -> DDPM-F64x4/TUG/TUG149.png
# Processado: TUG1490.png -> DDPM-F64x4/TUG/TUG1490.png
# Processado: TUG1491.png -> DDPM-F64x4/TUG/TUG1491.png
# Processado: TUG1492.png -> DDPM-F64x4/TUG/TUG1492.png
# Processado: TUG1493.png -> DDPM-F64x4/TUG/TUG1493.png
# Processado: TUG1494.png -> DDPM-F64x4/TUG/TUG1494.png
# Processado: TUG1495.png -> DDPM-F64x4/TUG/TUG1495.png
# Processado: TUG1496.png -> DDPM-F64x4/TUG/TUG1496.png
# Processado: TUG1497.png -> DDPM-F64x4/TUG/TUG1497.png
# Processado: TUG1498.png -> DDPM-F64x4/TUG/TUG1498.png
# Processado: TUG1499.png -> DDPM-F64x4/TUG/TUG1499.png
# Processado: TUG15.png -> DDPM-F64x4/TUG/TUG15.png
# Processado: TUG150.png -> DDPM-F64x4/TUG/TUG150.png
# Processado: TUG1500.png -> DDPM-F64x4/TUG/TUG1500.png
# Processado: TUG1501.png -> DDPM-F64x4/TUG/TUG1501.png
# Processado: TUG1502.png -> DDPM-F64x4/TUG/TUG1502.png
# Processado: TUG1503.png -> DDPM-F64x4/TUG/TUG1503.png
# Processado: TUG1504.png -> DDPM-F64x4/TUG/TUG1504.png
# Processado: TUG1505.png -> DDPM-F64x4/TUG/TUG1505.png
# Processado: TUG1506.png -> DDPM-F64x4/TUG/TUG1506.png
# Processado: TUG1507.png -> DDPM-F64x4/TUG/TUG1507.png
# Processado: TUG1508.png -> DDPM-F64x4/TUG/TUG1508.png
# Processado: TUG1509.png -> DDPM-F64x4/TUG/TUG1509.png
# Processado: TUG151.png -> DDPM-F64x4/TUG/TUG151.png
# Processado: TUG1510.png -> DDPM-F64x4/TUG/TUG1510.png
# Processado: TUG1511.png -> DDPM-F64x4/TUG/TUG1511.png
# Processado: TUG1512.png -> DDPM-F64x4/TUG/TUG1512.png
# Processado: TUG1513.png -> DDPM-F64x4/TUG/TUG1513.png
# Processado: TUG1514.png -> DDPM-F64x4/TUG/TUG1514.png
# Processado: TUG1515.png -> DDPM-F64x4/TUG/TUG1515.png
# Processado: TUG1516.png -> DDPM-F64x4/TUG/TUG1516.png
# Processado: TUG1517.png -> DDPM-F64x4/TUG/TUG1517.png
# Processado: TUG1518.png -> DDPM-F64x4/TUG/TUG1518.png
# Processado: TUG1519.png -> DDPM-F64x4/TUG/TUG1519.png
# Processado: TUG152.png -> DDPM-F64x4/TUG/TUG152.png
# Processado: TUG1520.png -> DDPM-F64x4/TUG/TUG1520.png
# Processado: TUG1521.png -> DDPM-F64x4/TUG/TUG1521.png
# Processado: TUG1522.png -> DDPM-F64x4/TUG/TUG1522.png
# Processado: TUG1523.png -> DDPM-F64x4/TUG/TUG1523.png
# Processado: TUG1524.png -> DDPM-F64x4/TUG/TUG1524.png
# Processado: TUG1525.png -> DDPM-F64x4/TUG/TUG1525.png
# Processado: TUG1526.png -> DDPM-F64x4/TUG/TUG1526.png
# Processado: TUG1527.png -> DDPM-F64x4/TUG/TUG1527.png
# Processado: TUG1528.png -> DDPM-F64x4/TUG/TUG1528.png
# Processado: TUG1529.png -> DDPM-F64x4/TUG/TUG1529.png
# Processado: TUG153.png -> DDPM-F64x4/TUG/TUG153.png
# Processado: TUG1530.png -> DDPM-F64x4/TUG/TUG1530.png
# Processado: TUG1531.png -> DDPM-F64x4/TUG/TUG1531.png
# Processado: TUG1532.png -> DDPM-F64x4/TUG/TUG1532.png
# Processado: TUG1533.png -> DDPM-F64x4/TUG/TUG1533.png
# Processado: TUG1534.png -> DDPM-F64x4/TUG/TUG1534.png
# Processado: TUG1535.png -> DDPM-F64x4/TUG/TUG1535.png
# Processado: TUG1536.png -> DDPM-F64x4/TUG/TUG1536.png
# Processado: TUG1537.png -> DDPM-F64x4/TUG/TUG1537.png
# Processado: TUG1538.png -> DDPM-F64x4/TUG/TUG1538.png
# Processado: TUG1539.png -> DDPM-F64x4/TUG/TUG1539.png
# Processado: TUG154.png -> DDPM-F64x4/TUG/TUG154.png
# Processado: TUG1540.png -> DDPM-F64x4/TUG/TUG1540.png
# Processado: TUG1541.png -> DDPM-F64x4/TUG/TUG1541.png
# Processado: TUG1542.png -> DDPM-F64x4/TUG/TUG1542.png
# Processado: TUG1543.png -> DDPM-F64x4/TUG/TUG1543.png
# Processado: TUG1544.png -> DDPM-F64x4/TUG/TUG1544.png
# Processado: TUG1545.png -> DDPM-F64x4/TUG/TUG1545.png
# Processado: TUG1546.png -> DDPM-F64x4/TUG/TUG1546.png
# Processado: TUG1547.png -> DDPM-F64x4/TUG/TUG1547.png
# Processado: TUG1548.png -> DDPM-F64x4/TUG/TUG1548.png
# Processado: TUG1549.png -> DDPM-F64x4/TUG/TUG1549.png
# Processado: TUG155.png -> DDPM-F64x4/TUG/TUG155.png
# Processado: TUG1550.png -> DDPM-F64x4/TUG/TUG1550.png
# Processado: TUG1551.png -> DDPM-F64x4/TUG/TUG1551.png
# Processado: TUG1552.png -> DDPM-F64x4/TUG/TUG1552.png
# Processado: TUG1553.png -> DDPM-F64x4/TUG/TUG1553.png
# Processado: TUG1554.png -> DDPM-F64x4/TUG/TUG1554.png
# Processado: TUG1555.png -> DDPM-F64x4/TUG/TUG1555.png
# Processado: TUG1556.png -> DDPM-F64x4/TUG/TUG1556.png
# Processado: TUG1557.png -> DDPM-F64x4/TUG/TUG1557.png
# Processado: TUG1558.png -> DDPM-F64x4/TUG/TUG1558.png
# Processado: TUG1559.png -> DDPM-F64x4/TUG/TUG1559.png
# Processado: TUG156.png -> DDPM-F64x4/TUG/TUG156.png
# Processado: TUG1560.png -> DDPM-F64x4/TUG/TUG1560.png
# Processado: TUG1561.png -> DDPM-F64x4/TUG/TUG1561.png
# Processado: TUG1562.png -> DDPM-F64x4/TUG/TUG1562.png
# Processado: TUG1563.png -> DDPM-F64x4/TUG/TUG1563.png
# Processado: TUG1564.png -> DDPM-F64x4/TUG/TUG1564.png
# Processado: TUG1565.png -> DDPM-F64x4/TUG/TUG1565.png
# Processado: TUG1566.png -> DDPM-F64x4/TUG/TUG1566.png
# Processado: TUG1567.png -> DDPM-F64x4/TUG/TUG1567.png
# Processado: TUG1568.png -> DDPM-F64x4/TUG/TUG1568.png
# Processado: TUG1569.png -> DDPM-F64x4/TUG/TUG1569.png
# Processado: TUG157.png -> DDPM-F64x4/TUG/TUG157.png
# Processado: TUG1570.png -> DDPM-F64x4/TUG/TUG1570.png
# Processado: TUG1571.png -> DDPM-F64x4/TUG/TUG1571.png
# Processado: TUG1572.png -> DDPM-F64x4/TUG/TUG1572.png
# Processado: TUG1573.png -> DDPM-F64x4/TUG/TUG1573.png
# Processado: TUG1574.png -> DDPM-F64x4/TUG/TUG1574.png
# Processado: TUG1575.png -> DDPM-F64x4/TUG/TUG1575.png
# Processado: TUG1576.png -> DDPM-F64x4/TUG/TUG1576.png
# Processado: TUG1577.png -> DDPM-F64x4/TUG/TUG1577.png
# Processado: TUG1578.png -> DDPM-F64x4/TUG/TUG1578.png
# Processado: TUG1579.png -> DDPM-F64x4/TUG/TUG1579.png
# Processado: TUG158.png -> DDPM-F64x4/TUG/TUG158.png
# Processado: TUG1580.png -> DDPM-F64x4/TUG/TUG1580.png
# Processado: TUG1581.png -> DDPM-F64x4/TUG/TUG1581.png
# Processado: TUG1582.png -> DDPM-F64x4/TUG/TUG1582.png
# Processado: TUG1583.png -> DDPM-F64x4/TUG/TUG1583.png
# Processado: TUG1584.png -> DDPM-F64x4/TUG/TUG1584.png
# Processado: TUG1585.png -> DDPM-F64x4/TUG/TUG1585.png
# Processado: TUG1586.png -> DDPM-F64x4/TUG/TUG1586.png
# Processado: TUG1587.png -> DDPM-F64x4/TUG/TUG1587.png
# Processado: TUG1588.png -> DDPM-F64x4/TUG/TUG1588.png
# Processado: TUG1589.png -> DDPM-F64x4/TUG/TUG1589.png
# Processado: TUG159.png -> DDPM-F64x4/TUG/TUG159.png
# Processado: TUG1590.png -> DDPM-F64x4/TUG/TUG1590.png
# Processado: TUG1591.png -> DDPM-F64x4/TUG/TUG1591.png
# Processado: TUG1592.png -> DDPM-F64x4/TUG/TUG1592.png
# Processado: TUG1593.png -> DDPM-F64x4/TUG/TUG1593.png
# Processado: TUG1594.png -> DDPM-F64x4/TUG/TUG1594.png
# Processado: TUG1595.png -> DDPM-F64x4/TUG/TUG1595.png
# Processado: TUG1596.png -> DDPM-F64x4/TUG/TUG1596.png
# Processado: TUG1597.png -> DDPM-F64x4/TUG/TUG1597.png
# Processado: TUG1598.png -> DDPM-F64x4/TUG/TUG1598.png
# Processado: TUG1599.png -> DDPM-F64x4/TUG/TUG1599.png
# Processado: TUG16.png -> DDPM-F64x4/TUG/TUG16.png
# Processado: TUG160.png -> DDPM-F64x4/TUG/TUG160.png
# Processado: TUG1600.png -> DDPM-F64x4/TUG/TUG1600.png
# Processado: TUG1601.png -> DDPM-F64x4/TUG/TUG1601.png
# Processado: TUG1602.png -> DDPM-F64x4/TUG/TUG1602.png
# Processado: TUG1603.png -> DDPM-F64x4/TUG/TUG1603.png
# Processado: TUG1604.png -> DDPM-F64x4/TUG/TUG1604.png
# Processado: TUG1605.png -> DDPM-F64x4/TUG/TUG1605.png
# Processado: TUG1606.png -> DDPM-F64x4/TUG/TUG1606.png
# Processado: TUG1607.png -> DDPM-F64x4/TUG/TUG1607.png
# Processado: TUG1608.png -> DDPM-F64x4/TUG/TUG1608.png
# Processado: TUG1609.png -> DDPM-F64x4/TUG/TUG1609.png
# Processado: TUG161.png -> DDPM-F64x4/TUG/TUG161.png
# Processado: TUG1610.png -> DDPM-F64x4/TUG/TUG1610.png
# Processado: TUG1611.png -> DDPM-F64x4/TUG/TUG1611.png
# Processado: TUG1612.png -> DDPM-F64x4/TUG/TUG1612.png
# Processado: TUG1613.png -> DDPM-F64x4/TUG/TUG1613.png
# Processado: TUG1614.png -> DDPM-F64x4/TUG/TUG1614.png
# Processado: TUG1615.png -> DDPM-F64x4/TUG/TUG1615.png
# Processado: TUG1616.png -> DDPM-F64x4/TUG/TUG1616.png
# Processado: TUG1617.png -> DDPM-F64x4/TUG/TUG1617.png
# Processado: TUG1618.png -> DDPM-F64x4/TUG/TUG1618.png
# Processado: TUG1619.png -> DDPM-F64x4/TUG/TUG1619.png
# Processado: TUG162.png -> DDPM-F64x4/TUG/TUG162.png
# Processado: TUG1620.png -> DDPM-F64x4/TUG/TUG1620.png
# Processado: TUG1621.png -> DDPM-F64x4/TUG/TUG1621.png
# Processado: TUG1622.png -> DDPM-F64x4/TUG/TUG1622.png
# Processado: TUG1623.png -> DDPM-F64x4/TUG/TUG1623.png
# Processado: TUG1624.png -> DDPM-F64x4/TUG/TUG1624.png
# Processado: TUG1625.png -> DDPM-F64x4/TUG/TUG1625.png
# Processado: TUG1626.png -> DDPM-F64x4/TUG/TUG1626.png
# Processado: TUG1627.png -> DDPM-F64x4/TUG/TUG1627.png
# Processado: TUG1628.png -> DDPM-F64x4/TUG/TUG1628.png
# Processado: TUG1629.png -> DDPM-F64x4/TUG/TUG1629.png
# Processado: TUG163.png -> DDPM-F64x4/TUG/TUG163.png
# Processado: TUG1630.png -> DDPM-F64x4/TUG/TUG1630.png
# Processado: TUG1631.png -> DDPM-F64x4/TUG/TUG1631.png
# Processado: TUG1632.png -> DDPM-F64x4/TUG/TUG1632.png
# Processado: TUG1633.png -> DDPM-F64x4/TUG/TUG1633.png
# Processado: TUG1634.png -> DDPM-F64x4/TUG/TUG1634.png
# Processado: TUG1635.png -> DDPM-F64x4/TUG/TUG1635.png
# Processado: TUG1636.png -> DDPM-F64x4/TUG/TUG1636.png
# Processado: TUG1637.png -> DDPM-F64x4/TUG/TUG1637.png
# Processado: TUG1638.png -> DDPM-F64x4/TUG/TUG1638.png
# Processado: TUG1639.png -> DDPM-F64x4/TUG/TUG1639.png
# Processado: TUG164.png -> DDPM-F64x4/TUG/TUG164.png
# Processado: TUG1640.png -> DDPM-F64x4/TUG/TUG1640.png
# Processado: TUG1641.png -> DDPM-F64x4/TUG/TUG1641.png
# Processado: TUG1642.png -> DDPM-F64x4/TUG/TUG1642.png
# Processado: TUG1643.png -> DDPM-F64x4/TUG/TUG1643.png
# Processado: TUG1644.png -> DDPM-F64x4/TUG/TUG1644.png
# Processado: TUG1645.png -> DDPM-F64x4/TUG/TUG1645.png
# Processado: TUG1646.png -> DDPM-F64x4/TUG/TUG1646.png
# Processado: TUG1647.png -> DDPM-F64x4/TUG/TUG1647.png
# Processado: TUG1648.png -> DDPM-F64x4/TUG/TUG1648.png
# Processado: TUG1649.png -> DDPM-F64x4/TUG/TUG1649.png
# Processado: TUG165.png -> DDPM-F64x4/TUG/TUG165.png
# Processado: TUG1650.png -> DDPM-F64x4/TUG/TUG1650.png
# Processado: TUG1651.png -> DDPM-F64x4/TUG/TUG1651.png
# Processado: TUG1652.png -> DDPM-F64x4/TUG/TUG1652.png
# Processado: TUG1653.png -> DDPM-F64x4/TUG/TUG1653.png
# Processado: TUG1654.png -> DDPM-F64x4/TUG/TUG1654.png
# Processado: TUG1655.png -> DDPM-F64x4/TUG/TUG1655.png
# Processado: TUG1656.png -> DDPM-F64x4/TUG/TUG1656.png
# Processado: TUG1657.png -> DDPM-F64x4/TUG/TUG1657.png
# Processado: TUG1658.png -> DDPM-F64x4/TUG/TUG1658.png
# Processado: TUG1659.png -> DDPM-F64x4/TUG/TUG1659.png
# Processado: TUG166.png -> DDPM-F64x4/TUG/TUG166.png
# Processado: TUG1660.png -> DDPM-F64x4/TUG/TUG1660.png
# Processado: TUG1661.png -> DDPM-F64x4/TUG/TUG1661.png
# Processado: TUG1662.png -> DDPM-F64x4/TUG/TUG1662.png
# Processado: TUG1663.png -> DDPM-F64x4/TUG/TUG1663.png
# Processado: TUG1664.png -> DDPM-F64x4/TUG/TUG1664.png
# Processado: TUG1665.png -> DDPM-F64x4/TUG/TUG1665.png
# Processado: TUG1666.png -> DDPM-F64x4/TUG/TUG1666.png
# Processado: TUG1667.png -> DDPM-F64x4/TUG/TUG1667.png
# Processado: TUG1668.png -> DDPM-F64x4/TUG/TUG1668.png
# Processado: TUG1669.png -> DDPM-F64x4/TUG/TUG1669.png
# Processado: TUG167.png -> DDPM-F64x4/TUG/TUG167.png
# Processado: TUG1670.png -> DDPM-F64x4/TUG/TUG1670.png
# Processado: TUG1671.png -> DDPM-F64x4/TUG/TUG1671.png
# Processado: TUG1672.png -> DDPM-F64x4/TUG/TUG1672.png
# Processado: TUG1673.png -> DDPM-F64x4/TUG/TUG1673.png
# Processado: TUG1674.png -> DDPM-F64x4/TUG/TUG1674.png
# Processado: TUG1675.png -> DDPM-F64x4/TUG/TUG1675.png
# Processado: TUG1676.png -> DDPM-F64x4/TUG/TUG1676.png
# Processado: TUG1677.png -> DDPM-F64x4/TUG/TUG1677.png
# Processado: TUG1678.png -> DDPM-F64x4/TUG/TUG1678.png
# Processado: TUG1679.png -> DDPM-F64x4/TUG/TUG1679.png
# Processado: TUG168.png -> DDPM-F64x4/TUG/TUG168.png
# Processado: TUG1680.png -> DDPM-F64x4/TUG/TUG1680.png
# Processado: TUG1681.png -> DDPM-F64x4/TUG/TUG1681.png
# Processado: TUG1682.png -> DDPM-F64x4/TUG/TUG1682.png
# Processado: TUG1683.png -> DDPM-F64x4/TUG/TUG1683.png
# Processado: TUG1684.png -> DDPM-F64x4/TUG/TUG1684.png
# Processado: TUG1685.png -> DDPM-F64x4/TUG/TUG1685.png
# Processado: TUG1686.png -> DDPM-F64x4/TUG/TUG1686.png
# Processado: TUG1687.png -> DDPM-F64x4/TUG/TUG1687.png
# Processado: TUG1688.png -> DDPM-F64x4/TUG/TUG1688.png
# Processado: TUG1689.png -> DDPM-F64x4/TUG/TUG1689.png
# Processado: TUG169.png -> DDPM-F64x4/TUG/TUG169.png
# Processado: TUG1690.png -> DDPM-F64x4/TUG/TUG1690.png
# Processado: TUG1691.png -> DDPM-F64x4/TUG/TUG1691.png
# Processado: TUG1692.png -> DDPM-F64x4/TUG/TUG1692.png
# Processado: TUG1693.png -> DDPM-F64x4/TUG/TUG1693.png
# Processado: TUG1694.png -> DDPM-F64x4/TUG/TUG1694.png
# Processado: TUG1695.png -> DDPM-F64x4/TUG/TUG1695.png
# Processado: TUG1696.png -> DDPM-F64x4/TUG/TUG1696.png
# Processado: TUG1697.png -> DDPM-F64x4/TUG/TUG1697.png
# Processado: TUG1698.png -> DDPM-F64x4/TUG/TUG1698.png
# Processado: TUG1699.png -> DDPM-F64x4/TUG/TUG1699.png
# Processado: TUG17.png -> DDPM-F64x4/TUG/TUG17.png
# Processado: TUG170.png -> DDPM-F64x4/TUG/TUG170.png
# Processado: TUG1700.png -> DDPM-F64x4/TUG/TUG1700.png
# Processado: TUG1701.png -> DDPM-F64x4/TUG/TUG1701.png
# Processado: TUG1702.png -> DDPM-F64x4/TUG/TUG1702.png
# Processado: TUG1703.png -> DDPM-F64x4/TUG/TUG1703.png
# Processado: TUG1704.png -> DDPM-F64x4/TUG/TUG1704.png
# Processado: TUG1705.png -> DDPM-F64x4/TUG/TUG1705.png
# Processado: TUG1706.png -> DDPM-F64x4/TUG/TUG1706.png
# Processado: TUG1707.png -> DDPM-F64x4/TUG/TUG1707.png
# Processado: TUG1708.png -> DDPM-F64x4/TUG/TUG1708.png
# Processado: TUG1709.png -> DDPM-F64x4/TUG/TUG1709.png
# Processado: TUG171.png -> DDPM-F64x4/TUG/TUG171.png
# Processado: TUG1710.png -> DDPM-F64x4/TUG/TUG1710.png
# Processado: TUG1711.png -> DDPM-F64x4/TUG/TUG1711.png
# Processado: TUG1712.png -> DDPM-F64x4/TUG/TUG1712.png
# Processado: TUG1713.png -> DDPM-F64x4/TUG/TUG1713.png
# Processado: TUG1714.png -> DDPM-F64x4/TUG/TUG1714.png
# Processado: TUG1715.png -> DDPM-F64x4/TUG/TUG1715.png
# Processado: TUG1716.png -> DDPM-F64x4/TUG/TUG1716.png
# Processado: TUG1717.png -> DDPM-F64x4/TUG/TUG1717.png
# Processado: TUG1718.png -> DDPM-F64x4/TUG/TUG1718.png
# Processado: TUG1719.png -> DDPM-F64x4/TUG/TUG1719.png
# Processado: TUG172.png -> DDPM-F64x4/TUG/TUG172.png
# Processado: TUG1720.png -> DDPM-F64x4/TUG/TUG1720.png
# Processado: TUG1721.png -> DDPM-F64x4/TUG/TUG1721.png
# Processado: TUG1722.png -> DDPM-F64x4/TUG/TUG1722.png
# Processado: TUG1723.png -> DDPM-F64x4/TUG/TUG1723.png
# Processado: TUG1724.png -> DDPM-F64x4/TUG/TUG1724.png
# Processado: TUG1725.png -> DDPM-F64x4/TUG/TUG1725.png
# Processado: TUG1726.png -> DDPM-F64x4/TUG/TUG1726.png
# Processado: TUG1727.png -> DDPM-F64x4/TUG/TUG1727.png
# Processado: TUG1728.png -> DDPM-F64x4/TUG/TUG1728.png
# Processado: TUG1729.png -> DDPM-F64x4/TUG/TUG1729.png
# Processado: TUG173.png -> DDPM-F64x4/TUG/TUG173.png
# Processado: TUG1730.png -> DDPM-F64x4/TUG/TUG1730.png
# Processado: TUG1731.png -> DDPM-F64x4/TUG/TUG1731.png
# Processado: TUG1732.png -> DDPM-F64x4/TUG/TUG1732.png
# Processado: TUG1733.png -> DDPM-F64x4/TUG/TUG1733.png
# Processado: TUG1734.png -> DDPM-F64x4/TUG/TUG1734.png
# Processado: TUG1735.png -> DDPM-F64x4/TUG/TUG1735.png
# Processado: TUG1736.png -> DDPM-F64x4/TUG/TUG1736.png
# Processado: TUG1737.png -> DDPM-F64x4/TUG/TUG1737.png
# Processado: TUG1738.png -> DDPM-F64x4/TUG/TUG1738.png
# Processado: TUG1739.png -> DDPM-F64x4/TUG/TUG1739.png
# Processado: TUG174.png -> DDPM-F64x4/TUG/TUG174.png
# Processado: TUG1740.png -> DDPM-F64x4/TUG/TUG1740.png
# Processado: TUG1741.png -> DDPM-F64x4/TUG/TUG1741.png
# Processado: TUG1742.png -> DDPM-F64x4/TUG/TUG1742.png
# Processado: TUG1743.png -> DDPM-F64x4/TUG/TUG1743.png
# Processado: TUG1744.png -> DDPM-F64x4/TUG/TUG1744.png
# Processado: TUG1745.png -> DDPM-F64x4/TUG/TUG1745.png
# Processado: TUG1746.png -> DDPM-F64x4/TUG/TUG1746.png
# Processado: TUG1747.png -> DDPM-F64x4/TUG/TUG1747.png
# Processado: TUG1748.png -> DDPM-F64x4/TUG/TUG1748.png
# Processado: TUG1749.png -> DDPM-F64x4/TUG/TUG1749.png
# Processado: TUG175.png -> DDPM-F64x4/TUG/TUG175.png
# Processado: TUG1750.png -> DDPM-F64x4/TUG/TUG1750.png
# Processado: TUG1751.png -> DDPM-F64x4/TUG/TUG1751.png
# Processado: TUG1752.png -> DDPM-F64x4/TUG/TUG1752.png
# Processado: TUG1753.png -> DDPM-F64x4/TUG/TUG1753.png
# Processado: TUG1754.png -> DDPM-F64x4/TUG/TUG1754.png
# Processado: TUG1755.png -> DDPM-F64x4/TUG/TUG1755.png
# Processado: TUG1756.png -> DDPM-F64x4/TUG/TUG1756.png
# Processado: TUG1757.png -> DDPM-F64x4/TUG/TUG1757.png
# Processado: TUG1758.png -> DDPM-F64x4/TUG/TUG1758.png
# Processado: TUG1759.png -> DDPM-F64x4/TUG/TUG1759.png
# Processado: TUG176.png -> DDPM-F64x4/TUG/TUG176.png
# Processado: TUG1760.png -> DDPM-F64x4/TUG/TUG1760.png
# Processado: TUG1761.png -> DDPM-F64x4/TUG/TUG1761.png
# Processado: TUG1762.png -> DDPM-F64x4/TUG/TUG1762.png
# Processado: TUG1763.png -> DDPM-F64x4/TUG/TUG1763.png
# Processado: TUG1764.png -> DDPM-F64x4/TUG/TUG1764.png
# Processado: TUG1765.png -> DDPM-F64x4/TUG/TUG1765.png
# Processado: TUG1766.png -> DDPM-F64x4/TUG/TUG1766.png
# Processado: TUG1767.png -> DDPM-F64x4/TUG/TUG1767.png
# Processado: TUG1768.png -> DDPM-F64x4/TUG/TUG1768.png
# Processado: TUG1769.png -> DDPM-F64x4/TUG/TUG1769.png
# Processado: TUG177.png -> DDPM-F64x4/TUG/TUG177.png
# Processado: TUG1770.png -> DDPM-F64x4/TUG/TUG1770.png
# Processado: TUG1771.png -> DDPM-F64x4/TUG/TUG1771.png
# Processado: TUG1772.png -> DDPM-F64x4/TUG/TUG1772.png
# Processado: TUG1773.png -> DDPM-F64x4/TUG/TUG1773.png
# Processado: TUG1774.png -> DDPM-F64x4/TUG/TUG1774.png
# Processado: TUG1775.png -> DDPM-F64x4/TUG/TUG1775.png
# Processado: TUG1776.png -> DDPM-F64x4/TUG/TUG1776.png
# Processado: TUG1777.png -> DDPM-F64x4/TUG/TUG1777.png
# Processado: TUG1778.png -> DDPM-F64x4/TUG/TUG1778.png
# Processado: TUG1779.png -> DDPM-F64x4/TUG/TUG1779.png
# Processado: TUG178.png -> DDPM-F64x4/TUG/TUG178.png
# Processado: TUG1780.png -> DDPM-F64x4/TUG/TUG1780.png
# Processado: TUG1781.png -> DDPM-F64x4/TUG/TUG1781.png
# Processado: TUG1782.png -> DDPM-F64x4/TUG/TUG1782.png
# Processado: TUG1783.png -> DDPM-F64x4/TUG/TUG1783.png
# Processado: TUG1784.png -> DDPM-F64x4/TUG/TUG1784.png
# Processado: TUG1785.png -> DDPM-F64x4/TUG/TUG1785.png
# Processado: TUG1786.png -> DDPM-F64x4/TUG/TUG1786.png
# Processado: TUG1787.png -> DDPM-F64x4/TUG/TUG1787.png
# Processado: TUG1788.png -> DDPM-F64x4/TUG/TUG1788.png
# Processado: TUG1789.png -> DDPM-F64x4/TUG/TUG1789.png
# Processado: TUG179.png -> DDPM-F64x4/TUG/TUG179.png
# Processado: TUG1790.png -> DDPM-F64x4/TUG/TUG1790.png
# Processado: TUG1791.png -> DDPM-F64x4/TUG/TUG1791.png
# Processado: TUG1792.png -> DDPM-F64x4/TUG/TUG1792.png
# Processado: TUG1793.png -> DDPM-F64x4/TUG/TUG1793.png
# Processado: TUG1794.png -> DDPM-F64x4/TUG/TUG1794.png
# Processado: TUG1795.png -> DDPM-F64x4/TUG/TUG1795.png
# Processado: TUG1796.png -> DDPM-F64x4/TUG/TUG1796.png
# Processado: TUG1797.png -> DDPM-F64x4/TUG/TUG1797.png
# Processado: TUG1798.png -> DDPM-F64x4/TUG/TUG1798.png
# Processado: TUG1799.png -> DDPM-F64x4/TUG/TUG1799.png
# Processado: TUG18.png -> DDPM-F64x4/TUG/TUG18.png
# Processado: TUG180.png -> DDPM-F64x4/TUG/TUG180.png
# ...
# Processado: TUG721.png -> DDPM-F64x4/TUG/TUG721.png
# Processado: TUG722.png -> DDPM-F64x4/TUG/TUG722.png
# Processado: TUG723.png -> DDPM-F64x4/TUG/TUG723.png
# Processado: TUG724.png -> DDPM-F64x4/TUG/TUG724.png
# Processado: TUG725.png -> DDPM-F64x4/TUG/TUG725.png
# Processado: TUG726.png -> DDPM-F64x4/TUG/TUG726.png
# Processado: TUG727.png -> DDPM-F64x4/TUG/TUG727.png
# Processado: TUG728.png -> DDPM-F64x4/TUG/TUG728.png
# Processado: TUG729.png -> DDPM-F64x4/TUG/TUG729.png
# Processado: TUG73.png -> DDPM-F64x4/TUG/TUG73.png
# Processado: TUG730.png -> DDPM-F64x4/TUG/TUG730.png
# Processado: TUG731.png -> DDPM-F64x4/TUG/TUG731.png
# Processado: TUG732.png -> DDPM-F64x4/TUG/TUG732.png
# Processado: TUG733.png -> DDPM-F64x4/TUG/TUG733.png
# Processado: TUG734.png -> DDPM-F64x4/TUG/TUG734.png
# Processado: TUG735.png -> DDPM-F64x4/TUG/TUG735.png
# Processado: TUG736.png -> DDPM-F64x4/TUG/TUG736.png
# Processado: TUG737.png -> DDPM-F64x4/TUG/TUG737.png
# Processado: TUG738.png -> DDPM-F64x4/TUG/TUG738.png
# Processado: TUG739.png -> DDPM-F64x4/TUG/TUG739.png
# Processado: TUG74.png -> DDPM-F64x4/TUG/TUG74.png
# Processado: TUG740.png -> DDPM-F64x4/TUG/TUG740.png
# Processado: TUG741.png -> DDPM-F64x4/TUG/TUG741.png
# Processado: TUG742.png -> DDPM-F64x4/TUG/TUG742.png
# Processado: TUG743.png -> DDPM-F64x4/TUG/TUG743.png
# Processado: TUG744.png -> DDPM-F64x4/TUG/TUG744.png
# Processado: TUG745.png -> DDPM-F64x4/TUG/TUG745.png
# Processado: TUG746.png -> DDPM-F64x4/TUG/TUG746.png
# Processado: TUG747.png -> DDPM-F64x4/TUG/TUG747.png
# Processado: TUG748.png -> DDPM-F64x4/TUG/TUG748.png
# Processado: TUG749.png -> DDPM-F64x4/TUG/TUG749.png
# Processado: TUG75.png -> DDPM-F64x4/TUG/TUG75.png
# Processado: TUG750.png -> DDPM-F64x4/TUG/TUG750.png
# Processado: TUG751.png -> DDPM-F64x4/TUG/TUG751.png
# Processado: TUG752.png -> DDPM-F64x4/TUG/TUG752.png
# Processado: TUG753.png -> DDPM-F64x4/TUG/TUG753.png
# Processado: TUG754.png -> DDPM-F64x4/TUG/TUG754.png
# Processado: TUG755.png -> DDPM-F64x4/TUG/TUG755.png
# Processado: TUG756.png -> DDPM-F64x4/TUG/TUG756.png
# Processado: TUG757.png -> DDPM-F64x4/TUG/TUG757.png
# Processado: TUG758.png -> DDPM-F64x4/TUG/TUG758.png
# Processado: TUG759.png -> DDPM-F64x4/TUG/TUG759.png
# Processado: TUG76.png -> DDPM-F64x4/TUG/TUG76.png
# Processado: TUG760.png -> DDPM-F64x4/TUG/TUG760.png
# Processado: TUG761.png -> DDPM-F64x4/TUG/TUG761.png
# Processado: TUG762.png -> DDPM-F64x4/TUG/TUG762.png
# Processado: TUG763.png -> DDPM-F64x4/TUG/TUG763.png
# Processado: TUG764.png -> DDPM-F64x4/TUG/TUG764.png
# Processado: TUG765.png -> DDPM-F64x4/TUG/TUG765.png
# Processado: TUG766.png -> DDPM-F64x4/TUG/TUG766.png
# Processado: TUG767.png -> DDPM-F64x4/TUG/TUG767.png
# Processado: TUG768.png -> DDPM-F64x4/TUG/TUG768.png
# Processado: TUG769.png -> DDPM-F64x4/TUG/TUG769.png
# Processado: TUG77.png -> DDPM-F64x4/TUG/TUG77.png
# Processado: TUG770.png -> DDPM-F64x4/TUG/TUG770.png
# Processado: TUG771.png -> DDPM-F64x4/TUG/TUG771.png
# Processado: TUG772.png -> DDPM-F64x4/TUG/TUG772.png
# Processado: TUG773.png -> DDPM-F64x4/TUG/TUG773.png
# Processado: TUG774.png -> DDPM-F64x4/TUG/TUG774.png
# Processado: TUG775.png -> DDPM-F64x4/TUG/TUG775.png
# Processado: TUG776.png -> DDPM-F64x4/TUG/TUG776.png
# Processado: TUG777.png -> DDPM-F64x4/TUG/TUG777.png
# Processado: TUG778.png -> DDPM-F64x4/TUG/TUG778.png
# Processado: TUG779.png -> DDPM-F64x4/TUG/TUG779.png
# Processado: TUG78.png -> DDPM-F64x4/TUG/TUG78.png
# Processado: TUG780.png -> DDPM-F64x4/TUG/TUG780.png
# Processado: TUG781.png -> DDPM-F64x4/TUG/TUG781.png
# Processado: TUG782.png -> DDPM-F64x4/TUG/TUG782.png
# Processado: TUG783.png -> DDPM-F64x4/TUG/TUG783.png
# Processado: TUG784.png -> DDPM-F64x4/TUG/TUG784.png
# Processado: TUG785.png -> DDPM-F64x4/TUG/TUG785.png
# Processado: TUG786.png -> DDPM-F64x4/TUG/TUG786.png
# Processado: TUG787.png -> DDPM-F64x4/TUG/TUG787.png
# Processado: TUG788.png -> DDPM-F64x4/TUG/TUG788.png
# Processado: TUG789.png -> DDPM-F64x4/TUG/TUG789.png
# Processado: TUG79.png -> DDPM-F64x4/TUG/TUG79.png
# Processado: TUG790.png -> DDPM-F64x4/TUG/TUG790.png
# Processado: TUG791.png -> DDPM-F64x4/TUG/TUG791.png
# Processado: TUG792.png -> DDPM-F64x4/TUG/TUG792.png
# Processado: TUG793.png -> DDPM-F64x4/TUG/TUG793.png
# Processado: TUG794.png -> DDPM-F64x4/TUG/TUG794.png
# Processado: TUG795.png -> DDPM-F64x4/TUG/TUG795.png
# Processado: TUG796.png -> DDPM-F64x4/TUG/TUG796.png
# Processado: TUG797.png -> DDPM-F64x4/TUG/TUG797.png
# Processado: TUG798.png -> DDPM-F64x4/TUG/TUG798.png
# Processado: TUG799.png -> DDPM-F64x4/TUG/TUG799.png
# Processado: TUG8.png -> DDPM-F64x4/TUG/TUG8.png
# Processado: TUG80.png -> DDPM-F64x4/TUG/TUG80.png
# Processado: TUG800.png -> DDPM-F64x4/TUG/TUG800.png
# Processado: TUG801.png -> DDPM-F64x4/TUG/TUG801.png
# Processado: TUG802.png -> DDPM-F64x4/TUG/TUG802.png
# Processado: TUG803.png -> DDPM-F64x4/TUG/TUG803.png
# Processado: TUG804.png -> DDPM-F64x4/TUG/TUG804.png
# Processado: TUG805.png -> DDPM-F64x4/TUG/TUG805.png
# Processado: TUG806.png -> DDPM-F64x4/TUG/TUG806.png
# Processado: TUG807.png -> DDPM-F64x4/TUG/TUG807.png
# Processado: TUG808.png -> DDPM-F64x4/TUG/TUG808.png
# Processado: TUG809.png -> DDPM-F64x4/TUG/TUG809.png
# Processado: TUG81.png -> DDPM-F64x4/TUG/TUG81.png
# Processado: TUG810.png -> DDPM-F64x4/TUG/TUG810.png
# Processado: TUG811.png -> DDPM-F64x4/TUG/TUG811.png
# Processado: TUG812.png -> DDPM-F64x4/TUG/TUG812.png
# Processado: TUG813.png -> DDPM-F64x4/TUG/TUG813.png
# Processado: TUG814.png -> DDPM-F64x4/TUG/TUG814.png
# Processado: TUG815.png -> DDPM-F64x4/TUG/TUG815.png
# Processado: TUG816.png -> DDPM-F64x4/TUG/TUG816.png
# Processado: TUG817.png -> DDPM-F64x4/TUG/TUG817.png
# Processado: TUG818.png -> DDPM-F64x4/TUG/TUG818.png
# Processado: TUG819.png -> DDPM-F64x4/TUG/TUG819.png
# Processado: TUG82.png -> DDPM-F64x4/TUG/TUG82.png
# Processado: TUG820.png -> DDPM-F64x4/TUG/TUG820.png
# Processado: TUG821.png -> DDPM-F64x4/TUG/TUG821.png
# Processado: TUG822.png -> DDPM-F64x4/TUG/TUG822.png
# Processado: TUG823.png -> DDPM-F64x4/TUG/TUG823.png
# Processado: TUG824.png -> DDPM-F64x4/TUG/TUG824.png
# Processado: TUG825.png -> DDPM-F64x4/TUG/TUG825.png
# Processado: TUG826.png -> DDPM-F64x4/TUG/TUG826.png
# Processado: TUG827.png -> DDPM-F64x4/TUG/TUG827.png
# Processado: TUG828.png -> DDPM-F64x4/TUG/TUG828.png
# Processado: TUG829.png -> DDPM-F64x4/TUG/TUG829.png
# Processado: TUG83.png -> DDPM-F64x4/TUG/TUG83.png
# Processado: TUG830.png -> DDPM-F64x4/TUG/TUG830.png
# Processado: TUG831.png -> DDPM-F64x4/TUG/TUG831.png
# Processado: TUG832.png -> DDPM-F64x4/TUG/TUG832.png
# Processado: TUG833.png -> DDPM-F64x4/TUG/TUG833.png
# Processado: TUG834.png -> DDPM-F64x4/TUG/TUG834.png
# Processado: TUG835.png -> DDPM-F64x4/TUG/TUG835.png
# Processado: TUG836.png -> DDPM-F64x4/TUG/TUG836.png
# Processado: TUG837.png -> DDPM-F64x4/TUG/TUG837.png
# Processado: TUG838.png -> DDPM-F64x4/TUG/TUG838.png
# Processado: TUG839.png -> DDPM-F64x4/TUG/TUG839.png
# Processado: TUG84.png -> DDPM-F64x4/TUG/TUG84.png
# Processado: TUG840.png -> DDPM-F64x4/TUG/TUG840.png
# Processado: TUG841.png -> DDPM-F64x4/TUG/TUG841.png
# Processado: TUG842.png -> DDPM-F64x4/TUG/TUG842.png
# Processado: TUG843.png -> DDPM-F64x4/TUG/TUG843.png
# Processado: TUG844.png -> DDPM-F64x4/TUG/TUG844.png
# Processado: TUG845.png -> DDPM-F64x4/TUG/TUG845.png
# Processado: TUG846.png -> DDPM-F64x4/TUG/TUG846.png
# Processado: TUG847.png -> DDPM-F64x4/TUG/TUG847.png
# Processado: TUG848.png -> DDPM-F64x4/TUG/TUG848.png
# Processado: TUG849.png -> DDPM-F64x4/TUG/TUG849.png
# Processado: TUG85.png -> DDPM-F64x4/TUG/TUG85.png
# Processado: TUG850.png -> DDPM-F64x4/TUG/TUG850.png
# Processado: TUG851.png -> DDPM-F64x4/TUG/TUG851.png
# Processado: TUG852.png -> DDPM-F64x4/TUG/TUG852.png
# Processado: TUG853.png -> DDPM-F64x4/TUG/TUG853.png
# Processado: TUG854.png -> DDPM-F64x4/TUG/TUG854.png
# Processado: TUG855.png -> DDPM-F64x4/TUG/TUG855.png
# Processado: TUG856.png -> DDPM-F64x4/TUG/TUG856.png
# Processado: TUG857.png -> DDPM-F64x4/TUG/TUG857.png
# Processado: TUG858.png -> DDPM-F64x4/TUG/TUG858.png
# Processado: TUG859.png -> DDPM-F64x4/TUG/TUG859.png
# Processado: TUG86.png -> DDPM-F64x4/TUG/TUG86.png
# Processado: TUG860.png -> DDPM-F64x4/TUG/TUG860.png
# Processado: TUG861.png -> DDPM-F64x4/TUG/TUG861.png
# Processado: TUG862.png -> DDPM-F64x4/TUG/TUG862.png
# Processado: TUG863.png -> DDPM-F64x4/TUG/TUG863.png
# Processado: TUG864.png -> DDPM-F64x4/TUG/TUG864.png
# Processado: TUG865.png -> DDPM-F64x4/TUG/TUG865.png
# Processado: TUG866.png -> DDPM-F64x4/TUG/TUG866.png
# Processado: TUG867.png -> DDPM-F64x4/TUG/TUG867.png
# Processado: TUG868.png -> DDPM-F64x4/TUG/TUG868.png
# Processado: TUG869.png -> DDPM-F64x4/TUG/TUG869.png
# Processado: TUG87.png -> DDPM-F64x4/TUG/TUG87.png
# Processado: TUG870.png -> DDPM-F64x4/TUG/TUG870.png
# Processado: TUG871.png -> DDPM-F64x4/TUG/TUG871.png
# Processado: TUG872.png -> DDPM-F64x4/TUG/TUG872.png
# Processado: TUG873.png -> DDPM-F64x4/TUG/TUG873.png
# Processado: TUG874.png -> DDPM-F64x4/TUG/TUG874.png
# Processado: TUG875.png -> DDPM-F64x4/TUG/TUG875.png
# Processado: TUG876.png -> DDPM-F64x4/TUG/TUG876.png
# Processado: TUG877.png -> DDPM-F64x4/TUG/TUG877.png
# Processado: TUG878.png -> DDPM-F64x4/TUG/TUG878.png
# Processado: TUG879.png -> DDPM-F64x4/TUG/TUG879.png
# Processado: TUG88.png -> DDPM-F64x4/TUG/TUG88.png
# Processado: TUG880.png -> DDPM-F64x4/TUG/TUG880.png
# Processado: TUG881.png -> DDPM-F64x4/TUG/TUG881.png
# Processado: TUG882.png -> DDPM-F64x4/TUG/TUG882.png
# Processado: TUG883.png -> DDPM-F64x4/TUG/TUG883.png
# Processado: TUG884.png -> DDPM-F64x4/TUG/TUG884.png
# Processado: TUG885.png -> DDPM-F64x4/TUG/TUG885.png
# Processado: TUG886.png -> DDPM-F64x4/TUG/TUG886.png
# Processado: TUG887.png -> DDPM-F64x4/TUG/TUG887.png
# Processado: TUG888.png -> DDPM-F64x4/TUG/TUG888.png
# Processado: TUG889.png -> DDPM-F64x4/TUG/TUG889.png
# Processado: TUG89.png -> DDPM-F64x4/TUG/TUG89.png
# Processado: TUG890.png -> DDPM-F64x4/TUG/TUG890.png
# Processado: TUG891.png -> DDPM-F64x4/TUG/TUG891.png
# Processado: TUG892.png -> DDPM-F64x4/TUG/TUG892.png
# Processado: TUG893.png -> DDPM-F64x4/TUG/TUG893.png
# Processado: TUG894.png -> DDPM-F64x4/TUG/TUG894.png
# Processado: TUG895.png -> DDPM-F64x4/TUG/TUG895.png
# Processado: TUG896.png -> DDPM-F64x4/TUG/TUG896.png
# Processado: TUG897.png -> DDPM-F64x4/TUG/TUG897.png
# Processado: TUG898.png -> DDPM-F64x4/TUG/TUG898.png
# Processado: TUG899.png -> DDPM-F64x4/TUG/TUG899.png
# Processado: TUG9.png -> DDPM-F64x4/TUG/TUG9.png
# Processado: TUG90.png -> DDPM-F64x4/TUG/TUG90.png
# Processado: TUG900.png -> DDPM-F64x4/TUG/TUG900.png
# Processado: TUG901.png -> DDPM-F64x4/TUG/TUG901.png
# Processado: TUG902.png -> DDPM-F64x4/TUG/TUG902.png
# Processado: TUG903.png -> DDPM-F64x4/TUG/TUG903.png
# Processado: TUG904.png -> DDPM-F64x4/TUG/TUG904.png
# Processado: TUG905.png -> DDPM-F64x4/TUG/TUG905.png
# Processado: TUG906.png -> DDPM-F64x4/TUG/TUG906.png
# Processado: TUG907.png -> DDPM-F64x4/TUG/TUG907.png
# Processado: TUG908.png -> DDPM-F64x4/TUG/TUG908.png
# Processado: TUG909.png -> DDPM-F64x4/TUG/TUG909.png
# Processado: TUG91.png -> DDPM-F64x4/TUG/TUG91.png
# Processado: TUG910.png -> DDPM-F64x4/TUG/TUG910.png
# Processado: TUG911.png -> DDPM-F64x4/TUG/TUG911.png
# Processado: TUG912.png -> DDPM-F64x4/TUG/TUG912.png
# Processado: TUG913.png -> DDPM-F64x4/TUG/TUG913.png
# Processado: TUG914.png -> DDPM-F64x4/TUG/TUG914.png
# Processado: TUG915.png -> DDPM-F64x4/TUG/TUG915.png
# Processado: TUG916.png -> DDPM-F64x4/TUG/TUG916.png
# Processado: TUG917.png -> DDPM-F64x4/TUG/TUG917.png
# Processado: TUG918.png -> DDPM-F64x4/TUG/TUG918.png
# Processado: TUG919.png -> DDPM-F64x4/TUG/TUG919.png
# Processado: TUG92.png -> DDPM-F64x4/TUG/TUG92.png
# Processado: TUG920.png -> DDPM-F64x4/TUG/TUG920.png
# Processado: TUG921.png -> DDPM-F64x4/TUG/TUG921.png
# Processado: TUG922.png -> DDPM-F64x4/TUG/TUG922.png
# Processado: TUG923.png -> DDPM-F64x4/TUG/TUG923.png
# Processado: TUG924.png -> DDPM-F64x4/TUG/TUG924.png
# Processado: TUG925.png -> DDPM-F64x4/TUG/TUG925.png
# Processado: TUG926.png -> DDPM-F64x4/TUG/TUG926.png
# Processado: TUG927.png -> DDPM-F64x4/TUG/TUG927.png
# Processado: TUG928.png -> DDPM-F64x4/TUG/TUG928.png
# Processado: TUG929.png -> DDPM-F64x4/TUG/TUG929.png
# Processado: TUG93.png -> DDPM-F64x4/TUG/TUG93.png
# Processado: TUG930.png -> DDPM-F64x4/TUG/TUG930.png
# Processado: TUG931.png -> DDPM-F64x4/TUG/TUG931.png
# Processado: TUG932.png -> DDPM-F64x4/TUG/TUG932.png
# Processado: TUG933.png -> DDPM-F64x4/TUG/TUG933.png
# Processado: TUG934.png -> DDPM-F64x4/TUG/TUG934.png
# Processado: TUG935.png -> DDPM-F64x4/TUG/TUG935.png
# Processado: TUG936.png -> DDPM-F64x4/TUG/TUG936.png
# Processado: TUG937.png -> DDPM-F64x4/TUG/TUG937.png
# Processado: TUG938.png -> DDPM-F64x4/TUG/TUG938.png
# Processado: TUG939.png -> DDPM-F64x4/TUG/TUG939.png
# Processado: TUG94.png -> DDPM-F64x4/TUG/TUG94.png
# Processado: TUG940.png -> DDPM-F64x4/TUG/TUG940.png
# Processado: TUG941.png -> DDPM-F64x4/TUG/TUG941.png
# Processado: TUG942.png -> DDPM-F64x4/TUG/TUG942.png
# Processado: TUG943.png -> DDPM-F64x4/TUG/TUG943.png
# Processado: TUG944.png -> DDPM-F64x4/TUG/TUG944.png
# Processado: TUG945.png -> DDPM-F64x4/TUG/TUG945.png
# Processado: TUG946.png -> DDPM-F64x4/TUG/TUG946.png
# Processado: TUG947.png -> DDPM-F64x4/TUG/TUG947.png
# Processado: TUG948.png -> DDPM-F64x4/TUG/TUG948.png
# Processado: TUG949.png -> DDPM-F64x4/TUG/TUG949.png
# Processado: TUG95.png -> DDPM-F64x4/TUG/TUG95.png
# Processado: TUG950.png -> DDPM-F64x4/TUG/TUG950.png
# Processado: TUG951.png -> DDPM-F64x4/TUG/TUG951.png
# Processado: TUG952.png -> DDPM-F64x4/TUG/TUG952.png
# Processado: TUG953.png -> DDPM-F64x4/TUG/TUG953.png
# Processado: TUG954.png -> DDPM-F64x4/TUG/TUG954.png
# Processado: TUG955.png -> DDPM-F64x4/TUG/TUG955.png
# Processado: TUG956.png -> DDPM-F64x4/TUG/TUG956.png
# Processado: TUG957.png -> DDPM-F64x4/TUG/TUG957.png
# Processado: TUG958.png -> DDPM-F64x4/TUG/TUG958.png
# Processado: TUG959.png -> DDPM-F64x4/TUG/TUG959.png
# Processado: TUG96.png -> DDPM-F64x4/TUG/TUG96.png
# Processado: TUG960.png -> DDPM-F64x4/TUG/TUG960.png
# Processado: TUG961.png -> DDPM-F64x4/TUG/TUG961.png
# Processado: TUG962.png -> DDPM-F64x4/TUG/TUG962.png
# Processado: TUG963.png -> DDPM-F64x4/TUG/TUG963.png
# Processado: TUG964.png -> DDPM-F64x4/TUG/TUG964.png
# Processado: TUG965.png -> DDPM-F64x4/TUG/TUG965.png
# Processado: TUG966.png -> DDPM-F64x4/TUG/TUG966.png
# Processado: TUG967.png -> DDPM-F64x4/TUG/TUG967.png
# Processado: TUG968.png -> DDPM-F64x4/TUG/TUG968.png
# Processado: TUG969.png -> DDPM-F64x4/TUG/TUG969.png
# Processado: TUG97.png -> DDPM-F64x4/TUG/TUG97.png
# Processado: TUG970.png -> DDPM-F64x4/TUG/TUG970.png
# Processado: TUG971.png -> DDPM-F64x4/TUG/TUG971.png
# Processado: TUG972.png -> DDPM-F64x4/TUG/TUG972.png
# Processado: TUG973.png -> DDPM-F64x4/TUG/TUG973.png
# Processado: TUG974.png -> DDPM-F64x4/TUG/TUG974.png
# Processado: TUG975.png -> DDPM-F64x4/TUG/TUG975.png
# Processado: TUG976.png -> DDPM-F64x4/TUG/TUG976.png
# Processado: TUG977.png -> DDPM-F64x4/TUG/TUG977.png
# Processado: TUG978.png -> DDPM-F64x4/TUG/TUG978.png
# Processado: TUG979.png -> DDPM-F64x4/TUG/TUG979.png
# Processado: TUG98.png -> DDPM-F64x4/TUG/TUG98.png
# Processado: TUG980.png -> DDPM-F64x4/TUG/TUG980.png
# Processado: TUG981.png -> DDPM-F64x4/TUG/TUG981.png
# Processado: TUG982.png -> DDPM-F64x4/TUG/TUG982.png
# Processado: TUG983.png -> DDPM-F64x4/TUG/TUG983.png
# Processado: TUG984.png -> DDPM-F64x4/TUG/TUG984.png
# Processado: TUG985.png -> DDPM-F64x4/TUG/TUG985.png
# Processado: TUG986.png -> DDPM-F64x4/TUG/TUG986.png
# Processado: TUG987.png -> DDPM-F64x4/TUG/TUG987.png
# Processado: TUG988.png -> DDPM-F64x4/TUG/TUG988.png
# Processado: TUG989.png -> DDPM-F64x4/TUG/TUG989.png
# Processado: TUG99.png -> DDPM-F64x4/TUG/TUG99.png
# Processado: TUG990.png -> DDPM-F64x4/TUG/TUG990.png
# Processado: TUG991.png -> DDPM-F64x4/TUG/TUG991.png
# Processado: TUG992.png -> DDPM-F64x4/TUG/TUG992.png
# Processado: TUG993.png -> DDPM-F64x4/TUG/TUG993.png
# Processado: TUG994.png -> DDPM-F64x4/TUG/TUG994.png
# Processado: TUG995.png -> DDPM-F64x4/TUG/TUG995.png
# Processado: TUG996.png -> DDPM-F64x4/TUG/TUG996.png
# Processado: TUG997.png -> DDPM-F64x4/TUG/TUG997.png
# Processado: TUG998.png -> DDPM-F64x4/TUG/TUG998.png
# Processado: TUG999.png -> DDPM-F64x4/TUG/TUG999.png
# Processamento concluído!
