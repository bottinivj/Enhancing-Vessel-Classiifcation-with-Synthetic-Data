# %%
generating_class = 'OILPRODUCTSTANKER'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-01-31 02:12:49.552305: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-31 02:12:49.572745: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-01-31 02:12:50.403671: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.406547: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.406564: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-01-31 02:12:50.416886: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.416923: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.416935: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.575910: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.575937: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.575942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-01-31 02:12:50.575961: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 02:12:50.575978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738289593.265107     188 service.cc:145] XLA service 0x7f62a80030e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738289593.265199     188 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-01-31 02:13:14.085892: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738289594.797977     188 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-01-31 02:13:16.245453: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738289598.073214     364 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738289598.169520     351 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738289598.190486     362 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738289598.221346     361 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738289598.312905     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738289598.867479     371 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738289598.914257     363 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738289598.933317     373 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738289599.044855     369 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738289599.047526     348 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738289599.162399     358 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738289599.178167     368 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738289599.331686     361 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738289599.334949     363 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738289599.343930     376 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738289599.507879     366 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738289599.753149     356 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738289600.033887     366 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738289600.235684     360 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738289600.344586     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738289600.350005     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738289600.503180     376 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738289600.589672     364 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738289600.598129     359 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738289600.723657     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738289600.864824     373 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738289600.906824     376 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738289601.066014     359 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738289601.076609     364 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738289601.148362     373 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738289601.225192     363 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738289601.295826     365 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738289601.329106     371 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738289628.718381     188 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738289628.759746     188 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 67s 68ms/step - loss: 0.2371
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0286
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0244
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0205
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0201
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0194
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0189
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0177
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0184
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0172
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0168
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0185
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0177
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0174
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0161
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0165
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0165
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0162
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0174
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0165
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0160
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0172
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0155
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0166
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0155
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0161
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0156
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0161
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0166
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0162
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0153
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0150
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0158
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0151
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0160
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0157
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0148
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0149
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0154
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0154
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0150
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0155
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0154
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0148
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0149
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0153
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0144
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0141
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0148
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0142
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0149
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0145
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0149
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0142
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0153
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0144
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0149
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0145
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0146
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0151
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0143
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0138
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0142
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0143
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0142
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0150
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0145
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0151
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0148
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0145
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0140
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0143
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0138
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0139
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0147
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0138
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0143
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0143
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0139
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0141
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0143
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0136
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0137
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0135
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0141
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0143
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0142
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0141
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0136
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0141
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0128
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0134
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0144
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0146
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0144
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0141
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0146
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0145
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0144
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0143
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0143
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0144
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0141
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0134
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0130
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0136
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0134
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0129
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0148
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0127
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0130
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0133
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0135
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0132
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0132
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0131
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0141
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0125
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0139
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 327/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 328/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 346/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 347/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 348/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 349/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 350/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 351/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 352/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 353/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 354/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 355/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 356/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 357/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 358/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 359/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 360/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 361/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 362/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0137
# Epoch 363/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0142
# Epoch 364/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 365/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 366/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 367/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 368/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 369/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 370/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 371/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 372/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 373/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 374/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 375/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 376/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 377/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 378/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 379/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 380/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 381/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 382/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 383/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 384/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 385/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 386/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 387/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 388/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 389/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0138
# Epoch 390/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0136
# Epoch 391/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 392/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 393/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 394/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 395/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 396/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 397/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 398/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 399/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 400/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 401/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 402/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 403/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 404/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 405/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0134
# Epoch 406/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 407/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 408/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 409/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 410/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 411/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 412/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 413/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0118
# Epoch 414/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 415/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 416/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 417/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 418/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 419/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0135
# Epoch 420/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 421/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 422/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 423/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 424/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 425/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 426/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 427/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 428/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0118
# Epoch 429/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 430/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 431/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 432/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 433/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 434/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 435/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 436/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 437/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 438/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 439/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 440/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 441/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 442/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 443/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 444/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 445/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 446/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 447/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 448/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 449/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 450/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 451/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0130
# Epoch 452/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 453/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 454/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 455/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 456/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 457/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 458/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 459/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 460/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 461/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 462/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 463/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 464/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 465/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 466/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 467/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0115
# Epoch 468/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0132
# Epoch 469/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0128
# Epoch 470/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 471/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 472/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0129
# Epoch 473/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0133
# Epoch 474/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 475/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 476/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 477/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 478/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 479/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 480/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0116
# Epoch 481/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 482/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 483/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 484/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 485/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0118
# Epoch 486/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0124
# Epoch 487/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 488/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 489/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 490/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0123
# Epoch 491/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 492/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0131
# Epoch 493/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 494/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 495/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 496/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0115
# Epoch 497/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 498/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0126
# Epoch 499/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 500/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# INFO:tensorflow:Assets written to: DDPM-GI/OILPRODUCTSTANKER/GERADOR/assets
# INFO:tensorflow:Assets written to: DDPM-GI/OILPRODUCTSTANKER/GERADOR/assets

# %%
import os
from IPython.display import clear_output

num_img = 5400

output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    print("Faltam %d iterações" % (t))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# Faltam 0 iterações

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: OILPRODUCTSTANKER0.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER0.png
# Processado: OILPRODUCTSTANKER1.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1.png
# Processado: OILPRODUCTSTANKER10.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER10.png
# Processado: OILPRODUCTSTANKER100.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER100.png
# Processado: OILPRODUCTSTANKER1000.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1000.png
# Processado: OILPRODUCTSTANKER1001.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1001.png
# Processado: OILPRODUCTSTANKER1002.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1002.png
# Processado: OILPRODUCTSTANKER1003.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1003.png
# Processado: OILPRODUCTSTANKER1004.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1004.png
# Processado: OILPRODUCTSTANKER1005.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1005.png
# Processado: OILPRODUCTSTANKER1006.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1006.png
# Processado: OILPRODUCTSTANKER1007.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1007.png
# Processado: OILPRODUCTSTANKER1008.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1008.png
# Processado: OILPRODUCTSTANKER1009.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1009.png
# Processado: OILPRODUCTSTANKER101.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER101.png
# Processado: OILPRODUCTSTANKER1010.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1010.png
# Processado: OILPRODUCTSTANKER1011.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1011.png
# Processado: OILPRODUCTSTANKER1012.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1012.png
# Processado: OILPRODUCTSTANKER1013.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1013.png
# Processado: OILPRODUCTSTANKER1014.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1014.png
# Processado: OILPRODUCTSTANKER1015.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1015.png
# Processado: OILPRODUCTSTANKER1016.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1016.png
# Processado: OILPRODUCTSTANKER1017.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1017.png
# Processado: OILPRODUCTSTANKER1018.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1018.png
# Processado: OILPRODUCTSTANKER1019.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1019.png
# Processado: OILPRODUCTSTANKER102.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER102.png
# Processado: OILPRODUCTSTANKER1020.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1020.png
# Processado: OILPRODUCTSTANKER1021.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1021.png
# Processado: OILPRODUCTSTANKER1022.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1022.png
# Processado: OILPRODUCTSTANKER1023.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1023.png
# Processado: OILPRODUCTSTANKER1024.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1024.png
# Processado: OILPRODUCTSTANKER1025.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1025.png
# Processado: OILPRODUCTSTANKER1026.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1026.png
# Processado: OILPRODUCTSTANKER1027.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1027.png
# Processado: OILPRODUCTSTANKER1028.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1028.png
# Processado: OILPRODUCTSTANKER1029.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1029.png
# Processado: OILPRODUCTSTANKER103.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER103.png
# Processado: OILPRODUCTSTANKER1030.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1030.png
# Processado: OILPRODUCTSTANKER1031.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1031.png
# Processado: OILPRODUCTSTANKER1032.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1032.png
# Processado: OILPRODUCTSTANKER1033.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1033.png
# Processado: OILPRODUCTSTANKER1034.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1034.png
# Processado: OILPRODUCTSTANKER1035.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1035.png
# Processado: OILPRODUCTSTANKER1036.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1036.png
# Processado: OILPRODUCTSTANKER1037.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1037.png
# Processado: OILPRODUCTSTANKER1038.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1038.png
# Processado: OILPRODUCTSTANKER1039.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1039.png
# Processado: OILPRODUCTSTANKER104.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER104.png
# Processado: OILPRODUCTSTANKER1040.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1040.png
# Processado: OILPRODUCTSTANKER1041.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1041.png
# Processado: OILPRODUCTSTANKER1042.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1042.png
# Processado: OILPRODUCTSTANKER1043.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1043.png
# Processado: OILPRODUCTSTANKER1044.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1044.png
# Processado: OILPRODUCTSTANKER1045.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1045.png
# Processado: OILPRODUCTSTANKER1046.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1046.png
# Processado: OILPRODUCTSTANKER1047.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1047.png
# Processado: OILPRODUCTSTANKER1048.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1048.png
# Processado: OILPRODUCTSTANKER1049.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1049.png
# Processado: OILPRODUCTSTANKER105.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER105.png
# Processado: OILPRODUCTSTANKER1050.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1050.png
# Processado: OILPRODUCTSTANKER1051.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1051.png
# Processado: OILPRODUCTSTANKER1052.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1052.png
# Processado: OILPRODUCTSTANKER1053.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1053.png
# Processado: OILPRODUCTSTANKER1054.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1054.png
# Processado: OILPRODUCTSTANKER1055.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1055.png
# Processado: OILPRODUCTSTANKER1056.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1056.png
# Processado: OILPRODUCTSTANKER1057.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1057.png
# Processado: OILPRODUCTSTANKER1058.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1058.png
# Processado: OILPRODUCTSTANKER1059.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1059.png
# Processado: OILPRODUCTSTANKER106.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER106.png
# Processado: OILPRODUCTSTANKER1060.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1060.png
# Processado: OILPRODUCTSTANKER1061.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1061.png
# Processado: OILPRODUCTSTANKER1062.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1062.png
# Processado: OILPRODUCTSTANKER1063.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1063.png
# Processado: OILPRODUCTSTANKER1064.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1064.png
# Processado: OILPRODUCTSTANKER1065.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1065.png
# Processado: OILPRODUCTSTANKER1066.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1066.png
# Processado: OILPRODUCTSTANKER1067.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1067.png
# Processado: OILPRODUCTSTANKER1068.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1068.png
# Processado: OILPRODUCTSTANKER1069.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1069.png
# Processado: OILPRODUCTSTANKER107.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER107.png
# Processado: OILPRODUCTSTANKER1070.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1070.png
# Processado: OILPRODUCTSTANKER1071.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1071.png
# Processado: OILPRODUCTSTANKER1072.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1072.png
# Processado: OILPRODUCTSTANKER1073.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1073.png
# Processado: OILPRODUCTSTANKER1074.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1074.png
# Processado: OILPRODUCTSTANKER1075.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1075.png
# Processado: OILPRODUCTSTANKER1076.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1076.png
# Processado: OILPRODUCTSTANKER1077.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1077.png
# Processado: OILPRODUCTSTANKER1078.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1078.png
# Processado: OILPRODUCTSTANKER1079.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1079.png
# Processado: OILPRODUCTSTANKER108.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER108.png
# Processado: OILPRODUCTSTANKER1080.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1080.png
# Processado: OILPRODUCTSTANKER1081.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1081.png
# Processado: OILPRODUCTSTANKER1082.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1082.png
# Processado: OILPRODUCTSTANKER1083.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1083.png
# Processado: OILPRODUCTSTANKER1084.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1084.png
# Processado: OILPRODUCTSTANKER1085.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1085.png
# Processado: OILPRODUCTSTANKER1086.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1086.png
# Processado: OILPRODUCTSTANKER1087.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1087.png
# Processado: OILPRODUCTSTANKER1088.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1088.png
# Processado: OILPRODUCTSTANKER1089.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1089.png
# Processado: OILPRODUCTSTANKER109.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER109.png
# Processado: OILPRODUCTSTANKER1090.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1090.png
# Processado: OILPRODUCTSTANKER1091.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1091.png
# Processado: OILPRODUCTSTANKER1092.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1092.png
# Processado: OILPRODUCTSTANKER1093.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1093.png
# Processado: OILPRODUCTSTANKER1094.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1094.png
# Processado: OILPRODUCTSTANKER1095.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1095.png
# Processado: OILPRODUCTSTANKER1096.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1096.png
# Processado: OILPRODUCTSTANKER1097.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1097.png
# Processado: OILPRODUCTSTANKER1098.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1098.png
# Processado: OILPRODUCTSTANKER1099.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1099.png
# Processado: OILPRODUCTSTANKER11.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER11.png
# Processado: OILPRODUCTSTANKER110.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER110.png
# Processado: OILPRODUCTSTANKER1100.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1100.png
# Processado: OILPRODUCTSTANKER1101.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1101.png
# Processado: OILPRODUCTSTANKER1102.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1102.png
# Processado: OILPRODUCTSTANKER1103.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1103.png
# Processado: OILPRODUCTSTANKER1104.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1104.png
# Processado: OILPRODUCTSTANKER1105.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1105.png
# Processado: OILPRODUCTSTANKER1106.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1106.png
# Processado: OILPRODUCTSTANKER1107.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1107.png
# Processado: OILPRODUCTSTANKER1108.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1108.png
# Processado: OILPRODUCTSTANKER1109.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1109.png
# Processado: OILPRODUCTSTANKER111.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER111.png
# Processado: OILPRODUCTSTANKER1110.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1110.png
# Processado: OILPRODUCTSTANKER1111.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1111.png
# Processado: OILPRODUCTSTANKER1112.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1112.png
# Processado: OILPRODUCTSTANKER1113.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1113.png
# Processado: OILPRODUCTSTANKER1114.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1114.png
# Processado: OILPRODUCTSTANKER1115.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1115.png
# Processado: OILPRODUCTSTANKER1116.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1116.png
# Processado: OILPRODUCTSTANKER1117.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1117.png
# Processado: OILPRODUCTSTANKER1118.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1118.png
# Processado: OILPRODUCTSTANKER1119.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1119.png
# Processado: OILPRODUCTSTANKER112.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER112.png
# Processado: OILPRODUCTSTANKER1120.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1120.png
# Processado: OILPRODUCTSTANKER1121.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1121.png
# Processado: OILPRODUCTSTANKER1122.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1122.png
# Processado: OILPRODUCTSTANKER1123.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1123.png
# Processado: OILPRODUCTSTANKER1124.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1124.png
# Processado: OILPRODUCTSTANKER1125.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1125.png
# Processado: OILPRODUCTSTANKER1126.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1126.png
# Processado: OILPRODUCTSTANKER1127.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1127.png
# Processado: OILPRODUCTSTANKER1128.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1128.png
# Processado: OILPRODUCTSTANKER1129.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1129.png
# Processado: OILPRODUCTSTANKER113.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER113.png
# Processado: OILPRODUCTSTANKER1130.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1130.png
# Processado: OILPRODUCTSTANKER1131.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1131.png
# Processado: OILPRODUCTSTANKER1132.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1132.png
# Processado: OILPRODUCTSTANKER1133.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1133.png
# Processado: OILPRODUCTSTANKER1134.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1134.png
# Processado: OILPRODUCTSTANKER1135.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1135.png
# Processado: OILPRODUCTSTANKER1136.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1136.png
# Processado: OILPRODUCTSTANKER1137.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1137.png
# Processado: OILPRODUCTSTANKER1138.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1138.png
# Processado: OILPRODUCTSTANKER1139.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1139.png
# Processado: OILPRODUCTSTANKER114.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER114.png
# Processado: OILPRODUCTSTANKER1140.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1140.png
# Processado: OILPRODUCTSTANKER1141.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1141.png
# Processado: OILPRODUCTSTANKER1142.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1142.png
# Processado: OILPRODUCTSTANKER1143.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1143.png
# Processado: OILPRODUCTSTANKER1144.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1144.png
# Processado: OILPRODUCTSTANKER1145.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1145.png
# Processado: OILPRODUCTSTANKER1146.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1146.png
# Processado: OILPRODUCTSTANKER1147.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1147.png
# Processado: OILPRODUCTSTANKER1148.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1148.png
# Processado: OILPRODUCTSTANKER1149.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1149.png
# Processado: OILPRODUCTSTANKER115.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER115.png
# Processado: OILPRODUCTSTANKER1150.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1150.png
# Processado: OILPRODUCTSTANKER1151.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1151.png
# Processado: OILPRODUCTSTANKER1152.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1152.png
# Processado: OILPRODUCTSTANKER1153.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1153.png
# Processado: OILPRODUCTSTANKER1154.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1154.png
# Processado: OILPRODUCTSTANKER1155.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1155.png
# Processado: OILPRODUCTSTANKER1156.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1156.png
# Processado: OILPRODUCTSTANKER1157.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1157.png
# Processado: OILPRODUCTSTANKER1158.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1158.png
# Processado: OILPRODUCTSTANKER1159.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1159.png
# Processado: OILPRODUCTSTANKER116.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER116.png
# Processado: OILPRODUCTSTANKER1160.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1160.png
# Processado: OILPRODUCTSTANKER1161.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1161.png
# Processado: OILPRODUCTSTANKER1162.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1162.png
# Processado: OILPRODUCTSTANKER1163.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1163.png
# Processado: OILPRODUCTSTANKER1164.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1164.png
# Processado: OILPRODUCTSTANKER1165.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1165.png
# Processado: OILPRODUCTSTANKER1166.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1166.png
# Processado: OILPRODUCTSTANKER1167.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1167.png
# Processado: OILPRODUCTSTANKER1168.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1168.png
# Processado: OILPRODUCTSTANKER1169.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1169.png
# Processado: OILPRODUCTSTANKER117.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER117.png
# Processado: OILPRODUCTSTANKER1170.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1170.png
# Processado: OILPRODUCTSTANKER1171.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1171.png
# Processado: OILPRODUCTSTANKER1172.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1172.png
# Processado: OILPRODUCTSTANKER1173.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1173.png
# Processado: OILPRODUCTSTANKER1174.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1174.png
# Processado: OILPRODUCTSTANKER1175.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1175.png
# Processado: OILPRODUCTSTANKER1176.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1176.png
# Processado: OILPRODUCTSTANKER1177.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1177.png
# Processado: OILPRODUCTSTANKER1178.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1178.png
# Processado: OILPRODUCTSTANKER1179.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1179.png
# Processado: OILPRODUCTSTANKER118.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER118.png
# Processado: OILPRODUCTSTANKER1180.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1180.png
# Processado: OILPRODUCTSTANKER1181.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1181.png
# Processado: OILPRODUCTSTANKER1182.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1182.png
# Processado: OILPRODUCTSTANKER1183.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1183.png
# Processado: OILPRODUCTSTANKER1184.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1184.png
# Processado: OILPRODUCTSTANKER1185.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1185.png
# Processado: OILPRODUCTSTANKER1186.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1186.png
# Processado: OILPRODUCTSTANKER1187.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1187.png
# Processado: OILPRODUCTSTANKER1188.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1188.png
# Processado: OILPRODUCTSTANKER1189.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1189.png
# Processado: OILPRODUCTSTANKER119.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER119.png
# Processado: OILPRODUCTSTANKER1190.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1190.png
# Processado: OILPRODUCTSTANKER1191.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1191.png
# Processado: OILPRODUCTSTANKER1192.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1192.png
# Processado: OILPRODUCTSTANKER1193.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1193.png
# Processado: OILPRODUCTSTANKER1194.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1194.png
# Processado: OILPRODUCTSTANKER1195.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1195.png
# Processado: OILPRODUCTSTANKER1196.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1196.png
# Processado: OILPRODUCTSTANKER1197.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1197.png
# Processado: OILPRODUCTSTANKER1198.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1198.png
# Processado: OILPRODUCTSTANKER1199.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1199.png
# Processado: OILPRODUCTSTANKER12.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER12.png
# Processado: OILPRODUCTSTANKER120.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER120.png
# Processado: OILPRODUCTSTANKER1200.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1200.png
# Processado: OILPRODUCTSTANKER1201.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1201.png
# Processado: OILPRODUCTSTANKER1202.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1202.png
# Processado: OILPRODUCTSTANKER1203.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1203.png
# Processado: OILPRODUCTSTANKER1204.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1204.png
# Processado: OILPRODUCTSTANKER1205.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1205.png
# Processado: OILPRODUCTSTANKER1206.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1206.png
# Processado: OILPRODUCTSTANKER1207.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1207.png
# Processado: OILPRODUCTSTANKER1208.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1208.png
# Processado: OILPRODUCTSTANKER1209.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1209.png
# Processado: OILPRODUCTSTANKER121.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER121.png
# Processado: OILPRODUCTSTANKER1210.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1210.png
# Processado: OILPRODUCTSTANKER1211.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1211.png
# Processado: OILPRODUCTSTANKER1212.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1212.png
# Processado: OILPRODUCTSTANKER1213.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1213.png
# Processado: OILPRODUCTSTANKER1214.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1214.png
# Processado: OILPRODUCTSTANKER1215.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1215.png
# Processado: OILPRODUCTSTANKER1216.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1216.png
# Processado: OILPRODUCTSTANKER1217.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1217.png
# Processado: OILPRODUCTSTANKER1218.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1218.png
# Processado: OILPRODUCTSTANKER1219.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1219.png
# Processado: OILPRODUCTSTANKER122.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER122.png
# Processado: OILPRODUCTSTANKER1220.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1220.png
# Processado: OILPRODUCTSTANKER1221.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1221.png
# Processado: OILPRODUCTSTANKER1222.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1222.png
# Processado: OILPRODUCTSTANKER1223.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1223.png
# Processado: OILPRODUCTSTANKER1224.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1224.png
# Processado: OILPRODUCTSTANKER1225.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1225.png
# Processado: OILPRODUCTSTANKER1226.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1226.png
# Processado: OILPRODUCTSTANKER1227.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1227.png
# Processado: OILPRODUCTSTANKER1228.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1228.png
# Processado: OILPRODUCTSTANKER1229.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1229.png
# Processado: OILPRODUCTSTANKER123.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER123.png
# Processado: OILPRODUCTSTANKER1230.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1230.png
# Processado: OILPRODUCTSTANKER1231.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1231.png
# Processado: OILPRODUCTSTANKER1232.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1232.png
# Processado: OILPRODUCTSTANKER1233.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1233.png
# Processado: OILPRODUCTSTANKER1234.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1234.png
# Processado: OILPRODUCTSTANKER1235.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1235.png
# Processado: OILPRODUCTSTANKER1236.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1236.png
# Processado: OILPRODUCTSTANKER1237.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1237.png
# Processado: OILPRODUCTSTANKER1238.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1238.png
# Processado: OILPRODUCTSTANKER1239.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1239.png
# Processado: OILPRODUCTSTANKER124.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER124.png
# Processado: OILPRODUCTSTANKER1240.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1240.png
# Processado: OILPRODUCTSTANKER1241.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1241.png
# Processado: OILPRODUCTSTANKER1242.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1242.png
# Processado: OILPRODUCTSTANKER1243.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1243.png
# Processado: OILPRODUCTSTANKER1244.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1244.png
# Processado: OILPRODUCTSTANKER1245.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1245.png
# Processado: OILPRODUCTSTANKER1246.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1246.png
# Processado: OILPRODUCTSTANKER1247.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1247.png
# Processado: OILPRODUCTSTANKER1248.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1248.png
# Processado: OILPRODUCTSTANKER1249.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1249.png
# Processado: OILPRODUCTSTANKER125.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER125.png
# Processado: OILPRODUCTSTANKER1250.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1250.png
# Processado: OILPRODUCTSTANKER1251.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1251.png
# Processado: OILPRODUCTSTANKER1252.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1252.png
# Processado: OILPRODUCTSTANKER1253.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1253.png
# Processado: OILPRODUCTSTANKER1254.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1254.png
# Processado: OILPRODUCTSTANKER1255.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1255.png
# Processado: OILPRODUCTSTANKER1256.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1256.png
# Processado: OILPRODUCTSTANKER1257.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1257.png
# Processado: OILPRODUCTSTANKER1258.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1258.png
# Processado: OILPRODUCTSTANKER1259.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1259.png
# Processado: OILPRODUCTSTANKER126.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER126.png
# Processado: OILPRODUCTSTANKER1260.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1260.png
# Processado: OILPRODUCTSTANKER1261.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1261.png
# Processado: OILPRODUCTSTANKER1262.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1262.png
# Processado: OILPRODUCTSTANKER1263.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1263.png
# Processado: OILPRODUCTSTANKER1264.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1264.png
# Processado: OILPRODUCTSTANKER1265.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1265.png
# Processado: OILPRODUCTSTANKER1266.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1266.png
# Processado: OILPRODUCTSTANKER1267.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1267.png
# Processado: OILPRODUCTSTANKER1268.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1268.png
# Processado: OILPRODUCTSTANKER1269.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1269.png
# Processado: OILPRODUCTSTANKER127.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER127.png
# Processado: OILPRODUCTSTANKER1270.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1270.png
# Processado: OILPRODUCTSTANKER1271.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1271.png
# Processado: OILPRODUCTSTANKER1272.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1272.png
# Processado: OILPRODUCTSTANKER1273.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1273.png
# Processado: OILPRODUCTSTANKER1274.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1274.png
# Processado: OILPRODUCTSTANKER1275.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1275.png
# Processado: OILPRODUCTSTANKER1276.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1276.png
# Processado: OILPRODUCTSTANKER1277.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1277.png
# Processado: OILPRODUCTSTANKER1278.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1278.png
# Processado: OILPRODUCTSTANKER1279.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1279.png
# Processado: OILPRODUCTSTANKER128.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER128.png
# Processado: OILPRODUCTSTANKER1280.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1280.png
# Processado: OILPRODUCTSTANKER1281.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1281.png
# Processado: OILPRODUCTSTANKER1282.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1282.png
# Processado: OILPRODUCTSTANKER1283.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1283.png
# Processado: OILPRODUCTSTANKER1284.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1284.png
# Processado: OILPRODUCTSTANKER1285.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1285.png
# Processado: OILPRODUCTSTANKER1286.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1286.png
# Processado: OILPRODUCTSTANKER1287.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1287.png
# Processado: OILPRODUCTSTANKER1288.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1288.png
# Processado: OILPRODUCTSTANKER1289.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1289.png
# Processado: OILPRODUCTSTANKER129.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER129.png
# Processado: OILPRODUCTSTANKER1290.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1290.png
# Processado: OILPRODUCTSTANKER1291.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1291.png
# Processado: OILPRODUCTSTANKER1292.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1292.png
# Processado: OILPRODUCTSTANKER1293.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1293.png
# Processado: OILPRODUCTSTANKER1294.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1294.png
# Processado: OILPRODUCTSTANKER1295.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1295.png
# Processado: OILPRODUCTSTANKER1296.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1296.png
# Processado: OILPRODUCTSTANKER1297.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1297.png
# Processado: OILPRODUCTSTANKER1298.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1298.png
# Processado: OILPRODUCTSTANKER1299.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1299.png
# Processado: OILPRODUCTSTANKER13.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER13.png
# Processado: OILPRODUCTSTANKER130.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER130.png
# Processado: OILPRODUCTSTANKER1300.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1300.png
# Processado: OILPRODUCTSTANKER1301.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1301.png
# Processado: OILPRODUCTSTANKER1302.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1302.png
# Processado: OILPRODUCTSTANKER1303.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1303.png
# Processado: OILPRODUCTSTANKER1304.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1304.png
# Processado: OILPRODUCTSTANKER1305.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1305.png
# Processado: OILPRODUCTSTANKER1306.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1306.png
# Processado: OILPRODUCTSTANKER1307.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1307.png
# Processado: OILPRODUCTSTANKER1308.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1308.png
# Processado: OILPRODUCTSTANKER1309.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1309.png
# Processado: OILPRODUCTSTANKER131.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER131.png
# Processado: OILPRODUCTSTANKER1310.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1310.png
# Processado: OILPRODUCTSTANKER1311.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1311.png
# Processado: OILPRODUCTSTANKER1312.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1312.png
# Processado: OILPRODUCTSTANKER1313.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1313.png
# Processado: OILPRODUCTSTANKER1314.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1314.png
# Processado: OILPRODUCTSTANKER1315.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1315.png
# Processado: OILPRODUCTSTANKER1316.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1316.png
# Processado: OILPRODUCTSTANKER1317.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1317.png
# Processado: OILPRODUCTSTANKER1318.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1318.png
# Processado: OILPRODUCTSTANKER1319.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1319.png
# Processado: OILPRODUCTSTANKER132.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER132.png
# Processado: OILPRODUCTSTANKER1320.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1320.png
# Processado: OILPRODUCTSTANKER1321.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1321.png
# Processado: OILPRODUCTSTANKER1322.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1322.png
# Processado: OILPRODUCTSTANKER1323.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1323.png
# Processado: OILPRODUCTSTANKER1324.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1324.png
# Processado: OILPRODUCTSTANKER1325.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1325.png
# Processado: OILPRODUCTSTANKER1326.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1326.png
# Processado: OILPRODUCTSTANKER1327.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1327.png
# Processado: OILPRODUCTSTANKER1328.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1328.png
# Processado: OILPRODUCTSTANKER1329.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1329.png
# Processado: OILPRODUCTSTANKER133.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER133.png
# Processado: OILPRODUCTSTANKER1330.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1330.png
# Processado: OILPRODUCTSTANKER1331.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1331.png
# Processado: OILPRODUCTSTANKER1332.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1332.png
# Processado: OILPRODUCTSTANKER1333.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1333.png
# Processado: OILPRODUCTSTANKER1334.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1334.png
# Processado: OILPRODUCTSTANKER1335.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1335.png
# Processado: OILPRODUCTSTANKER1336.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1336.png
# Processado: OILPRODUCTSTANKER1337.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1337.png
# Processado: OILPRODUCTSTANKER1338.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1338.png
# Processado: OILPRODUCTSTANKER1339.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1339.png
# Processado: OILPRODUCTSTANKER134.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER134.png
# Processado: OILPRODUCTSTANKER1340.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1340.png
# Processado: OILPRODUCTSTANKER1341.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1341.png
# Processado: OILPRODUCTSTANKER1342.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1342.png
# Processado: OILPRODUCTSTANKER1343.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1343.png
# Processado: OILPRODUCTSTANKER1344.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1344.png
# Processado: OILPRODUCTSTANKER1345.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1345.png
# Processado: OILPRODUCTSTANKER1346.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1346.png
# Processado: OILPRODUCTSTANKER1347.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1347.png
# Processado: OILPRODUCTSTANKER1348.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1348.png
# Processado: OILPRODUCTSTANKER1349.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1349.png
# Processado: OILPRODUCTSTANKER135.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER135.png
# Processado: OILPRODUCTSTANKER1350.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1350.png
# Processado: OILPRODUCTSTANKER1351.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1351.png
# Processado: OILPRODUCTSTANKER1352.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1352.png
# Processado: OILPRODUCTSTANKER1353.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1353.png
# Processado: OILPRODUCTSTANKER1354.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1354.png
# Processado: OILPRODUCTSTANKER1355.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1355.png
# Processado: OILPRODUCTSTANKER1356.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1356.png
# Processado: OILPRODUCTSTANKER1357.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1357.png
# Processado: OILPRODUCTSTANKER1358.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1358.png
# Processado: OILPRODUCTSTANKER1359.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1359.png
# Processado: OILPRODUCTSTANKER136.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER136.png
# Processado: OILPRODUCTSTANKER1360.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1360.png
# Processado: OILPRODUCTSTANKER1361.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1361.png
# Processado: OILPRODUCTSTANKER1362.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1362.png
# Processado: OILPRODUCTSTANKER1363.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1363.png
# Processado: OILPRODUCTSTANKER1364.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1364.png
# Processado: OILPRODUCTSTANKER1365.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1365.png
# Processado: OILPRODUCTSTANKER1366.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1366.png
# Processado: OILPRODUCTSTANKER1367.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1367.png
# Processado: OILPRODUCTSTANKER1368.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1368.png
# Processado: OILPRODUCTSTANKER1369.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1369.png
# Processado: OILPRODUCTSTANKER137.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER137.png
# Processado: OILPRODUCTSTANKER1370.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1370.png
# Processado: OILPRODUCTSTANKER1371.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1371.png
# Processado: OILPRODUCTSTANKER1372.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1372.png
# Processado: OILPRODUCTSTANKER1373.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1373.png
# Processado: OILPRODUCTSTANKER1374.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1374.png
# Processado: OILPRODUCTSTANKER1375.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1375.png
# Processado: OILPRODUCTSTANKER1376.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1376.png
# Processado: OILPRODUCTSTANKER1377.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1377.png
# Processado: OILPRODUCTSTANKER1378.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1378.png
# Processado: OILPRODUCTSTANKER1379.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1379.png
# Processado: OILPRODUCTSTANKER138.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER138.png
# Processado: OILPRODUCTSTANKER1380.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1380.png
# Processado: OILPRODUCTSTANKER1381.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1381.png
# Processado: OILPRODUCTSTANKER1382.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1382.png
# Processado: OILPRODUCTSTANKER1383.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1383.png
# Processado: OILPRODUCTSTANKER1384.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1384.png
# Processado: OILPRODUCTSTANKER1385.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1385.png
# Processado: OILPRODUCTSTANKER1386.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1386.png
# Processado: OILPRODUCTSTANKER1387.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1387.png
# Processado: OILPRODUCTSTANKER1388.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1388.png
# Processado: OILPRODUCTSTANKER1389.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1389.png
# Processado: OILPRODUCTSTANKER139.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER139.png
# Processado: OILPRODUCTSTANKER1390.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1390.png
# Processado: OILPRODUCTSTANKER1391.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1391.png
# Processado: OILPRODUCTSTANKER1392.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1392.png
# Processado: OILPRODUCTSTANKER1393.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1393.png
# Processado: OILPRODUCTSTANKER1394.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1394.png
# Processado: OILPRODUCTSTANKER1395.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1395.png
# Processado: OILPRODUCTSTANKER1396.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1396.png
# Processado: OILPRODUCTSTANKER1397.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1397.png
# Processado: OILPRODUCTSTANKER1398.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1398.png
# Processado: OILPRODUCTSTANKER1399.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1399.png
# Processado: OILPRODUCTSTANKER14.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER14.png
# Processado: OILPRODUCTSTANKER140.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER140.png
# Processado: OILPRODUCTSTANKER1400.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1400.png
# Processado: OILPRODUCTSTANKER1401.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1401.png
# Processado: OILPRODUCTSTANKER1402.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1402.png
# Processado: OILPRODUCTSTANKER1403.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1403.png
# Processado: OILPRODUCTSTANKER1404.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1404.png
# Processado: OILPRODUCTSTANKER1405.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1405.png
# Processado: OILPRODUCTSTANKER1406.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1406.png
# Processado: OILPRODUCTSTANKER1407.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1407.png
# Processado: OILPRODUCTSTANKER1408.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1408.png
# Processado: OILPRODUCTSTANKER1409.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1409.png
# Processado: OILPRODUCTSTANKER141.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER141.png
# Processado: OILPRODUCTSTANKER1410.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1410.png
# Processado: OILPRODUCTSTANKER1411.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1411.png
# Processado: OILPRODUCTSTANKER1412.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1412.png
# Processado: OILPRODUCTSTANKER1413.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1413.png
# Processado: OILPRODUCTSTANKER1414.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1414.png
# Processado: OILPRODUCTSTANKER1415.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1415.png
# Processado: OILPRODUCTSTANKER1416.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1416.png
# Processado: OILPRODUCTSTANKER1417.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1417.png
# Processado: OILPRODUCTSTANKER1418.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1418.png
# Processado: OILPRODUCTSTANKER1419.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1419.png
# Processado: OILPRODUCTSTANKER142.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER142.png
# Processado: OILPRODUCTSTANKER1420.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1420.png
# Processado: OILPRODUCTSTANKER1421.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1421.png
# Processado: OILPRODUCTSTANKER1422.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1422.png
# Processado: OILPRODUCTSTANKER1423.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1423.png
# Processado: OILPRODUCTSTANKER1424.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1424.png
# Processado: OILPRODUCTSTANKER1425.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1425.png
# Processado: OILPRODUCTSTANKER1426.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1426.png
# Processado: OILPRODUCTSTANKER1427.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1427.png
# Processado: OILPRODUCTSTANKER1428.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1428.png
# Processado: OILPRODUCTSTANKER1429.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1429.png
# Processado: OILPRODUCTSTANKER143.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER143.png
# Processado: OILPRODUCTSTANKER1430.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1430.png
# Processado: OILPRODUCTSTANKER1431.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1431.png
# Processado: OILPRODUCTSTANKER1432.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1432.png
# Processado: OILPRODUCTSTANKER1433.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1433.png
# Processado: OILPRODUCTSTANKER1434.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1434.png
# Processado: OILPRODUCTSTANKER1435.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1435.png
# Processado: OILPRODUCTSTANKER1436.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1436.png
# Processado: OILPRODUCTSTANKER1437.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1437.png
# Processado: OILPRODUCTSTANKER1438.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1438.png
# Processado: OILPRODUCTSTANKER1439.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1439.png
# Processado: OILPRODUCTSTANKER144.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER144.png
# Processado: OILPRODUCTSTANKER1440.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1440.png
# Processado: OILPRODUCTSTANKER1441.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1441.png
# Processado: OILPRODUCTSTANKER1442.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1442.png
# Processado: OILPRODUCTSTANKER1443.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1443.png
# Processado: OILPRODUCTSTANKER1444.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1444.png
# Processado: OILPRODUCTSTANKER1445.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1445.png
# Processado: OILPRODUCTSTANKER1446.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1446.png
# Processado: OILPRODUCTSTANKER1447.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1447.png
# Processado: OILPRODUCTSTANKER1448.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER1448.png
# ...
# Processado: OILPRODUCTSTANKER846.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER846.png
# Processado: OILPRODUCTSTANKER847.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER847.png
# Processado: OILPRODUCTSTANKER848.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER848.png
# Processado: OILPRODUCTSTANKER849.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER849.png
# Processado: OILPRODUCTSTANKER85.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER85.png
# Processado: OILPRODUCTSTANKER850.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER850.png
# Processado: OILPRODUCTSTANKER851.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER851.png
# Processado: OILPRODUCTSTANKER852.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER852.png
# Processado: OILPRODUCTSTANKER853.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER853.png
# Processado: OILPRODUCTSTANKER854.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER854.png
# Processado: OILPRODUCTSTANKER855.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER855.png
# Processado: OILPRODUCTSTANKER856.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER856.png
# Processado: OILPRODUCTSTANKER857.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER857.png
# Processado: OILPRODUCTSTANKER858.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER858.png
# Processado: OILPRODUCTSTANKER859.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER859.png
# Processado: OILPRODUCTSTANKER86.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER86.png
# Processado: OILPRODUCTSTANKER860.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER860.png
# Processado: OILPRODUCTSTANKER861.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER861.png
# Processado: OILPRODUCTSTANKER862.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER862.png
# Processado: OILPRODUCTSTANKER863.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER863.png
# Processado: OILPRODUCTSTANKER864.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER864.png
# Processado: OILPRODUCTSTANKER865.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER865.png
# Processado: OILPRODUCTSTANKER866.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER866.png
# Processado: OILPRODUCTSTANKER867.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER867.png
# Processado: OILPRODUCTSTANKER868.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER868.png
# Processado: OILPRODUCTSTANKER869.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER869.png
# Processado: OILPRODUCTSTANKER87.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER87.png
# Processado: OILPRODUCTSTANKER870.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER870.png
# Processado: OILPRODUCTSTANKER871.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER871.png
# Processado: OILPRODUCTSTANKER872.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER872.png
# Processado: OILPRODUCTSTANKER873.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER873.png
# Processado: OILPRODUCTSTANKER874.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER874.png
# Processado: OILPRODUCTSTANKER875.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER875.png
# Processado: OILPRODUCTSTANKER876.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER876.png
# Processado: OILPRODUCTSTANKER877.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER877.png
# Processado: OILPRODUCTSTANKER878.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER878.png
# Processado: OILPRODUCTSTANKER879.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER879.png
# Processado: OILPRODUCTSTANKER88.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER88.png
# Processado: OILPRODUCTSTANKER880.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER880.png
# Processado: OILPRODUCTSTANKER881.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER881.png
# Processado: OILPRODUCTSTANKER882.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER882.png
# Processado: OILPRODUCTSTANKER883.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER883.png
# Processado: OILPRODUCTSTANKER884.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER884.png
# Processado: OILPRODUCTSTANKER885.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER885.png
# Processado: OILPRODUCTSTANKER886.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER886.png
# Processado: OILPRODUCTSTANKER887.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER887.png
# Processado: OILPRODUCTSTANKER888.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER888.png
# Processado: OILPRODUCTSTANKER889.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER889.png
# Processado: OILPRODUCTSTANKER89.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER89.png
# Processado: OILPRODUCTSTANKER890.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER890.png
# Processado: OILPRODUCTSTANKER891.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER891.png
# Processado: OILPRODUCTSTANKER892.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER892.png
# Processado: OILPRODUCTSTANKER893.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER893.png
# Processado: OILPRODUCTSTANKER894.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER894.png
# Processado: OILPRODUCTSTANKER895.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER895.png
# Processado: OILPRODUCTSTANKER896.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER896.png
# Processado: OILPRODUCTSTANKER897.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER897.png
# Processado: OILPRODUCTSTANKER898.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER898.png
# Processado: OILPRODUCTSTANKER899.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER899.png
# Processado: OILPRODUCTSTANKER9.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER9.png
# Processado: OILPRODUCTSTANKER90.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER90.png
# Processado: OILPRODUCTSTANKER900.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER900.png
# Processado: OILPRODUCTSTANKER901.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER901.png
# Processado: OILPRODUCTSTANKER902.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER902.png
# Processado: OILPRODUCTSTANKER903.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER903.png
# Processado: OILPRODUCTSTANKER904.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER904.png
# Processado: OILPRODUCTSTANKER905.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER905.png
# Processado: OILPRODUCTSTANKER906.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER906.png
# Processado: OILPRODUCTSTANKER907.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER907.png
# Processado: OILPRODUCTSTANKER908.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER908.png
# Processado: OILPRODUCTSTANKER909.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER909.png
# Processado: OILPRODUCTSTANKER91.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER91.png
# Processado: OILPRODUCTSTANKER910.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER910.png
# Processado: OILPRODUCTSTANKER911.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER911.png
# Processado: OILPRODUCTSTANKER912.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER912.png
# Processado: OILPRODUCTSTANKER913.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER913.png
# Processado: OILPRODUCTSTANKER914.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER914.png
# Processado: OILPRODUCTSTANKER915.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER915.png
# Processado: OILPRODUCTSTANKER916.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER916.png
# Processado: OILPRODUCTSTANKER917.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER917.png
# Processado: OILPRODUCTSTANKER918.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER918.png
# Processado: OILPRODUCTSTANKER919.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER919.png
# Processado: OILPRODUCTSTANKER92.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER92.png
# Processado: OILPRODUCTSTANKER920.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER920.png
# Processado: OILPRODUCTSTANKER921.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER921.png
# Processado: OILPRODUCTSTANKER922.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER922.png
# Processado: OILPRODUCTSTANKER923.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER923.png
# Processado: OILPRODUCTSTANKER924.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER924.png
# Processado: OILPRODUCTSTANKER925.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER925.png
# Processado: OILPRODUCTSTANKER926.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER926.png
# Processado: OILPRODUCTSTANKER927.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER927.png
# Processado: OILPRODUCTSTANKER928.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER928.png
# Processado: OILPRODUCTSTANKER929.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER929.png
# Processado: OILPRODUCTSTANKER93.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER93.png
# Processado: OILPRODUCTSTANKER930.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER930.png
# Processado: OILPRODUCTSTANKER931.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER931.png
# Processado: OILPRODUCTSTANKER932.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER932.png
# Processado: OILPRODUCTSTANKER933.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER933.png
# Processado: OILPRODUCTSTANKER934.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER934.png
# Processado: OILPRODUCTSTANKER935.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER935.png
# Processado: OILPRODUCTSTANKER936.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER936.png
# Processado: OILPRODUCTSTANKER937.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER937.png
# Processado: OILPRODUCTSTANKER938.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER938.png
# Processado: OILPRODUCTSTANKER939.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER939.png
# Processado: OILPRODUCTSTANKER94.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER94.png
# Processado: OILPRODUCTSTANKER940.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER940.png
# Processado: OILPRODUCTSTANKER941.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER941.png
# Processado: OILPRODUCTSTANKER942.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER942.png
# Processado: OILPRODUCTSTANKER943.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER943.png
# Processado: OILPRODUCTSTANKER944.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER944.png
# Processado: OILPRODUCTSTANKER945.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER945.png
# Processado: OILPRODUCTSTANKER946.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER946.png
# Processado: OILPRODUCTSTANKER947.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER947.png
# Processado: OILPRODUCTSTANKER948.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER948.png
# Processado: OILPRODUCTSTANKER949.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER949.png
# Processado: OILPRODUCTSTANKER95.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER95.png
# Processado: OILPRODUCTSTANKER950.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER950.png
# Processado: OILPRODUCTSTANKER951.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER951.png
# Processado: OILPRODUCTSTANKER952.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER952.png
# Processado: OILPRODUCTSTANKER953.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER953.png
# Processado: OILPRODUCTSTANKER954.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER954.png
# Processado: OILPRODUCTSTANKER955.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER955.png
# Processado: OILPRODUCTSTANKER956.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER956.png
# Processado: OILPRODUCTSTANKER957.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER957.png
# Processado: OILPRODUCTSTANKER958.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER958.png
# Processado: OILPRODUCTSTANKER959.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER959.png
# Processado: OILPRODUCTSTANKER96.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER96.png
# Processado: OILPRODUCTSTANKER960.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER960.png
# Processado: OILPRODUCTSTANKER961.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER961.png
# Processado: OILPRODUCTSTANKER962.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER962.png
# Processado: OILPRODUCTSTANKER963.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER963.png
# Processado: OILPRODUCTSTANKER964.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER964.png
# Processado: OILPRODUCTSTANKER965.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER965.png
# Processado: OILPRODUCTSTANKER966.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER966.png
# Processado: OILPRODUCTSTANKER967.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER967.png
# Processado: OILPRODUCTSTANKER968.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER968.png
# Processado: OILPRODUCTSTANKER969.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER969.png
# Processado: OILPRODUCTSTANKER97.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER97.png
# Processado: OILPRODUCTSTANKER970.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER970.png
# Processado: OILPRODUCTSTANKER971.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER971.png
# Processado: OILPRODUCTSTANKER972.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER972.png
# Processado: OILPRODUCTSTANKER973.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER973.png
# Processado: OILPRODUCTSTANKER974.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER974.png
# Processado: OILPRODUCTSTANKER975.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER975.png
# Processado: OILPRODUCTSTANKER976.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER976.png
# Processado: OILPRODUCTSTANKER977.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER977.png
# Processado: OILPRODUCTSTANKER978.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER978.png
# Processado: OILPRODUCTSTANKER979.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER979.png
# Processado: OILPRODUCTSTANKER98.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER98.png
# Processado: OILPRODUCTSTANKER980.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER980.png
# Processado: OILPRODUCTSTANKER981.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER981.png
# Processado: OILPRODUCTSTANKER982.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER982.png
# Processado: OILPRODUCTSTANKER983.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER983.png
# Processado: OILPRODUCTSTANKER984.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER984.png
# Processado: OILPRODUCTSTANKER985.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER985.png
# Processado: OILPRODUCTSTANKER986.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER986.png
# Processado: OILPRODUCTSTANKER987.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER987.png
# Processado: OILPRODUCTSTANKER988.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER988.png
# Processado: OILPRODUCTSTANKER989.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER989.png
# Processado: OILPRODUCTSTANKER99.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER99.png
# Processado: OILPRODUCTSTANKER990.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER990.png
# Processado: OILPRODUCTSTANKER991.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER991.png
# Processado: OILPRODUCTSTANKER992.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER992.png
# Processado: OILPRODUCTSTANKER993.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER993.png
# Processado: OILPRODUCTSTANKER994.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER994.png
# Processado: OILPRODUCTSTANKER995.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER995.png
# Processado: OILPRODUCTSTANKER996.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER996.png
# Processado: OILPRODUCTSTANKER997.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER997.png
# Processado: OILPRODUCTSTANKER998.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER998.png
# Processado: OILPRODUCTSTANKER999.png -> DDPM-F64x4/OILPRODUCTSTANKER/OILPRODUCTSTANKER999.png
# Processamento concluído!
