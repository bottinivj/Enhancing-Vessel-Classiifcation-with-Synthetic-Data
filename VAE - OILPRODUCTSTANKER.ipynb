# %%
generating_class = 'OILPRODUCTSTANKER'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-24 22:13:59.126733: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-24 22:13:59.147120: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-24 22:14:00.907019: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:00.909848: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:00.909865: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-24 22:14:07.812920: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:07.812958: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:07.812968: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:07.921196: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:07.921223: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:07.921228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-24 22:14:07.921242: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 22:14:07.921260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-24 22:14:10.858380: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-24 22:14:10.858411: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753395251.922151   93237 service.cc:145] XLA service 0x7f423c0142b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753395251.922187   93237 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-24 22:14:11.987231: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-24 22:14:12.164047: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-24 22:14:18.331018: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:18.420162: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.089235762s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:30.622994: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:31.361931: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.739038719s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:32.362079: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:33.012547: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.650547078s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:34.012703: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:34.803329: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.790723876s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:35.803490: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 22:14:36.399717: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.596323945s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753395283.657925   93237 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 44s 464ms/step - kl_loss: 4.5385e-07 - loss: 2838.9600 - reconstruction_loss: 2838.9600
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 1.1268e-05 - loss: 2837.9263 - reconstruction_loss: 2837.9263
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 0.9986 - loss: 2831.7739 - reconstruction_loss: 2830.7754
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6762 - loss: 2746.5872 - reconstruction_loss: 2724.9109
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 5.3736 - loss: 2689.9658 - reconstruction_loss: 2684.5920
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 3.9609 - loss: 2671.1138 - reconstruction_loss: 2667.1528
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 7.2832 - loss: 2647.3335 - reconstruction_loss: 2640.0503
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.5052 - loss: 2644.4531 - reconstruction_loss: 2634.9478
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 7.5578 - loss: 2635.3186 - reconstruction_loss: 2627.7610
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 6.5891 - loss: 2631.2874 - reconstruction_loss: 2624.6985
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 7.5300 - loss: 2622.0493 - reconstruction_loss: 2614.5198
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 8.6661 - loss: 2614.9553 - reconstruction_loss: 2606.2891
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.4043 - loss: 2605.3010 - reconstruction_loss: 2594.8967
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.2400 - loss: 2595.2437 - reconstruction_loss: 2584.0037
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.2479 - loss: 2591.2107 - reconstruction_loss: 2579.9629
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.9975 - loss: 2591.6077 - reconstruction_loss: 2580.6101
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.9478 - loss: 2587.0601 - reconstruction_loss: 2576.1121
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.4235 - loss: 2583.2185 - reconstruction_loss: 2572.7952
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 10.2205 - loss: 2579.9199 - reconstruction_loss: 2569.6995
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.0405 - loss: 2577.3152 - reconstruction_loss: 2567.2749
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.2695 - loss: 2566.3916 - reconstruction_loss: 2555.1221
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.3646 - loss: 2564.3330 - reconstruction_loss: 2552.9683
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3448 - loss: 2559.5327 - reconstruction_loss: 2547.1877
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.6014 - loss: 2553.5996 - reconstruction_loss: 2540.9983
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.5415 - loss: 2548.1624 - reconstruction_loss: 2535.6208
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.1835 - loss: 2549.6477 - reconstruction_loss: 2537.4639
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.1061 - loss: 2546.8621 - reconstruction_loss: 2534.7561
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.7470 - loss: 2546.3743 - reconstruction_loss: 2534.6274
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.4541 - loss: 2546.8228 - reconstruction_loss: 2535.3689
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.5475 - loss: 2540.2075 - reconstruction_loss: 2528.6602
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.4026 - loss: 2539.0869 - reconstruction_loss: 2527.6843
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.1158 - loss: 2540.7039 - reconstruction_loss: 2529.5881
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.1209 - loss: 2539.0024 - reconstruction_loss: 2527.8813
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.1931 - loss: 2534.8574 - reconstruction_loss: 2523.6641
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.8308 - loss: 2528.5964 - reconstruction_loss: 2516.7659
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.2187 - loss: 2528.0579 - reconstruction_loss: 2515.8394
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.4903 - loss: 2524.4539 - reconstruction_loss: 2511.9636
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.5371 - loss: 2520.5066 - reconstruction_loss: 2506.9692
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.1053 - loss: 2512.3491 - reconstruction_loss: 2498.2437
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.8122 - loss: 2515.7617 - reconstruction_loss: 2501.9495
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4997 - loss: 2513.9473 - reconstruction_loss: 2500.4478
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.5154 - loss: 2513.2634 - reconstruction_loss: 2499.7480
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 13.6796 - loss: 2509.3535 - reconstruction_loss: 2495.6738
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 13.6506 - loss: 2509.7190 - reconstruction_loss: 2496.0684
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.1610 - loss: 2505.7422 - reconstruction_loss: 2491.5808
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.3540 - loss: 2506.9946 - reconstruction_loss: 2492.6406
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2806 - loss: 2502.9971 - reconstruction_loss: 2488.7168
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.2915 - loss: 2504.6482 - reconstruction_loss: 2490.3564
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.6119 - loss: 2498.4204 - reconstruction_loss: 2483.8083
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3634 - loss: 2500.6165 - reconstruction_loss: 2486.2532
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.4781 - loss: 2499.6833 - reconstruction_loss: 2485.2053
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3809 - loss: 2502.7000 - reconstruction_loss: 2488.3191
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5362 - loss: 2495.8149 - reconstruction_loss: 2481.2788
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2932 - loss: 2500.7607 - reconstruction_loss: 2486.4680
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.4479 - loss: 2495.8835 - reconstruction_loss: 2481.4353
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.3693 - loss: 2495.5984 - reconstruction_loss: 2481.2292
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5312 - loss: 2496.4829 - reconstruction_loss: 2481.9517
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.4288 - loss: 2492.6421 - reconstruction_loss: 2478.2131
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5420 - loss: 2492.1736 - reconstruction_loss: 2477.6318
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.8181 - loss: 2489.0710 - reconstruction_loss: 2474.2529
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.9892 - loss: 2493.4849 - reconstruction_loss: 2478.4956
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.0417 - loss: 2487.2524 - reconstruction_loss: 2472.2104
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.9901 - loss: 2489.1794 - reconstruction_loss: 2474.1895
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1221 - loss: 2487.0798 - reconstruction_loss: 2471.9578
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1010 - loss: 2487.7856 - reconstruction_loss: 2472.6841
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.3132 - loss: 2486.4690 - reconstruction_loss: 2471.1560
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.4554 - loss: 2484.8267 - reconstruction_loss: 2469.3713
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.4842 - loss: 2483.7166 - reconstruction_loss: 2468.2322
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.7983 - loss: 2484.6182 - reconstruction_loss: 2468.8198
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.1591 - loss: 2480.1855 - reconstruction_loss: 2464.0264
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.3481 - loss: 2480.1035 - reconstruction_loss: 2463.7554
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.6686 - loss: 2483.3813 - reconstruction_loss: 2466.7129
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.9346 - loss: 2482.2498 - reconstruction_loss: 2465.3152
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.0248 - loss: 2474.8870 - reconstruction_loss: 2457.8621
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.1579 - loss: 2476.2476 - reconstruction_loss: 2459.0896
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.2937 - loss: 2473.9788 - reconstruction_loss: 2456.6851
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.2207 - loss: 2474.7781 - reconstruction_loss: 2457.5579
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.3158 - loss: 2474.8899 - reconstruction_loss: 2457.5740
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.1547 - loss: 2477.1687 - reconstruction_loss: 2460.0137
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.4696 - loss: 2474.5562 - reconstruction_loss: 2457.0867
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5538 - loss: 2473.8328 - reconstruction_loss: 2456.2791
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.2857 - loss: 2476.6633 - reconstruction_loss: 2459.3774
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.5041 - loss: 2472.3125 - reconstruction_loss: 2454.8088
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.5386 - loss: 2475.9373 - reconstruction_loss: 2458.3982
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.6342 - loss: 2470.1057 - reconstruction_loss: 2452.4719
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.6325 - loss: 2468.7075 - reconstruction_loss: 2451.0750
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.7669 - loss: 2472.5005 - reconstruction_loss: 2454.7334
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.0266 - loss: 2470.1572 - reconstruction_loss: 2452.1306
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.8545 - loss: 2468.3125 - reconstruction_loss: 2450.4580
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.1283 - loss: 2466.1611 - reconstruction_loss: 2448.0330
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2724 - loss: 2464.7214 - reconstruction_loss: 2446.4490
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.2532 - loss: 2469.1931 - reconstruction_loss: 2450.9399
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2606 - loss: 2466.6262 - reconstruction_loss: 2448.3655
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.3190 - loss: 2466.9087 - reconstruction_loss: 2448.5898
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4000 - loss: 2469.6943 - reconstruction_loss: 2451.2947
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2753 - loss: 2465.4492 - reconstruction_loss: 2447.1738
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4333 - loss: 2459.3704 - reconstruction_loss: 2440.9373
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.5641 - loss: 2463.3440 - reconstruction_loss: 2444.7798
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.6370 - loss: 2465.3931 - reconstruction_loss: 2446.7561
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.8076 - loss: 2462.6306 - reconstruction_loss: 2443.8228
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.9190 - loss: 2462.3635 - reconstruction_loss: 2443.4446
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8281 - loss: 2463.6101 - reconstruction_loss: 2444.7815
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.2439 - loss: 2465.5715 - reconstruction_loss: 2446.3276
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3623 - loss: 2463.7112 - reconstruction_loss: 2444.3486
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.4000 - loss: 2465.8347 - reconstruction_loss: 2446.4346
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.1872 - loss: 2463.2935 - reconstruction_loss: 2444.1062
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.3427 - loss: 2461.4324 - reconstruction_loss: 2442.0901
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.3888 - loss: 2462.0439 - reconstruction_loss: 2442.6553
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.2749 - loss: 2461.2012 - reconstruction_loss: 2441.9265
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.3499 - loss: 2461.8765 - reconstruction_loss: 2442.5266
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.4034 - loss: 2461.2393 - reconstruction_loss: 2441.8359
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.3378 - loss: 2461.4751 - reconstruction_loss: 2442.1370
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5389 - loss: 2460.0522 - reconstruction_loss: 2440.5134
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3672 - loss: 2459.8679 - reconstruction_loss: 2440.5005
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5796 - loss: 2459.3416 - reconstruction_loss: 2439.7622
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.5649 - loss: 2461.3462 - reconstruction_loss: 2441.7812
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.7427 - loss: 2463.2764 - reconstruction_loss: 2443.5337
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6770 - loss: 2457.6394 - reconstruction_loss: 2437.9624
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.7055 - loss: 2457.3977 - reconstruction_loss: 2437.6924
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.7155 - loss: 2456.1206 - reconstruction_loss: 2436.4050
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.8941 - loss: 2453.9402 - reconstruction_loss: 2434.0461
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9067 - loss: 2454.8618 - reconstruction_loss: 2434.9551
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.7741 - loss: 2458.6062 - reconstruction_loss: 2438.8323
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.8880 - loss: 2455.1707 - reconstruction_loss: 2435.2822
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8650 - loss: 2456.1111 - reconstruction_loss: 2436.2461
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0930 - loss: 2452.4487 - reconstruction_loss: 2432.3562
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1672 - loss: 2455.8325 - reconstruction_loss: 2435.6653
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2981 - loss: 2450.0662 - reconstruction_loss: 2429.7678
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0266 - loss: 2457.0120 - reconstruction_loss: 2436.9851
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.2516 - loss: 2452.9407 - reconstruction_loss: 2432.6890
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.2431 - loss: 2450.0339 - reconstruction_loss: 2429.7910
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.1590 - loss: 2453.6663 - reconstruction_loss: 2433.5073
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.5783 - loss: 2452.8342 - reconstruction_loss: 2432.2559
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2722 - loss: 2454.2568 - reconstruction_loss: 2433.9846
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3950 - loss: 2449.9763 - reconstruction_loss: 2429.5813
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4976 - loss: 2452.2673 - reconstruction_loss: 2431.7698
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.4850 - loss: 2452.8655 - reconstruction_loss: 2432.3806
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4841 - loss: 2449.2063 - reconstruction_loss: 2428.7222
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.2827 - loss: 2450.8970 - reconstruction_loss: 2430.6138
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6185 - loss: 2449.7551 - reconstruction_loss: 2429.1367
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6366 - loss: 2447.8228 - reconstruction_loss: 2427.1860
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6216 - loss: 2448.0830 - reconstruction_loss: 2427.4617
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6828 - loss: 2446.1794 - reconstruction_loss: 2425.4966
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5592 - loss: 2451.3337 - reconstruction_loss: 2430.7744
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6668 - loss: 2450.5933 - reconstruction_loss: 2429.9268
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5731 - loss: 2447.9573 - reconstruction_loss: 2427.3843
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8470 - loss: 2449.6482 - reconstruction_loss: 2428.8015
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8533 - loss: 2445.5063 - reconstruction_loss: 2424.6528
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.7029 - loss: 2453.1047 - reconstruction_loss: 2432.4016
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.9710 - loss: 2448.7058 - reconstruction_loss: 2427.7346
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8291 - loss: 2450.2458 - reconstruction_loss: 2429.4167
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8835 - loss: 2447.8625 - reconstruction_loss: 2426.9788
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9049 - loss: 2445.2681 - reconstruction_loss: 2424.3630
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8049 - loss: 2450.4214 - reconstruction_loss: 2429.6167
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9831 - loss: 2449.5549 - reconstruction_loss: 2428.5718
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.0978 - loss: 2446.4021 - reconstruction_loss: 2425.3044
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0362 - loss: 2448.1394 - reconstruction_loss: 2427.1035
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0662 - loss: 2447.8430 - reconstruction_loss: 2426.7769
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1571 - loss: 2443.2690 - reconstruction_loss: 2422.1121
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.0383 - loss: 2445.3567 - reconstruction_loss: 2424.3184
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.9271 - loss: 2447.9094 - reconstruction_loss: 2426.9824
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.1322 - loss: 2443.6331 - reconstruction_loss: 2422.5007
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0735 - loss: 2445.0481 - reconstruction_loss: 2423.9744
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0768 - loss: 2445.4668 - reconstruction_loss: 2424.3899
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0330 - loss: 2441.6279 - reconstruction_loss: 2420.5950
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2341 - loss: 2443.2737 - reconstruction_loss: 2422.0396
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.3514 - loss: 2445.7703 - reconstruction_loss: 2424.4187
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.2521 - loss: 2444.3452 - reconstruction_loss: 2423.0930
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3175 - loss: 2444.8010 - reconstruction_loss: 2423.4836
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.2598 - loss: 2444.7485 - reconstruction_loss: 2423.4888
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.4342 - loss: 2439.1792 - reconstruction_loss: 2417.7451
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3812 - loss: 2444.7805 - reconstruction_loss: 2423.3992
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.3525 - loss: 2441.3784 - reconstruction_loss: 2420.0261
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.4037 - loss: 2441.3303 - reconstruction_loss: 2419.9263
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2635 - loss: 2443.4292 - reconstruction_loss: 2422.1655
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.5481 - loss: 2439.2515 - reconstruction_loss: 2417.7031
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6112 - loss: 2441.3289 - reconstruction_loss: 2419.7178
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.4632 - loss: 2444.4126 - reconstruction_loss: 2422.9495
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.5741 - loss: 2438.8452 - reconstruction_loss: 2417.2712
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6007 - loss: 2439.5193 - reconstruction_loss: 2417.9185
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.6431 - loss: 2441.9133 - reconstruction_loss: 2420.2703
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.5361 - loss: 2440.9683 - reconstruction_loss: 2419.4319
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.6312 - loss: 2439.9565 - reconstruction_loss: 2418.3252
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.5478 - loss: 2438.1941 - reconstruction_loss: 2416.6465
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6307 - loss: 2437.9751 - reconstruction_loss: 2416.3442
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.7668 - loss: 2437.6516 - reconstruction_loss: 2415.8848
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.8058 - loss: 2439.2659 - reconstruction_loss: 2417.4600
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7332 - loss: 2441.8484 - reconstruction_loss: 2420.1152
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.7560 - loss: 2438.3079 - reconstruction_loss: 2416.5520
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6594 - loss: 2440.6731 - reconstruction_loss: 2419.0137
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6988 - loss: 2440.0315 - reconstruction_loss: 2418.3328
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8408 - loss: 2441.0359 - reconstruction_loss: 2419.1951
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9068 - loss: 2435.7910 - reconstruction_loss: 2413.8840
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.7928 - loss: 2442.0840 - reconstruction_loss: 2420.2910
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.0227 - loss: 2438.6414 - reconstruction_loss: 2416.6184
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.9970 - loss: 2438.2805 - reconstruction_loss: 2416.2842
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.0060 - loss: 2438.6877 - reconstruction_loss: 2416.6816
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9605 - loss: 2433.8738 - reconstruction_loss: 2411.9133
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0643 - loss: 2435.5203 - reconstruction_loss: 2413.4563
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0157 - loss: 2436.5417 - reconstruction_loss: 2414.5261
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0954 - loss: 2435.5928 - reconstruction_loss: 2413.4973
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2681 - loss: 2428.5518 - reconstruction_loss: 2406.2837
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0505 - loss: 2436.4836 - reconstruction_loss: 2414.4331
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0321 - loss: 2434.3875 - reconstruction_loss: 2412.3555
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3657 - loss: 2436.5251 - reconstruction_loss: 2414.1597
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.1766 - loss: 2435.3093 - reconstruction_loss: 2413.1331
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.4236 - loss: 2430.8713 - reconstruction_loss: 2408.4478
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2275 - loss: 2433.2781 - reconstruction_loss: 2411.0505
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.2551 - loss: 2433.2507 - reconstruction_loss: 2410.9958
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.1255 - loss: 2435.6699 - reconstruction_loss: 2413.5444
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.2422 - loss: 2431.5027 - reconstruction_loss: 2409.2607
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.2559 - loss: 2429.6440 - reconstruction_loss: 2407.3887
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.4074 - loss: 2430.9197 - reconstruction_loss: 2408.5122
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2577 - loss: 2431.6526 - reconstruction_loss: 2409.3953
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3154 - loss: 2429.8442 - reconstruction_loss: 2407.5291
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.4039 - loss: 2430.9453 - reconstruction_loss: 2408.5413
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6324 - loss: 2428.6921 - reconstruction_loss: 2406.0601
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5886 - loss: 2432.8608 - reconstruction_loss: 2410.2722
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4768 - loss: 2429.5432 - reconstruction_loss: 2407.0662
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5977 - loss: 2429.4536 - reconstruction_loss: 2406.8560
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5049 - loss: 2425.8887 - reconstruction_loss: 2403.3838
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.5102 - loss: 2432.3733 - reconstruction_loss: 2409.8628
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.5608 - loss: 2428.4729 - reconstruction_loss: 2405.9119
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7328 - loss: 2429.7537 - reconstruction_loss: 2407.0205
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6538 - loss: 2427.1235 - reconstruction_loss: 2404.4695
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.7222 - loss: 2426.5105 - reconstruction_loss: 2403.7883
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5910 - loss: 2431.1392 - reconstruction_loss: 2408.5479
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6595 - loss: 2427.0632 - reconstruction_loss: 2404.4038
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7387 - loss: 2428.4678 - reconstruction_loss: 2405.7292
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.6082 - loss: 2427.2078 - reconstruction_loss: 2404.5996
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6128 - loss: 2425.5129 - reconstruction_loss: 2402.9001
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9878 - loss: 2427.4053 - reconstruction_loss: 2404.4172
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7174 - loss: 2427.8760 - reconstruction_loss: 2405.1587
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6477 - loss: 2429.8982 - reconstruction_loss: 2407.2502
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.7507 - loss: 2432.4800 - reconstruction_loss: 2409.7292
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.7332 - loss: 2432.7100 - reconstruction_loss: 2409.9768
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.8921 - loss: 2426.2786 - reconstruction_loss: 2403.3865
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9675 - loss: 2418.7961 - reconstruction_loss: 2395.8289
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9866 - loss: 2424.3005 - reconstruction_loss: 2401.3137
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9834 - loss: 2427.9412 - reconstruction_loss: 2404.9578
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.8597 - loss: 2420.7957 - reconstruction_loss: 2397.9358
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0304 - loss: 2425.2107 - reconstruction_loss: 2402.1804
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0892 - loss: 2425.6833 - reconstruction_loss: 2402.5942
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9719 - loss: 2424.4141 - reconstruction_loss: 2401.4421
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0581 - loss: 2424.1873 - reconstruction_loss: 2401.1294
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0256 - loss: 2422.3428 - reconstruction_loss: 2399.3169
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1313 - loss: 2424.3245 - reconstruction_loss: 2401.1934
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1084 - loss: 2423.5674 - reconstruction_loss: 2400.4592
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1573 - loss: 2420.1604 - reconstruction_loss: 2397.0032
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2512 - loss: 2420.9868 - reconstruction_loss: 2397.7354
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2454 - loss: 2422.0574 - reconstruction_loss: 2398.8120
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1643 - loss: 2424.0095 - reconstruction_loss: 2400.8452
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.3370 - loss: 2422.0239 - reconstruction_loss: 2398.6870
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2214 - loss: 2423.0190 - reconstruction_loss: 2399.7979
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2864 - loss: 2423.1396 - reconstruction_loss: 2399.8528
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3506 - loss: 2422.8054 - reconstruction_loss: 2399.4546
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2309 - loss: 2420.5972 - reconstruction_loss: 2397.3665
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2132 - loss: 2420.7202 - reconstruction_loss: 2397.5071
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4042 - loss: 2423.0542 - reconstruction_loss: 2399.6501
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4116 - loss: 2421.3076 - reconstruction_loss: 2397.8958
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4561 - loss: 2424.0945 - reconstruction_loss: 2400.6382
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2944 - loss: 2424.2385 - reconstruction_loss: 2400.9438
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.3828 - loss: 2419.5000 - reconstruction_loss: 2396.1172
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.3396 - loss: 2424.3665 - reconstruction_loss: 2401.0271
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4300 - loss: 2419.6060 - reconstruction_loss: 2396.1758
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.5296 - loss: 2414.4053 - reconstruction_loss: 2390.8757
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4142 - loss: 2426.5332 - reconstruction_loss: 2403.1187
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4885 - loss: 2423.7903 - reconstruction_loss: 2400.3018
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.5004 - loss: 2419.6514 - reconstruction_loss: 2396.1511
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.4144 - loss: 2421.0857 - reconstruction_loss: 2397.6714
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.5166 - loss: 2416.8044 - reconstruction_loss: 2393.2878
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4575 - loss: 2420.2996 - reconstruction_loss: 2396.8425
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.5628 - loss: 2416.0203 - reconstruction_loss: 2392.4578
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.3580 - loss: 2421.9131 - reconstruction_loss: 2398.5549
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6899 - loss: 2417.0906 - reconstruction_loss: 2393.4006
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.6862 - loss: 2420.0056 - reconstruction_loss: 2396.3191
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.8157 - loss: 2413.7488 - reconstruction_loss: 2389.9331
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6832 - loss: 2417.2229 - reconstruction_loss: 2393.5398
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.7633 - loss: 2412.7678 - reconstruction_loss: 2389.0046
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6918 - loss: 2414.1943 - reconstruction_loss: 2390.5022
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6981 - loss: 2417.1541 - reconstruction_loss: 2393.4563
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.7141 - loss: 2420.6140 - reconstruction_loss: 2396.8997
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.5302 - loss: 2416.0212 - reconstruction_loss: 2392.4912
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6295 - loss: 2414.8992 - reconstruction_loss: 2391.2698
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6292 - loss: 2413.3860 - reconstruction_loss: 2389.7568
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6752 - loss: 2416.2268 - reconstruction_loss: 2392.5515
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6474 - loss: 2418.9851 - reconstruction_loss: 2395.3374
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4290 - loss: 2369.4294 - reconstruction_loss: 2344.0005
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3848 - loss: 2366.6274 - reconstruction_loss: 2341.2427
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3588 - loss: 2370.5117 - reconstruction_loss: 2345.1528
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5267 - loss: 2368.0371 - reconstruction_loss: 2342.5103
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5082 - loss: 2370.1248 - reconstruction_loss: 2344.6165
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5296 - loss: 2365.5154 - reconstruction_loss: 2339.9858
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4636 - loss: 2369.9187 - reconstruction_loss: 2344.4551
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4243 - loss: 2367.0103 - reconstruction_loss: 2341.5859
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4582 - loss: 2368.7913 - reconstruction_loss: 2343.3330
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4029 - loss: 2369.3049 - reconstruction_loss: 2343.9019
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4268 - loss: 2369.1992 - reconstruction_loss: 2343.7722
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3317 - loss: 2369.5469 - reconstruction_loss: 2344.2153
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4387 - loss: 2365.7068 - reconstruction_loss: 2340.2683
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3951 - loss: 2368.1099 - reconstruction_loss: 2342.7148
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4357 - loss: 2369.0862 - reconstruction_loss: 2343.6504
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4621 - loss: 2364.2898 - reconstruction_loss: 2338.8276
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.6003 - loss: 2369.0684 - reconstruction_loss: 2343.4680
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.6213 - loss: 2365.7090 - reconstruction_loss: 2340.0879
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4988 - loss: 2364.5444 - reconstruction_loss: 2339.0454
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5037 - loss: 2366.4131 - reconstruction_loss: 2340.9097
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5094 - loss: 2367.5127 - reconstruction_loss: 2342.0032
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5037 - loss: 2361.9644 - reconstruction_loss: 2336.4604
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4517 - loss: 2369.4558 - reconstruction_loss: 2344.0042
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4309 - loss: 2367.3918 - reconstruction_loss: 2341.9609
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4699 - loss: 2364.2371 - reconstruction_loss: 2338.7671
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4416 - loss: 2368.8389 - reconstruction_loss: 2343.3975
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4435 - loss: 2368.0171 - reconstruction_loss: 2342.5735
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3804 - loss: 2370.2510 - reconstruction_loss: 2344.8704
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4224 - loss: 2364.0686 - reconstruction_loss: 2338.6462
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4614 - loss: 2368.5576 - reconstruction_loss: 2343.0962
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4292 - loss: 2366.9255 - reconstruction_loss: 2341.4963
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4288 - loss: 2365.7263 - reconstruction_loss: 2340.2974
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5461 - loss: 2367.7090 - reconstruction_loss: 2342.1633
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4226 - loss: 2369.3379 - reconstruction_loss: 2343.9153
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4671 - loss: 2369.6721 - reconstruction_loss: 2344.2051
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4874 - loss: 2368.5891 - reconstruction_loss: 2343.1016
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5731 - loss: 2367.2751 - reconstruction_loss: 2341.7021
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4521 - loss: 2365.3594 - reconstruction_loss: 2339.9072
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3579 - loss: 2365.9871 - reconstruction_loss: 2340.6292
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4703 - loss: 2365.3337 - reconstruction_loss: 2339.8633
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4623 - loss: 2369.0540 - reconstruction_loss: 2343.5916
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4092 - loss: 2369.1448 - reconstruction_loss: 2343.7358
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4739 - loss: 2366.4773 - reconstruction_loss: 2341.0037
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3994 - loss: 2367.1682 - reconstruction_loss: 2341.7686
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4482 - loss: 2366.0908 - reconstruction_loss: 2340.6426
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4896 - loss: 2369.3052 - reconstruction_loss: 2343.8154
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4241 - loss: 2370.2681 - reconstruction_loss: 2344.8442
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4181 - loss: 2369.0986 - reconstruction_loss: 2343.6804
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4386 - loss: 2367.5383 - reconstruction_loss: 2342.0994
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5376 - loss: 2366.0461 - reconstruction_loss: 2340.5085
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3809 - loss: 2369.4351 - reconstruction_loss: 2344.0542
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4484 - loss: 2367.2202 - reconstruction_loss: 2341.7717
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5271 - loss: 2366.2432 - reconstruction_loss: 2340.7161
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4393 - loss: 2367.0120 - reconstruction_loss: 2341.5728
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5485 - loss: 2361.0044 - reconstruction_loss: 2335.4561
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4647 - loss: 2371.6833 - reconstruction_loss: 2346.2188
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4011 - loss: 2368.4900 - reconstruction_loss: 2343.0884
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5198 - loss: 2362.3792 - reconstruction_loss: 2336.8591
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4905 - loss: 2367.1411 - reconstruction_loss: 2341.6506
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3684 - loss: 2370.3093 - reconstruction_loss: 2344.9412
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5528 - loss: 2368.2346 - reconstruction_loss: 2342.6819
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.6207 - loss: 2364.7258 - reconstruction_loss: 2339.1050
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4237 - loss: 2369.7881 - reconstruction_loss: 2344.3643
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4367 - loss: 2370.1750 - reconstruction_loss: 2344.7383
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5198 - loss: 2368.3625 - reconstruction_loss: 2342.8428
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4985 - loss: 2367.9036 - reconstruction_loss: 2342.4053
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4860 - loss: 2365.8210 - reconstruction_loss: 2340.3347
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4832 - loss: 2364.2998 - reconstruction_loss: 2338.8167
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4617 - loss: 2367.5225 - reconstruction_loss: 2342.0605
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4496 - loss: 2370.2139 - reconstruction_loss: 2344.7642
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5450 - loss: 2370.1550 - reconstruction_loss: 2344.6099
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5333 - loss: 2366.7625 - reconstruction_loss: 2341.2290
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5518 - loss: 2367.2024 - reconstruction_loss: 2341.6509
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4853 - loss: 2364.3965 - reconstruction_loss: 2338.9109
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4814 - loss: 2366.7271 - reconstruction_loss: 2341.2456
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4822 - loss: 2367.1760 - reconstruction_loss: 2341.6938
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4154 - loss: 2365.0701 - reconstruction_loss: 2339.6548
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5997 - loss: 2370.5759 - reconstruction_loss: 2344.9761
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4895 - loss: 2367.7102 - reconstruction_loss: 2342.2207
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4242 - loss: 2369.5059 - reconstruction_loss: 2344.0818
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4615 - loss: 2368.6411 - reconstruction_loss: 2343.1794
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3885 - loss: 2368.5244 - reconstruction_loss: 2343.1360
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4170 - loss: 2370.4619 - reconstruction_loss: 2345.0449
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4305 - loss: 2367.4390 - reconstruction_loss: 2342.0085
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4475 - loss: 2369.8391 - reconstruction_loss: 2344.3914
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3568 - loss: 2369.1816 - reconstruction_loss: 2343.8245
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4539 - loss: 2362.1782 - reconstruction_loss: 2336.7244
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4380 - loss: 2361.4841 - reconstruction_loss: 2336.0461
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4852 - loss: 2365.9277 - reconstruction_loss: 2340.4424
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3356 - loss: 2373.4639 - reconstruction_loss: 2348.1282
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4510 - loss: 2366.0564 - reconstruction_loss: 2340.6055
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4087 - loss: 2370.2681 - reconstruction_loss: 2344.8594
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5019 - loss: 2362.4170 - reconstruction_loss: 2336.9150
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4357 - loss: 2366.2764 - reconstruction_loss: 2340.8406
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4341 - loss: 2367.8923 - reconstruction_loss: 2342.4585
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5125 - loss: 2364.6118 - reconstruction_loss: 2339.0994
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3887 - loss: 2369.9829 - reconstruction_loss: 2344.5945
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5217 - loss: 2364.0891 - reconstruction_loss: 2338.5671
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4042 - loss: 2364.9146 - reconstruction_loss: 2339.5100
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3853 - loss: 2365.0979 - reconstruction_loss: 2339.7124
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4807 - loss: 2361.7141 - reconstruction_loss: 2336.2336
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4634 - loss: 2365.3987 - reconstruction_loss: 2339.9353
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5648 - loss: 2365.1445 - reconstruction_loss: 2339.5798
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5496 - loss: 2361.2947 - reconstruction_loss: 2335.7446
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.2893 - loss: 2370.0713 - reconstruction_loss: 2344.7820
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3507 - loss: 2366.0774 - reconstruction_loss: 2340.7266
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4627 - loss: 2369.1199 - reconstruction_loss: 2343.6572
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5569 - loss: 2362.2883 - reconstruction_loss: 2336.7314
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4497 - loss: 2366.5693 - reconstruction_loss: 2341.1194
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4652 - loss: 2364.4902 - reconstruction_loss: 2339.0249
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4413 - loss: 2365.8450 - reconstruction_loss: 2340.4036
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4133 - loss: 2366.3557 - reconstruction_loss: 2340.9421
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3900 - loss: 2361.1458 - reconstruction_loss: 2335.7559
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5178 - loss: 2364.7896 - reconstruction_loss: 2339.2722
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5446 - loss: 2363.2036 - reconstruction_loss: 2337.6589
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5812 - loss: 2363.6670 - reconstruction_loss: 2338.0857
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5508 - loss: 2362.7078 - reconstruction_loss: 2337.1565
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4384 - loss: 2363.0950 - reconstruction_loss: 2337.6567
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4378 - loss: 2366.8088 - reconstruction_loss: 2341.3708
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3876 - loss: 2365.2822 - reconstruction_loss: 2339.8948
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.5209 - loss: 2363.8743 - reconstruction_loss: 2338.3533
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.4807 - loss: 2368.7910 - reconstruction_loss: 2343.3105
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.3258 - loss: 2363.0579 - reconstruction_loss: 2337.7319
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5256 - loss: 2363.0928 - reconstruction_loss: 2337.5669
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4825 - loss: 2363.8604 - reconstruction_loss: 2338.3777
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3857 - loss: 2359.4648 - reconstruction_loss: 2334.0789
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4420 - loss: 2362.5842 - reconstruction_loss: 2337.1423
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4439 - loss: 2365.1296 - reconstruction_loss: 2339.6855

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'OILPRODUCTSTANKER': 100%|█████████████████████████████████████████| 540/540 [04:14<00:00,  2.12it/s]
# FID = 37.626956939697266
