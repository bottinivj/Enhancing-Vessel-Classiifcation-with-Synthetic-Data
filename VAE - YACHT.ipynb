# %%
generating_class = 'YACHT'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-25 12:59:57.818112: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-25 12:59:57.837924: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-25 12:59:59.589756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:59:59.592655: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:59:59.592672: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-25 13:00:06.722670: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 13:00:06.722707: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 13:00:06.722728: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 13:00:06.828152: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 13:00:06.828178: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 13:00:06.828183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-25 13:00:06.828198: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 13:00:06.828215: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-25 13:00:09.698256: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-25 13:00:09.698289: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753448410.792975   85999 service.cc:145] XLA service 0x7f143c006be0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753448410.793008   85999 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-25 13:00:10.843513: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-25 13:00:11.003944: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-25 13:00:16.878135: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:16.946497: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.06846321s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:28.655477: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:29.359541: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.704141005s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:30.359696: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:30.998419: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.638813004s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:31.998575: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:32.740869: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.742390522s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:33.741023: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 13:00:34.297438: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.556507192s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753448441.584587   85999 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 458ms/step - kl_loss: 1.0534e-06 - loss: 2839.0125 - reconstruction_loss: 2839.0125
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 8.1158e-04 - loss: 2838.3110 - reconstruction_loss: 2838.3105
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 0.3715 - loss: 2835.7925 - reconstruction_loss: 2835.4211
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 1.4855 - loss: 2825.6924 - reconstruction_loss: 2824.2068
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 3.6494 - loss: 2802.9539 - reconstruction_loss: 2799.3044
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 4.5137 - loss: 2774.7595 - reconstruction_loss: 2770.2458
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 6.3621 - loss: 2743.4092 - reconstruction_loss: 2737.0471
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 8.8272 - loss: 2727.2314 - reconstruction_loss: 2718.4043
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 7.9194 - loss: 2722.5437 - reconstruction_loss: 2714.6248
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 8.0487 - loss: 2712.0593 - reconstruction_loss: 2704.0110
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 8.7408 - loss: 2703.0483 - reconstruction_loss: 2694.3071
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.1651 - loss: 2690.8645 - reconstruction_loss: 2681.6995
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.5896 - loss: 2684.7727 - reconstruction_loss: 2675.1831
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.1078 - loss: 2672.0544 - reconstruction_loss: 2661.9468
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 10.4238 - loss: 2665.4697 - reconstruction_loss: 2655.0459
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.8378 - loss: 2655.1462 - reconstruction_loss: 2644.3086
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.2614 - loss: 2644.2810 - reconstruction_loss: 2633.0198
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 11.1682 - loss: 2640.9822 - reconstruction_loss: 2629.8135
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.0314 - loss: 2635.7432 - reconstruction_loss: 2624.7117
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 10.7039 - loss: 2630.2312 - reconstruction_loss: 2619.5271
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.4211 - loss: 2630.3992 - reconstruction_loss: 2619.9783
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.5911 - loss: 2628.3560 - reconstruction_loss: 2617.7651
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.8355 - loss: 2625.0706 - reconstruction_loss: 2614.2351
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 11.0797 - loss: 2620.7642 - reconstruction_loss: 2609.6848
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.3258 - loss: 2613.8730 - reconstruction_loss: 2602.5474
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.9671 - loss: 2607.8142 - reconstruction_loss: 2595.8472
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.7753 - loss: 2610.2654 - reconstruction_loss: 2598.4902
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.8567 - loss: 2601.6455 - reconstruction_loss: 2589.7893
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.8591 - loss: 2601.1233 - reconstruction_loss: 2589.2642
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3385 - loss: 2598.0686 - reconstruction_loss: 2585.7300
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3487 - loss: 2595.2686 - reconstruction_loss: 2582.9199
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3591 - loss: 2592.8193 - reconstruction_loss: 2580.4602
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.4498 - loss: 2587.0281 - reconstruction_loss: 2574.5784
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.5131 - loss: 2587.1218 - reconstruction_loss: 2574.6086
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.4923 - loss: 2585.5059 - reconstruction_loss: 2573.0132
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.7773 - loss: 2582.6243 - reconstruction_loss: 2569.8467
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1165 - loss: 2582.9858 - reconstruction_loss: 2569.8694
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.6921 - loss: 2576.0076 - reconstruction_loss: 2562.3154
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.1769 - loss: 2578.7363 - reconstruction_loss: 2564.5593
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5066 - loss: 2572.1187 - reconstruction_loss: 2557.6121
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5336 - loss: 2572.5266 - reconstruction_loss: 2557.9929
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5118 - loss: 2569.5437 - reconstruction_loss: 2555.0317
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5979 - loss: 2570.1692 - reconstruction_loss: 2555.5713
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.6981 - loss: 2564.5537 - reconstruction_loss: 2549.8557
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.0742 - loss: 2559.8523 - reconstruction_loss: 2544.7783
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1228 - loss: 2566.3970 - reconstruction_loss: 2551.2742
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.4630 - loss: 2563.6572 - reconstruction_loss: 2548.1943
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.6484 - loss: 2559.5051 - reconstruction_loss: 2543.8564
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.4452 - loss: 2558.1396 - reconstruction_loss: 2542.6946
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.7585 - loss: 2559.2183 - reconstruction_loss: 2543.4597
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.7504 - loss: 2557.5938 - reconstruction_loss: 2541.8435
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 15.6232 - loss: 2556.6023 - reconstruction_loss: 2540.9790
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.6161 - loss: 2558.2949 - reconstruction_loss: 2542.6787
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.6647 - loss: 2557.0752 - reconstruction_loss: 2541.4106
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.7550 - loss: 2554.0657 - reconstruction_loss: 2538.3108
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.8553 - loss: 2551.8132 - reconstruction_loss: 2535.9580
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.7107 - loss: 2555.4099 - reconstruction_loss: 2539.6990
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 15.6728 - loss: 2554.7729 - reconstruction_loss: 2539.1001
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9049 - loss: 2553.6157 - reconstruction_loss: 2537.7107
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9694 - loss: 2552.2161 - reconstruction_loss: 2536.2466
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9931 - loss: 2550.1321 - reconstruction_loss: 2534.1387
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.2189 - loss: 2550.1050 - reconstruction_loss: 2533.8865
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3576 - loss: 2549.6877 - reconstruction_loss: 2533.3301
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3540 - loss: 2549.6428 - reconstruction_loss: 2533.2891
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.4370 - loss: 2549.4563 - reconstruction_loss: 2533.0195
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5469 - loss: 2546.6804 - reconstruction_loss: 2530.1335
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5063 - loss: 2548.8218 - reconstruction_loss: 2532.3154
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.7880 - loss: 2545.0276 - reconstruction_loss: 2528.2395
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5917 - loss: 2543.0046 - reconstruction_loss: 2526.4128
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.6768 - loss: 2546.6428 - reconstruction_loss: 2529.9658
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.8829 - loss: 2546.9202 - reconstruction_loss: 2530.0374
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.0111 - loss: 2544.9744 - reconstruction_loss: 2527.9631
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.0647 - loss: 2544.1663 - reconstruction_loss: 2527.1018
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.9247 - loss: 2545.6636 - reconstruction_loss: 2528.7390
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.1014 - loss: 2545.9436 - reconstruction_loss: 2528.8423
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.3866 - loss: 2541.3569 - reconstruction_loss: 2523.9702
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5661 - loss: 2546.3025 - reconstruction_loss: 2528.7363
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.6146 - loss: 2541.6643 - reconstruction_loss: 2524.0496
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.7067 - loss: 2543.6809 - reconstruction_loss: 2525.9744
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.9793 - loss: 2541.2869 - reconstruction_loss: 2523.3079
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8798 - loss: 2542.0786 - reconstruction_loss: 2524.1987
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1188 - loss: 2542.1187 - reconstruction_loss: 2523.9995
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2963 - loss: 2540.5640 - reconstruction_loss: 2522.2676
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4951 - loss: 2541.4648 - reconstruction_loss: 2522.9697
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.5993 - loss: 2542.8171 - reconstruction_loss: 2524.2180
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8644 - loss: 2537.0459 - reconstruction_loss: 2518.1814
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9016 - loss: 2541.6313 - reconstruction_loss: 2522.7297
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2786 - loss: 2535.9773 - reconstruction_loss: 2516.6987
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 19.3363 - loss: 2536.0422 - reconstruction_loss: 2516.7056
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.4041 - loss: 2536.9307 - reconstruction_loss: 2517.5266
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5321 - loss: 2537.5913 - reconstruction_loss: 2518.0596
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5295 - loss: 2536.0706 - reconstruction_loss: 2516.5413
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6663 - loss: 2536.7964 - reconstruction_loss: 2517.1301
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5471 - loss: 2531.8953 - reconstruction_loss: 2512.3481
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.7003 - loss: 2534.1323 - reconstruction_loss: 2514.4316
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6607 - loss: 2535.7625 - reconstruction_loss: 2516.1018
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6310 - loss: 2535.6099 - reconstruction_loss: 2515.9790
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8212 - loss: 2537.2578 - reconstruction_loss: 2517.4363
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.7311 - loss: 2536.2952 - reconstruction_loss: 2516.5640
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8380 - loss: 2535.4216 - reconstruction_loss: 2515.5835
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8134 - loss: 2532.6765 - reconstruction_loss: 2512.8630
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8959 - loss: 2532.3228 - reconstruction_loss: 2512.4268
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8282 - loss: 2533.8110 - reconstruction_loss: 2513.9829
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1000 - loss: 2533.5415 - reconstruction_loss: 2513.4414
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0404 - loss: 2533.7334 - reconstruction_loss: 2513.6931
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9559 - loss: 2530.6726 - reconstruction_loss: 2510.7166
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0664 - loss: 2533.4094 - reconstruction_loss: 2513.3430
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9496 - loss: 2533.7517 - reconstruction_loss: 2513.8020
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0126 - loss: 2527.9827 - reconstruction_loss: 2507.9702
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8612 - loss: 2532.0037 - reconstruction_loss: 2512.1421
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8675 - loss: 2534.3662 - reconstruction_loss: 2514.4985
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1089 - loss: 2530.0688 - reconstruction_loss: 2509.9600
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2746 - loss: 2526.8318 - reconstruction_loss: 2506.5569
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0949 - loss: 2527.4973 - reconstruction_loss: 2507.4023
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2955 - loss: 2531.2122 - reconstruction_loss: 2510.9165
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0969 - loss: 2527.6304 - reconstruction_loss: 2507.5337
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3102 - loss: 2527.8955 - reconstruction_loss: 2507.5852
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1628 - loss: 2528.3608 - reconstruction_loss: 2508.1978
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3359 - loss: 2528.5671 - reconstruction_loss: 2508.2310
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2847 - loss: 2526.4351 - reconstruction_loss: 2506.1504
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4273 - loss: 2528.2456 - reconstruction_loss: 2507.8184
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4677 - loss: 2531.2283 - reconstruction_loss: 2510.7607
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.4792 - loss: 2525.3975 - reconstruction_loss: 2504.9182
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.5231 - loss: 2528.0234 - reconstruction_loss: 2507.5010
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4813 - loss: 2522.6516 - reconstruction_loss: 2502.1704
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6205 - loss: 2526.0916 - reconstruction_loss: 2505.4712
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 20.5131 - loss: 2524.4475 - reconstruction_loss: 2503.9343
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7051 - loss: 2524.3096 - reconstruction_loss: 2503.6045
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6794 - loss: 2525.3770 - reconstruction_loss: 2504.6978
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6135 - loss: 2524.5830 - reconstruction_loss: 2503.9692
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 20.7409 - loss: 2524.8455 - reconstruction_loss: 2504.1050
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6858 - loss: 2521.7744 - reconstruction_loss: 2501.0889
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7814 - loss: 2524.8486 - reconstruction_loss: 2504.0674
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6964 - loss: 2525.0518 - reconstruction_loss: 2504.3552
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0216 - loss: 2523.7200 - reconstruction_loss: 2502.6982
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 20.8914 - loss: 2523.9436 - reconstruction_loss: 2503.0520
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0374 - loss: 2521.0159 - reconstruction_loss: 2499.9783
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1594 - loss: 2520.9954 - reconstruction_loss: 2499.8362
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9369 - loss: 2525.4536 - reconstruction_loss: 2504.5168
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0865 - loss: 2521.5913 - reconstruction_loss: 2500.5049
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0146 - loss: 2521.7419 - reconstruction_loss: 2500.7275
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0725 - loss: 2523.0181 - reconstruction_loss: 2501.9456
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1703 - loss: 2515.6306 - reconstruction_loss: 2494.4607
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3081 - loss: 2517.9629 - reconstruction_loss: 2496.6548
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3163 - loss: 2520.0239 - reconstruction_loss: 2498.7078
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2639 - loss: 2518.0725 - reconstruction_loss: 2496.8083
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.4773 - loss: 2517.3765 - reconstruction_loss: 2495.8992
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.5133 - loss: 2518.3298 - reconstruction_loss: 2496.8164
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 21.4772 - loss: 2517.2820 - reconstruction_loss: 2495.8049
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6629 - loss: 2517.8213 - reconstruction_loss: 2496.1582
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7584 - loss: 2517.1282 - reconstruction_loss: 2495.3696
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6545 - loss: 2520.9355 - reconstruction_loss: 2499.2812
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8335 - loss: 2514.0962 - reconstruction_loss: 2492.2625
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9520 - loss: 2514.5410 - reconstruction_loss: 2492.5884
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 21.9913 - loss: 2513.7217 - reconstruction_loss: 2491.7302
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9728 - loss: 2517.2537 - reconstruction_loss: 2495.2810
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.1440 - loss: 2513.4409 - reconstruction_loss: 2491.2971
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2396 - loss: 2514.2544 - reconstruction_loss: 2492.0149
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4342 - loss: 2515.0669 - reconstruction_loss: 2492.6326
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4922 - loss: 2512.1465 - reconstruction_loss: 2489.6543
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3944 - loss: 2513.0020 - reconstruction_loss: 2490.6074
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5007 - loss: 2509.8198 - reconstruction_loss: 2487.3193
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5282 - loss: 2511.4746 - reconstruction_loss: 2488.9463
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6960 - loss: 2510.8447 - reconstruction_loss: 2488.1487
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6280 - loss: 2510.4634 - reconstruction_loss: 2487.8354
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7390 - loss: 2510.3516 - reconstruction_loss: 2487.6125
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 22.8712 - loss: 2511.8167 - reconstruction_loss: 2488.9453
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.8438 - loss: 2511.5115 - reconstruction_loss: 2488.6677
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1015 - loss: 2506.9031 - reconstruction_loss: 2483.8015
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0064 - loss: 2510.9988 - reconstruction_loss: 2487.9924
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9872 - loss: 2510.7512 - reconstruction_loss: 2487.7642
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1505 - loss: 2509.7129 - reconstruction_loss: 2486.5623
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1833 - loss: 2504.2998 - reconstruction_loss: 2481.1162
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4076 - loss: 2505.0725 - reconstruction_loss: 2481.6648
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2363 - loss: 2509.5322 - reconstruction_loss: 2486.2959
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4256 - loss: 2505.6008 - reconstruction_loss: 2482.1753
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4321 - loss: 2505.4465 - reconstruction_loss: 2482.0144
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.5152 - loss: 2500.3770 - reconstruction_loss: 2476.8621
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.4670 - loss: 2502.6335 - reconstruction_loss: 2479.1665
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.5657 - loss: 2506.7520 - reconstruction_loss: 2483.1863
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 23.7784 - loss: 2504.3066 - reconstruction_loss: 2480.5283
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.7438 - loss: 2502.6777 - reconstruction_loss: 2478.9338
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6340 - loss: 2503.9614 - reconstruction_loss: 2480.3274
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.6928 - loss: 2502.5181 - reconstruction_loss: 2478.8252
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 23.8186 - loss: 2502.4141 - reconstruction_loss: 2478.5955
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.8434 - loss: 2498.9841 - reconstruction_loss: 2475.1406
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.9577 - loss: 2500.7229 - reconstruction_loss: 2476.7649
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.0402 - loss: 2499.9980 - reconstruction_loss: 2475.9578
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.1992 - loss: 2496.7004 - reconstruction_loss: 2472.5012
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.0606 - loss: 2500.1421 - reconstruction_loss: 2476.0815
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.0531 - loss: 2499.6301 - reconstruction_loss: 2475.5767
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.2673 - loss: 2499.4548 - reconstruction_loss: 2475.1873
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.2716 - loss: 2496.1614 - reconstruction_loss: 2471.8894
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.3001 - loss: 2497.5591 - reconstruction_loss: 2473.2593
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.3863 - loss: 2497.5979 - reconstruction_loss: 2473.2114
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.4331 - loss: 2497.1404 - reconstruction_loss: 2472.7070
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.4890 - loss: 2495.1699 - reconstruction_loss: 2470.6809
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.5692 - loss: 2492.6685 - reconstruction_loss: 2468.0994
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.5896 - loss: 2495.4294 - reconstruction_loss: 2470.8398
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.7483 - loss: 2490.8372 - reconstruction_loss: 2466.0889
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.7651 - loss: 2492.5281 - reconstruction_loss: 2467.7627
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.6947 - loss: 2495.2517 - reconstruction_loss: 2470.5571
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.8187 - loss: 2497.8079 - reconstruction_loss: 2472.9893
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.9706 - loss: 2488.2451 - reconstruction_loss: 2463.2747
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.9646 - loss: 2491.6968 - reconstruction_loss: 2466.7324
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.9998 - loss: 2489.6121 - reconstruction_loss: 2464.6123
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.1010 - loss: 2489.3203 - reconstruction_loss: 2464.2192
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.1453 - loss: 2488.6265 - reconstruction_loss: 2463.4810
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.1372 - loss: 2488.4067 - reconstruction_loss: 2463.2698
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 24.9298 - loss: 2490.3577 - reconstruction_loss: 2465.4277
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.0723 - loss: 2488.8098 - reconstruction_loss: 2463.7373
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.0556 - loss: 2487.4915 - reconstruction_loss: 2462.4358
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3104 - loss: 2483.8530 - reconstruction_loss: 2458.5425
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.2691 - loss: 2490.5142 - reconstruction_loss: 2465.2451
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4055 - loss: 2482.9221 - reconstruction_loss: 2457.5168
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3833 - loss: 2486.1248 - reconstruction_loss: 2460.7415
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.3870 - loss: 2490.0525 - reconstruction_loss: 2464.6655
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.2291 - loss: 2485.5193 - reconstruction_loss: 2460.2903
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4253 - loss: 2482.9849 - reconstruction_loss: 2457.5598
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.5599 - loss: 2484.6826 - reconstruction_loss: 2459.1226
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 25.5166 - loss: 2483.3491 - reconstruction_loss: 2457.8323
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.4919 - loss: 2485.5364 - reconstruction_loss: 2460.0444
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.6551 - loss: 2483.7754 - reconstruction_loss: 2458.1204
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.7402 - loss: 2485.3208 - reconstruction_loss: 2459.5811
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.6431 - loss: 2483.1611 - reconstruction_loss: 2457.5183
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.7092 - loss: 2485.0850 - reconstruction_loss: 2459.3755
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.7948 - loss: 2483.1797 - reconstruction_loss: 2457.3848
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.8229 - loss: 2479.4937 - reconstruction_loss: 2453.6704
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.7632 - loss: 2482.7380 - reconstruction_loss: 2456.9751
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.7227 - loss: 2483.5444 - reconstruction_loss: 2457.8215
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 25.8091 - loss: 2479.2273 - reconstruction_loss: 2453.4185
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 25.8018 - loss: 2480.4185 - reconstruction_loss: 2454.6165
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.9734 - loss: 2480.1658 - reconstruction_loss: 2454.1924
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.8948 - loss: 2481.9724 - reconstruction_loss: 2456.0779
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.1399 - loss: 2480.9224 - reconstruction_loss: 2454.7825
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 25.9852 - loss: 2477.9917 - reconstruction_loss: 2452.0063
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.1448 - loss: 2477.6970 - reconstruction_loss: 2451.5520
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3298 - loss: 2480.5466 - reconstruction_loss: 2454.2173
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.1288 - loss: 2477.7983 - reconstruction_loss: 2451.6697
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.1789 - loss: 2477.1199 - reconstruction_loss: 2450.9409
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2420 - loss: 2475.2446 - reconstruction_loss: 2449.0024
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2067 - loss: 2479.6655 - reconstruction_loss: 2453.4587
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2202 - loss: 2474.4070 - reconstruction_loss: 2448.1868
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3864 - loss: 2475.4998 - reconstruction_loss: 2449.1133
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3280 - loss: 2475.1565 - reconstruction_loss: 2448.8281
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3022 - loss: 2476.7351 - reconstruction_loss: 2450.4329
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2769 - loss: 2473.8318 - reconstruction_loss: 2447.5549
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3959 - loss: 2474.8857 - reconstruction_loss: 2448.4900
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.5931 - loss: 2475.2664 - reconstruction_loss: 2448.6731
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.5177 - loss: 2471.8008 - reconstruction_loss: 2445.2832
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 26.4759 - loss: 2474.5356 - reconstruction_loss: 2448.0598
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.5946 - loss: 2473.9490 - reconstruction_loss: 2447.3542
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4893 - loss: 2473.3359 - reconstruction_loss: 2446.8469
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.7176 - loss: 2472.4124 - reconstruction_loss: 2445.6946
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.6691 - loss: 2471.6672 - reconstruction_loss: 2444.9980
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.7882 - loss: 2471.9714 - reconstruction_loss: 2445.1833
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.5776 - loss: 2474.0210 - reconstruction_loss: 2447.4434
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 26.7329 - loss: 2467.6748 - reconstruction_loss: 2440.9417
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.5592 - loss: 2472.9121 - reconstruction_loss: 2446.3525
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.8288 - loss: 2472.1206 - reconstruction_loss: 2445.2920
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.8527 - loss: 2468.8923 - reconstruction_loss: 2442.0393
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.7955 - loss: 2469.2412 - reconstruction_loss: 2442.4458
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.7605 - loss: 2471.4507 - reconstruction_loss: 2444.6902
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.8042 - loss: 2466.5027 - reconstruction_loss: 2439.6985
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 26.9897 - loss: 2468.3247 - reconstruction_loss: 2441.3350
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.9251 - loss: 2466.4092 - reconstruction_loss: 2439.4836
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.0202 - loss: 2466.9541 - reconstruction_loss: 2439.9338
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.0643 - loss: 2463.7786 - reconstruction_loss: 2436.7144
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.0722 - loss: 2462.7927 - reconstruction_loss: 2435.7205
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.1099 - loss: 2468.6128 - reconstruction_loss: 2441.5032
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 27.1490 - loss: 2466.8176 - reconstruction_loss: 2439.6687
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.0692 - loss: 2468.3999 - reconstruction_loss: 2441.3306
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.1442 - loss: 2462.7468 - reconstruction_loss: 2435.6025
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 27.2637 - loss: 2464.0522 - reconstruction_loss: 2436.7883
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 27.2883 - loss: 2463.7632 - reconstruction_loss: 2436.4749
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.3734 - loss: 2461.5623 - reconstruction_loss: 2434.1887
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.2228 - loss: 2464.9355 - reconstruction_loss: 2437.7129
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.1535 - loss: 2464.9043 - reconstruction_loss: 2437.7505
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.3440 - loss: 2464.4180 - reconstruction_loss: 2437.0740
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.2185 - loss: 2467.5281 - reconstruction_loss: 2440.3096
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.4187 - loss: 2464.4192 - reconstruction_loss: 2437.0007
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.3775 - loss: 2463.2981 - reconstruction_loss: 2435.9209
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.2450 - loss: 2464.8191 - reconstruction_loss: 2437.5745
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.3727 - loss: 2461.7058 - reconstruction_loss: 2434.3330
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.2977 - loss: 2464.5581 - reconstruction_loss: 2437.2607
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.5873 - loss: 2457.3760 - reconstruction_loss: 2429.7888
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 27.5691 - loss: 2457.4133 - reconstruction_loss: 2429.8440
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9636 - loss: 2393.0999 - reconstruction_loss: 2363.1365
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.7202 - loss: 2393.1843 - reconstruction_loss: 2363.4644
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.7590 - loss: 2393.5901 - reconstruction_loss: 2363.8311
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9337 - loss: 2397.9473 - reconstruction_loss: 2368.0137
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8950 - loss: 2395.7332 - reconstruction_loss: 2365.8381
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8672 - loss: 2395.7615 - reconstruction_loss: 2365.8943
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8829 - loss: 2392.6292 - reconstruction_loss: 2362.7463
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.7888 - loss: 2398.8267 - reconstruction_loss: 2369.0376
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.7762 - loss: 2396.2727 - reconstruction_loss: 2366.4966
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8073 - loss: 2395.2268 - reconstruction_loss: 2365.4194
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.7582 - loss: 2392.4480 - reconstruction_loss: 2362.6897
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8601 - loss: 2391.1895 - reconstruction_loss: 2361.3293
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9352 - loss: 2392.5500 - reconstruction_loss: 2362.6147
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8148 - loss: 2395.8875 - reconstruction_loss: 2366.0728
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8584 - loss: 2391.6516 - reconstruction_loss: 2361.7932
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8757 - loss: 2390.7698 - reconstruction_loss: 2360.8940
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9355 - loss: 2390.6587 - reconstruction_loss: 2360.7229
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9943 - loss: 2391.3298 - reconstruction_loss: 2361.3354
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9543 - loss: 2395.7737 - reconstruction_loss: 2365.8191
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8857 - loss: 2393.6318 - reconstruction_loss: 2363.7458
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8508 - loss: 2397.7605 - reconstruction_loss: 2367.9094
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8058 - loss: 2394.7627 - reconstruction_loss: 2364.9573
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9115 - loss: 2395.4060 - reconstruction_loss: 2365.4946
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8150 - loss: 2393.9092 - reconstruction_loss: 2364.0945
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8510 - loss: 2391.1636 - reconstruction_loss: 2361.3123
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8230 - loss: 2390.9988 - reconstruction_loss: 2361.1760
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8538 - loss: 2394.2490 - reconstruction_loss: 2364.3953
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8580 - loss: 2392.9697 - reconstruction_loss: 2363.1118
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9163 - loss: 2397.0181 - reconstruction_loss: 2367.1018
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8146 - loss: 2391.7271 - reconstruction_loss: 2361.9124
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8455 - loss: 2395.3132 - reconstruction_loss: 2365.4678
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8900 - loss: 2390.5554 - reconstruction_loss: 2360.6650
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8606 - loss: 2396.0571 - reconstruction_loss: 2366.1963
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9590 - loss: 2396.7600 - reconstruction_loss: 2366.8010
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8994 - loss: 2392.5530 - reconstruction_loss: 2362.6536
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9662 - loss: 2393.1709 - reconstruction_loss: 2363.2046
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8924 - loss: 2390.4990 - reconstruction_loss: 2360.6064
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8445 - loss: 2395.5498 - reconstruction_loss: 2365.7051
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9347 - loss: 2390.6609 - reconstruction_loss: 2360.7261
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9255 - loss: 2388.5645 - reconstruction_loss: 2358.6392
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9793 - loss: 2392.1194 - reconstruction_loss: 2362.1399
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8571 - loss: 2389.6592 - reconstruction_loss: 2359.8020
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8350 - loss: 2392.9333 - reconstruction_loss: 2363.0984
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8107 - loss: 2392.5605 - reconstruction_loss: 2362.7498
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9314 - loss: 2394.7881 - reconstruction_loss: 2364.8567
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8416 - loss: 2391.2410 - reconstruction_loss: 2361.3997
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8373 - loss: 2390.9451 - reconstruction_loss: 2361.1082
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8889 - loss: 2394.8660 - reconstruction_loss: 2364.9771
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8995 - loss: 2393.6223 - reconstruction_loss: 2363.7229
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8698 - loss: 2393.7971 - reconstruction_loss: 2363.9272
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8041 - loss: 2387.7983 - reconstruction_loss: 2357.9944
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9165 - loss: 2390.6006 - reconstruction_loss: 2360.6838
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9427 - loss: 2389.6370 - reconstruction_loss: 2359.6946
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8808 - loss: 2392.4365 - reconstruction_loss: 2362.5554
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9410 - loss: 2391.6389 - reconstruction_loss: 2361.6982
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0733 - loss: 2387.7292 - reconstruction_loss: 2357.6565
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9659 - loss: 2396.5164 - reconstruction_loss: 2366.5505
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9524 - loss: 2391.0610 - reconstruction_loss: 2361.1089
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9617 - loss: 2390.1694 - reconstruction_loss: 2360.2080
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8927 - loss: 2392.7107 - reconstruction_loss: 2362.8179
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9959 - loss: 2390.9180 - reconstruction_loss: 2360.9224
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9281 - loss: 2394.5500 - reconstruction_loss: 2364.6218
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8423 - loss: 2392.5657 - reconstruction_loss: 2362.7234
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9458 - loss: 2387.9033 - reconstruction_loss: 2357.9573
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9375 - loss: 2390.1855 - reconstruction_loss: 2360.2480
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8866 - loss: 2392.1255 - reconstruction_loss: 2362.2388
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8828 - loss: 2391.3147 - reconstruction_loss: 2361.4319
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8305 - loss: 2391.2686 - reconstruction_loss: 2361.4377
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8544 - loss: 2390.9956 - reconstruction_loss: 2361.1411
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8796 - loss: 2392.0496 - reconstruction_loss: 2362.1699
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9315 - loss: 2392.0706 - reconstruction_loss: 2362.1389
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9903 - loss: 2389.2363 - reconstruction_loss: 2359.2458
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9502 - loss: 2395.9238 - reconstruction_loss: 2365.9739
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9239 - loss: 2388.5254 - reconstruction_loss: 2358.6016
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9470 - loss: 2390.1555 - reconstruction_loss: 2360.2087
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9305 - loss: 2388.3718 - reconstruction_loss: 2358.4409
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8647 - loss: 2390.6938 - reconstruction_loss: 2360.8289
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8909 - loss: 2393.3962 - reconstruction_loss: 2363.5054
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8313 - loss: 2387.3274 - reconstruction_loss: 2357.4963
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8698 - loss: 2392.4805 - reconstruction_loss: 2362.6106
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8955 - loss: 2391.6716 - reconstruction_loss: 2361.7764
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8484 - loss: 2389.7727 - reconstruction_loss: 2359.9248
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0349 - loss: 2389.1174 - reconstruction_loss: 2359.0828
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9417 - loss: 2393.4365 - reconstruction_loss: 2363.4946
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8587 - loss: 2391.9160 - reconstruction_loss: 2362.0574
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.7944 - loss: 2390.9456 - reconstruction_loss: 2361.1514
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8782 - loss: 2389.1042 - reconstruction_loss: 2359.2258
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9234 - loss: 2389.5757 - reconstruction_loss: 2359.6523
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0104 - loss: 2389.1233 - reconstruction_loss: 2359.1130
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.7462 - loss: 2392.3779 - reconstruction_loss: 2362.6316
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8751 - loss: 2390.6438 - reconstruction_loss: 2360.7683
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9602 - loss: 2387.9197 - reconstruction_loss: 2357.9595
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9191 - loss: 2394.1001 - reconstruction_loss: 2364.1812
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8967 - loss: 2390.4690 - reconstruction_loss: 2360.5723
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0008 - loss: 2389.9915 - reconstruction_loss: 2359.9907
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9283 - loss: 2397.5667 - reconstruction_loss: 2367.6384
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0035 - loss: 2391.2080 - reconstruction_loss: 2361.2043
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0300 - loss: 2392.0383 - reconstruction_loss: 2362.0083
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8926 - loss: 2393.1472 - reconstruction_loss: 2363.2542
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9045 - loss: 2393.6013 - reconstruction_loss: 2363.6965
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8938 - loss: 2390.2363 - reconstruction_loss: 2360.3425
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9320 - loss: 2392.0374 - reconstruction_loss: 2362.1052
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0948 - loss: 2390.3423 - reconstruction_loss: 2360.2476
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0562 - loss: 2390.7087 - reconstruction_loss: 2360.6526
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8476 - loss: 2388.4021 - reconstruction_loss: 2358.5544
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8867 - loss: 2391.3508 - reconstruction_loss: 2361.4641
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9151 - loss: 2389.3645 - reconstruction_loss: 2359.4497
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0636 - loss: 2391.1970 - reconstruction_loss: 2361.1335
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9347 - loss: 2395.2117 - reconstruction_loss: 2365.2769
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9434 - loss: 2387.1343 - reconstruction_loss: 2357.1909
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9522 - loss: 2390.0613 - reconstruction_loss: 2360.1091
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8634 - loss: 2390.7876 - reconstruction_loss: 2360.9238
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8953 - loss: 2392.4453 - reconstruction_loss: 2362.5498
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9667 - loss: 2390.0442 - reconstruction_loss: 2360.0774
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 30.0322 - loss: 2392.0881 - reconstruction_loss: 2362.0562
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9380 - loss: 2390.9231 - reconstruction_loss: 2360.9851
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9488 - loss: 2389.1428 - reconstruction_loss: 2359.1941
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9819 - loss: 2390.6416 - reconstruction_loss: 2360.6597
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9407 - loss: 2387.9727 - reconstruction_loss: 2358.0322
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9336 - loss: 2388.2283 - reconstruction_loss: 2358.2947
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8711 - loss: 2391.7480 - reconstruction_loss: 2361.8770
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9437 - loss: 2388.2576 - reconstruction_loss: 2358.3140
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.8459 - loss: 2390.1392 - reconstruction_loss: 2360.2935
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9649 - loss: 2388.8420 - reconstruction_loss: 2358.8772
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9734 - loss: 2393.1077 - reconstruction_loss: 2363.1343
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.8767 - loss: 2391.5303 - reconstruction_loss: 2361.6536
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 29.9771 - loss: 2391.5117 - reconstruction_loss: 2361.5349
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 29.9161 - loss: 2390.5020 - reconstruction_loss: 2360.5859

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'YACHT': 100%|█████████████████████████████████████████████████████| 540/540 [04:06<00:00,  2.19it/s]
# FID = 92.78311157226562
