# %%
generating_class = 'TANKER'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-24 23:48:03.406370: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-24 23:48:03.427299: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-24 23:48:05.303099: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:05.306007: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:05.306024: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-24 23:48:12.983568: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:12.983610: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:12.983620: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:13.097119: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:13.097148: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:13.097154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-24 23:48:13.097170: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 23:48:13.097190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-24 23:48:15.964632: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-24 23:48:15.964678: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753400897.144743   32324 service.cc:145] XLA service 0x7feb00002720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753400897.144781   32324 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-24 23:48:17.196227: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-24 23:48:17.358554: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-24 23:48:23.203076: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:23.273303: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.070343329s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:34.518251: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:35.225032: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.706872563s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:36.225173: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:36.863447: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.638346532s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:37.863597: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:38.605640: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.742130954s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:39.605771: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 23:48:40.161321: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.555628458s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753400927.291618   32324 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 42s 451ms/step - kl_loss: 9.3136e-07 - loss: 2838.9126 - reconstruction_loss: 2838.9126
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 4.7406e-05 - loss: 2837.5825 - reconstruction_loss: 2837.5823
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 4.5366 - loss: 2827.7681 - reconstruction_loss: 2823.2317
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0170 - loss: 2740.0515 - reconstruction_loss: 2722.0342
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 6.4441 - loss: 2693.4126 - reconstruction_loss: 2686.9688
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 4.9965 - loss: 2675.0291 - reconstruction_loss: 2670.0327
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 7.3062 - loss: 2659.3962 - reconstruction_loss: 2652.0901
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.4161 - loss: 2646.5024 - reconstruction_loss: 2637.0862
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.3552 - loss: 2640.2246 - reconstruction_loss: 2630.8699
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 8.9163 - loss: 2626.5947 - reconstruction_loss: 2617.6785
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.5663 - loss: 2618.2151 - reconstruction_loss: 2608.6487
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.8547 - loss: 2611.6638 - reconstruction_loss: 2601.8093
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.0001 - loss: 2603.0632 - reconstruction_loss: 2593.0632
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.6886 - loss: 2590.6123 - reconstruction_loss: 2579.9236
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.3886 - loss: 2582.2805 - reconstruction_loss: 2570.8918
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.5581 - loss: 2573.7100 - reconstruction_loss: 2561.1519
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4016 - loss: 2565.0823 - reconstruction_loss: 2551.6807
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.9580 - loss: 2565.0610 - reconstruction_loss: 2552.1030
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.5149 - loss: 2561.9509 - reconstruction_loss: 2549.4358
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.2968 - loss: 2555.1794 - reconstruction_loss: 2542.8828
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3270 - loss: 2550.5972 - reconstruction_loss: 2538.2703
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3347 - loss: 2550.4480 - reconstruction_loss: 2538.1135
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3544 - loss: 2548.5583 - reconstruction_loss: 2536.2036
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.4539 - loss: 2544.1538 - reconstruction_loss: 2531.6997
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.2764 - loss: 2545.4814 - reconstruction_loss: 2533.2051
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.0312 - loss: 2538.0884 - reconstruction_loss: 2526.0566
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3488 - loss: 2531.3994 - reconstruction_loss: 2519.0505
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.4829 - loss: 2530.5667 - reconstruction_loss: 2518.0837
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.6163 - loss: 2530.1135 - reconstruction_loss: 2517.4971
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.6889 - loss: 2527.4014 - reconstruction_loss: 2514.7119
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.7742 - loss: 2526.8235 - reconstruction_loss: 2514.0493
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.7883 - loss: 2522.7190 - reconstruction_loss: 2509.9304
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.8207 - loss: 2521.0769 - reconstruction_loss: 2508.2563
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.9693 - loss: 2520.7148 - reconstruction_loss: 2507.7456
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.0368 - loss: 2517.0093 - reconstruction_loss: 2503.9722
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.9374 - loss: 2515.2534 - reconstruction_loss: 2502.3162
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.9462 - loss: 2517.5063 - reconstruction_loss: 2504.5605
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.0759 - loss: 2510.8462 - reconstruction_loss: 2497.7703
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1417 - loss: 2514.0742 - reconstruction_loss: 2500.9326
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.2807 - loss: 2506.6768 - reconstruction_loss: 2493.3962
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.0894 - loss: 2508.6699 - reconstruction_loss: 2495.5803
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1806 - loss: 2506.7080 - reconstruction_loss: 2493.5276
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1828 - loss: 2508.8730 - reconstruction_loss: 2495.6904
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.2031 - loss: 2502.8196 - reconstruction_loss: 2489.6165
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.2401 - loss: 2501.0571 - reconstruction_loss: 2487.8171
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4405 - loss: 2500.5999 - reconstruction_loss: 2487.1594
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 13.4838 - loss: 2498.6760 - reconstruction_loss: 2485.1919
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4272 - loss: 2500.0254 - reconstruction_loss: 2486.5984
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4841 - loss: 2499.2866 - reconstruction_loss: 2485.8025
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7160 - loss: 2496.3450 - reconstruction_loss: 2482.6292
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7449 - loss: 2497.1516 - reconstruction_loss: 2483.4065
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.9101 - loss: 2495.5527 - reconstruction_loss: 2481.6426
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7398 - loss: 2495.8279 - reconstruction_loss: 2482.0881
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.8288 - loss: 2490.6267 - reconstruction_loss: 2476.7979
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.9533 - loss: 2496.3713 - reconstruction_loss: 2482.4180
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.0144 - loss: 2491.3735 - reconstruction_loss: 2477.3589
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.0031 - loss: 2490.2134 - reconstruction_loss: 2476.2102
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.0456 - loss: 2491.4756 - reconstruction_loss: 2477.4299
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2141 - loss: 2490.1074 - reconstruction_loss: 2475.8933
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2072 - loss: 2488.6873 - reconstruction_loss: 2474.4797
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2424 - loss: 2488.1604 - reconstruction_loss: 2473.9182
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3434 - loss: 2485.7068 - reconstruction_loss: 2471.3635
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.1780 - loss: 2487.3179 - reconstruction_loss: 2473.1404
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.4517 - loss: 2480.0298 - reconstruction_loss: 2465.5781
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.4065 - loss: 2482.1519 - reconstruction_loss: 2467.7456
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2729 - loss: 2488.0576 - reconstruction_loss: 2473.7847
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2267 - loss: 2482.8027 - reconstruction_loss: 2468.5757
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2002 - loss: 2482.8232 - reconstruction_loss: 2468.6230
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3392 - loss: 2478.3643 - reconstruction_loss: 2464.0249
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3235 - loss: 2486.4648 - reconstruction_loss: 2472.1418
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2654 - loss: 2483.5330 - reconstruction_loss: 2469.2676
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2423 - loss: 2482.1060 - reconstruction_loss: 2467.8638
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3947 - loss: 2476.0850 - reconstruction_loss: 2461.6902
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5368 - loss: 2474.2148 - reconstruction_loss: 2459.6782
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5759 - loss: 2479.0217 - reconstruction_loss: 2464.4458
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.5733 - loss: 2474.6165 - reconstruction_loss: 2460.0432
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.6444 - loss: 2474.4004 - reconstruction_loss: 2459.7559
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.7796 - loss: 2473.3054 - reconstruction_loss: 2458.5259
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.7284 - loss: 2474.6069 - reconstruction_loss: 2459.8787
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.8420 - loss: 2475.2920 - reconstruction_loss: 2460.4497
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.7598 - loss: 2472.9966 - reconstruction_loss: 2458.2366
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.9854 - loss: 2478.6292 - reconstruction_loss: 2463.6436
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1360 - loss: 2473.4146 - reconstruction_loss: 2458.2786
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1399 - loss: 2473.0107 - reconstruction_loss: 2457.8706
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.2581 - loss: 2468.1138 - reconstruction_loss: 2452.8557
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.4311 - loss: 2471.7458 - reconstruction_loss: 2456.3149
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.3675 - loss: 2470.8411 - reconstruction_loss: 2455.4736
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.3982 - loss: 2470.7341 - reconstruction_loss: 2455.3359
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.6809 - loss: 2470.1760 - reconstruction_loss: 2454.4951
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.7669 - loss: 2466.4602 - reconstruction_loss: 2450.6934
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.8548 - loss: 2470.5154 - reconstruction_loss: 2454.6604
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.8238 - loss: 2469.0627 - reconstruction_loss: 2453.2390
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9396 - loss: 2467.2463 - reconstruction_loss: 2451.3064
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.0639 - loss: 2464.5520 - reconstruction_loss: 2448.4883
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9906 - loss: 2466.6848 - reconstruction_loss: 2450.6938
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.1387 - loss: 2463.1135 - reconstruction_loss: 2446.9751
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.0782 - loss: 2467.6030 - reconstruction_loss: 2451.5249
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.1847 - loss: 2462.8940 - reconstruction_loss: 2446.7095
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.4317 - loss: 2464.6790 - reconstruction_loss: 2448.2468
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3714 - loss: 2464.5723 - reconstruction_loss: 2448.2009
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3067 - loss: 2468.2236 - reconstruction_loss: 2451.9170
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3661 - loss: 2464.7131 - reconstruction_loss: 2448.3472
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.4146 - loss: 2466.3604 - reconstruction_loss: 2449.9458
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5962 - loss: 2462.9873 - reconstruction_loss: 2446.3911
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.6012 - loss: 2461.0154 - reconstruction_loss: 2444.4141
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5798 - loss: 2463.1567 - reconstruction_loss: 2446.5771
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.7157 - loss: 2461.4421 - reconstruction_loss: 2444.7263
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.7532 - loss: 2460.9280 - reconstruction_loss: 2444.1746
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.9306 - loss: 2459.4084 - reconstruction_loss: 2442.4778
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.9579 - loss: 2458.6565 - reconstruction_loss: 2441.6990
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.9991 - loss: 2461.0999 - reconstruction_loss: 2444.1008
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.0741 - loss: 2464.7078 - reconstruction_loss: 2447.6335
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.3520 - loss: 2461.5671 - reconstruction_loss: 2444.2153
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.3364 - loss: 2457.9197 - reconstruction_loss: 2440.5833
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.4603 - loss: 2457.1509 - reconstruction_loss: 2439.6904
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5118 - loss: 2462.4966 - reconstruction_loss: 2444.9846
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.6381 - loss: 2458.7239 - reconstruction_loss: 2441.0859
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8520 - loss: 2458.9104 - reconstruction_loss: 2441.0586
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.6551 - loss: 2461.8232 - reconstruction_loss: 2444.1677
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.7816 - loss: 2462.6855 - reconstruction_loss: 2444.9041
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8206 - loss: 2459.1204 - reconstruction_loss: 2441.2996
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.9241 - loss: 2455.4370 - reconstruction_loss: 2437.5129
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.9754 - loss: 2454.6370 - reconstruction_loss: 2436.6619
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.7648 - loss: 2456.8674 - reconstruction_loss: 2439.1028
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1113 - loss: 2456.8032 - reconstruction_loss: 2438.6921
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0201 - loss: 2455.8345 - reconstruction_loss: 2437.8142
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1488 - loss: 2459.0081 - reconstruction_loss: 2440.8596
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0893 - loss: 2455.6035 - reconstruction_loss: 2437.5142
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0262 - loss: 2456.2932 - reconstruction_loss: 2438.2668
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1237 - loss: 2456.0188 - reconstruction_loss: 2437.8948
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0688 - loss: 2459.4153 - reconstruction_loss: 2441.3464
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0256 - loss: 2456.2412 - reconstruction_loss: 2438.2158
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1179 - loss: 2461.5059 - reconstruction_loss: 2443.3882
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.0882 - loss: 2456.0232 - reconstruction_loss: 2437.9351
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1180 - loss: 2458.5549 - reconstruction_loss: 2440.4368
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1269 - loss: 2458.5210 - reconstruction_loss: 2440.3938
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1646 - loss: 2461.1577 - reconstruction_loss: 2442.9932
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2175 - loss: 2454.5486 - reconstruction_loss: 2436.3311
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2846 - loss: 2453.8403 - reconstruction_loss: 2435.5557
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2690 - loss: 2454.4497 - reconstruction_loss: 2436.1809
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3356 - loss: 2456.4211 - reconstruction_loss: 2438.0857
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3802 - loss: 2455.7971 - reconstruction_loss: 2437.4172
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3079 - loss: 2456.3103 - reconstruction_loss: 2438.0022
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2478 - loss: 2453.0645 - reconstruction_loss: 2434.8167
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3585 - loss: 2446.3960 - reconstruction_loss: 2428.0376
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3248 - loss: 2453.9780 - reconstruction_loss: 2435.6531
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.5942 - loss: 2448.4995 - reconstruction_loss: 2429.9053
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4075 - loss: 2455.2039 - reconstruction_loss: 2436.7966
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2962 - loss: 2457.1489 - reconstruction_loss: 2438.8525
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4023 - loss: 2450.9136 - reconstruction_loss: 2432.5115
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.5872 - loss: 2449.9526 - reconstruction_loss: 2431.3652
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4935 - loss: 2453.1550 - reconstruction_loss: 2434.6616
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4762 - loss: 2451.7095 - reconstruction_loss: 2433.2329
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.6850 - loss: 2453.1106 - reconstruction_loss: 2434.4258
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.5114 - loss: 2455.1072 - reconstruction_loss: 2436.5957
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.6528 - loss: 2449.7476 - reconstruction_loss: 2431.0945
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.5652 - loss: 2448.0876 - reconstruction_loss: 2429.5225
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8176 - loss: 2448.7734 - reconstruction_loss: 2429.9558
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7503 - loss: 2450.5251 - reconstruction_loss: 2431.7751
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7246 - loss: 2453.5059 - reconstruction_loss: 2434.7815
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7910 - loss: 2448.9216 - reconstruction_loss: 2430.1304
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.6780 - loss: 2453.0779 - reconstruction_loss: 2434.4001
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.6787 - loss: 2455.5537 - reconstruction_loss: 2436.8752
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8833 - loss: 2450.4963 - reconstruction_loss: 2431.6128
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7545 - loss: 2447.1411 - reconstruction_loss: 2428.3870
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7647 - loss: 2449.5938 - reconstruction_loss: 2430.8289
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9083 - loss: 2452.0347 - reconstruction_loss: 2433.1262
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8330 - loss: 2453.0630 - reconstruction_loss: 2434.2300
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.0788 - loss: 2447.3135 - reconstruction_loss: 2428.2346
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9587 - loss: 2448.9055 - reconstruction_loss: 2429.9465
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9058 - loss: 2450.6416 - reconstruction_loss: 2431.7358
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9639 - loss: 2447.6899 - reconstruction_loss: 2428.7258
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8800 - loss: 2446.3745 - reconstruction_loss: 2427.4941
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.0353 - loss: 2448.5188 - reconstruction_loss: 2429.4836
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8594 - loss: 2447.2134 - reconstruction_loss: 2428.3540
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9984 - loss: 2448.7397 - reconstruction_loss: 2429.7415
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2126 - loss: 2449.3115 - reconstruction_loss: 2430.0989
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.0620 - loss: 2445.7964 - reconstruction_loss: 2426.7346
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8967 - loss: 2449.9429 - reconstruction_loss: 2431.0459
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2004 - loss: 2447.5364 - reconstruction_loss: 2428.3362
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3444 - loss: 2447.1721 - reconstruction_loss: 2427.8279
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.1623 - loss: 2449.1785 - reconstruction_loss: 2430.0164
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2314 - loss: 2445.7861 - reconstruction_loss: 2426.5547
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2863 - loss: 2443.7422 - reconstruction_loss: 2424.4561
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3000 - loss: 2447.3604 - reconstruction_loss: 2428.0603
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.1734 - loss: 2449.5784 - reconstruction_loss: 2430.4050
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2553 - loss: 2443.9956 - reconstruction_loss: 2424.7402
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3562 - loss: 2444.8713 - reconstruction_loss: 2425.5151
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3590 - loss: 2448.8406 - reconstruction_loss: 2429.4819
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3405 - loss: 2446.8665 - reconstruction_loss: 2427.5259
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3852 - loss: 2446.1208 - reconstruction_loss: 2426.7354
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3981 - loss: 2448.4673 - reconstruction_loss: 2429.0693
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5972 - loss: 2443.9719 - reconstruction_loss: 2424.3750
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5168 - loss: 2446.7224 - reconstruction_loss: 2427.2058
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5564 - loss: 2446.0891 - reconstruction_loss: 2426.5327
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.6568 - loss: 2441.8313 - reconstruction_loss: 2422.1746
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6780 - loss: 2446.3293 - reconstruction_loss: 2426.6511
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.4323 - loss: 2448.4617 - reconstruction_loss: 2429.0291
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6828 - loss: 2439.8442 - reconstruction_loss: 2420.1616
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5460 - loss: 2449.5005 - reconstruction_loss: 2429.9543
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6725 - loss: 2443.8215 - reconstruction_loss: 2424.1492
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8758 - loss: 2443.6082 - reconstruction_loss: 2423.7324
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6968 - loss: 2447.1997 - reconstruction_loss: 2427.5029
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8908 - loss: 2440.9841 - reconstruction_loss: 2421.0935
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.8427 - loss: 2440.7454 - reconstruction_loss: 2420.9026
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8377 - loss: 2440.6230 - reconstruction_loss: 2420.7854
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.7199 - loss: 2444.3010 - reconstruction_loss: 2424.5813
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8792 - loss: 2439.8589 - reconstruction_loss: 2419.9797
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9140 - loss: 2442.2246 - reconstruction_loss: 2422.3108
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8980 - loss: 2445.4014 - reconstruction_loss: 2425.5034
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8305 - loss: 2441.8179 - reconstruction_loss: 2421.9873
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9196 - loss: 2441.9990 - reconstruction_loss: 2422.0796
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0463 - loss: 2446.5654 - reconstruction_loss: 2426.5190
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9514 - loss: 2440.2771 - reconstruction_loss: 2420.3257
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9226 - loss: 2439.7920 - reconstruction_loss: 2419.8694
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0756 - loss: 2440.3826 - reconstruction_loss: 2420.3071
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0442 - loss: 2442.1709 - reconstruction_loss: 2422.1265
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0839 - loss: 2443.4409 - reconstruction_loss: 2423.3567
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2807 - loss: 2436.1492 - reconstruction_loss: 2415.8682
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1825 - loss: 2439.3757 - reconstruction_loss: 2419.1934
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0558 - loss: 2442.0562 - reconstruction_loss: 2422.0005
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1088 - loss: 2442.0649 - reconstruction_loss: 2421.9561
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1817 - loss: 2444.5276 - reconstruction_loss: 2424.3457
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2706 - loss: 2437.2507 - reconstruction_loss: 2416.9802
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1936 - loss: 2439.7600 - reconstruction_loss: 2419.5667
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2565 - loss: 2440.8674 - reconstruction_loss: 2420.6108
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3478 - loss: 2440.2498 - reconstruction_loss: 2419.9016
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.2548 - loss: 2437.2000 - reconstruction_loss: 2416.9453
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2125 - loss: 2440.5432 - reconstruction_loss: 2420.3311
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2521 - loss: 2438.2407 - reconstruction_loss: 2417.9885
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2057 - loss: 2441.3879 - reconstruction_loss: 2421.1821
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2268 - loss: 2440.2146 - reconstruction_loss: 2419.9878
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4585 - loss: 2437.1448 - reconstruction_loss: 2416.6863
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5141 - loss: 2438.8062 - reconstruction_loss: 2418.2922
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5594 - loss: 2437.9192 - reconstruction_loss: 2417.3596
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3402 - loss: 2441.7371 - reconstruction_loss: 2421.3967
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3863 - loss: 2436.9729 - reconstruction_loss: 2416.5864
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.4445 - loss: 2437.7759 - reconstruction_loss: 2417.3313
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6022 - loss: 2441.1069 - reconstruction_loss: 2420.5051
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5754 - loss: 2438.8269 - reconstruction_loss: 2418.2515
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5932 - loss: 2436.0757 - reconstruction_loss: 2415.4827
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4770 - loss: 2437.7798 - reconstruction_loss: 2417.3030
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5815 - loss: 2439.6143 - reconstruction_loss: 2419.0327
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7239 - loss: 2437.9827 - reconstruction_loss: 2417.2588
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5727 - loss: 2440.9978 - reconstruction_loss: 2420.4250
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6679 - loss: 2436.6462 - reconstruction_loss: 2415.9785
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6656 - loss: 2439.7219 - reconstruction_loss: 2419.0564
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8322 - loss: 2438.2256 - reconstruction_loss: 2417.3931
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6540 - loss: 2433.8992 - reconstruction_loss: 2413.2454
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7076 - loss: 2435.1985 - reconstruction_loss: 2414.4907
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6982 - loss: 2439.3896 - reconstruction_loss: 2418.6914
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7647 - loss: 2437.0745 - reconstruction_loss: 2416.3098
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7752 - loss: 2434.5427 - reconstruction_loss: 2413.7676
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8578 - loss: 2433.8411 - reconstruction_loss: 2412.9832
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8985 - loss: 2431.1360 - reconstruction_loss: 2410.2375
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7979 - loss: 2435.2061 - reconstruction_loss: 2414.4082
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9111 - loss: 2430.7007 - reconstruction_loss: 2409.7893
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9356 - loss: 2431.8188 - reconstruction_loss: 2410.8831
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8524 - loss: 2434.4275 - reconstruction_loss: 2413.5750
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8249 - loss: 2437.8665 - reconstruction_loss: 2417.0415
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0018 - loss: 2437.3513 - reconstruction_loss: 2416.3494
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0163 - loss: 2429.4299 - reconstruction_loss: 2408.4138
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9607 - loss: 2433.5652 - reconstruction_loss: 2412.6042
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0167 - loss: 2434.2524 - reconstruction_loss: 2413.2356
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9933 - loss: 2434.1201 - reconstruction_loss: 2413.1267
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0343 - loss: 2433.1265 - reconstruction_loss: 2412.0923
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0153 - loss: 2429.2251 - reconstruction_loss: 2408.2095
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1557 - loss: 2433.9797 - reconstruction_loss: 2412.8240
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9896 - loss: 2439.7986 - reconstruction_loss: 2418.8088
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0360 - loss: 2436.9946 - reconstruction_loss: 2415.9587
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1807 - loss: 2438.3440 - reconstruction_loss: 2417.1631
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2251 - loss: 2433.1584 - reconstruction_loss: 2411.9336
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1421 - loss: 2429.9456 - reconstruction_loss: 2408.8032
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1717 - loss: 2434.7561 - reconstruction_loss: 2413.5845
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1808 - loss: 2432.5186 - reconstruction_loss: 2411.3379
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3387 - loss: 2435.0364 - reconstruction_loss: 2413.6978
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2205 - loss: 2433.9014 - reconstruction_loss: 2412.6807
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1369 - loss: 2433.9304 - reconstruction_loss: 2412.7937
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2211 - loss: 2432.9072 - reconstruction_loss: 2411.6858
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.4189 - loss: 2429.6748 - reconstruction_loss: 2408.2561
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2698 - loss: 2436.1091 - reconstruction_loss: 2414.8391
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3512 - loss: 2431.0759 - reconstruction_loss: 2409.7246
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1774 - loss: 2431.2808 - reconstruction_loss: 2410.1035
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3943 - loss: 2426.6396 - reconstruction_loss: 2405.2451
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.2697 - loss: 2437.0054 - reconstruction_loss: 2415.7358
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3843 - loss: 2434.3054 - reconstruction_loss: 2412.9211
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3162 - loss: 2428.5295 - reconstruction_loss: 2407.2136
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1219 - loss: 2393.3157 - reconstruction_loss: 2370.1938
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0576 - loss: 2390.0591 - reconstruction_loss: 2367.0015
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0342 - loss: 2391.5046 - reconstruction_loss: 2368.4705
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0545 - loss: 2394.5342 - reconstruction_loss: 2371.4795
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1238 - loss: 2392.9697 - reconstruction_loss: 2369.8457
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0208 - loss: 2391.1023 - reconstruction_loss: 2368.0815
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9755 - loss: 2389.4690 - reconstruction_loss: 2366.4934
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1030 - loss: 2391.0740 - reconstruction_loss: 2367.9712
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0473 - loss: 2391.9692 - reconstruction_loss: 2368.9219
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0727 - loss: 2392.5427 - reconstruction_loss: 2369.4697
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0112 - loss: 2389.8442 - reconstruction_loss: 2366.8330
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0663 - loss: 2391.3423 - reconstruction_loss: 2368.2761
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0390 - loss: 2393.1997 - reconstruction_loss: 2370.1609
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0248 - loss: 2393.2822 - reconstruction_loss: 2370.2576
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0480 - loss: 2387.7988 - reconstruction_loss: 2364.7507
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1126 - loss: 2382.6255 - reconstruction_loss: 2359.5132
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1696 - loss: 2390.4143 - reconstruction_loss: 2367.2446
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2143 - loss: 2388.3359 - reconstruction_loss: 2365.1218
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1836 - loss: 2389.9875 - reconstruction_loss: 2366.8037
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1172 - loss: 2387.3687 - reconstruction_loss: 2364.2515
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0982 - loss: 2387.3037 - reconstruction_loss: 2364.2056
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0768 - loss: 2389.9204 - reconstruction_loss: 2366.8438
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0633 - loss: 2391.0447 - reconstruction_loss: 2367.9814
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0743 - loss: 2391.3503 - reconstruction_loss: 2368.2766
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0435 - loss: 2392.6421 - reconstruction_loss: 2369.5981
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0613 - loss: 2390.0071 - reconstruction_loss: 2366.9460
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0086 - loss: 2393.4326 - reconstruction_loss: 2370.4241
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0367 - loss: 2392.6960 - reconstruction_loss: 2369.6594
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0716 - loss: 2389.2920 - reconstruction_loss: 2366.2205
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0550 - loss: 2394.4160 - reconstruction_loss: 2371.3611
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1155 - loss: 2388.3958 - reconstruction_loss: 2365.2803
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0555 - loss: 2394.2273 - reconstruction_loss: 2371.1721
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0719 - loss: 2386.3552 - reconstruction_loss: 2363.2832
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0671 - loss: 2390.0461 - reconstruction_loss: 2366.9795
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0480 - loss: 2389.4363 - reconstruction_loss: 2366.3882
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0689 - loss: 2387.0029 - reconstruction_loss: 2363.9341
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9985 - loss: 2393.0496 - reconstruction_loss: 2370.0510
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1246 - loss: 2388.1145 - reconstruction_loss: 2364.9897
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0701 - loss: 2390.4272 - reconstruction_loss: 2367.3569
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0035 - loss: 2391.0466 - reconstruction_loss: 2368.0430
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1797 - loss: 2391.9531 - reconstruction_loss: 2368.7734
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0028 - loss: 2385.5969 - reconstruction_loss: 2362.5940
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0080 - loss: 2391.4495 - reconstruction_loss: 2368.4414
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0414 - loss: 2390.5149 - reconstruction_loss: 2367.4734
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9547 - loss: 2388.7720 - reconstruction_loss: 2365.8171
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0283 - loss: 2385.6726 - reconstruction_loss: 2362.6445
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1261 - loss: 2390.3701 - reconstruction_loss: 2367.2437
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0324 - loss: 2392.2175 - reconstruction_loss: 2369.1853
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0179 - loss: 2384.5183 - reconstruction_loss: 2361.5005
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0120 - loss: 2390.2190 - reconstruction_loss: 2367.2068
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0600 - loss: 2393.1350 - reconstruction_loss: 2370.0750
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1281 - loss: 2388.7715 - reconstruction_loss: 2365.6436
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1022 - loss: 2391.4253 - reconstruction_loss: 2368.3232
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0203 - loss: 2390.7966 - reconstruction_loss: 2367.7761
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0519 - loss: 2391.6711 - reconstruction_loss: 2368.6191
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1402 - loss: 2386.8525 - reconstruction_loss: 2363.7124
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0818 - loss: 2391.1321 - reconstruction_loss: 2368.0500
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0573 - loss: 2388.0381 - reconstruction_loss: 2364.9810
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1597 - loss: 2393.0854 - reconstruction_loss: 2369.9258
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1061 - loss: 2388.1091 - reconstruction_loss: 2365.0032
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0573 - loss: 2392.0078 - reconstruction_loss: 2368.9509
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1277 - loss: 2389.4185 - reconstruction_loss: 2366.2908
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0897 - loss: 2390.2407 - reconstruction_loss: 2367.1511
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0578 - loss: 2390.3306 - reconstruction_loss: 2367.2729
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1297 - loss: 2385.7471 - reconstruction_loss: 2362.6174
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0526 - loss: 2389.1135 - reconstruction_loss: 2366.0610
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0399 - loss: 2391.2397 - reconstruction_loss: 2368.2000
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0799 - loss: 2391.3870 - reconstruction_loss: 2368.3071
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0244 - loss: 2390.9929 - reconstruction_loss: 2367.9685
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1368 - loss: 2389.3359 - reconstruction_loss: 2366.1990
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1550 - loss: 2386.0901 - reconstruction_loss: 2362.9351
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1318 - loss: 2386.5735 - reconstruction_loss: 2363.4417
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1354 - loss: 2384.3472 - reconstruction_loss: 2361.2117
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9720 - loss: 2390.4480 - reconstruction_loss: 2367.4763
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1276 - loss: 2388.6875 - reconstruction_loss: 2365.5598
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9534 - loss: 2381.9729 - reconstruction_loss: 2359.0198
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0574 - loss: 2387.6418 - reconstruction_loss: 2364.5845
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0979 - loss: 2384.4148 - reconstruction_loss: 2361.3171
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0286 - loss: 2388.2029 - reconstruction_loss: 2365.1743
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9750 - loss: 2391.0566 - reconstruction_loss: 2368.0815
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0159 - loss: 2387.4255 - reconstruction_loss: 2364.4099
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0613 - loss: 2386.0996 - reconstruction_loss: 2363.0383
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1822 - loss: 2384.9580 - reconstruction_loss: 2361.7754
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1579 - loss: 2391.7458 - reconstruction_loss: 2368.5879
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0832 - loss: 2388.6472 - reconstruction_loss: 2365.5640
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0869 - loss: 2383.6580 - reconstruction_loss: 2360.5710
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9999 - loss: 2389.7830 - reconstruction_loss: 2366.7827
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1095 - loss: 2387.5298 - reconstruction_loss: 2364.4202
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0477 - loss: 2387.9946 - reconstruction_loss: 2364.9468
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0593 - loss: 2386.4946 - reconstruction_loss: 2363.4355
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0381 - loss: 2384.7993 - reconstruction_loss: 2361.7612
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1135 - loss: 2389.9900 - reconstruction_loss: 2366.8770
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1292 - loss: 2386.9204 - reconstruction_loss: 2363.7913
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0814 - loss: 2388.0430 - reconstruction_loss: 2364.9617
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0348 - loss: 2387.2563 - reconstruction_loss: 2364.2214
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1106 - loss: 2390.1750 - reconstruction_loss: 2367.0645
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0210 - loss: 2388.6140 - reconstruction_loss: 2365.5933
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0884 - loss: 2387.6091 - reconstruction_loss: 2364.5208
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0951 - loss: 2389.2949 - reconstruction_loss: 2366.1995
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0536 - loss: 2386.8958 - reconstruction_loss: 2363.8423
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1429 - loss: 2393.2163 - reconstruction_loss: 2370.0735
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0563 - loss: 2388.9226 - reconstruction_loss: 2365.8667
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1456 - loss: 2390.2659 - reconstruction_loss: 2367.1206
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0498 - loss: 2387.6323 - reconstruction_loss: 2364.5825
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0465 - loss: 2389.1235 - reconstruction_loss: 2366.0774
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0623 - loss: 2388.6182 - reconstruction_loss: 2365.5562
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1407 - loss: 2385.7993 - reconstruction_loss: 2362.6584
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2041 - loss: 2387.9001 - reconstruction_loss: 2364.6960
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1066 - loss: 2388.3318 - reconstruction_loss: 2365.2256
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1265 - loss: 2386.4395 - reconstruction_loss: 2363.3127
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0269 - loss: 2388.8774 - reconstruction_loss: 2365.8503
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1167 - loss: 2387.3840 - reconstruction_loss: 2364.2676
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0507 - loss: 2389.9468 - reconstruction_loss: 2366.8962
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.2119 - loss: 2383.6423 - reconstruction_loss: 2360.4307
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1543 - loss: 2385.0020 - reconstruction_loss: 2361.8477
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.0719 - loss: 2388.2883 - reconstruction_loss: 2365.2163
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0969 - loss: 2389.9795 - reconstruction_loss: 2366.8826
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1762 - loss: 2389.0015 - reconstruction_loss: 2365.8250
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1255 - loss: 2387.2837 - reconstruction_loss: 2364.1582
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0081 - loss: 2390.0574 - reconstruction_loss: 2367.0491
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0339 - loss: 2387.5603 - reconstruction_loss: 2364.5266
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 23.1126 - loss: 2386.2222 - reconstruction_loss: 2363.1096
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.9924 - loss: 2385.2734 - reconstruction_loss: 2362.2810
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0950 - loss: 2389.7620 - reconstruction_loss: 2366.6672
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9689 - loss: 2390.4460 - reconstruction_loss: 2367.4771
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0483 - loss: 2386.4050 - reconstruction_loss: 2363.3567
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.0499 - loss: 2389.2644 - reconstruction_loss: 2366.2144
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1299 - loss: 2381.2854 - reconstruction_loss: 2358.1555

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'TANKER': 100%|████████████████████████████████████████████████████| 540/540 [04:26<00:00,  2.03it/s]
# FID = 29.21886444091797
