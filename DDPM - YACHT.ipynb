# %%
generating_class = 'YACHT'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-08-12 14:07:07.005459: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-12 14:07:07.012532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755007627.020078   20166 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755007627.022234   20166 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755007627.029796   20166 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755007627.029802   20166 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755007627.029803   20166 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755007627.029803   20166 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-12 14:07:07.031793: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.19.0

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU não está disponível. Usando CPU
# W0000 00:00:1755007634.448021   20166 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-02-02 14:12:11.295899: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 14:12:11.295931: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 14:12:11.295941: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 14:12:11.441532: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 14:12:11.441560: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 14:12:11.441564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-02-02 14:12:11.441581: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 14:12:11.441600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738505554.632155     168 service.cc:145] XLA service 0x7f58e0002ed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738505554.632197     168 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-02-02 14:12:35.466392: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738505556.183759     168 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-02-02 14:12:37.647015: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738505559.758232     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738505559.937277     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738505559.950087     334 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738505560.059724     343 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738505560.066203     332 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738505560.534096     336 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738505560.568581     353 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738505560.823193     333 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738505560.891762     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738505561.012157     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738505561.072188     339 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738505561.108560     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738505561.157150     336 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738505561.243709     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738505561.253818     340 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738505561.350534     339 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738505561.371938     353 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738505561.380559     329 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738505561.543379     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738505561.565688     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738505561.608301     330 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738505561.632300     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738505561.710509     350 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738505561.710537     344 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738505561.726158     348 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738505562.066677     330 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738505562.072758     350 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738505562.190818     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738505562.352078     333 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738505562.672258     333 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738505562.731769     343 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738505562.731768     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738505562.850197     350 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738505591.257556     168 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738505591.303578     168 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 68s 67ms/step - loss: 0.2383
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0312
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0273
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0232
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0228
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0207
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0215
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0199
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0198
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0217
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0204
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0201
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0192
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0191
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0186
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0189
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0207
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0195
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0187
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0199
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0182
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0192
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0173
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0179
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - loss: 0.0173
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0170
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - loss: 0.0153
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - loss: 0.0162
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0167
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0167
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0167
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0162
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0165
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0159
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0158
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0170
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0169
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0173
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0171
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0171
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0143
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 327/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 328/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 346/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 347/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 348/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 349/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 350/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 351/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 352/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 353/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 354/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 355/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 356/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 357/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 358/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 359/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 360/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 361/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 362/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 363/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 364/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 365/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 366/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 367/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 368/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 369/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 370/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 371/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 372/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 373/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 374/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 375/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 376/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 377/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 378/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 379/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 380/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 381/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0143
# Epoch 382/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 383/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 384/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 385/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 386/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 387/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 388/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 389/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 390/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 391/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 392/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 393/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 394/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 395/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 396/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 397/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 398/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 399/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 400/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 401/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 402/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 403/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 404/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 405/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 406/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 407/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 408/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 409/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 410/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 411/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 412/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 413/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0142
# Epoch 414/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 415/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 416/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 417/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 418/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 419/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 420/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 421/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 422/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 423/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 424/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 425/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 426/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 427/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 428/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 429/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 430/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 431/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 432/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 433/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 434/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 435/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 436/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 437/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 438/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 439/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 440/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 441/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 442/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 443/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 444/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 445/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 446/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 447/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 448/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 449/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 450/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 451/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 452/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 453/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 454/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 455/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 456/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 457/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 458/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 459/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 460/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 461/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 462/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 463/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 464/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 465/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 466/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 467/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0140
# Epoch 468/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 469/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 470/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 471/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 472/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 473/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 474/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 475/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 476/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 477/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 478/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 479/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 480/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 481/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0141
# Epoch 482/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 483/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 484/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 485/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 486/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 487/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 488/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 489/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 490/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 491/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 492/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 493/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 494/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 495/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 496/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0140
# Epoch 497/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 498/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 499/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 500/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# INFO:tensorflow:Assets written to: DDPM-GI/YACHT/GERADOR/assets
# INFO:tensorflow:Assets written to: DDPM-GI/YACHT/GERADOR/assets

# %%
import os
from IPython.display import clear_output
import time

num_img = 5400
output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    ini = time.time()
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    fim = time.time()
    tim = fim - ini
    timt = (tim * t) / 3600
    print("Faltam %d iterações" % (t))
    print("A iteração atual levou %d segundos" % (tim))
    print("Faltam %.2f horas" % (timt))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# Faltam 0 iterações
# A iteração atual levou 27 segundos
# Faltam 0.00 horas

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: YACHT0.png -> DDPM-F64x4/YACHT/YACHT0.png
# Processado: YACHT1.png -> DDPM-F64x4/YACHT/YACHT1.png
# Processado: YACHT10.png -> DDPM-F64x4/YACHT/YACHT10.png
# Processado: YACHT100.png -> DDPM-F64x4/YACHT/YACHT100.png
# Processado: YACHT1000.png -> DDPM-F64x4/YACHT/YACHT1000.png
# Processado: YACHT1001.png -> DDPM-F64x4/YACHT/YACHT1001.png
# Processado: YACHT1002.png -> DDPM-F64x4/YACHT/YACHT1002.png
# Processado: YACHT1003.png -> DDPM-F64x4/YACHT/YACHT1003.png
# Processado: YACHT1004.png -> DDPM-F64x4/YACHT/YACHT1004.png
# Processado: YACHT1005.png -> DDPM-F64x4/YACHT/YACHT1005.png
# Processado: YACHT1006.png -> DDPM-F64x4/YACHT/YACHT1006.png
# Processado: YACHT1007.png -> DDPM-F64x4/YACHT/YACHT1007.png
# Processado: YACHT1008.png -> DDPM-F64x4/YACHT/YACHT1008.png
# Processado: YACHT1009.png -> DDPM-F64x4/YACHT/YACHT1009.png
# Processado: YACHT101.png -> DDPM-F64x4/YACHT/YACHT101.png
# Processado: YACHT1010.png -> DDPM-F64x4/YACHT/YACHT1010.png
# Processado: YACHT1011.png -> DDPM-F64x4/YACHT/YACHT1011.png
# Processado: YACHT1012.png -> DDPM-F64x4/YACHT/YACHT1012.png
# Processado: YACHT1013.png -> DDPM-F64x4/YACHT/YACHT1013.png
# Processado: YACHT1014.png -> DDPM-F64x4/YACHT/YACHT1014.png
# Processado: YACHT1015.png -> DDPM-F64x4/YACHT/YACHT1015.png
# Processado: YACHT1016.png -> DDPM-F64x4/YACHT/YACHT1016.png
# Processado: YACHT1017.png -> DDPM-F64x4/YACHT/YACHT1017.png
# Processado: YACHT1018.png -> DDPM-F64x4/YACHT/YACHT1018.png
# Processado: YACHT1019.png -> DDPM-F64x4/YACHT/YACHT1019.png
# Processado: YACHT102.png -> DDPM-F64x4/YACHT/YACHT102.png
# Processado: YACHT1020.png -> DDPM-F64x4/YACHT/YACHT1020.png
# Processado: YACHT1021.png -> DDPM-F64x4/YACHT/YACHT1021.png
# Processado: YACHT1022.png -> DDPM-F64x4/YACHT/YACHT1022.png
# Processado: YACHT1023.png -> DDPM-F64x4/YACHT/YACHT1023.png
# Processado: YACHT1024.png -> DDPM-F64x4/YACHT/YACHT1024.png
# Processado: YACHT1025.png -> DDPM-F64x4/YACHT/YACHT1025.png
# Processado: YACHT1026.png -> DDPM-F64x4/YACHT/YACHT1026.png
# Processado: YACHT1027.png -> DDPM-F64x4/YACHT/YACHT1027.png
# Processado: YACHT1028.png -> DDPM-F64x4/YACHT/YACHT1028.png
# Processado: YACHT1029.png -> DDPM-F64x4/YACHT/YACHT1029.png
# Processado: YACHT103.png -> DDPM-F64x4/YACHT/YACHT103.png
# Processado: YACHT1030.png -> DDPM-F64x4/YACHT/YACHT1030.png
# Processado: YACHT1031.png -> DDPM-F64x4/YACHT/YACHT1031.png
# Processado: YACHT1032.png -> DDPM-F64x4/YACHT/YACHT1032.png
# Processado: YACHT1033.png -> DDPM-F64x4/YACHT/YACHT1033.png
# Processado: YACHT1034.png -> DDPM-F64x4/YACHT/YACHT1034.png
# Processado: YACHT1035.png -> DDPM-F64x4/YACHT/YACHT1035.png
# Processado: YACHT1036.png -> DDPM-F64x4/YACHT/YACHT1036.png
# Processado: YACHT1037.png -> DDPM-F64x4/YACHT/YACHT1037.png
# Processado: YACHT1038.png -> DDPM-F64x4/YACHT/YACHT1038.png
# Processado: YACHT1039.png -> DDPM-F64x4/YACHT/YACHT1039.png
# Processado: YACHT104.png -> DDPM-F64x4/YACHT/YACHT104.png
# Processado: YACHT1040.png -> DDPM-F64x4/YACHT/YACHT1040.png
# Processado: YACHT1041.png -> DDPM-F64x4/YACHT/YACHT1041.png
# Processado: YACHT1042.png -> DDPM-F64x4/YACHT/YACHT1042.png
# Processado: YACHT1043.png -> DDPM-F64x4/YACHT/YACHT1043.png
# Processado: YACHT1044.png -> DDPM-F64x4/YACHT/YACHT1044.png
# Processado: YACHT1045.png -> DDPM-F64x4/YACHT/YACHT1045.png
# Processado: YACHT1046.png -> DDPM-F64x4/YACHT/YACHT1046.png
# Processado: YACHT1047.png -> DDPM-F64x4/YACHT/YACHT1047.png
# Processado: YACHT1048.png -> DDPM-F64x4/YACHT/YACHT1048.png
# Processado: YACHT1049.png -> DDPM-F64x4/YACHT/YACHT1049.png
# Processado: YACHT105.png -> DDPM-F64x4/YACHT/YACHT105.png
# Processado: YACHT1050.png -> DDPM-F64x4/YACHT/YACHT1050.png
# Processado: YACHT1051.png -> DDPM-F64x4/YACHT/YACHT1051.png
# Processado: YACHT1052.png -> DDPM-F64x4/YACHT/YACHT1052.png
# Processado: YACHT1053.png -> DDPM-F64x4/YACHT/YACHT1053.png
# Processado: YACHT1054.png -> DDPM-F64x4/YACHT/YACHT1054.png
# Processado: YACHT1055.png -> DDPM-F64x4/YACHT/YACHT1055.png
# Processado: YACHT1056.png -> DDPM-F64x4/YACHT/YACHT1056.png
# Processado: YACHT1057.png -> DDPM-F64x4/YACHT/YACHT1057.png
# Processado: YACHT1058.png -> DDPM-F64x4/YACHT/YACHT1058.png
# Processado: YACHT1059.png -> DDPM-F64x4/YACHT/YACHT1059.png
# Processado: YACHT106.png -> DDPM-F64x4/YACHT/YACHT106.png
# Processado: YACHT1060.png -> DDPM-F64x4/YACHT/YACHT1060.png
# Processado: YACHT1061.png -> DDPM-F64x4/YACHT/YACHT1061.png
# Processado: YACHT1062.png -> DDPM-F64x4/YACHT/YACHT1062.png
# Processado: YACHT1063.png -> DDPM-F64x4/YACHT/YACHT1063.png
# Processado: YACHT1064.png -> DDPM-F64x4/YACHT/YACHT1064.png
# Processado: YACHT1065.png -> DDPM-F64x4/YACHT/YACHT1065.png
# Processado: YACHT1066.png -> DDPM-F64x4/YACHT/YACHT1066.png
# Processado: YACHT1067.png -> DDPM-F64x4/YACHT/YACHT1067.png
# Processado: YACHT1068.png -> DDPM-F64x4/YACHT/YACHT1068.png
# Processado: YACHT1069.png -> DDPM-F64x4/YACHT/YACHT1069.png
# Processado: YACHT107.png -> DDPM-F64x4/YACHT/YACHT107.png
# Processado: YACHT1070.png -> DDPM-F64x4/YACHT/YACHT1070.png
# Processado: YACHT1071.png -> DDPM-F64x4/YACHT/YACHT1071.png
# Processado: YACHT1072.png -> DDPM-F64x4/YACHT/YACHT1072.png
# Processado: YACHT1073.png -> DDPM-F64x4/YACHT/YACHT1073.png
# Processado: YACHT1074.png -> DDPM-F64x4/YACHT/YACHT1074.png
# Processado: YACHT1075.png -> DDPM-F64x4/YACHT/YACHT1075.png
# Processado: YACHT1076.png -> DDPM-F64x4/YACHT/YACHT1076.png
# Processado: YACHT1077.png -> DDPM-F64x4/YACHT/YACHT1077.png
# Processado: YACHT1078.png -> DDPM-F64x4/YACHT/YACHT1078.png
# Processado: YACHT1079.png -> DDPM-F64x4/YACHT/YACHT1079.png
# Processado: YACHT108.png -> DDPM-F64x4/YACHT/YACHT108.png
# Processado: YACHT1080.png -> DDPM-F64x4/YACHT/YACHT1080.png
# Processado: YACHT1081.png -> DDPM-F64x4/YACHT/YACHT1081.png
# Processado: YACHT1082.png -> DDPM-F64x4/YACHT/YACHT1082.png
# Processado: YACHT1083.png -> DDPM-F64x4/YACHT/YACHT1083.png
# Processado: YACHT1084.png -> DDPM-F64x4/YACHT/YACHT1084.png
# Processado: YACHT1085.png -> DDPM-F64x4/YACHT/YACHT1085.png
# Processado: YACHT1086.png -> DDPM-F64x4/YACHT/YACHT1086.png
# Processado: YACHT1087.png -> DDPM-F64x4/YACHT/YACHT1087.png
# Processado: YACHT1088.png -> DDPM-F64x4/YACHT/YACHT1088.png
# Processado: YACHT1089.png -> DDPM-F64x4/YACHT/YACHT1089.png
# Processado: YACHT109.png -> DDPM-F64x4/YACHT/YACHT109.png
# Processado: YACHT1090.png -> DDPM-F64x4/YACHT/YACHT1090.png
# Processado: YACHT1091.png -> DDPM-F64x4/YACHT/YACHT1091.png
# Processado: YACHT1092.png -> DDPM-F64x4/YACHT/YACHT1092.png
# Processado: YACHT1093.png -> DDPM-F64x4/YACHT/YACHT1093.png
# Processado: YACHT1094.png -> DDPM-F64x4/YACHT/YACHT1094.png
# Processado: YACHT1095.png -> DDPM-F64x4/YACHT/YACHT1095.png
# Processado: YACHT1096.png -> DDPM-F64x4/YACHT/YACHT1096.png
# Processado: YACHT1097.png -> DDPM-F64x4/YACHT/YACHT1097.png
# Processado: YACHT1098.png -> DDPM-F64x4/YACHT/YACHT1098.png
# Processado: YACHT1099.png -> DDPM-F64x4/YACHT/YACHT1099.png
# Processado: YACHT11.png -> DDPM-F64x4/YACHT/YACHT11.png
# Processado: YACHT110.png -> DDPM-F64x4/YACHT/YACHT110.png
# Processado: YACHT1100.png -> DDPM-F64x4/YACHT/YACHT1100.png
# Processado: YACHT1101.png -> DDPM-F64x4/YACHT/YACHT1101.png
# Processado: YACHT1102.png -> DDPM-F64x4/YACHT/YACHT1102.png
# Processado: YACHT1103.png -> DDPM-F64x4/YACHT/YACHT1103.png
# Processado: YACHT1104.png -> DDPM-F64x4/YACHT/YACHT1104.png
# Processado: YACHT1105.png -> DDPM-F64x4/YACHT/YACHT1105.png
# Processado: YACHT1106.png -> DDPM-F64x4/YACHT/YACHT1106.png
# Processado: YACHT1107.png -> DDPM-F64x4/YACHT/YACHT1107.png
# Processado: YACHT1108.png -> DDPM-F64x4/YACHT/YACHT1108.png
# Processado: YACHT1109.png -> DDPM-F64x4/YACHT/YACHT1109.png
# Processado: YACHT111.png -> DDPM-F64x4/YACHT/YACHT111.png
# Processado: YACHT1110.png -> DDPM-F64x4/YACHT/YACHT1110.png
# Processado: YACHT1111.png -> DDPM-F64x4/YACHT/YACHT1111.png
# Processado: YACHT1112.png -> DDPM-F64x4/YACHT/YACHT1112.png
# Processado: YACHT1113.png -> DDPM-F64x4/YACHT/YACHT1113.png
# Processado: YACHT1114.png -> DDPM-F64x4/YACHT/YACHT1114.png
# Processado: YACHT1115.png -> DDPM-F64x4/YACHT/YACHT1115.png
# Processado: YACHT1116.png -> DDPM-F64x4/YACHT/YACHT1116.png
# Processado: YACHT1117.png -> DDPM-F64x4/YACHT/YACHT1117.png
# Processado: YACHT1118.png -> DDPM-F64x4/YACHT/YACHT1118.png
# Processado: YACHT1119.png -> DDPM-F64x4/YACHT/YACHT1119.png
# Processado: YACHT112.png -> DDPM-F64x4/YACHT/YACHT112.png
# Processado: YACHT1120.png -> DDPM-F64x4/YACHT/YACHT1120.png
# Processado: YACHT1121.png -> DDPM-F64x4/YACHT/YACHT1121.png
# Processado: YACHT1122.png -> DDPM-F64x4/YACHT/YACHT1122.png
# Processado: YACHT1123.png -> DDPM-F64x4/YACHT/YACHT1123.png
# Processado: YACHT1124.png -> DDPM-F64x4/YACHT/YACHT1124.png
# Processado: YACHT1125.png -> DDPM-F64x4/YACHT/YACHT1125.png
# Processado: YACHT1126.png -> DDPM-F64x4/YACHT/YACHT1126.png
# Processado: YACHT1127.png -> DDPM-F64x4/YACHT/YACHT1127.png
# Processado: YACHT1128.png -> DDPM-F64x4/YACHT/YACHT1128.png
# Processado: YACHT1129.png -> DDPM-F64x4/YACHT/YACHT1129.png
# Processado: YACHT113.png -> DDPM-F64x4/YACHT/YACHT113.png
# Processado: YACHT1130.png -> DDPM-F64x4/YACHT/YACHT1130.png
# Processado: YACHT1131.png -> DDPM-F64x4/YACHT/YACHT1131.png
# Processado: YACHT1132.png -> DDPM-F64x4/YACHT/YACHT1132.png
# Processado: YACHT1133.png -> DDPM-F64x4/YACHT/YACHT1133.png
# Processado: YACHT1134.png -> DDPM-F64x4/YACHT/YACHT1134.png
# Processado: YACHT1135.png -> DDPM-F64x4/YACHT/YACHT1135.png
# Processado: YACHT1136.png -> DDPM-F64x4/YACHT/YACHT1136.png
# Processado: YACHT1137.png -> DDPM-F64x4/YACHT/YACHT1137.png
# Processado: YACHT1138.png -> DDPM-F64x4/YACHT/YACHT1138.png
# Processado: YACHT1139.png -> DDPM-F64x4/YACHT/YACHT1139.png
# Processado: YACHT114.png -> DDPM-F64x4/YACHT/YACHT114.png
# Processado: YACHT1140.png -> DDPM-F64x4/YACHT/YACHT1140.png
# Processado: YACHT1141.png -> DDPM-F64x4/YACHT/YACHT1141.png
# Processado: YACHT1142.png -> DDPM-F64x4/YACHT/YACHT1142.png
# Processado: YACHT1143.png -> DDPM-F64x4/YACHT/YACHT1143.png
# Processado: YACHT1144.png -> DDPM-F64x4/YACHT/YACHT1144.png
# Processado: YACHT1145.png -> DDPM-F64x4/YACHT/YACHT1145.png
# Processado: YACHT1146.png -> DDPM-F64x4/YACHT/YACHT1146.png
# Processado: YACHT1147.png -> DDPM-F64x4/YACHT/YACHT1147.png
# Processado: YACHT1148.png -> DDPM-F64x4/YACHT/YACHT1148.png
# Processado: YACHT1149.png -> DDPM-F64x4/YACHT/YACHT1149.png
# Processado: YACHT115.png -> DDPM-F64x4/YACHT/YACHT115.png
# Processado: YACHT1150.png -> DDPM-F64x4/YACHT/YACHT1150.png
# Processado: YACHT1151.png -> DDPM-F64x4/YACHT/YACHT1151.png
# Processado: YACHT1152.png -> DDPM-F64x4/YACHT/YACHT1152.png
# Processado: YACHT1153.png -> DDPM-F64x4/YACHT/YACHT1153.png
# Processado: YACHT1154.png -> DDPM-F64x4/YACHT/YACHT1154.png
# Processado: YACHT1155.png -> DDPM-F64x4/YACHT/YACHT1155.png
# Processado: YACHT1156.png -> DDPM-F64x4/YACHT/YACHT1156.png
# Processado: YACHT1157.png -> DDPM-F64x4/YACHT/YACHT1157.png
# Processado: YACHT1158.png -> DDPM-F64x4/YACHT/YACHT1158.png
# Processado: YACHT1159.png -> DDPM-F64x4/YACHT/YACHT1159.png
# Processado: YACHT116.png -> DDPM-F64x4/YACHT/YACHT116.png
# Processado: YACHT1160.png -> DDPM-F64x4/YACHT/YACHT1160.png
# Processado: YACHT1161.png -> DDPM-F64x4/YACHT/YACHT1161.png
# Processado: YACHT1162.png -> DDPM-F64x4/YACHT/YACHT1162.png
# Processado: YACHT1163.png -> DDPM-F64x4/YACHT/YACHT1163.png
# Processado: YACHT1164.png -> DDPM-F64x4/YACHT/YACHT1164.png
# Processado: YACHT1165.png -> DDPM-F64x4/YACHT/YACHT1165.png
# Processado: YACHT1166.png -> DDPM-F64x4/YACHT/YACHT1166.png
# Processado: YACHT1167.png -> DDPM-F64x4/YACHT/YACHT1167.png
# Processado: YACHT1168.png -> DDPM-F64x4/YACHT/YACHT1168.png
# Processado: YACHT1169.png -> DDPM-F64x4/YACHT/YACHT1169.png
# Processado: YACHT117.png -> DDPM-F64x4/YACHT/YACHT117.png
# Processado: YACHT1170.png -> DDPM-F64x4/YACHT/YACHT1170.png
# Processado: YACHT1171.png -> DDPM-F64x4/YACHT/YACHT1171.png
# Processado: YACHT1172.png -> DDPM-F64x4/YACHT/YACHT1172.png
# Processado: YACHT1173.png -> DDPM-F64x4/YACHT/YACHT1173.png
# Processado: YACHT1174.png -> DDPM-F64x4/YACHT/YACHT1174.png
# Processado: YACHT1175.png -> DDPM-F64x4/YACHT/YACHT1175.png
# Processado: YACHT1176.png -> DDPM-F64x4/YACHT/YACHT1176.png
# Processado: YACHT1177.png -> DDPM-F64x4/YACHT/YACHT1177.png
# Processado: YACHT1178.png -> DDPM-F64x4/YACHT/YACHT1178.png
# Processado: YACHT1179.png -> DDPM-F64x4/YACHT/YACHT1179.png
# Processado: YACHT118.png -> DDPM-F64x4/YACHT/YACHT118.png
# Processado: YACHT1180.png -> DDPM-F64x4/YACHT/YACHT1180.png
# Processado: YACHT1181.png -> DDPM-F64x4/YACHT/YACHT1181.png
# Processado: YACHT1182.png -> DDPM-F64x4/YACHT/YACHT1182.png
# Processado: YACHT1183.png -> DDPM-F64x4/YACHT/YACHT1183.png
# Processado: YACHT1184.png -> DDPM-F64x4/YACHT/YACHT1184.png
# Processado: YACHT1185.png -> DDPM-F64x4/YACHT/YACHT1185.png
# Processado: YACHT1186.png -> DDPM-F64x4/YACHT/YACHT1186.png
# Processado: YACHT1187.png -> DDPM-F64x4/YACHT/YACHT1187.png
# Processado: YACHT1188.png -> DDPM-F64x4/YACHT/YACHT1188.png
# Processado: YACHT1189.png -> DDPM-F64x4/YACHT/YACHT1189.png
# Processado: YACHT119.png -> DDPM-F64x4/YACHT/YACHT119.png
# Processado: YACHT1190.png -> DDPM-F64x4/YACHT/YACHT1190.png
# Processado: YACHT1191.png -> DDPM-F64x4/YACHT/YACHT1191.png
# Processado: YACHT1192.png -> DDPM-F64x4/YACHT/YACHT1192.png
# Processado: YACHT1193.png -> DDPM-F64x4/YACHT/YACHT1193.png
# Processado: YACHT1194.png -> DDPM-F64x4/YACHT/YACHT1194.png
# Processado: YACHT1195.png -> DDPM-F64x4/YACHT/YACHT1195.png
# Processado: YACHT1196.png -> DDPM-F64x4/YACHT/YACHT1196.png
# Processado: YACHT1197.png -> DDPM-F64x4/YACHT/YACHT1197.png
# Processado: YACHT1198.png -> DDPM-F64x4/YACHT/YACHT1198.png
# Processado: YACHT1199.png -> DDPM-F64x4/YACHT/YACHT1199.png
# Processado: YACHT12.png -> DDPM-F64x4/YACHT/YACHT12.png
# Processado: YACHT120.png -> DDPM-F64x4/YACHT/YACHT120.png
# Processado: YACHT1200.png -> DDPM-F64x4/YACHT/YACHT1200.png
# Processado: YACHT1201.png -> DDPM-F64x4/YACHT/YACHT1201.png
# Processado: YACHT1202.png -> DDPM-F64x4/YACHT/YACHT1202.png
# Processado: YACHT1203.png -> DDPM-F64x4/YACHT/YACHT1203.png
# Processado: YACHT1204.png -> DDPM-F64x4/YACHT/YACHT1204.png
# Processado: YACHT1205.png -> DDPM-F64x4/YACHT/YACHT1205.png
# Processado: YACHT1206.png -> DDPM-F64x4/YACHT/YACHT1206.png
# Processado: YACHT1207.png -> DDPM-F64x4/YACHT/YACHT1207.png
# Processado: YACHT1208.png -> DDPM-F64x4/YACHT/YACHT1208.png
# Processado: YACHT1209.png -> DDPM-F64x4/YACHT/YACHT1209.png
# Processado: YACHT121.png -> DDPM-F64x4/YACHT/YACHT121.png
# Processado: YACHT1210.png -> DDPM-F64x4/YACHT/YACHT1210.png
# Processado: YACHT1211.png -> DDPM-F64x4/YACHT/YACHT1211.png
# Processado: YACHT1212.png -> DDPM-F64x4/YACHT/YACHT1212.png
# Processado: YACHT1213.png -> DDPM-F64x4/YACHT/YACHT1213.png
# Processado: YACHT1214.png -> DDPM-F64x4/YACHT/YACHT1214.png
# Processado: YACHT1215.png -> DDPM-F64x4/YACHT/YACHT1215.png
# Processado: YACHT1216.png -> DDPM-F64x4/YACHT/YACHT1216.png
# Processado: YACHT1217.png -> DDPM-F64x4/YACHT/YACHT1217.png
# Processado: YACHT1218.png -> DDPM-F64x4/YACHT/YACHT1218.png
# Processado: YACHT1219.png -> DDPM-F64x4/YACHT/YACHT1219.png
# Processado: YACHT122.png -> DDPM-F64x4/YACHT/YACHT122.png
# Processado: YACHT1220.png -> DDPM-F64x4/YACHT/YACHT1220.png
# Processado: YACHT1221.png -> DDPM-F64x4/YACHT/YACHT1221.png
# Processado: YACHT1222.png -> DDPM-F64x4/YACHT/YACHT1222.png
# Processado: YACHT1223.png -> DDPM-F64x4/YACHT/YACHT1223.png
# Processado: YACHT1224.png -> DDPM-F64x4/YACHT/YACHT1224.png
# Processado: YACHT1225.png -> DDPM-F64x4/YACHT/YACHT1225.png
# Processado: YACHT1226.png -> DDPM-F64x4/YACHT/YACHT1226.png
# Processado: YACHT1227.png -> DDPM-F64x4/YACHT/YACHT1227.png
# Processado: YACHT1228.png -> DDPM-F64x4/YACHT/YACHT1228.png
# Processado: YACHT1229.png -> DDPM-F64x4/YACHT/YACHT1229.png
# Processado: YACHT123.png -> DDPM-F64x4/YACHT/YACHT123.png
# Processado: YACHT1230.png -> DDPM-F64x4/YACHT/YACHT1230.png
# Processado: YACHT1231.png -> DDPM-F64x4/YACHT/YACHT1231.png
# Processado: YACHT1232.png -> DDPM-F64x4/YACHT/YACHT1232.png
# Processado: YACHT1233.png -> DDPM-F64x4/YACHT/YACHT1233.png
# Processado: YACHT1234.png -> DDPM-F64x4/YACHT/YACHT1234.png
# Processado: YACHT1235.png -> DDPM-F64x4/YACHT/YACHT1235.png
# Processado: YACHT1236.png -> DDPM-F64x4/YACHT/YACHT1236.png
# Processado: YACHT1237.png -> DDPM-F64x4/YACHT/YACHT1237.png
# Processado: YACHT1238.png -> DDPM-F64x4/YACHT/YACHT1238.png
# Processado: YACHT1239.png -> DDPM-F64x4/YACHT/YACHT1239.png
# Processado: YACHT124.png -> DDPM-F64x4/YACHT/YACHT124.png
# Processado: YACHT1240.png -> DDPM-F64x4/YACHT/YACHT1240.png
# Processado: YACHT1241.png -> DDPM-F64x4/YACHT/YACHT1241.png
# Processado: YACHT1242.png -> DDPM-F64x4/YACHT/YACHT1242.png
# Processado: YACHT1243.png -> DDPM-F64x4/YACHT/YACHT1243.png
# Processado: YACHT1244.png -> DDPM-F64x4/YACHT/YACHT1244.png
# Processado: YACHT1245.png -> DDPM-F64x4/YACHT/YACHT1245.png
# Processado: YACHT1246.png -> DDPM-F64x4/YACHT/YACHT1246.png
# Processado: YACHT1247.png -> DDPM-F64x4/YACHT/YACHT1247.png
# Processado: YACHT1248.png -> DDPM-F64x4/YACHT/YACHT1248.png
# Processado: YACHT1249.png -> DDPM-F64x4/YACHT/YACHT1249.png
# Processado: YACHT125.png -> DDPM-F64x4/YACHT/YACHT125.png
# Processado: YACHT1250.png -> DDPM-F64x4/YACHT/YACHT1250.png
# Processado: YACHT1251.png -> DDPM-F64x4/YACHT/YACHT1251.png
# Processado: YACHT1252.png -> DDPM-F64x4/YACHT/YACHT1252.png
# Processado: YACHT1253.png -> DDPM-F64x4/YACHT/YACHT1253.png
# Processado: YACHT1254.png -> DDPM-F64x4/YACHT/YACHT1254.png
# Processado: YACHT1255.png -> DDPM-F64x4/YACHT/YACHT1255.png
# Processado: YACHT1256.png -> DDPM-F64x4/YACHT/YACHT1256.png
# Processado: YACHT1257.png -> DDPM-F64x4/YACHT/YACHT1257.png
# Processado: YACHT1258.png -> DDPM-F64x4/YACHT/YACHT1258.png
# Processado: YACHT1259.png -> DDPM-F64x4/YACHT/YACHT1259.png
# Processado: YACHT126.png -> DDPM-F64x4/YACHT/YACHT126.png
# Processado: YACHT1260.png -> DDPM-F64x4/YACHT/YACHT1260.png
# Processado: YACHT1261.png -> DDPM-F64x4/YACHT/YACHT1261.png
# Processado: YACHT1262.png -> DDPM-F64x4/YACHT/YACHT1262.png
# Processado: YACHT1263.png -> DDPM-F64x4/YACHT/YACHT1263.png
# Processado: YACHT1264.png -> DDPM-F64x4/YACHT/YACHT1264.png
# Processado: YACHT1265.png -> DDPM-F64x4/YACHT/YACHT1265.png
# Processado: YACHT1266.png -> DDPM-F64x4/YACHT/YACHT1266.png
# Processado: YACHT1267.png -> DDPM-F64x4/YACHT/YACHT1267.png
# Processado: YACHT1268.png -> DDPM-F64x4/YACHT/YACHT1268.png
# Processado: YACHT1269.png -> DDPM-F64x4/YACHT/YACHT1269.png
# Processado: YACHT127.png -> DDPM-F64x4/YACHT/YACHT127.png
# Processado: YACHT1270.png -> DDPM-F64x4/YACHT/YACHT1270.png
# Processado: YACHT1271.png -> DDPM-F64x4/YACHT/YACHT1271.png
# Processado: YACHT1272.png -> DDPM-F64x4/YACHT/YACHT1272.png
# Processado: YACHT1273.png -> DDPM-F64x4/YACHT/YACHT1273.png
# Processado: YACHT1274.png -> DDPM-F64x4/YACHT/YACHT1274.png
# Processado: YACHT1275.png -> DDPM-F64x4/YACHT/YACHT1275.png
# Processado: YACHT1276.png -> DDPM-F64x4/YACHT/YACHT1276.png
# Processado: YACHT1277.png -> DDPM-F64x4/YACHT/YACHT1277.png
# Processado: YACHT1278.png -> DDPM-F64x4/YACHT/YACHT1278.png
# Processado: YACHT1279.png -> DDPM-F64x4/YACHT/YACHT1279.png
# Processado: YACHT128.png -> DDPM-F64x4/YACHT/YACHT128.png
# Processado: YACHT1280.png -> DDPM-F64x4/YACHT/YACHT1280.png
# Processado: YACHT1281.png -> DDPM-F64x4/YACHT/YACHT1281.png
# Processado: YACHT1282.png -> DDPM-F64x4/YACHT/YACHT1282.png
# Processado: YACHT1283.png -> DDPM-F64x4/YACHT/YACHT1283.png
# Processado: YACHT1284.png -> DDPM-F64x4/YACHT/YACHT1284.png
# Processado: YACHT1285.png -> DDPM-F64x4/YACHT/YACHT1285.png
# Processado: YACHT1286.png -> DDPM-F64x4/YACHT/YACHT1286.png
# Processado: YACHT1287.png -> DDPM-F64x4/YACHT/YACHT1287.png
# Processado: YACHT1288.png -> DDPM-F64x4/YACHT/YACHT1288.png
# Processado: YACHT1289.png -> DDPM-F64x4/YACHT/YACHT1289.png
# Processado: YACHT129.png -> DDPM-F64x4/YACHT/YACHT129.png
# Processado: YACHT1290.png -> DDPM-F64x4/YACHT/YACHT1290.png
# Processado: YACHT1291.png -> DDPM-F64x4/YACHT/YACHT1291.png
# Processado: YACHT1292.png -> DDPM-F64x4/YACHT/YACHT1292.png
# Processado: YACHT1293.png -> DDPM-F64x4/YACHT/YACHT1293.png
# Processado: YACHT1294.png -> DDPM-F64x4/YACHT/YACHT1294.png
# Processado: YACHT1295.png -> DDPM-F64x4/YACHT/YACHT1295.png
# Processado: YACHT1296.png -> DDPM-F64x4/YACHT/YACHT1296.png
# Processado: YACHT1297.png -> DDPM-F64x4/YACHT/YACHT1297.png
# Processado: YACHT1298.png -> DDPM-F64x4/YACHT/YACHT1298.png
# Processado: YACHT1299.png -> DDPM-F64x4/YACHT/YACHT1299.png
# Processado: YACHT13.png -> DDPM-F64x4/YACHT/YACHT13.png
# Processado: YACHT130.png -> DDPM-F64x4/YACHT/YACHT130.png
# Processado: YACHT1300.png -> DDPM-F64x4/YACHT/YACHT1300.png
# Processado: YACHT1301.png -> DDPM-F64x4/YACHT/YACHT1301.png
# Processado: YACHT1302.png -> DDPM-F64x4/YACHT/YACHT1302.png
# Processado: YACHT1303.png -> DDPM-F64x4/YACHT/YACHT1303.png
# Processado: YACHT1304.png -> DDPM-F64x4/YACHT/YACHT1304.png
# Processado: YACHT1305.png -> DDPM-F64x4/YACHT/YACHT1305.png
# Processado: YACHT1306.png -> DDPM-F64x4/YACHT/YACHT1306.png
# Processado: YACHT1307.png -> DDPM-F64x4/YACHT/YACHT1307.png
# Processado: YACHT1308.png -> DDPM-F64x4/YACHT/YACHT1308.png
# Processado: YACHT1309.png -> DDPM-F64x4/YACHT/YACHT1309.png
# Processado: YACHT131.png -> DDPM-F64x4/YACHT/YACHT131.png
# Processado: YACHT1310.png -> DDPM-F64x4/YACHT/YACHT1310.png
# Processado: YACHT1311.png -> DDPM-F64x4/YACHT/YACHT1311.png
# Processado: YACHT1312.png -> DDPM-F64x4/YACHT/YACHT1312.png
# Processado: YACHT1313.png -> DDPM-F64x4/YACHT/YACHT1313.png
# Processado: YACHT1314.png -> DDPM-F64x4/YACHT/YACHT1314.png
# Processado: YACHT1315.png -> DDPM-F64x4/YACHT/YACHT1315.png
# Processado: YACHT1316.png -> DDPM-F64x4/YACHT/YACHT1316.png
# Processado: YACHT1317.png -> DDPM-F64x4/YACHT/YACHT1317.png
# Processado: YACHT1318.png -> DDPM-F64x4/YACHT/YACHT1318.png
# Processado: YACHT1319.png -> DDPM-F64x4/YACHT/YACHT1319.png
# Processado: YACHT132.png -> DDPM-F64x4/YACHT/YACHT132.png
# Processado: YACHT1320.png -> DDPM-F64x4/YACHT/YACHT1320.png
# Processado: YACHT1321.png -> DDPM-F64x4/YACHT/YACHT1321.png
# Processado: YACHT1322.png -> DDPM-F64x4/YACHT/YACHT1322.png
# Processado: YACHT1323.png -> DDPM-F64x4/YACHT/YACHT1323.png
# Processado: YACHT1324.png -> DDPM-F64x4/YACHT/YACHT1324.png
# Processado: YACHT1325.png -> DDPM-F64x4/YACHT/YACHT1325.png
# Processado: YACHT1326.png -> DDPM-F64x4/YACHT/YACHT1326.png
# Processado: YACHT1327.png -> DDPM-F64x4/YACHT/YACHT1327.png
# Processado: YACHT1328.png -> DDPM-F64x4/YACHT/YACHT1328.png
# Processado: YACHT1329.png -> DDPM-F64x4/YACHT/YACHT1329.png
# Processado: YACHT133.png -> DDPM-F64x4/YACHT/YACHT133.png
# Processado: YACHT1330.png -> DDPM-F64x4/YACHT/YACHT1330.png
# Processado: YACHT1331.png -> DDPM-F64x4/YACHT/YACHT1331.png
# Processado: YACHT1332.png -> DDPM-F64x4/YACHT/YACHT1332.png
# Processado: YACHT1333.png -> DDPM-F64x4/YACHT/YACHT1333.png
# Processado: YACHT1334.png -> DDPM-F64x4/YACHT/YACHT1334.png
# Processado: YACHT1335.png -> DDPM-F64x4/YACHT/YACHT1335.png
# Processado: YACHT1336.png -> DDPM-F64x4/YACHT/YACHT1336.png
# Processado: YACHT1337.png -> DDPM-F64x4/YACHT/YACHT1337.png
# Processado: YACHT1338.png -> DDPM-F64x4/YACHT/YACHT1338.png
# Processado: YACHT1339.png -> DDPM-F64x4/YACHT/YACHT1339.png
# Processado: YACHT134.png -> DDPM-F64x4/YACHT/YACHT134.png
# Processado: YACHT1340.png -> DDPM-F64x4/YACHT/YACHT1340.png
# Processado: YACHT1341.png -> DDPM-F64x4/YACHT/YACHT1341.png
# Processado: YACHT1342.png -> DDPM-F64x4/YACHT/YACHT1342.png
# Processado: YACHT1343.png -> DDPM-F64x4/YACHT/YACHT1343.png
# Processado: YACHT1344.png -> DDPM-F64x4/YACHT/YACHT1344.png
# Processado: YACHT1345.png -> DDPM-F64x4/YACHT/YACHT1345.png
# Processado: YACHT1346.png -> DDPM-F64x4/YACHT/YACHT1346.png
# Processado: YACHT1347.png -> DDPM-F64x4/YACHT/YACHT1347.png
# Processado: YACHT1348.png -> DDPM-F64x4/YACHT/YACHT1348.png
# Processado: YACHT1349.png -> DDPM-F64x4/YACHT/YACHT1349.png
# Processado: YACHT135.png -> DDPM-F64x4/YACHT/YACHT135.png
# Processado: YACHT1350.png -> DDPM-F64x4/YACHT/YACHT1350.png
# Processado: YACHT1351.png -> DDPM-F64x4/YACHT/YACHT1351.png
# Processado: YACHT1352.png -> DDPM-F64x4/YACHT/YACHT1352.png
# Processado: YACHT1353.png -> DDPM-F64x4/YACHT/YACHT1353.png
# Processado: YACHT1354.png -> DDPM-F64x4/YACHT/YACHT1354.png
# Processado: YACHT1355.png -> DDPM-F64x4/YACHT/YACHT1355.png
# Processado: YACHT1356.png -> DDPM-F64x4/YACHT/YACHT1356.png
# Processado: YACHT1357.png -> DDPM-F64x4/YACHT/YACHT1357.png
# Processado: YACHT1358.png -> DDPM-F64x4/YACHT/YACHT1358.png
# Processado: YACHT1359.png -> DDPM-F64x4/YACHT/YACHT1359.png
# Processado: YACHT136.png -> DDPM-F64x4/YACHT/YACHT136.png
# Processado: YACHT1360.png -> DDPM-F64x4/YACHT/YACHT1360.png
# Processado: YACHT1361.png -> DDPM-F64x4/YACHT/YACHT1361.png
# Processado: YACHT1362.png -> DDPM-F64x4/YACHT/YACHT1362.png
# Processado: YACHT1363.png -> DDPM-F64x4/YACHT/YACHT1363.png
# Processado: YACHT1364.png -> DDPM-F64x4/YACHT/YACHT1364.png
# Processado: YACHT1365.png -> DDPM-F64x4/YACHT/YACHT1365.png
# Processado: YACHT1366.png -> DDPM-F64x4/YACHT/YACHT1366.png
# Processado: YACHT1367.png -> DDPM-F64x4/YACHT/YACHT1367.png
# Processado: YACHT1368.png -> DDPM-F64x4/YACHT/YACHT1368.png
# Processado: YACHT1369.png -> DDPM-F64x4/YACHT/YACHT1369.png
# Processado: YACHT137.png -> DDPM-F64x4/YACHT/YACHT137.png
# Processado: YACHT1370.png -> DDPM-F64x4/YACHT/YACHT1370.png
# Processado: YACHT1371.png -> DDPM-F64x4/YACHT/YACHT1371.png
# Processado: YACHT1372.png -> DDPM-F64x4/YACHT/YACHT1372.png
# Processado: YACHT1373.png -> DDPM-F64x4/YACHT/YACHT1373.png
# Processado: YACHT1374.png -> DDPM-F64x4/YACHT/YACHT1374.png
# Processado: YACHT1375.png -> DDPM-F64x4/YACHT/YACHT1375.png
# Processado: YACHT1376.png -> DDPM-F64x4/YACHT/YACHT1376.png
# Processado: YACHT1377.png -> DDPM-F64x4/YACHT/YACHT1377.png
# Processado: YACHT1378.png -> DDPM-F64x4/YACHT/YACHT1378.png
# Processado: YACHT1379.png -> DDPM-F64x4/YACHT/YACHT1379.png
# Processado: YACHT138.png -> DDPM-F64x4/YACHT/YACHT138.png
# Processado: YACHT1380.png -> DDPM-F64x4/YACHT/YACHT1380.png
# Processado: YACHT1381.png -> DDPM-F64x4/YACHT/YACHT1381.png
# Processado: YACHT1382.png -> DDPM-F64x4/YACHT/YACHT1382.png
# Processado: YACHT1383.png -> DDPM-F64x4/YACHT/YACHT1383.png
# Processado: YACHT1384.png -> DDPM-F64x4/YACHT/YACHT1384.png
# Processado: YACHT1385.png -> DDPM-F64x4/YACHT/YACHT1385.png
# Processado: YACHT1386.png -> DDPM-F64x4/YACHT/YACHT1386.png
# Processado: YACHT1387.png -> DDPM-F64x4/YACHT/YACHT1387.png
# Processado: YACHT1388.png -> DDPM-F64x4/YACHT/YACHT1388.png
# Processado: YACHT1389.png -> DDPM-F64x4/YACHT/YACHT1389.png
# Processado: YACHT139.png -> DDPM-F64x4/YACHT/YACHT139.png
# Processado: YACHT1390.png -> DDPM-F64x4/YACHT/YACHT1390.png
# Processado: YACHT1391.png -> DDPM-F64x4/YACHT/YACHT1391.png
# Processado: YACHT1392.png -> DDPM-F64x4/YACHT/YACHT1392.png
# Processado: YACHT1393.png -> DDPM-F64x4/YACHT/YACHT1393.png
# Processado: YACHT1394.png -> DDPM-F64x4/YACHT/YACHT1394.png
# Processado: YACHT1395.png -> DDPM-F64x4/YACHT/YACHT1395.png
# Processado: YACHT1396.png -> DDPM-F64x4/YACHT/YACHT1396.png
# Processado: YACHT1397.png -> DDPM-F64x4/YACHT/YACHT1397.png
# Processado: YACHT1398.png -> DDPM-F64x4/YACHT/YACHT1398.png
# Processado: YACHT1399.png -> DDPM-F64x4/YACHT/YACHT1399.png
# Processado: YACHT14.png -> DDPM-F64x4/YACHT/YACHT14.png
# Processado: YACHT140.png -> DDPM-F64x4/YACHT/YACHT140.png
# Processado: YACHT1400.png -> DDPM-F64x4/YACHT/YACHT1400.png
# Processado: YACHT1401.png -> DDPM-F64x4/YACHT/YACHT1401.png
# Processado: YACHT1402.png -> DDPM-F64x4/YACHT/YACHT1402.png
# Processado: YACHT1403.png -> DDPM-F64x4/YACHT/YACHT1403.png
# Processado: YACHT1404.png -> DDPM-F64x4/YACHT/YACHT1404.png
# Processado: YACHT1405.png -> DDPM-F64x4/YACHT/YACHT1405.png
# Processado: YACHT1406.png -> DDPM-F64x4/YACHT/YACHT1406.png
# Processado: YACHT1407.png -> DDPM-F64x4/YACHT/YACHT1407.png
# Processado: YACHT1408.png -> DDPM-F64x4/YACHT/YACHT1408.png
# Processado: YACHT1409.png -> DDPM-F64x4/YACHT/YACHT1409.png
# Processado: YACHT141.png -> DDPM-F64x4/YACHT/YACHT141.png
# Processado: YACHT1410.png -> DDPM-F64x4/YACHT/YACHT1410.png
# Processado: YACHT1411.png -> DDPM-F64x4/YACHT/YACHT1411.png
# Processado: YACHT1412.png -> DDPM-F64x4/YACHT/YACHT1412.png
# Processado: YACHT1413.png -> DDPM-F64x4/YACHT/YACHT1413.png
# Processado: YACHT1414.png -> DDPM-F64x4/YACHT/YACHT1414.png
# Processado: YACHT1415.png -> DDPM-F64x4/YACHT/YACHT1415.png
# Processado: YACHT1416.png -> DDPM-F64x4/YACHT/YACHT1416.png
# Processado: YACHT1417.png -> DDPM-F64x4/YACHT/YACHT1417.png
# Processado: YACHT1418.png -> DDPM-F64x4/YACHT/YACHT1418.png
# Processado: YACHT1419.png -> DDPM-F64x4/YACHT/YACHT1419.png
# Processado: YACHT142.png -> DDPM-F64x4/YACHT/YACHT142.png
# Processado: YACHT1420.png -> DDPM-F64x4/YACHT/YACHT1420.png
# Processado: YACHT1421.png -> DDPM-F64x4/YACHT/YACHT1421.png
# Processado: YACHT1422.png -> DDPM-F64x4/YACHT/YACHT1422.png
# Processado: YACHT1423.png -> DDPM-F64x4/YACHT/YACHT1423.png
# Processado: YACHT1424.png -> DDPM-F64x4/YACHT/YACHT1424.png
# Processado: YACHT1425.png -> DDPM-F64x4/YACHT/YACHT1425.png
# Processado: YACHT1426.png -> DDPM-F64x4/YACHT/YACHT1426.png
# Processado: YACHT1427.png -> DDPM-F64x4/YACHT/YACHT1427.png
# Processado: YACHT1428.png -> DDPM-F64x4/YACHT/YACHT1428.png
# Processado: YACHT1429.png -> DDPM-F64x4/YACHT/YACHT1429.png
# Processado: YACHT143.png -> DDPM-F64x4/YACHT/YACHT143.png
# Processado: YACHT1430.png -> DDPM-F64x4/YACHT/YACHT1430.png
# Processado: YACHT1431.png -> DDPM-F64x4/YACHT/YACHT1431.png
# Processado: YACHT1432.png -> DDPM-F64x4/YACHT/YACHT1432.png
# Processado: YACHT1433.png -> DDPM-F64x4/YACHT/YACHT1433.png
# Processado: YACHT1434.png -> DDPM-F64x4/YACHT/YACHT1434.png
# Processado: YACHT1435.png -> DDPM-F64x4/YACHT/YACHT1435.png
# Processado: YACHT1436.png -> DDPM-F64x4/YACHT/YACHT1436.png
# Processado: YACHT1437.png -> DDPM-F64x4/YACHT/YACHT1437.png
# Processado: YACHT1438.png -> DDPM-F64x4/YACHT/YACHT1438.png
# Processado: YACHT1439.png -> DDPM-F64x4/YACHT/YACHT1439.png
# Processado: YACHT144.png -> DDPM-F64x4/YACHT/YACHT144.png
# Processado: YACHT1440.png -> DDPM-F64x4/YACHT/YACHT1440.png
# Processado: YACHT1441.png -> DDPM-F64x4/YACHT/YACHT1441.png
# Processado: YACHT1442.png -> DDPM-F64x4/YACHT/YACHT1442.png
# Processado: YACHT1443.png -> DDPM-F64x4/YACHT/YACHT1443.png
# Processado: YACHT1444.png -> DDPM-F64x4/YACHT/YACHT1444.png
# Processado: YACHT1445.png -> DDPM-F64x4/YACHT/YACHT1445.png
# Processado: YACHT1446.png -> DDPM-F64x4/YACHT/YACHT1446.png
# Processado: YACHT1447.png -> DDPM-F64x4/YACHT/YACHT1447.png
# Processado: YACHT1448.png -> DDPM-F64x4/YACHT/YACHT1448.png
# Processado: YACHT1449.png -> DDPM-F64x4/YACHT/YACHT1449.png
# Processado: YACHT145.png -> DDPM-F64x4/YACHT/YACHT145.png
# Processado: YACHT1450.png -> DDPM-F64x4/YACHT/YACHT1450.png
# Processado: YACHT1451.png -> DDPM-F64x4/YACHT/YACHT1451.png
# Processado: YACHT1452.png -> DDPM-F64x4/YACHT/YACHT1452.png
# Processado: YACHT1453.png -> DDPM-F64x4/YACHT/YACHT1453.png
# Processado: YACHT1454.png -> DDPM-F64x4/YACHT/YACHT1454.png
# Processado: YACHT1455.png -> DDPM-F64x4/YACHT/YACHT1455.png
# Processado: YACHT1456.png -> DDPM-F64x4/YACHT/YACHT1456.png
# Processado: YACHT1457.png -> DDPM-F64x4/YACHT/YACHT1457.png
# Processado: YACHT1458.png -> DDPM-F64x4/YACHT/YACHT1458.png
# Processado: YACHT1459.png -> DDPM-F64x4/YACHT/YACHT1459.png
# Processado: YACHT146.png -> DDPM-F64x4/YACHT/YACHT146.png
# Processado: YACHT1460.png -> DDPM-F64x4/YACHT/YACHT1460.png
# Processado: YACHT1461.png -> DDPM-F64x4/YACHT/YACHT1461.png
# Processado: YACHT1462.png -> DDPM-F64x4/YACHT/YACHT1462.png
# Processado: YACHT1463.png -> DDPM-F64x4/YACHT/YACHT1463.png
# Processado: YACHT1464.png -> DDPM-F64x4/YACHT/YACHT1464.png
# Processado: YACHT1465.png -> DDPM-F64x4/YACHT/YACHT1465.png
# Processado: YACHT1466.png -> DDPM-F64x4/YACHT/YACHT1466.png
# Processado: YACHT1467.png -> DDPM-F64x4/YACHT/YACHT1467.png
# Processado: YACHT1468.png -> DDPM-F64x4/YACHT/YACHT1468.png
# Processado: YACHT1469.png -> DDPM-F64x4/YACHT/YACHT1469.png
# Processado: YACHT147.png -> DDPM-F64x4/YACHT/YACHT147.png
# Processado: YACHT1470.png -> DDPM-F64x4/YACHT/YACHT1470.png
# Processado: YACHT1471.png -> DDPM-F64x4/YACHT/YACHT1471.png
# Processado: YACHT1472.png -> DDPM-F64x4/YACHT/YACHT1472.png
# Processado: YACHT1473.png -> DDPM-F64x4/YACHT/YACHT1473.png
# Processado: YACHT1474.png -> DDPM-F64x4/YACHT/YACHT1474.png
# Processado: YACHT1475.png -> DDPM-F64x4/YACHT/YACHT1475.png
# Processado: YACHT1476.png -> DDPM-F64x4/YACHT/YACHT1476.png
# Processado: YACHT1477.png -> DDPM-F64x4/YACHT/YACHT1477.png
# Processado: YACHT1478.png -> DDPM-F64x4/YACHT/YACHT1478.png
# Processado: YACHT1479.png -> DDPM-F64x4/YACHT/YACHT1479.png
# Processado: YACHT148.png -> DDPM-F64x4/YACHT/YACHT148.png
# Processado: YACHT1480.png -> DDPM-F64x4/YACHT/YACHT1480.png
# Processado: YACHT1481.png -> DDPM-F64x4/YACHT/YACHT1481.png
# Processado: YACHT1482.png -> DDPM-F64x4/YACHT/YACHT1482.png
# Processado: YACHT1483.png -> DDPM-F64x4/YACHT/YACHT1483.png
# Processado: YACHT1484.png -> DDPM-F64x4/YACHT/YACHT1484.png
# Processado: YACHT1485.png -> DDPM-F64x4/YACHT/YACHT1485.png
# Processado: YACHT1486.png -> DDPM-F64x4/YACHT/YACHT1486.png
# Processado: YACHT1487.png -> DDPM-F64x4/YACHT/YACHT1487.png
# Processado: YACHT1488.png -> DDPM-F64x4/YACHT/YACHT1488.png
# Processado: YACHT1489.png -> DDPM-F64x4/YACHT/YACHT1489.png
# Processado: YACHT149.png -> DDPM-F64x4/YACHT/YACHT149.png
# Processado: YACHT1490.png -> DDPM-F64x4/YACHT/YACHT1490.png
# Processado: YACHT1491.png -> DDPM-F64x4/YACHT/YACHT1491.png
# Processado: YACHT1492.png -> DDPM-F64x4/YACHT/YACHT1492.png
# Processado: YACHT1493.png -> DDPM-F64x4/YACHT/YACHT1493.png
# Processado: YACHT1494.png -> DDPM-F64x4/YACHT/YACHT1494.png
# Processado: YACHT1495.png -> DDPM-F64x4/YACHT/YACHT1495.png
# Processado: YACHT1496.png -> DDPM-F64x4/YACHT/YACHT1496.png
# Processado: YACHT1497.png -> DDPM-F64x4/YACHT/YACHT1497.png
# Processado: YACHT1498.png -> DDPM-F64x4/YACHT/YACHT1498.png
# Processado: YACHT1499.png -> DDPM-F64x4/YACHT/YACHT1499.png
# Processado: YACHT15.png -> DDPM-F64x4/YACHT/YACHT15.png
# Processado: YACHT150.png -> DDPM-F64x4/YACHT/YACHT150.png
# Processado: YACHT1500.png -> DDPM-F64x4/YACHT/YACHT1500.png
# Processado: YACHT1501.png -> DDPM-F64x4/YACHT/YACHT1501.png
# Processado: YACHT1502.png -> DDPM-F64x4/YACHT/YACHT1502.png
# Processado: YACHT1503.png -> DDPM-F64x4/YACHT/YACHT1503.png
# Processado: YACHT1504.png -> DDPM-F64x4/YACHT/YACHT1504.png
# Processado: YACHT1505.png -> DDPM-F64x4/YACHT/YACHT1505.png
# Processado: YACHT1506.png -> DDPM-F64x4/YACHT/YACHT1506.png
# Processado: YACHT1507.png -> DDPM-F64x4/YACHT/YACHT1507.png
# Processado: YACHT1508.png -> DDPM-F64x4/YACHT/YACHT1508.png
# Processado: YACHT1509.png -> DDPM-F64x4/YACHT/YACHT1509.png
# Processado: YACHT151.png -> DDPM-F64x4/YACHT/YACHT151.png
# Processado: YACHT1510.png -> DDPM-F64x4/YACHT/YACHT1510.png
# Processado: YACHT1511.png -> DDPM-F64x4/YACHT/YACHT1511.png
# Processado: YACHT1512.png -> DDPM-F64x4/YACHT/YACHT1512.png
# Processado: YACHT1513.png -> DDPM-F64x4/YACHT/YACHT1513.png
# Processado: YACHT1514.png -> DDPM-F64x4/YACHT/YACHT1514.png
# Processado: YACHT1515.png -> DDPM-F64x4/YACHT/YACHT1515.png
# Processado: YACHT1516.png -> DDPM-F64x4/YACHT/YACHT1516.png
# Processado: YACHT1517.png -> DDPM-F64x4/YACHT/YACHT1517.png
# Processado: YACHT1518.png -> DDPM-F64x4/YACHT/YACHT1518.png
# Processado: YACHT1519.png -> DDPM-F64x4/YACHT/YACHT1519.png
# Processado: YACHT152.png -> DDPM-F64x4/YACHT/YACHT152.png
# Processado: YACHT1520.png -> DDPM-F64x4/YACHT/YACHT1520.png
# Processado: YACHT1521.png -> DDPM-F64x4/YACHT/YACHT1521.png
# Processado: YACHT1522.png -> DDPM-F64x4/YACHT/YACHT1522.png
# Processado: YACHT1523.png -> DDPM-F64x4/YACHT/YACHT1523.png
# Processado: YACHT1524.png -> DDPM-F64x4/YACHT/YACHT1524.png
# Processado: YACHT1525.png -> DDPM-F64x4/YACHT/YACHT1525.png
# Processado: YACHT1526.png -> DDPM-F64x4/YACHT/YACHT1526.png
# Processado: YACHT1527.png -> DDPM-F64x4/YACHT/YACHT1527.png
# Processado: YACHT1528.png -> DDPM-F64x4/YACHT/YACHT1528.png
# Processado: YACHT1529.png -> DDPM-F64x4/YACHT/YACHT1529.png
# Processado: YACHT153.png -> DDPM-F64x4/YACHT/YACHT153.png
# Processado: YACHT1530.png -> DDPM-F64x4/YACHT/YACHT1530.png
# Processado: YACHT1531.png -> DDPM-F64x4/YACHT/YACHT1531.png
# Processado: YACHT1532.png -> DDPM-F64x4/YACHT/YACHT1532.png
# Processado: YACHT1533.png -> DDPM-F64x4/YACHT/YACHT1533.png
# Processado: YACHT1534.png -> DDPM-F64x4/YACHT/YACHT1534.png
# Processado: YACHT1535.png -> DDPM-F64x4/YACHT/YACHT1535.png
# Processado: YACHT1536.png -> DDPM-F64x4/YACHT/YACHT1536.png
# Processado: YACHT1537.png -> DDPM-F64x4/YACHT/YACHT1537.png
# Processado: YACHT1538.png -> DDPM-F64x4/YACHT/YACHT1538.png
# Processado: YACHT1539.png -> DDPM-F64x4/YACHT/YACHT1539.png
# Processado: YACHT154.png -> DDPM-F64x4/YACHT/YACHT154.png
# Processado: YACHT1540.png -> DDPM-F64x4/YACHT/YACHT1540.png
# Processado: YACHT1541.png -> DDPM-F64x4/YACHT/YACHT1541.png
# Processado: YACHT1542.png -> DDPM-F64x4/YACHT/YACHT1542.png
# Processado: YACHT1543.png -> DDPM-F64x4/YACHT/YACHT1543.png
# Processado: YACHT1544.png -> DDPM-F64x4/YACHT/YACHT1544.png
# Processado: YACHT1545.png -> DDPM-F64x4/YACHT/YACHT1545.png
# Processado: YACHT1546.png -> DDPM-F64x4/YACHT/YACHT1546.png
# Processado: YACHT1547.png -> DDPM-F64x4/YACHT/YACHT1547.png
# Processado: YACHT1548.png -> DDPM-F64x4/YACHT/YACHT1548.png
# Processado: YACHT1549.png -> DDPM-F64x4/YACHT/YACHT1549.png
# Processado: YACHT155.png -> DDPM-F64x4/YACHT/YACHT155.png
# Processado: YACHT1550.png -> DDPM-F64x4/YACHT/YACHT1550.png
# Processado: YACHT1551.png -> DDPM-F64x4/YACHT/YACHT1551.png
# Processado: YACHT1552.png -> DDPM-F64x4/YACHT/YACHT1552.png
# Processado: YACHT1553.png -> DDPM-F64x4/YACHT/YACHT1553.png
# Processado: YACHT1554.png -> DDPM-F64x4/YACHT/YACHT1554.png
# Processado: YACHT1555.png -> DDPM-F64x4/YACHT/YACHT1555.png
# Processado: YACHT1556.png -> DDPM-F64x4/YACHT/YACHT1556.png
# Processado: YACHT1557.png -> DDPM-F64x4/YACHT/YACHT1557.png
# Processado: YACHT1558.png -> DDPM-F64x4/YACHT/YACHT1558.png
# Processado: YACHT1559.png -> DDPM-F64x4/YACHT/YACHT1559.png
# Processado: YACHT156.png -> DDPM-F64x4/YACHT/YACHT156.png
# Processado: YACHT1560.png -> DDPM-F64x4/YACHT/YACHT1560.png
# Processado: YACHT1561.png -> DDPM-F64x4/YACHT/YACHT1561.png
# Processado: YACHT1562.png -> DDPM-F64x4/YACHT/YACHT1562.png
# Processado: YACHT1563.png -> DDPM-F64x4/YACHT/YACHT1563.png
# Processado: YACHT1564.png -> DDPM-F64x4/YACHT/YACHT1564.png
# Processado: YACHT1565.png -> DDPM-F64x4/YACHT/YACHT1565.png
# Processado: YACHT1566.png -> DDPM-F64x4/YACHT/YACHT1566.png
# Processado: YACHT1567.png -> DDPM-F64x4/YACHT/YACHT1567.png
# Processado: YACHT1568.png -> DDPM-F64x4/YACHT/YACHT1568.png
# Processado: YACHT1569.png -> DDPM-F64x4/YACHT/YACHT1569.png
# Processado: YACHT157.png -> DDPM-F64x4/YACHT/YACHT157.png
# Processado: YACHT1570.png -> DDPM-F64x4/YACHT/YACHT1570.png
# Processado: YACHT1571.png -> DDPM-F64x4/YACHT/YACHT1571.png
# Processado: YACHT1572.png -> DDPM-F64x4/YACHT/YACHT1572.png
# Processado: YACHT1573.png -> DDPM-F64x4/YACHT/YACHT1573.png
# Processado: YACHT1574.png -> DDPM-F64x4/YACHT/YACHT1574.png
# Processado: YACHT1575.png -> DDPM-F64x4/YACHT/YACHT1575.png
# Processado: YACHT1576.png -> DDPM-F64x4/YACHT/YACHT1576.png
# Processado: YACHT1577.png -> DDPM-F64x4/YACHT/YACHT1577.png
# Processado: YACHT1578.png -> DDPM-F64x4/YACHT/YACHT1578.png
# Processado: YACHT1579.png -> DDPM-F64x4/YACHT/YACHT1579.png
# Processado: YACHT158.png -> DDPM-F64x4/YACHT/YACHT158.png
# Processado: YACHT1580.png -> DDPM-F64x4/YACHT/YACHT1580.png
# Processado: YACHT1581.png -> DDPM-F64x4/YACHT/YACHT1581.png
# Processado: YACHT1582.png -> DDPM-F64x4/YACHT/YACHT1582.png
# Processado: YACHT1583.png -> DDPM-F64x4/YACHT/YACHT1583.png
# Processado: YACHT1584.png -> DDPM-F64x4/YACHT/YACHT1584.png
# Processado: YACHT1585.png -> DDPM-F64x4/YACHT/YACHT1585.png
# Processado: YACHT1586.png -> DDPM-F64x4/YACHT/YACHT1586.png
# Processado: YACHT1587.png -> DDPM-F64x4/YACHT/YACHT1587.png
# Processado: YACHT1588.png -> DDPM-F64x4/YACHT/YACHT1588.png
# Processado: YACHT1589.png -> DDPM-F64x4/YACHT/YACHT1589.png
# Processado: YACHT159.png -> DDPM-F64x4/YACHT/YACHT159.png
# Processado: YACHT1590.png -> DDPM-F64x4/YACHT/YACHT1590.png
# Processado: YACHT1591.png -> DDPM-F64x4/YACHT/YACHT1591.png
# Processado: YACHT1592.png -> DDPM-F64x4/YACHT/YACHT1592.png
# Processado: YACHT1593.png -> DDPM-F64x4/YACHT/YACHT1593.png
# Processado: YACHT1594.png -> DDPM-F64x4/YACHT/YACHT1594.png
# Processado: YACHT1595.png -> DDPM-F64x4/YACHT/YACHT1595.png
# Processado: YACHT1596.png -> DDPM-F64x4/YACHT/YACHT1596.png
# Processado: YACHT1597.png -> DDPM-F64x4/YACHT/YACHT1597.png
# Processado: YACHT1598.png -> DDPM-F64x4/YACHT/YACHT1598.png
# Processado: YACHT1599.png -> DDPM-F64x4/YACHT/YACHT1599.png
# Processado: YACHT16.png -> DDPM-F64x4/YACHT/YACHT16.png
# Processado: YACHT160.png -> DDPM-F64x4/YACHT/YACHT160.png
# Processado: YACHT1600.png -> DDPM-F64x4/YACHT/YACHT1600.png
# Processado: YACHT1601.png -> DDPM-F64x4/YACHT/YACHT1601.png
# Processado: YACHT1602.png -> DDPM-F64x4/YACHT/YACHT1602.png
# Processado: YACHT1603.png -> DDPM-F64x4/YACHT/YACHT1603.png
# Processado: YACHT1604.png -> DDPM-F64x4/YACHT/YACHT1604.png
# Processado: YACHT1605.png -> DDPM-F64x4/YACHT/YACHT1605.png
# Processado: YACHT1606.png -> DDPM-F64x4/YACHT/YACHT1606.png
# Processado: YACHT1607.png -> DDPM-F64x4/YACHT/YACHT1607.png
# Processado: YACHT1608.png -> DDPM-F64x4/YACHT/YACHT1608.png
# Processado: YACHT1609.png -> DDPM-F64x4/YACHT/YACHT1609.png
# Processado: YACHT161.png -> DDPM-F64x4/YACHT/YACHT161.png
# Processado: YACHT1610.png -> DDPM-F64x4/YACHT/YACHT1610.png
# Processado: YACHT1611.png -> DDPM-F64x4/YACHT/YACHT1611.png
# Processado: YACHT1612.png -> DDPM-F64x4/YACHT/YACHT1612.png
# Processado: YACHT1613.png -> DDPM-F64x4/YACHT/YACHT1613.png
# Processado: YACHT1614.png -> DDPM-F64x4/YACHT/YACHT1614.png
# Processado: YACHT1615.png -> DDPM-F64x4/YACHT/YACHT1615.png
# Processado: YACHT1616.png -> DDPM-F64x4/YACHT/YACHT1616.png
# Processado: YACHT1617.png -> DDPM-F64x4/YACHT/YACHT1617.png
# Processado: YACHT1618.png -> DDPM-F64x4/YACHT/YACHT1618.png
# Processado: YACHT1619.png -> DDPM-F64x4/YACHT/YACHT1619.png
# Processado: YACHT162.png -> DDPM-F64x4/YACHT/YACHT162.png
# Processado: YACHT1620.png -> DDPM-F64x4/YACHT/YACHT1620.png
# Processado: YACHT1621.png -> DDPM-F64x4/YACHT/YACHT1621.png
# Processado: YACHT1622.png -> DDPM-F64x4/YACHT/YACHT1622.png
# Processado: YACHT1623.png -> DDPM-F64x4/YACHT/YACHT1623.png
# Processado: YACHT1624.png -> DDPM-F64x4/YACHT/YACHT1624.png
# Processado: YACHT1625.png -> DDPM-F64x4/YACHT/YACHT1625.png
# Processado: YACHT1626.png -> DDPM-F64x4/YACHT/YACHT1626.png
# Processado: YACHT1627.png -> DDPM-F64x4/YACHT/YACHT1627.png
# Processado: YACHT1628.png -> DDPM-F64x4/YACHT/YACHT1628.png
# Processado: YACHT1629.png -> DDPM-F64x4/YACHT/YACHT1629.png
# Processado: YACHT163.png -> DDPM-F64x4/YACHT/YACHT163.png
# Processado: YACHT1630.png -> DDPM-F64x4/YACHT/YACHT1630.png
# Processado: YACHT1631.png -> DDPM-F64x4/YACHT/YACHT1631.png
# Processado: YACHT1632.png -> DDPM-F64x4/YACHT/YACHT1632.png
# Processado: YACHT1633.png -> DDPM-F64x4/YACHT/YACHT1633.png
# Processado: YACHT1634.png -> DDPM-F64x4/YACHT/YACHT1634.png
# Processado: YACHT1635.png -> DDPM-F64x4/YACHT/YACHT1635.png
# Processado: YACHT1636.png -> DDPM-F64x4/YACHT/YACHT1636.png
# Processado: YACHT1637.png -> DDPM-F64x4/YACHT/YACHT1637.png
# Processado: YACHT1638.png -> DDPM-F64x4/YACHT/YACHT1638.png
# Processado: YACHT1639.png -> DDPM-F64x4/YACHT/YACHT1639.png
# Processado: YACHT164.png -> DDPM-F64x4/YACHT/YACHT164.png
# Processado: YACHT1640.png -> DDPM-F64x4/YACHT/YACHT1640.png
# Processado: YACHT1641.png -> DDPM-F64x4/YACHT/YACHT1641.png
# Processado: YACHT1642.png -> DDPM-F64x4/YACHT/YACHT1642.png
# Processado: YACHT1643.png -> DDPM-F64x4/YACHT/YACHT1643.png
# Processado: YACHT1644.png -> DDPM-F64x4/YACHT/YACHT1644.png
# Processado: YACHT1645.png -> DDPM-F64x4/YACHT/YACHT1645.png
# Processado: YACHT1646.png -> DDPM-F64x4/YACHT/YACHT1646.png
# Processado: YACHT1647.png -> DDPM-F64x4/YACHT/YACHT1647.png
# Processado: YACHT1648.png -> DDPM-F64x4/YACHT/YACHT1648.png
# Processado: YACHT1649.png -> DDPM-F64x4/YACHT/YACHT1649.png
# Processado: YACHT165.png -> DDPM-F64x4/YACHT/YACHT165.png
# Processado: YACHT1650.png -> DDPM-F64x4/YACHT/YACHT1650.png
# Processado: YACHT1651.png -> DDPM-F64x4/YACHT/YACHT1651.png
# Processado: YACHT1652.png -> DDPM-F64x4/YACHT/YACHT1652.png
# Processado: YACHT1653.png -> DDPM-F64x4/YACHT/YACHT1653.png
# Processado: YACHT1654.png -> DDPM-F64x4/YACHT/YACHT1654.png
# Processado: YACHT1655.png -> DDPM-F64x4/YACHT/YACHT1655.png
# Processado: YACHT1656.png -> DDPM-F64x4/YACHT/YACHT1656.png
# Processado: YACHT1657.png -> DDPM-F64x4/YACHT/YACHT1657.png
# Processado: YACHT1658.png -> DDPM-F64x4/YACHT/YACHT1658.png
# Processado: YACHT1659.png -> DDPM-F64x4/YACHT/YACHT1659.png
# Processado: YACHT166.png -> DDPM-F64x4/YACHT/YACHT166.png
# Processado: YACHT1660.png -> DDPM-F64x4/YACHT/YACHT1660.png
# Processado: YACHT1661.png -> DDPM-F64x4/YACHT/YACHT1661.png
# Processado: YACHT1662.png -> DDPM-F64x4/YACHT/YACHT1662.png
# Processado: YACHT1663.png -> DDPM-F64x4/YACHT/YACHT1663.png
# Processado: YACHT1664.png -> DDPM-F64x4/YACHT/YACHT1664.png
# Processado: YACHT1665.png -> DDPM-F64x4/YACHT/YACHT1665.png
# Processado: YACHT1666.png -> DDPM-F64x4/YACHT/YACHT1666.png
# Processado: YACHT1667.png -> DDPM-F64x4/YACHT/YACHT1667.png
# Processado: YACHT1668.png -> DDPM-F64x4/YACHT/YACHT1668.png
# Processado: YACHT1669.png -> DDPM-F64x4/YACHT/YACHT1669.png
# Processado: YACHT167.png -> DDPM-F64x4/YACHT/YACHT167.png
# Processado: YACHT1670.png -> DDPM-F64x4/YACHT/YACHT1670.png
# Processado: YACHT1671.png -> DDPM-F64x4/YACHT/YACHT1671.png
# Processado: YACHT1672.png -> DDPM-F64x4/YACHT/YACHT1672.png
# Processado: YACHT1673.png -> DDPM-F64x4/YACHT/YACHT1673.png
# Processado: YACHT1674.png -> DDPM-F64x4/YACHT/YACHT1674.png
# Processado: YACHT1675.png -> DDPM-F64x4/YACHT/YACHT1675.png
# Processado: YACHT1676.png -> DDPM-F64x4/YACHT/YACHT1676.png
# Processado: YACHT1677.png -> DDPM-F64x4/YACHT/YACHT1677.png
# Processado: YACHT1678.png -> DDPM-F64x4/YACHT/YACHT1678.png
# Processado: YACHT1679.png -> DDPM-F64x4/YACHT/YACHT1679.png
# Processado: YACHT168.png -> DDPM-F64x4/YACHT/YACHT168.png
# Processado: YACHT1680.png -> DDPM-F64x4/YACHT/YACHT1680.png
# Processado: YACHT1681.png -> DDPM-F64x4/YACHT/YACHT1681.png
# Processado: YACHT1682.png -> DDPM-F64x4/YACHT/YACHT1682.png
# Processado: YACHT1683.png -> DDPM-F64x4/YACHT/YACHT1683.png
# Processado: YACHT1684.png -> DDPM-F64x4/YACHT/YACHT1684.png
# Processado: YACHT1685.png -> DDPM-F64x4/YACHT/YACHT1685.png
# Processado: YACHT1686.png -> DDPM-F64x4/YACHT/YACHT1686.png
# Processado: YACHT1687.png -> DDPM-F64x4/YACHT/YACHT1687.png
# Processado: YACHT1688.png -> DDPM-F64x4/YACHT/YACHT1688.png
# Processado: YACHT1689.png -> DDPM-F64x4/YACHT/YACHT1689.png
# Processado: YACHT169.png -> DDPM-F64x4/YACHT/YACHT169.png
# Processado: YACHT1690.png -> DDPM-F64x4/YACHT/YACHT1690.png
# Processado: YACHT1691.png -> DDPM-F64x4/YACHT/YACHT1691.png
# Processado: YACHT1692.png -> DDPM-F64x4/YACHT/YACHT1692.png
# Processado: YACHT1693.png -> DDPM-F64x4/YACHT/YACHT1693.png
# Processado: YACHT1694.png -> DDPM-F64x4/YACHT/YACHT1694.png
# Processado: YACHT1695.png -> DDPM-F64x4/YACHT/YACHT1695.png
# Processado: YACHT1696.png -> DDPM-F64x4/YACHT/YACHT1696.png
# Processado: YACHT1697.png -> DDPM-F64x4/YACHT/YACHT1697.png
# Processado: YACHT1698.png -> DDPM-F64x4/YACHT/YACHT1698.png
# Processado: YACHT1699.png -> DDPM-F64x4/YACHT/YACHT1699.png
# Processado: YACHT17.png -> DDPM-F64x4/YACHT/YACHT17.png
# Processado: YACHT170.png -> DDPM-F64x4/YACHT/YACHT170.png
# Processado: YACHT1700.png -> DDPM-F64x4/YACHT/YACHT1700.png
# Processado: YACHT1701.png -> DDPM-F64x4/YACHT/YACHT1701.png
# Processado: YACHT1702.png -> DDPM-F64x4/YACHT/YACHT1702.png
# Processado: YACHT1703.png -> DDPM-F64x4/YACHT/YACHT1703.png
# Processado: YACHT1704.png -> DDPM-F64x4/YACHT/YACHT1704.png
# Processado: YACHT1705.png -> DDPM-F64x4/YACHT/YACHT1705.png
# Processado: YACHT1706.png -> DDPM-F64x4/YACHT/YACHT1706.png
# Processado: YACHT1707.png -> DDPM-F64x4/YACHT/YACHT1707.png
# Processado: YACHT1708.png -> DDPM-F64x4/YACHT/YACHT1708.png
# Processado: YACHT1709.png -> DDPM-F64x4/YACHT/YACHT1709.png
# Processado: YACHT171.png -> DDPM-F64x4/YACHT/YACHT171.png
# Processado: YACHT1710.png -> DDPM-F64x4/YACHT/YACHT1710.png
# Processado: YACHT1711.png -> DDPM-F64x4/YACHT/YACHT1711.png
# Processado: YACHT1712.png -> DDPM-F64x4/YACHT/YACHT1712.png
# Processado: YACHT1713.png -> DDPM-F64x4/YACHT/YACHT1713.png
# Processado: YACHT1714.png -> DDPM-F64x4/YACHT/YACHT1714.png
# Processado: YACHT1715.png -> DDPM-F64x4/YACHT/YACHT1715.png
# Processado: YACHT1716.png -> DDPM-F64x4/YACHT/YACHT1716.png
# Processado: YACHT1717.png -> DDPM-F64x4/YACHT/YACHT1717.png
# Processado: YACHT1718.png -> DDPM-F64x4/YACHT/YACHT1718.png
# Processado: YACHT1719.png -> DDPM-F64x4/YACHT/YACHT1719.png
# Processado: YACHT172.png -> DDPM-F64x4/YACHT/YACHT172.png
# ...
# Processado: YACHT750.png -> DDPM-F64x4/YACHT/YACHT750.png
# Processado: YACHT751.png -> DDPM-F64x4/YACHT/YACHT751.png
# Processado: YACHT752.png -> DDPM-F64x4/YACHT/YACHT752.png
# Processado: YACHT753.png -> DDPM-F64x4/YACHT/YACHT753.png
# Processado: YACHT754.png -> DDPM-F64x4/YACHT/YACHT754.png
# Processado: YACHT755.png -> DDPM-F64x4/YACHT/YACHT755.png
# Processado: YACHT756.png -> DDPM-F64x4/YACHT/YACHT756.png
# Processado: YACHT757.png -> DDPM-F64x4/YACHT/YACHT757.png
# Processado: YACHT758.png -> DDPM-F64x4/YACHT/YACHT758.png
# Processado: YACHT759.png -> DDPM-F64x4/YACHT/YACHT759.png
# Processado: YACHT76.png -> DDPM-F64x4/YACHT/YACHT76.png
# Processado: YACHT760.png -> DDPM-F64x4/YACHT/YACHT760.png
# Processado: YACHT761.png -> DDPM-F64x4/YACHT/YACHT761.png
# Processado: YACHT762.png -> DDPM-F64x4/YACHT/YACHT762.png
# Processado: YACHT763.png -> DDPM-F64x4/YACHT/YACHT763.png
# Processado: YACHT764.png -> DDPM-F64x4/YACHT/YACHT764.png
# Processado: YACHT765.png -> DDPM-F64x4/YACHT/YACHT765.png
# Processado: YACHT766.png -> DDPM-F64x4/YACHT/YACHT766.png
# Processado: YACHT767.png -> DDPM-F64x4/YACHT/YACHT767.png
# Processado: YACHT768.png -> DDPM-F64x4/YACHT/YACHT768.png
# Processado: YACHT769.png -> DDPM-F64x4/YACHT/YACHT769.png
# Processado: YACHT77.png -> DDPM-F64x4/YACHT/YACHT77.png
# Processado: YACHT770.png -> DDPM-F64x4/YACHT/YACHT770.png
# Processado: YACHT771.png -> DDPM-F64x4/YACHT/YACHT771.png
# Processado: YACHT772.png -> DDPM-F64x4/YACHT/YACHT772.png
# Processado: YACHT773.png -> DDPM-F64x4/YACHT/YACHT773.png
# Processado: YACHT774.png -> DDPM-F64x4/YACHT/YACHT774.png
# Processado: YACHT775.png -> DDPM-F64x4/YACHT/YACHT775.png
# Processado: YACHT776.png -> DDPM-F64x4/YACHT/YACHT776.png
# Processado: YACHT777.png -> DDPM-F64x4/YACHT/YACHT777.png
# Processado: YACHT778.png -> DDPM-F64x4/YACHT/YACHT778.png
# Processado: YACHT779.png -> DDPM-F64x4/YACHT/YACHT779.png
# Processado: YACHT78.png -> DDPM-F64x4/YACHT/YACHT78.png
# Processado: YACHT780.png -> DDPM-F64x4/YACHT/YACHT780.png
# Processado: YACHT781.png -> DDPM-F64x4/YACHT/YACHT781.png
# Processado: YACHT782.png -> DDPM-F64x4/YACHT/YACHT782.png
# Processado: YACHT783.png -> DDPM-F64x4/YACHT/YACHT783.png
# Processado: YACHT784.png -> DDPM-F64x4/YACHT/YACHT784.png
# Processado: YACHT785.png -> DDPM-F64x4/YACHT/YACHT785.png
# Processado: YACHT786.png -> DDPM-F64x4/YACHT/YACHT786.png
# Processado: YACHT787.png -> DDPM-F64x4/YACHT/YACHT787.png
# Processado: YACHT788.png -> DDPM-F64x4/YACHT/YACHT788.png
# Processado: YACHT789.png -> DDPM-F64x4/YACHT/YACHT789.png
# Processado: YACHT79.png -> DDPM-F64x4/YACHT/YACHT79.png
# Processado: YACHT790.png -> DDPM-F64x4/YACHT/YACHT790.png
# Processado: YACHT791.png -> DDPM-F64x4/YACHT/YACHT791.png
# Processado: YACHT792.png -> DDPM-F64x4/YACHT/YACHT792.png
# Processado: YACHT793.png -> DDPM-F64x4/YACHT/YACHT793.png
# Processado: YACHT794.png -> DDPM-F64x4/YACHT/YACHT794.png
# Processado: YACHT795.png -> DDPM-F64x4/YACHT/YACHT795.png
# Processado: YACHT796.png -> DDPM-F64x4/YACHT/YACHT796.png
# Processado: YACHT797.png -> DDPM-F64x4/YACHT/YACHT797.png
# Processado: YACHT798.png -> DDPM-F64x4/YACHT/YACHT798.png
# Processado: YACHT799.png -> DDPM-F64x4/YACHT/YACHT799.png
# Processado: YACHT8.png -> DDPM-F64x4/YACHT/YACHT8.png
# Processado: YACHT80.png -> DDPM-F64x4/YACHT/YACHT80.png
# Processado: YACHT800.png -> DDPM-F64x4/YACHT/YACHT800.png
# Processado: YACHT801.png -> DDPM-F64x4/YACHT/YACHT801.png
# Processado: YACHT802.png -> DDPM-F64x4/YACHT/YACHT802.png
# Processado: YACHT803.png -> DDPM-F64x4/YACHT/YACHT803.png
# Processado: YACHT804.png -> DDPM-F64x4/YACHT/YACHT804.png
# Processado: YACHT805.png -> DDPM-F64x4/YACHT/YACHT805.png
# Processado: YACHT806.png -> DDPM-F64x4/YACHT/YACHT806.png
# Processado: YACHT807.png -> DDPM-F64x4/YACHT/YACHT807.png
# Processado: YACHT808.png -> DDPM-F64x4/YACHT/YACHT808.png
# Processado: YACHT809.png -> DDPM-F64x4/YACHT/YACHT809.png
# Processado: YACHT81.png -> DDPM-F64x4/YACHT/YACHT81.png
# Processado: YACHT810.png -> DDPM-F64x4/YACHT/YACHT810.png
# Processado: YACHT811.png -> DDPM-F64x4/YACHT/YACHT811.png
# Processado: YACHT812.png -> DDPM-F64x4/YACHT/YACHT812.png
# Processado: YACHT813.png -> DDPM-F64x4/YACHT/YACHT813.png
# Processado: YACHT814.png -> DDPM-F64x4/YACHT/YACHT814.png
# Processado: YACHT815.png -> DDPM-F64x4/YACHT/YACHT815.png
# Processado: YACHT816.png -> DDPM-F64x4/YACHT/YACHT816.png
# Processado: YACHT817.png -> DDPM-F64x4/YACHT/YACHT817.png
# Processado: YACHT818.png -> DDPM-F64x4/YACHT/YACHT818.png
# Processado: YACHT819.png -> DDPM-F64x4/YACHT/YACHT819.png
# Processado: YACHT82.png -> DDPM-F64x4/YACHT/YACHT82.png
# Processado: YACHT820.png -> DDPM-F64x4/YACHT/YACHT820.png
# Processado: YACHT821.png -> DDPM-F64x4/YACHT/YACHT821.png
# Processado: YACHT822.png -> DDPM-F64x4/YACHT/YACHT822.png
# Processado: YACHT823.png -> DDPM-F64x4/YACHT/YACHT823.png
# Processado: YACHT824.png -> DDPM-F64x4/YACHT/YACHT824.png
# Processado: YACHT825.png -> DDPM-F64x4/YACHT/YACHT825.png
# Processado: YACHT826.png -> DDPM-F64x4/YACHT/YACHT826.png
# Processado: YACHT827.png -> DDPM-F64x4/YACHT/YACHT827.png
# Processado: YACHT828.png -> DDPM-F64x4/YACHT/YACHT828.png
# Processado: YACHT829.png -> DDPM-F64x4/YACHT/YACHT829.png
# Processado: YACHT83.png -> DDPM-F64x4/YACHT/YACHT83.png
# Processado: YACHT830.png -> DDPM-F64x4/YACHT/YACHT830.png
# Processado: YACHT831.png -> DDPM-F64x4/YACHT/YACHT831.png
# Processado: YACHT832.png -> DDPM-F64x4/YACHT/YACHT832.png
# Processado: YACHT833.png -> DDPM-F64x4/YACHT/YACHT833.png
# Processado: YACHT834.png -> DDPM-F64x4/YACHT/YACHT834.png
# Processado: YACHT835.png -> DDPM-F64x4/YACHT/YACHT835.png
# Processado: YACHT836.png -> DDPM-F64x4/YACHT/YACHT836.png
# Processado: YACHT837.png -> DDPM-F64x4/YACHT/YACHT837.png
# Processado: YACHT838.png -> DDPM-F64x4/YACHT/YACHT838.png
# Processado: YACHT839.png -> DDPM-F64x4/YACHT/YACHT839.png
# Processado: YACHT84.png -> DDPM-F64x4/YACHT/YACHT84.png
# Processado: YACHT840.png -> DDPM-F64x4/YACHT/YACHT840.png
# Processado: YACHT841.png -> DDPM-F64x4/YACHT/YACHT841.png
# Processado: YACHT842.png -> DDPM-F64x4/YACHT/YACHT842.png
# Processado: YACHT843.png -> DDPM-F64x4/YACHT/YACHT843.png
# Processado: YACHT844.png -> DDPM-F64x4/YACHT/YACHT844.png
# Processado: YACHT845.png -> DDPM-F64x4/YACHT/YACHT845.png
# Processado: YACHT846.png -> DDPM-F64x4/YACHT/YACHT846.png
# Processado: YACHT847.png -> DDPM-F64x4/YACHT/YACHT847.png
# Processado: YACHT848.png -> DDPM-F64x4/YACHT/YACHT848.png
# Processado: YACHT849.png -> DDPM-F64x4/YACHT/YACHT849.png
# Processado: YACHT85.png -> DDPM-F64x4/YACHT/YACHT85.png
# Processado: YACHT850.png -> DDPM-F64x4/YACHT/YACHT850.png
# Processado: YACHT851.png -> DDPM-F64x4/YACHT/YACHT851.png
# Processado: YACHT852.png -> DDPM-F64x4/YACHT/YACHT852.png
# Processado: YACHT853.png -> DDPM-F64x4/YACHT/YACHT853.png
# Processado: YACHT854.png -> DDPM-F64x4/YACHT/YACHT854.png
# Processado: YACHT855.png -> DDPM-F64x4/YACHT/YACHT855.png
# Processado: YACHT856.png -> DDPM-F64x4/YACHT/YACHT856.png
# Processado: YACHT857.png -> DDPM-F64x4/YACHT/YACHT857.png
# Processado: YACHT858.png -> DDPM-F64x4/YACHT/YACHT858.png
# Processado: YACHT859.png -> DDPM-F64x4/YACHT/YACHT859.png
# Processado: YACHT86.png -> DDPM-F64x4/YACHT/YACHT86.png
# Processado: YACHT860.png -> DDPM-F64x4/YACHT/YACHT860.png
# Processado: YACHT861.png -> DDPM-F64x4/YACHT/YACHT861.png
# Processado: YACHT862.png -> DDPM-F64x4/YACHT/YACHT862.png
# Processado: YACHT863.png -> DDPM-F64x4/YACHT/YACHT863.png
# Processado: YACHT864.png -> DDPM-F64x4/YACHT/YACHT864.png
# Processado: YACHT865.png -> DDPM-F64x4/YACHT/YACHT865.png
# Processado: YACHT866.png -> DDPM-F64x4/YACHT/YACHT866.png
# Processado: YACHT867.png -> DDPM-F64x4/YACHT/YACHT867.png
# Processado: YACHT868.png -> DDPM-F64x4/YACHT/YACHT868.png
# Processado: YACHT869.png -> DDPM-F64x4/YACHT/YACHT869.png
# Processado: YACHT87.png -> DDPM-F64x4/YACHT/YACHT87.png
# Processado: YACHT870.png -> DDPM-F64x4/YACHT/YACHT870.png
# Processado: YACHT871.png -> DDPM-F64x4/YACHT/YACHT871.png
# Processado: YACHT872.png -> DDPM-F64x4/YACHT/YACHT872.png
# Processado: YACHT873.png -> DDPM-F64x4/YACHT/YACHT873.png
# Processado: YACHT874.png -> DDPM-F64x4/YACHT/YACHT874.png
# Processado: YACHT875.png -> DDPM-F64x4/YACHT/YACHT875.png
# Processado: YACHT876.png -> DDPM-F64x4/YACHT/YACHT876.png
# Processado: YACHT877.png -> DDPM-F64x4/YACHT/YACHT877.png
# Processado: YACHT878.png -> DDPM-F64x4/YACHT/YACHT878.png
# Processado: YACHT879.png -> DDPM-F64x4/YACHT/YACHT879.png
# Processado: YACHT88.png -> DDPM-F64x4/YACHT/YACHT88.png
# Processado: YACHT880.png -> DDPM-F64x4/YACHT/YACHT880.png
# Processado: YACHT881.png -> DDPM-F64x4/YACHT/YACHT881.png
# Processado: YACHT882.png -> DDPM-F64x4/YACHT/YACHT882.png
# Processado: YACHT883.png -> DDPM-F64x4/YACHT/YACHT883.png
# Processado: YACHT884.png -> DDPM-F64x4/YACHT/YACHT884.png
# Processado: YACHT885.png -> DDPM-F64x4/YACHT/YACHT885.png
# Processado: YACHT886.png -> DDPM-F64x4/YACHT/YACHT886.png
# Processado: YACHT887.png -> DDPM-F64x4/YACHT/YACHT887.png
# Processado: YACHT888.png -> DDPM-F64x4/YACHT/YACHT888.png
# Processado: YACHT889.png -> DDPM-F64x4/YACHT/YACHT889.png
# Processado: YACHT89.png -> DDPM-F64x4/YACHT/YACHT89.png
# Processado: YACHT890.png -> DDPM-F64x4/YACHT/YACHT890.png
# Processado: YACHT891.png -> DDPM-F64x4/YACHT/YACHT891.png
# Processado: YACHT892.png -> DDPM-F64x4/YACHT/YACHT892.png
# Processado: YACHT893.png -> DDPM-F64x4/YACHT/YACHT893.png
# Processado: YACHT894.png -> DDPM-F64x4/YACHT/YACHT894.png
# Processado: YACHT895.png -> DDPM-F64x4/YACHT/YACHT895.png
# Processado: YACHT896.png -> DDPM-F64x4/YACHT/YACHT896.png
# Processado: YACHT897.png -> DDPM-F64x4/YACHT/YACHT897.png
# Processado: YACHT898.png -> DDPM-F64x4/YACHT/YACHT898.png
# Processado: YACHT899.png -> DDPM-F64x4/YACHT/YACHT899.png
# Processado: YACHT9.png -> DDPM-F64x4/YACHT/YACHT9.png
# Processado: YACHT90.png -> DDPM-F64x4/YACHT/YACHT90.png
# Processado: YACHT900.png -> DDPM-F64x4/YACHT/YACHT900.png
# Processado: YACHT901.png -> DDPM-F64x4/YACHT/YACHT901.png
# Processado: YACHT902.png -> DDPM-F64x4/YACHT/YACHT902.png
# Processado: YACHT903.png -> DDPM-F64x4/YACHT/YACHT903.png
# Processado: YACHT904.png -> DDPM-F64x4/YACHT/YACHT904.png
# Processado: YACHT905.png -> DDPM-F64x4/YACHT/YACHT905.png
# Processado: YACHT906.png -> DDPM-F64x4/YACHT/YACHT906.png
# Processado: YACHT907.png -> DDPM-F64x4/YACHT/YACHT907.png
# Processado: YACHT908.png -> DDPM-F64x4/YACHT/YACHT908.png
# Processado: YACHT909.png -> DDPM-F64x4/YACHT/YACHT909.png
# Processado: YACHT91.png -> DDPM-F64x4/YACHT/YACHT91.png
# Processado: YACHT910.png -> DDPM-F64x4/YACHT/YACHT910.png
# Processado: YACHT911.png -> DDPM-F64x4/YACHT/YACHT911.png
# Processado: YACHT912.png -> DDPM-F64x4/YACHT/YACHT912.png
# Processado: YACHT913.png -> DDPM-F64x4/YACHT/YACHT913.png
# Processado: YACHT914.png -> DDPM-F64x4/YACHT/YACHT914.png
# Processado: YACHT915.png -> DDPM-F64x4/YACHT/YACHT915.png
# Processado: YACHT916.png -> DDPM-F64x4/YACHT/YACHT916.png
# Processado: YACHT917.png -> DDPM-F64x4/YACHT/YACHT917.png
# Processado: YACHT918.png -> DDPM-F64x4/YACHT/YACHT918.png
# Processado: YACHT919.png -> DDPM-F64x4/YACHT/YACHT919.png
# Processado: YACHT92.png -> DDPM-F64x4/YACHT/YACHT92.png
# Processado: YACHT920.png -> DDPM-F64x4/YACHT/YACHT920.png
# Processado: YACHT921.png -> DDPM-F64x4/YACHT/YACHT921.png
# Processado: YACHT922.png -> DDPM-F64x4/YACHT/YACHT922.png
# Processado: YACHT923.png -> DDPM-F64x4/YACHT/YACHT923.png
# Processado: YACHT924.png -> DDPM-F64x4/YACHT/YACHT924.png
# Processado: YACHT925.png -> DDPM-F64x4/YACHT/YACHT925.png
# Processado: YACHT926.png -> DDPM-F64x4/YACHT/YACHT926.png
# Processado: YACHT927.png -> DDPM-F64x4/YACHT/YACHT927.png
# Processado: YACHT928.png -> DDPM-F64x4/YACHT/YACHT928.png
# Processado: YACHT929.png -> DDPM-F64x4/YACHT/YACHT929.png
# Processado: YACHT93.png -> DDPM-F64x4/YACHT/YACHT93.png
# Processado: YACHT930.png -> DDPM-F64x4/YACHT/YACHT930.png
# Processado: YACHT931.png -> DDPM-F64x4/YACHT/YACHT931.png
# Processado: YACHT932.png -> DDPM-F64x4/YACHT/YACHT932.png
# Processado: YACHT933.png -> DDPM-F64x4/YACHT/YACHT933.png
# Processado: YACHT934.png -> DDPM-F64x4/YACHT/YACHT934.png
# Processado: YACHT935.png -> DDPM-F64x4/YACHT/YACHT935.png
# Processado: YACHT936.png -> DDPM-F64x4/YACHT/YACHT936.png
# Processado: YACHT937.png -> DDPM-F64x4/YACHT/YACHT937.png
# Processado: YACHT938.png -> DDPM-F64x4/YACHT/YACHT938.png
# Processado: YACHT939.png -> DDPM-F64x4/YACHT/YACHT939.png
# Processado: YACHT94.png -> DDPM-F64x4/YACHT/YACHT94.png
# Processado: YACHT940.png -> DDPM-F64x4/YACHT/YACHT940.png
# Processado: YACHT941.png -> DDPM-F64x4/YACHT/YACHT941.png
# Processado: YACHT942.png -> DDPM-F64x4/YACHT/YACHT942.png
# Processado: YACHT943.png -> DDPM-F64x4/YACHT/YACHT943.png
# Processado: YACHT944.png -> DDPM-F64x4/YACHT/YACHT944.png
# Processado: YACHT945.png -> DDPM-F64x4/YACHT/YACHT945.png
# Processado: YACHT946.png -> DDPM-F64x4/YACHT/YACHT946.png
# Processado: YACHT947.png -> DDPM-F64x4/YACHT/YACHT947.png
# Processado: YACHT948.png -> DDPM-F64x4/YACHT/YACHT948.png
# Processado: YACHT949.png -> DDPM-F64x4/YACHT/YACHT949.png
# Processado: YACHT95.png -> DDPM-F64x4/YACHT/YACHT95.png
# Processado: YACHT950.png -> DDPM-F64x4/YACHT/YACHT950.png
# Processado: YACHT951.png -> DDPM-F64x4/YACHT/YACHT951.png
# Processado: YACHT952.png -> DDPM-F64x4/YACHT/YACHT952.png
# Processado: YACHT953.png -> DDPM-F64x4/YACHT/YACHT953.png
# Processado: YACHT954.png -> DDPM-F64x4/YACHT/YACHT954.png
# Processado: YACHT955.png -> DDPM-F64x4/YACHT/YACHT955.png
# Processado: YACHT956.png -> DDPM-F64x4/YACHT/YACHT956.png
# Processado: YACHT957.png -> DDPM-F64x4/YACHT/YACHT957.png
# Processado: YACHT958.png -> DDPM-F64x4/YACHT/YACHT958.png
# Processado: YACHT959.png -> DDPM-F64x4/YACHT/YACHT959.png
# Processado: YACHT96.png -> DDPM-F64x4/YACHT/YACHT96.png
# Processado: YACHT960.png -> DDPM-F64x4/YACHT/YACHT960.png
# Processado: YACHT961.png -> DDPM-F64x4/YACHT/YACHT961.png
# Processado: YACHT962.png -> DDPM-F64x4/YACHT/YACHT962.png
# Processado: YACHT963.png -> DDPM-F64x4/YACHT/YACHT963.png
# Processado: YACHT964.png -> DDPM-F64x4/YACHT/YACHT964.png
# Processado: YACHT965.png -> DDPM-F64x4/YACHT/YACHT965.png
# Processado: YACHT966.png -> DDPM-F64x4/YACHT/YACHT966.png
# Processado: YACHT967.png -> DDPM-F64x4/YACHT/YACHT967.png
# Processado: YACHT968.png -> DDPM-F64x4/YACHT/YACHT968.png
# Processado: YACHT969.png -> DDPM-F64x4/YACHT/YACHT969.png
# Processado: YACHT97.png -> DDPM-F64x4/YACHT/YACHT97.png
# Processado: YACHT970.png -> DDPM-F64x4/YACHT/YACHT970.png
# Processado: YACHT971.png -> DDPM-F64x4/YACHT/YACHT971.png
# Processado: YACHT972.png -> DDPM-F64x4/YACHT/YACHT972.png
# Processado: YACHT973.png -> DDPM-F64x4/YACHT/YACHT973.png
# Processado: YACHT974.png -> DDPM-F64x4/YACHT/YACHT974.png
# Processado: YACHT975.png -> DDPM-F64x4/YACHT/YACHT975.png
# Processado: YACHT976.png -> DDPM-F64x4/YACHT/YACHT976.png
# Processado: YACHT977.png -> DDPM-F64x4/YACHT/YACHT977.png
# Processado: YACHT978.png -> DDPM-F64x4/YACHT/YACHT978.png
# Processado: YACHT979.png -> DDPM-F64x4/YACHT/YACHT979.png
# Processado: YACHT98.png -> DDPM-F64x4/YACHT/YACHT98.png
# Processado: YACHT980.png -> DDPM-F64x4/YACHT/YACHT980.png
# Processado: YACHT981.png -> DDPM-F64x4/YACHT/YACHT981.png
# Processado: YACHT982.png -> DDPM-F64x4/YACHT/YACHT982.png
# Processado: YACHT983.png -> DDPM-F64x4/YACHT/YACHT983.png
# Processado: YACHT984.png -> DDPM-F64x4/YACHT/YACHT984.png
# Processado: YACHT985.png -> DDPM-F64x4/YACHT/YACHT985.png
# Processado: YACHT986.png -> DDPM-F64x4/YACHT/YACHT986.png
# Processado: YACHT987.png -> DDPM-F64x4/YACHT/YACHT987.png
# Processado: YACHT988.png -> DDPM-F64x4/YACHT/YACHT988.png
# Processado: YACHT989.png -> DDPM-F64x4/YACHT/YACHT989.png
# Processado: YACHT99.png -> DDPM-F64x4/YACHT/YACHT99.png
# Processado: YACHT990.png -> DDPM-F64x4/YACHT/YACHT990.png
# Processado: YACHT991.png -> DDPM-F64x4/YACHT/YACHT991.png
# Processado: YACHT992.png -> DDPM-F64x4/YACHT/YACHT992.png
# Processado: YACHT993.png -> DDPM-F64x4/YACHT/YACHT993.png
# Processado: YACHT994.png -> DDPM-F64x4/YACHT/YACHT994.png
# Processado: YACHT995.png -> DDPM-F64x4/YACHT/YACHT995.png
# Processado: YACHT996.png -> DDPM-F64x4/YACHT/YACHT996.png
# Processado: YACHT997.png -> DDPM-F64x4/YACHT/YACHT997.png
# Processado: YACHT998.png -> DDPM-F64x4/YACHT/YACHT998.png
# Processado: YACHT999.png -> DDPM-F64x4/YACHT/YACHT999.png
# Processamento concluído!
