# %%
generating_class = 'GENERALCARGO'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-24 21:14:54.057047: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-24 21:14:54.077341: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-24 21:14:55.832993: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:14:55.835811: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:14:55.835827: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-24 21:15:03.139886: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:15:03.139920: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:15:03.139930: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:15:03.254481: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:15:03.254504: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:15:03.254508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-24 21:15:03.254523: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 21:15:03.254538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-24 21:15:06.100428: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-24 21:15:06.100459: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753391707.156487   55358 service.cc:145] XLA service 0x7f5144002750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753391707.156533   55358 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-24 21:15:07.212835: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-24 21:15:07.404696: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-24 21:15:13.296383: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:13.366843: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.07057701s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:24.881612: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:25.587772: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.706260262s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:26.587928: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:27.226804: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.638973841s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:28.226975: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:28.966533: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.739670243s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:29.966687: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 21:15:30.523470: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.556891183s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753391737.663478   55358 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 42s 455ms/step - kl_loss: 2.2264e-06 - loss: 2838.7935 - reconstruction_loss: 2838.7935
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 0.0177 - loss: 2836.7688 - reconstruction_loss: 2836.7512
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 14.7444 - loss: 2810.8069 - reconstruction_loss: 2796.0625
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2573 - loss: 2679.6538 - reconstruction_loss: 2659.3965
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 8.1110 - loss: 2631.4456 - reconstruction_loss: 2623.3345
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 6.2134 - loss: 2607.2783 - reconstruction_loss: 2601.0645
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.5782 - loss: 2585.0112 - reconstruction_loss: 2575.4329
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.7132 - loss: 2578.6799 - reconstruction_loss: 2567.9668
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.4856 - loss: 2565.6582 - reconstruction_loss: 2556.1729
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 9.9762 - loss: 2553.6428 - reconstruction_loss: 2543.6667
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 9.5174 - loss: 2547.4119 - reconstruction_loss: 2537.8945
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 9.8613 - loss: 2531.8596 - reconstruction_loss: 2521.9983
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.0677 - loss: 2526.2893 - reconstruction_loss: 2516.2217
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 12.7594 - loss: 2510.3455 - reconstruction_loss: 2497.5857
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3800 - loss: 2507.0266 - reconstruction_loss: 2494.6465
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 11.8172 - loss: 2501.6409 - reconstruction_loss: 2489.8235
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.5346 - loss: 2497.7876 - reconstruction_loss: 2486.2532
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.3755 - loss: 2488.6030 - reconstruction_loss: 2477.2278
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.3835 - loss: 2486.0549 - reconstruction_loss: 2474.6711
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.2039 - loss: 2488.2078 - reconstruction_loss: 2477.0037
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 11.1233 - loss: 2481.4387 - reconstruction_loss: 2470.3157
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 10.7911 - loss: 2480.8123 - reconstruction_loss: 2470.0212
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.7407 - loss: 2482.0779 - reconstruction_loss: 2471.3372
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 10.7758 - loss: 2480.3125 - reconstruction_loss: 2469.5364
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.7222 - loss: 2472.8223 - reconstruction_loss: 2462.1001
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.8703 - loss: 2469.7944 - reconstruction_loss: 2458.9241
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 10.8491 - loss: 2470.9868 - reconstruction_loss: 2460.1377
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.0453 - loss: 2476.8325 - reconstruction_loss: 2465.7871
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.3678 - loss: 2466.3040 - reconstruction_loss: 2454.9363
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 11.9296 - loss: 2462.5012 - reconstruction_loss: 2450.5718
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.0574 - loss: 2463.5447 - reconstruction_loss: 2451.4871
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3632 - loss: 2462.1738 - reconstruction_loss: 2449.8105
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.2906 - loss: 2462.1494 - reconstruction_loss: 2449.8591
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3970 - loss: 2454.7739 - reconstruction_loss: 2442.3770
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3511 - loss: 2462.6167 - reconstruction_loss: 2450.2654
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.3556 - loss: 2453.9529 - reconstruction_loss: 2441.5977
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.6098 - loss: 2452.5400 - reconstruction_loss: 2439.9299
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.6370 - loss: 2451.1023 - reconstruction_loss: 2438.4656
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 12.7762 - loss: 2448.0737 - reconstruction_loss: 2435.2979
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.0041 - loss: 2448.4246 - reconstruction_loss: 2435.4204
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 13.1336 - loss: 2444.3105 - reconstruction_loss: 2431.1768
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1939 - loss: 2444.5227 - reconstruction_loss: 2431.3289
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.8533 - loss: 2439.3906 - reconstruction_loss: 2425.5371
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.9400 - loss: 2438.3594 - reconstruction_loss: 2424.4192
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7137 - loss: 2435.4600 - reconstruction_loss: 2421.7463
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.8327 - loss: 2437.6226 - reconstruction_loss: 2423.7896
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7686 - loss: 2438.4412 - reconstruction_loss: 2424.6726
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.5807 - loss: 2435.9810 - reconstruction_loss: 2422.4001
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.5686 - loss: 2433.3240 - reconstruction_loss: 2419.7554
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 13.5882 - loss: 2435.9321 - reconstruction_loss: 2422.3440
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4664 - loss: 2433.5911 - reconstruction_loss: 2420.1248
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4538 - loss: 2433.9666 - reconstruction_loss: 2420.5127
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4502 - loss: 2430.9421 - reconstruction_loss: 2417.4922
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.5590 - loss: 2430.9626 - reconstruction_loss: 2417.4033
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4393 - loss: 2427.4700 - reconstruction_loss: 2414.0305
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.6390 - loss: 2427.3882 - reconstruction_loss: 2413.7493
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1767 - loss: 2429.5381 - reconstruction_loss: 2416.3616
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.3348 - loss: 2424.6641 - reconstruction_loss: 2411.3291
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4428 - loss: 2427.6064 - reconstruction_loss: 2414.1638
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.2371 - loss: 2426.4031 - reconstruction_loss: 2413.1660
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.2776 - loss: 2422.1040 - reconstruction_loss: 2408.8267
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1301 - loss: 2426.1731 - reconstruction_loss: 2413.0432
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.3944 - loss: 2423.7451 - reconstruction_loss: 2410.3506
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 13.4384 - loss: 2418.1482 - reconstruction_loss: 2404.7095
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1680 - loss: 2425.6497 - reconstruction_loss: 2412.4817
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.1548 - loss: 2424.9602 - reconstruction_loss: 2411.8057
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.3251 - loss: 2423.0283 - reconstruction_loss: 2409.7034
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.4814 - loss: 2422.2312 - reconstruction_loss: 2408.7498
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.6095 - loss: 2425.5613 - reconstruction_loss: 2411.9514
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.5650 - loss: 2420.6597 - reconstruction_loss: 2407.0947
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7332 - loss: 2415.7654 - reconstruction_loss: 2402.0322
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7520 - loss: 2415.2976 - reconstruction_loss: 2401.5454
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 13.7239 - loss: 2416.5750 - reconstruction_loss: 2402.8508
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.0295 - loss: 2414.7627 - reconstruction_loss: 2400.7329
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.0772 - loss: 2416.3623 - reconstruction_loss: 2402.2854
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.2061 - loss: 2410.9089 - reconstruction_loss: 2396.7029
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.3381 - loss: 2417.2542 - reconstruction_loss: 2402.9160
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.6227 - loss: 2414.7498 - reconstruction_loss: 2400.1270
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.7903 - loss: 2411.9004 - reconstruction_loss: 2397.1104
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.7740 - loss: 2409.3408 - reconstruction_loss: 2394.5669
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.9379 - loss: 2404.8357 - reconstruction_loss: 2389.8979
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.8937 - loss: 2410.8535 - reconstruction_loss: 2395.9597
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.0193 - loss: 2410.4834 - reconstruction_loss: 2395.4641
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1051 - loss: 2413.2544 - reconstruction_loss: 2398.1492
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 14.9956 - loss: 2410.7131 - reconstruction_loss: 2395.7178
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.3270 - loss: 2405.6052 - reconstruction_loss: 2390.2783
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.1890 - loss: 2404.4482 - reconstruction_loss: 2389.2593
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.2301 - loss: 2406.2207 - reconstruction_loss: 2390.9907
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.1961 - loss: 2409.7458 - reconstruction_loss: 2394.5498
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1646 - loss: 2410.6890 - reconstruction_loss: 2395.5244
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.2786 - loss: 2408.1477 - reconstruction_loss: 2392.8691
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 15.1321 - loss: 2409.2576 - reconstruction_loss: 2394.1252
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.2070 - loss: 2406.8357 - reconstruction_loss: 2391.6289
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.2566 - loss: 2407.0256 - reconstruction_loss: 2391.7693
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1522 - loss: 2408.6626 - reconstruction_loss: 2393.5107
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.2006 - loss: 2404.6841 - reconstruction_loss: 2389.4834
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.4342 - loss: 2405.0020 - reconstruction_loss: 2389.5679
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.1824 - loss: 2409.9707 - reconstruction_loss: 2394.7883
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.3915 - loss: 2403.0718 - reconstruction_loss: 2387.6804
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.3353 - loss: 2403.0896 - reconstruction_loss: 2387.7546
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.5627 - loss: 2406.2969 - reconstruction_loss: 2390.7341
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.3888 - loss: 2404.4819 - reconstruction_loss: 2389.0933
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.4052 - loss: 2406.5818 - reconstruction_loss: 2391.1765
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.5220 - loss: 2404.0911 - reconstruction_loss: 2388.5693
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 15.4636 - loss: 2404.3853 - reconstruction_loss: 2388.9216
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.5328 - loss: 2406.5073 - reconstruction_loss: 2390.9746
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.7626 - loss: 2401.3066 - reconstruction_loss: 2385.5439
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 15.8692 - loss: 2410.2534 - reconstruction_loss: 2394.3843
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9499 - loss: 2398.2000 - reconstruction_loss: 2382.2500
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 15.9012 - loss: 2400.8638 - reconstruction_loss: 2384.9624
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.1184 - loss: 2403.7576 - reconstruction_loss: 2387.6392
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.1924 - loss: 2404.8457 - reconstruction_loss: 2388.6533
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.2583 - loss: 2399.9607 - reconstruction_loss: 2383.7026
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3971 - loss: 2395.5583 - reconstruction_loss: 2379.1614
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3181 - loss: 2405.1643 - reconstruction_loss: 2388.8462
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 16.3486 - loss: 2404.3774 - reconstruction_loss: 2388.0288
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3790 - loss: 2399.6553 - reconstruction_loss: 2383.2764
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.3494 - loss: 2397.9973 - reconstruction_loss: 2381.6479
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5859 - loss: 2398.0518 - reconstruction_loss: 2381.4658
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.5297 - loss: 2400.5342 - reconstruction_loss: 2384.0044
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.7949 - loss: 2394.5244 - reconstruction_loss: 2377.7295
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.6879 - loss: 2396.5833 - reconstruction_loss: 2379.8955
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.8482 - loss: 2393.6409 - reconstruction_loss: 2376.7927
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.7703 - loss: 2401.1543 - reconstruction_loss: 2384.3838
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 16.9351 - loss: 2392.9229 - reconstruction_loss: 2375.9875
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.0105 - loss: 2393.6931 - reconstruction_loss: 2376.6824
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 17.0125 - loss: 2393.6470 - reconstruction_loss: 2376.6348
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.1641 - loss: 2396.8657 - reconstruction_loss: 2379.7017
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.2299 - loss: 2394.4990 - reconstruction_loss: 2377.2693
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.0234 - loss: 2396.7024 - reconstruction_loss: 2379.6792
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.0859 - loss: 2398.1885 - reconstruction_loss: 2381.1025
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.2188 - loss: 2394.7610 - reconstruction_loss: 2377.5422
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.1576 - loss: 2392.2205 - reconstruction_loss: 2375.0625
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.1759 - loss: 2396.5608 - reconstruction_loss: 2379.3848
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.2314 - loss: 2395.1824 - reconstruction_loss: 2377.9512
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.3864 - loss: 2392.0168 - reconstruction_loss: 2374.6304
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.3743 - loss: 2393.8342 - reconstruction_loss: 2376.4600
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5434 - loss: 2388.2793 - reconstruction_loss: 2370.7361
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.4751 - loss: 2397.5518 - reconstruction_loss: 2380.0767
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5298 - loss: 2392.0166 - reconstruction_loss: 2374.4868
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.4706 - loss: 2391.6672 - reconstruction_loss: 2374.1965
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5100 - loss: 2394.2786 - reconstruction_loss: 2376.7688
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5485 - loss: 2391.3909 - reconstruction_loss: 2373.8423
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.6541 - loss: 2392.2263 - reconstruction_loss: 2374.5723
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5711 - loss: 2392.1125 - reconstruction_loss: 2374.5415
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.5763 - loss: 2396.3982 - reconstruction_loss: 2378.8220
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.9183 - loss: 2387.7703 - reconstruction_loss: 2369.8518
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8909 - loss: 2390.5623 - reconstruction_loss: 2372.6714
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8291 - loss: 2387.1479 - reconstruction_loss: 2369.3188
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8714 - loss: 2393.1370 - reconstruction_loss: 2375.2654
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.0609 - loss: 2390.8403 - reconstruction_loss: 2372.7793
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 17.8582 - loss: 2390.5520 - reconstruction_loss: 2372.6941
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1403 - loss: 2390.6968 - reconstruction_loss: 2372.5564
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2026 - loss: 2391.7915 - reconstruction_loss: 2373.5891
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2941 - loss: 2394.7163 - reconstruction_loss: 2376.4224
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.2329 - loss: 2390.6055 - reconstruction_loss: 2372.3726
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.1568 - loss: 2392.9583 - reconstruction_loss: 2374.8010
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3611 - loss: 2383.5396 - reconstruction_loss: 2365.1785
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3493 - loss: 2389.9224 - reconstruction_loss: 2371.5728
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.3732 - loss: 2393.3938 - reconstruction_loss: 2375.0203
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4971 - loss: 2390.7815 - reconstruction_loss: 2372.2844
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4580 - loss: 2387.0767 - reconstruction_loss: 2368.6189
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 18.6159 - loss: 2384.0039 - reconstruction_loss: 2365.3882
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.4885 - loss: 2387.1582 - reconstruction_loss: 2368.6694
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.6200 - loss: 2382.3630 - reconstruction_loss: 2363.7429
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7927 - loss: 2390.7312 - reconstruction_loss: 2371.9387
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8471 - loss: 2388.6719 - reconstruction_loss: 2369.8250
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.8436 - loss: 2388.9082 - reconstruction_loss: 2370.0649
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.7673 - loss: 2390.7544 - reconstruction_loss: 2371.9871
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.0249 - loss: 2382.8389 - reconstruction_loss: 2363.8137
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 18.9221 - loss: 2387.6768 - reconstruction_loss: 2368.7546
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.1257 - loss: 2383.9746 - reconstruction_loss: 2364.8486
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.0799 - loss: 2386.8108 - reconstruction_loss: 2367.7307
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.0853 - loss: 2385.6191 - reconstruction_loss: 2366.5337
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2223 - loss: 2386.1318 - reconstruction_loss: 2366.9097
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.1115 - loss: 2384.9768 - reconstruction_loss: 2365.8647
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3142 - loss: 2381.3926 - reconstruction_loss: 2362.0784
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.2658 - loss: 2382.1511 - reconstruction_loss: 2362.8853
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.3265 - loss: 2385.6882 - reconstruction_loss: 2366.3613
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5391 - loss: 2383.4270 - reconstruction_loss: 2363.8879
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.4874 - loss: 2379.2375 - reconstruction_loss: 2359.7502
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.5989 - loss: 2383.3325 - reconstruction_loss: 2363.7334
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6713 - loss: 2386.9775 - reconstruction_loss: 2367.3062
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6477 - loss: 2386.4812 - reconstruction_loss: 2366.8335
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.6979 - loss: 2382.5059 - reconstruction_loss: 2362.8079
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9616 - loss: 2380.6006 - reconstruction_loss: 2360.6387
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.8033 - loss: 2382.4766 - reconstruction_loss: 2362.6733
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9381 - loss: 2378.3149 - reconstruction_loss: 2358.3770
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 19.9800 - loss: 2379.5696 - reconstruction_loss: 2359.5896
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0341 - loss: 2379.6125 - reconstruction_loss: 2359.5784
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.1130 - loss: 2378.3521 - reconstruction_loss: 2358.2385
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0817 - loss: 2384.2625 - reconstruction_loss: 2364.1812
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2265 - loss: 2380.8665 - reconstruction_loss: 2360.6401
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.0872 - loss: 2375.8225 - reconstruction_loss: 2355.7358
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2738 - loss: 2382.3540 - reconstruction_loss: 2362.0801
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2629 - loss: 2385.4500 - reconstruction_loss: 2365.1873
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.2371 - loss: 2382.8101 - reconstruction_loss: 2362.5732
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4000 - loss: 2378.6804 - reconstruction_loss: 2358.2808
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4195 - loss: 2379.0085 - reconstruction_loss: 2358.5886
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3779 - loss: 2381.3628 - reconstruction_loss: 2360.9846
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.3815 - loss: 2382.5542 - reconstruction_loss: 2362.1726
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6147 - loss: 2377.4746 - reconstruction_loss: 2356.8601
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.4561 - loss: 2378.8464 - reconstruction_loss: 2358.3904
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7092 - loss: 2372.7432 - reconstruction_loss: 2352.0339
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6645 - loss: 2381.7905 - reconstruction_loss: 2361.1257
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6186 - loss: 2378.6694 - reconstruction_loss: 2358.0508
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6680 - loss: 2377.0015 - reconstruction_loss: 2356.3335
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.5687 - loss: 2378.0596 - reconstruction_loss: 2357.4912
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7873 - loss: 2375.3901 - reconstruction_loss: 2354.6028
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.6578 - loss: 2379.3826 - reconstruction_loss: 2358.7249
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.7276 - loss: 2376.0740 - reconstruction_loss: 2355.3462
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8055 - loss: 2371.0044 - reconstruction_loss: 2350.1990
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8438 - loss: 2377.1289 - reconstruction_loss: 2356.2849
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8848 - loss: 2377.4607 - reconstruction_loss: 2356.5759
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8558 - loss: 2378.5461 - reconstruction_loss: 2357.6902
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9878 - loss: 2380.1057 - reconstruction_loss: 2359.1179
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.8896 - loss: 2375.2302 - reconstruction_loss: 2354.3411
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9513 - loss: 2381.3801 - reconstruction_loss: 2360.4290
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0331 - loss: 2375.7937 - reconstruction_loss: 2354.7603
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0463 - loss: 2374.3589 - reconstruction_loss: 2353.3127
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 20.9877 - loss: 2371.2900 - reconstruction_loss: 2350.3027
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0440 - loss: 2377.1777 - reconstruction_loss: 2356.1335
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.0878 - loss: 2374.6121 - reconstruction_loss: 2353.5239
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3362 - loss: 2373.4382 - reconstruction_loss: 2352.1023
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1494 - loss: 2366.3704 - reconstruction_loss: 2345.2207
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.1884 - loss: 2375.2424 - reconstruction_loss: 2354.0540
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3529 - loss: 2371.4651 - reconstruction_loss: 2350.1125
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3227 - loss: 2372.7493 - reconstruction_loss: 2351.4263
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2370 - loss: 2376.1785 - reconstruction_loss: 2354.9417
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3814 - loss: 2369.6970 - reconstruction_loss: 2348.3157
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2149 - loss: 2374.4365 - reconstruction_loss: 2353.2214
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.2784 - loss: 2375.6704 - reconstruction_loss: 2354.3918
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 21.3145 - loss: 2370.2031 - reconstruction_loss: 2348.8887
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.3923 - loss: 2376.6167 - reconstruction_loss: 2355.2244
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.4795 - loss: 2370.3252 - reconstruction_loss: 2348.8457
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.5569 - loss: 2365.6494 - reconstruction_loss: 2344.0923
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.4015 - loss: 2371.5396 - reconstruction_loss: 2350.1382
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.5617 - loss: 2376.5664 - reconstruction_loss: 2355.0049
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6421 - loss: 2370.1572 - reconstruction_loss: 2348.5149
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6657 - loss: 2369.8352 - reconstruction_loss: 2348.1694
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.5843 - loss: 2369.1851 - reconstruction_loss: 2347.6006
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.6356 - loss: 2376.8503 - reconstruction_loss: 2355.2146
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7416 - loss: 2365.0049 - reconstruction_loss: 2343.2634
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7385 - loss: 2370.4082 - reconstruction_loss: 2348.6699
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9940 - loss: 2366.1577 - reconstruction_loss: 2344.1641
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7843 - loss: 2368.4355 - reconstruction_loss: 2346.6514
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8261 - loss: 2366.9502 - reconstruction_loss: 2345.1243
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7819 - loss: 2373.6392 - reconstruction_loss: 2351.8574
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8746 - loss: 2370.1045 - reconstruction_loss: 2348.2302
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.7920 - loss: 2368.6975 - reconstruction_loss: 2346.9055
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8710 - loss: 2372.8799 - reconstruction_loss: 2351.0090
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8222 - loss: 2363.5847 - reconstruction_loss: 2341.7627
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.8595 - loss: 2366.1448 - reconstruction_loss: 2344.2849
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9343 - loss: 2367.9597 - reconstruction_loss: 2346.0254
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9633 - loss: 2369.7285 - reconstruction_loss: 2347.7649
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.1805 - loss: 2367.4438 - reconstruction_loss: 2345.2632
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.1226 - loss: 2369.1599 - reconstruction_loss: 2347.0371
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0122 - loss: 2368.3494 - reconstruction_loss: 2346.3374
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 21.9983 - loss: 2363.3027 - reconstruction_loss: 2341.3044
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0648 - loss: 2366.7666 - reconstruction_loss: 2344.7021
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.1597 - loss: 2364.7190 - reconstruction_loss: 2342.5591
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2679 - loss: 2368.5361 - reconstruction_loss: 2346.2683
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2765 - loss: 2362.0020 - reconstruction_loss: 2339.7256
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - kl_loss: 22.2107 - loss: 2362.6084 - reconstruction_loss: 2340.3977
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.0885 - loss: 2365.8259 - reconstruction_loss: 2343.7375
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2906 - loss: 2367.2195 - reconstruction_loss: 2344.9290
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4295 - loss: 2361.6594 - reconstruction_loss: 2339.2302
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3156 - loss: 2368.5349 - reconstruction_loss: 2346.2192
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.2647 - loss: 2364.5161 - reconstruction_loss: 2342.2517
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4182 - loss: 2363.5349 - reconstruction_loss: 2341.1167
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3464 - loss: 2366.5168 - reconstruction_loss: 2344.1707
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5762 - loss: 2363.6018 - reconstruction_loss: 2341.0254
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3500 - loss: 2365.5906 - reconstruction_loss: 2343.2402
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4750 - loss: 2362.8545 - reconstruction_loss: 2340.3796
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4763 - loss: 2359.4683 - reconstruction_loss: 2336.9919
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5786 - loss: 2361.5610 - reconstruction_loss: 2338.9822
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.3698 - loss: 2365.2424 - reconstruction_loss: 2342.8726
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.4908 - loss: 2365.9866 - reconstruction_loss: 2343.4958
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6697 - loss: 2358.1406 - reconstruction_loss: 2335.4712
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5230 - loss: 2359.1790 - reconstruction_loss: 2336.6560
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7436 - loss: 2361.3401 - reconstruction_loss: 2338.5964
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7590 - loss: 2359.0146 - reconstruction_loss: 2336.2556
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.6710 - loss: 2363.0459 - reconstruction_loss: 2340.3748
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.5871 - loss: 2361.9226 - reconstruction_loss: 2339.3354
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7493 - loss: 2364.9436 - reconstruction_loss: 2342.1943
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.8252 - loss: 2360.6868 - reconstruction_loss: 2337.8613
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 22.7476 - loss: 2361.5896 - reconstruction_loss: 2338.8418
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4464 - loss: 2305.5454 - reconstruction_loss: 2279.0989
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3565 - loss: 2304.7029 - reconstruction_loss: 2278.3462
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.1980 - loss: 2308.7288 - reconstruction_loss: 2282.5308
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3132 - loss: 2308.9592 - reconstruction_loss: 2282.6460
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4065 - loss: 2305.2593 - reconstruction_loss: 2278.8530
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3418 - loss: 2307.3008 - reconstruction_loss: 2280.9590
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4070 - loss: 2301.0071 - reconstruction_loss: 2274.6001
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4420 - loss: 2303.3450 - reconstruction_loss: 2276.9031
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2901 - loss: 2305.9871 - reconstruction_loss: 2279.6973
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2232 - loss: 2310.0532 - reconstruction_loss: 2283.8301
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3235 - loss: 2309.0034 - reconstruction_loss: 2282.6799
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3667 - loss: 2308.0068 - reconstruction_loss: 2281.6399
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3767 - loss: 2308.3330 - reconstruction_loss: 2281.9563
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3052 - loss: 2304.5972 - reconstruction_loss: 2278.2917
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3372 - loss: 2305.7280 - reconstruction_loss: 2279.3909
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2058 - loss: 2311.3574 - reconstruction_loss: 2285.1511
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3628 - loss: 2311.2849 - reconstruction_loss: 2284.9219
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.5648 - loss: 2302.4126 - reconstruction_loss: 2275.8481
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3666 - loss: 2301.3035 - reconstruction_loss: 2274.9368
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3214 - loss: 2307.4792 - reconstruction_loss: 2281.1582
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2936 - loss: 2301.1504 - reconstruction_loss: 2274.8569
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3874 - loss: 2300.5483 - reconstruction_loss: 2274.1611
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3746 - loss: 2305.9775 - reconstruction_loss: 2279.6030
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3242 - loss: 2307.2246 - reconstruction_loss: 2280.9004
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2693 - loss: 2308.1633 - reconstruction_loss: 2281.8943
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2923 - loss: 2308.8127 - reconstruction_loss: 2282.5208
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2247 - loss: 2302.8694 - reconstruction_loss: 2276.6448
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3555 - loss: 2304.2129 - reconstruction_loss: 2277.8577
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3890 - loss: 2306.5132 - reconstruction_loss: 2280.1243
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3667 - loss: 2302.1348 - reconstruction_loss: 2275.7678
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3729 - loss: 2304.2969 - reconstruction_loss: 2277.9238
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3289 - loss: 2301.5381 - reconstruction_loss: 2275.2090
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3377 - loss: 2302.7502 - reconstruction_loss: 2276.4126
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3437 - loss: 2304.4055 - reconstruction_loss: 2278.0618
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4393 - loss: 2308.6821 - reconstruction_loss: 2282.2429
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2732 - loss: 2308.9451 - reconstruction_loss: 2282.6716
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4763 - loss: 2305.6152 - reconstruction_loss: 2279.1387
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3242 - loss: 2305.1777 - reconstruction_loss: 2278.8535
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3976 - loss: 2309.9873 - reconstruction_loss: 2283.5896
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3401 - loss: 2308.4475 - reconstruction_loss: 2282.1074
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2618 - loss: 2307.8933 - reconstruction_loss: 2281.6316
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2789 - loss: 2304.9065 - reconstruction_loss: 2278.6277
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3008 - loss: 2307.7852 - reconstruction_loss: 2281.4844
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3098 - loss: 2305.9094 - reconstruction_loss: 2279.5996
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3778 - loss: 2307.7986 - reconstruction_loss: 2281.4209
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2719 - loss: 2307.5103 - reconstruction_loss: 2281.2385
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4258 - loss: 2307.0803 - reconstruction_loss: 2280.6545
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4332 - loss: 2306.5332 - reconstruction_loss: 2280.1001
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3145 - loss: 2308.3608 - reconstruction_loss: 2282.0464
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4284 - loss: 2305.7129 - reconstruction_loss: 2279.2842
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3861 - loss: 2301.9734 - reconstruction_loss: 2275.5872
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3905 - loss: 2304.9473 - reconstruction_loss: 2278.5564
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4431 - loss: 2301.1162 - reconstruction_loss: 2274.6731
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3954 - loss: 2304.6733 - reconstruction_loss: 2278.2783
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2894 - loss: 2304.3264 - reconstruction_loss: 2278.0371
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3997 - loss: 2306.1045 - reconstruction_loss: 2279.7046
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3389 - loss: 2311.1599 - reconstruction_loss: 2284.8213
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4286 - loss: 2306.2554 - reconstruction_loss: 2279.8269
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4159 - loss: 2305.3486 - reconstruction_loss: 2278.9329
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3844 - loss: 2307.9714 - reconstruction_loss: 2281.5867
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4224 - loss: 2302.6150 - reconstruction_loss: 2276.1926
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4100 - loss: 2301.8525 - reconstruction_loss: 2275.4424
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3617 - loss: 2298.9705 - reconstruction_loss: 2272.6086
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2386 - loss: 2301.0010 - reconstruction_loss: 2274.7625
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4107 - loss: 2308.9761 - reconstruction_loss: 2282.5654
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4322 - loss: 2299.0364 - reconstruction_loss: 2272.6040
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2726 - loss: 2308.7979 - reconstruction_loss: 2282.5251
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.1995 - loss: 2307.3867 - reconstruction_loss: 2281.1873
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2456 - loss: 2307.9077 - reconstruction_loss: 2281.6624
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2709 - loss: 2309.7485 - reconstruction_loss: 2283.4775
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4919 - loss: 2301.6301 - reconstruction_loss: 2275.1379
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4127 - loss: 2300.6509 - reconstruction_loss: 2274.2380
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.5378 - loss: 2308.1978 - reconstruction_loss: 2281.6602
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3465 - loss: 2299.9666 - reconstruction_loss: 2273.6201
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3729 - loss: 2306.5569 - reconstruction_loss: 2280.1838
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3968 - loss: 2303.3486 - reconstruction_loss: 2276.9519
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3245 - loss: 2308.1025 - reconstruction_loss: 2281.7781
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4029 - loss: 2308.6794 - reconstruction_loss: 2282.2766
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3335 - loss: 2305.2263 - reconstruction_loss: 2278.8931
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3074 - loss: 2300.5327 - reconstruction_loss: 2274.2251
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3110 - loss: 2299.4282 - reconstruction_loss: 2273.1172
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2707 - loss: 2309.2385 - reconstruction_loss: 2282.9675
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.2853 - loss: 2308.5950 - reconstruction_loss: 2282.3098
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3703 - loss: 2302.6575 - reconstruction_loss: 2276.2874
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4182 - loss: 2300.6877 - reconstruction_loss: 2274.2693
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3273 - loss: 2305.4563 - reconstruction_loss: 2279.1292
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3838 - loss: 2299.6426 - reconstruction_loss: 2273.2588
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3689 - loss: 2308.7537 - reconstruction_loss: 2282.3848
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4422 - loss: 2305.2063 - reconstruction_loss: 2278.7642
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3351 - loss: 2303.0198 - reconstruction_loss: 2276.6843
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3659 - loss: 2302.6538 - reconstruction_loss: 2276.2883
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3610 - loss: 2303.4084 - reconstruction_loss: 2277.0476
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3605 - loss: 2300.5957 - reconstruction_loss: 2274.2351
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3831 - loss: 2298.3293 - reconstruction_loss: 2271.9458
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2989 - loss: 2302.5154 - reconstruction_loss: 2276.2163
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3561 - loss: 2305.5076 - reconstruction_loss: 2279.1519
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3401 - loss: 2306.9092 - reconstruction_loss: 2280.5688
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4168 - loss: 2302.5066 - reconstruction_loss: 2276.0898
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3855 - loss: 2303.7573 - reconstruction_loss: 2277.3718
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.3989 - loss: 2301.9124 - reconstruction_loss: 2275.5137
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4143 - loss: 2300.6616 - reconstruction_loss: 2274.2476
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4363 - loss: 2306.7664 - reconstruction_loss: 2280.3301
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4505 - loss: 2306.5479 - reconstruction_loss: 2280.0974
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4492 - loss: 2302.9404 - reconstruction_loss: 2276.4912
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3703 - loss: 2301.7095 - reconstruction_loss: 2275.3391
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3603 - loss: 2306.6440 - reconstruction_loss: 2280.2837
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3725 - loss: 2301.0222 - reconstruction_loss: 2274.6499
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4021 - loss: 2308.1145 - reconstruction_loss: 2281.7126
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4576 - loss: 2302.4846 - reconstruction_loss: 2276.0266
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2976 - loss: 2304.6213 - reconstruction_loss: 2278.3237
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3249 - loss: 2302.3704 - reconstruction_loss: 2276.0457
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3737 - loss: 2306.1218 - reconstruction_loss: 2279.7483
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3744 - loss: 2300.8901 - reconstruction_loss: 2274.5159
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3594 - loss: 2306.0225 - reconstruction_loss: 2279.6631
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4708 - loss: 2301.5771 - reconstruction_loss: 2275.1067
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3709 - loss: 2306.1162 - reconstruction_loss: 2279.7454
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4272 - loss: 2301.2898 - reconstruction_loss: 2274.8628
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4285 - loss: 2303.9116 - reconstruction_loss: 2277.4829
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4199 - loss: 2301.8945 - reconstruction_loss: 2275.4746
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4025 - loss: 2302.9136 - reconstruction_loss: 2276.5110
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4263 - loss: 2299.6831 - reconstruction_loss: 2273.2568
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.4461 - loss: 2308.5383 - reconstruction_loss: 2282.0920
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2490 - loss: 2301.6196 - reconstruction_loss: 2275.3704
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4037 - loss: 2300.2932 - reconstruction_loss: 2273.8892
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 26.4215 - loss: 2299.4221 - reconstruction_loss: 2273.0007
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3798 - loss: 2307.6890 - reconstruction_loss: 2281.3088
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.2631 - loss: 2307.7063 - reconstruction_loss: 2281.4434
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - kl_loss: 26.3411 - loss: 2309.8396 - reconstruction_loss: 2283.4985

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'GENERALCARGO': 100%|██████████████████████████████████████████████| 540/540 [04:19<00:00,  2.08it/s]
# FID = 39.414100646972656
