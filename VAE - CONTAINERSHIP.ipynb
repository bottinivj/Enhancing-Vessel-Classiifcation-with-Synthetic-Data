# %%
generating_class = 'CONTAINERSHIP'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-24 20:15:38.065524: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-24 20:15:38.085593: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-24 20:15:39.836405: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:39.839177: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:39.839192: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-24 20:15:47.586408: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:47.586442: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:47.586451: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:47.696756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:47.696780: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:47.696785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-24 20:15:47.696800: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 20:15:47.696815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-24 20:15:50.604730: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-24 20:15:50.604759: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753388151.698429   17464 service.cc:145] XLA service 0x7f6df8006980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753388151.698464   17464 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-24 20:15:51.756116: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-24 20:15:51.929731: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-24 20:15:57.873429: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:15:57.956327: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.08300089s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:09.481616: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:10.185308: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.703786932s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:11.185470: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:11.828329: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.642955171s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:12.828469: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:13.569005: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.740617612s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:14.569151: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 20:16:15.125339: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.556274006s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753388182.233262   17464 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 42s 453ms/step - kl_loss: 2.7212e-06 - loss: 2838.9128 - reconstruction_loss: 2838.9128
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 0.0036 - loss: 2837.5969 - reconstruction_loss: 2837.5933
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 5.8529 - loss: 2825.0972 - reconstruction_loss: 2819.2444
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.3887 - loss: 2723.2493 - reconstruction_loss: 2700.8611
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 7.0808 - loss: 2658.7971 - reconstruction_loss: 2651.7168
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 5.0678 - loss: 2634.3655 - reconstruction_loss: 2629.2979
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 8.5266 - loss: 2615.4648 - reconstruction_loss: 2606.9377
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 9.4227 - loss: 2603.4072 - reconstruction_loss: 2593.9846
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 8.7529 - loss: 2592.2134 - reconstruction_loss: 2583.4604
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 9.3192 - loss: 2581.4783 - reconstruction_loss: 2572.1589
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 10.4086 - loss: 2573.3701 - reconstruction_loss: 2562.9612
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 9.9273 - loss: 2568.3472 - reconstruction_loss: 2558.4197
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 10.2717 - loss: 2556.9692 - reconstruction_loss: 2546.6973
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 10.8046 - loss: 2552.1387 - reconstruction_loss: 2541.3340
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.0093 - loss: 2546.2979 - reconstruction_loss: 2534.2886
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.2549 - loss: 2537.4529 - reconstruction_loss: 2524.1982
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.2776 - loss: 2535.4341 - reconstruction_loss: 2522.1565
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.6723 - loss: 2531.2468 - reconstruction_loss: 2518.5745
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.0461 - loss: 2530.2000 - reconstruction_loss: 2518.1533
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 11.6678 - loss: 2524.0684 - reconstruction_loss: 2512.4009
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 11.7868 - loss: 2521.3738 - reconstruction_loss: 2509.5869
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 11.4640 - loss: 2520.8015 - reconstruction_loss: 2509.3379
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 11.2688 - loss: 2515.5564 - reconstruction_loss: 2504.2876
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 11.0225 - loss: 2516.4307 - reconstruction_loss: 2505.4082
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 10.7966 - loss: 2508.7727 - reconstruction_loss: 2497.9761
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 10.5396 - loss: 2508.9204 - reconstruction_loss: 2498.3809
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 10.4090 - loss: 2504.6494 - reconstruction_loss: 2494.2405
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 10.4520 - loss: 2507.1101 - reconstruction_loss: 2496.6582
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 10.8202 - loss: 2502.5417 - reconstruction_loss: 2491.7219
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 11.2136 - loss: 2500.4370 - reconstruction_loss: 2489.2234
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 11.5652 - loss: 2498.7007 - reconstruction_loss: 2487.1353
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 11.8551 - loss: 2494.7268 - reconstruction_loss: 2482.8716
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.2741 - loss: 2492.8630 - reconstruction_loss: 2480.5889
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.2101 - loss: 2492.1357 - reconstruction_loss: 2479.9255
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.5911 - loss: 2486.8906 - reconstruction_loss: 2474.2998
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 12.7820 - loss: 2484.9326 - reconstruction_loss: 2472.1506
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.5694 - loss: 2485.1436 - reconstruction_loss: 2472.5740
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 12.4800 - loss: 2483.0872 - reconstruction_loss: 2470.6072
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.6295 - loss: 2481.6482 - reconstruction_loss: 2469.0188
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.0126 - loss: 2472.9348 - reconstruction_loss: 2459.9221
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.1152 - loss: 2473.1716 - reconstruction_loss: 2460.0564
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.3392 - loss: 2475.8628 - reconstruction_loss: 2462.5237
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.3587 - loss: 2470.6682 - reconstruction_loss: 2457.3093
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.2826 - loss: 2470.2500 - reconstruction_loss: 2456.9673
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.5466 - loss: 2470.1252 - reconstruction_loss: 2456.5789
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.5617 - loss: 2471.0112 - reconstruction_loss: 2457.4495
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.2812 - loss: 2467.9500 - reconstruction_loss: 2454.6692
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.4241 - loss: 2464.8997 - reconstruction_loss: 2451.4756
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.3405 - loss: 2466.9993 - reconstruction_loss: 2453.6587
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.4262 - loss: 2465.0601 - reconstruction_loss: 2451.6340
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.5646 - loss: 2467.5115 - reconstruction_loss: 2453.9468
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.3489 - loss: 2463.3992 - reconstruction_loss: 2450.0503
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.4176 - loss: 2461.6772 - reconstruction_loss: 2448.2595
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.3684 - loss: 2461.4150 - reconstruction_loss: 2448.0469
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.7004 - loss: 2456.4841 - reconstruction_loss: 2442.7839
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.9163 - loss: 2454.2883 - reconstruction_loss: 2440.3721
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 14.1488 - loss: 2459.0444 - reconstruction_loss: 2444.8958
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.2192 - loss: 2455.4641 - reconstruction_loss: 2441.2451
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.2655 - loss: 2451.2100 - reconstruction_loss: 2436.9443
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.0527 - loss: 2453.0920 - reconstruction_loss: 2439.0393
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.4812 - loss: 2450.8760 - reconstruction_loss: 2436.3948
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 14.1530 - loss: 2455.3625 - reconstruction_loss: 2441.2095
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.2526 - loss: 2450.9207 - reconstruction_loss: 2436.6682
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 14.0704 - loss: 2454.3606 - reconstruction_loss: 2440.2903
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.1765 - loss: 2450.1086 - reconstruction_loss: 2435.9316
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 14.4362 - loss: 2450.0625 - reconstruction_loss: 2435.6260
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 14.4547 - loss: 2446.6880 - reconstruction_loss: 2432.2332
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.3283 - loss: 2452.3472 - reconstruction_loss: 2438.0188
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.4445 - loss: 2449.5098 - reconstruction_loss: 2435.0649
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.5091 - loss: 2448.4290 - reconstruction_loss: 2433.9199
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.8659 - loss: 2443.6719 - reconstruction_loss: 2428.8062
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.9662 - loss: 2447.3206 - reconstruction_loss: 2432.3540
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.0389 - loss: 2445.7561 - reconstruction_loss: 2430.7173
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 15.2833 - loss: 2443.1028 - reconstruction_loss: 2427.8196
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.2910 - loss: 2441.7737 - reconstruction_loss: 2426.4827
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.3959 - loss: 2444.7817 - reconstruction_loss: 2429.3855
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 15.3895 - loss: 2443.2563 - reconstruction_loss: 2427.8669
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.5755 - loss: 2444.6541 - reconstruction_loss: 2429.0784
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 15.3132 - loss: 2445.0801 - reconstruction_loss: 2429.7671
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.5363 - loss: 2443.8438 - reconstruction_loss: 2428.3071
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.5016 - loss: 2446.2925 - reconstruction_loss: 2430.7910
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.5616 - loss: 2440.7385 - reconstruction_loss: 2425.1772
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 15.6112 - loss: 2439.5054 - reconstruction_loss: 2423.8943
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 15.9262 - loss: 2440.5193 - reconstruction_loss: 2424.5933
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 16.0303 - loss: 2439.9048 - reconstruction_loss: 2423.8743
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 16.0315 - loss: 2438.8025 - reconstruction_loss: 2422.7710
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 16.1838 - loss: 2439.1423 - reconstruction_loss: 2422.9585
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 16.2712 - loss: 2433.1465 - reconstruction_loss: 2416.8752
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 16.5552 - loss: 2435.3530 - reconstruction_loss: 2418.7979
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 16.6534 - loss: 2433.5676 - reconstruction_loss: 2416.9143
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 16.7252 - loss: 2436.2512 - reconstruction_loss: 2419.5259
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 16.9576 - loss: 2435.9189 - reconstruction_loss: 2418.9612
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 16.9336 - loss: 2428.3152 - reconstruction_loss: 2411.3816
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.0328 - loss: 2432.8743 - reconstruction_loss: 2415.8413
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.3693 - loss: 2434.8428 - reconstruction_loss: 2417.4734
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.1146 - loss: 2432.3418 - reconstruction_loss: 2415.2275
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 17.3508 - loss: 2433.0122 - reconstruction_loss: 2415.6614
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 17.3598 - loss: 2432.1125 - reconstruction_loss: 2414.7524
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.5295 - loss: 2433.8896 - reconstruction_loss: 2416.3604
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.6900 - loss: 2431.7700 - reconstruction_loss: 2414.0801
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.8645 - loss: 2429.3926 - reconstruction_loss: 2411.5283
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 17.9230 - loss: 2428.7166 - reconstruction_loss: 2410.7937
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.0362 - loss: 2430.4182 - reconstruction_loss: 2412.3821
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.2028 - loss: 2429.1868 - reconstruction_loss: 2410.9841
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.2612 - loss: 2424.3025 - reconstruction_loss: 2406.0415
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.0978 - loss: 2430.0559 - reconstruction_loss: 2411.9580
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.2965 - loss: 2429.6060 - reconstruction_loss: 2411.3093
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.1923 - loss: 2425.2346 - reconstruction_loss: 2407.0422
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 18.3953 - loss: 2429.0815 - reconstruction_loss: 2410.6860
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.4643 - loss: 2425.0750 - reconstruction_loss: 2406.6108
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.4689 - loss: 2426.4956 - reconstruction_loss: 2408.0266
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.6954 - loss: 2427.4917 - reconstruction_loss: 2408.7961
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.4589 - loss: 2428.7380 - reconstruction_loss: 2410.2793
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.5210 - loss: 2425.3557 - reconstruction_loss: 2406.8345
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.7283 - loss: 2426.6226 - reconstruction_loss: 2407.8943
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.7442 - loss: 2426.5522 - reconstruction_loss: 2407.8083
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.7024 - loss: 2423.4514 - reconstruction_loss: 2404.7490
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.6870 - loss: 2423.1008 - reconstruction_loss: 2404.4138
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.8861 - loss: 2421.0132 - reconstruction_loss: 2402.1267
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.9993 - loss: 2428.8132 - reconstruction_loss: 2409.8140
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.0206 - loss: 2426.0247 - reconstruction_loss: 2407.0042
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 18.7400 - loss: 2422.4751 - reconstruction_loss: 2403.7346
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.8720 - loss: 2422.4563 - reconstruction_loss: 2403.5845
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.8520 - loss: 2423.6865 - reconstruction_loss: 2404.8347
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.7795 - loss: 2425.4902 - reconstruction_loss: 2406.7109
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.2276 - loss: 2419.6113 - reconstruction_loss: 2400.3835
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 18.9719 - loss: 2423.3931 - reconstruction_loss: 2404.4209
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.0692 - loss: 2421.3970 - reconstruction_loss: 2402.3279
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.0940 - loss: 2424.8184 - reconstruction_loss: 2405.7244
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 19.2289 - loss: 2417.2759 - reconstruction_loss: 2398.0469
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 19.4242 - loss: 2418.6797 - reconstruction_loss: 2399.2554
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.2541 - loss: 2418.3887 - reconstruction_loss: 2399.1343
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.4322 - loss: 2415.4216 - reconstruction_loss: 2395.9900
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.4190 - loss: 2418.9998 - reconstruction_loss: 2399.5803
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 19.4568 - loss: 2422.8843 - reconstruction_loss: 2403.4275
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.3208 - loss: 2419.7581 - reconstruction_loss: 2400.4375
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.6268 - loss: 2416.6431 - reconstruction_loss: 2397.0159
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.8208 - loss: 2414.8335 - reconstruction_loss: 2395.0125
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.5802 - loss: 2421.8613 - reconstruction_loss: 2402.2810
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.8843 - loss: 2418.0618 - reconstruction_loss: 2398.1775
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.7757 - loss: 2415.2930 - reconstruction_loss: 2395.5173
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.8590 - loss: 2421.1072 - reconstruction_loss: 2401.2478
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.8712 - loss: 2417.8486 - reconstruction_loss: 2397.9775
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 19.9535 - loss: 2416.0273 - reconstruction_loss: 2396.0737
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 19.9021 - loss: 2417.0276 - reconstruction_loss: 2397.1252
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.0110 - loss: 2417.5786 - reconstruction_loss: 2397.5679
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.1473 - loss: 2415.3352 - reconstruction_loss: 2395.1877
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.0930 - loss: 2418.1104 - reconstruction_loss: 2398.0173
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.1338 - loss: 2411.4272 - reconstruction_loss: 2391.2935
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.2116 - loss: 2419.5249 - reconstruction_loss: 2399.3132
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 20.3115 - loss: 2413.2415 - reconstruction_loss: 2392.9297
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.2534 - loss: 2417.9338 - reconstruction_loss: 2397.6804
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.6276 - loss: 2410.8921 - reconstruction_loss: 2390.2642
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.3678 - loss: 2413.3333 - reconstruction_loss: 2392.9653
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.3666 - loss: 2408.7563 - reconstruction_loss: 2388.3899
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.4294 - loss: 2410.4690 - reconstruction_loss: 2390.0393
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 20.3414 - loss: 2412.5879 - reconstruction_loss: 2392.2466
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.7105 - loss: 2413.1421 - reconstruction_loss: 2392.4316
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.4958 - loss: 2410.5552 - reconstruction_loss: 2390.0593
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.6000 - loss: 2411.0171 - reconstruction_loss: 2390.4167
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.6749 - loss: 2411.0225 - reconstruction_loss: 2390.3474
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 20.6936 - loss: 2408.5415 - reconstruction_loss: 2387.8479
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.7512 - loss: 2408.8193 - reconstruction_loss: 2388.0679
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.7671 - loss: 2405.2451 - reconstruction_loss: 2384.4780
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.8485 - loss: 2414.2195 - reconstruction_loss: 2393.3711
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 20.8528 - loss: 2407.6699 - reconstruction_loss: 2386.8171
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.9863 - loss: 2412.5945 - reconstruction_loss: 2391.6086
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.9171 - loss: 2409.7073 - reconstruction_loss: 2388.7903
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.1079 - loss: 2407.1458 - reconstruction_loss: 2386.0381
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.0455 - loss: 2408.5251 - reconstruction_loss: 2387.4797
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 20.7928 - loss: 2409.1577 - reconstruction_loss: 2388.3650
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.3064 - loss: 2406.5508 - reconstruction_loss: 2385.2446
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.1409 - loss: 2407.6536 - reconstruction_loss: 2386.5127
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.0558 - loss: 2407.7993 - reconstruction_loss: 2386.7439
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.0604 - loss: 2404.5674 - reconstruction_loss: 2383.5071
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.2657 - loss: 2409.4219 - reconstruction_loss: 2388.1562
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.1916 - loss: 2407.2117 - reconstruction_loss: 2386.0203
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.2513 - loss: 2401.6338 - reconstruction_loss: 2380.3826
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.3178 - loss: 2400.4829 - reconstruction_loss: 2379.1653
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.4224 - loss: 2407.6614 - reconstruction_loss: 2386.2388
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.3602 - loss: 2402.8999 - reconstruction_loss: 2381.5396
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.5729 - loss: 2402.7932 - reconstruction_loss: 2381.2205
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.4625 - loss: 2409.8416 - reconstruction_loss: 2388.3792
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.6113 - loss: 2405.5056 - reconstruction_loss: 2383.8943
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.6543 - loss: 2398.4077 - reconstruction_loss: 2376.7534
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.5783 - loss: 2405.6326 - reconstruction_loss: 2384.0542
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.5178 - loss: 2399.9509 - reconstruction_loss: 2378.4333
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.6603 - loss: 2405.6152 - reconstruction_loss: 2383.9551
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.7235 - loss: 2403.3557 - reconstruction_loss: 2381.6316
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.6004 - loss: 2400.7681 - reconstruction_loss: 2379.1677
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.8845 - loss: 2405.8662 - reconstruction_loss: 2383.9812
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.8487 - loss: 2402.0581 - reconstruction_loss: 2380.2095
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.9452 - loss: 2395.7576 - reconstruction_loss: 2373.8123
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 21.9169 - loss: 2401.9617 - reconstruction_loss: 2380.0444
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 21.9663 - loss: 2397.8274 - reconstruction_loss: 2375.8613
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.9756 - loss: 2397.9446 - reconstruction_loss: 2375.9692
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.1904 - loss: 2392.2771 - reconstruction_loss: 2370.0864
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.1156 - loss: 2397.5444 - reconstruction_loss: 2375.4290
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.0598 - loss: 2402.6594 - reconstruction_loss: 2380.6001
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.1772 - loss: 2399.0142 - reconstruction_loss: 2376.8369
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.2030 - loss: 2396.0242 - reconstruction_loss: 2373.8213
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.1996 - loss: 2394.7375 - reconstruction_loss: 2372.5378
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.2557 - loss: 2397.3994 - reconstruction_loss: 2375.1438
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.2522 - loss: 2395.8860 - reconstruction_loss: 2373.6340
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 22.3881 - loss: 2397.9043 - reconstruction_loss: 2375.5161
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.3492 - loss: 2400.5327 - reconstruction_loss: 2378.1833
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.3433 - loss: 2398.9739 - reconstruction_loss: 2376.6304
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.3730 - loss: 2395.0393 - reconstruction_loss: 2372.6663
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.4349 - loss: 2394.2520 - reconstruction_loss: 2371.8171
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.4797 - loss: 2391.7959 - reconstruction_loss: 2369.3162
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 22.4281 - loss: 2395.3662 - reconstruction_loss: 2372.9382
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 22.4144 - loss: 2398.0305 - reconstruction_loss: 2375.6162
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.5700 - loss: 2391.1511 - reconstruction_loss: 2368.5813
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.6343 - loss: 2392.5723 - reconstruction_loss: 2369.9382
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.5667 - loss: 2396.2954 - reconstruction_loss: 2373.7288
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.6602 - loss: 2396.8882 - reconstruction_loss: 2374.2280
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.8388 - loss: 2388.2090 - reconstruction_loss: 2365.3704
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.6188 - loss: 2394.0281 - reconstruction_loss: 2371.4092
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.6819 - loss: 2392.2766 - reconstruction_loss: 2369.5945
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.7864 - loss: 2391.6538 - reconstruction_loss: 2368.8674
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.8337 - loss: 2389.8752 - reconstruction_loss: 2367.0417
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.9219 - loss: 2390.6375 - reconstruction_loss: 2367.7156
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.8884 - loss: 2390.2820 - reconstruction_loss: 2367.3938
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.8549 - loss: 2387.3730 - reconstruction_loss: 2364.5181
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.0302 - loss: 2387.3564 - reconstruction_loss: 2364.3262
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.1029 - loss: 2394.5085 - reconstruction_loss: 2371.4055
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 22.9597 - loss: 2386.6960 - reconstruction_loss: 2363.7366
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.1712 - loss: 2391.9651 - reconstruction_loss: 2368.7937
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 22.9449 - loss: 2385.8921 - reconstruction_loss: 2362.9473
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.0546 - loss: 2388.1458 - reconstruction_loss: 2365.0908
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.1206 - loss: 2390.2937 - reconstruction_loss: 2367.1731
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.0818 - loss: 2387.9312 - reconstruction_loss: 2364.8496
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.1689 - loss: 2389.8247 - reconstruction_loss: 2366.6558
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.0778 - loss: 2387.8413 - reconstruction_loss: 2364.7634
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.4886 - loss: 2390.4216 - reconstruction_loss: 2366.9331
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.3649 - loss: 2385.7102 - reconstruction_loss: 2362.3455
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.2915 - loss: 2386.4800 - reconstruction_loss: 2363.1885
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.3940 - loss: 2389.9602 - reconstruction_loss: 2366.5662
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.3787 - loss: 2383.0610 - reconstruction_loss: 2359.6821
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.3643 - loss: 2384.3687 - reconstruction_loss: 2361.0042
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.4040 - loss: 2387.0071 - reconstruction_loss: 2363.6035
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.4444 - loss: 2387.6343 - reconstruction_loss: 2364.1899
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.4002 - loss: 2382.6306 - reconstruction_loss: 2359.2305
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.5490 - loss: 2387.9138 - reconstruction_loss: 2364.3645
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.6400 - loss: 2379.4138 - reconstruction_loss: 2355.7737
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.5591 - loss: 2386.0928 - reconstruction_loss: 2362.5337
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.6317 - loss: 2383.3669 - reconstruction_loss: 2359.7354
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.6468 - loss: 2382.7507 - reconstruction_loss: 2359.1040
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.7869 - loss: 2381.4990 - reconstruction_loss: 2357.7119
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.6887 - loss: 2380.6265 - reconstruction_loss: 2356.9377
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.6294 - loss: 2380.8027 - reconstruction_loss: 2357.1733
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.7126 - loss: 2381.8906 - reconstruction_loss: 2358.1780
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.6705 - loss: 2378.8303 - reconstruction_loss: 2355.1597
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.7459 - loss: 2379.4888 - reconstruction_loss: 2355.7427
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.8932 - loss: 2384.8379 - reconstruction_loss: 2360.9446
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.8308 - loss: 2383.5469 - reconstruction_loss: 2359.7161
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.9583 - loss: 2377.6965 - reconstruction_loss: 2353.7385
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.7822 - loss: 2383.7527 - reconstruction_loss: 2359.9705
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.7246 - loss: 2380.0107 - reconstruction_loss: 2356.2864
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.0565 - loss: 2376.0925 - reconstruction_loss: 2352.0361
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.9358 - loss: 2375.5203 - reconstruction_loss: 2351.5845
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.8361 - loss: 2380.0820 - reconstruction_loss: 2356.2458
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.8263 - loss: 2380.0210 - reconstruction_loss: 2356.1951
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 23.8248 - loss: 2381.8196 - reconstruction_loss: 2357.9951
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.1765 - loss: 2376.8933 - reconstruction_loss: 2352.7168
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2005 - loss: 2377.8948 - reconstruction_loss: 2353.6946
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 23.9701 - loss: 2379.3049 - reconstruction_loss: 2355.3350
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.1387 - loss: 2377.4224 - reconstruction_loss: 2353.2837
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.0583 - loss: 2379.4624 - reconstruction_loss: 2355.4038
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2597 - loss: 2376.5383 - reconstruction_loss: 2352.2783
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2957 - loss: 2377.4741 - reconstruction_loss: 2353.1785
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.1346 - loss: 2377.9517 - reconstruction_loss: 2353.8169
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2221 - loss: 2373.8088 - reconstruction_loss: 2349.5867
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.3412 - loss: 2373.4700 - reconstruction_loss: 2349.1287
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2530 - loss: 2376.9900 - reconstruction_loss: 2352.7373
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.3759 - loss: 2371.5684 - reconstruction_loss: 2347.1926
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.3729 - loss: 2376.0623 - reconstruction_loss: 2351.6892
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2120 - loss: 2379.1919 - reconstruction_loss: 2354.9797
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.4790 - loss: 2374.7922 - reconstruction_loss: 2350.3132
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.1800 - loss: 2375.7761 - reconstruction_loss: 2351.5957
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.3761 - loss: 2371.6870 - reconstruction_loss: 2347.3108
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 24.3871 - loss: 2376.1348 - reconstruction_loss: 2351.7476
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.2213 - loss: 2377.1768 - reconstruction_loss: 2352.9561
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.5814 - loss: 2371.8115 - reconstruction_loss: 2347.2302
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.4112 - loss: 2376.6074 - reconstruction_loss: 2352.1965
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 24.5250 - loss: 2376.3137 - reconstruction_loss: 2351.7888
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 24.5218 - loss: 2372.3218 - reconstruction_loss: 2347.7996
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9289 - loss: 2308.5476 - reconstruction_loss: 2280.6189
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7178 - loss: 2316.6877 - reconstruction_loss: 2288.9700
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.6944 - loss: 2311.4790 - reconstruction_loss: 2283.7844
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8197 - loss: 2311.4539 - reconstruction_loss: 2283.6343
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8666 - loss: 2312.0198 - reconstruction_loss: 2284.1531
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7926 - loss: 2312.8879 - reconstruction_loss: 2285.0955
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.6745 - loss: 2313.6353 - reconstruction_loss: 2285.9612
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8295 - loss: 2311.3508 - reconstruction_loss: 2283.5210
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7710 - loss: 2311.5239 - reconstruction_loss: 2283.7532
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.6738 - loss: 2315.3826 - reconstruction_loss: 2287.7085
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8954 - loss: 2307.2598 - reconstruction_loss: 2279.3643
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8749 - loss: 2310.6155 - reconstruction_loss: 2282.7407
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.7427 - loss: 2313.2529 - reconstruction_loss: 2285.5103
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7801 - loss: 2307.4707 - reconstruction_loss: 2279.6907
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7634 - loss: 2316.4189 - reconstruction_loss: 2288.6555
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7968 - loss: 2307.8293 - reconstruction_loss: 2280.0325
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9014 - loss: 2312.8462 - reconstruction_loss: 2284.9446
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9983 - loss: 2311.7983 - reconstruction_loss: 2283.8003
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7602 - loss: 2315.0151 - reconstruction_loss: 2287.2549
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8845 - loss: 2315.6780 - reconstruction_loss: 2287.7935
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.7705 - loss: 2316.5273 - reconstruction_loss: 2288.7571
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8403 - loss: 2312.1179 - reconstruction_loss: 2284.2776
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7784 - loss: 2316.8228 - reconstruction_loss: 2289.0444
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8038 - loss: 2310.6448 - reconstruction_loss: 2282.8413
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8479 - loss: 2310.4446 - reconstruction_loss: 2282.5969
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8042 - loss: 2308.7754 - reconstruction_loss: 2280.9712
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8002 - loss: 2310.9482 - reconstruction_loss: 2283.1477
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8708 - loss: 2312.5466 - reconstruction_loss: 2284.6758
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8052 - loss: 2308.2310 - reconstruction_loss: 2280.4260
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7540 - loss: 2311.2256 - reconstruction_loss: 2283.4719
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.7305 - loss: 2305.6377 - reconstruction_loss: 2277.9072
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7865 - loss: 2308.3621 - reconstruction_loss: 2280.5752
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8242 - loss: 2311.3152 - reconstruction_loss: 2283.4910
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8807 - loss: 2310.4834 - reconstruction_loss: 2282.6025
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8174 - loss: 2312.8950 - reconstruction_loss: 2285.0776
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8875 - loss: 2311.3689 - reconstruction_loss: 2283.4812
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9452 - loss: 2305.6804 - reconstruction_loss: 2277.7351
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.7789 - loss: 2302.2966 - reconstruction_loss: 2274.5176
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.7814 - loss: 2309.6548 - reconstruction_loss: 2281.8735
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8519 - loss: 2310.6941 - reconstruction_loss: 2282.8425
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9121 - loss: 2311.8596 - reconstruction_loss: 2283.9473
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8586 - loss: 2305.2190 - reconstruction_loss: 2277.3604
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8008 - loss: 2308.3826 - reconstruction_loss: 2280.5818
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7622 - loss: 2311.2375 - reconstruction_loss: 2283.4751
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8262 - loss: 2309.9541 - reconstruction_loss: 2282.1284
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.7018 - loss: 2310.3726 - reconstruction_loss: 2282.6707
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.7833 - loss: 2317.8921 - reconstruction_loss: 2290.1091
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8359 - loss: 2309.7234 - reconstruction_loss: 2281.8875
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8097 - loss: 2309.5420 - reconstruction_loss: 2281.7322
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7902 - loss: 2312.2983 - reconstruction_loss: 2284.5081
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8611 - loss: 2305.9243 - reconstruction_loss: 2278.0632
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8703 - loss: 2310.1091 - reconstruction_loss: 2282.2388
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9442 - loss: 2307.2976 - reconstruction_loss: 2279.3535
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8888 - loss: 2306.2788 - reconstruction_loss: 2278.3904
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8572 - loss: 2306.5593 - reconstruction_loss: 2278.7021
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.9734 - loss: 2304.4626 - reconstruction_loss: 2276.4895
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8233 - loss: 2310.7253 - reconstruction_loss: 2282.9021
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.9234 - loss: 2306.8135 - reconstruction_loss: 2278.8901
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.9321 - loss: 2306.1914 - reconstruction_loss: 2278.2593
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9320 - loss: 2307.6101 - reconstruction_loss: 2279.6780
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8957 - loss: 2306.0054 - reconstruction_loss: 2278.1094
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9322 - loss: 2307.4895 - reconstruction_loss: 2279.5571
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9097 - loss: 2309.8306 - reconstruction_loss: 2281.9209
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7322 - loss: 2310.6575 - reconstruction_loss: 2282.9253
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9273 - loss: 2308.5767 - reconstruction_loss: 2280.6492
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8804 - loss: 2310.9487 - reconstruction_loss: 2283.0684
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8929 - loss: 2309.8491 - reconstruction_loss: 2281.9563
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7812 - loss: 2307.3298 - reconstruction_loss: 2279.5483
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7598 - loss: 2312.8804 - reconstruction_loss: 2285.1204
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.7671 - loss: 2312.4031 - reconstruction_loss: 2284.6362
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 28.0071 - loss: 2307.7500 - reconstruction_loss: 2279.7429
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9406 - loss: 2308.8440 - reconstruction_loss: 2280.9031
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 28.0221 - loss: 2305.0740 - reconstruction_loss: 2277.0518
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8819 - loss: 2303.9885 - reconstruction_loss: 2276.1064
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8773 - loss: 2303.6821 - reconstruction_loss: 2275.8049
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8225 - loss: 2311.7964 - reconstruction_loss: 2283.9741
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8019 - loss: 2310.5840 - reconstruction_loss: 2282.7815
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8673 - loss: 2307.8931 - reconstruction_loss: 2280.0259
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8748 - loss: 2309.1616 - reconstruction_loss: 2281.2866
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8255 - loss: 2308.2905 - reconstruction_loss: 2280.4648
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8245 - loss: 2307.0510 - reconstruction_loss: 2279.2263
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8536 - loss: 2306.2493 - reconstruction_loss: 2278.3955
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 28.0169 - loss: 2311.6802 - reconstruction_loss: 2283.6633
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9389 - loss: 2305.0005 - reconstruction_loss: 2277.0615
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8332 - loss: 2304.9868 - reconstruction_loss: 2277.1536
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8304 - loss: 2306.2224 - reconstruction_loss: 2278.3921
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9262 - loss: 2308.2493 - reconstruction_loss: 2280.3228
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8218 - loss: 2307.2461 - reconstruction_loss: 2279.4243
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8991 - loss: 2308.4658 - reconstruction_loss: 2280.5667
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9116 - loss: 2304.8560 - reconstruction_loss: 2276.9446
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9837 - loss: 2305.8425 - reconstruction_loss: 2277.8589
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8094 - loss: 2305.0742 - reconstruction_loss: 2277.2649
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8982 - loss: 2306.0374 - reconstruction_loss: 2278.1392
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 28.0116 - loss: 2305.1252 - reconstruction_loss: 2277.1135
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9461 - loss: 2308.9841 - reconstruction_loss: 2281.0381
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9660 - loss: 2307.5303 - reconstruction_loss: 2279.5640
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8259 - loss: 2308.7595 - reconstruction_loss: 2280.9338
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9832 - loss: 2311.6604 - reconstruction_loss: 2283.6772
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8763 - loss: 2306.6873 - reconstruction_loss: 2278.8110
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8419 - loss: 2308.2842 - reconstruction_loss: 2280.4421
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.8166 - loss: 2305.0103 - reconstruction_loss: 2277.1936
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9328 - loss: 2305.5576 - reconstruction_loss: 2277.6248
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 28.0021 - loss: 2304.9006 - reconstruction_loss: 2276.8984
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9077 - loss: 2307.5828 - reconstruction_loss: 2279.6750
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8911 - loss: 2308.9148 - reconstruction_loss: 2281.0242
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9640 - loss: 2306.6084 - reconstruction_loss: 2278.6443
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9672 - loss: 2304.4268 - reconstruction_loss: 2276.4595
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 28.0334 - loss: 2304.9031 - reconstruction_loss: 2276.8704
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.9308 - loss: 2309.2449 - reconstruction_loss: 2281.3142
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.9442 - loss: 2304.8342 - reconstruction_loss: 2276.8901
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8351 - loss: 2312.0288 - reconstruction_loss: 2284.1938
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8551 - loss: 2309.5901 - reconstruction_loss: 2281.7351
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 27.8596 - loss: 2312.4849 - reconstruction_loss: 2284.6255
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9119 - loss: 2306.1711 - reconstruction_loss: 2278.2593
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 28.0066 - loss: 2304.0156 - reconstruction_loss: 2276.0090
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9893 - loss: 2311.4270 - reconstruction_loss: 2283.4375
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8921 - loss: 2306.7966 - reconstruction_loss: 2278.9048
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8629 - loss: 2307.5012 - reconstruction_loss: 2279.6384
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9014 - loss: 2313.1648 - reconstruction_loss: 2285.2632
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9289 - loss: 2304.8782 - reconstruction_loss: 2276.9490
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 28.0044 - loss: 2307.8005 - reconstruction_loss: 2279.7964
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9846 - loss: 2305.3362 - reconstruction_loss: 2277.3513
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9269 - loss: 2306.4680 - reconstruction_loss: 2278.5413
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9513 - loss: 2303.0027 - reconstruction_loss: 2275.0513
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.8613 - loss: 2304.1233 - reconstruction_loss: 2276.2617
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9769 - loss: 2306.3320 - reconstruction_loss: 2278.3552
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 27.9232 - loss: 2307.3513 - reconstruction_loss: 2279.4280
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 27.9486 - loss: 2306.8892 - reconstruction_loss: 2278.9407

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'CONTAINERSHIP': 100%|█████████████████████████████████████████████| 540/540 [04:28<00:00,  2.01it/s]
# FID = 45.8021240234375
