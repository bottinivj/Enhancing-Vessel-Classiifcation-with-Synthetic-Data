# %%
generating_class = 'PASSENGERSSHIP'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-24 17:28:15.412477: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-24 17:28:15.432761: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-24 17:28:17.244128: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:17.247113: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:17.247129: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-24 17:28:30.606122: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:30.606158: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:30.606168: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:30.732425: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:30.732454: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:30.732459: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-24 17:28:30.732474: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-24 17:28:30.732491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-24 17:29:15.519725: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-24 17:29:15.519761: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753378156.604529   21811 service.cc:145] XLA service 0x7f95a0014330 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753378156.604563   21811 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-24 17:29:16.662883: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-24 17:29:16.842713: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-24 17:29:22.871255: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:22.937366: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.066224842s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:34.542805: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:35.244433: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.701714163s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:36.244571: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:36.887628: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.643138224s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:37.887756: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:38.639605: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.751915295s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:39.639726: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-24 17:29:40.207495: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.567836524s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753378187.414933   21811 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 460ms/step - kl_loss: 7.8614e-07 - loss: 2839.0046 - reconstruction_loss: 2839.0046
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 9.4013e-04 - loss: 2838.2590 - reconstruction_loss: 2838.2581
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 1.0333 - loss: 2834.4299 - reconstruction_loss: 2833.3965
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 7.1939 - loss: 2804.9524 - reconstruction_loss: 2797.7585
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 4.5516 - loss: 2770.4851 - reconstruction_loss: 2765.9333
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 6.3248 - loss: 2738.9551 - reconstruction_loss: 2732.6301
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 8.6905 - loss: 2725.9734 - reconstruction_loss: 2717.2832
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 8.6902 - loss: 2711.7334 - reconstruction_loss: 2703.0432
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 7.9068 - loss: 2699.3240 - reconstruction_loss: 2691.4172
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 8.1505 - loss: 2688.6582 - reconstruction_loss: 2680.5076
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 8.0125 - loss: 2679.6438 - reconstruction_loss: 2671.6311
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 8.2277 - loss: 2676.5371 - reconstruction_loss: 2668.3091
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 8.4487 - loss: 2667.9473 - reconstruction_loss: 2659.4985
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 8.6346 - loss: 2660.8289 - reconstruction_loss: 2652.1943
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 8.9565 - loss: 2652.5432 - reconstruction_loss: 2643.5867
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 9.2819 - loss: 2646.6663 - reconstruction_loss: 2637.3843
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 9.8116 - loss: 2641.2397 - reconstruction_loss: 2631.4282
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 10.1231 - loss: 2636.1946 - reconstruction_loss: 2626.0713
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 10.5590 - loss: 2632.7539 - reconstruction_loss: 2622.1946
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 10.1456 - loss: 2629.0605 - reconstruction_loss: 2618.9148
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 9.7949 - loss: 2626.8533 - reconstruction_loss: 2617.0583
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 9.7475 - loss: 2621.5632 - reconstruction_loss: 2611.8157
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 9.7119 - loss: 2619.4890 - reconstruction_loss: 2609.7773
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 9.8039 - loss: 2615.1838 - reconstruction_loss: 2605.3799
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 9.8668 - loss: 2612.4629 - reconstruction_loss: 2602.5962
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 10.7080 - loss: 2609.2915 - reconstruction_loss: 2598.5835
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 11.7491 - loss: 2604.8843 - reconstruction_loss: 2593.1355
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 11.7538 - loss: 2599.7905 - reconstruction_loss: 2588.0366
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - kl_loss: 11.1190 - loss: 2600.6453 - reconstruction_loss: 2589.5264
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 11.2191 - loss: 2595.3870 - reconstruction_loss: 2584.1677
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 11.4248 - loss: 2594.2312 - reconstruction_loss: 2582.8064
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 11.6916 - loss: 2591.2214 - reconstruction_loss: 2579.5300
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 12.1492 - loss: 2588.8289 - reconstruction_loss: 2576.6797
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 12.3076 - loss: 2585.8352 - reconstruction_loss: 2573.5276
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 12.5162 - loss: 2585.3694 - reconstruction_loss: 2572.8535
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 13.0505 - loss: 2580.6672 - reconstruction_loss: 2567.6169
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.0565 - loss: 2580.3452 - reconstruction_loss: 2567.2886
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.6252 - loss: 2577.9668 - reconstruction_loss: 2564.3418
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.5844 - loss: 2578.1873 - reconstruction_loss: 2564.6030
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.7057 - loss: 2577.7024 - reconstruction_loss: 2563.9966
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 13.7574 - loss: 2574.2446 - reconstruction_loss: 2560.4873
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.9107 - loss: 2571.6282 - reconstruction_loss: 2557.7173
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 13.7660 - loss: 2574.4717 - reconstruction_loss: 2560.7058
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 13.8432 - loss: 2569.0195 - reconstruction_loss: 2555.1760
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.9288 - loss: 2566.9963 - reconstruction_loss: 2553.0676
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.7494 - loss: 2567.0115 - reconstruction_loss: 2553.2620
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.8894 - loss: 2568.7573 - reconstruction_loss: 2554.8679
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.8977 - loss: 2562.8589 - reconstruction_loss: 2548.9614
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 13.6797 - loss: 2566.2966 - reconstruction_loss: 2552.6169
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 13.9607 - loss: 2560.7275 - reconstruction_loss: 2546.7671
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 14.1620 - loss: 2559.0203 - reconstruction_loss: 2544.8584
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 14.1475 - loss: 2561.5303 - reconstruction_loss: 2547.3831
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 14.2231 - loss: 2561.9216 - reconstruction_loss: 2547.6985
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 14.5972 - loss: 2558.8792 - reconstruction_loss: 2544.2822
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 15.0772 - loss: 2557.5466 - reconstruction_loss: 2542.4695
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 15.0983 - loss: 2557.6938 - reconstruction_loss: 2542.5955
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 14.9396 - loss: 2554.3274 - reconstruction_loss: 2539.3882
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 15.2330 - loss: 2552.9731 - reconstruction_loss: 2537.7402
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 15.1503 - loss: 2553.5330 - reconstruction_loss: 2538.3826
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 15.3209 - loss: 2554.9143 - reconstruction_loss: 2539.5935
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 15.2405 - loss: 2549.6196 - reconstruction_loss: 2534.3792
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 15.4767 - loss: 2551.1270 - reconstruction_loss: 2535.6504
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 15.7793 - loss: 2548.2632 - reconstruction_loss: 2532.4836
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 16.0337 - loss: 2550.4990 - reconstruction_loss: 2534.4651
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 15.9735 - loss: 2544.5237 - reconstruction_loss: 2528.5505
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 16.0270 - loss: 2550.6233 - reconstruction_loss: 2534.5962
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 16.3127 - loss: 2548.0767 - reconstruction_loss: 2531.7637
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 16.2715 - loss: 2544.0850 - reconstruction_loss: 2527.8132
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 16.3515 - loss: 2544.7373 - reconstruction_loss: 2528.3857
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 16.3931 - loss: 2542.1587 - reconstruction_loss: 2525.7656
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 16.5496 - loss: 2540.8403 - reconstruction_loss: 2524.2910
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 16.6091 - loss: 2540.5913 - reconstruction_loss: 2523.9819
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 16.8187 - loss: 2540.4617 - reconstruction_loss: 2523.6431
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 16.9417 - loss: 2540.7878 - reconstruction_loss: 2523.8459
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.0607 - loss: 2541.2732 - reconstruction_loss: 2524.2126
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.2911 - loss: 2539.2229 - reconstruction_loss: 2521.9316
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.3501 - loss: 2540.4746 - reconstruction_loss: 2523.1245
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 17.2892 - loss: 2540.1118 - reconstruction_loss: 2522.8228
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.3992 - loss: 2542.6431 - reconstruction_loss: 2525.2441
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.6562 - loss: 2538.7888 - reconstruction_loss: 2521.1328
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 17.8287 - loss: 2534.3469 - reconstruction_loss: 2516.5181
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 17.6063 - loss: 2535.9822 - reconstruction_loss: 2518.3757
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.7440 - loss: 2535.2524 - reconstruction_loss: 2517.5085
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 17.9686 - loss: 2531.6750 - reconstruction_loss: 2513.7068
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 17.9795 - loss: 2536.1436 - reconstruction_loss: 2518.1643
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 17.9041 - loss: 2534.1350 - reconstruction_loss: 2516.2310
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 18.4006 - loss: 2533.4182 - reconstruction_loss: 2515.0176
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 18.3071 - loss: 2534.0642 - reconstruction_loss: 2515.7571
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 18.3797 - loss: 2534.2034 - reconstruction_loss: 2515.8240
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 18.5866 - loss: 2532.0837 - reconstruction_loss: 2513.4973
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 18.6453 - loss: 2533.0444 - reconstruction_loss: 2514.3992
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 18.7095 - loss: 2533.4431 - reconstruction_loss: 2514.7336
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 18.8632 - loss: 2526.8384 - reconstruction_loss: 2507.9751
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 18.7568 - loss: 2534.6482 - reconstruction_loss: 2515.8911
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 19.0263 - loss: 2529.5991 - reconstruction_loss: 2510.5728
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 19.1827 - loss: 2528.8181 - reconstruction_loss: 2509.6355
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 19.2371 - loss: 2527.7737 - reconstruction_loss: 2508.5369
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 19.3164 - loss: 2531.3127 - reconstruction_loss: 2511.9961
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 19.4188 - loss: 2528.1841 - reconstruction_loss: 2508.7654
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 19.5787 - loss: 2527.6375 - reconstruction_loss: 2508.0588
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 19.3006 - loss: 2527.3481 - reconstruction_loss: 2508.0476
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 19.5732 - loss: 2525.2905 - reconstruction_loss: 2505.7175
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 19.6565 - loss: 2525.4873 - reconstruction_loss: 2505.8306
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 19.8839 - loss: 2522.5684 - reconstruction_loss: 2502.6843
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 19.9230 - loss: 2526.5093 - reconstruction_loss: 2506.5862
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 19.7873 - loss: 2522.9841 - reconstruction_loss: 2503.1968
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 19.7280 - loss: 2524.6624 - reconstruction_loss: 2504.9343
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 19.9717 - loss: 2525.5308 - reconstruction_loss: 2505.5591
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.0202 - loss: 2520.7073 - reconstruction_loss: 2500.6870
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 19.9449 - loss: 2519.6611 - reconstruction_loss: 2499.7166
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.0391 - loss: 2524.0601 - reconstruction_loss: 2504.0210
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.1322 - loss: 2523.5811 - reconstruction_loss: 2503.4490
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.2292 - loss: 2523.4617 - reconstruction_loss: 2503.2324
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.2014 - loss: 2522.9016 - reconstruction_loss: 2502.7000
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.4626 - loss: 2521.0227 - reconstruction_loss: 2500.5601
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.5133 - loss: 2520.6079 - reconstruction_loss: 2500.0945
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.3606 - loss: 2521.9885 - reconstruction_loss: 2501.6279
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.6636 - loss: 2523.1396 - reconstruction_loss: 2502.4761
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.7343 - loss: 2523.5271 - reconstruction_loss: 2502.7927
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.7646 - loss: 2516.4897 - reconstruction_loss: 2495.7251
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.7777 - loss: 2519.0054 - reconstruction_loss: 2498.2273
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.6521 - loss: 2520.1648 - reconstruction_loss: 2499.5129
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 20.8182 - loss: 2520.3279 - reconstruction_loss: 2499.5098
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.8717 - loss: 2515.3845 - reconstruction_loss: 2494.5129
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.8737 - loss: 2517.2793 - reconstruction_loss: 2496.4055
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 20.9068 - loss: 2518.1597 - reconstruction_loss: 2497.2532
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.1223 - loss: 2514.4382 - reconstruction_loss: 2493.3159
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.0749 - loss: 2518.1721 - reconstruction_loss: 2497.0974
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 21.1047 - loss: 2518.2783 - reconstruction_loss: 2497.1738
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.2095 - loss: 2516.8213 - reconstruction_loss: 2495.6118
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.0594 - loss: 2517.6335 - reconstruction_loss: 2496.5740
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 20.9360 - loss: 2517.9958 - reconstruction_loss: 2497.0596
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.2492 - loss: 2513.7656 - reconstruction_loss: 2492.5164
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 21.1582 - loss: 2513.7334 - reconstruction_loss: 2492.5750
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 21.1462 - loss: 2516.1643 - reconstruction_loss: 2495.0186
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.2531 - loss: 2511.4983 - reconstruction_loss: 2490.2456
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.3603 - loss: 2513.8345 - reconstruction_loss: 2492.4741
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.2681 - loss: 2512.8379 - reconstruction_loss: 2491.5698
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.3168 - loss: 2511.1091 - reconstruction_loss: 2489.7925
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 21.5523 - loss: 2513.2805 - reconstruction_loss: 2491.7280
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.5343 - loss: 2511.8604 - reconstruction_loss: 2490.3259
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 21.4552 - loss: 2513.5002 - reconstruction_loss: 2492.0452
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.5678 - loss: 2513.3323 - reconstruction_loss: 2491.7644
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.5652 - loss: 2514.9272 - reconstruction_loss: 2493.3621
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.5716 - loss: 2511.7095 - reconstruction_loss: 2490.1379
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.6319 - loss: 2510.4443 - reconstruction_loss: 2488.8123
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.8198 - loss: 2511.8687 - reconstruction_loss: 2490.0488
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.7062 - loss: 2511.4495 - reconstruction_loss: 2489.7434
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 21.7351 - loss: 2509.0850 - reconstruction_loss: 2487.3496
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 21.7947 - loss: 2505.8162 - reconstruction_loss: 2484.0217
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.7822 - loss: 2511.0889 - reconstruction_loss: 2489.3066
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 21.8796 - loss: 2504.7307 - reconstruction_loss: 2482.8508
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 21.9511 - loss: 2509.5427 - reconstruction_loss: 2487.5916
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 21.9506 - loss: 2506.9238 - reconstruction_loss: 2484.9729
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.1843 - loss: 2509.8167 - reconstruction_loss: 2487.6326
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.1424 - loss: 2505.4871 - reconstruction_loss: 2483.3447
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.1022 - loss: 2506.2351 - reconstruction_loss: 2484.1331
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 22.1850 - loss: 2508.3782 - reconstruction_loss: 2486.1934
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.2173 - loss: 2507.4617 - reconstruction_loss: 2485.2444
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 22.3577 - loss: 2502.0527 - reconstruction_loss: 2479.6951
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.3599 - loss: 2506.0989 - reconstruction_loss: 2483.7388
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.3075 - loss: 2504.9114 - reconstruction_loss: 2482.6040
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.3623 - loss: 2505.1802 - reconstruction_loss: 2482.8179
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.3314 - loss: 2501.2068 - reconstruction_loss: 2478.8748
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.3916 - loss: 2502.2830 - reconstruction_loss: 2479.8914
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 22.5294 - loss: 2505.1853 - reconstruction_loss: 2482.6560
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.5031 - loss: 2503.2759 - reconstruction_loss: 2480.7729
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.5279 - loss: 2500.3721 - reconstruction_loss: 2477.8440
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.6754 - loss: 2504.2156 - reconstruction_loss: 2481.5400
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.5846 - loss: 2503.0493 - reconstruction_loss: 2480.4646
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.5279 - loss: 2503.8462 - reconstruction_loss: 2481.3181
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.6981 - loss: 2504.2654 - reconstruction_loss: 2481.5671
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.8904 - loss: 2499.1335 - reconstruction_loss: 2476.2432
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 22.8601 - loss: 2500.5574 - reconstruction_loss: 2477.6973
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.8172 - loss: 2497.7468 - reconstruction_loss: 2474.9299
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.7453 - loss: 2498.3948 - reconstruction_loss: 2475.6489
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.0067 - loss: 2498.0684 - reconstruction_loss: 2475.0618
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 22.9840 - loss: 2497.0103 - reconstruction_loss: 2474.0261
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.0195 - loss: 2495.0625 - reconstruction_loss: 2472.0427
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.1235 - loss: 2499.9705 - reconstruction_loss: 2476.8469
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.2465 - loss: 2498.2080 - reconstruction_loss: 2474.9617
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.3226 - loss: 2499.7832 - reconstruction_loss: 2476.4607
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.2258 - loss: 2497.1340 - reconstruction_loss: 2473.9082
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.2854 - loss: 2497.1711 - reconstruction_loss: 2473.8857
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.3958 - loss: 2496.7734 - reconstruction_loss: 2473.3774
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.3369 - loss: 2495.3235 - reconstruction_loss: 2471.9863
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.4186 - loss: 2496.4954 - reconstruction_loss: 2473.0767
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.2460 - loss: 2497.7874 - reconstruction_loss: 2474.5415
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.4038 - loss: 2495.6318 - reconstruction_loss: 2472.2278
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.4468 - loss: 2492.9382 - reconstruction_loss: 2469.4917
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.6382 - loss: 2494.3181 - reconstruction_loss: 2470.6799
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 23.6868 - loss: 2495.2324 - reconstruction_loss: 2471.5454
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.5415 - loss: 2492.9133 - reconstruction_loss: 2469.3718
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 23.6168 - loss: 2492.2673 - reconstruction_loss: 2468.6506
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.6957 - loss: 2490.2683 - reconstruction_loss: 2466.5725
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.7634 - loss: 2487.6084 - reconstruction_loss: 2463.8450
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.9281 - loss: 2491.7671 - reconstruction_loss: 2467.8391
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.7399 - loss: 2494.3743 - reconstruction_loss: 2470.6343
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.7887 - loss: 2488.9731 - reconstruction_loss: 2465.1843
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 23.8539 - loss: 2491.9644 - reconstruction_loss: 2468.1108
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.9737 - loss: 2491.4221 - reconstruction_loss: 2467.4482
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.0345 - loss: 2487.2029 - reconstruction_loss: 2463.1687
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.0430 - loss: 2488.7163 - reconstruction_loss: 2464.6731
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 23.9514 - loss: 2486.4973 - reconstruction_loss: 2462.5459
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 24.3910 - loss: 2485.0034 - reconstruction_loss: 2460.6125
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.1389 - loss: 2488.9290 - reconstruction_loss: 2464.7898
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.0116 - loss: 2486.6833 - reconstruction_loss: 2462.6716
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.0868 - loss: 2491.3345 - reconstruction_loss: 2467.2480
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.1641 - loss: 2489.6165 - reconstruction_loss: 2465.4524
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.1960 - loss: 2482.4050 - reconstruction_loss: 2458.2092
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.2147 - loss: 2486.2544 - reconstruction_loss: 2462.0398
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.1938 - loss: 2484.3210 - reconstruction_loss: 2460.1274
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.2746 - loss: 2487.1592 - reconstruction_loss: 2462.8845
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 24.3077 - loss: 2486.2107 - reconstruction_loss: 2461.9031
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.3226 - loss: 2487.6008 - reconstruction_loss: 2463.2781
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.4615 - loss: 2487.5710 - reconstruction_loss: 2463.1094
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.5569 - loss: 2485.7878 - reconstruction_loss: 2461.2310
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.4736 - loss: 2484.1914 - reconstruction_loss: 2459.7180
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.4973 - loss: 2485.0393 - reconstruction_loss: 2460.5417
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.4872 - loss: 2483.1794 - reconstruction_loss: 2458.6921
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.6453 - loss: 2480.5918 - reconstruction_loss: 2455.9463
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.5704 - loss: 2481.5522 - reconstruction_loss: 2456.9819
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.5781 - loss: 2480.5659 - reconstruction_loss: 2455.9880
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.7363 - loss: 2482.0776 - reconstruction_loss: 2457.3411
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.6886 - loss: 2477.1101 - reconstruction_loss: 2452.4219
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.7506 - loss: 2481.9453 - reconstruction_loss: 2457.1951
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.5577 - loss: 2481.7122 - reconstruction_loss: 2457.1545
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.6791 - loss: 2483.7820 - reconstruction_loss: 2459.1033
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.6875 - loss: 2479.6023 - reconstruction_loss: 2454.9148
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.8563 - loss: 2477.1782 - reconstruction_loss: 2452.3223
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.7874 - loss: 2484.0117 - reconstruction_loss: 2459.2244
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.8392 - loss: 2481.3616 - reconstruction_loss: 2456.5222
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 24.9370 - loss: 2477.2615 - reconstruction_loss: 2452.3247
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.8108 - loss: 2478.4756 - reconstruction_loss: 2453.6648
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.0988 - loss: 2480.1428 - reconstruction_loss: 2455.0442
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 24.9941 - loss: 2478.7607 - reconstruction_loss: 2453.7666
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.8926 - loss: 2479.3306 - reconstruction_loss: 2454.4380
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.0031 - loss: 2477.0427 - reconstruction_loss: 2452.0393
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.1012 - loss: 2473.4692 - reconstruction_loss: 2448.3682
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.1328 - loss: 2476.2720 - reconstruction_loss: 2451.1389
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.9925 - loss: 2474.2068 - reconstruction_loss: 2449.2144
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 24.9295 - loss: 2473.4517 - reconstruction_loss: 2448.5222
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.1628 - loss: 2470.3545 - reconstruction_loss: 2445.1917
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.3016 - loss: 2478.2004 - reconstruction_loss: 2452.8987
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.1681 - loss: 2474.8821 - reconstruction_loss: 2449.7141
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.3147 - loss: 2472.7937 - reconstruction_loss: 2447.4790
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.1915 - loss: 2473.0203 - reconstruction_loss: 2447.8289
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.2514 - loss: 2472.9919 - reconstruction_loss: 2447.7405
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.2581 - loss: 2474.6934 - reconstruction_loss: 2449.4355
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.3955 - loss: 2472.0913 - reconstruction_loss: 2446.6960
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 25.3398 - loss: 2473.8037 - reconstruction_loss: 2448.4639
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.2099 - loss: 2475.5105 - reconstruction_loss: 2450.3005
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.3229 - loss: 2471.6733 - reconstruction_loss: 2446.3501
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.5609 - loss: 2470.4897 - reconstruction_loss: 2444.9290
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.3389 - loss: 2472.4741 - reconstruction_loss: 2447.1353
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 25.5221 - loss: 2471.5974 - reconstruction_loss: 2446.0754
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 25.5776 - loss: 2472.4058 - reconstruction_loss: 2446.8281
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 25.5176 - loss: 2469.5269 - reconstruction_loss: 2444.0090
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 25.3257 - loss: 2470.2063 - reconstruction_loss: 2444.8804
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.4822 - loss: 2472.2236 - reconstruction_loss: 2446.7415
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.7199 - loss: 2469.7056 - reconstruction_loss: 2443.9858
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.5951 - loss: 2471.2466 - reconstruction_loss: 2445.6516
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.5698 - loss: 2470.8491 - reconstruction_loss: 2445.2791
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.5679 - loss: 2465.4829 - reconstruction_loss: 2439.9150
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.5687 - loss: 2465.3679 - reconstruction_loss: 2439.7988
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.6850 - loss: 2465.1846 - reconstruction_loss: 2439.4993
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.6011 - loss: 2467.5662 - reconstruction_loss: 2441.9651
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.8333 - loss: 2466.2302 - reconstruction_loss: 2440.3970
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 25.7044 - loss: 2466.0889 - reconstruction_loss: 2440.3848
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.6530 - loss: 2466.5867 - reconstruction_loss: 2440.9338
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 25.8563 - loss: 2470.0564 - reconstruction_loss: 2444.2000
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 25.7796 - loss: 2466.6062 - reconstruction_loss: 2440.8267
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 25.9256 - loss: 2461.2998 - reconstruction_loss: 2435.3743
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.8787 - loss: 2466.3042 - reconstruction_loss: 2440.4255
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.8654 - loss: 2464.6899 - reconstruction_loss: 2438.8245
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 26.0280 - loss: 2466.1091 - reconstruction_loss: 2440.0811
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.9532 - loss: 2462.0710 - reconstruction_loss: 2436.1179
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.8207 - loss: 2464.1809 - reconstruction_loss: 2438.3601
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 26.0767 - loss: 2462.1587 - reconstruction_loss: 2436.0820
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 25.8916 - loss: 2466.7515 - reconstruction_loss: 2440.8601
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 26.0220 - loss: 2466.1726 - reconstruction_loss: 2440.1509
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 26.0631 - loss: 2463.7263 - reconstruction_loss: 2437.6631
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.9831 - loss: 2464.7603 - reconstruction_loss: 2438.7771
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 25.9859 - loss: 2465.5315 - reconstruction_loss: 2439.5454
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 26.0030 - loss: 2465.0068 - reconstruction_loss: 2439.0037
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 25.9937 - loss: 2464.1711 - reconstruction_loss: 2438.1772
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 26.0969 - loss: 2464.8770 - reconstruction_loss: 2438.7798
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.1107 - loss: 2384.8496 - reconstruction_loss: 2355.7388
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.0204 - loss: 2389.4768 - reconstruction_loss: 2360.4568
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0228 - loss: 2384.9668 - reconstruction_loss: 2355.9438
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0382 - loss: 2386.1775 - reconstruction_loss: 2357.1392
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0726 - loss: 2387.1384 - reconstruction_loss: 2358.0657
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0622 - loss: 2389.5623 - reconstruction_loss: 2360.5002
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.0969 - loss: 2386.3440 - reconstruction_loss: 2357.2471
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0525 - loss: 2387.5852 - reconstruction_loss: 2358.5325
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0467 - loss: 2389.2620 - reconstruction_loss: 2360.2151
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0274 - loss: 2385.0515 - reconstruction_loss: 2356.0239
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0378 - loss: 2390.0720 - reconstruction_loss: 2361.0339
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0148 - loss: 2386.5359 - reconstruction_loss: 2357.5210
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 29.0725 - loss: 2385.2500 - reconstruction_loss: 2356.1772
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0690 - loss: 2387.1968 - reconstruction_loss: 2358.1282
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.0009 - loss: 2386.9658 - reconstruction_loss: 2357.9648
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0461 - loss: 2387.3179 - reconstruction_loss: 2358.2717
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1946 - loss: 2386.5205 - reconstruction_loss: 2357.3262
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1606 - loss: 2387.9065 - reconstruction_loss: 2358.7458
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0207 - loss: 2389.5918 - reconstruction_loss: 2360.5710
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.2165 - loss: 2386.3157 - reconstruction_loss: 2357.0991
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1135 - loss: 2385.8984 - reconstruction_loss: 2356.7852
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1101 - loss: 2387.2556 - reconstruction_loss: 2358.1453
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0656 - loss: 2386.8438 - reconstruction_loss: 2357.7781
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0968 - loss: 2385.3750 - reconstruction_loss: 2356.2781
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0742 - loss: 2386.9690 - reconstruction_loss: 2357.8950
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.0470 - loss: 2386.9182 - reconstruction_loss: 2357.8706
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1309 - loss: 2388.3496 - reconstruction_loss: 2359.2185
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0853 - loss: 2392.7439 - reconstruction_loss: 2363.6587
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0975 - loss: 2387.8845 - reconstruction_loss: 2358.7869
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0995 - loss: 2391.7688 - reconstruction_loss: 2362.6694
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0197 - loss: 2387.5852 - reconstruction_loss: 2358.5657
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.0319 - loss: 2388.2720 - reconstruction_loss: 2359.2400
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0844 - loss: 2387.0388 - reconstruction_loss: 2357.9546
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0906 - loss: 2387.4038 - reconstruction_loss: 2358.3130
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.0254 - loss: 2389.1711 - reconstruction_loss: 2360.1460
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0746 - loss: 2389.2690 - reconstruction_loss: 2360.1943
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1766 - loss: 2390.6685 - reconstruction_loss: 2361.4917
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1473 - loss: 2382.2747 - reconstruction_loss: 2353.1272
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.0530 - loss: 2390.6777 - reconstruction_loss: 2361.6248
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1547 - loss: 2384.3801 - reconstruction_loss: 2355.2253
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1350 - loss: 2387.7883 - reconstruction_loss: 2358.6536
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 29.0650 - loss: 2385.7700 - reconstruction_loss: 2356.7048
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.0660 - loss: 2386.6448 - reconstruction_loss: 2357.5786
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.0204 - loss: 2389.8972 - reconstruction_loss: 2360.8770
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1334 - loss: 2386.9724 - reconstruction_loss: 2357.8394
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 28.9900 - loss: 2391.5000 - reconstruction_loss: 2362.5103
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1759 - loss: 2388.9189 - reconstruction_loss: 2359.7432
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.0999 - loss: 2383.9829 - reconstruction_loss: 2354.8831
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.0864 - loss: 2386.9470 - reconstruction_loss: 2357.8608
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.1548 - loss: 2386.1504 - reconstruction_loss: 2356.9956
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.0805 - loss: 2386.4688 - reconstruction_loss: 2357.3882
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1450 - loss: 2388.2056 - reconstruction_loss: 2359.0603
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1508 - loss: 2387.5212 - reconstruction_loss: 2358.3704
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.2257 - loss: 2387.3262 - reconstruction_loss: 2358.1001
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1262 - loss: 2386.9407 - reconstruction_loss: 2357.8140
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1970 - loss: 2384.2930 - reconstruction_loss: 2355.0962
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.0894 - loss: 2385.1003 - reconstruction_loss: 2356.0110
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.0872 - loss: 2390.8213 - reconstruction_loss: 2361.7341
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.2120 - loss: 2386.0032 - reconstruction_loss: 2356.7910
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 29.0825 - loss: 2383.6111 - reconstruction_loss: 2354.5286
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1368 - loss: 2386.7725 - reconstruction_loss: 2357.6357
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.2699 - loss: 2384.5635 - reconstruction_loss: 2355.2937
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.0837 - loss: 2385.6445 - reconstruction_loss: 2356.5605
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.0639 - loss: 2388.1814 - reconstruction_loss: 2359.1174
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1847 - loss: 2388.1592 - reconstruction_loss: 2358.9744
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - kl_loss: 29.1106 - loss: 2388.9180 - reconstruction_loss: 2359.8076
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1953 - loss: 2386.8523 - reconstruction_loss: 2357.6570
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.0839 - loss: 2386.4355 - reconstruction_loss: 2357.3516
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.1071 - loss: 2384.5640 - reconstruction_loss: 2355.4565
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 29.1181 - loss: 2387.9038 - reconstruction_loss: 2358.7859
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1435 - loss: 2387.4102 - reconstruction_loss: 2358.2668
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 29.2589 - loss: 2387.5032 - reconstruction_loss: 2358.2441
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1892 - loss: 2389.1433 - reconstruction_loss: 2359.9541
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1456 - loss: 2385.3992 - reconstruction_loss: 2356.2537
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1500 - loss: 2386.2942 - reconstruction_loss: 2357.1443
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1141 - loss: 2381.9517 - reconstruction_loss: 2352.8379
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1573 - loss: 2380.5476 - reconstruction_loss: 2351.3899
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - kl_loss: 29.0845 - loss: 2384.3831 - reconstruction_loss: 2355.2986
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.0199 - loss: 2386.3606 - reconstruction_loss: 2357.3406
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - kl_loss: 29.1179 - loss: 2384.6841 - reconstruction_loss: 2355.5667
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 29.0974 - loss: 2383.6096 - reconstruction_loss: 2354.5125
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1190 - loss: 2383.8513 - reconstruction_loss: 2354.7322
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1340 - loss: 2385.1716 - reconstruction_loss: 2356.0376
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.2154 - loss: 2386.4207 - reconstruction_loss: 2357.2053
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - kl_loss: 29.1723 - loss: 2383.5757 - reconstruction_loss: 2354.4033
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 29.1089 - loss: 2387.9023 - reconstruction_loss: 2358.7935
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - kl_loss: 29.1595 - loss: 2386.8684 - reconstruction_loss: 2357.7087
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0192 - loss: 2387.9761 - reconstruction_loss: 2358.9570
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1287 - loss: 2384.4329 - reconstruction_loss: 2355.3040
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0380 - loss: 2386.1382 - reconstruction_loss: 2357.1001
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1334 - loss: 2381.6660 - reconstruction_loss: 2352.5327
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.2336 - loss: 2386.5442 - reconstruction_loss: 2357.3105
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.2509 - loss: 2384.6348 - reconstruction_loss: 2355.3840
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.1202 - loss: 2388.6445 - reconstruction_loss: 2359.5242
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.1679 - loss: 2385.9417 - reconstruction_loss: 2356.7737
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0928 - loss: 2384.1733 - reconstruction_loss: 2355.0806
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.1805 - loss: 2381.6802 - reconstruction_loss: 2352.4998
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - kl_loss: 29.1742 - loss: 2388.7122 - reconstruction_loss: 2359.5381
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1815 - loss: 2386.0593 - reconstruction_loss: 2356.8774
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.2033 - loss: 2381.5635 - reconstruction_loss: 2352.3601
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0900 - loss: 2382.3999 - reconstruction_loss: 2353.3103
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.0667 - loss: 2383.0254 - reconstruction_loss: 2353.9585
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1834 - loss: 2384.8806 - reconstruction_loss: 2355.6973
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.2452 - loss: 2385.5984 - reconstruction_loss: 2356.3535
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.2645 - loss: 2384.2319 - reconstruction_loss: 2354.9678
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1584 - loss: 2382.2727 - reconstruction_loss: 2353.1143
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.2068 - loss: 2388.0332 - reconstruction_loss: 2358.8262
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.3314 - loss: 2385.8708 - reconstruction_loss: 2356.5396
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.2311 - loss: 2381.1924 - reconstruction_loss: 2351.9612
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.2133 - loss: 2381.8025 - reconstruction_loss: 2352.5891
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.2240 - loss: 2385.3301 - reconstruction_loss: 2356.1057
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1505 - loss: 2384.7317 - reconstruction_loss: 2355.5811
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1566 - loss: 2385.5735 - reconstruction_loss: 2356.4170
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.2345 - loss: 2383.5876 - reconstruction_loss: 2354.3530
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - kl_loss: 29.1589 - loss: 2387.8484 - reconstruction_loss: 2358.6892
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1853 - loss: 2381.8540 - reconstruction_loss: 2352.6689
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1835 - loss: 2387.6221 - reconstruction_loss: 2358.4382
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1404 - loss: 2383.0859 - reconstruction_loss: 2353.9456
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.2246 - loss: 2384.9465 - reconstruction_loss: 2355.7219
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1915 - loss: 2382.5225 - reconstruction_loss: 2353.3308
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1282 - loss: 2386.3718 - reconstruction_loss: 2357.2439
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.1665 - loss: 2386.5037 - reconstruction_loss: 2357.3372
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1317 - loss: 2386.7942 - reconstruction_loss: 2357.6626
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1786 - loss: 2384.8379 - reconstruction_loss: 2355.6594
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.3294 - loss: 2378.7107 - reconstruction_loss: 2349.3813
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - kl_loss: 29.1549 - loss: 2386.2173 - reconstruction_loss: 2357.0625
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 29.1883 - loss: 2384.0278 - reconstruction_loss: 2354.8396
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 29.1774 - loss: 2385.1279 - reconstruction_loss: 2355.9500

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'PASSENGERSSHIP': 100%|████████████████████████████████████████████| 540/540 [04:20<00:00,  2.07it/s]
# FID = 109.999755859375
