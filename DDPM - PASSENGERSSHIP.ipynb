# %%
generating_class = 'PASSENGERSSHIP'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-01-31 11:29:48.615944: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-31 11:29:48.636887: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-01-31 11:29:49.465044: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.467898: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.467915: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-01-31 11:29:49.478751: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.478784: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.478794: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.632835: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.632863: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.632868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-01-31 11:29:49.632883: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 11:29:49.632900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738323012.910903     171 service.cc:145] XLA service 0x7fd37c03ce90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738323012.910944     171 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-01-31 11:30:13.733843: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738323014.441096     171 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-01-31 11:30:15.885021: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738323017.447099     329 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738323017.489437     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738323017.693230     338 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738323017.729015     337 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738323017.996956     350 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738323017.998180     349 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738323017.998988     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738323018.014176     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738323018.015299     343 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738323018.035358     326 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738323018.055983     332 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738323018.148154     357 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738323018.229411     345 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738323018.230221     339 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738323018.439917     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738323018.653798     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738323018.677872     353 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738323018.840029     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738323018.931567     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738323018.958018     337 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738323018.970513     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738323019.083711     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738323019.249135     351 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738323019.663944     342 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738323019.696099     350 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738323019.836800     348 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738323020.054603     334 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738323020.062065     342 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738323020.063508     356 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738323020.136468     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738323020.293742     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738323020.352013     353 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738323020.734982     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738323047.052538     171 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738323047.092968     171 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 66s 66ms/step - loss: 0.2412
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0324
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0290
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0250
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0243
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0234
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0232
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0220
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0222
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0214
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0231
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0216
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0216
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0202
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0205
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0212
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0200
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0202
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0207
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0200
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0177
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0170
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0165
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0163
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0169
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - loss: 0.0177
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0162
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0166
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0161
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0158
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 327/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 328/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 346/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 347/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 348/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0148
# Epoch 349/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 350/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 351/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 352/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 353/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 354/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 355/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 356/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 357/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 358/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 359/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 360/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 361/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 362/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0166
# Epoch 363/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 364/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 365/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 366/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 367/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 368/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 369/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 370/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 371/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 372/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 373/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 374/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 375/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 376/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 377/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 378/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 379/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 380/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 381/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 382/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 383/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 384/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 385/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 386/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 387/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0161
# Epoch 388/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 389/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0167
# Epoch 390/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0164
# Epoch 391/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0154
# Epoch 392/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 393/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 394/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 395/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 396/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 397/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 398/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0148
# Epoch 399/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 400/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 401/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0148
# Epoch 402/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 403/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 404/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 405/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0161
# Epoch 406/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 407/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 408/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0157
# Epoch 409/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 410/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 411/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 412/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 413/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 414/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 415/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0155
# Epoch 416/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 417/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 418/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 419/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0162
# Epoch 420/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 421/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 422/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 423/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 424/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 425/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 426/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 427/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 428/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 429/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 430/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 431/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 432/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 433/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 434/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 435/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 436/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 437/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 438/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 439/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 440/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 441/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 442/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 443/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 444/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 445/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 446/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0148
# Epoch 447/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 448/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 449/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0153
# Epoch 450/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0146
# Epoch 451/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 452/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 453/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 454/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 455/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 456/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 457/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 458/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 459/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 460/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 461/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0145
# Epoch 462/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 463/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 464/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 465/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0145
# Epoch 466/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 467/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0142
# Epoch 468/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 469/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0156
# Epoch 470/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 471/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 472/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 473/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 474/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 475/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0152
# Epoch 476/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 477/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 478/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 479/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0157
# Epoch 480/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 481/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 482/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0149
# Epoch 483/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0151
# Epoch 484/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0146
# Epoch 485/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0145
# Epoch 486/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# Epoch 487/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0147
# Epoch 488/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 489/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 490/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0151
# Epoch 491/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 492/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 493/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0145
# Epoch 494/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0155
# Epoch 495/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0150
# Epoch 496/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0140
# Epoch 497/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 498/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0153
# Epoch 499/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0148
# Epoch 500/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0152
# INFO:tensorflow:Assets written to: DDPM-GI/PASSENGERSSHIP/GERADOR/assets
# INFO:tensorflow:Assets written to: DDPM-GI/PASSENGERSSHIP/GERADOR/assets

# %%
import os
from IPython.display import clear_output
import time

num_img = 5400
output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    ini = time.time()
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    fim = time.time()
    tim = fim - ini
    print("Faltam %d iterações" % (t))
    print("A iteração atual levou %d segundos" % (tim))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 21
#      19 ini = time.time()
#      20 tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
# ---> 21 pred_noise = ema_network.predict(
#      22     [samples, tt], verbose=0, batch_size=1
#      23 )
#      24 samples = gdf_util.p_sample(
#      25     pred_noise, samples, tt, clip_denoised=True
#      26 )
#      27 fim = time.time()
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:510, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     508 callbacks.on_predict_batch_begin(step)
#     509 data = get_data(iterator)
# --> 510 batch_outputs = self.predict_function(data)
#     511 outputs = append_to_outputs(batch_outputs, outputs)
#     512 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: PASSENGERSSHIP0.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP0.png
# Processado: PASSENGERSSHIP1.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1.png
# Processado: PASSENGERSSHIP10.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP10.png
# Processado: PASSENGERSSHIP100.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP100.png
# Processado: PASSENGERSSHIP1000.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1000.png
# Processado: PASSENGERSSHIP1001.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1001.png
# Processado: PASSENGERSSHIP1002.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1002.png
# Processado: PASSENGERSSHIP1003.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1003.png
# Processado: PASSENGERSSHIP1004.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1004.png
# Processado: PASSENGERSSHIP1005.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1005.png
# Processado: PASSENGERSSHIP1006.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1006.png
# Processado: PASSENGERSSHIP1007.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1007.png
# Processado: PASSENGERSSHIP1008.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1008.png
# Processado: PASSENGERSSHIP1009.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1009.png
# Processado: PASSENGERSSHIP101.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP101.png
# Processado: PASSENGERSSHIP1010.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1010.png
# Processado: PASSENGERSSHIP1011.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1011.png
# Processado: PASSENGERSSHIP1012.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1012.png
# Processado: PASSENGERSSHIP1013.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1013.png
# Processado: PASSENGERSSHIP1014.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1014.png
# Processado: PASSENGERSSHIP1015.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1015.png
# Processado: PASSENGERSSHIP1016.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1016.png
# Processado: PASSENGERSSHIP1017.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1017.png
# Processado: PASSENGERSSHIP1018.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1018.png
# Processado: PASSENGERSSHIP1019.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1019.png
# Processado: PASSENGERSSHIP102.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP102.png
# Processado: PASSENGERSSHIP1020.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1020.png
# Processado: PASSENGERSSHIP1021.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1021.png
# Processado: PASSENGERSSHIP1022.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1022.png
# Processado: PASSENGERSSHIP1023.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1023.png
# Processado: PASSENGERSSHIP1024.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1024.png
# Processado: PASSENGERSSHIP1025.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1025.png
# Processado: PASSENGERSSHIP1026.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1026.png
# Processado: PASSENGERSSHIP1027.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1027.png
# Processado: PASSENGERSSHIP1028.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1028.png
# Processado: PASSENGERSSHIP1029.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1029.png
# Processado: PASSENGERSSHIP103.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP103.png
# Processado: PASSENGERSSHIP1030.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1030.png
# Processado: PASSENGERSSHIP1031.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1031.png
# Processado: PASSENGERSSHIP1032.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1032.png
# Processado: PASSENGERSSHIP1033.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1033.png
# Processado: PASSENGERSSHIP1034.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1034.png
# Processado: PASSENGERSSHIP1035.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1035.png
# Processado: PASSENGERSSHIP1036.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1036.png
# Processado: PASSENGERSSHIP1037.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1037.png
# Processado: PASSENGERSSHIP1038.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1038.png
# Processado: PASSENGERSSHIP1039.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1039.png
# Processado: PASSENGERSSHIP104.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP104.png
# Processado: PASSENGERSSHIP1040.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1040.png
# Processado: PASSENGERSSHIP1041.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1041.png
# Processado: PASSENGERSSHIP1042.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1042.png
# Processado: PASSENGERSSHIP1043.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1043.png
# Processado: PASSENGERSSHIP1044.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1044.png
# Processado: PASSENGERSSHIP1045.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1045.png
# Processado: PASSENGERSSHIP1046.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1046.png
# Processado: PASSENGERSSHIP1047.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1047.png
# Processado: PASSENGERSSHIP1048.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1048.png
# Processado: PASSENGERSSHIP1049.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1049.png
# Processado: PASSENGERSSHIP105.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP105.png
# Processado: PASSENGERSSHIP1050.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1050.png
# Processado: PASSENGERSSHIP1051.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1051.png
# Processado: PASSENGERSSHIP1052.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1052.png
# Processado: PASSENGERSSHIP1053.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1053.png
# Processado: PASSENGERSSHIP1054.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1054.png
# Processado: PASSENGERSSHIP1055.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1055.png
# Processado: PASSENGERSSHIP1056.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1056.png
# Processado: PASSENGERSSHIP1057.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1057.png
# Processado: PASSENGERSSHIP1058.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1058.png
# Processado: PASSENGERSSHIP1059.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1059.png
# Processado: PASSENGERSSHIP106.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP106.png
# Processado: PASSENGERSSHIP1060.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1060.png
# Processado: PASSENGERSSHIP1061.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1061.png
# Processado: PASSENGERSSHIP1062.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1062.png
# Processado: PASSENGERSSHIP1063.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1063.png
# Processado: PASSENGERSSHIP1064.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1064.png
# Processado: PASSENGERSSHIP1065.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1065.png
# Processado: PASSENGERSSHIP1066.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1066.png
# Processado: PASSENGERSSHIP1067.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1067.png
# Processado: PASSENGERSSHIP1068.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1068.png
# Processado: PASSENGERSSHIP1069.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1069.png
# Processado: PASSENGERSSHIP107.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP107.png
# Processado: PASSENGERSSHIP1070.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1070.png
# Processado: PASSENGERSSHIP1071.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1071.png
# Processado: PASSENGERSSHIP1072.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1072.png
# Processado: PASSENGERSSHIP1073.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1073.png
# Processado: PASSENGERSSHIP1074.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1074.png
# Processado: PASSENGERSSHIP1075.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1075.png
# Processado: PASSENGERSSHIP1076.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1076.png
# Processado: PASSENGERSSHIP1077.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1077.png
# Processado: PASSENGERSSHIP1078.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1078.png
# Processado: PASSENGERSSHIP1079.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1079.png
# Processado: PASSENGERSSHIP108.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP108.png
# Processado: PASSENGERSSHIP1080.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1080.png
# Processado: PASSENGERSSHIP1081.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1081.png
# Processado: PASSENGERSSHIP1082.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1082.png
# Processado: PASSENGERSSHIP1083.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1083.png
# Processado: PASSENGERSSHIP1084.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1084.png
# Processado: PASSENGERSSHIP1085.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1085.png
# Processado: PASSENGERSSHIP1086.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1086.png
# Processado: PASSENGERSSHIP1087.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1087.png
# Processado: PASSENGERSSHIP1088.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1088.png
# Processado: PASSENGERSSHIP1089.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1089.png
# Processado: PASSENGERSSHIP109.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP109.png
# Processado: PASSENGERSSHIP1090.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1090.png
# Processado: PASSENGERSSHIP1091.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1091.png
# Processado: PASSENGERSSHIP1092.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1092.png
# Processado: PASSENGERSSHIP1093.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1093.png
# Processado: PASSENGERSSHIP1094.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1094.png
# Processado: PASSENGERSSHIP1095.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1095.png
# Processado: PASSENGERSSHIP1096.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1096.png
# Processado: PASSENGERSSHIP1097.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1097.png
# Processado: PASSENGERSSHIP1098.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1098.png
# Processado: PASSENGERSSHIP1099.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1099.png
# Processado: PASSENGERSSHIP11.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP11.png
# Processado: PASSENGERSSHIP110.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP110.png
# Processado: PASSENGERSSHIP1100.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1100.png
# Processado: PASSENGERSSHIP1101.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1101.png
# Processado: PASSENGERSSHIP1102.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1102.png
# Processado: PASSENGERSSHIP1103.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1103.png
# Processado: PASSENGERSSHIP1104.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1104.png
# Processado: PASSENGERSSHIP1105.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1105.png
# Processado: PASSENGERSSHIP1106.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1106.png
# Processado: PASSENGERSSHIP1107.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1107.png
# Processado: PASSENGERSSHIP1108.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1108.png
# Processado: PASSENGERSSHIP1109.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1109.png
# Processado: PASSENGERSSHIP111.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP111.png
# Processado: PASSENGERSSHIP1110.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1110.png
# Processado: PASSENGERSSHIP1111.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1111.png
# Processado: PASSENGERSSHIP1112.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1112.png
# Processado: PASSENGERSSHIP1113.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1113.png
# Processado: PASSENGERSSHIP1114.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1114.png
# Processado: PASSENGERSSHIP1115.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1115.png
# Processado: PASSENGERSSHIP1116.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1116.png
# Processado: PASSENGERSSHIP1117.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1117.png
# Processado: PASSENGERSSHIP1118.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1118.png
# Processado: PASSENGERSSHIP1119.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1119.png
# Processado: PASSENGERSSHIP112.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP112.png
# Processado: PASSENGERSSHIP1120.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1120.png
# Processado: PASSENGERSSHIP1121.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1121.png
# Processado: PASSENGERSSHIP1122.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1122.png
# Processado: PASSENGERSSHIP1123.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1123.png
# Processado: PASSENGERSSHIP1124.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1124.png
# Processado: PASSENGERSSHIP1125.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1125.png
# Processado: PASSENGERSSHIP1126.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1126.png
# Processado: PASSENGERSSHIP1127.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1127.png
# Processado: PASSENGERSSHIP1128.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1128.png
# Processado: PASSENGERSSHIP1129.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1129.png
# Processado: PASSENGERSSHIP113.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP113.png
# Processado: PASSENGERSSHIP1130.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1130.png
# Processado: PASSENGERSSHIP1131.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1131.png
# Processado: PASSENGERSSHIP1132.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1132.png
# Processado: PASSENGERSSHIP1133.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1133.png
# Processado: PASSENGERSSHIP1134.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1134.png
# Processado: PASSENGERSSHIP1135.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1135.png
# Processado: PASSENGERSSHIP1136.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1136.png
# Processado: PASSENGERSSHIP1137.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1137.png
# Processado: PASSENGERSSHIP1138.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1138.png
# Processado: PASSENGERSSHIP1139.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1139.png
# Processado: PASSENGERSSHIP114.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP114.png
# Processado: PASSENGERSSHIP1140.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1140.png
# Processado: PASSENGERSSHIP1141.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1141.png
# Processado: PASSENGERSSHIP1142.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1142.png
# Processado: PASSENGERSSHIP1143.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1143.png
# Processado: PASSENGERSSHIP1144.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1144.png
# Processado: PASSENGERSSHIP1145.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1145.png
# Processado: PASSENGERSSHIP1146.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1146.png
# Processado: PASSENGERSSHIP1147.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1147.png
# Processado: PASSENGERSSHIP1148.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1148.png
# Processado: PASSENGERSSHIP1149.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1149.png
# Processado: PASSENGERSSHIP115.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP115.png
# Processado: PASSENGERSSHIP1150.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1150.png
# Processado: PASSENGERSSHIP1151.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1151.png
# Processado: PASSENGERSSHIP1152.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1152.png
# Processado: PASSENGERSSHIP1153.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1153.png
# Processado: PASSENGERSSHIP1154.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1154.png
# Processado: PASSENGERSSHIP1155.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1155.png
# Processado: PASSENGERSSHIP1156.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1156.png
# Processado: PASSENGERSSHIP1157.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1157.png
# Processado: PASSENGERSSHIP1158.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1158.png
# Processado: PASSENGERSSHIP1159.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1159.png
# Processado: PASSENGERSSHIP116.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP116.png
# Processado: PASSENGERSSHIP1160.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1160.png
# Processado: PASSENGERSSHIP1161.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1161.png
# Processado: PASSENGERSSHIP1162.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1162.png
# Processado: PASSENGERSSHIP1163.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1163.png
# Processado: PASSENGERSSHIP1164.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1164.png
# Processado: PASSENGERSSHIP1165.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1165.png
# Processado: PASSENGERSSHIP1166.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1166.png
# Processado: PASSENGERSSHIP1167.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1167.png
# Processado: PASSENGERSSHIP1168.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1168.png
# Processado: PASSENGERSSHIP1169.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1169.png
# Processado: PASSENGERSSHIP117.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP117.png
# Processado: PASSENGERSSHIP1170.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1170.png
# Processado: PASSENGERSSHIP1171.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1171.png
# Processado: PASSENGERSSHIP1172.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1172.png
# Processado: PASSENGERSSHIP1173.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1173.png
# Processado: PASSENGERSSHIP1174.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1174.png
# Processado: PASSENGERSSHIP1175.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1175.png
# Processado: PASSENGERSSHIP1176.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1176.png
# Processado: PASSENGERSSHIP1177.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1177.png
# Processado: PASSENGERSSHIP1178.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1178.png
# Processado: PASSENGERSSHIP1179.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1179.png
# Processado: PASSENGERSSHIP118.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP118.png
# Processado: PASSENGERSSHIP1180.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1180.png
# Processado: PASSENGERSSHIP1181.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1181.png
# Processado: PASSENGERSSHIP1182.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1182.png
# Processado: PASSENGERSSHIP1183.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1183.png
# Processado: PASSENGERSSHIP1184.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1184.png
# Processado: PASSENGERSSHIP1185.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1185.png
# Processado: PASSENGERSSHIP1186.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1186.png
# Processado: PASSENGERSSHIP1187.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1187.png
# Processado: PASSENGERSSHIP1188.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1188.png
# Processado: PASSENGERSSHIP1189.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1189.png
# Processado: PASSENGERSSHIP119.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP119.png
# Processado: PASSENGERSSHIP1190.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1190.png
# Processado: PASSENGERSSHIP1191.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1191.png
# Processado: PASSENGERSSHIP1192.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1192.png
# Processado: PASSENGERSSHIP1193.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1193.png
# Processado: PASSENGERSSHIP1194.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1194.png
# Processado: PASSENGERSSHIP1195.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1195.png
# Processado: PASSENGERSSHIP1196.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1196.png
# Processado: PASSENGERSSHIP1197.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1197.png
# Processado: PASSENGERSSHIP1198.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1198.png
# Processado: PASSENGERSSHIP1199.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1199.png
# Processado: PASSENGERSSHIP12.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP12.png
# Processado: PASSENGERSSHIP120.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP120.png
# Processado: PASSENGERSSHIP1200.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1200.png
# Processado: PASSENGERSSHIP1201.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1201.png
# Processado: PASSENGERSSHIP1202.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1202.png
# Processado: PASSENGERSSHIP1203.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1203.png
# Processado: PASSENGERSSHIP1204.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1204.png
# Processado: PASSENGERSSHIP1205.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1205.png
# Processado: PASSENGERSSHIP1206.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1206.png
# Processado: PASSENGERSSHIP1207.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1207.png
# Processado: PASSENGERSSHIP1208.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1208.png
# Processado: PASSENGERSSHIP1209.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1209.png
# Processado: PASSENGERSSHIP121.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP121.png
# Processado: PASSENGERSSHIP1210.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1210.png
# Processado: PASSENGERSSHIP1211.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1211.png
# Processado: PASSENGERSSHIP1212.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1212.png
# Processado: PASSENGERSSHIP1213.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1213.png
# Processado: PASSENGERSSHIP1214.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1214.png
# Processado: PASSENGERSSHIP1215.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1215.png
# Processado: PASSENGERSSHIP1216.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1216.png
# Processado: PASSENGERSSHIP1217.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1217.png
# Processado: PASSENGERSSHIP1218.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1218.png
# Processado: PASSENGERSSHIP1219.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1219.png
# Processado: PASSENGERSSHIP122.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP122.png
# Processado: PASSENGERSSHIP1220.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1220.png
# Processado: PASSENGERSSHIP1221.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1221.png
# Processado: PASSENGERSSHIP1222.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1222.png
# Processado: PASSENGERSSHIP1223.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1223.png
# Processado: PASSENGERSSHIP1224.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1224.png
# Processado: PASSENGERSSHIP1225.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1225.png
# Processado: PASSENGERSSHIP1226.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1226.png
# Processado: PASSENGERSSHIP1227.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1227.png
# Processado: PASSENGERSSHIP1228.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1228.png
# Processado: PASSENGERSSHIP1229.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1229.png
# Processado: PASSENGERSSHIP123.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP123.png
# Processado: PASSENGERSSHIP1230.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1230.png
# Processado: PASSENGERSSHIP1231.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1231.png
# Processado: PASSENGERSSHIP1232.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1232.png
# Processado: PASSENGERSSHIP1233.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1233.png
# Processado: PASSENGERSSHIP1234.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1234.png
# Processado: PASSENGERSSHIP1235.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1235.png
# Processado: PASSENGERSSHIP1236.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1236.png
# Processado: PASSENGERSSHIP1237.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1237.png
# Processado: PASSENGERSSHIP1238.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1238.png
# Processado: PASSENGERSSHIP1239.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1239.png
# Processado: PASSENGERSSHIP124.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP124.png
# Processado: PASSENGERSSHIP1240.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1240.png
# Processado: PASSENGERSSHIP1241.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1241.png
# Processado: PASSENGERSSHIP1242.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1242.png
# Processado: PASSENGERSSHIP1243.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1243.png
# Processado: PASSENGERSSHIP1244.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1244.png
# Processado: PASSENGERSSHIP1245.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1245.png
# Processado: PASSENGERSSHIP1246.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1246.png
# Processado: PASSENGERSSHIP1247.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1247.png
# Processado: PASSENGERSSHIP1248.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1248.png
# Processado: PASSENGERSSHIP1249.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1249.png
# Processado: PASSENGERSSHIP125.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP125.png
# Processado: PASSENGERSSHIP1250.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1250.png
# Processado: PASSENGERSSHIP1251.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1251.png
# Processado: PASSENGERSSHIP1252.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1252.png
# Processado: PASSENGERSSHIP1253.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1253.png
# Processado: PASSENGERSSHIP1254.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1254.png
# Processado: PASSENGERSSHIP1255.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1255.png
# Processado: PASSENGERSSHIP1256.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1256.png
# Processado: PASSENGERSSHIP1257.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1257.png
# Processado: PASSENGERSSHIP1258.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1258.png
# Processado: PASSENGERSSHIP1259.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1259.png
# Processado: PASSENGERSSHIP126.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP126.png
# Processado: PASSENGERSSHIP1260.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1260.png
# Processado: PASSENGERSSHIP1261.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1261.png
# Processado: PASSENGERSSHIP1262.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1262.png
# Processado: PASSENGERSSHIP1263.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1263.png
# Processado: PASSENGERSSHIP1264.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1264.png
# Processado: PASSENGERSSHIP1265.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1265.png
# Processado: PASSENGERSSHIP1266.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1266.png
# Processado: PASSENGERSSHIP1267.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1267.png
# Processado: PASSENGERSSHIP1268.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1268.png
# Processado: PASSENGERSSHIP1269.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1269.png
# Processado: PASSENGERSSHIP127.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP127.png
# Processado: PASSENGERSSHIP1270.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1270.png
# Processado: PASSENGERSSHIP1271.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1271.png
# Processado: PASSENGERSSHIP1272.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1272.png
# Processado: PASSENGERSSHIP1273.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1273.png
# Processado: PASSENGERSSHIP1274.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1274.png
# Processado: PASSENGERSSHIP1275.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1275.png
# Processado: PASSENGERSSHIP1276.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1276.png
# Processado: PASSENGERSSHIP1277.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1277.png
# Processado: PASSENGERSSHIP1278.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1278.png
# Processado: PASSENGERSSHIP1279.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1279.png
# Processado: PASSENGERSSHIP128.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP128.png
# Processado: PASSENGERSSHIP1280.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1280.png
# Processado: PASSENGERSSHIP1281.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1281.png
# Processado: PASSENGERSSHIP1282.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1282.png
# Processado: PASSENGERSSHIP1283.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1283.png
# Processado: PASSENGERSSHIP1284.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1284.png
# Processado: PASSENGERSSHIP1285.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1285.png
# Processado: PASSENGERSSHIP1286.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1286.png
# Processado: PASSENGERSSHIP1287.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1287.png
# Processado: PASSENGERSSHIP1288.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1288.png
# Processado: PASSENGERSSHIP1289.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1289.png
# Processado: PASSENGERSSHIP129.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP129.png
# Processado: PASSENGERSSHIP1290.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1290.png
# Processado: PASSENGERSSHIP1291.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1291.png
# Processado: PASSENGERSSHIP1292.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1292.png
# Processado: PASSENGERSSHIP1293.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1293.png
# Processado: PASSENGERSSHIP1294.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1294.png
# Processado: PASSENGERSSHIP1295.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1295.png
# Processado: PASSENGERSSHIP1296.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1296.png
# Processado: PASSENGERSSHIP1297.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1297.png
# Processado: PASSENGERSSHIP1298.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1298.png
# Processado: PASSENGERSSHIP1299.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1299.png
# Processado: PASSENGERSSHIP13.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP13.png
# Processado: PASSENGERSSHIP130.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP130.png
# Processado: PASSENGERSSHIP1300.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1300.png
# Processado: PASSENGERSSHIP1301.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1301.png
# Processado: PASSENGERSSHIP1302.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1302.png
# Processado: PASSENGERSSHIP1303.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1303.png
# Processado: PASSENGERSSHIP1304.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1304.png
# Processado: PASSENGERSSHIP1305.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1305.png
# Processado: PASSENGERSSHIP1306.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1306.png
# Processado: PASSENGERSSHIP1307.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1307.png
# Processado: PASSENGERSSHIP1308.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1308.png
# Processado: PASSENGERSSHIP1309.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1309.png
# Processado: PASSENGERSSHIP131.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP131.png
# Processado: PASSENGERSSHIP1310.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1310.png
# Processado: PASSENGERSSHIP1311.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1311.png
# Processado: PASSENGERSSHIP1312.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1312.png
# Processado: PASSENGERSSHIP1313.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1313.png
# Processado: PASSENGERSSHIP1314.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1314.png
# Processado: PASSENGERSSHIP1315.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1315.png
# Processado: PASSENGERSSHIP1316.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1316.png
# Processado: PASSENGERSSHIP1317.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1317.png
# Processado: PASSENGERSSHIP1318.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1318.png
# Processado: PASSENGERSSHIP1319.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1319.png
# Processado: PASSENGERSSHIP132.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP132.png
# Processado: PASSENGERSSHIP1320.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1320.png
# Processado: PASSENGERSSHIP1321.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1321.png
# Processado: PASSENGERSSHIP1322.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1322.png
# Processado: PASSENGERSSHIP1323.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1323.png
# Processado: PASSENGERSSHIP1324.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1324.png
# Processado: PASSENGERSSHIP1325.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1325.png
# Processado: PASSENGERSSHIP1326.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1326.png
# Processado: PASSENGERSSHIP1327.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1327.png
# Processado: PASSENGERSSHIP1328.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1328.png
# Processado: PASSENGERSSHIP1329.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1329.png
# Processado: PASSENGERSSHIP133.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP133.png
# Processado: PASSENGERSSHIP1330.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1330.png
# Processado: PASSENGERSSHIP1331.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1331.png
# Processado: PASSENGERSSHIP1332.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1332.png
# Processado: PASSENGERSSHIP1333.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1333.png
# Processado: PASSENGERSSHIP1334.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1334.png
# Processado: PASSENGERSSHIP1335.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1335.png
# Processado: PASSENGERSSHIP1336.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1336.png
# Processado: PASSENGERSSHIP1337.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1337.png
# Processado: PASSENGERSSHIP1338.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1338.png
# Processado: PASSENGERSSHIP1339.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1339.png
# Processado: PASSENGERSSHIP134.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP134.png
# Processado: PASSENGERSSHIP1340.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1340.png
# Processado: PASSENGERSSHIP1341.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1341.png
# Processado: PASSENGERSSHIP1342.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1342.png
# Processado: PASSENGERSSHIP1343.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1343.png
# Processado: PASSENGERSSHIP1344.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1344.png
# Processado: PASSENGERSSHIP1345.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1345.png
# Processado: PASSENGERSSHIP1346.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1346.png
# Processado: PASSENGERSSHIP1347.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1347.png
# Processado: PASSENGERSSHIP1348.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1348.png
# Processado: PASSENGERSSHIP1349.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1349.png
# Processado: PASSENGERSSHIP135.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP135.png
# Processado: PASSENGERSSHIP1350.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1350.png
# Processado: PASSENGERSSHIP1351.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1351.png
# Processado: PASSENGERSSHIP1352.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1352.png
# Processado: PASSENGERSSHIP1353.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1353.png
# Processado: PASSENGERSSHIP1354.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1354.png
# Processado: PASSENGERSSHIP1355.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1355.png
# Processado: PASSENGERSSHIP1356.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1356.png
# Processado: PASSENGERSSHIP1357.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1357.png
# Processado: PASSENGERSSHIP1358.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1358.png
# Processado: PASSENGERSSHIP1359.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1359.png
# Processado: PASSENGERSSHIP136.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP136.png
# Processado: PASSENGERSSHIP1360.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1360.png
# Processado: PASSENGERSSHIP1361.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1361.png
# Processado: PASSENGERSSHIP1362.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1362.png
# Processado: PASSENGERSSHIP1363.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1363.png
# Processado: PASSENGERSSHIP1364.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1364.png
# Processado: PASSENGERSSHIP1365.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1365.png
# Processado: PASSENGERSSHIP1366.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1366.png
# Processado: PASSENGERSSHIP1367.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1367.png
# Processado: PASSENGERSSHIP1368.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1368.png
# Processado: PASSENGERSSHIP1369.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1369.png
# Processado: PASSENGERSSHIP137.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP137.png
# Processado: PASSENGERSSHIP1370.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1370.png
# Processado: PASSENGERSSHIP1371.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1371.png
# Processado: PASSENGERSSHIP1372.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1372.png
# Processado: PASSENGERSSHIP1373.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1373.png
# Processado: PASSENGERSSHIP1374.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1374.png
# Processado: PASSENGERSSHIP1375.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1375.png
# Processado: PASSENGERSSHIP1376.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1376.png
# Processado: PASSENGERSSHIP1377.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1377.png
# Processado: PASSENGERSSHIP1378.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1378.png
# Processado: PASSENGERSSHIP1379.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1379.png
# Processado: PASSENGERSSHIP138.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP138.png
# Processado: PASSENGERSSHIP1380.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1380.png
# Processado: PASSENGERSSHIP1381.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1381.png
# Processado: PASSENGERSSHIP1382.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1382.png
# Processado: PASSENGERSSHIP1383.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1383.png
# Processado: PASSENGERSSHIP1384.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1384.png
# Processado: PASSENGERSSHIP1385.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1385.png
# Processado: PASSENGERSSHIP1386.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1386.png
# Processado: PASSENGERSSHIP1387.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1387.png
# Processado: PASSENGERSSHIP1388.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1388.png
# Processado: PASSENGERSSHIP1389.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1389.png
# Processado: PASSENGERSSHIP139.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP139.png
# Processado: PASSENGERSSHIP1390.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1390.png
# Processado: PASSENGERSSHIP1391.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1391.png
# Processado: PASSENGERSSHIP1392.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1392.png
# Processado: PASSENGERSSHIP1393.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1393.png
# Processado: PASSENGERSSHIP1394.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1394.png
# Processado: PASSENGERSSHIP1395.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1395.png
# Processado: PASSENGERSSHIP1396.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1396.png
# Processado: PASSENGERSSHIP1397.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1397.png
# Processado: PASSENGERSSHIP1398.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1398.png
# Processado: PASSENGERSSHIP1399.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1399.png
# Processado: PASSENGERSSHIP14.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP14.png
# Processado: PASSENGERSSHIP140.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP140.png
# Processado: PASSENGERSSHIP1400.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1400.png
# Processado: PASSENGERSSHIP1401.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1401.png
# Processado: PASSENGERSSHIP1402.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1402.png
# Processado: PASSENGERSSHIP1403.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1403.png
# Processado: PASSENGERSSHIP1404.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1404.png
# Processado: PASSENGERSSHIP1405.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1405.png
# Processado: PASSENGERSSHIP1406.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1406.png
# Processado: PASSENGERSSHIP1407.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1407.png
# Processado: PASSENGERSSHIP1408.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1408.png
# Processado: PASSENGERSSHIP1409.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1409.png
# Processado: PASSENGERSSHIP141.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP141.png
# Processado: PASSENGERSSHIP1410.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1410.png
# Processado: PASSENGERSSHIP1411.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1411.png
# Processado: PASSENGERSSHIP1412.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1412.png
# Processado: PASSENGERSSHIP1413.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1413.png
# Processado: PASSENGERSSHIP1414.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1414.png
# Processado: PASSENGERSSHIP1415.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1415.png
# Processado: PASSENGERSSHIP1416.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1416.png
# Processado: PASSENGERSSHIP1417.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1417.png
# Processado: PASSENGERSSHIP1418.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1418.png
# Processado: PASSENGERSSHIP1419.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1419.png
# Processado: PASSENGERSSHIP142.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP142.png
# Processado: PASSENGERSSHIP1420.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1420.png
# Processado: PASSENGERSSHIP1421.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1421.png
# Processado: PASSENGERSSHIP1422.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1422.png
# Processado: PASSENGERSSHIP1423.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1423.png
# Processado: PASSENGERSSHIP1424.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1424.png
# Processado: PASSENGERSSHIP1425.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1425.png
# Processado: PASSENGERSSHIP1426.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1426.png
# Processado: PASSENGERSSHIP1427.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1427.png
# Processado: PASSENGERSSHIP1428.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1428.png
# Processado: PASSENGERSSHIP1429.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1429.png
# Processado: PASSENGERSSHIP143.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP143.png
# Processado: PASSENGERSSHIP1430.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1430.png
# Processado: PASSENGERSSHIP1431.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1431.png
# Processado: PASSENGERSSHIP1432.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1432.png
# Processado: PASSENGERSSHIP1433.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1433.png
# Processado: PASSENGERSSHIP1434.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1434.png
# Processado: PASSENGERSSHIP1435.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1435.png
# Processado: PASSENGERSSHIP1436.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1436.png
# Processado: PASSENGERSSHIP1437.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1437.png
# Processado: PASSENGERSSHIP1438.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1438.png
# Processado: PASSENGERSSHIP1439.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1439.png
# Processado: PASSENGERSSHIP144.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP144.png
# Processado: PASSENGERSSHIP1440.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1440.png
# Processado: PASSENGERSSHIP1441.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1441.png
# Processado: PASSENGERSSHIP1442.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1442.png
# Processado: PASSENGERSSHIP1443.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1443.png
# Processado: PASSENGERSSHIP1444.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1444.png
# Processado: PASSENGERSSHIP1445.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1445.png
# Processado: PASSENGERSSHIP1446.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1446.png
# Processado: PASSENGERSSHIP1447.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1447.png
# Processado: PASSENGERSSHIP1448.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1448.png
# Processado: PASSENGERSSHIP1449.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1449.png
# Processado: PASSENGERSSHIP145.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP145.png
# Processado: PASSENGERSSHIP1450.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1450.png
# Processado: PASSENGERSSHIP1451.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1451.png
# Processado: PASSENGERSSHIP1452.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1452.png
# Processado: PASSENGERSSHIP1453.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1453.png
# Processado: PASSENGERSSHIP1454.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1454.png
# Processado: PASSENGERSSHIP1455.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1455.png
# Processado: PASSENGERSSHIP1456.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1456.png
# Processado: PASSENGERSSHIP1457.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1457.png
# Processado: PASSENGERSSHIP1458.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1458.png
# Processado: PASSENGERSSHIP1459.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1459.png
# Processado: PASSENGERSSHIP146.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP146.png
# Processado: PASSENGERSSHIP1460.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1460.png
# Processado: PASSENGERSSHIP1461.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1461.png
# Processado: PASSENGERSSHIP1462.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1462.png
# Processado: PASSENGERSSHIP1463.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1463.png
# Processado: PASSENGERSSHIP1464.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1464.png
# Processado: PASSENGERSSHIP1465.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1465.png
# Processado: PASSENGERSSHIP1466.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1466.png
# Processado: PASSENGERSSHIP1467.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1467.png
# Processado: PASSENGERSSHIP1468.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1468.png
# Processado: PASSENGERSSHIP1469.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1469.png
# Processado: PASSENGERSSHIP147.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP147.png
# Processado: PASSENGERSSHIP1470.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1470.png
# Processado: PASSENGERSSHIP1471.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1471.png
# Processado: PASSENGERSSHIP1472.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1472.png
# Processado: PASSENGERSSHIP1473.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1473.png
# Processado: PASSENGERSSHIP1474.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1474.png
# Processado: PASSENGERSSHIP1475.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1475.png
# Processado: PASSENGERSSHIP1476.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1476.png
# Processado: PASSENGERSSHIP1477.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1477.png
# Processado: PASSENGERSSHIP1478.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1478.png
# Processado: PASSENGERSSHIP1479.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1479.png
# Processado: PASSENGERSSHIP148.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP148.png
# Processado: PASSENGERSSHIP1480.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1480.png
# Processado: PASSENGERSSHIP1481.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1481.png
# Processado: PASSENGERSSHIP1482.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1482.png
# Processado: PASSENGERSSHIP1483.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1483.png
# Processado: PASSENGERSSHIP1484.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1484.png
# Processado: PASSENGERSSHIP1485.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1485.png
# Processado: PASSENGERSSHIP1486.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1486.png
# Processado: PASSENGERSSHIP1487.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1487.png
# Processado: PASSENGERSSHIP1488.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1488.png
# Processado: PASSENGERSSHIP1489.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1489.png
# Processado: PASSENGERSSHIP149.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP149.png
# Processado: PASSENGERSSHIP1490.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1490.png
# Processado: PASSENGERSSHIP1491.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1491.png
# Processado: PASSENGERSSHIP1492.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1492.png
# Processado: PASSENGERSSHIP1493.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1493.png
# Processado: PASSENGERSSHIP1494.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1494.png
# Processado: PASSENGERSSHIP1495.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP1495.png
# ...
# Processado: PASSENGERSSHIP83.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP83.png
# Processado: PASSENGERSSHIP830.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP830.png
# Processado: PASSENGERSSHIP831.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP831.png
# Processado: PASSENGERSSHIP832.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP832.png
# Processado: PASSENGERSSHIP833.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP833.png
# Processado: PASSENGERSSHIP834.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP834.png
# Processado: PASSENGERSSHIP835.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP835.png
# Processado: PASSENGERSSHIP836.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP836.png
# Processado: PASSENGERSSHIP837.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP837.png
# Processado: PASSENGERSSHIP838.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP838.png
# Processado: PASSENGERSSHIP839.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP839.png
# Processado: PASSENGERSSHIP84.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP84.png
# Processado: PASSENGERSSHIP840.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP840.png
# Processado: PASSENGERSSHIP841.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP841.png
# Processado: PASSENGERSSHIP842.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP842.png
# Processado: PASSENGERSSHIP843.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP843.png
# Processado: PASSENGERSSHIP844.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP844.png
# Processado: PASSENGERSSHIP845.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP845.png
# Processado: PASSENGERSSHIP846.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP846.png
# Processado: PASSENGERSSHIP847.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP847.png
# Processado: PASSENGERSSHIP848.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP848.png
# Processado: PASSENGERSSHIP849.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP849.png
# Processado: PASSENGERSSHIP85.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP85.png
# Processado: PASSENGERSSHIP850.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP850.png
# Processado: PASSENGERSSHIP851.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP851.png
# Processado: PASSENGERSSHIP852.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP852.png
# Processado: PASSENGERSSHIP853.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP853.png
# Processado: PASSENGERSSHIP854.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP854.png
# Processado: PASSENGERSSHIP855.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP855.png
# Processado: PASSENGERSSHIP856.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP856.png
# Processado: PASSENGERSSHIP857.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP857.png
# Processado: PASSENGERSSHIP858.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP858.png
# Processado: PASSENGERSSHIP859.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP859.png
# Processado: PASSENGERSSHIP86.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP86.png
# Processado: PASSENGERSSHIP860.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP860.png
# Processado: PASSENGERSSHIP861.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP861.png
# Processado: PASSENGERSSHIP862.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP862.png
# Processado: PASSENGERSSHIP863.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP863.png
# Processado: PASSENGERSSHIP864.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP864.png
# Processado: PASSENGERSSHIP865.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP865.png
# Processado: PASSENGERSSHIP866.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP866.png
# Processado: PASSENGERSSHIP867.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP867.png
# Processado: PASSENGERSSHIP868.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP868.png
# Processado: PASSENGERSSHIP869.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP869.png
# Processado: PASSENGERSSHIP87.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP87.png
# Processado: PASSENGERSSHIP870.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP870.png
# Processado: PASSENGERSSHIP871.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP871.png
# Processado: PASSENGERSSHIP872.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP872.png
# Processado: PASSENGERSSHIP873.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP873.png
# Processado: PASSENGERSSHIP874.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP874.png
# Processado: PASSENGERSSHIP875.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP875.png
# Processado: PASSENGERSSHIP876.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP876.png
# Processado: PASSENGERSSHIP877.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP877.png
# Processado: PASSENGERSSHIP878.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP878.png
# Processado: PASSENGERSSHIP879.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP879.png
# Processado: PASSENGERSSHIP88.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP88.png
# Processado: PASSENGERSSHIP880.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP880.png
# Processado: PASSENGERSSHIP881.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP881.png
# Processado: PASSENGERSSHIP882.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP882.png
# Processado: PASSENGERSSHIP883.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP883.png
# Processado: PASSENGERSSHIP884.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP884.png
# Processado: PASSENGERSSHIP885.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP885.png
# Processado: PASSENGERSSHIP886.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP886.png
# Processado: PASSENGERSSHIP887.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP887.png
# Processado: PASSENGERSSHIP888.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP888.png
# Processado: PASSENGERSSHIP889.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP889.png
# Processado: PASSENGERSSHIP89.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP89.png
# Processado: PASSENGERSSHIP890.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP890.png
# Processado: PASSENGERSSHIP891.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP891.png
# Processado: PASSENGERSSHIP892.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP892.png
# Processado: PASSENGERSSHIP893.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP893.png
# Processado: PASSENGERSSHIP894.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP894.png
# Processado: PASSENGERSSHIP895.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP895.png
# Processado: PASSENGERSSHIP896.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP896.png
# Processado: PASSENGERSSHIP897.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP897.png
# Processado: PASSENGERSSHIP898.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP898.png
# Processado: PASSENGERSSHIP899.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP899.png
# Processado: PASSENGERSSHIP9.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP9.png
# Processado: PASSENGERSSHIP90.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP90.png
# Processado: PASSENGERSSHIP900.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP900.png
# Processado: PASSENGERSSHIP901.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP901.png
# Processado: PASSENGERSSHIP902.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP902.png
# Processado: PASSENGERSSHIP903.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP903.png
# Processado: PASSENGERSSHIP904.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP904.png
# Processado: PASSENGERSSHIP905.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP905.png
# Processado: PASSENGERSSHIP906.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP906.png
# Processado: PASSENGERSSHIP907.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP907.png
# Processado: PASSENGERSSHIP908.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP908.png
# Processado: PASSENGERSSHIP909.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP909.png
# Processado: PASSENGERSSHIP91.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP91.png
# Processado: PASSENGERSSHIP910.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP910.png
# Processado: PASSENGERSSHIP911.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP911.png
# Processado: PASSENGERSSHIP912.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP912.png
# Processado: PASSENGERSSHIP913.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP913.png
# Processado: PASSENGERSSHIP914.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP914.png
# Processado: PASSENGERSSHIP915.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP915.png
# Processado: PASSENGERSSHIP916.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP916.png
# Processado: PASSENGERSSHIP917.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP917.png
# Processado: PASSENGERSSHIP918.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP918.png
# Processado: PASSENGERSSHIP919.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP919.png
# Processado: PASSENGERSSHIP92.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP92.png
# Processado: PASSENGERSSHIP920.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP920.png
# Processado: PASSENGERSSHIP921.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP921.png
# Processado: PASSENGERSSHIP922.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP922.png
# Processado: PASSENGERSSHIP923.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP923.png
# Processado: PASSENGERSSHIP924.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP924.png
# Processado: PASSENGERSSHIP925.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP925.png
# Processado: PASSENGERSSHIP926.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP926.png
# Processado: PASSENGERSSHIP927.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP927.png
# Processado: PASSENGERSSHIP928.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP928.png
# Processado: PASSENGERSSHIP929.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP929.png
# Processado: PASSENGERSSHIP93.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP93.png
# Processado: PASSENGERSSHIP930.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP930.png
# Processado: PASSENGERSSHIP931.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP931.png
# Processado: PASSENGERSSHIP932.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP932.png
# Processado: PASSENGERSSHIP933.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP933.png
# Processado: PASSENGERSSHIP934.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP934.png
# Processado: PASSENGERSSHIP935.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP935.png
# Processado: PASSENGERSSHIP936.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP936.png
# Processado: PASSENGERSSHIP937.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP937.png
# Processado: PASSENGERSSHIP938.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP938.png
# Processado: PASSENGERSSHIP939.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP939.png
# Processado: PASSENGERSSHIP94.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP94.png
# Processado: PASSENGERSSHIP940.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP940.png
# Processado: PASSENGERSSHIP941.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP941.png
# Processado: PASSENGERSSHIP942.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP942.png
# Processado: PASSENGERSSHIP943.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP943.png
# Processado: PASSENGERSSHIP944.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP944.png
# Processado: PASSENGERSSHIP945.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP945.png
# Processado: PASSENGERSSHIP946.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP946.png
# Processado: PASSENGERSSHIP947.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP947.png
# Processado: PASSENGERSSHIP948.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP948.png
# Processado: PASSENGERSSHIP949.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP949.png
# Processado: PASSENGERSSHIP95.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP95.png
# Processado: PASSENGERSSHIP950.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP950.png
# Processado: PASSENGERSSHIP951.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP951.png
# Processado: PASSENGERSSHIP952.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP952.png
# Processado: PASSENGERSSHIP953.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP953.png
# Processado: PASSENGERSSHIP954.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP954.png
# Processado: PASSENGERSSHIP955.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP955.png
# Processado: PASSENGERSSHIP956.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP956.png
# Processado: PASSENGERSSHIP957.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP957.png
# Processado: PASSENGERSSHIP958.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP958.png
# Processado: PASSENGERSSHIP959.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP959.png
# Processado: PASSENGERSSHIP96.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP96.png
# Processado: PASSENGERSSHIP960.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP960.png
# Processado: PASSENGERSSHIP961.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP961.png
# Processado: PASSENGERSSHIP962.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP962.png
# Processado: PASSENGERSSHIP963.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP963.png
# Processado: PASSENGERSSHIP964.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP964.png
# Processado: PASSENGERSSHIP965.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP965.png
# Processado: PASSENGERSSHIP966.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP966.png
# Processado: PASSENGERSSHIP967.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP967.png
# Processado: PASSENGERSSHIP968.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP968.png
# Processado: PASSENGERSSHIP969.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP969.png
# Processado: PASSENGERSSHIP97.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP97.png
# Processado: PASSENGERSSHIP970.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP970.png
# Processado: PASSENGERSSHIP971.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP971.png
# Processado: PASSENGERSSHIP972.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP972.png
# Processado: PASSENGERSSHIP973.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP973.png
# Processado: PASSENGERSSHIP974.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP974.png
# Processado: PASSENGERSSHIP975.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP975.png
# Processado: PASSENGERSSHIP976.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP976.png
# Processado: PASSENGERSSHIP977.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP977.png
# Processado: PASSENGERSSHIP978.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP978.png
# Processado: PASSENGERSSHIP979.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP979.png
# Processado: PASSENGERSSHIP98.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP98.png
# Processado: PASSENGERSSHIP980.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP980.png
# Processado: PASSENGERSSHIP981.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP981.png
# Processado: PASSENGERSSHIP982.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP982.png
# Processado: PASSENGERSSHIP983.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP983.png
# Processado: PASSENGERSSHIP984.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP984.png
# Processado: PASSENGERSSHIP985.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP985.png
# Processado: PASSENGERSSHIP986.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP986.png
# Processado: PASSENGERSSHIP987.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP987.png
# Processado: PASSENGERSSHIP988.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP988.png
# Processado: PASSENGERSSHIP989.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP989.png
# Processado: PASSENGERSSHIP99.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP99.png
# Processado: PASSENGERSSHIP990.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP990.png
# Processado: PASSENGERSSHIP991.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP991.png
# Processado: PASSENGERSSHIP992.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP992.png
# Processado: PASSENGERSSHIP993.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP993.png
# Processado: PASSENGERSSHIP994.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP994.png
# Processado: PASSENGERSSHIP995.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP995.png
# Processado: PASSENGERSSHIP996.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP996.png
# Processado: PASSENGERSSHIP997.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP997.png
# Processado: PASSENGERSSHIP998.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP998.png
# Processado: PASSENGERSSHIP999.png -> DDPM-F64x4/PASSENGERSSHIP/PASSENGERSSHIP999.png
# Processamento concluído!
