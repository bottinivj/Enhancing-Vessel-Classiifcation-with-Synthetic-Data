# %%
generating_class = 'GENERALCARGO'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738239941.334788   97366 service.cc:145] XLA service 0x7f9d6c013130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738239941.334822   97366 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-01-30 12:25:42.225519: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738239942.971614   97366 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-01-30 12:25:44.503542: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738239946.097650   56249 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738239946.591542   56237 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738239946.649677   56255 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738239946.690415   56243 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738239946.961519   56266 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738239947.046612   56236 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738239947.109471   56255 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738239947.389648   56245 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738239947.440357   56251 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738239947.456567   56243 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738239947.634069   56237 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738239947.634822   56246 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738239947.765120   56243 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738239947.789570   56236 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738239947.826177   56263 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738239947.888673   56267 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738239947.927253   56256 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738239948.002856   56245 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738239948.124330   56239 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738239948.188699   56261 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738239948.196384   56249 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738239948.275094   56236 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738239948.280932   56241 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738239948.288707   56251 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738239948.464244   56242 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738239949.040940   56267 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738239949.238661   56243 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738239949.443688   56266 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738239949.561503   56253 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738239949.606031   56237 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738239949.609581   56265 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738239949.614507   56250 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738239949.650853   56242 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# 2025-01-30 12:25:58.882421: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:28:10.073095: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m12.19077811s
# Trying algorithm eng19{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:28:11.073245: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng25{k2=2,k3=0} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:28:30.369615: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 20.296453641s
# Trying algorithm eng25{k2=2,k3=0} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:28:31.369775: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng2{k2=1,k3=0} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:31:15.160256: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m44.790574089s
# Trying algorithm eng2{k2=1,k3=0} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:31:16.834120: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng5{} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-01-30 12:35:09.051157: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3m53.217096285s
# Trying algorithm eng5{} for conv (f32[32,768,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,8,8]{3,2,1,0}, f32[512,768,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1738240529.273474   97366 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738240529.318891   97366 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 684s 452ms/step - loss: 0.2381
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - loss: 0.0287
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - loss: 0.0249
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0205
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0202
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0194
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0190
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0177
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0185
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0173
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0169
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0188
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0173
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0174
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0162
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0160
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0164
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0160
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0171
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0164
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2706s 16s/step - loss: 0.0158
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - loss: 0.0167
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0151
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0163
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0152
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0160
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0155
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0156
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0166
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2559s 15s/step - loss: 0.0160
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0155
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0156
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0155
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0143
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 7165s 43s/step - loss: 0.0155
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 39s 143ms/step - loss: 0.0156
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0144
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - loss: 0.0149
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1401s 8s/step - loss: 0.0153
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0153
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0148
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0151
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0156
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0146
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0146
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0150
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0143
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0142
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0146
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0140
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0148
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0148
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0151
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0139
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0151
# Epoch 56/500
# 142/168 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0146
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - loss: 0.0131
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0127
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0127
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0127
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - loss: 0.0128
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0119
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0121
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0130
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0128
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0130
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0125
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0125
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0127
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0127
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0127
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0127
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - loss: 0.0127
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0134
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0124
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0137
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0131
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0126
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0132
# Epoch 346/500
#  93/168 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0132
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import os
from IPython.display import clear_output

num_img = 5400

output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    print("Faltam %d iterações" % (t))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# Faltam 0 iterações

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: GENERALCARGO0.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO0.png
# Processado: GENERALCARGO1.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1.png
# Processado: GENERALCARGO10.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO10.png
# Processado: GENERALCARGO100.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO100.png
# Processado: GENERALCARGO1000.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1000.png
# Processado: GENERALCARGO1001.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1001.png
# Processado: GENERALCARGO1002.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1002.png
# Processado: GENERALCARGO1003.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1003.png
# Processado: GENERALCARGO1004.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1004.png
# Processado: GENERALCARGO1005.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1005.png
# Processado: GENERALCARGO1006.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1006.png
# Processado: GENERALCARGO1007.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1007.png
# Processado: GENERALCARGO1008.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1008.png
# Processado: GENERALCARGO1009.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1009.png
# Processado: GENERALCARGO101.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO101.png
# Processado: GENERALCARGO1010.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1010.png
# Processado: GENERALCARGO1011.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1011.png
# Processado: GENERALCARGO1012.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1012.png
# Processado: GENERALCARGO1013.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1013.png
# Processado: GENERALCARGO1014.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1014.png
# Processado: GENERALCARGO1015.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1015.png
# Processado: GENERALCARGO1016.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1016.png
# Processado: GENERALCARGO1017.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1017.png
# Processado: GENERALCARGO1018.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1018.png
# Processado: GENERALCARGO1019.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1019.png
# Processado: GENERALCARGO102.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO102.png
# Processado: GENERALCARGO1020.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1020.png
# Processado: GENERALCARGO1021.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1021.png
# Processado: GENERALCARGO1022.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1022.png
# Processado: GENERALCARGO1023.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1023.png
# Processado: GENERALCARGO1024.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1024.png
# Processado: GENERALCARGO1025.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1025.png
# Processado: GENERALCARGO1026.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1026.png
# Processado: GENERALCARGO1027.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1027.png
# Processado: GENERALCARGO1028.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1028.png
# Processado: GENERALCARGO1029.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1029.png
# Processado: GENERALCARGO103.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO103.png
# Processado: GENERALCARGO1030.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1030.png
# Processado: GENERALCARGO1031.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1031.png
# Processado: GENERALCARGO1032.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1032.png
# Processado: GENERALCARGO1033.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1033.png
# Processado: GENERALCARGO1034.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1034.png
# Processado: GENERALCARGO1035.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1035.png
# Processado: GENERALCARGO1036.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1036.png
# Processado: GENERALCARGO1037.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1037.png
# Processado: GENERALCARGO1038.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1038.png
# Processado: GENERALCARGO1039.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1039.png
# Processado: GENERALCARGO104.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO104.png
# Processado: GENERALCARGO1040.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1040.png
# Processado: GENERALCARGO1041.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1041.png
# Processado: GENERALCARGO1042.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1042.png
# Processado: GENERALCARGO1043.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1043.png
# Processado: GENERALCARGO1044.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1044.png
# Processado: GENERALCARGO1045.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1045.png
# Processado: GENERALCARGO1046.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1046.png
# Processado: GENERALCARGO1047.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1047.png
# Processado: GENERALCARGO1048.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1048.png
# Processado: GENERALCARGO1049.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1049.png
# Processado: GENERALCARGO105.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO105.png
# Processado: GENERALCARGO1050.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1050.png
# Processado: GENERALCARGO1051.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1051.png
# Processado: GENERALCARGO1052.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1052.png
# Processado: GENERALCARGO1053.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1053.png
# Processado: GENERALCARGO1054.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1054.png
# Processado: GENERALCARGO1055.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1055.png
# Processado: GENERALCARGO1056.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1056.png
# Processado: GENERALCARGO1057.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1057.png
# Processado: GENERALCARGO1058.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1058.png
# Processado: GENERALCARGO1059.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1059.png
# Processado: GENERALCARGO106.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO106.png
# Processado: GENERALCARGO1060.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1060.png
# Processado: GENERALCARGO1061.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1061.png
# Processado: GENERALCARGO1062.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1062.png
# Processado: GENERALCARGO1063.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1063.png
# Processado: GENERALCARGO1064.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1064.png
# Processado: GENERALCARGO1065.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1065.png
# Processado: GENERALCARGO1066.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1066.png
# Processado: GENERALCARGO1067.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1067.png
# Processado: GENERALCARGO1068.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1068.png
# Processado: GENERALCARGO1069.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1069.png
# Processado: GENERALCARGO107.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO107.png
# Processado: GENERALCARGO1070.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1070.png
# Processado: GENERALCARGO1071.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1071.png
# Processado: GENERALCARGO1072.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1072.png
# Processado: GENERALCARGO1073.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1073.png
# Processado: GENERALCARGO1074.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1074.png
# Processado: GENERALCARGO1075.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1075.png
# Processado: GENERALCARGO1076.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1076.png
# Processado: GENERALCARGO1077.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1077.png
# Processado: GENERALCARGO1078.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1078.png
# Processado: GENERALCARGO1079.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1079.png
# Processado: GENERALCARGO108.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO108.png
# Processado: GENERALCARGO1080.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1080.png
# Processado: GENERALCARGO1081.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1081.png
# Processado: GENERALCARGO1082.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1082.png
# Processado: GENERALCARGO1083.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1083.png
# Processado: GENERALCARGO1084.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1084.png
# Processado: GENERALCARGO1085.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1085.png
# Processado: GENERALCARGO1086.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1086.png
# Processado: GENERALCARGO1087.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1087.png
# Processado: GENERALCARGO1088.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1088.png
# Processado: GENERALCARGO1089.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1089.png
# Processado: GENERALCARGO109.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO109.png
# Processado: GENERALCARGO1090.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1090.png
# Processado: GENERALCARGO1091.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1091.png
# Processado: GENERALCARGO1092.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1092.png
# Processado: GENERALCARGO1093.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1093.png
# Processado: GENERALCARGO1094.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1094.png
# Processado: GENERALCARGO1095.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1095.png
# Processado: GENERALCARGO1096.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1096.png
# Processado: GENERALCARGO1097.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1097.png
# Processado: GENERALCARGO1098.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1098.png
# Processado: GENERALCARGO1099.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1099.png
# Processado: GENERALCARGO11.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO11.png
# Processado: GENERALCARGO110.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO110.png
# Processado: GENERALCARGO1100.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1100.png
# Processado: GENERALCARGO1101.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1101.png
# Processado: GENERALCARGO1102.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1102.png
# Processado: GENERALCARGO1103.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1103.png
# Processado: GENERALCARGO1104.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1104.png
# Processado: GENERALCARGO1105.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1105.png
# Processado: GENERALCARGO1106.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1106.png
# Processado: GENERALCARGO1107.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1107.png
# Processado: GENERALCARGO1108.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1108.png
# Processado: GENERALCARGO1109.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1109.png
# Processado: GENERALCARGO111.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO111.png
# Processado: GENERALCARGO1110.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1110.png
# Processado: GENERALCARGO1111.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1111.png
# Processado: GENERALCARGO1112.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1112.png
# Processado: GENERALCARGO1113.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1113.png
# Processado: GENERALCARGO1114.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1114.png
# Processado: GENERALCARGO1115.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1115.png
# Processado: GENERALCARGO1116.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1116.png
# Processado: GENERALCARGO1117.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1117.png
# Processado: GENERALCARGO1118.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1118.png
# Processado: GENERALCARGO1119.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1119.png
# Processado: GENERALCARGO112.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO112.png
# Processado: GENERALCARGO1120.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1120.png
# Processado: GENERALCARGO1121.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1121.png
# Processado: GENERALCARGO1122.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1122.png
# Processado: GENERALCARGO1123.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1123.png
# Processado: GENERALCARGO1124.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1124.png
# Processado: GENERALCARGO1125.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1125.png
# Processado: GENERALCARGO1126.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1126.png
# Processado: GENERALCARGO1127.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1127.png
# Processado: GENERALCARGO1128.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1128.png
# Processado: GENERALCARGO1129.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1129.png
# Processado: GENERALCARGO113.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO113.png
# Processado: GENERALCARGO1130.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1130.png
# Processado: GENERALCARGO1131.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1131.png
# Processado: GENERALCARGO1132.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1132.png
# Processado: GENERALCARGO1133.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1133.png
# Processado: GENERALCARGO1134.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1134.png
# Processado: GENERALCARGO1135.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1135.png
# Processado: GENERALCARGO1136.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1136.png
# Processado: GENERALCARGO1137.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1137.png
# Processado: GENERALCARGO1138.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1138.png
# Processado: GENERALCARGO1139.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1139.png
# Processado: GENERALCARGO114.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO114.png
# Processado: GENERALCARGO1140.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1140.png
# Processado: GENERALCARGO1141.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1141.png
# Processado: GENERALCARGO1142.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1142.png
# Processado: GENERALCARGO1143.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1143.png
# Processado: GENERALCARGO1144.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1144.png
# Processado: GENERALCARGO1145.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1145.png
# Processado: GENERALCARGO1146.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1146.png
# Processado: GENERALCARGO1147.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1147.png
# Processado: GENERALCARGO1148.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1148.png
# Processado: GENERALCARGO1149.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1149.png
# Processado: GENERALCARGO115.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO115.png
# Processado: GENERALCARGO1150.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1150.png
# Processado: GENERALCARGO1151.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1151.png
# Processado: GENERALCARGO1152.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1152.png
# Processado: GENERALCARGO1153.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1153.png
# Processado: GENERALCARGO1154.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1154.png
# Processado: GENERALCARGO1155.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1155.png
# Processado: GENERALCARGO1156.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1156.png
# Processado: GENERALCARGO1157.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1157.png
# Processado: GENERALCARGO1158.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1158.png
# Processado: GENERALCARGO1159.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1159.png
# Processado: GENERALCARGO116.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO116.png
# Processado: GENERALCARGO1160.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1160.png
# Processado: GENERALCARGO1161.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1161.png
# Processado: GENERALCARGO1162.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1162.png
# Processado: GENERALCARGO1163.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1163.png
# Processado: GENERALCARGO1164.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1164.png
# Processado: GENERALCARGO1165.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1165.png
# Processado: GENERALCARGO1166.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1166.png
# Processado: GENERALCARGO1167.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1167.png
# Processado: GENERALCARGO1168.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1168.png
# Processado: GENERALCARGO1169.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1169.png
# Processado: GENERALCARGO117.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO117.png
# Processado: GENERALCARGO1170.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1170.png
# Processado: GENERALCARGO1171.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1171.png
# Processado: GENERALCARGO1172.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1172.png
# Processado: GENERALCARGO1173.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1173.png
# Processado: GENERALCARGO1174.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1174.png
# Processado: GENERALCARGO1175.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1175.png
# Processado: GENERALCARGO1176.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1176.png
# Processado: GENERALCARGO1177.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1177.png
# Processado: GENERALCARGO1178.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1178.png
# Processado: GENERALCARGO1179.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1179.png
# Processado: GENERALCARGO118.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO118.png
# Processado: GENERALCARGO1180.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1180.png
# Processado: GENERALCARGO1181.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1181.png
# Processado: GENERALCARGO1182.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1182.png
# Processado: GENERALCARGO1183.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1183.png
# Processado: GENERALCARGO1184.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1184.png
# Processado: GENERALCARGO1185.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1185.png
# Processado: GENERALCARGO1186.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1186.png
# Processado: GENERALCARGO1187.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1187.png
# Processado: GENERALCARGO1188.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1188.png
# Processado: GENERALCARGO1189.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1189.png
# Processado: GENERALCARGO119.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO119.png
# Processado: GENERALCARGO1190.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1190.png
# Processado: GENERALCARGO1191.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1191.png
# Processado: GENERALCARGO1192.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1192.png
# Processado: GENERALCARGO1193.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1193.png
# Processado: GENERALCARGO1194.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1194.png
# Processado: GENERALCARGO1195.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1195.png
# Processado: GENERALCARGO1196.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1196.png
# Processado: GENERALCARGO1197.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1197.png
# Processado: GENERALCARGO1198.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1198.png
# Processado: GENERALCARGO1199.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1199.png
# Processado: GENERALCARGO12.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO12.png
# Processado: GENERALCARGO120.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO120.png
# Processado: GENERALCARGO1200.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1200.png
# Processado: GENERALCARGO1201.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1201.png
# Processado: GENERALCARGO1202.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1202.png
# Processado: GENERALCARGO1203.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1203.png
# Processado: GENERALCARGO1204.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1204.png
# Processado: GENERALCARGO1205.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1205.png
# Processado: GENERALCARGO1206.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1206.png
# Processado: GENERALCARGO1207.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1207.png
# Processado: GENERALCARGO1208.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1208.png
# Processado: GENERALCARGO1209.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1209.png
# Processado: GENERALCARGO121.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO121.png
# Processado: GENERALCARGO1210.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1210.png
# Processado: GENERALCARGO1211.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1211.png
# Processado: GENERALCARGO1212.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1212.png
# Processado: GENERALCARGO1213.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1213.png
# Processado: GENERALCARGO1214.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1214.png
# Processado: GENERALCARGO1215.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1215.png
# Processado: GENERALCARGO1216.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1216.png
# Processado: GENERALCARGO1217.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1217.png
# Processado: GENERALCARGO1218.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1218.png
# Processado: GENERALCARGO1219.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1219.png
# Processado: GENERALCARGO122.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO122.png
# Processado: GENERALCARGO1220.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1220.png
# Processado: GENERALCARGO1221.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1221.png
# Processado: GENERALCARGO1222.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1222.png
# Processado: GENERALCARGO1223.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1223.png
# Processado: GENERALCARGO1224.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1224.png
# Processado: GENERALCARGO1225.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1225.png
# Processado: GENERALCARGO1226.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1226.png
# Processado: GENERALCARGO1227.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1227.png
# Processado: GENERALCARGO1228.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1228.png
# Processado: GENERALCARGO1229.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1229.png
# Processado: GENERALCARGO123.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO123.png
# Processado: GENERALCARGO1230.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1230.png
# Processado: GENERALCARGO1231.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1231.png
# Processado: GENERALCARGO1232.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1232.png
# Processado: GENERALCARGO1233.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1233.png
# Processado: GENERALCARGO1234.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1234.png
# Processado: GENERALCARGO1235.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1235.png
# Processado: GENERALCARGO1236.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1236.png
# Processado: GENERALCARGO1237.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1237.png
# Processado: GENERALCARGO1238.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1238.png
# Processado: GENERALCARGO1239.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1239.png
# Processado: GENERALCARGO124.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO124.png
# Processado: GENERALCARGO1240.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1240.png
# Processado: GENERALCARGO1241.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1241.png
# Processado: GENERALCARGO1242.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1242.png
# Processado: GENERALCARGO1243.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1243.png
# Processado: GENERALCARGO1244.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1244.png
# Processado: GENERALCARGO1245.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1245.png
# Processado: GENERALCARGO1246.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1246.png
# Processado: GENERALCARGO1247.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1247.png
# Processado: GENERALCARGO1248.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1248.png
# Processado: GENERALCARGO1249.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1249.png
# Processado: GENERALCARGO125.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO125.png
# Processado: GENERALCARGO1250.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1250.png
# Processado: GENERALCARGO1251.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1251.png
# Processado: GENERALCARGO1252.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1252.png
# Processado: GENERALCARGO1253.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1253.png
# Processado: GENERALCARGO1254.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1254.png
# Processado: GENERALCARGO1255.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1255.png
# Processado: GENERALCARGO1256.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1256.png
# Processado: GENERALCARGO1257.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1257.png
# Processado: GENERALCARGO1258.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1258.png
# Processado: GENERALCARGO1259.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1259.png
# Processado: GENERALCARGO126.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO126.png
# Processado: GENERALCARGO1260.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1260.png
# Processado: GENERALCARGO1261.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1261.png
# Processado: GENERALCARGO1262.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1262.png
# Processado: GENERALCARGO1263.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1263.png
# Processado: GENERALCARGO1264.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1264.png
# Processado: GENERALCARGO1265.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1265.png
# Processado: GENERALCARGO1266.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1266.png
# Processado: GENERALCARGO1267.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1267.png
# Processado: GENERALCARGO1268.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1268.png
# Processado: GENERALCARGO1269.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1269.png
# Processado: GENERALCARGO127.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO127.png
# Processado: GENERALCARGO1270.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1270.png
# Processado: GENERALCARGO1271.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1271.png
# Processado: GENERALCARGO1272.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1272.png
# Processado: GENERALCARGO1273.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1273.png
# Processado: GENERALCARGO1274.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1274.png
# Processado: GENERALCARGO1275.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1275.png
# Processado: GENERALCARGO1276.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1276.png
# Processado: GENERALCARGO1277.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1277.png
# Processado: GENERALCARGO1278.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1278.png
# Processado: GENERALCARGO1279.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1279.png
# Processado: GENERALCARGO128.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO128.png
# Processado: GENERALCARGO1280.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1280.png
# Processado: GENERALCARGO1281.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1281.png
# Processado: GENERALCARGO1282.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1282.png
# Processado: GENERALCARGO1283.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1283.png
# Processado: GENERALCARGO1284.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1284.png
# Processado: GENERALCARGO1285.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1285.png
# Processado: GENERALCARGO1286.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1286.png
# Processado: GENERALCARGO1287.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1287.png
# Processado: GENERALCARGO1288.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1288.png
# Processado: GENERALCARGO1289.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1289.png
# Processado: GENERALCARGO129.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO129.png
# Processado: GENERALCARGO1290.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1290.png
# Processado: GENERALCARGO1291.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1291.png
# Processado: GENERALCARGO1292.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1292.png
# Processado: GENERALCARGO1293.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1293.png
# Processado: GENERALCARGO1294.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1294.png
# Processado: GENERALCARGO1295.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1295.png
# Processado: GENERALCARGO1296.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1296.png
# Processado: GENERALCARGO1297.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1297.png
# Processado: GENERALCARGO1298.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1298.png
# Processado: GENERALCARGO1299.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1299.png
# Processado: GENERALCARGO13.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO13.png
# Processado: GENERALCARGO130.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO130.png
# Processado: GENERALCARGO1300.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1300.png
# Processado: GENERALCARGO1301.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1301.png
# Processado: GENERALCARGO1302.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1302.png
# Processado: GENERALCARGO1303.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1303.png
# Processado: GENERALCARGO1304.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1304.png
# Processado: GENERALCARGO1305.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1305.png
# Processado: GENERALCARGO1306.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1306.png
# Processado: GENERALCARGO1307.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1307.png
# Processado: GENERALCARGO1308.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1308.png
# Processado: GENERALCARGO1309.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1309.png
# Processado: GENERALCARGO131.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO131.png
# Processado: GENERALCARGO1310.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1310.png
# Processado: GENERALCARGO1311.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1311.png
# Processado: GENERALCARGO1312.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1312.png
# Processado: GENERALCARGO1313.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1313.png
# Processado: GENERALCARGO1314.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1314.png
# Processado: GENERALCARGO1315.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1315.png
# Processado: GENERALCARGO1316.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1316.png
# Processado: GENERALCARGO1317.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1317.png
# Processado: GENERALCARGO1318.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1318.png
# Processado: GENERALCARGO1319.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1319.png
# Processado: GENERALCARGO132.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO132.png
# Processado: GENERALCARGO1320.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1320.png
# Processado: GENERALCARGO1321.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1321.png
# Processado: GENERALCARGO1322.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1322.png
# Processado: GENERALCARGO1323.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1323.png
# Processado: GENERALCARGO1324.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1324.png
# Processado: GENERALCARGO1325.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1325.png
# Processado: GENERALCARGO1326.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1326.png
# Processado: GENERALCARGO1327.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1327.png
# Processado: GENERALCARGO1328.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1328.png
# Processado: GENERALCARGO1329.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1329.png
# Processado: GENERALCARGO133.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO133.png
# Processado: GENERALCARGO1330.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1330.png
# Processado: GENERALCARGO1331.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1331.png
# Processado: GENERALCARGO1332.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1332.png
# Processado: GENERALCARGO1333.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1333.png
# Processado: GENERALCARGO1334.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1334.png
# Processado: GENERALCARGO1335.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1335.png
# Processado: GENERALCARGO1336.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1336.png
# Processado: GENERALCARGO1337.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1337.png
# Processado: GENERALCARGO1338.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1338.png
# Processado: GENERALCARGO1339.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1339.png
# Processado: GENERALCARGO134.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO134.png
# Processado: GENERALCARGO1340.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1340.png
# Processado: GENERALCARGO1341.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1341.png
# Processado: GENERALCARGO1342.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1342.png
# Processado: GENERALCARGO1343.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1343.png
# Processado: GENERALCARGO1344.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1344.png
# Processado: GENERALCARGO1345.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1345.png
# Processado: GENERALCARGO1346.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1346.png
# Processado: GENERALCARGO1347.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1347.png
# Processado: GENERALCARGO1348.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1348.png
# Processado: GENERALCARGO1349.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1349.png
# Processado: GENERALCARGO135.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO135.png
# Processado: GENERALCARGO1350.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1350.png
# Processado: GENERALCARGO1351.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1351.png
# Processado: GENERALCARGO1352.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1352.png
# Processado: GENERALCARGO1353.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1353.png
# Processado: GENERALCARGO1354.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1354.png
# Processado: GENERALCARGO1355.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1355.png
# Processado: GENERALCARGO1356.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1356.png
# Processado: GENERALCARGO1357.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1357.png
# Processado: GENERALCARGO1358.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1358.png
# Processado: GENERALCARGO1359.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1359.png
# Processado: GENERALCARGO136.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO136.png
# Processado: GENERALCARGO1360.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1360.png
# Processado: GENERALCARGO1361.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1361.png
# Processado: GENERALCARGO1362.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1362.png
# Processado: GENERALCARGO1363.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1363.png
# Processado: GENERALCARGO1364.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1364.png
# Processado: GENERALCARGO1365.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1365.png
# Processado: GENERALCARGO1366.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1366.png
# Processado: GENERALCARGO1367.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1367.png
# Processado: GENERALCARGO1368.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1368.png
# Processado: GENERALCARGO1369.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1369.png
# Processado: GENERALCARGO137.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO137.png
# Processado: GENERALCARGO1370.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1370.png
# Processado: GENERALCARGO1371.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1371.png
# Processado: GENERALCARGO1372.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1372.png
# Processado: GENERALCARGO1373.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1373.png
# Processado: GENERALCARGO1374.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1374.png
# Processado: GENERALCARGO1375.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1375.png
# Processado: GENERALCARGO1376.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1376.png
# Processado: GENERALCARGO1377.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1377.png
# Processado: GENERALCARGO1378.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1378.png
# Processado: GENERALCARGO1379.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1379.png
# Processado: GENERALCARGO138.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO138.png
# Processado: GENERALCARGO1380.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1380.png
# Processado: GENERALCARGO1381.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1381.png
# Processado: GENERALCARGO1382.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1382.png
# Processado: GENERALCARGO1383.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1383.png
# Processado: GENERALCARGO1384.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1384.png
# Processado: GENERALCARGO1385.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1385.png
# Processado: GENERALCARGO1386.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1386.png
# Processado: GENERALCARGO1387.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1387.png
# Processado: GENERALCARGO1388.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1388.png
# Processado: GENERALCARGO1389.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1389.png
# Processado: GENERALCARGO139.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO139.png
# Processado: GENERALCARGO1390.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1390.png
# Processado: GENERALCARGO1391.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1391.png
# Processado: GENERALCARGO1392.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1392.png
# Processado: GENERALCARGO1393.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1393.png
# Processado: GENERALCARGO1394.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1394.png
# Processado: GENERALCARGO1395.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1395.png
# Processado: GENERALCARGO1396.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1396.png
# Processado: GENERALCARGO1397.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1397.png
# Processado: GENERALCARGO1398.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1398.png
# Processado: GENERALCARGO1399.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1399.png
# Processado: GENERALCARGO14.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO14.png
# Processado: GENERALCARGO140.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO140.png
# Processado: GENERALCARGO1400.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1400.png
# Processado: GENERALCARGO1401.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1401.png
# Processado: GENERALCARGO1402.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1402.png
# Processado: GENERALCARGO1403.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1403.png
# Processado: GENERALCARGO1404.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1404.png
# Processado: GENERALCARGO1405.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1405.png
# Processado: GENERALCARGO1406.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1406.png
# Processado: GENERALCARGO1407.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1407.png
# Processado: GENERALCARGO1408.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1408.png
# Processado: GENERALCARGO1409.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1409.png
# Processado: GENERALCARGO141.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO141.png
# Processado: GENERALCARGO1410.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1410.png
# Processado: GENERALCARGO1411.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1411.png
# Processado: GENERALCARGO1412.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1412.png
# Processado: GENERALCARGO1413.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1413.png
# Processado: GENERALCARGO1414.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1414.png
# Processado: GENERALCARGO1415.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1415.png
# Processado: GENERALCARGO1416.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1416.png
# Processado: GENERALCARGO1417.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1417.png
# Processado: GENERALCARGO1418.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1418.png
# Processado: GENERALCARGO1419.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1419.png
# Processado: GENERALCARGO142.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO142.png
# Processado: GENERALCARGO1420.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1420.png
# Processado: GENERALCARGO1421.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1421.png
# Processado: GENERALCARGO1422.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1422.png
# Processado: GENERALCARGO1423.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1423.png
# Processado: GENERALCARGO1424.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1424.png
# Processado: GENERALCARGO1425.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1425.png
# Processado: GENERALCARGO1426.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1426.png
# Processado: GENERALCARGO1427.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1427.png
# Processado: GENERALCARGO1428.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1428.png
# Processado: GENERALCARGO1429.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1429.png
# Processado: GENERALCARGO143.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO143.png
# Processado: GENERALCARGO1430.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1430.png
# Processado: GENERALCARGO1431.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1431.png
# Processado: GENERALCARGO1432.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1432.png
# Processado: GENERALCARGO1433.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1433.png
# Processado: GENERALCARGO1434.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1434.png
# Processado: GENERALCARGO1435.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1435.png
# Processado: GENERALCARGO1436.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1436.png
# Processado: GENERALCARGO1437.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1437.png
# Processado: GENERALCARGO1438.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1438.png
# Processado: GENERALCARGO1439.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1439.png
# Processado: GENERALCARGO144.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO144.png
# Processado: GENERALCARGO1440.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1440.png
# Processado: GENERALCARGO1441.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1441.png
# Processado: GENERALCARGO1442.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1442.png
# Processado: GENERALCARGO1443.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1443.png
# Processado: GENERALCARGO1444.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1444.png
# Processado: GENERALCARGO1445.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1445.png
# Processado: GENERALCARGO1446.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1446.png
# Processado: GENERALCARGO1447.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1447.png
# Processado: GENERALCARGO1448.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1448.png
# Processado: GENERALCARGO1449.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1449.png
# Processado: GENERALCARGO145.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO145.png
# Processado: GENERALCARGO1450.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1450.png
# Processado: GENERALCARGO1451.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1451.png
# Processado: GENERALCARGO1452.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1452.png
# Processado: GENERALCARGO1453.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1453.png
# Processado: GENERALCARGO1454.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1454.png
# Processado: GENERALCARGO1455.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1455.png
# Processado: GENERALCARGO1456.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1456.png
# Processado: GENERALCARGO1457.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1457.png
# Processado: GENERALCARGO1458.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1458.png
# Processado: GENERALCARGO1459.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1459.png
# Processado: GENERALCARGO146.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO146.png
# Processado: GENERALCARGO1460.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1460.png
# Processado: GENERALCARGO1461.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1461.png
# Processado: GENERALCARGO1462.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1462.png
# Processado: GENERALCARGO1463.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1463.png
# Processado: GENERALCARGO1464.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1464.png
# Processado: GENERALCARGO1465.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1465.png
# Processado: GENERALCARGO1466.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1466.png
# Processado: GENERALCARGO1467.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1467.png
# Processado: GENERALCARGO1468.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1468.png
# Processado: GENERALCARGO1469.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1469.png
# Processado: GENERALCARGO147.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO147.png
# Processado: GENERALCARGO1470.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1470.png
# Processado: GENERALCARGO1471.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1471.png
# Processado: GENERALCARGO1472.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1472.png
# Processado: GENERALCARGO1473.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1473.png
# Processado: GENERALCARGO1474.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1474.png
# Processado: GENERALCARGO1475.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1475.png
# Processado: GENERALCARGO1476.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1476.png
# Processado: GENERALCARGO1477.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1477.png
# Processado: GENERALCARGO1478.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1478.png
# Processado: GENERALCARGO1479.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1479.png
# Processado: GENERALCARGO148.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO148.png
# Processado: GENERALCARGO1480.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1480.png
# Processado: GENERALCARGO1481.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1481.png
# Processado: GENERALCARGO1482.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1482.png
# Processado: GENERALCARGO1483.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1483.png
# Processado: GENERALCARGO1484.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1484.png
# Processado: GENERALCARGO1485.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1485.png
# Processado: GENERALCARGO1486.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1486.png
# Processado: GENERALCARGO1487.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1487.png
# Processado: GENERALCARGO1488.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1488.png
# Processado: GENERALCARGO1489.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1489.png
# Processado: GENERALCARGO149.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO149.png
# Processado: GENERALCARGO1490.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1490.png
# Processado: GENERALCARGO1491.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1491.png
# Processado: GENERALCARGO1492.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1492.png
# Processado: GENERALCARGO1493.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1493.png
# Processado: GENERALCARGO1494.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1494.png
# Processado: GENERALCARGO1495.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1495.png
# Processado: GENERALCARGO1496.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1496.png
# Processado: GENERALCARGO1497.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1497.png
# Processado: GENERALCARGO1498.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1498.png
# Processado: GENERALCARGO1499.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1499.png
# Processado: GENERALCARGO15.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO15.png
# Processado: GENERALCARGO150.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO150.png
# Processado: GENERALCARGO1500.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1500.png
# Processado: GENERALCARGO1501.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1501.png
# Processado: GENERALCARGO1502.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1502.png
# Processado: GENERALCARGO1503.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1503.png
# Processado: GENERALCARGO1504.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1504.png
# Processado: GENERALCARGO1505.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1505.png
# Processado: GENERALCARGO1506.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1506.png
# Processado: GENERALCARGO1507.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1507.png
# Processado: GENERALCARGO1508.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1508.png
# Processado: GENERALCARGO1509.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1509.png
# Processado: GENERALCARGO151.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO151.png
# Processado: GENERALCARGO1510.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1510.png
# Processado: GENERALCARGO1511.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1511.png
# Processado: GENERALCARGO1512.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1512.png
# Processado: GENERALCARGO1513.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1513.png
# Processado: GENERALCARGO1514.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1514.png
# Processado: GENERALCARGO1515.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1515.png
# Processado: GENERALCARGO1516.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1516.png
# Processado: GENERALCARGO1517.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1517.png
# Processado: GENERALCARGO1518.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1518.png
# Processado: GENERALCARGO1519.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1519.png
# Processado: GENERALCARGO152.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO152.png
# Processado: GENERALCARGO1520.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1520.png
# Processado: GENERALCARGO1521.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1521.png
# Processado: GENERALCARGO1522.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1522.png
# Processado: GENERALCARGO1523.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1523.png
# Processado: GENERALCARGO1524.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1524.png
# Processado: GENERALCARGO1525.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1525.png
# Processado: GENERALCARGO1526.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1526.png
# Processado: GENERALCARGO1527.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1527.png
# Processado: GENERALCARGO1528.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1528.png
# Processado: GENERALCARGO1529.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1529.png
# Processado: GENERALCARGO153.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO153.png
# Processado: GENERALCARGO1530.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1530.png
# Processado: GENERALCARGO1531.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO1531.png
# ...
# Processado: GENERALCARGO817.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO817.png
# Processado: GENERALCARGO818.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO818.png
# Processado: GENERALCARGO819.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO819.png
# Processado: GENERALCARGO82.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO82.png
# Processado: GENERALCARGO820.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO820.png
# Processado: GENERALCARGO821.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO821.png
# Processado: GENERALCARGO822.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO822.png
# Processado: GENERALCARGO823.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO823.png
# Processado: GENERALCARGO824.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO824.png
# Processado: GENERALCARGO825.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO825.png
# Processado: GENERALCARGO826.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO826.png
# Processado: GENERALCARGO827.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO827.png
# Processado: GENERALCARGO828.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO828.png
# Processado: GENERALCARGO829.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO829.png
# Processado: GENERALCARGO83.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO83.png
# Processado: GENERALCARGO830.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO830.png
# Processado: GENERALCARGO831.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO831.png
# Processado: GENERALCARGO832.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO832.png
# Processado: GENERALCARGO833.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO833.png
# Processado: GENERALCARGO834.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO834.png
# Processado: GENERALCARGO835.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO835.png
# Processado: GENERALCARGO836.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO836.png
# Processado: GENERALCARGO837.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO837.png
# Processado: GENERALCARGO838.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO838.png
# Processado: GENERALCARGO839.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO839.png
# Processado: GENERALCARGO84.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO84.png
# Processado: GENERALCARGO840.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO840.png
# Processado: GENERALCARGO841.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO841.png
# Processado: GENERALCARGO842.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO842.png
# Processado: GENERALCARGO843.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO843.png
# Processado: GENERALCARGO844.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO844.png
# Processado: GENERALCARGO845.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO845.png
# Processado: GENERALCARGO846.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO846.png
# Processado: GENERALCARGO847.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO847.png
# Processado: GENERALCARGO848.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO848.png
# Processado: GENERALCARGO849.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO849.png
# Processado: GENERALCARGO85.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO85.png
# Processado: GENERALCARGO850.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO850.png
# Processado: GENERALCARGO851.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO851.png
# Processado: GENERALCARGO852.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO852.png
# Processado: GENERALCARGO853.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO853.png
# Processado: GENERALCARGO854.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO854.png
# Processado: GENERALCARGO855.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO855.png
# Processado: GENERALCARGO856.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO856.png
# Processado: GENERALCARGO857.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO857.png
# Processado: GENERALCARGO858.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO858.png
# Processado: GENERALCARGO859.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO859.png
# Processado: GENERALCARGO86.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO86.png
# Processado: GENERALCARGO860.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO860.png
# Processado: GENERALCARGO861.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO861.png
# Processado: GENERALCARGO862.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO862.png
# Processado: GENERALCARGO863.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO863.png
# Processado: GENERALCARGO864.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO864.png
# Processado: GENERALCARGO865.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO865.png
# Processado: GENERALCARGO866.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO866.png
# Processado: GENERALCARGO867.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO867.png
# Processado: GENERALCARGO868.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO868.png
# Processado: GENERALCARGO869.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO869.png
# Processado: GENERALCARGO87.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO87.png
# Processado: GENERALCARGO870.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO870.png
# Processado: GENERALCARGO871.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO871.png
# Processado: GENERALCARGO872.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO872.png
# Processado: GENERALCARGO873.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO873.png
# Processado: GENERALCARGO874.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO874.png
# Processado: GENERALCARGO875.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO875.png
# Processado: GENERALCARGO876.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO876.png
# Processado: GENERALCARGO877.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO877.png
# Processado: GENERALCARGO878.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO878.png
# Processado: GENERALCARGO879.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO879.png
# Processado: GENERALCARGO88.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO88.png
# Processado: GENERALCARGO880.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO880.png
# Processado: GENERALCARGO881.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO881.png
# Processado: GENERALCARGO882.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO882.png
# Processado: GENERALCARGO883.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO883.png
# Processado: GENERALCARGO884.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO884.png
# Processado: GENERALCARGO885.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO885.png
# Processado: GENERALCARGO886.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO886.png
# Processado: GENERALCARGO887.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO887.png
# Processado: GENERALCARGO888.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO888.png
# Processado: GENERALCARGO889.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO889.png
# Processado: GENERALCARGO89.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO89.png
# Processado: GENERALCARGO890.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO890.png
# Processado: GENERALCARGO891.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO891.png
# Processado: GENERALCARGO892.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO892.png
# Processado: GENERALCARGO893.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO893.png
# Processado: GENERALCARGO894.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO894.png
# Processado: GENERALCARGO895.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO895.png
# Processado: GENERALCARGO896.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO896.png
# Processado: GENERALCARGO897.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO897.png
# Processado: GENERALCARGO898.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO898.png
# Processado: GENERALCARGO899.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO899.png
# Processado: GENERALCARGO9.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO9.png
# Processado: GENERALCARGO90.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO90.png
# Processado: GENERALCARGO900.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO900.png
# Processado: GENERALCARGO901.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO901.png
# Processado: GENERALCARGO902.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO902.png
# Processado: GENERALCARGO903.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO903.png
# Processado: GENERALCARGO904.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO904.png
# Processado: GENERALCARGO905.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO905.png
# Processado: GENERALCARGO906.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO906.png
# Processado: GENERALCARGO907.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO907.png
# Processado: GENERALCARGO908.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO908.png
# Processado: GENERALCARGO909.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO909.png
# Processado: GENERALCARGO91.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO91.png
# Processado: GENERALCARGO910.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO910.png
# Processado: GENERALCARGO911.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO911.png
# Processado: GENERALCARGO912.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO912.png
# Processado: GENERALCARGO913.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO913.png
# Processado: GENERALCARGO914.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO914.png
# Processado: GENERALCARGO915.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO915.png
# Processado: GENERALCARGO916.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO916.png
# Processado: GENERALCARGO917.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO917.png
# Processado: GENERALCARGO918.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO918.png
# Processado: GENERALCARGO919.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO919.png
# Processado: GENERALCARGO92.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO92.png
# Processado: GENERALCARGO920.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO920.png
# Processado: GENERALCARGO921.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO921.png
# Processado: GENERALCARGO922.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO922.png
# Processado: GENERALCARGO923.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO923.png
# Processado: GENERALCARGO924.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO924.png
# Processado: GENERALCARGO925.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO925.png
# Processado: GENERALCARGO926.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO926.png
# Processado: GENERALCARGO927.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO927.png
# Processado: GENERALCARGO928.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO928.png
# Processado: GENERALCARGO929.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO929.png
# Processado: GENERALCARGO93.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO93.png
# Processado: GENERALCARGO930.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO930.png
# Processado: GENERALCARGO931.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO931.png
# Processado: GENERALCARGO932.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO932.png
# Processado: GENERALCARGO933.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO933.png
# Processado: GENERALCARGO934.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO934.png
# Processado: GENERALCARGO935.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO935.png
# Processado: GENERALCARGO936.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO936.png
# Processado: GENERALCARGO937.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO937.png
# Processado: GENERALCARGO938.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO938.png
# Processado: GENERALCARGO939.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO939.png
# Processado: GENERALCARGO94.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO94.png
# Processado: GENERALCARGO940.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO940.png
# Processado: GENERALCARGO941.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO941.png
# Processado: GENERALCARGO942.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO942.png
# Processado: GENERALCARGO943.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO943.png
# Processado: GENERALCARGO944.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO944.png
# Processado: GENERALCARGO945.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO945.png
# Processado: GENERALCARGO946.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO946.png
# Processado: GENERALCARGO947.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO947.png
# Processado: GENERALCARGO948.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO948.png
# Processado: GENERALCARGO949.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO949.png
# Processado: GENERALCARGO95.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO95.png
# Processado: GENERALCARGO950.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO950.png
# Processado: GENERALCARGO951.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO951.png
# Processado: GENERALCARGO952.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO952.png
# Processado: GENERALCARGO953.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO953.png
# Processado: GENERALCARGO954.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO954.png
# Processado: GENERALCARGO955.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO955.png
# Processado: GENERALCARGO956.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO956.png
# Processado: GENERALCARGO957.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO957.png
# Processado: GENERALCARGO958.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO958.png
# Processado: GENERALCARGO959.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO959.png
# Processado: GENERALCARGO96.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO96.png
# Processado: GENERALCARGO960.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO960.png
# Processado: GENERALCARGO961.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO961.png
# Processado: GENERALCARGO962.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO962.png
# Processado: GENERALCARGO963.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO963.png
# Processado: GENERALCARGO964.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO964.png
# Processado: GENERALCARGO965.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO965.png
# Processado: GENERALCARGO966.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO966.png
# Processado: GENERALCARGO967.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO967.png
# Processado: GENERALCARGO968.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO968.png
# Processado: GENERALCARGO969.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO969.png
# Processado: GENERALCARGO97.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO97.png
# Processado: GENERALCARGO970.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO970.png
# Processado: GENERALCARGO971.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO971.png
# Processado: GENERALCARGO972.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO972.png
# Processado: GENERALCARGO973.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO973.png
# Processado: GENERALCARGO974.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO974.png
# Processado: GENERALCARGO975.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO975.png
# Processado: GENERALCARGO976.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO976.png
# Processado: GENERALCARGO977.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO977.png
# Processado: GENERALCARGO978.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO978.png
# Processado: GENERALCARGO979.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO979.png
# Processado: GENERALCARGO98.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO98.png
# Processado: GENERALCARGO980.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO980.png
# Processado: GENERALCARGO981.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO981.png
# Processado: GENERALCARGO982.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO982.png
# Processado: GENERALCARGO983.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO983.png
# Processado: GENERALCARGO984.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO984.png
# Processado: GENERALCARGO985.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO985.png
# Processado: GENERALCARGO986.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO986.png
# Processado: GENERALCARGO987.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO987.png
# Processado: GENERALCARGO988.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO988.png
# Processado: GENERALCARGO989.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO989.png
# Processado: GENERALCARGO99.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO99.png
# Processado: GENERALCARGO990.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO990.png
# Processado: GENERALCARGO991.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO991.png
# Processado: GENERALCARGO992.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO992.png
# Processado: GENERALCARGO993.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO993.png
# Processado: GENERALCARGO994.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO994.png
# Processado: GENERALCARGO995.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO995.png
# Processado: GENERALCARGO996.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO996.png
# Processado: GENERALCARGO997.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO997.png
# Processado: GENERALCARGO998.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO998.png
# Processado: GENERALCARGO999.png -> DDPM-F64x4/GENERALCARGO/GENERALCARGO999.png
# Processamento concluído!
