# %%
generating_class = 'VEHICLESCARRIER'
real_dir = 'DATASET54000'
fake_dir = 'VAE-F64'

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
import optuna
import gc
from keras import ops
from keras import layers
from tqdm import tqdm
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt


from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from itertools import product
import torch
import torchvision


print(f"Versão do Tensorflow: {tf.__version__}")
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")

print(f"PyTorch version: {torch.__version__}")
print(torchvision.__version__)
print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# 2025-07-25 12:15:22.920637: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-25 12:15:22.940590: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# True
# NVIDIA GeForce RTX 4090
# 2025-07-25 12:15:24.665093: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:24.667967: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:24.667983: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
input_dir = str(real_dir + '/' + generating_class)

dataset = keras.utils.image_dataset_from_directory(
    input_dir, label_mode=None, image_size=(64, 64), batch_size=256
)
dataset = dataset.map(lambda x: x / 255.0)

for x in dataset:
    plt.figure(figsize=(20,15))

    for i in range (15):
        plt.subplot(1, 15, i + 1)
        plt.axis("off")
        plt.imshow((x.numpy() * 255).astype("int32")[i])
    break
# Out:
# Found 5400 files.
# 2025-07-25 12:15:31.710950: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:31.710985: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:31.710995: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:31.809713: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:31.809740: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:31.809744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-25 12:15:31.809760: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-25 12:15:31.809778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
#encoder
def getEncoder(convLayers=1, denseLayer=1, denseUnits=1024, latent_dim=2, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  encoder_inputs = keras.Input(shape=(64, 64, 3))

  for i in range(convLayers):
    if i == 0:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(encoder_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Conv2D(filters*(2**i), kernel, activation=activation, strides=2, padding="same")(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  x = layers.Flatten()(x)

  for i in range(denseLayer):
    x = layers.Dense(denseUnits//(2**i), activation="relu")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  z_mean = layers.Dense(latent_dim, name="z_mean")(x)
  z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
  z = Sampling()([z_mean, z_log_var])
  encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
  encoder.summary()
  return encoder

#decoder
def getDecoder(convLayers=1, denseLayers=3, latent_dim=2, latent_dim_mult=16, activation='relu', filters=32, kernel=3, addBatchNorm=True, addDropout=True, dropout_rate=0):
  latent_inputs = keras.Input(shape=(latent_dim,))

  for i in range(denseLayers):
    if i == 0:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(latent_inputs)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)
    else:
      x = layers.Dense(latent_dim*latent_dim_mult*(2**i), activation=activation)(x)
      if addBatchNorm == True:
          x = layers.BatchNormalization()(x)
      if addDropout == True:
          x = layers.Dropout(dropout_rate)(x)

  if(denseLayers==0):
    x = latent_inputs

  x = layers.Dense((64//(2**convLayers)) * (64//(2**convLayers)) * filters*(2**(convLayers-1)), activation=activation)(x)
  if addBatchNorm == True:
      x = layers.BatchNormalization()(x)
  if addDropout == True:
      x = layers.Dropout(dropout_rate)(x)

  x = layers.Reshape( ( 64//(2**convLayers), 64//(2**convLayers), filters*(2**(convLayers-1)) )  )   (x)

  for i in range(convLayers):
    x = layers.Conv2DTranspose((convLayers*filters)//(i+1), kernel, activation=activation, strides=2, padding="same")(x)
    if addBatchNorm == True:
        x = layers.BatchNormalization()(x)
    if addDropout == True:
        x = layers.Dropout(dropout_rate)(x)

  decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
  decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
  decoder.summary()
  return decoder

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
# Configurações globais
image_size = 64  # Dimensão para redimensionar imagens
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# Função para carregar e pré-processar uma imagem
def load_image(image_path):
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        tensor = transform(img) * 255  # Escalar de [0, 1] para [0, 255]
        return tensor.to(torch.uint8).unsqueeze(0)  # Adiciona dimensão de batch (1, C, H, W)

# Função para calcular FID
def calculate_fid(real_dir, generated_dir, target_class, num_samples=100, batch_size=10):
    real_class_dir = os.path.join(real_dir, target_class)
    generated_class_dir = os.path.join(generated_dir, target_class)

    # Listar imagens nas pastas
    real_files = [os.path.join(real_class_dir, f) for f in os.listdir(real_class_dir) if f.endswith(("png", "jpg", "jpeg"))]
    gen_files = [os.path.join(generated_class_dir, f) for f in os.listdir(generated_class_dir) if f.endswith(("png", "jpg", "jpeg"))]

    if len(real_files) < num_samples or len(gen_files) < num_samples:
        raise ValueError(f"Imagens insuficientes para a classe '{target_class}'. É necessário pelo menos {num_samples} imagens por classe.")

    sampled_real = np.random.choice(real_files, num_samples, replace=False)
    sampled_gen = np.random.choice(gen_files, num_samples, replace=False)

    fid = FrechetInceptionDistance()

    # Usar tqdm para mostrar o progresso
    for i in tqdm(range(0, num_samples, batch_size), desc=f"Processando classe '{target_class}'"):
        batch_real_files = sampled_real[i:i + batch_size]
        batch_gen_files = sampled_gen[i:i + batch_size]

        real_batch = []
        gen_batch = []

        for real_file, gen_file in zip(batch_real_files, batch_gen_files):
            # Preparar imagens para FID
            real_batch.append(load_image(real_file))
            gen_batch.append(load_image(gen_file))

        # Concatenar batches
        real_batch = torch.cat(real_batch, dim=0)
        gen_batch = torch.cat(gen_batch, dim=0)

        # Atualizar FID por batch
        fid.update(real_batch, real=True)
        fid.update(gen_batch, real=False)

    # Calcular FID final
    fid_score = fid.compute()

    return fid_score.item()

# %%
best_convLayers = 6
best_denseLayer1 = 1
best_denseUnits = 60
best_activation = 'gelu'
best_filters = 103
best_kernel = 5
best_addBatchNorm = False
best_addDropout = False
best_dropout_rate = 0.08233384817854303
best_denseLayer2 = 0
best_latent_dim = 13
best_latent_dim_mult = 9
best_learning_rate = 2.4790430493940505e-05
best_optimzer = keras.optimizers.Lion(learning_rate=best_learning_rate)
best_batch_size = 128

encoder = getEncoder(convLayers=best_convLayers, denseLayer=best_denseLayer1, denseUnits=best_denseUnits, latent_dim=best_latent_dim, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)
decoder = getDecoder(convLayers=best_convLayers, denseLayers=best_denseLayer2, latent_dim=best_latent_dim, latent_dim_mult=best_latent_dim_mult, activation=best_activation, filters=best_filters, kernel=best_kernel, addBatchNorm=best_addBatchNorm, addDropout=best_addDropout, dropout_rate=best_dropout_rate)

vae = VAE(encoder, decoder)
vae.compile(optimizer=best_optimzer)
history = vae.fit(dataset, epochs=1000, batch_size=best_batch_size)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      7,828 │ input_layer[0][0] │
# │                     │ 103)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    530,656 │ conv2d[0][0]      │
# │                     │ 206)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 412) │  2,122,212 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 824) │  8,488,024 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 2, 2,      │ 33,950,448 │ conv2d_3[0][0]    │
# │                     │ 1648)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 1, 1,      │ 135,798,4… │ conv2d_4[0][0]    │
# │                     │ 3296)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3296)      │          0 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60)        │    197,820 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 13)        │        793 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 13)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 181,097,070 (690.83 MB)
#  Trainable params: 181,097,070 (690.83 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3296)           │        46,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 3296)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 618)      │    50,923,818 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 4, 4, 309)      │     4,774,359 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 8, 8, 206)      │     1,591,556 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 16, 16, 154)    │       793,254 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 123)    │       473,673 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 103)    │       316,828 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 64, 64, 3)      │         2,784 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,922,416 (224.77 MB)
#  Trainable params: 58,922,416 (224.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 2025-07-25 12:15:34.743088: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1629] failed to alloc 1073741824 bytes on host: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-07-25 12:15:34.743116: W external/local_xla/xla/stream_executor/integrations/device_host_allocator.h:51] could not allocate pinned host memory of size: 1073741824
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753445735.821654   47515 service.cc:145] XLA service 0x7f2b34014520 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753445735.821696   47515 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-25 12:15:35.874911: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-25 12:15:36.037371: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 2025-07-25 12:15:41.885261: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:41.953751: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.068589653s
# Trying algorithm eng0{} for conv (f32[256,103,65,65]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,123,32,32]{3,2,1,0}, f32[123,103,5,5]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:53.573213: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:54.278977: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.705855294s
# Trying algorithm eng20{k2=5,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:55.279121: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:55.912824: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.63378557s
# Trying algorithm eng20{k2=8,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:56.913012: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:57.658126: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.745226567s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:58.658271: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2025-07-25 12:15:59.215712: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.557525999s
# Trying algorithm eng20{k2=6,k3=0} for conv (f32[3296,1648,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1648,3,3]{3,2,1,0}, f32[256,3296,1,1]{3,2,1,0}), window={size=5x5 stride=2x2 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1753445766.446374   47515 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 42s 453ms/step - kl_loss: 2.2742e-06 - loss: 2838.9617 - reconstruction_loss: 2838.9617
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 0.0090 - loss: 2837.8433 - reconstruction_loss: 2837.8342
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 8.6661 - loss: 2821.2454 - reconstruction_loss: 2812.5791
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.0429 - loss: 2716.3394 - reconstruction_loss: 2700.2964
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 5.5583 - loss: 2684.2935 - reconstruction_loss: 2678.7354
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 5.4583 - loss: 2671.6477 - reconstruction_loss: 2666.1895
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 6.8743 - loss: 2653.0730 - reconstruction_loss: 2646.1987
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 8.8851 - loss: 2637.5562 - reconstruction_loss: 2628.6707
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 8.0717 - loss: 2630.8167 - reconstruction_loss: 2622.7449
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 8.4590 - loss: 2619.6147 - reconstruction_loss: 2611.1558
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 9.7215 - loss: 2605.1274 - reconstruction_loss: 2595.4060
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 10.2291 - loss: 2591.9504 - reconstruction_loss: 2581.7212
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 10.9974 - loss: 2580.3625 - reconstruction_loss: 2569.3652
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.0875 - loss: 2576.5320 - reconstruction_loss: 2564.4446
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 11.7977 - loss: 2562.9617 - reconstruction_loss: 2551.1638
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 11.2784 - loss: 2566.4841 - reconstruction_loss: 2555.2061
# Epoch 17/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 11.6294 - loss: 2558.8801 - reconstruction_loss: 2547.2505
# Epoch 18/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 11.9839 - loss: 2551.1921 - reconstruction_loss: 2539.2083
# Epoch 19/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.2798 - loss: 2544.7256 - reconstruction_loss: 2532.4456
# Epoch 20/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.8333 - loss: 2538.8108 - reconstruction_loss: 2525.9775
# Epoch 21/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.8862 - loss: 2533.5652 - reconstruction_loss: 2520.6787
# Epoch 22/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.6451 - loss: 2527.1350 - reconstruction_loss: 2514.4900
# Epoch 23/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.6028 - loss: 2524.8586 - reconstruction_loss: 2512.2556
# Epoch 24/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.6400 - loss: 2524.0520 - reconstruction_loss: 2511.4121
# Epoch 25/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.4857 - loss: 2520.0127 - reconstruction_loss: 2507.5269
# Epoch 26/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.3722 - loss: 2520.2871 - reconstruction_loss: 2507.9148
# Epoch 27/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.1333 - loss: 2516.1902 - reconstruction_loss: 2504.0569
# Epoch 28/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.2458 - loss: 2514.1448 - reconstruction_loss: 2501.8992
# Epoch 29/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.5260 - loss: 2506.0923 - reconstruction_loss: 2493.5662
# Epoch 30/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.6463 - loss: 2510.0251 - reconstruction_loss: 2497.3787
# Epoch 31/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.7840 - loss: 2507.9241 - reconstruction_loss: 2495.1399
# Epoch 32/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.6682 - loss: 2510.7568 - reconstruction_loss: 2498.0884
# Epoch 33/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 12.6905 - loss: 2505.5979 - reconstruction_loss: 2492.9077
# Epoch 34/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 12.7632 - loss: 2501.8179 - reconstruction_loss: 2489.0549
# Epoch 35/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 12.8385 - loss: 2503.6023 - reconstruction_loss: 2490.7637
# Epoch 36/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 12.8024 - loss: 2501.2500 - reconstruction_loss: 2488.4475
# Epoch 37/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.7741 - loss: 2501.2493 - reconstruction_loss: 2488.4751
# Epoch 38/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 12.8975 - loss: 2498.8813 - reconstruction_loss: 2485.9839
# Epoch 39/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 12.9165 - loss: 2500.0757 - reconstruction_loss: 2487.1594
# Epoch 40/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 13.0820 - loss: 2498.1218 - reconstruction_loss: 2485.0400
# Epoch 41/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 13.1046 - loss: 2493.1975 - reconstruction_loss: 2480.0928
# Epoch 42/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 13.1390 - loss: 2495.4094 - reconstruction_loss: 2482.2705
# Epoch 43/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.5557 - loss: 2492.9749 - reconstruction_loss: 2479.4192
# Epoch 44/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 13.9407 - loss: 2489.4888 - reconstruction_loss: 2475.5481
# Epoch 45/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.0981 - loss: 2485.9998 - reconstruction_loss: 2471.9016
# Epoch 46/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 14.3151 - loss: 2486.2227 - reconstruction_loss: 2471.9075
# Epoch 47/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.3120 - loss: 2486.8262 - reconstruction_loss: 2472.5142
# Epoch 48/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.1926 - loss: 2480.2705 - reconstruction_loss: 2466.0781
# Epoch 49/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.0926 - loss: 2487.0767 - reconstruction_loss: 2472.9841
# Epoch 50/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.1889 - loss: 2486.7241 - reconstruction_loss: 2472.5354
# Epoch 51/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.2214 - loss: 2481.9060 - reconstruction_loss: 2467.6843
# Epoch 52/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.2822 - loss: 2482.2732 - reconstruction_loss: 2467.9910
# Epoch 53/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 14.5272 - loss: 2479.1921 - reconstruction_loss: 2464.6648
# Epoch 54/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.5238 - loss: 2475.4109 - reconstruction_loss: 2460.8872
# Epoch 55/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 14.8253 - loss: 2476.6021 - reconstruction_loss: 2461.7766
# Epoch 56/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.0053 - loss: 2475.1846 - reconstruction_loss: 2460.1794
# Epoch 57/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 15.2090 - loss: 2477.8635 - reconstruction_loss: 2462.6548
# Epoch 58/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.5502 - loss: 2472.6191 - reconstruction_loss: 2457.0688
# Epoch 59/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.7232 - loss: 2471.7224 - reconstruction_loss: 2455.9993
# Epoch 60/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.8288 - loss: 2470.5110 - reconstruction_loss: 2454.6821
# Epoch 61/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.7809 - loss: 2470.9619 - reconstruction_loss: 2455.1812
# Epoch 62/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.0621 - loss: 2469.8315 - reconstruction_loss: 2453.7693
# Epoch 63/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 15.9021 - loss: 2467.1970 - reconstruction_loss: 2451.2949
# Epoch 64/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.0443 - loss: 2468.5315 - reconstruction_loss: 2452.4871
# Epoch 65/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.1706 - loss: 2463.3740 - reconstruction_loss: 2447.2029
# Epoch 66/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.2408 - loss: 2463.2961 - reconstruction_loss: 2447.0554
# Epoch 67/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 16.4599 - loss: 2464.3247 - reconstruction_loss: 2447.8647
# Epoch 68/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 16.6630 - loss: 2459.6748 - reconstruction_loss: 2443.0120
# Epoch 69/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.0250 - loss: 2458.3042 - reconstruction_loss: 2441.2791
# Epoch 70/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.2214 - loss: 2459.3560 - reconstruction_loss: 2442.1348
# Epoch 71/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.6887 - loss: 2454.1890 - reconstruction_loss: 2436.5002
# Epoch 72/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 17.8585 - loss: 2452.4265 - reconstruction_loss: 2434.5684
# Epoch 73/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.0360 - loss: 2449.8625 - reconstruction_loss: 2431.8264
# Epoch 74/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.0990 - loss: 2451.7041 - reconstruction_loss: 2433.6047
# Epoch 75/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.1750 - loss: 2448.5537 - reconstruction_loss: 2430.3789
# Epoch 76/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.3056 - loss: 2444.9922 - reconstruction_loss: 2426.6865
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.2656 - loss: 2448.4277 - reconstruction_loss: 2430.1624
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.5049 - loss: 2451.2297 - reconstruction_loss: 2432.7249
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.6522 - loss: 2447.5762 - reconstruction_loss: 2428.9236
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.6477 - loss: 2445.9946 - reconstruction_loss: 2427.3464
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.6181 - loss: 2444.6609 - reconstruction_loss: 2426.0430
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.8440 - loss: 2445.5332 - reconstruction_loss: 2426.6890
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 18.7917 - loss: 2445.4922 - reconstruction_loss: 2426.7007
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.8036 - loss: 2444.3022 - reconstruction_loss: 2425.4988
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.9982 - loss: 2443.0549 - reconstruction_loss: 2424.0566
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 18.9949 - loss: 2441.7395 - reconstruction_loss: 2422.7444
# Epoch 87/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.0077 - loss: 2439.3855 - reconstruction_loss: 2420.3777
# Epoch 88/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 19.2594 - loss: 2441.1235 - reconstruction_loss: 2421.8638
# Epoch 89/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 19.2951 - loss: 2436.2983 - reconstruction_loss: 2417.0034
# Epoch 90/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.2803 - loss: 2439.7046 - reconstruction_loss: 2420.4243
# Epoch 91/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.2583 - loss: 2439.0808 - reconstruction_loss: 2419.8228
# Epoch 92/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.2098 - loss: 2441.1960 - reconstruction_loss: 2421.9863
# Epoch 93/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.3395 - loss: 2437.7678 - reconstruction_loss: 2418.4282
# Epoch 94/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.4479 - loss: 2436.9097 - reconstruction_loss: 2417.4619
# Epoch 95/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.5301 - loss: 2435.7192 - reconstruction_loss: 2416.1892
# Epoch 96/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.5968 - loss: 2437.9150 - reconstruction_loss: 2418.3181
# Epoch 97/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.5186 - loss: 2434.2268 - reconstruction_loss: 2414.7083
# Epoch 98/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.7345 - loss: 2434.5161 - reconstruction_loss: 2414.7820
# Epoch 99/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 19.7937 - loss: 2431.2637 - reconstruction_loss: 2411.4697
# Epoch 100/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.0478 - loss: 2430.7432 - reconstruction_loss: 2410.6956
# Epoch 101/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.0149 - loss: 2431.9253 - reconstruction_loss: 2411.9104
# Epoch 102/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.1458 - loss: 2429.5720 - reconstruction_loss: 2409.4265
# Epoch 103/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.1316 - loss: 2433.5039 - reconstruction_loss: 2413.3726
# Epoch 104/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.3504 - loss: 2428.1213 - reconstruction_loss: 2407.7710
# Epoch 105/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.2053 - loss: 2432.0967 - reconstruction_loss: 2411.8914
# Epoch 106/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.4158 - loss: 2431.5176 - reconstruction_loss: 2411.1016
# Epoch 107/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.5037 - loss: 2429.4819 - reconstruction_loss: 2408.9785
# Epoch 108/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.4870 - loss: 2426.9275 - reconstruction_loss: 2406.4404
# Epoch 109/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.2157 - loss: 2429.2944 - reconstruction_loss: 2409.0789
# Epoch 110/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.3794 - loss: 2430.3669 - reconstruction_loss: 2409.9875
# Epoch 111/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6789 - loss: 2428.7107 - reconstruction_loss: 2408.0317
# Epoch 112/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.5151 - loss: 2431.3647 - reconstruction_loss: 2410.8496
# Epoch 113/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.4369 - loss: 2430.2708 - reconstruction_loss: 2409.8340
# Epoch 114/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.5624 - loss: 2424.4429 - reconstruction_loss: 2403.8804
# Epoch 115/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6207 - loss: 2424.5496 - reconstruction_loss: 2403.9290
# Epoch 116/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.7041 - loss: 2424.9016 - reconstruction_loss: 2404.1975
# Epoch 117/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6170 - loss: 2428.3616 - reconstruction_loss: 2407.7446
# Epoch 118/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.7757 - loss: 2423.3684 - reconstruction_loss: 2402.5928
# Epoch 119/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.6806 - loss: 2427.9351 - reconstruction_loss: 2407.2546
# Epoch 120/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.7370 - loss: 2423.5081 - reconstruction_loss: 2402.7712
# Epoch 121/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.6704 - loss: 2425.1497 - reconstruction_loss: 2404.4790
# Epoch 122/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.6835 - loss: 2428.5979 - reconstruction_loss: 2407.9148
# Epoch 123/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8569 - loss: 2424.3870 - reconstruction_loss: 2403.5303
# Epoch 124/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.7448 - loss: 2421.3799 - reconstruction_loss: 2400.6353
# Epoch 125/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8078 - loss: 2422.1721 - reconstruction_loss: 2401.3640
# Epoch 126/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.9027 - loss: 2422.1353 - reconstruction_loss: 2401.2324
# Epoch 127/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.9395 - loss: 2421.5845 - reconstruction_loss: 2400.6448
# Epoch 128/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8849 - loss: 2424.1973 - reconstruction_loss: 2403.3123
# Epoch 129/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.9401 - loss: 2422.5232 - reconstruction_loss: 2401.5833
# Epoch 130/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.1742 - loss: 2420.6633 - reconstruction_loss: 2399.4890
# Epoch 131/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.9965 - loss: 2422.3826 - reconstruction_loss: 2401.3860
# Epoch 132/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8601 - loss: 2423.7209 - reconstruction_loss: 2402.8613
# Epoch 133/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8788 - loss: 2419.0945 - reconstruction_loss: 2398.2161
# Epoch 134/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.9596 - loss: 2419.5449 - reconstruction_loss: 2398.5854
# Epoch 135/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 20.9520 - loss: 2421.0828 - reconstruction_loss: 2400.1309
# Epoch 136/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 20.8427 - loss: 2417.7437 - reconstruction_loss: 2396.9006
# Epoch 137/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.0510 - loss: 2421.3123 - reconstruction_loss: 2400.2615
# Epoch 138/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.1611 - loss: 2422.8335 - reconstruction_loss: 2401.6721
# Epoch 139/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.1064 - loss: 2416.7649 - reconstruction_loss: 2395.6587
# Epoch 140/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.0946 - loss: 2420.0144 - reconstruction_loss: 2398.9199
# Epoch 141/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.0791 - loss: 2418.7417 - reconstruction_loss: 2397.6626
# Epoch 142/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.1670 - loss: 2421.3689 - reconstruction_loss: 2400.2017
# Epoch 143/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.2180 - loss: 2416.7876 - reconstruction_loss: 2395.5696
# Epoch 144/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.1319 - loss: 2421.6064 - reconstruction_loss: 2400.4744
# Epoch 145/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.2060 - loss: 2420.0708 - reconstruction_loss: 2398.8650
# Epoch 146/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.3288 - loss: 2416.2568 - reconstruction_loss: 2394.9282
# Epoch 147/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.4185 - loss: 2418.1733 - reconstruction_loss: 2396.7546
# Epoch 148/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.3748 - loss: 2415.3962 - reconstruction_loss: 2394.0215
# Epoch 149/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.2930 - loss: 2415.5850 - reconstruction_loss: 2394.2917
# Epoch 150/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.3616 - loss: 2418.9780 - reconstruction_loss: 2397.6165
# Epoch 151/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.3724 - loss: 2417.1211 - reconstruction_loss: 2395.7483
# Epoch 152/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.3641 - loss: 2414.9077 - reconstruction_loss: 2393.5435
# Epoch 153/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.6009 - loss: 2412.6628 - reconstruction_loss: 2391.0618
# Epoch 154/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.6231 - loss: 2412.4160 - reconstruction_loss: 2390.7927
# Epoch 155/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.4895 - loss: 2418.7385 - reconstruction_loss: 2397.2490
# Epoch 156/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.6794 - loss: 2412.5308 - reconstruction_loss: 2390.8516
# Epoch 157/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.6719 - loss: 2414.1721 - reconstruction_loss: 2392.5000
# Epoch 158/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.7050 - loss: 2417.3760 - reconstruction_loss: 2395.6711
# Epoch 159/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.6847 - loss: 2411.0359 - reconstruction_loss: 2389.3513
# Epoch 160/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.6483 - loss: 2415.2324 - reconstruction_loss: 2393.5842
# Epoch 161/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.7563 - loss: 2412.7021 - reconstruction_loss: 2390.9456
# Epoch 162/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.8069 - loss: 2415.0527 - reconstruction_loss: 2393.2456
# Epoch 163/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.5981 - loss: 2414.8823 - reconstruction_loss: 2393.2839
# Epoch 164/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.7521 - loss: 2412.1028 - reconstruction_loss: 2390.3508
# Epoch 165/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.8418 - loss: 2414.0181 - reconstruction_loss: 2392.1763
# Epoch 166/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.8778 - loss: 2411.9194 - reconstruction_loss: 2390.0417
# Epoch 167/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.0216 - loss: 2411.5244 - reconstruction_loss: 2389.5029
# Epoch 168/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.9362 - loss: 2410.0417 - reconstruction_loss: 2388.1055
# Epoch 169/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 21.9757 - loss: 2411.4907 - reconstruction_loss: 2389.5151
# Epoch 170/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 22.0277 - loss: 2411.9365 - reconstruction_loss: 2389.9089
# Epoch 171/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 21.9952 - loss: 2409.8584 - reconstruction_loss: 2387.8633
# Epoch 172/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.1127 - loss: 2409.4246 - reconstruction_loss: 2387.3118
# Epoch 173/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.0654 - loss: 2408.7490 - reconstruction_loss: 2386.6836
# Epoch 174/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.1884 - loss: 2411.3635 - reconstruction_loss: 2389.1753
# Epoch 175/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.0856 - loss: 2407.8813 - reconstruction_loss: 2385.7959
# Epoch 176/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.2088 - loss: 2406.2468 - reconstruction_loss: 2384.0381
# Epoch 177/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.1413 - loss: 2406.5210 - reconstruction_loss: 2384.3799
# Epoch 178/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.2058 - loss: 2411.1006 - reconstruction_loss: 2388.8948
# Epoch 179/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.4295 - loss: 2407.0085 - reconstruction_loss: 2384.5786
# Epoch 180/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.4743 - loss: 2408.0813 - reconstruction_loss: 2385.6069
# Epoch 181/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.5149 - loss: 2408.3518 - reconstruction_loss: 2385.8367
# Epoch 182/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.3805 - loss: 2410.6267 - reconstruction_loss: 2388.2461
# Epoch 183/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.5344 - loss: 2406.5737 - reconstruction_loss: 2384.0393
# Epoch 184/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.5596 - loss: 2406.9690 - reconstruction_loss: 2384.4094
# Epoch 185/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.6956 - loss: 2404.7227 - reconstruction_loss: 2382.0271
# Epoch 186/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.8069 - loss: 2400.3091 - reconstruction_loss: 2377.5024
# Epoch 187/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.6310 - loss: 2405.2537 - reconstruction_loss: 2382.6228
# Epoch 188/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.8747 - loss: 2406.9258 - reconstruction_loss: 2384.0510
# Epoch 189/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.8525 - loss: 2404.7710 - reconstruction_loss: 2381.9187
# Epoch 190/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.7248 - loss: 2408.0991 - reconstruction_loss: 2385.3740
# Epoch 191/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.7745 - loss: 2408.7815 - reconstruction_loss: 2386.0071
# Epoch 192/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9074 - loss: 2406.2988 - reconstruction_loss: 2383.3916
# Epoch 193/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.8842 - loss: 2402.7029 - reconstruction_loss: 2379.8186
# Epoch 194/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9421 - loss: 2401.2412 - reconstruction_loss: 2378.2991
# Epoch 195/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 22.9677 - loss: 2402.4102 - reconstruction_loss: 2379.4426
# Epoch 196/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9535 - loss: 2404.7407 - reconstruction_loss: 2381.7871
# Epoch 197/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.1889 - loss: 2400.1208 - reconstruction_loss: 2376.9321
# Epoch 198/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 22.9721 - loss: 2402.4590 - reconstruction_loss: 2379.4868
# Epoch 199/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.1962 - loss: 2398.5874 - reconstruction_loss: 2375.3914
# Epoch 200/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.1722 - loss: 2402.0847 - reconstruction_loss: 2378.9126
# Epoch 201/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2798 - loss: 2398.6431 - reconstruction_loss: 2375.3630
# Epoch 202/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2557 - loss: 2400.9714 - reconstruction_loss: 2377.7158
# Epoch 203/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2048 - loss: 2403.3767 - reconstruction_loss: 2380.1719
# Epoch 204/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.2352 - loss: 2403.4136 - reconstruction_loss: 2380.1782
# Epoch 205/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3788 - loss: 2398.8772 - reconstruction_loss: 2375.4983
# Epoch 206/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3932 - loss: 2400.8145 - reconstruction_loss: 2377.4211
# Epoch 207/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.4014 - loss: 2395.8862 - reconstruction_loss: 2372.4849
# Epoch 208/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3797 - loss: 2399.9712 - reconstruction_loss: 2376.5913
# Epoch 209/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.4296 - loss: 2397.5325 - reconstruction_loss: 2374.1030
# Epoch 210/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3296 - loss: 2400.1443 - reconstruction_loss: 2376.8145
# Epoch 211/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3190 - loss: 2397.6592 - reconstruction_loss: 2374.3401
# Epoch 212/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.3865 - loss: 2397.8025 - reconstruction_loss: 2374.4160
# Epoch 213/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.5489 - loss: 2399.8855 - reconstruction_loss: 2376.3362
# Epoch 214/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.4023 - loss: 2394.3652 - reconstruction_loss: 2370.9631
# Epoch 215/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.4476 - loss: 2397.7812 - reconstruction_loss: 2374.3335
# Epoch 216/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.6779 - loss: 2396.2922 - reconstruction_loss: 2372.6140
# Epoch 217/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.6079 - loss: 2397.6448 - reconstruction_loss: 2374.0366
# Epoch 218/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.6499 - loss: 2396.5725 - reconstruction_loss: 2372.9224
# Epoch 219/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.5763 - loss: 2396.5793 - reconstruction_loss: 2373.0032
# Epoch 220/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.6426 - loss: 2397.9395 - reconstruction_loss: 2374.2966
# Epoch 221/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.5440 - loss: 2400.2144 - reconstruction_loss: 2376.6699
# Epoch 222/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.7163 - loss: 2397.5774 - reconstruction_loss: 2373.8613
# Epoch 223/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.6421 - loss: 2391.9309 - reconstruction_loss: 2368.2888
# Epoch 224/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.7000 - loss: 2394.5837 - reconstruction_loss: 2370.8838
# Epoch 225/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.8536 - loss: 2393.4019 - reconstruction_loss: 2369.5483
# Epoch 226/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.9360 - loss: 2391.6162 - reconstruction_loss: 2367.6804
# Epoch 227/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.9005 - loss: 2396.0178 - reconstruction_loss: 2372.1174
# Epoch 228/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.6767 - loss: 2391.7151 - reconstruction_loss: 2368.0383
# Epoch 229/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.7900 - loss: 2392.2224 - reconstruction_loss: 2368.4324
# Epoch 230/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.8454 - loss: 2390.8391 - reconstruction_loss: 2366.9937
# Epoch 231/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.7509 - loss: 2395.7446 - reconstruction_loss: 2371.9939
# Epoch 232/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.7636 - loss: 2394.8845 - reconstruction_loss: 2371.1211
# Epoch 233/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.9099 - loss: 2390.5740 - reconstruction_loss: 2366.6641
# Epoch 234/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 23.9433 - loss: 2389.8552 - reconstruction_loss: 2365.9121
# Epoch 235/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.9393 - loss: 2394.8757 - reconstruction_loss: 2370.9365
# Epoch 236/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.9046 - loss: 2395.0903 - reconstruction_loss: 2371.1851
# Epoch 237/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.8948 - loss: 2392.9988 - reconstruction_loss: 2369.1042
# Epoch 238/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.9883 - loss: 2392.4348 - reconstruction_loss: 2368.4468
# Epoch 239/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.0474 - loss: 2391.9155 - reconstruction_loss: 2367.8679
# Epoch 240/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.1623 - loss: 2392.3752 - reconstruction_loss: 2368.2129
# Epoch 241/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 23.9558 - loss: 2391.5913 - reconstruction_loss: 2367.6355
# Epoch 242/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.1183 - loss: 2388.6030 - reconstruction_loss: 2364.4846
# Epoch 243/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.0345 - loss: 2386.3193 - reconstruction_loss: 2362.2849
# Epoch 244/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2205 - loss: 2388.8770 - reconstruction_loss: 2364.6565
# Epoch 245/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.1905 - loss: 2389.3894 - reconstruction_loss: 2365.1992
# Epoch 246/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2278 - loss: 2393.5684 - reconstruction_loss: 2369.3406
# Epoch 247/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.1659 - loss: 2388.2920 - reconstruction_loss: 2364.1260
# Epoch 248/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.3550 - loss: 2384.1560 - reconstruction_loss: 2359.8013
# Epoch 249/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2326 - loss: 2391.2776 - reconstruction_loss: 2367.0452
# Epoch 250/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2840 - loss: 2387.4231 - reconstruction_loss: 2363.1392
# Epoch 251/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2393 - loss: 2387.2297 - reconstruction_loss: 2362.9905
# Epoch 252/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.1499 - loss: 2388.1787 - reconstruction_loss: 2364.0288
# Epoch 253/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2228 - loss: 2387.8870 - reconstruction_loss: 2363.6641
# Epoch 254/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2640 - loss: 2388.5225 - reconstruction_loss: 2364.2585
# Epoch 255/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.2703 - loss: 2387.4602 - reconstruction_loss: 2363.1897
# Epoch 256/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.3437 - loss: 2387.3740 - reconstruction_loss: 2363.0305
# Epoch 257/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.4044 - loss: 2386.7383 - reconstruction_loss: 2362.3337
# Epoch 258/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.1815 - loss: 2390.5752 - reconstruction_loss: 2366.3938
# Epoch 259/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.3063 - loss: 2387.5847 - reconstruction_loss: 2363.2783
# Epoch 260/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.4281 - loss: 2386.6121 - reconstruction_loss: 2362.1838
# Epoch 261/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.5012 - loss: 2387.0020 - reconstruction_loss: 2362.5010
# Epoch 262/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.3413 - loss: 2388.8623 - reconstruction_loss: 2364.5212
# Epoch 263/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.3761 - loss: 2386.0605 - reconstruction_loss: 2361.6841
# Epoch 264/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.5185 - loss: 2383.6560 - reconstruction_loss: 2359.1379
# Epoch 265/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.4209 - loss: 2387.6814 - reconstruction_loss: 2363.2603
# Epoch 266/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.4836 - loss: 2386.6873 - reconstruction_loss: 2362.2036
# Epoch 267/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.5102 - loss: 2390.7520 - reconstruction_loss: 2366.2419
# Epoch 268/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.6530 - loss: 2386.5657 - reconstruction_loss: 2361.9131
# Epoch 269/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.5098 - loss: 2385.5483 - reconstruction_loss: 2361.0386
# Epoch 270/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.6235 - loss: 2385.1577 - reconstruction_loss: 2360.5344
# Epoch 271/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.6451 - loss: 2380.1592 - reconstruction_loss: 2355.5142
# Epoch 272/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.5499 - loss: 2382.2310 - reconstruction_loss: 2357.6814
# Epoch 273/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.5734 - loss: 2385.0188 - reconstruction_loss: 2360.4453
# Epoch 274/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.5623 - loss: 2385.2659 - reconstruction_loss: 2360.7036
# Epoch 275/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7316 - loss: 2384.5398 - reconstruction_loss: 2359.8081
# Epoch 276/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.7712 - loss: 2383.1165 - reconstruction_loss: 2358.3452
# Epoch 277/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.6303 - loss: 2382.9971 - reconstruction_loss: 2358.3669
# Epoch 278/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.7563 - loss: 2380.4180 - reconstruction_loss: 2355.6619
# Epoch 279/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7847 - loss: 2383.2209 - reconstruction_loss: 2358.4363
# Epoch 280/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.7727 - loss: 2382.2131 - reconstruction_loss: 2357.4407
# Epoch 281/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7152 - loss: 2385.0571 - reconstruction_loss: 2360.3418
# Epoch 282/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.6619 - loss: 2386.3748 - reconstruction_loss: 2361.7131
# Epoch 283/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - kl_loss: 24.7828 - loss: 2379.2173 - reconstruction_loss: 2354.4346
# Epoch 284/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7847 - loss: 2379.9148 - reconstruction_loss: 2355.1301
# Epoch 285/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7889 - loss: 2382.4563 - reconstruction_loss: 2357.6672
# Epoch 286/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7891 - loss: 2375.6838 - reconstruction_loss: 2350.8945
# Epoch 287/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 24.7068 - loss: 2384.0132 - reconstruction_loss: 2359.3064
# Epoch 288/1000
# ...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0799 - loss: 2334.0110 - reconstruction_loss: 2307.9314
# Epoch 874/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 25.9663 - loss: 2332.4307 - reconstruction_loss: 2306.4644
# Epoch 875/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9959 - loss: 2335.3914 - reconstruction_loss: 2309.3953
# Epoch 876/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0943 - loss: 2334.8071 - reconstruction_loss: 2308.7129
# Epoch 877/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0877 - loss: 2333.1912 - reconstruction_loss: 2307.1035
# Epoch 878/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0531 - loss: 2330.4937 - reconstruction_loss: 2304.4404
# Epoch 879/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0500 - loss: 2331.8137 - reconstruction_loss: 2305.7639
# Epoch 880/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 26.1333 - loss: 2326.1304 - reconstruction_loss: 2299.9968
# Epoch 881/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0904 - loss: 2334.4277 - reconstruction_loss: 2308.3374
# Epoch 882/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 25.9038 - loss: 2333.2063 - reconstruction_loss: 2307.3027
# Epoch 883/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0322 - loss: 2334.3547 - reconstruction_loss: 2308.3228
# Epoch 884/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1052 - loss: 2328.5518 - reconstruction_loss: 2302.4468
# Epoch 885/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1841 - loss: 2329.4441 - reconstruction_loss: 2303.2603
# Epoch 886/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0873 - loss: 2333.9978 - reconstruction_loss: 2307.9104
# Epoch 887/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0167 - loss: 2336.2612 - reconstruction_loss: 2310.2444
# Epoch 888/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0914 - loss: 2332.1736 - reconstruction_loss: 2306.0825
# Epoch 889/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1589 - loss: 2330.0889 - reconstruction_loss: 2303.9299
# Epoch 890/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1790 - loss: 2332.9954 - reconstruction_loss: 2306.8162
# Epoch 891/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0302 - loss: 2333.8899 - reconstruction_loss: 2307.8596
# Epoch 892/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1211 - loss: 2333.9792 - reconstruction_loss: 2307.8579
# Epoch 893/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0359 - loss: 2333.3425 - reconstruction_loss: 2307.3066
# Epoch 894/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9966 - loss: 2335.1741 - reconstruction_loss: 2309.1775
# Epoch 895/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1507 - loss: 2332.0483 - reconstruction_loss: 2305.8975
# Epoch 896/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1084 - loss: 2334.2258 - reconstruction_loss: 2308.1172
# Epoch 897/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0391 - loss: 2328.9177 - reconstruction_loss: 2302.8787
# Epoch 898/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0107 - loss: 2334.2573 - reconstruction_loss: 2308.2463
# Epoch 899/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0173 - loss: 2331.9685 - reconstruction_loss: 2305.9509
# Epoch 900/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0718 - loss: 2332.1982 - reconstruction_loss: 2306.1267
# Epoch 901/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1054 - loss: 2331.7285 - reconstruction_loss: 2305.6230
# Epoch 902/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.1272 - loss: 2330.2415 - reconstruction_loss: 2304.1140
# Epoch 903/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0954 - loss: 2328.3457 - reconstruction_loss: 2302.2502
# Epoch 904/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0126 - loss: 2329.8203 - reconstruction_loss: 2303.8079
# Epoch 905/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.2168 - loss: 2334.6589 - reconstruction_loss: 2308.4421
# Epoch 906/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0965 - loss: 2327.1665 - reconstruction_loss: 2301.0701
# Epoch 907/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 26.0623 - loss: 2332.9302 - reconstruction_loss: 2306.8679
# Epoch 908/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 26.0198 - loss: 2329.5161 - reconstruction_loss: 2303.4963
# Epoch 909/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0489 - loss: 2330.7725 - reconstruction_loss: 2304.7236
# Epoch 910/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0307 - loss: 2332.1919 - reconstruction_loss: 2306.1611
# Epoch 911/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1718 - loss: 2326.1531 - reconstruction_loss: 2299.9812
# Epoch 912/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0476 - loss: 2334.3730 - reconstruction_loss: 2308.3254
# Epoch 913/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0455 - loss: 2334.2883 - reconstruction_loss: 2308.2429
# Epoch 914/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0795 - loss: 2331.4409 - reconstruction_loss: 2305.3613
# Epoch 915/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0013 - loss: 2332.4717 - reconstruction_loss: 2306.4705
# Epoch 916/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0389 - loss: 2334.1008 - reconstruction_loss: 2308.0623
# Epoch 917/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0807 - loss: 2328.6958 - reconstruction_loss: 2302.6150
# Epoch 918/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0737 - loss: 2330.7053 - reconstruction_loss: 2304.6313
# Epoch 919/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0589 - loss: 2330.8667 - reconstruction_loss: 2304.8079
# Epoch 920/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0770 - loss: 2330.8003 - reconstruction_loss: 2304.7231
# Epoch 921/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0339 - loss: 2331.3643 - reconstruction_loss: 2305.3303
# Epoch 922/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1299 - loss: 2331.6248 - reconstruction_loss: 2305.4946
# Epoch 923/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0513 - loss: 2330.5347 - reconstruction_loss: 2304.4834
# Epoch 924/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.1588 - loss: 2330.6567 - reconstruction_loss: 2304.4980
# Epoch 925/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.1333 - loss: 2327.6968 - reconstruction_loss: 2301.5635
# Epoch 926/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0882 - loss: 2332.1912 - reconstruction_loss: 2306.1028
# Epoch 927/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9857 - loss: 2330.6709 - reconstruction_loss: 2304.6851
# Epoch 928/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1250 - loss: 2326.9797 - reconstruction_loss: 2300.8550
# Epoch 929/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0567 - loss: 2329.0740 - reconstruction_loss: 2303.0173
# Epoch 930/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - kl_loss: 26.1646 - loss: 2328.7468 - reconstruction_loss: 2302.5825
# Epoch 931/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.1070 - loss: 2326.5103 - reconstruction_loss: 2300.4033
# Epoch 932/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 25.9531 - loss: 2329.9680 - reconstruction_loss: 2304.0149
# Epoch 933/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0147 - loss: 2327.7832 - reconstruction_loss: 2301.7688
# Epoch 934/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1232 - loss: 2329.1052 - reconstruction_loss: 2302.9819
# Epoch 935/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9600 - loss: 2329.8513 - reconstruction_loss: 2303.8914
# Epoch 936/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0098 - loss: 2327.1746 - reconstruction_loss: 2301.1648
# Epoch 937/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0709 - loss: 2329.9265 - reconstruction_loss: 2303.8557
# Epoch 938/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0599 - loss: 2331.9399 - reconstruction_loss: 2305.8799
# Epoch 939/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 25.9711 - loss: 2331.5566 - reconstruction_loss: 2305.5852
# Epoch 940/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0892 - loss: 2335.8782 - reconstruction_loss: 2309.7886
# Epoch 941/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 25.9523 - loss: 2329.1641 - reconstruction_loss: 2303.2117
# Epoch 942/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1507 - loss: 2326.5972 - reconstruction_loss: 2300.4468
# Epoch 943/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1314 - loss: 2329.3535 - reconstruction_loss: 2303.2219
# Epoch 944/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0524 - loss: 2334.5337 - reconstruction_loss: 2308.4812
# Epoch 945/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0726 - loss: 2328.5928 - reconstruction_loss: 2302.5200
# Epoch 946/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 25.9967 - loss: 2329.9656 - reconstruction_loss: 2303.9688
# Epoch 947/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1113 - loss: 2331.7380 - reconstruction_loss: 2305.6265
# Epoch 948/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0561 - loss: 2328.6484 - reconstruction_loss: 2302.5920
# Epoch 949/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9902 - loss: 2332.1235 - reconstruction_loss: 2306.1333
# Epoch 950/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9962 - loss: 2327.2639 - reconstruction_loss: 2301.2678
# Epoch 951/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0202 - loss: 2324.1733 - reconstruction_loss: 2298.1531
# Epoch 952/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - kl_loss: 26.0226 - loss: 2334.3333 - reconstruction_loss: 2308.3105
# Epoch 953/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0302 - loss: 2329.2681 - reconstruction_loss: 2303.2378
# Epoch 954/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9851 - loss: 2331.6929 - reconstruction_loss: 2305.7078
# Epoch 955/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.1568 - loss: 2326.1445 - reconstruction_loss: 2299.9878
# Epoch 956/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0303 - loss: 2328.6707 - reconstruction_loss: 2302.6404
# Epoch 957/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0606 - loss: 2328.4197 - reconstruction_loss: 2302.3591
# Epoch 958/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9838 - loss: 2335.2688 - reconstruction_loss: 2309.2852
# Epoch 959/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0524 - loss: 2324.6362 - reconstruction_loss: 2298.5837
# Epoch 960/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9891 - loss: 2331.8071 - reconstruction_loss: 2305.8179
# Epoch 961/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 25.9890 - loss: 2331.9729 - reconstruction_loss: 2305.9836
# Epoch 962/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0067 - loss: 2332.7095 - reconstruction_loss: 2306.7026
# Epoch 963/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0538 - loss: 2329.6599 - reconstruction_loss: 2303.6060
# Epoch 964/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1382 - loss: 2332.7385 - reconstruction_loss: 2306.6006
# Epoch 965/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0601 - loss: 2329.5305 - reconstruction_loss: 2303.4702
# Epoch 966/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1002 - loss: 2328.2585 - reconstruction_loss: 2302.1582
# Epoch 967/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0668 - loss: 2332.3411 - reconstruction_loss: 2306.2744
# Epoch 968/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0234 - loss: 2332.6116 - reconstruction_loss: 2306.5879
# Epoch 969/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0407 - loss: 2329.2891 - reconstruction_loss: 2303.2485
# Epoch 970/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9814 - loss: 2326.2629 - reconstruction_loss: 2300.2815
# Epoch 971/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0351 - loss: 2326.7432 - reconstruction_loss: 2300.7083
# Epoch 972/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0038 - loss: 2329.0623 - reconstruction_loss: 2303.0588
# Epoch 973/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0434 - loss: 2327.8950 - reconstruction_loss: 2301.8518
# Epoch 974/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0129 - loss: 2330.4199 - reconstruction_loss: 2304.4070
# Epoch 975/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0699 - loss: 2330.0972 - reconstruction_loss: 2304.0271
# Epoch 976/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.1213 - loss: 2330.7124 - reconstruction_loss: 2304.5908
# Epoch 977/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0614 - loss: 2329.8413 - reconstruction_loss: 2303.7798
# Epoch 978/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0147 - loss: 2326.9524 - reconstruction_loss: 2300.9373
# Epoch 979/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9538 - loss: 2326.5789 - reconstruction_loss: 2300.6255
# Epoch 980/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1572 - loss: 2333.1331 - reconstruction_loss: 2306.9758
# Epoch 981/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0572 - loss: 2329.7429 - reconstruction_loss: 2303.6855
# Epoch 982/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0545 - loss: 2330.4585 - reconstruction_loss: 2304.4041
# Epoch 983/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0145 - loss: 2328.6292 - reconstruction_loss: 2302.6147
# Epoch 984/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9979 - loss: 2328.2441 - reconstruction_loss: 2302.2463
# Epoch 985/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0304 - loss: 2324.4382 - reconstruction_loss: 2298.4080
# Epoch 986/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0500 - loss: 2329.7439 - reconstruction_loss: 2303.6938
# Epoch 987/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0267 - loss: 2328.5935 - reconstruction_loss: 2302.5667
# Epoch 988/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0619 - loss: 2329.7654 - reconstruction_loss: 2303.7034
# Epoch 989/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0525 - loss: 2329.6165 - reconstruction_loss: 2303.5642
# Epoch 990/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9866 - loss: 2330.1321 - reconstruction_loss: 2304.1455
# Epoch 991/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - kl_loss: 26.0351 - loss: 2330.8506 - reconstruction_loss: 2304.8154
# Epoch 992/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0625 - loss: 2331.8687 - reconstruction_loss: 2305.8064
# Epoch 993/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.1203 - loss: 2322.4885 - reconstruction_loss: 2296.3682
# Epoch 994/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.9267 - loss: 2328.9233 - reconstruction_loss: 2302.9966
# Epoch 995/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 25.8726 - loss: 2331.5010 - reconstruction_loss: 2305.6284
# Epoch 996/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0838 - loss: 2330.1367 - reconstruction_loss: 2304.0527
# Epoch 997/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0055 - loss: 2333.0334 - reconstruction_loss: 2307.0278
# Epoch 998/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0072 - loss: 2327.2769 - reconstruction_loss: 2301.2695
# Epoch 999/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0257 - loss: 2328.6792 - reconstruction_loss: 2302.6536
# Epoch 1000/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - kl_loss: 26.0904 - loss: 2325.5510 - reconstruction_loss: 2299.4607

# %%
num_images = 5400
output_dir = str(fake_dir + "/" + generating_class + "/")
os.makedirs(output_dir, exist_ok=True)
filename = str(generating_class + "%d.png")
output_path = os.path.join(output_dir, filename)

keras.random.SeedGenerator(42)

for i in range(num_images):
  # Amostrando pontos no espaço latente
  z_sample = np.random.normal(0, 1, (1, best_latent_dim))  # Amostra aleatória do espaço latente
  generated_image = vae.decoder.predict(z_sample, verbose=0)[0]  # Decodifica o ponto amostrado

  # Normalizando a imagem para o intervalo [0, 255] antes de salvar
  generated_image = (generated_image * 255).astype(np.uint8)

  # Salvar a imagem em uma pasta
  plt.imsave(output_path % (i), generated_image)

# Métrica FID para avaliar a qualidade do modelo
fid_score = calculate_fid(real_dir, fake_dir, generating_class, num_samples=num_images)

print(f"FID = {fid_score}")
# Out:
# Processando classe 'VEHICLESCARRIER': 100%|███████████████████████████████████████████| 540/540 [04:10<00:00,  2.15it/s]
# FID = 51.792381286621094
