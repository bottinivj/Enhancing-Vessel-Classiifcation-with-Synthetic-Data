# %%
generating_class = 'CONTAINERSHIP'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-01-30 03:10:46.971539: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-30 03:10:46.991769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-01-30 03:10:47.745694: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.748457: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.748474: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-01-30 03:10:47.757968: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.757998: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.758008: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.858303: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.858329: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.858334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-01-30 03:10:47.858350: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-30 03:10:47.858371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738206670.957561   98007 service.cc:145] XLA service 0x7f8ed8002fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738206670.957607   98007 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-01-30 03:11:11.773829: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738206672.475482   98007 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-01-30 03:11:13.890760: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738206675.733918   98173 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738206675.868445   98193 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738206676.047393   98187 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738206676.096755   98173 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738206676.097388   98195 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738206676.112523   98184 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738206676.121209   98169 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738206676.397968   98178 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738206676.425693   98190 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738206676.590403   98181 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738206676.641501   98195 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738206676.735366   98179 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738206676.748609   98168 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738206676.836661   98176 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738206676.963638   98185 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738206676.974690   98187 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738206677.221853   98171 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738206677.261840   98193 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738206677.304320   98175 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738206677.512981   98172 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738206677.538178   98181 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738206678.020155   98191 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738206678.088705   98179 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738206678.090545   98189 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738206678.205432   98170 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738206678.230791   98180 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738206678.324294   98183 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738206678.353862   98171 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738206678.437732   98188 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738206678.520200   98182 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738206678.807322   98181 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738206678.867656   98185 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738206678.904990   98188 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738206705.820018   98007 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738206705.861969   98007 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 66s 67ms/step - loss: 0.2425
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0345
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0302
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0257
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0252
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0249
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0241
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0237
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0224
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0219
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0238
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0223
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0227
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0210
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0213
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0213
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0216
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0226
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0215
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0223
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0214
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0205
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0207
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0217
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0205
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0204
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0206
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0204
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0206
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0194
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0194
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0194
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0194
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0175
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0180
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0184
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0160
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0173
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0185
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0160
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0171
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0178
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0180
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0158
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0179
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0163
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0156
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0177
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0174
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0182
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0176
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0172
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0165
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0175
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0169
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0170
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0164
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0162
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0168
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0173
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0181
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0172
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0166
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0168
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0173
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0166
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0167
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0159
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0170
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0169
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0172
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0164
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0169
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0170
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0166
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0170
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0161
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0168
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0169
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0160
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0175
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0164
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0177
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0169
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0165
# Epoch 345/500
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0174
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import os
from IPython.display import clear_output

num_img = 5400 

output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    print("Faltam %d iterações" % (t))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# Faltam 0 iterações

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: CONTAINERSHIP0.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP0.png
# Processado: CONTAINERSHIP1.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1.png
# Processado: CONTAINERSHIP10.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP10.png
# Processado: CONTAINERSHIP100.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP100.png
# Processado: CONTAINERSHIP1000.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1000.png
# Processado: CONTAINERSHIP1001.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1001.png
# Processado: CONTAINERSHIP1002.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1002.png
# Processado: CONTAINERSHIP1003.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1003.png
# Processado: CONTAINERSHIP1004.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1004.png
# Processado: CONTAINERSHIP1005.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1005.png
# Processado: CONTAINERSHIP1006.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1006.png
# Processado: CONTAINERSHIP1007.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1007.png
# Processado: CONTAINERSHIP1008.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1008.png
# Processado: CONTAINERSHIP1009.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1009.png
# Processado: CONTAINERSHIP101.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP101.png
# Processado: CONTAINERSHIP1010.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1010.png
# Processado: CONTAINERSHIP1011.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1011.png
# Processado: CONTAINERSHIP1012.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1012.png
# Processado: CONTAINERSHIP1013.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1013.png
# Processado: CONTAINERSHIP1014.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1014.png
# Processado: CONTAINERSHIP1015.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1015.png
# Processado: CONTAINERSHIP1016.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1016.png
# Processado: CONTAINERSHIP1017.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1017.png
# Processado: CONTAINERSHIP1018.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1018.png
# Processado: CONTAINERSHIP1019.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1019.png
# Processado: CONTAINERSHIP102.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP102.png
# Processado: CONTAINERSHIP1020.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1020.png
# Processado: CONTAINERSHIP1021.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1021.png
# Processado: CONTAINERSHIP1022.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1022.png
# Processado: CONTAINERSHIP1023.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1023.png
# Processado: CONTAINERSHIP1024.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1024.png
# Processado: CONTAINERSHIP1025.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1025.png
# Processado: CONTAINERSHIP1026.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1026.png
# Processado: CONTAINERSHIP1027.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1027.png
# Processado: CONTAINERSHIP1028.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1028.png
# Processado: CONTAINERSHIP1029.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1029.png
# Processado: CONTAINERSHIP103.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP103.png
# Processado: CONTAINERSHIP1030.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1030.png
# Processado: CONTAINERSHIP1031.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1031.png
# Processado: CONTAINERSHIP1032.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1032.png
# Processado: CONTAINERSHIP1033.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1033.png
# Processado: CONTAINERSHIP1034.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1034.png
# Processado: CONTAINERSHIP1035.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1035.png
# Processado: CONTAINERSHIP1036.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1036.png
# Processado: CONTAINERSHIP1037.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1037.png
# Processado: CONTAINERSHIP1038.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1038.png
# Processado: CONTAINERSHIP1039.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1039.png
# Processado: CONTAINERSHIP104.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP104.png
# Processado: CONTAINERSHIP1040.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1040.png
# Processado: CONTAINERSHIP1041.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1041.png
# Processado: CONTAINERSHIP1042.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1042.png
# Processado: CONTAINERSHIP1043.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1043.png
# Processado: CONTAINERSHIP1044.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1044.png
# Processado: CONTAINERSHIP1045.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1045.png
# Processado: CONTAINERSHIP1046.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1046.png
# Processado: CONTAINERSHIP1047.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1047.png
# Processado: CONTAINERSHIP1048.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1048.png
# Processado: CONTAINERSHIP1049.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1049.png
# Processado: CONTAINERSHIP105.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP105.png
# Processado: CONTAINERSHIP1050.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1050.png
# Processado: CONTAINERSHIP1051.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1051.png
# Processado: CONTAINERSHIP1052.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1052.png
# Processado: CONTAINERSHIP1053.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1053.png
# Processado: CONTAINERSHIP1054.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1054.png
# Processado: CONTAINERSHIP1055.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1055.png
# Processado: CONTAINERSHIP1056.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1056.png
# Processado: CONTAINERSHIP1057.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1057.png
# Processado: CONTAINERSHIP1058.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1058.png
# Processado: CONTAINERSHIP1059.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1059.png
# Processado: CONTAINERSHIP106.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP106.png
# Processado: CONTAINERSHIP1060.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1060.png
# Processado: CONTAINERSHIP1061.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1061.png
# Processado: CONTAINERSHIP1062.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1062.png
# Processado: CONTAINERSHIP1063.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1063.png
# Processado: CONTAINERSHIP1064.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1064.png
# Processado: CONTAINERSHIP1065.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1065.png
# Processado: CONTAINERSHIP1066.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1066.png
# Processado: CONTAINERSHIP1067.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1067.png
# Processado: CONTAINERSHIP1068.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1068.png
# Processado: CONTAINERSHIP1069.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1069.png
# Processado: CONTAINERSHIP107.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP107.png
# Processado: CONTAINERSHIP1070.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1070.png
# Processado: CONTAINERSHIP1071.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1071.png
# Processado: CONTAINERSHIP1072.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1072.png
# Processado: CONTAINERSHIP1073.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1073.png
# Processado: CONTAINERSHIP1074.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1074.png
# Processado: CONTAINERSHIP1075.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1075.png
# Processado: CONTAINERSHIP1076.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1076.png
# Processado: CONTAINERSHIP1077.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1077.png
# Processado: CONTAINERSHIP1078.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1078.png
# Processado: CONTAINERSHIP1079.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1079.png
# Processado: CONTAINERSHIP108.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP108.png
# Processado: CONTAINERSHIP1080.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1080.png
# Processado: CONTAINERSHIP1081.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1081.png
# Processado: CONTAINERSHIP1082.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1082.png
# Processado: CONTAINERSHIP1083.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1083.png
# Processado: CONTAINERSHIP1084.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1084.png
# Processado: CONTAINERSHIP1085.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1085.png
# Processado: CONTAINERSHIP1086.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1086.png
# Processado: CONTAINERSHIP1087.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1087.png
# Processado: CONTAINERSHIP1088.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1088.png
# Processado: CONTAINERSHIP1089.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1089.png
# Processado: CONTAINERSHIP109.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP109.png
# Processado: CONTAINERSHIP1090.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1090.png
# Processado: CONTAINERSHIP1091.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1091.png
# Processado: CONTAINERSHIP1092.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1092.png
# Processado: CONTAINERSHIP1093.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1093.png
# Processado: CONTAINERSHIP1094.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1094.png
# Processado: CONTAINERSHIP1095.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1095.png
# Processado: CONTAINERSHIP1096.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1096.png
# Processado: CONTAINERSHIP1097.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1097.png
# Processado: CONTAINERSHIP1098.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1098.png
# Processado: CONTAINERSHIP1099.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1099.png
# Processado: CONTAINERSHIP11.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP11.png
# Processado: CONTAINERSHIP110.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP110.png
# Processado: CONTAINERSHIP1100.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1100.png
# Processado: CONTAINERSHIP1101.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1101.png
# Processado: CONTAINERSHIP1102.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1102.png
# Processado: CONTAINERSHIP1103.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1103.png
# Processado: CONTAINERSHIP1104.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1104.png
# Processado: CONTAINERSHIP1105.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1105.png
# Processado: CONTAINERSHIP1106.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1106.png
# Processado: CONTAINERSHIP1107.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1107.png
# Processado: CONTAINERSHIP1108.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1108.png
# Processado: CONTAINERSHIP1109.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1109.png
# Processado: CONTAINERSHIP111.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP111.png
# Processado: CONTAINERSHIP1110.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1110.png
# Processado: CONTAINERSHIP1111.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1111.png
# Processado: CONTAINERSHIP1112.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1112.png
# Processado: CONTAINERSHIP1113.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1113.png
# Processado: CONTAINERSHIP1114.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1114.png
# Processado: CONTAINERSHIP1115.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1115.png
# Processado: CONTAINERSHIP1116.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1116.png
# Processado: CONTAINERSHIP1117.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1117.png
# Processado: CONTAINERSHIP1118.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1118.png
# Processado: CONTAINERSHIP1119.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1119.png
# Processado: CONTAINERSHIP112.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP112.png
# Processado: CONTAINERSHIP1120.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1120.png
# Processado: CONTAINERSHIP1121.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1121.png
# Processado: CONTAINERSHIP1122.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1122.png
# Processado: CONTAINERSHIP1123.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1123.png
# Processado: CONTAINERSHIP1124.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1124.png
# Processado: CONTAINERSHIP1125.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1125.png
# Processado: CONTAINERSHIP1126.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1126.png
# Processado: CONTAINERSHIP1127.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1127.png
# Processado: CONTAINERSHIP1128.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1128.png
# Processado: CONTAINERSHIP1129.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1129.png
# Processado: CONTAINERSHIP113.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP113.png
# Processado: CONTAINERSHIP1130.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1130.png
# Processado: CONTAINERSHIP1131.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1131.png
# Processado: CONTAINERSHIP1132.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1132.png
# Processado: CONTAINERSHIP1133.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1133.png
# Processado: CONTAINERSHIP1134.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1134.png
# Processado: CONTAINERSHIP1135.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1135.png
# Processado: CONTAINERSHIP1136.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1136.png
# Processado: CONTAINERSHIP1137.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1137.png
# Processado: CONTAINERSHIP1138.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1138.png
# Processado: CONTAINERSHIP1139.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1139.png
# Processado: CONTAINERSHIP114.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP114.png
# Processado: CONTAINERSHIP1140.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1140.png
# Processado: CONTAINERSHIP1141.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1141.png
# Processado: CONTAINERSHIP1142.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1142.png
# Processado: CONTAINERSHIP1143.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1143.png
# Processado: CONTAINERSHIP1144.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1144.png
# Processado: CONTAINERSHIP1145.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1145.png
# Processado: CONTAINERSHIP1146.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1146.png
# Processado: CONTAINERSHIP1147.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1147.png
# Processado: CONTAINERSHIP1148.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1148.png
# Processado: CONTAINERSHIP1149.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1149.png
# Processado: CONTAINERSHIP115.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP115.png
# Processado: CONTAINERSHIP1150.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1150.png
# Processado: CONTAINERSHIP1151.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1151.png
# Processado: CONTAINERSHIP1152.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1152.png
# Processado: CONTAINERSHIP1153.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1153.png
# Processado: CONTAINERSHIP1154.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1154.png
# Processado: CONTAINERSHIP1155.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1155.png
# Processado: CONTAINERSHIP1156.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1156.png
# Processado: CONTAINERSHIP1157.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1157.png
# Processado: CONTAINERSHIP1158.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1158.png
# Processado: CONTAINERSHIP1159.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1159.png
# Processado: CONTAINERSHIP116.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP116.png
# Processado: CONTAINERSHIP1160.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1160.png
# Processado: CONTAINERSHIP1161.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1161.png
# Processado: CONTAINERSHIP1162.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1162.png
# Processado: CONTAINERSHIP1163.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1163.png
# Processado: CONTAINERSHIP1164.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1164.png
# Processado: CONTAINERSHIP1165.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1165.png
# Processado: CONTAINERSHIP1166.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1166.png
# Processado: CONTAINERSHIP1167.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1167.png
# Processado: CONTAINERSHIP1168.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1168.png
# Processado: CONTAINERSHIP1169.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1169.png
# Processado: CONTAINERSHIP117.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP117.png
# Processado: CONTAINERSHIP1170.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1170.png
# Processado: CONTAINERSHIP1171.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1171.png
# Processado: CONTAINERSHIP1172.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1172.png
# Processado: CONTAINERSHIP1173.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1173.png
# Processado: CONTAINERSHIP1174.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1174.png
# Processado: CONTAINERSHIP1175.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1175.png
# Processado: CONTAINERSHIP1176.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1176.png
# Processado: CONTAINERSHIP1177.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1177.png
# Processado: CONTAINERSHIP1178.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1178.png
# Processado: CONTAINERSHIP1179.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1179.png
# Processado: CONTAINERSHIP118.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP118.png
# Processado: CONTAINERSHIP1180.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1180.png
# Processado: CONTAINERSHIP1181.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1181.png
# Processado: CONTAINERSHIP1182.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1182.png
# Processado: CONTAINERSHIP1183.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1183.png
# Processado: CONTAINERSHIP1184.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1184.png
# Processado: CONTAINERSHIP1185.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1185.png
# Processado: CONTAINERSHIP1186.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1186.png
# Processado: CONTAINERSHIP1187.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1187.png
# Processado: CONTAINERSHIP1188.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1188.png
# Processado: CONTAINERSHIP1189.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1189.png
# Processado: CONTAINERSHIP119.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP119.png
# Processado: CONTAINERSHIP1190.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1190.png
# Processado: CONTAINERSHIP1191.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1191.png
# Processado: CONTAINERSHIP1192.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1192.png
# Processado: CONTAINERSHIP1193.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1193.png
# Processado: CONTAINERSHIP1194.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1194.png
# Processado: CONTAINERSHIP1195.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1195.png
# Processado: CONTAINERSHIP1196.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1196.png
# Processado: CONTAINERSHIP1197.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1197.png
# Processado: CONTAINERSHIP1198.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1198.png
# Processado: CONTAINERSHIP1199.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1199.png
# Processado: CONTAINERSHIP12.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP12.png
# Processado: CONTAINERSHIP120.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP120.png
# Processado: CONTAINERSHIP1200.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1200.png
# Processado: CONTAINERSHIP1201.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1201.png
# Processado: CONTAINERSHIP1202.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1202.png
# Processado: CONTAINERSHIP1203.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1203.png
# Processado: CONTAINERSHIP1204.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1204.png
# Processado: CONTAINERSHIP1205.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1205.png
# Processado: CONTAINERSHIP1206.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1206.png
# Processado: CONTAINERSHIP1207.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1207.png
# Processado: CONTAINERSHIP1208.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1208.png
# Processado: CONTAINERSHIP1209.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1209.png
# Processado: CONTAINERSHIP121.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP121.png
# Processado: CONTAINERSHIP1210.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1210.png
# Processado: CONTAINERSHIP1211.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1211.png
# Processado: CONTAINERSHIP1212.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1212.png
# Processado: CONTAINERSHIP1213.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1213.png
# Processado: CONTAINERSHIP1214.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1214.png
# Processado: CONTAINERSHIP1215.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1215.png
# Processado: CONTAINERSHIP1216.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1216.png
# Processado: CONTAINERSHIP1217.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1217.png
# Processado: CONTAINERSHIP1218.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1218.png
# Processado: CONTAINERSHIP1219.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1219.png
# Processado: CONTAINERSHIP122.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP122.png
# Processado: CONTAINERSHIP1220.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1220.png
# Processado: CONTAINERSHIP1221.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1221.png
# Processado: CONTAINERSHIP1222.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1222.png
# Processado: CONTAINERSHIP1223.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1223.png
# Processado: CONTAINERSHIP1224.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1224.png
# Processado: CONTAINERSHIP1225.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1225.png
# Processado: CONTAINERSHIP1226.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1226.png
# Processado: CONTAINERSHIP1227.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1227.png
# Processado: CONTAINERSHIP1228.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1228.png
# Processado: CONTAINERSHIP1229.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1229.png
# Processado: CONTAINERSHIP123.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP123.png
# Processado: CONTAINERSHIP1230.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1230.png
# Processado: CONTAINERSHIP1231.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1231.png
# Processado: CONTAINERSHIP1232.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1232.png
# Processado: CONTAINERSHIP1233.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1233.png
# Processado: CONTAINERSHIP1234.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1234.png
# Processado: CONTAINERSHIP1235.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1235.png
# Processado: CONTAINERSHIP1236.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1236.png
# Processado: CONTAINERSHIP1237.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1237.png
# Processado: CONTAINERSHIP1238.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1238.png
# Processado: CONTAINERSHIP1239.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1239.png
# Processado: CONTAINERSHIP124.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP124.png
# Processado: CONTAINERSHIP1240.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1240.png
# Processado: CONTAINERSHIP1241.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1241.png
# Processado: CONTAINERSHIP1242.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1242.png
# Processado: CONTAINERSHIP1243.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1243.png
# Processado: CONTAINERSHIP1244.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1244.png
# Processado: CONTAINERSHIP1245.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1245.png
# Processado: CONTAINERSHIP1246.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1246.png
# Processado: CONTAINERSHIP1247.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1247.png
# Processado: CONTAINERSHIP1248.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1248.png
# Processado: CONTAINERSHIP1249.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1249.png
# Processado: CONTAINERSHIP125.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP125.png
# Processado: CONTAINERSHIP1250.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1250.png
# Processado: CONTAINERSHIP1251.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1251.png
# Processado: CONTAINERSHIP1252.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1252.png
# Processado: CONTAINERSHIP1253.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1253.png
# Processado: CONTAINERSHIP1254.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1254.png
# Processado: CONTAINERSHIP1255.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1255.png
# Processado: CONTAINERSHIP1256.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1256.png
# Processado: CONTAINERSHIP1257.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1257.png
# Processado: CONTAINERSHIP1258.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1258.png
# Processado: CONTAINERSHIP1259.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1259.png
# Processado: CONTAINERSHIP126.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP126.png
# Processado: CONTAINERSHIP1260.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1260.png
# Processado: CONTAINERSHIP1261.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1261.png
# Processado: CONTAINERSHIP1262.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1262.png
# Processado: CONTAINERSHIP1263.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1263.png
# Processado: CONTAINERSHIP1264.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1264.png
# Processado: CONTAINERSHIP1265.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1265.png
# Processado: CONTAINERSHIP1266.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1266.png
# Processado: CONTAINERSHIP1267.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1267.png
# Processado: CONTAINERSHIP1268.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1268.png
# Processado: CONTAINERSHIP1269.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1269.png
# Processado: CONTAINERSHIP127.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP127.png
# Processado: CONTAINERSHIP1270.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1270.png
# Processado: CONTAINERSHIP1271.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1271.png
# Processado: CONTAINERSHIP1272.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1272.png
# Processado: CONTAINERSHIP1273.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1273.png
# Processado: CONTAINERSHIP1274.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1274.png
# Processado: CONTAINERSHIP1275.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1275.png
# Processado: CONTAINERSHIP1276.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1276.png
# Processado: CONTAINERSHIP1277.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1277.png
# Processado: CONTAINERSHIP1278.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1278.png
# Processado: CONTAINERSHIP1279.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1279.png
# Processado: CONTAINERSHIP128.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP128.png
# Processado: CONTAINERSHIP1280.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1280.png
# Processado: CONTAINERSHIP1281.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1281.png
# Processado: CONTAINERSHIP1282.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1282.png
# Processado: CONTAINERSHIP1283.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1283.png
# Processado: CONTAINERSHIP1284.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1284.png
# Processado: CONTAINERSHIP1285.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1285.png
# Processado: CONTAINERSHIP1286.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1286.png
# Processado: CONTAINERSHIP1287.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1287.png
# Processado: CONTAINERSHIP1288.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1288.png
# Processado: CONTAINERSHIP1289.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1289.png
# Processado: CONTAINERSHIP129.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP129.png
# Processado: CONTAINERSHIP1290.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1290.png
# Processado: CONTAINERSHIP1291.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1291.png
# Processado: CONTAINERSHIP1292.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1292.png
# Processado: CONTAINERSHIP1293.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1293.png
# Processado: CONTAINERSHIP1294.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1294.png
# Processado: CONTAINERSHIP1295.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1295.png
# Processado: CONTAINERSHIP1296.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1296.png
# Processado: CONTAINERSHIP1297.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1297.png
# Processado: CONTAINERSHIP1298.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1298.png
# Processado: CONTAINERSHIP1299.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1299.png
# Processado: CONTAINERSHIP13.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP13.png
# Processado: CONTAINERSHIP130.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP130.png
# Processado: CONTAINERSHIP1300.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1300.png
# Processado: CONTAINERSHIP1301.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1301.png
# Processado: CONTAINERSHIP1302.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1302.png
# Processado: CONTAINERSHIP1303.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1303.png
# Processado: CONTAINERSHIP1304.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1304.png
# Processado: CONTAINERSHIP1305.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1305.png
# Processado: CONTAINERSHIP1306.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1306.png
# Processado: CONTAINERSHIP1307.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1307.png
# Processado: CONTAINERSHIP1308.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1308.png
# Processado: CONTAINERSHIP1309.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1309.png
# Processado: CONTAINERSHIP131.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP131.png
# Processado: CONTAINERSHIP1310.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1310.png
# Processado: CONTAINERSHIP1311.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1311.png
# Processado: CONTAINERSHIP1312.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1312.png
# Processado: CONTAINERSHIP1313.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1313.png
# Processado: CONTAINERSHIP1314.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1314.png
# Processado: CONTAINERSHIP1315.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1315.png
# Processado: CONTAINERSHIP1316.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1316.png
# Processado: CONTAINERSHIP1317.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1317.png
# Processado: CONTAINERSHIP1318.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1318.png
# Processado: CONTAINERSHIP1319.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1319.png
# Processado: CONTAINERSHIP132.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP132.png
# Processado: CONTAINERSHIP1320.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1320.png
# Processado: CONTAINERSHIP1321.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1321.png
# Processado: CONTAINERSHIP1322.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1322.png
# Processado: CONTAINERSHIP1323.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1323.png
# Processado: CONTAINERSHIP1324.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1324.png
# Processado: CONTAINERSHIP1325.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1325.png
# Processado: CONTAINERSHIP1326.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1326.png
# Processado: CONTAINERSHIP1327.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1327.png
# Processado: CONTAINERSHIP1328.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1328.png
# Processado: CONTAINERSHIP1329.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1329.png
# Processado: CONTAINERSHIP133.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP133.png
# Processado: CONTAINERSHIP1330.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1330.png
# Processado: CONTAINERSHIP1331.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1331.png
# Processado: CONTAINERSHIP1332.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1332.png
# Processado: CONTAINERSHIP1333.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1333.png
# Processado: CONTAINERSHIP1334.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1334.png
# Processado: CONTAINERSHIP1335.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1335.png
# Processado: CONTAINERSHIP1336.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1336.png
# Processado: CONTAINERSHIP1337.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1337.png
# Processado: CONTAINERSHIP1338.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1338.png
# Processado: CONTAINERSHIP1339.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1339.png
# Processado: CONTAINERSHIP134.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP134.png
# Processado: CONTAINERSHIP1340.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1340.png
# Processado: CONTAINERSHIP1341.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1341.png
# Processado: CONTAINERSHIP1342.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1342.png
# Processado: CONTAINERSHIP1343.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1343.png
# Processado: CONTAINERSHIP1344.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1344.png
# Processado: CONTAINERSHIP1345.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1345.png
# Processado: CONTAINERSHIP1346.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1346.png
# Processado: CONTAINERSHIP1347.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1347.png
# Processado: CONTAINERSHIP1348.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1348.png
# Processado: CONTAINERSHIP1349.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1349.png
# Processado: CONTAINERSHIP135.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP135.png
# Processado: CONTAINERSHIP1350.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1350.png
# Processado: CONTAINERSHIP1351.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1351.png
# Processado: CONTAINERSHIP1352.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1352.png
# Processado: CONTAINERSHIP1353.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1353.png
# Processado: CONTAINERSHIP1354.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1354.png
# Processado: CONTAINERSHIP1355.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1355.png
# Processado: CONTAINERSHIP1356.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1356.png
# Processado: CONTAINERSHIP1357.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1357.png
# Processado: CONTAINERSHIP1358.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1358.png
# Processado: CONTAINERSHIP1359.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1359.png
# Processado: CONTAINERSHIP136.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP136.png
# Processado: CONTAINERSHIP1360.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1360.png
# Processado: CONTAINERSHIP1361.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1361.png
# Processado: CONTAINERSHIP1362.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1362.png
# Processado: CONTAINERSHIP1363.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1363.png
# Processado: CONTAINERSHIP1364.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1364.png
# Processado: CONTAINERSHIP1365.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1365.png
# Processado: CONTAINERSHIP1366.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1366.png
# Processado: CONTAINERSHIP1367.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1367.png
# Processado: CONTAINERSHIP1368.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1368.png
# Processado: CONTAINERSHIP1369.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1369.png
# Processado: CONTAINERSHIP137.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP137.png
# Processado: CONTAINERSHIP1370.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1370.png
# Processado: CONTAINERSHIP1371.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1371.png
# Processado: CONTAINERSHIP1372.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1372.png
# Processado: CONTAINERSHIP1373.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1373.png
# Processado: CONTAINERSHIP1374.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1374.png
# Processado: CONTAINERSHIP1375.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1375.png
# Processado: CONTAINERSHIP1376.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1376.png
# Processado: CONTAINERSHIP1377.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1377.png
# Processado: CONTAINERSHIP1378.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1378.png
# Processado: CONTAINERSHIP1379.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1379.png
# Processado: CONTAINERSHIP138.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP138.png
# Processado: CONTAINERSHIP1380.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1380.png
# Processado: CONTAINERSHIP1381.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1381.png
# Processado: CONTAINERSHIP1382.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1382.png
# Processado: CONTAINERSHIP1383.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1383.png
# Processado: CONTAINERSHIP1384.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1384.png
# Processado: CONTAINERSHIP1385.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1385.png
# Processado: CONTAINERSHIP1386.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1386.png
# Processado: CONTAINERSHIP1387.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1387.png
# Processado: CONTAINERSHIP1388.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1388.png
# Processado: CONTAINERSHIP1389.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1389.png
# Processado: CONTAINERSHIP139.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP139.png
# Processado: CONTAINERSHIP1390.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1390.png
# Processado: CONTAINERSHIP1391.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1391.png
# Processado: CONTAINERSHIP1392.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1392.png
# Processado: CONTAINERSHIP1393.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1393.png
# Processado: CONTAINERSHIP1394.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1394.png
# Processado: CONTAINERSHIP1395.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1395.png
# Processado: CONTAINERSHIP1396.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1396.png
# Processado: CONTAINERSHIP1397.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1397.png
# Processado: CONTAINERSHIP1398.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1398.png
# Processado: CONTAINERSHIP1399.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1399.png
# Processado: CONTAINERSHIP14.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP14.png
# Processado: CONTAINERSHIP140.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP140.png
# Processado: CONTAINERSHIP1400.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1400.png
# Processado: CONTAINERSHIP1401.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1401.png
# Processado: CONTAINERSHIP1402.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1402.png
# Processado: CONTAINERSHIP1403.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1403.png
# Processado: CONTAINERSHIP1404.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1404.png
# Processado: CONTAINERSHIP1405.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1405.png
# Processado: CONTAINERSHIP1406.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1406.png
# Processado: CONTAINERSHIP1407.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1407.png
# Processado: CONTAINERSHIP1408.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1408.png
# Processado: CONTAINERSHIP1409.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1409.png
# Processado: CONTAINERSHIP141.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP141.png
# Processado: CONTAINERSHIP1410.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1410.png
# Processado: CONTAINERSHIP1411.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1411.png
# Processado: CONTAINERSHIP1412.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1412.png
# Processado: CONTAINERSHIP1413.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1413.png
# Processado: CONTAINERSHIP1414.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1414.png
# Processado: CONTAINERSHIP1415.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1415.png
# Processado: CONTAINERSHIP1416.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1416.png
# Processado: CONTAINERSHIP1417.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1417.png
# Processado: CONTAINERSHIP1418.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1418.png
# Processado: CONTAINERSHIP1419.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1419.png
# Processado: CONTAINERSHIP142.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP142.png
# Processado: CONTAINERSHIP1420.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1420.png
# Processado: CONTAINERSHIP1421.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1421.png
# Processado: CONTAINERSHIP1422.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1422.png
# Processado: CONTAINERSHIP1423.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1423.png
# Processado: CONTAINERSHIP1424.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1424.png
# Processado: CONTAINERSHIP1425.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1425.png
# Processado: CONTAINERSHIP1426.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1426.png
# Processado: CONTAINERSHIP1427.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1427.png
# Processado: CONTAINERSHIP1428.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1428.png
# Processado: CONTAINERSHIP1429.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1429.png
# Processado: CONTAINERSHIP143.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP143.png
# Processado: CONTAINERSHIP1430.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1430.png
# Processado: CONTAINERSHIP1431.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1431.png
# Processado: CONTAINERSHIP1432.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1432.png
# Processado: CONTAINERSHIP1433.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1433.png
# Processado: CONTAINERSHIP1434.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1434.png
# Processado: CONTAINERSHIP1435.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1435.png
# Processado: CONTAINERSHIP1436.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1436.png
# Processado: CONTAINERSHIP1437.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1437.png
# Processado: CONTAINERSHIP1438.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1438.png
# Processado: CONTAINERSHIP1439.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1439.png
# Processado: CONTAINERSHIP144.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP144.png
# Processado: CONTAINERSHIP1440.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1440.png
# Processado: CONTAINERSHIP1441.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1441.png
# Processado: CONTAINERSHIP1442.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1442.png
# Processado: CONTAINERSHIP1443.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1443.png
# Processado: CONTAINERSHIP1444.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1444.png
# Processado: CONTAINERSHIP1445.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1445.png
# Processado: CONTAINERSHIP1446.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1446.png
# Processado: CONTAINERSHIP1447.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1447.png
# Processado: CONTAINERSHIP1448.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1448.png
# Processado: CONTAINERSHIP1449.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1449.png
# Processado: CONTAINERSHIP145.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP145.png
# Processado: CONTAINERSHIP1450.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1450.png
# Processado: CONTAINERSHIP1451.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1451.png
# Processado: CONTAINERSHIP1452.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1452.png
# Processado: CONTAINERSHIP1453.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1453.png
# Processado: CONTAINERSHIP1454.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1454.png
# Processado: CONTAINERSHIP1455.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1455.png
# Processado: CONTAINERSHIP1456.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1456.png
# Processado: CONTAINERSHIP1457.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1457.png
# Processado: CONTAINERSHIP1458.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1458.png
# Processado: CONTAINERSHIP1459.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1459.png
# Processado: CONTAINERSHIP146.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP146.png
# Processado: CONTAINERSHIP1460.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1460.png
# Processado: CONTAINERSHIP1461.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1461.png
# Processado: CONTAINERSHIP1462.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1462.png
# Processado: CONTAINERSHIP1463.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1463.png
# Processado: CONTAINERSHIP1464.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1464.png
# Processado: CONTAINERSHIP1465.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1465.png
# Processado: CONTAINERSHIP1466.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1466.png
# Processado: CONTAINERSHIP1467.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1467.png
# Processado: CONTAINERSHIP1468.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1468.png
# Processado: CONTAINERSHIP1469.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1469.png
# Processado: CONTAINERSHIP147.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP147.png
# Processado: CONTAINERSHIP1470.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1470.png
# Processado: CONTAINERSHIP1471.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1471.png
# Processado: CONTAINERSHIP1472.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1472.png
# Processado: CONTAINERSHIP1473.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1473.png
# Processado: CONTAINERSHIP1474.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1474.png
# Processado: CONTAINERSHIP1475.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1475.png
# Processado: CONTAINERSHIP1476.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1476.png
# Processado: CONTAINERSHIP1477.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1477.png
# Processado: CONTAINERSHIP1478.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1478.png
# Processado: CONTAINERSHIP1479.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1479.png
# Processado: CONTAINERSHIP148.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP148.png
# Processado: CONTAINERSHIP1480.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1480.png
# Processado: CONTAINERSHIP1481.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1481.png
# Processado: CONTAINERSHIP1482.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1482.png
# Processado: CONTAINERSHIP1483.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1483.png
# Processado: CONTAINERSHIP1484.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1484.png
# Processado: CONTAINERSHIP1485.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1485.png
# Processado: CONTAINERSHIP1486.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1486.png
# Processado: CONTAINERSHIP1487.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1487.png
# Processado: CONTAINERSHIP1488.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1488.png
# Processado: CONTAINERSHIP1489.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1489.png
# Processado: CONTAINERSHIP149.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP149.png
# Processado: CONTAINERSHIP1490.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1490.png
# Processado: CONTAINERSHIP1491.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1491.png
# Processado: CONTAINERSHIP1492.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1492.png
# Processado: CONTAINERSHIP1493.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1493.png
# Processado: CONTAINERSHIP1494.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1494.png
# Processado: CONTAINERSHIP1495.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1495.png
# Processado: CONTAINERSHIP1496.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1496.png
# Processado: CONTAINERSHIP1497.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1497.png
# Processado: CONTAINERSHIP1498.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1498.png
# Processado: CONTAINERSHIP1499.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1499.png
# Processado: CONTAINERSHIP15.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP15.png
# Processado: CONTAINERSHIP150.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP150.png
# Processado: CONTAINERSHIP1500.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1500.png
# Processado: CONTAINERSHIP1501.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1501.png
# Processado: CONTAINERSHIP1502.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1502.png
# Processado: CONTAINERSHIP1503.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1503.png
# Processado: CONTAINERSHIP1504.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1504.png
# Processado: CONTAINERSHIP1505.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1505.png
# Processado: CONTAINERSHIP1506.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1506.png
# Processado: CONTAINERSHIP1507.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1507.png
# Processado: CONTAINERSHIP1508.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1508.png
# Processado: CONTAINERSHIP1509.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1509.png
# Processado: CONTAINERSHIP151.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP151.png
# Processado: CONTAINERSHIP1510.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1510.png
# Processado: CONTAINERSHIP1511.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1511.png
# Processado: CONTAINERSHIP1512.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP1512.png
# ...
# Processado: CONTAINERSHIP823.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP823.png
# Processado: CONTAINERSHIP824.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP824.png
# Processado: CONTAINERSHIP825.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP825.png
# Processado: CONTAINERSHIP826.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP826.png
# Processado: CONTAINERSHIP827.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP827.png
# Processado: CONTAINERSHIP828.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP828.png
# Processado: CONTAINERSHIP829.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP829.png
# Processado: CONTAINERSHIP83.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP83.png
# Processado: CONTAINERSHIP830.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP830.png
# Processado: CONTAINERSHIP831.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP831.png
# Processado: CONTAINERSHIP832.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP832.png
# Processado: CONTAINERSHIP833.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP833.png
# Processado: CONTAINERSHIP834.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP834.png
# Processado: CONTAINERSHIP835.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP835.png
# Processado: CONTAINERSHIP836.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP836.png
# Processado: CONTAINERSHIP837.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP837.png
# Processado: CONTAINERSHIP838.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP838.png
# Processado: CONTAINERSHIP839.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP839.png
# Processado: CONTAINERSHIP84.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP84.png
# Processado: CONTAINERSHIP840.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP840.png
# Processado: CONTAINERSHIP841.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP841.png
# Processado: CONTAINERSHIP842.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP842.png
# Processado: CONTAINERSHIP843.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP843.png
# Processado: CONTAINERSHIP844.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP844.png
# Processado: CONTAINERSHIP845.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP845.png
# Processado: CONTAINERSHIP846.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP846.png
# Processado: CONTAINERSHIP847.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP847.png
# Processado: CONTAINERSHIP848.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP848.png
# Processado: CONTAINERSHIP849.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP849.png
# Processado: CONTAINERSHIP85.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP85.png
# Processado: CONTAINERSHIP850.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP850.png
# Processado: CONTAINERSHIP851.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP851.png
# Processado: CONTAINERSHIP852.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP852.png
# Processado: CONTAINERSHIP853.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP853.png
# Processado: CONTAINERSHIP854.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP854.png
# Processado: CONTAINERSHIP855.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP855.png
# Processado: CONTAINERSHIP856.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP856.png
# Processado: CONTAINERSHIP857.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP857.png
# Processado: CONTAINERSHIP858.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP858.png
# Processado: CONTAINERSHIP859.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP859.png
# Processado: CONTAINERSHIP86.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP86.png
# Processado: CONTAINERSHIP860.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP860.png
# Processado: CONTAINERSHIP861.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP861.png
# Processado: CONTAINERSHIP862.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP862.png
# Processado: CONTAINERSHIP863.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP863.png
# Processado: CONTAINERSHIP864.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP864.png
# Processado: CONTAINERSHIP865.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP865.png
# Processado: CONTAINERSHIP866.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP866.png
# Processado: CONTAINERSHIP867.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP867.png
# Processado: CONTAINERSHIP868.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP868.png
# Processado: CONTAINERSHIP869.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP869.png
# Processado: CONTAINERSHIP87.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP87.png
# Processado: CONTAINERSHIP870.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP870.png
# Processado: CONTAINERSHIP871.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP871.png
# Processado: CONTAINERSHIP872.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP872.png
# Processado: CONTAINERSHIP873.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP873.png
# Processado: CONTAINERSHIP874.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP874.png
# Processado: CONTAINERSHIP875.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP875.png
# Processado: CONTAINERSHIP876.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP876.png
# Processado: CONTAINERSHIP877.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP877.png
# Processado: CONTAINERSHIP878.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP878.png
# Processado: CONTAINERSHIP879.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP879.png
# Processado: CONTAINERSHIP88.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP88.png
# Processado: CONTAINERSHIP880.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP880.png
# Processado: CONTAINERSHIP881.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP881.png
# Processado: CONTAINERSHIP882.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP882.png
# Processado: CONTAINERSHIP883.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP883.png
# Processado: CONTAINERSHIP884.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP884.png
# Processado: CONTAINERSHIP885.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP885.png
# Processado: CONTAINERSHIP886.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP886.png
# Processado: CONTAINERSHIP887.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP887.png
# Processado: CONTAINERSHIP888.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP888.png
# Processado: CONTAINERSHIP889.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP889.png
# Processado: CONTAINERSHIP89.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP89.png
# Processado: CONTAINERSHIP890.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP890.png
# Processado: CONTAINERSHIP891.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP891.png
# Processado: CONTAINERSHIP892.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP892.png
# Processado: CONTAINERSHIP893.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP893.png
# Processado: CONTAINERSHIP894.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP894.png
# Processado: CONTAINERSHIP895.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP895.png
# Processado: CONTAINERSHIP896.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP896.png
# Processado: CONTAINERSHIP897.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP897.png
# Processado: CONTAINERSHIP898.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP898.png
# Processado: CONTAINERSHIP899.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP899.png
# Processado: CONTAINERSHIP9.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP9.png
# Processado: CONTAINERSHIP90.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP90.png
# Processado: CONTAINERSHIP900.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP900.png
# Processado: CONTAINERSHIP901.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP901.png
# Processado: CONTAINERSHIP902.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP902.png
# Processado: CONTAINERSHIP903.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP903.png
# Processado: CONTAINERSHIP904.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP904.png
# Processado: CONTAINERSHIP905.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP905.png
# Processado: CONTAINERSHIP906.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP906.png
# Processado: CONTAINERSHIP907.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP907.png
# Processado: CONTAINERSHIP908.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP908.png
# Processado: CONTAINERSHIP909.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP909.png
# Processado: CONTAINERSHIP91.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP91.png
# Processado: CONTAINERSHIP910.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP910.png
# Processado: CONTAINERSHIP911.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP911.png
# Processado: CONTAINERSHIP912.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP912.png
# Processado: CONTAINERSHIP913.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP913.png
# Processado: CONTAINERSHIP914.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP914.png
# Processado: CONTAINERSHIP915.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP915.png
# Processado: CONTAINERSHIP916.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP916.png
# Processado: CONTAINERSHIP917.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP917.png
# Processado: CONTAINERSHIP918.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP918.png
# Processado: CONTAINERSHIP919.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP919.png
# Processado: CONTAINERSHIP92.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP92.png
# Processado: CONTAINERSHIP920.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP920.png
# Processado: CONTAINERSHIP921.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP921.png
# Processado: CONTAINERSHIP922.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP922.png
# Processado: CONTAINERSHIP923.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP923.png
# Processado: CONTAINERSHIP924.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP924.png
# Processado: CONTAINERSHIP925.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP925.png
# Processado: CONTAINERSHIP926.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP926.png
# Processado: CONTAINERSHIP927.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP927.png
# Processado: CONTAINERSHIP928.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP928.png
# Processado: CONTAINERSHIP929.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP929.png
# Processado: CONTAINERSHIP93.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP93.png
# Processado: CONTAINERSHIP930.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP930.png
# Processado: CONTAINERSHIP931.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP931.png
# Processado: CONTAINERSHIP932.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP932.png
# Processado: CONTAINERSHIP933.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP933.png
# Processado: CONTAINERSHIP934.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP934.png
# Processado: CONTAINERSHIP935.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP935.png
# Processado: CONTAINERSHIP936.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP936.png
# Processado: CONTAINERSHIP937.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP937.png
# Processado: CONTAINERSHIP938.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP938.png
# Processado: CONTAINERSHIP939.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP939.png
# Processado: CONTAINERSHIP94.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP94.png
# Processado: CONTAINERSHIP940.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP940.png
# Processado: CONTAINERSHIP941.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP941.png
# Processado: CONTAINERSHIP942.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP942.png
# Processado: CONTAINERSHIP943.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP943.png
# Processado: CONTAINERSHIP944.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP944.png
# Processado: CONTAINERSHIP945.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP945.png
# Processado: CONTAINERSHIP946.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP946.png
# Processado: CONTAINERSHIP947.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP947.png
# Processado: CONTAINERSHIP948.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP948.png
# Processado: CONTAINERSHIP949.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP949.png
# Processado: CONTAINERSHIP95.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP95.png
# Processado: CONTAINERSHIP950.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP950.png
# Processado: CONTAINERSHIP951.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP951.png
# Processado: CONTAINERSHIP952.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP952.png
# Processado: CONTAINERSHIP953.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP953.png
# Processado: CONTAINERSHIP954.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP954.png
# Processado: CONTAINERSHIP955.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP955.png
# Processado: CONTAINERSHIP956.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP956.png
# Processado: CONTAINERSHIP957.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP957.png
# Processado: CONTAINERSHIP958.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP958.png
# Processado: CONTAINERSHIP959.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP959.png
# Processado: CONTAINERSHIP96.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP96.png
# Processado: CONTAINERSHIP960.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP960.png
# Processado: CONTAINERSHIP961.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP961.png
# Processado: CONTAINERSHIP962.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP962.png
# Processado: CONTAINERSHIP963.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP963.png
# Processado: CONTAINERSHIP964.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP964.png
# Processado: CONTAINERSHIP965.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP965.png
# Processado: CONTAINERSHIP966.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP966.png
# Processado: CONTAINERSHIP967.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP967.png
# Processado: CONTAINERSHIP968.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP968.png
# Processado: CONTAINERSHIP969.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP969.png
# Processado: CONTAINERSHIP97.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP97.png
# Processado: CONTAINERSHIP970.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP970.png
# Processado: CONTAINERSHIP971.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP971.png
# Processado: CONTAINERSHIP972.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP972.png
# Processado: CONTAINERSHIP973.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP973.png
# Processado: CONTAINERSHIP974.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP974.png
# Processado: CONTAINERSHIP975.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP975.png
# Processado: CONTAINERSHIP976.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP976.png
# Processado: CONTAINERSHIP977.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP977.png
# Processado: CONTAINERSHIP978.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP978.png
# Processado: CONTAINERSHIP979.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP979.png
# Processado: CONTAINERSHIP98.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP98.png
# Processado: CONTAINERSHIP980.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP980.png
# Processado: CONTAINERSHIP981.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP981.png
# Processado: CONTAINERSHIP982.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP982.png
# Processado: CONTAINERSHIP983.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP983.png
# Processado: CONTAINERSHIP984.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP984.png
# Processado: CONTAINERSHIP985.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP985.png
# Processado: CONTAINERSHIP986.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP986.png
# Processado: CONTAINERSHIP987.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP987.png
# Processado: CONTAINERSHIP988.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP988.png
# Processado: CONTAINERSHIP989.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP989.png
# Processado: CONTAINERSHIP99.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP99.png
# Processado: CONTAINERSHIP990.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP990.png
# Processado: CONTAINERSHIP991.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP991.png
# Processado: CONTAINERSHIP992.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP992.png
# Processado: CONTAINERSHIP993.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP993.png
# Processado: CONTAINERSHIP994.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP994.png
# Processado: CONTAINERSHIP995.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP995.png
# Processado: CONTAINERSHIP996.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP996.png
# Processado: CONTAINERSHIP997.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP997.png
# Processado: CONTAINERSHIP998.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP998.png
# Processado: CONTAINERSHIP999.png -> DDPM-F64x4/CONTAINERSHIP/CONTAINERSHIP999.png
# Processamento concluído!
