# %%
generating_class = 'VEHICLESCARRIER'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-03-06 15:36:02.248034: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-06 15:36:02.268696: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-03-06 15:36:03.018746: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.021585: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.021602: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET500000/' + generating_class)

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-03-06 15:36:03.032260: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.032296: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.032307: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.156847: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.156874: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.156879: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-03-06 15:36:03.156894: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-06 15:36:03.156910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741275387.963819    1287 service.cc:145] XLA service 0x7f972803d150 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741275387.963854    1287 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-03-06 15:36:28.805183: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1741275389.512184    1287 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-03-06 15:36:30.954426: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741275393.067180    1460 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1741275393.091349    1474 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1741275393.157912    1457 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1741275393.199546    1459 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1741275393.314216    1445 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1741275393.317162    1462 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1741275393.366573    1457 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1741275393.470095    1474 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1741275393.481917    1469 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1741275393.558590    1449 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1741275393.699792    1450 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1741275393.871580    1446 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1741275394.051661    1474 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1741275394.098139    1466 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1741275394.238022    1457 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1741275394.304511    1467 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1741275394.304564    1455 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1741275394.396852    1473 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1741275394.404338    1456 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1741275394.439028    1465 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1741275394.509280    1452 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1741275394.549162    1469 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1741275394.618440    1455 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1741275394.636257    1447 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1741275394.653282    1458 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1741275394.736880    1475 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1741275395.253156    1471 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1741275395.268325    1474 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1741275395.729068    1460 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1741275395.778464    1448 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1741275395.804431    1464 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1741275395.876210    1462 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1741275395.885899    1445 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1741275423.628999    1287 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1741275423.674108    1287 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 109s 68ms/step - loss: 0.0710
# Epoch 2/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - loss: 0.0191
# Epoch 3/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 55s 69ms/step - loss: 0.0176
# Epoch 4/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - loss: 0.0167
# Epoch 5/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - loss: 0.0163
# Epoch 6/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - loss: 0.0156
# Epoch 7/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - loss: 0.0158
# Epoch 8/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - loss: 0.0151
# Epoch 9/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0152
# Epoch 10/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0148
# Epoch 11/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0142
# Epoch 12/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0144
# Epoch 13/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0144
# Epoch 14/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0139
# Epoch 15/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0145
# Epoch 16/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0140
# Epoch 17/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0138
# Epoch 18/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0143
# Epoch 19/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0136
# Epoch 20/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0138
# Epoch 21/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0139
# Epoch 22/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0140
# Epoch 23/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0137
# Epoch 24/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0132
# Epoch 25/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0136
# Epoch 26/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0139
# Epoch 27/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0135
# Epoch 28/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0139
# Epoch 29/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0136
# Epoch 30/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0132
# Epoch 31/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0137
# Epoch 32/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0132
# Epoch 33/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0132
# Epoch 34/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0136
# Epoch 35/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0129
# Epoch 36/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0130
# Epoch 37/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0130
# Epoch 38/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0131
# Epoch 39/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0130
# Epoch 40/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0128
# Epoch 41/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0133
# Epoch 42/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0129
# Epoch 43/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0129
# Epoch 44/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0131
# Epoch 45/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0131
# Epoch 46/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0128
# Epoch 47/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0126
# Epoch 48/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0129
# Epoch 49/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0130
# Epoch 50/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0128
# Epoch 51/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0128
# Epoch 52/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0127
# Epoch 53/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0127
# Epoch 54/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0130
# Epoch 55/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0125
# Epoch 56/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0126
# Epoch 57/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0128
# Epoch 58/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0130
# Epoch 59/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0125
# Epoch 60/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0129
# Epoch 61/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0125
# Epoch 62/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0126
# Epoch 63/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0131
# Epoch 64/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0124
# Epoch 65/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0127
# Epoch 66/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0125
# Epoch 67/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0127
# Epoch 68/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0125
# Epoch 69/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0127
# Epoch 70/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0124
# Epoch 71/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0126
# Epoch 72/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0125
# Epoch 73/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0126
# Epoch 74/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0127
# Epoch 75/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0126
# Epoch 76/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0128
# Epoch 77/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0126
# Epoch 78/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0131
# Epoch 79/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0125
# Epoch 80/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0126
# Epoch 81/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0127
# Epoch 82/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0125
# Epoch 83/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.
500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0112
# Epoch 427/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0114
# Epoch 428/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0114
# Epoch 429/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0114
# Epoch 430/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0110
# Epoch 431/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0113
# Epoch 432/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0114
# Epoch 433/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0111
# Epoch 434/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0110
# Epoch 435/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0113
# Epoch 436/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0112
# Epoch 437/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0112
# Epoch 438/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0116
# Epoch 439/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0111
# Epoch 440/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0109
# Epoch 441/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0113
# Epoch 442/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0112
# Epoch 443/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0114
# Epoch 444/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0108
# Epoch 445/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0111
# Epoch 446/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0112
# Epoch 447/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0108
# Epoch 448/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0114
# Epoch 449/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0110
# Epoch 450/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0111
# Epoch 451/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0112
# Epoch 452/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0107
# Epoch 453/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0114
# Epoch 454/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0112
# Epoch 455/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0114
# Epoch 456/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0115
# Epoch 457/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0115
# Epoch 458/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0112
# Epoch 459/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0110
# Epoch 460/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0119
# Epoch 461/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - loss: 0.0114
# Epoch 462/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0113
# Epoch 463/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - loss: 0.0112
# Epoch 464/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0113
# Epoch 465/500
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - loss: 0.0111
# Epoch 466/500
# 190/783 ━━━━━━━━━━━━━━━━━━━━ 39s 66ms/step - loss: 0.0118

# %%
import os
from IPython.display import clear_output
import time

num_img = 5400
output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    ini = time.time()
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    fim = time.time()
    tim = fim - ini
    timt = (tim * t) / 3600
    print("Faltam %d iterações" % (t))
    print("A iteração atual levou %d segundos" % (tim))
    print("Faltam %.2f horas" % (timt))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# Faltam 0 iterações
# A iteração atual levou 26 segundos
# Faltam 0.00 horas

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: VEHICLESCARRIER0.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER0.png
# Processado: VEHICLESCARRIER1.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1.png
# Processado: VEHICLESCARRIER10.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER10.png
# Processado: VEHICLESCARRIER100.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER100.png
# Processado: VEHICLESCARRIER1000.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1000.png
# Processado: VEHICLESCARRIER1001.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1001.png
# Processado: VEHICLESCARRIER1002.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1002.png
# Processado: VEHICLESCARRIER1003.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1003.png
# Processado: VEHICLESCARRIER1004.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1004.png
# Processado: VEHICLESCARRIER1005.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1005.png
# Processado: VEHICLESCARRIER1006.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1006.png
# Processado: VEHICLESCARRIER1007.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1007.png
# Processado: VEHICLESCARRIER1008.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1008.png
# Processado: VEHICLESCARRIER1009.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1009.png
# Processado: VEHICLESCARRIER101.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER101.png
# Processado: VEHICLESCARRIER1010.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1010.png
# Processado: VEHICLESCARRIER1011.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1011.png
# Processado: VEHICLESCARRIER1012.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1012.png
# Processado: VEHICLESCARRIER1013.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1013.png
# Processado: VEHICLESCARRIER1014.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1014.png
# Processado: VEHICLESCARRIER1015.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1015.png
# Processado: VEHICLESCARRIER1016.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1016.png
# Processado: VEHICLESCARRIER1017.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1017.png
# Processado: VEHICLESCARRIER1018.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1018.png
# Processado: VEHICLESCARRIER1019.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER
png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1469.png
# Processado: VEHICLESCARRIER147.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER147.png
# Processado: VEHICLESCARRIER1470.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1470.png
# Processado: VEHICLESCARRIER1471.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1471.png
# Processado: VEHICLESCARRIER1472.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1472.png
# Processado: VEHICLESCARRIER1473.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1473.png
# Processado: VEHICLESCARRIER1474.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1474.png
# Processado: VEHICLESCARRIER1475.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1475.png
# Processado: VEHICLESCARRIER1476.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1476.png
# Processado: VEHICLESCARRIER1477.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1477.png
# Processado: VEHICLESCARRIER1478.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER1478.png
# ...
# Processado: VEHICLESCARRIER836.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER836.png
# Processado: VEHICLESCARRIER837.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER837.png
# Processado: VEHICLESCARRIER838.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER838.png
# Processado: VEHICLESCARRIER839.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER839.png
# Processado: VEHICLESCARRIER84.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER84.png
# Processado: VEHICLESCARRIER840.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER840.png
# Processado: VEHICLESCARRIER841.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER841.png
# Processado: VEHICLESCARRIER842.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER842.png
# Processado: VEHICLESCARRIER843.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER843.png
# Processado: VEHICLESCARRIER844.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER844.png
# Processado: VEHICLESCARRIER845.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER845.png
# Processado: VEHICLESCARRIER846.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER846.png
# Processado: VEHICLESCARRIER847.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER847.png
# Processado: VEHICLESCARRIER848.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER848.png
# Processado: VEHICLESCARRIER849.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER849.png
# Processado: VEHICLESCARRIER85.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER85.png
# Processado: VEHICLESCARRIER850.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER850.png
# Processado: VEHICLESCARRIER851.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER851.png
# Processado: VEHICLESCARRIER852.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER852.png
# Processado: VEHICLESCARRIER853.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER853.png
# Processado: VEHICLESCARRIER854.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER854.png
# Processado: VEHICLESCARRIER855.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER855.png
# Processado: VEHICLESCARRIER856.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER856.png
# Processado: VEHICLESCARRIER857.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER857.png
# Processado: VEHICLESCARRIER858.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER858.png
# Processado: VEHICLESCARRIER859.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER859.png
# Processado: VEHICLESCARRIER86.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER86.png
# Processado: VEHICLESCARRIER860.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER860.png
# Processado: VEHICLESCARRIER861.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER861.png
# Processado: VEHICLESCARRIER862.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER862.png
# Processado: VEHICLESCARRIER863.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER863.png
# Processado: VEHICLESCARRIER864.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER864.png
# Processado: VEHICLESCARRIER865.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER865.png
# Processado: VEHICLESCARRIER866.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER866.png
# Processado: VEHICLESCARRIER867.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER867.png
# Processado: VEHICLESCARRIER868.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER868.png
# Processado: VEHICLESCARRIER869.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER869.png
# Processado: VEHICLESCARRIER87.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER87.png
# Processado: VEHICLESCARRIER870.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER870.png
# Processado: VEHICLESCARRIER871.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER871.png
# Processado: VEHICLESCARRIER872.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER872.png
# Processado: VEHICLESCARRIER873.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER873.png
# Processado: VEHICLESCARRIER874.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER874.png
# Processado: VEHICLESCARRIER875.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER875.png
# Processado: VEHICLESCARRIER876.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER876.png
# Processado: VEHICLESCARRIER877.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER877.png
# Processado: VEHICLESCARRIER878.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER878.png
# Processado: VEHICLESCARRIER879.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER879.png
# Processado: VEHICLESCARRIER88.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER88.png
# Processado: VEHICLESCARRIER880.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER880.png
# Processado: VEHICLESCARRIER881.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER881.png
# Processado: VEHICLESCARRIER882.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER882.png
# Processado: VEHICLESCARRIER883.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER883.png
# Processado: VEHICLESCARRIER884.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER884.png
# Processado: VEHICLESCARRIER885.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER885.png
# Processado: VEHICLESCARRIER886.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER886.png
# Processado: VEHICLESCARRIER887.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER887.png
# Processado: VEHICLESCARRIER888.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER888.png
# Processado: VEHICLESCARRIER889.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER889.png
# Processado: VEHICLESCARRIER89.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER89.png
# Processado: VEHICLESCARRIER890.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER890.png
# Processado: VEHICLESCARRIER891.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER891.png
# Processado: VEHICLESCARRIER892.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER892.png
# Processado: VEHICLESCARRIER893.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER893.png
# Processado: VEHICLESCARRIER894.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER894.png
# Processado: VEHICLESCARRIER895.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER895.png
# Processado: VEHICLESCARRIER896.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER896.png
# Processado: VEHICLESCARRIER897.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER897.png
# Processado: VEHICLESCARRIER898.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER898.png
# Processado: VEHICLESCARRIER899.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER899.png
# Processado: VEHICLESCARRIER9.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER9.png
# Processado: VEHICLESCARRIER90.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER90.png
# Processado: VEHICLESCARRIER900.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER900.png
# Processado: VEHICLESCARRIER901.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER901.png
# Processado: VEHICLESCARRIER902.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER902.png
# Processado: VEHICLESCARRIER903.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER903.png
# Processado: VEHICLESCARRIER904.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER904.png
# Processado: VEHICLESCARRIER905.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER905.png
# Processado: VEHICLESCARRIER906.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER906.png
# Processado: VEHICLESCARRIER907.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER907.png
# Processado: VEHICLESCARRIER908.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER908.png
# Processado: VEHICLESCARRIER909.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER909.png
# Processado: VEHICLESCARRIER91.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER91.png
# Processado: VEHICLESCARRIER910.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER910.png
# Processado: VEHICLESCARRIER911.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER911.png
# Processado: VEHICLESCARRIER912.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER912.png
# Processado: VEHICLESCARRIER913.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER913.png
# Processado: VEHICLESCARRIER914.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER914.png
# Processado: VEHICLESCARRIER915.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER915.png
# Processado: VEHICLESCARRIER916.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER916.png
# Processado: VEHICLESCARRIER917.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER917.png
# Processado: VEHICLESCARRIER918.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER918.png
# Processado: VEHICLESCARRIER919.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER919.png
# Processado: VEHICLESCARRIER92.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER92.png
# Processado: VEHICLESCARRIER920.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER920.png
# Processado: VEHICLESCARRIER921.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER921.png
# Processado: VEHICLESCARRIER922.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER922.png
# Processado: VEHICLESCARRIER923.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER923.png
# Processado: VEHICLESCARRIER924.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER924.png
# Processado: VEHICLESCARRIER925.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER925.png
# Processado: VEHICLESCARRIER926.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER926.png
# Processado: VEHICLESCARRIER927.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER927.png
# Processado: VEHICLESCARRIER928.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER928.png
# Processado: VEHICLESCARRIER929.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER929.png
# Processado: VEHICLESCARRIER93.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER93.png
# Processado: VEHICLESCARRIER930.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER930.png
# Processado: VEHICLESCARRIER931.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER931.png
# Processado: VEHICLESCARRIER932.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER932.png
# Processado: VEHICLESCARRIER933.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER933.png
# Processado: VEHICLESCARRIER934.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER934.png
# Processado: VEHICLESCARRIER935.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER935.png
# Processado: VEHICLESCARRIER936.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER936.png
# Processado: VEHICLESCARRIER937.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER937.png
# Processado: VEHICLESCARRIER938.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER938.png
# Processado: VEHICLESCARRIER939.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER939.png
# Processado: VEHICLESCARRIER94.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER94.png
# Processado: VEHICLESCARRIER940.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER940.png
# Processado: VEHICLESCARRIER941.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER941.png
# Processado: VEHICLESCARRIER942.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER942.png
# Processado: VEHICLESCARRIER943.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER943.png
# Processado: VEHICLESCARRIER944.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER944.png
# Processado: VEHICLESCARRIER945.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER945.png
# Processado: VEHICLESCARRIER946.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER946.png
# Processado: VEHICLESCARRIER947.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER947.png
# Processado: VEHICLESCARRIER948.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER948.png
# Processado: VEHICLESCARRIER949.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER949.png
# Processado: VEHICLESCARRIER95.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER95.png
# Processado: VEHICLESCARRIER950.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER950.png
# Processado: VEHICLESCARRIER951.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER951.png
# Processado: VEHICLESCARRIER952.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER952.png
# Processado: VEHICLESCARRIER953.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER953.png
# Processado: VEHICLESCARRIER954.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER954.png
# Processado: VEHICLESCARRIER955.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER955.png
# Processado: VEHICLESCARRIER956.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER956.png
# Processado: VEHICLESCARRIER957.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER957.png
# Processado: VEHICLESCARRIER958.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER958.png
# Processado: VEHICLESCARRIER959.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER959.png
# Processado: VEHICLESCARRIER96.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER96.png
# Processado: VEHICLESCARRIER960.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER960.png
# Processado: VEHICLESCARRIER961.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER961.png
# Processado: VEHICLESCARRIER962.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER962.png
# Processado: VEHICLESCARRIER963.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER963.png
# Processado: VEHICLESCARRIER964.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER964.png
# Processado: VEHICLESCARRIER965.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER965.png
# Processado: VEHICLESCARRIER966.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER966.png
# Processado: VEHICLESCARRIER967.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER967.png
# Processado: VEHICLESCARRIER968.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER968.png
# Processado: VEHICLESCARRIER969.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER969.png
# Processado: VEHICLESCARRIER97.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER97.png
# Processado: VEHICLESCARRIER970.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER970.png
# Processado: VEHICLESCARRIER971.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER971.png
# Processado: VEHICLESCARRIER972.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER972.png
# Processado: VEHICLESCARRIER973.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER973.png
# Processado: VEHICLESCARRIER974.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER974.png
# Processado: VEHICLESCARRIER975.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER975.png
# Processado: VEHICLESCARRIER976.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER976.png
# Processado: VEHICLESCARRIER977.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER977.png
# Processado: VEHICLESCARRIER978.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER978.png
# Processado: VEHICLESCARRIER979.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER979.png
# Processado: VEHICLESCARRIER98.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER98.png
# Processado: VEHICLESCARRIER980.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER980.png
# Processado: VEHICLESCARRIER981.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER981.png
# Processado: VEHICLESCARRIER982.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER982.png
# Processado: VEHICLESCARRIER983.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER983.png
# Processado: VEHICLESCARRIER984.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER984.png
# Processado: VEHICLESCARRIER985.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER985.png
# Processado: VEHICLESCARRIER986.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER986.png
# Processado: VEHICLESCARRIER987.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER987.png
# Processado: VEHICLESCARRIER988.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER988.png
# Processado: VEHICLESCARRIER989.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER989.png
# Processado: VEHICLESCARRIER99.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER99.png
# Processado: VEHICLESCARRIER990.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER990.png
# Processado: VEHICLESCARRIER991.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER991.png
# Processado: VEHICLESCARRIER992.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER992.png
# Processado: VEHICLESCARRIER993.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER993.png
# Processado: VEHICLESCARRIER994.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER994.png
# Processado: VEHICLESCARRIER995.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER995.png
# Processado: VEHICLESCARRIER996.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER996.png
# Processado: VEHICLESCARRIER997.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER997.png
# Processado: VEHICLESCARRIER998.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER998.png
# Processado: VEHICLESCARRIER999.png -> DDPM-F64x4/VEHICLESCARRIER/VEHICLESCARRIER999.png
# Processamento concluído!
