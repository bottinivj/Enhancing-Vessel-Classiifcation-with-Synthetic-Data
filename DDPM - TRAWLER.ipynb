# %%
generating_class = 'TRAWLER'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-02-02 01:47:35.651973: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-02 01:47:35.672927: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-02-02 01:47:36.492392: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.495343: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.495362: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-02-02 01:47:36.506732: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.506765: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.506775: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.653571: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.653601: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.653606: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-02-02 01:47:36.653622: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-02-02 01:47:36.653641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738460880.199668     174 service.cc:145] XLA service 0x7f9248002e80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738460880.199706     174 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-02-02 01:48:01.023643: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738460881.742643     174 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-02-02 01:48:03.196981: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738460884.650018     346 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738460885.127303     345 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738460885.149601     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738460885.202692     336 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738460885.249677     334 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738460885.318096     343 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738460885.413739     349 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738460885.487119     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738460885.505229     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738460885.595224     340 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738460885.734736     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738460885.766060     339 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738460885.884840     350 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738460885.946884     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738460885.952150     357 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738460885.977209     337 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738460886.149381     333 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738460886.149428     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738460886.191968     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738460886.261616     362 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738460886.303332     346 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738460886.334007     358 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738460886.342424     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738460886.445248     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738460886.612985     335 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738460887.083813     358 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738460887.228767     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738460887.450256     338 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738460887.672586     349 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738460887.868307     356 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738460887.983483     339 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738460888.046608     360 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738460888.055266     336 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738460915.965828     174 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_195', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_191', 36 bytes spill stores, 36 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_168', 44 bytes spill stores, 44 bytes spill loads
#
# I0000 00:00:1738460916.010702     174 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 67s 67ms/step - loss: 0.2453
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0378
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0343
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0298
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0294
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0289
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0281
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0262
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0273
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0257
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0256
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0280
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0264
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0262
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0250
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0244
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0248
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0246
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0263
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0252
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0246
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0259
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0249
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0237
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0246
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0244
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0253
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0244
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0232
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0242
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0227
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0242
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0237
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0224
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0232
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0234
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0231
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0235
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0238
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0227
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0229
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0229
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0221
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0215
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0227
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0226
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0229
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0220
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0226
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0222
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0225
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0223
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0221
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0227
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0207
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0218
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0212
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0213
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0227
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0224
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0228
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0228
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0221
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0215
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0222
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0208
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0217
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0222
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0212
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0215
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0211
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0228
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0230
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0214
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0218
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0216
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0223
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0220
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0216
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0218
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0222
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0225
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0221
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0215
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0216
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0218
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0209
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0215
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0224
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0215
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0218
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0217
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0216
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0216
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0224
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0223
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0209
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0223
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0221
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0209
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0211
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0211
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0218
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0216
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0220
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0217
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0213
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0200
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0207
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0206
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0219
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0200
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0202
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0189
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0202
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0206
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0207
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0206
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0211
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0194
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0204
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0202
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0214
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0210
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0202
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 327/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 328/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 346/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 347/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 348/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 349/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0199
# Epoch 350/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 351/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 352/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 353/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 354/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0203
# Epoch 355/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 356/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 357/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0201
# Epoch 358/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 359/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 360/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 361/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 362/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0207
# Epoch 363/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0215
# Epoch 364/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 365/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 366/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 367/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 368/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 369/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 370/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0204
# Epoch 371/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 372/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 373/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 374/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 375/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 376/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208
# Epoch 377/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 378/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 379/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 380/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 381/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 382/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0201
# Epoch 383/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 384/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 385/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 386/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 387/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0202
# Epoch 388/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0199
# Epoch 389/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0210
# Epoch 390/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0204
# Epoch 391/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0195
# Epoch 392/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0192
# Epoch 393/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0188
# Epoch 394/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 395/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 396/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 397/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 398/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 399/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0207
# Epoch 400/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0190
# Epoch 401/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 402/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0186
# Epoch 403/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0183
# Epoch 404/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0191
# Epoch 405/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0203
# Epoch 406/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0196
# Epoch 407/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0194
# Epoch 408/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0198
# Epoch 409/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 410/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 411/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 412/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 413/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 414/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0198
# Epoch 415/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 416/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 417/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 418/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 419/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0205
# Epoch 420/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 421/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 422/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 423/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 424/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 425/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 426/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 427/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 428/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 429/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 430/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 431/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 432/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 433/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 434/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0195
# Epoch 435/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 436/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 437/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 438/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 439/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 440/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 441/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 442/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 443/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 444/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 445/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 446/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 447/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 448/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 449/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 450/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 451/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0197
# Epoch 452/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 453/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0185
# Epoch 454/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 455/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 456/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 457/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 458/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 459/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 460/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 461/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 462/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 463/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 464/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 465/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 466/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 467/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0179
# Epoch 468/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 469/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 470/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0190
# Epoch 471/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 472/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0196
# Epoch 473/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 474/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 475/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 476/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 477/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 478/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 479/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 480/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0183
# Epoch 481/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0181
# Epoch 482/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 483/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0188
# Epoch 484/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0184
# Epoch 485/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 486/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 487/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0186
# Epoch 488/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 489/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0189
# Epoch 490/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192
# Epoch 491/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0193
# Epoch 492/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0200
# Epoch 493/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0182
# Epoch 494/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0194
# Epoch 495/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0191
# Epoch 496/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0178
# Epoch 497/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0187
# Epoch 498/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0193
# Epoch 499/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0187
# Epoch 500/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0197
# INFO:tensorflow:Assets written to: DDPM-GI/TRAWLER/GERADOR/assets
# INFO:tensorflow:Assets written to: DDPM-GI/TRAWLER/GERADOR/assets

# %%
import os
from IPython.display import clear_output
import time

num_img = 5400
output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    ini = time.time()
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    fim = time.time()
    tim = fim - ini
    timt = (tim * t) / 3600
    print("Faltam %d iterações" % (t))
    print("A iteração atual levou %d segundos" % (tim))
    print("Faltam %.2f horas" % (timt))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# Faltam 0 iterações
# A iteração atual levou 27 segundos
# Faltam 0.00 horas

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: TRAWLER0.png -> DDPM-F64x4/TRAWLER/TRAWLER0.png
# Processado: TRAWLER1.png -> DDPM-F64x4/TRAWLER/TRAWLER1.png
# Processado: TRAWLER10.png -> DDPM-F64x4/TRAWLER/TRAWLER10.png
# Processado: TRAWLER100.png -> DDPM-F64x4/TRAWLER/TRAWLER100.png
# Processado: TRAWLER1000.png -> DDPM-F64x4/TRAWLER/TRAWLER1000.png
# Processado: TRAWLER1001.png -> DDPM-F64x4/TRAWLER/TRAWLER1001.png
# Processado: TRAWLER1002.png -> DDPM-F64x4/TRAWLER/TRAWLER1002.png
# Processado: TRAWLER1003.png -> DDPM-F64x4/TRAWLER/TRAWLER1003.png
# Processado: TRAWLER1004.png -> DDPM-F64x4/TRAWLER/TRAWLER1004.png
# Processado: TRAWLER1005.png -> DDPM-F64x4/TRAWLER/TRAWLER1005.png
# Processado: TRAWLER1006.png -> DDPM-F64x4/TRAWLER/TRAWLER1006.png
# Processado: TRAWLER1007.png -> DDPM-F64x4/TRAWLER/TRAWLER1007.png
# Processado: TRAWLER1008.png -> DDPM-F64x4/TRAWLER/TRAWLER1008.png
# Processado: TRAWLER1009.png -> DDPM-F64x4/TRAWLER/TRAWLER1009.png
# Processado: TRAWLER101.png -> DDPM-F64x4/TRAWLER/TRAWLER101.png
# Processado: TRAWLER1010.png -> DDPM-F64x4/TRAWLER/TRAWLER1010.png
# Processado: TRAWLER1011.png -> DDPM-F64x4/TRAWLER/TRAWLER1011.png
# Processado: TRAWLER1012.png -> DDPM-F64x4/TRAWLER/TRAWLER1012.png
# Processado: TRAWLER1013.png -> DDPM-F64x4/TRAWLER/TRAWLER1013.png
# Processado: TRAWLER1014.png -> DDPM-F64x4/TRAWLER/TRAWLER1014.png
# Processado: TRAWLER1015.png -> DDPM-F64x4/TRAWLER/TRAWLER1015.png
# Processado: TRAWLER1016.png -> DDPM-F64x4/TRAWLER/TRAWLER1016.png
# Processado: TRAWLER1017.png -> DDPM-F64x4/TRAWLER/TRAWLER1017.png
# Processado: TRAWLER1018.png -> DDPM-F64x4/TRAWLER/TRAWLER1018.png
# Processado: TRAWLER1019.png -> DDPM-F64x4/TRAWLER/TRAWLER1019.png
# Processado: TRAWLER102.png -> DDPM-F64x4/TRAWLER/TRAWLER102.png
# Processado: TRAWLER1020.png -> DDPM-F64x4/TRAWLER/TRAWLER1020.png
# Processado: TRAWLER1021.png -> DDPM-F64x4/TRAWLER/TRAWLER1021.png
# Processado: TRAWLER1022.png -> DDPM-F64x4/TRAWLER/TRAWLER1022.png
# Processado: TRAWLER1023.png -> DDPM-F64x4/TRAWLER/TRAWLER1023.png
# Processado: TRAWLER1024.png -> DDPM-F64x4/TRAWLER/TRAWLER1024.png
# Processado: TRAWLER1025.png -> DDPM-F64x4/TRAWLER/TRAWLER1025.png
# Processado: TRAWLER1026.png -> DDPM-F64x4/TRAWLER/TRAWLER1026.png
# Processado: TRAWLER1027.png -> DDPM-F64x4/TRAWLER/TRAWLER1027.png
# Processado: TRAWLER1028.png -> DDPM-F64x4/TRAWLER/TRAWLER1028.png
# Processado: TRAWLER1029.png -> DDPM-F64x4/TRAWLER/TRAWLER1029.png
# Processado: TRAWLER103.png -> DDPM-F64x4/TRAWLER/TRAWLER103.png
# Processado: TRAWLER1030.png -> DDPM-F64x4/TRAWLER/TRAWLER1030.png
# Processado: TRAWLER1031.png -> DDPM-F64x4/TRAWLER/TRAWLER1031.png
# Processado: TRAWLER1032.png -> DDPM-F64x4/TRAWLER/TRAWLER1032.png
# Processado: TRAWLER1033.png -> DDPM-F64x4/TRAWLER/TRAWLER1033.png
# Processado: TRAWLER1034.png -> DDPM-F64x4/TRAWLER/TRAWLER1034.png
# Processado: TRAWLER1035.png -> DDPM-F64x4/TRAWLER/TRAWLER1035.png
# Processado: TRAWLER1036.png -> DDPM-F64x4/TRAWLER/TRAWLER1036.png
# Processado: TRAWLER1037.png -> DDPM-F64x4/TRAWLER/TRAWLER1037.png
# Processado: TRAWLER1038.png -> DDPM-F64x4/TRAWLER/TRAWLER1038.png
# Processado: TRAWLER1039.png -> DDPM-F64x4/TRAWLER/TRAWLER1039.png
# Processado: TRAWLER104.png -> DDPM-F64x4/TRAWLER/TRAWLER104.png
# Processado: TRAWLER1040.png -> DDPM-F64x4/TRAWLER/TRAWLER1040.png
# Processado: TRAWLER1041.png -> DDPM-F64x4/TRAWLER/TRAWLER1041.png
# Processado: TRAWLER1042.png -> DDPM-F64x4/TRAWLER/TRAWLER1042.png
# Processado: TRAWLER1043.png -> DDPM-F64x4/TRAWLER/TRAWLER1043.png
# Processado: TRAWLER1044.png -> DDPM-F64x4/TRAWLER/TRAWLER1044.png
# Processado: TRAWLER1045.png -> DDPM-F64x4/TRAWLER/TRAWLER1045.png
# Processado: TRAWLER1046.png -> DDPM-F64x4/TRAWLER/TRAWLER1046.png
# Processado: TRAWLER1047.png -> DDPM-F64x4/TRAWLER/TRAWLER1047.png
# Processado: TRAWLER1048.png -> DDPM-F64x4/TRAWLER/TRAWLER1048.png
# Processado: TRAWLER1049.png -> DDPM-F64x4/TRAWLER/TRAWLER1049.png
# Processado: TRAWLER105.png -> DDPM-F64x4/TRAWLER/TRAWLER105.png
# Processado: TRAWLER1050.png -> DDPM-F64x4/TRAWLER/TRAWLER1050.png
# Processado: TRAWLER1051.png -> DDPM-F64x4/TRAWLER/TRAWLER1051.png
# Processado: TRAWLER1052.png -> DDPM-F64x4/TRAWLER/TRAWLER1052.png
# Processado: TRAWLER1053.png -> DDPM-F64x4/TRAWLER/TRAWLER1053.png
# Processado: TRAWLER1054.png -> DDPM-F64x4/TRAWLER/TRAWLER1054.png
# Processado: TRAWLER1055.png -> DDPM-F64x4/TRAWLER/TRAWLER1055.png
# Processado: TRAWLER1056.png -> DDPM-F64x4/TRAWLER/TRAWLER1056.png
# Processado: TRAWLER1057.png -> DDPM-F64x4/TRAWLER/TRAWLER1057.png
# Processado: TRAWLER1058.png -> DDPM-F64x4/TRAWLER/TRAWLER1058.png
# Processado: TRAWLER1059.png -> DDPM-F64x4/TRAWLER/TRAWLER1059.png
# Processado: TRAWLER106.png -> DDPM-F64x4/TRAWLER/TRAWLER106.png
# Processado: TRAWLER1060.png -> DDPM-F64x4/TRAWLER/TRAWLER1060.png
# Processado: TRAWLER1061.png -> DDPM-F64x4/TRAWLER/TRAWLER1061.png
# Processado: TRAWLER1062.png -> DDPM-F64x4/TRAWLER/TRAWLER1062.png
# Processado: TRAWLER1063.png -> DDPM-F64x4/TRAWLER/TRAWLER1063.png
# Processado: TRAWLER1064.png -> DDPM-F64x4/TRAWLER/TRAWLER1064.png
# Processado: TRAWLER1065.png -> DDPM-F64x4/TRAWLER/TRAWLER1065.png
# Processado: TRAWLER1066.png -> DDPM-F64x4/TRAWLER/TRAWLER1066.png
# Processado: TRAWLER1067.png -> DDPM-F64x4/TRAWLER/TRAWLER1067.png
# Processado: TRAWLER1068.png -> DDPM-F64x4/TRAWLER/TRAWLER1068.png
# Processado: TRAWLER1069.png -> DDPM-F64x4/TRAWLER/TRAWLER1069.png
# Processado: TRAWLER107.png -> DDPM-F64x4/TRAWLER/TRAWLER107.png
# Processado: TRAWLER1070.png -> DDPM-F64x4/TRAWLER/TRAWLER1070.png
# Processado: TRAWLER1071.png -> DDPM-F64x4/TRAWLER/TRAWLER1071.png
# Processado: TRAWLER1072.png -> DDPM-F64x4/TRAWLER/TRAWLER1072.png
# Processado: TRAWLER1073.png -> DDPM-F64x4/TRAWLER/TRAWLER1073.png
# Processado: TRAWLER1074.png -> DDPM-F64x4/TRAWLER/TRAWLER1074.png
# Processado: TRAWLER1075.png -> DDPM-F64x4/TRAWLER/TRAWLER1075.png
# Processado: TRAWLER1076.png -> DDPM-F64x4/TRAWLER/TRAWLER1076.png
# Processado: TRAWLER1077.png -> DDPM-F64x4/TRAWLER/TRAWLER1077.png
# Processado: TRAWLER1078.png -> DDPM-F64x4/TRAWLER/TRAWLER1078.png
# Processado: TRAWLER1079.png -> DDPM-F64x4/TRAWLER/TRAWLER1079.png
# Processado: TRAWLER108.png -> DDPM-F64x4/TRAWLER/TRAWLER108.png
# Processado: TRAWLER1080.png -> DDPM-F64x4/TRAWLER/TRAWLER1080.png
# Processado: TRAWLER1081.png -> DDPM-F64x4/TRAWLER/TRAWLER1081.png
# Processado: TRAWLER1082.png -> DDPM-F64x4/TRAWLER/TRAWLER1082.png
# Processado: TRAWLER1083.png -> DDPM-F64x4/TRAWLER/TRAWLER1083.png
# Processado: TRAWLER1084.png -> DDPM-F64x4/TRAWLER/TRAWLER1084.png
# Processado: TRAWLER1085.png -> DDPM-F64x4/TRAWLER/TRAWLER1085.png
# Processado: TRAWLER1086.png -> DDPM-F64x4/TRAWLER/TRAWLER1086.png
# Processado: TRAWLER1087.png -> DDPM-F64x4/TRAWLER/TRAWLER1087.png
# Processado: TRAWLER1088.png -> DDPM-F64x4/TRAWLER/TRAWLER1088.png
# Processado: TRAWLER1089.png -> DDPM-F64x4/TRAWLER/TRAWLER1089.png
# Processado: TRAWLER109.png -> DDPM-F64x4/TRAWLER/TRAWLER109.png
# Processado: TRAWLER1090.png -> DDPM-F64x4/TRAWLER/TRAWLER1090.png
# Processado: TRAWLER1091.png -> DDPM-F64x4/TRAWLER/TRAWLER1091.png
# Processado: TRAWLER1092.png -> DDPM-F64x4/TRAWLER/TRAWLER1092.png
# Processado: TRAWLER1093.png -> DDPM-F64x4/TRAWLER/TRAWLER1093.png
# Processado: TRAWLER1094.png -> DDPM-F64x4/TRAWLER/TRAWLER1094.png
# Processado: TRAWLER1095.png -> DDPM-F64x4/TRAWLER/TRAWLER1095.png
# Processado: TRAWLER1096.png -> DDPM-F64x4/TRAWLER/TRAWLER1096.png
# Processado: TRAWLER1097.png -> DDPM-F64x4/TRAWLER/TRAWLER1097.png
# Processado: TRAWLER1098.png -> DDPM-F64x4/TRAWLER/TRAWLER1098.png
# Processado: TRAWLER1099.png -> DDPM-F64x4/TRAWLER/TRAWLER1099.png
# Processado: TRAWLER11.png -> DDPM-F64x4/TRAWLER/TRAWLER11.png
# Processado: TRAWLER110.png -> DDPM-F64x4/TRAWLER/TRAWLER110.png
# Processado: TRAWLER1100.png -> DDPM-F64x4/TRAWLER/TRAWLER1100.png
# Processado: TRAWLER1101.png -> DDPM-F64x4/TRAWLER/TRAWLER1101.png
# Processado: TRAWLER1102.png -> DDPM-F64x4/TRAWLER/TRAWLER1102.png
# Processado: TRAWLER1103.png -> DDPM-F64x4/TRAWLER/TRAWLER1103.png
# Processado: TRAWLER1104.png -> DDPM-F64x4/TRAWLER/TRAWLER1104.png
# Processado: TRAWLER1105.png -> DDPM-F64x4/TRAWLER/TRAWLER1105.png
# Processado: TRAWLER1106.png -> DDPM-F64x4/TRAWLER/TRAWLER1106.png
# Processado: TRAWLER1107.png -> DDPM-F64x4/TRAWLER/TRAWLER1107.png
# Processado: TRAWLER1108.png -> DDPM-F64x4/TRAWLER/TRAWLER1108.png
# Processado: TRAWLER1109.png -> DDPM-F64x4/TRAWLER/TRAWLER1109.png
# Processado: TRAWLER111.png -> DDPM-F64x4/TRAWLER/TRAWLER111.png
# Processado: TRAWLER1110.png -> DDPM-F64x4/TRAWLER/TRAWLER1110.png
# Processado: TRAWLER1111.png -> DDPM-F64x4/TRAWLER/TRAWLER1111.png
# Processado: TRAWLER1112.png -> DDPM-F64x4/TRAWLER/TRAWLER1112.png
# Processado: TRAWLER1113.png -> DDPM-F64x4/TRAWLER/TRAWLER1113.png
# Processado: TRAWLER1114.png -> DDPM-F64x4/TRAWLER/TRAWLER1114.png
# Processado: TRAWLER1115.png -> DDPM-F64x4/TRAWLER/TRAWLER1115.png
# Processado: TRAWLER1116.png -> DDPM-F64x4/TRAWLER/TRAWLER1116.png
# Processado: TRAWLER1117.png -> DDPM-F64x4/TRAWLER/TRAWLER1117.png
# Processado: TRAWLER1118.png -> DDPM-F64x4/TRAWLER/TRAWLER1118.png
# Processado: TRAWLER1119.png -> DDPM-F64x4/TRAWLER/TRAWLER1119.png
# Processado: TRAWLER112.png -> DDPM-F64x4/TRAWLER/TRAWLER112.png
# Processado: TRAWLER1120.png -> DDPM-F64x4/TRAWLER/TRAWLER1120.png
# Processado: TRAWLER1121.png -> DDPM-F64x4/TRAWLER/TRAWLER1121.png
# Processado: TRAWLER1122.png -> DDPM-F64x4/TRAWLER/TRAWLER1122.png
# Processado: TRAWLER1123.png -> DDPM-F64x4/TRAWLER/TRAWLER1123.png
# Processado: TRAWLER1124.png -> DDPM-F64x4/TRAWLER/TRAWLER1124.png
# Processado: TRAWLER1125.png -> DDPM-F64x4/TRAWLER/TRAWLER1125.png
# Processado: TRAWLER1126.png -> DDPM-F64x4/TRAWLER/TRAWLER1126.png
# Processado: TRAWLER1127.png -> DDPM-F64x4/TRAWLER/TRAWLER1127.png
# Processado: TRAWLER1128.png -> DDPM-F64x4/TRAWLER/TRAWLER1128.png
# Processado: TRAWLER1129.png -> DDPM-F64x4/TRAWLER/TRAWLER1129.png
# Processado: TRAWLER113.png -> DDPM-F64x4/TRAWLER/TRAWLER113.png
# Processado: TRAWLER1130.png -> DDPM-F64x4/TRAWLER/TRAWLER1130.png
# Processado: TRAWLER1131.png -> DDPM-F64x4/TRAWLER/TRAWLER1131.png
# Processado: TRAWLER1132.png -> DDPM-F64x4/TRAWLER/TRAWLER1132.png
# Processado: TRAWLER1133.png -> DDPM-F64x4/TRAWLER/TRAWLER1133.png
# Processado: TRAWLER1134.png -> DDPM-F64x4/TRAWLER/TRAWLER1134.png
# Processado: TRAWLER1135.png -> DDPM-F64x4/TRAWLER/TRAWLER1135.png
# Processado: TRAWLER1136.png -> DDPM-F64x4/TRAWLER/TRAWLER1136.png
# Processado: TRAWLER1137.png -> DDPM-F64x4/TRAWLER/TRAWLER1137.png
# Processado: TRAWLER1138.png -> DDPM-F64x4/TRAWLER/TRAWLER1138.png
# Processado: TRAWLER1139.png -> DDPM-F64x4/TRAWLER/TRAWLER1139.png
# Processado: TRAWLER114.png -> DDPM-F64x4/TRAWLER/TRAWLER114.png
# Processado: TRAWLER1140.png -> DDPM-F64x4/TRAWLER/TRAWLER1140.png
# Processado: TRAWLER1141.png -> DDPM-F64x4/TRAWLER/TRAWLER1141.png
# Processado: TRAWLER1142.png -> DDPM-F64x4/TRAWLER/TRAWLER1142.png
# Processado: TRAWLER1143.png -> DDPM-F64x4/TRAWLER/TRAWLER1143.png
# Processado: TRAWLER1144.png -> DDPM-F64x4/TRAWLER/TRAWLER1144.png
# Processado: TRAWLER1145.png -> DDPM-F64x4/TRAWLER/TRAWLER1145.png
# Processado: TRAWLER1146.png -> DDPM-F64x4/TRAWLER/TRAWLER1146.png
# Processado: TRAWLER1147.png -> DDPM-F64x4/TRAWLER/TRAWLER1147.png
# Processado: TRAWLER1148.png -> DDPM-F64x4/TRAWLER/TRAWLER1148.png
# Processado: TRAWLER1149.png -> DDPM-F64x4/TRAWLER/TRAWLER1149.png
# Processado: TRAWLER115.png -> DDPM-F64x4/TRAWLER/TRAWLER115.png
# Processado: TRAWLER1150.png -> DDPM-F64x4/TRAWLER/TRAWLER1150.png
# Processado: TRAWLER1151.png -> DDPM-F64x4/TRAWLER/TRAWLER1151.png
# Processado: TRAWLER1152.png -> DDPM-F64x4/TRAWLER/TRAWLER1152.png
# Processado: TRAWLER1153.png -> DDPM-F64x4/TRAWLER/TRAWLER1153.png
# Processado: TRAWLER1154.png -> DDPM-F64x4/TRAWLER/TRAWLER1154.png
# Processado: TRAWLER1155.png -> DDPM-F64x4/TRAWLER/TRAWLER1155.png
# Processado: TRAWLER1156.png -> DDPM-F64x4/TRAWLER/TRAWLER1156.png
# Processado: TRAWLER1157.png -> DDPM-F64x4/TRAWLER/TRAWLER1157.png
# Processado: TRAWLER1158.png -> DDPM-F64x4/TRAWLER/TRAWLER1158.png
# Processado: TRAWLER1159.png -> DDPM-F64x4/TRAWLER/TRAWLER1159.png
# Processado: TRAWLER116.png -> DDPM-F64x4/TRAWLER/TRAWLER116.png
# Processado: TRAWLER1160.png -> DDPM-F64x4/TRAWLER/TRAWLER1160.png
# Processado: TRAWLER1161.png -> DDPM-F64x4/TRAWLER/TRAWLER1161.png
# Processado: TRAWLER1162.png -> DDPM-F64x4/TRAWLER/TRAWLER1162.png
# Processado: TRAWLER1163.png -> DDPM-F64x4/TRAWLER/TRAWLER1163.png
# Processado: TRAWLER1164.png -> DDPM-F64x4/TRAWLER/TRAWLER1164.png
# Processado: TRAWLER1165.png -> DDPM-F64x4/TRAWLER/TRAWLER1165.png
# Processado: TRAWLER1166.png -> DDPM-F64x4/TRAWLER/TRAWLER1166.png
# Processado: TRAWLER1167.png -> DDPM-F64x4/TRAWLER/TRAWLER1167.png
# Processado: TRAWLER1168.png -> DDPM-F64x4/TRAWLER/TRAWLER1168.png
# Processado: TRAWLER1169.png -> DDPM-F64x4/TRAWLER/TRAWLER1169.png
# Processado: TRAWLER117.png -> DDPM-F64x4/TRAWLER/TRAWLER117.png
# Processado: TRAWLER1170.png -> DDPM-F64x4/TRAWLER/TRAWLER1170.png
# Processado: TRAWLER1171.png -> DDPM-F64x4/TRAWLER/TRAWLER1171.png
# Processado: TRAWLER1172.png -> DDPM-F64x4/TRAWLER/TRAWLER1172.png
# Processado: TRAWLER1173.png -> DDPM-F64x4/TRAWLER/TRAWLER1173.png
# Processado: TRAWLER1174.png -> DDPM-F64x4/TRAWLER/TRAWLER1174.png
# Processado: TRAWLER1175.png -> DDPM-F64x4/TRAWLER/TRAWLER1175.png
# Processado: TRAWLER1176.png -> DDPM-F64x4/TRAWLER/TRAWLER1176.png
# Processado: TRAWLER1177.png -> DDPM-F64x4/TRAWLER/TRAWLER1177.png
# Processado: TRAWLER1178.png -> DDPM-F64x4/TRAWLER/TRAWLER1178.png
# Processado: TRAWLER1179.png -> DDPM-F64x4/TRAWLER/TRAWLER1179.png
# Processado: TRAWLER118.png -> DDPM-F64x4/TRAWLER/TRAWLER118.png
# Processado: TRAWLER1180.png -> DDPM-F64x4/TRAWLER/TRAWLER1180.png
# Processado: TRAWLER1181.png -> DDPM-F64x4/TRAWLER/TRAWLER1181.png
# Processado: TRAWLER1182.png -> DDPM-F64x4/TRAWLER/TRAWLER1182.png
# Processado: TRAWLER1183.png -> DDPM-F64x4/TRAWLER/TRAWLER1183.png
# Processado: TRAWLER1184.png -> DDPM-F64x4/TRAWLER/TRAWLER1184.png
# Processado: TRAWLER1185.png -> DDPM-F64x4/TRAWLER/TRAWLER1185.png
# Processado: TRAWLER1186.png -> DDPM-F64x4/TRAWLER/TRAWLER1186.png
# Processado: TRAWLER1187.png -> DDPM-F64x4/TRAWLER/TRAWLER1187.png
# Processado: TRAWLER1188.png -> DDPM-F64x4/TRAWLER/TRAWLER1188.png
# Processado: TRAWLER1189.png -> DDPM-F64x4/TRAWLER/TRAWLER1189.png
# Processado: TRAWLER119.png -> DDPM-F64x4/TRAWLER/TRAWLER119.png
# Processado: TRAWLER1190.png -> DDPM-F64x4/TRAWLER/TRAWLER1190.png
# Processado: TRAWLER1191.png -> DDPM-F64x4/TRAWLER/TRAWLER1191.png
# Processado: TRAWLER1192.png -> DDPM-F64x4/TRAWLER/TRAWLER1192.png
# Processado: TRAWLER1193.png -> DDPM-F64x4/TRAWLER/TRAWLER1193.png
# Processado: TRAWLER1194.png -> DDPM-F64x4/TRAWLER/TRAWLER1194.png
# Processado: TRAWLER1195.png -> DDPM-F64x4/TRAWLER/TRAWLER1195.png
# Processado: TRAWLER1196.png -> DDPM-F64x4/TRAWLER/TRAWLER1196.png
# Processado: TRAWLER1197.png -> DDPM-F64x4/TRAWLER/TRAWLER1197.png
# Processado: TRAWLER1198.png -> DDPM-F64x4/TRAWLER/TRAWLER1198.png
# Processado: TRAWLER1199.png -> DDPM-F64x4/TRAWLER/TRAWLER1199.png
# Processado: TRAWLER12.png -> DDPM-F64x4/TRAWLER/TRAWLER12.png
# Processado: TRAWLER120.png -> DDPM-F64x4/TRAWLER/TRAWLER120.png
# Processado: TRAWLER1200.png -> DDPM-F64x4/TRAWLER/TRAWLER1200.png
# Processado: TRAWLER1201.png -> DDPM-F64x4/TRAWLER/TRAWLER1201.png
# Processado: TRAWLER1202.png -> DDPM-F64x4/TRAWLER/TRAWLER1202.png
# Processado: TRAWLER1203.png -> DDPM-F64x4/TRAWLER/TRAWLER1203.png
# Processado: TRAWLER1204.png -> DDPM-F64x4/TRAWLER/TRAWLER1204.png
# Processado: TRAWLER1205.png -> DDPM-F64x4/TRAWLER/TRAWLER1205.png
# Processado: TRAWLER1206.png -> DDPM-F64x4/TRAWLER/TRAWLER1206.png
# Processado: TRAWLER1207.png -> DDPM-F64x4/TRAWLER/TRAWLER1207.png
# Processado: TRAWLER1208.png -> DDPM-F64x4/TRAWLER/TRAWLER1208.png
# Processado: TRAWLER1209.png -> DDPM-F64x4/TRAWLER/TRAWLER1209.png
# Processado: TRAWLER121.png -> DDPM-F64x4/TRAWLER/TRAWLER121.png
# Processado: TRAWLER1210.png -> DDPM-F64x4/TRAWLER/TRAWLER1210.png
# Processado: TRAWLER1211.png -> DDPM-F64x4/TRAWLER/TRAWLER1211.png
# Processado: TRAWLER1212.png -> DDPM-F64x4/TRAWLER/TRAWLER1212.png
# Processado: TRAWLER1213.png -> DDPM-F64x4/TRAWLER/TRAWLER1213.png
# Processado: TRAWLER1214.png -> DDPM-F64x4/TRAWLER/TRAWLER1214.png
# Processado: TRAWLER1215.png -> DDPM-F64x4/TRAWLER/TRAWLER1215.png
# Processado: TRAWLER1216.png -> DDPM-F64x4/TRAWLER/TRAWLER1216.png
# Processado: TRAWLER1217.png -> DDPM-F64x4/TRAWLER/TRAWLER1217.png
# Processado: TRAWLER1218.png -> DDPM-F64x4/TRAWLER/TRAWLER1218.png
# Processado: TRAWLER1219.png -> DDPM-F64x4/TRAWLER/TRAWLER1219.png
# Processado: TRAWLER122.png -> DDPM-F64x4/TRAWLER/TRAWLER122.png
# Processado: TRAWLER1220.png -> DDPM-F64x4/TRAWLER/TRAWLER1220.png
# Processado: TRAWLER1221.png -> DDPM-F64x4/TRAWLER/TRAWLER1221.png
# Processado: TRAWLER1222.png -> DDPM-F64x4/TRAWLER/TRAWLER1222.png
# Processado: TRAWLER1223.png -> DDPM-F64x4/TRAWLER/TRAWLER1223.png
# Processado: TRAWLER1224.png -> DDPM-F64x4/TRAWLER/TRAWLER1224.png
# Processado: TRAWLER1225.png -> DDPM-F64x4/TRAWLER/TRAWLER1225.png
# Processado: TRAWLER1226.png -> DDPM-F64x4/TRAWLER/TRAWLER1226.png
# Processado: TRAWLER1227.png -> DDPM-F64x4/TRAWLER/TRAWLER1227.png
# Processado: TRAWLER1228.png -> DDPM-F64x4/TRAWLER/TRAWLER1228.png
# Processado: TRAWLER1229.png -> DDPM-F64x4/TRAWLER/TRAWLER1229.png
# Processado: TRAWLER123.png -> DDPM-F64x4/TRAWLER/TRAWLER123.png
# Processado: TRAWLER1230.png -> DDPM-F64x4/TRAWLER/TRAWLER1230.png
# Processado: TRAWLER1231.png -> DDPM-F64x4/TRAWLER/TRAWLER1231.png
# Processado: TRAWLER1232.png -> DDPM-F64x4/TRAWLER/TRAWLER1232.png
# Processado: TRAWLER1233.png -> DDPM-F64x4/TRAWLER/TRAWLER1233.png
# Processado: TRAWLER1234.png -> DDPM-F64x4/TRAWLER/TRAWLER1234.png
# Processado: TRAWLER1235.png -> DDPM-F64x4/TRAWLER/TRAWLER1235.png
# Processado: TRAWLER1236.png -> DDPM-F64x4/TRAWLER/TRAWLER1236.png
# Processado: TRAWLER1237.png -> DDPM-F64x4/TRAWLER/TRAWLER1237.png
# Processado: TRAWLER1238.png -> DDPM-F64x4/TRAWLER/TRAWLER1238.png
# Processado: TRAWLER1239.png -> DDPM-F64x4/TRAWLER/TRAWLER1239.png
# Processado: TRAWLER124.png -> DDPM-F64x4/TRAWLER/TRAWLER124.png
# Processado: TRAWLER1240.png -> DDPM-F64x4/TRAWLER/TRAWLER1240.png
# Processado: TRAWLER1241.png -> DDPM-F64x4/TRAWLER/TRAWLER1241.png
# Processado: TRAWLER1242.png -> DDPM-F64x4/TRAWLER/TRAWLER1242.png
# Processado: TRAWLER1243.png -> DDPM-F64x4/TRAWLER/TRAWLER1243.png
# Processado: TRAWLER1244.png -> DDPM-F64x4/TRAWLER/TRAWLER1244.png
# Processado: TRAWLER1245.png -> DDPM-F64x4/TRAWLER/TRAWLER1245.png
# Processado: TRAWLER1246.png -> DDPM-F64x4/TRAWLER/TRAWLER1246.png
# Processado: TRAWLER1247.png -> DDPM-F64x4/TRAWLER/TRAWLER1247.png
# Processado: TRAWLER1248.png -> DDPM-F64x4/TRAWLER/TRAWLER1248.png
# Processado: TRAWLER1249.png -> DDPM-F64x4/TRAWLER/TRAWLER1249.png
# Processado: TRAWLER125.png -> DDPM-F64x4/TRAWLER/TRAWLER125.png
# Processado: TRAWLER1250.png -> DDPM-F64x4/TRAWLER/TRAWLER1250.png
# Processado: TRAWLER1251.png -> DDPM-F64x4/TRAWLER/TRAWLER1251.png
# Processado: TRAWLER1252.png -> DDPM-F64x4/TRAWLER/TRAWLER1252.png
# Processado: TRAWLER1253.png -> DDPM-F64x4/TRAWLER/TRAWLER1253.png
# Processado: TRAWLER1254.png -> DDPM-F64x4/TRAWLER/TRAWLER1254.png
# Processado: TRAWLER1255.png -> DDPM-F64x4/TRAWLER/TRAWLER1255.png
# Processado: TRAWLER1256.png -> DDPM-F64x4/TRAWLER/TRAWLER1256.png
# Processado: TRAWLER1257.png -> DDPM-F64x4/TRAWLER/TRAWLER1257.png
# Processado: TRAWLER1258.png -> DDPM-F64x4/TRAWLER/TRAWLER1258.png
# Processado: TRAWLER1259.png -> DDPM-F64x4/TRAWLER/TRAWLER1259.png
# Processado: TRAWLER126.png -> DDPM-F64x4/TRAWLER/TRAWLER126.png
# Processado: TRAWLER1260.png -> DDPM-F64x4/TRAWLER/TRAWLER1260.png
# Processado: TRAWLER1261.png -> DDPM-F64x4/TRAWLER/TRAWLER1261.png
# Processado: TRAWLER1262.png -> DDPM-F64x4/TRAWLER/TRAWLER1262.png
# Processado: TRAWLER1263.png -> DDPM-F64x4/TRAWLER/TRAWLER1263.png
# Processado: TRAWLER1264.png -> DDPM-F64x4/TRAWLER/TRAWLER1264.png
# Processado: TRAWLER1265.png -> DDPM-F64x4/TRAWLER/TRAWLER1265.png
# Processado: TRAWLER1266.png -> DDPM-F64x4/TRAWLER/TRAWLER1266.png
# Processado: TRAWLER1267.png -> DDPM-F64x4/TRAWLER/TRAWLER1267.png
# Processado: TRAWLER1268.png -> DDPM-F64x4/TRAWLER/TRAWLER1268.png
# Processado: TRAWLER1269.png -> DDPM-F64x4/TRAWLER/TRAWLER1269.png
# Processado: TRAWLER127.png -> DDPM-F64x4/TRAWLER/TRAWLER127.png
# Processado: TRAWLER1270.png -> DDPM-F64x4/TRAWLER/TRAWLER1270.png
# Processado: TRAWLER1271.png -> DDPM-F64x4/TRAWLER/TRAWLER1271.png
# Processado: TRAWLER1272.png -> DDPM-F64x4/TRAWLER/TRAWLER1272.png
# Processado: TRAWLER1273.png -> DDPM-F64x4/TRAWLER/TRAWLER1273.png
# Processado: TRAWLER1274.png -> DDPM-F64x4/TRAWLER/TRAWLER1274.png
# Processado: TRAWLER1275.png -> DDPM-F64x4/TRAWLER/TRAWLER1275.png
# Processado: TRAWLER1276.png -> DDPM-F64x4/TRAWLER/TRAWLER1276.png
# Processado: TRAWLER1277.png -> DDPM-F64x4/TRAWLER/TRAWLER1277.png
# Processado: TRAWLER1278.png -> DDPM-F64x4/TRAWLER/TRAWLER1278.png
# Processado: TRAWLER1279.png -> DDPM-F64x4/TRAWLER/TRAWLER1279.png
# Processado: TRAWLER128.png -> DDPM-F64x4/TRAWLER/TRAWLER128.png
# Processado: TRAWLER1280.png -> DDPM-F64x4/TRAWLER/TRAWLER1280.png
# Processado: TRAWLER1281.png -> DDPM-F64x4/TRAWLER/TRAWLER1281.png
# Processado: TRAWLER1282.png -> DDPM-F64x4/TRAWLER/TRAWLER1282.png
# Processado: TRAWLER1283.png -> DDPM-F64x4/TRAWLER/TRAWLER1283.png
# Processado: TRAWLER1284.png -> DDPM-F64x4/TRAWLER/TRAWLER1284.png
# Processado: TRAWLER1285.png -> DDPM-F64x4/TRAWLER/TRAWLER1285.png
# Processado: TRAWLER1286.png -> DDPM-F64x4/TRAWLER/TRAWLER1286.png
# Processado: TRAWLER1287.png -> DDPM-F64x4/TRAWLER/TRAWLER1287.png
# Processado: TRAWLER1288.png -> DDPM-F64x4/TRAWLER/TRAWLER1288.png
# Processado: TRAWLER1289.png -> DDPM-F64x4/TRAWLER/TRAWLER1289.png
# Processado: TRAWLER129.png -> DDPM-F64x4/TRAWLER/TRAWLER129.png
# Processado: TRAWLER1290.png -> DDPM-F64x4/TRAWLER/TRAWLER1290.png
# Processado: TRAWLER1291.png -> DDPM-F64x4/TRAWLER/TRAWLER1291.png
# Processado: TRAWLER1292.png -> DDPM-F64x4/TRAWLER/TRAWLER1292.png
# Processado: TRAWLER1293.png -> DDPM-F64x4/TRAWLER/TRAWLER1293.png
# Processado: TRAWLER1294.png -> DDPM-F64x4/TRAWLER/TRAWLER1294.png
# Processado: TRAWLER1295.png -> DDPM-F64x4/TRAWLER/TRAWLER1295.png
# Processado: TRAWLER1296.png -> DDPM-F64x4/TRAWLER/TRAWLER1296.png
# Processado: TRAWLER1297.png -> DDPM-F64x4/TRAWLER/TRAWLER1297.png
# Processado: TRAWLER1298.png -> DDPM-F64x4/TRAWLER/TRAWLER1298.png
# Processado: TRAWLER1299.png -> DDPM-F64x4/TRAWLER/TRAWLER1299.png
# Processado: TRAWLER13.png -> DDPM-F64x4/TRAWLER/TRAWLER13.png
# Processado: TRAWLER130.png -> DDPM-F64x4/TRAWLER/TRAWLER130.png
# Processado: TRAWLER1300.png -> DDPM-F64x4/TRAWLER/TRAWLER1300.png
# Processado: TRAWLER1301.png -> DDPM-F64x4/TRAWLER/TRAWLER1301.png
# Processado: TRAWLER1302.png -> DDPM-F64x4/TRAWLER/TRAWLER1302.png
# Processado: TRAWLER1303.png -> DDPM-F64x4/TRAWLER/TRAWLER1303.png
# Processado: TRAWLER1304.png -> DDPM-F64x4/TRAWLER/TRAWLER1304.png
# Processado: TRAWLER1305.png -> DDPM-F64x4/TRAWLER/TRAWLER1305.png
# Processado: TRAWLER1306.png -> DDPM-F64x4/TRAWLER/TRAWLER1306.png
# Processado: TRAWLER1307.png -> DDPM-F64x4/TRAWLER/TRAWLER1307.png
# Processado: TRAWLER1308.png -> DDPM-F64x4/TRAWLER/TRAWLER1308.png
# Processado: TRAWLER1309.png -> DDPM-F64x4/TRAWLER/TRAWLER1309.png
# Processado: TRAWLER131.png -> DDPM-F64x4/TRAWLER/TRAWLER131.png
# Processado: TRAWLER1310.png -> DDPM-F64x4/TRAWLER/TRAWLER1310.png
# Processado: TRAWLER1311.png -> DDPM-F64x4/TRAWLER/TRAWLER1311.png
# Processado: TRAWLER1312.png -> DDPM-F64x4/TRAWLER/TRAWLER1312.png
# Processado: TRAWLER1313.png -> DDPM-F64x4/TRAWLER/TRAWLER1313.png
# Processado: TRAWLER1314.png -> DDPM-F64x4/TRAWLER/TRAWLER1314.png
# Processado: TRAWLER1315.png -> DDPM-F64x4/TRAWLER/TRAWLER1315.png
# Processado: TRAWLER1316.png -> DDPM-F64x4/TRAWLER/TRAWLER1316.png
# Processado: TRAWLER1317.png -> DDPM-F64x4/TRAWLER/TRAWLER1317.png
# Processado: TRAWLER1318.png -> DDPM-F64x4/TRAWLER/TRAWLER1318.png
# Processado: TRAWLER1319.png -> DDPM-F64x4/TRAWLER/TRAWLER1319.png
# Processado: TRAWLER132.png -> DDPM-F64x4/TRAWLER/TRAWLER132.png
# Processado: TRAWLER1320.png -> DDPM-F64x4/TRAWLER/TRAWLER1320.png
# Processado: TRAWLER1321.png -> DDPM-F64x4/TRAWLER/TRAWLER1321.png
# Processado: TRAWLER1322.png -> DDPM-F64x4/TRAWLER/TRAWLER1322.png
# Processado: TRAWLER1323.png -> DDPM-F64x4/TRAWLER/TRAWLER1323.png
# Processado: TRAWLER1324.png -> DDPM-F64x4/TRAWLER/TRAWLER1324.png
# Processado: TRAWLER1325.png -> DDPM-F64x4/TRAWLER/TRAWLER1325.png
# Processado: TRAWLER1326.png -> DDPM-F64x4/TRAWLER/TRAWLER1326.png
# Processado: TRAWLER1327.png -> DDPM-F64x4/TRAWLER/TRAWLER1327.png
# Processado: TRAWLER1328.png -> DDPM-F64x4/TRAWLER/TRAWLER1328.png
# Processado: TRAWLER1329.png -> DDPM-F64x4/TRAWLER/TRAWLER1329.png
# Processado: TRAWLER133.png -> DDPM-F64x4/TRAWLER/TRAWLER133.png
# Processado: TRAWLER1330.png -> DDPM-F64x4/TRAWLER/TRAWLER1330.png
# Processado: TRAWLER1331.png -> DDPM-F64x4/TRAWLER/TRAWLER1331.png
# Processado: TRAWLER1332.png -> DDPM-F64x4/TRAWLER/TRAWLER1332.png
# Processado: TRAWLER1333.png -> DDPM-F64x4/TRAWLER/TRAWLER1333.png
# Processado: TRAWLER1334.png -> DDPM-F64x4/TRAWLER/TRAWLER1334.png
# Processado: TRAWLER1335.png -> DDPM-F64x4/TRAWLER/TRAWLER1335.png
# Processado: TRAWLER1336.png -> DDPM-F64x4/TRAWLER/TRAWLER1336.png
# Processado: TRAWLER1337.png -> DDPM-F64x4/TRAWLER/TRAWLER1337.png
# Processado: TRAWLER1338.png -> DDPM-F64x4/TRAWLER/TRAWLER1338.png
# Processado: TRAWLER1339.png -> DDPM-F64x4/TRAWLER/TRAWLER1339.png
# Processado: TRAWLER134.png -> DDPM-F64x4/TRAWLER/TRAWLER134.png
# Processado: TRAWLER1340.png -> DDPM-F64x4/TRAWLER/TRAWLER1340.png
# Processado: TRAWLER1341.png -> DDPM-F64x4/TRAWLER/TRAWLER1341.png
# Processado: TRAWLER1342.png -> DDPM-F64x4/TRAWLER/TRAWLER1342.png
# Processado: TRAWLER1343.png -> DDPM-F64x4/TRAWLER/TRAWLER1343.png
# Processado: TRAWLER1344.png -> DDPM-F64x4/TRAWLER/TRAWLER1344.png
# Processado: TRAWLER1345.png -> DDPM-F64x4/TRAWLER/TRAWLER1345.png
# Processado: TRAWLER1346.png -> DDPM-F64x4/TRAWLER/TRAWLER1346.png
# Processado: TRAWLER1347.png -> DDPM-F64x4/TRAWLER/TRAWLER1347.png
# Processado: TRAWLER1348.png -> DDPM-F64x4/TRAWLER/TRAWLER1348.png
# Processado: TRAWLER1349.png -> DDPM-F64x4/TRAWLER/TRAWLER1349.png
# Processado: TRAWLER135.png -> DDPM-F64x4/TRAWLER/TRAWLER135.png
# Processado: TRAWLER1350.png -> DDPM-F64x4/TRAWLER/TRAWLER1350.png
# Processado: TRAWLER1351.png -> DDPM-F64x4/TRAWLER/TRAWLER1351.png
# Processado: TRAWLER1352.png -> DDPM-F64x4/TRAWLER/TRAWLER1352.png
# Processado: TRAWLER1353.png -> DDPM-F64x4/TRAWLER/TRAWLER1353.png
# Processado: TRAWLER1354.png -> DDPM-F64x4/TRAWLER/TRAWLER1354.png
# Processado: TRAWLER1355.png -> DDPM-F64x4/TRAWLER/TRAWLER1355.png
# Processado: TRAWLER1356.png -> DDPM-F64x4/TRAWLER/TRAWLER1356.png
# Processado: TRAWLER1357.png -> DDPM-F64x4/TRAWLER/TRAWLER1357.png
# Processado: TRAWLER1358.png -> DDPM-F64x4/TRAWLER/TRAWLER1358.png
# Processado: TRAWLER1359.png -> DDPM-F64x4/TRAWLER/TRAWLER1359.png
# Processado: TRAWLER136.png -> DDPM-F64x4/TRAWLER/TRAWLER136.png
# Processado: TRAWLER1360.png -> DDPM-F64x4/TRAWLER/TRAWLER1360.png
# Processado: TRAWLER1361.png -> DDPM-F64x4/TRAWLER/TRAWLER1361.png
# Processado: TRAWLER1362.png -> DDPM-F64x4/TRAWLER/TRAWLER1362.png
# Processado: TRAWLER1363.png -> DDPM-F64x4/TRAWLER/TRAWLER1363.png
# Processado: TRAWLER1364.png -> DDPM-F64x4/TRAWLER/TRAWLER1364.png
# Processado: TRAWLER1365.png -> DDPM-F64x4/TRAWLER/TRAWLER1365.png
# Processado: TRAWLER1366.png -> DDPM-F64x4/TRAWLER/TRAWLER1366.png
# Processado: TRAWLER1367.png -> DDPM-F64x4/TRAWLER/TRAWLER1367.png
# Processado: TRAWLER1368.png -> DDPM-F64x4/TRAWLER/TRAWLER1368.png
# Processado: TRAWLER1369.png -> DDPM-F64x4/TRAWLER/TRAWLER1369.png
# Processado: TRAWLER137.png -> DDPM-F64x4/TRAWLER/TRAWLER137.png
# Processado: TRAWLER1370.png -> DDPM-F64x4/TRAWLER/TRAWLER1370.png
# Processado: TRAWLER1371.png -> DDPM-F64x4/TRAWLER/TRAWLER1371.png
# Processado: TRAWLER1372.png -> DDPM-F64x4/TRAWLER/TRAWLER1372.png
# Processado: TRAWLER1373.png -> DDPM-F64x4/TRAWLER/TRAWLER1373.png
# Processado: TRAWLER1374.png -> DDPM-F64x4/TRAWLER/TRAWLER1374.png
# Processado: TRAWLER1375.png -> DDPM-F64x4/TRAWLER/TRAWLER1375.png
# Processado: TRAWLER1376.png -> DDPM-F64x4/TRAWLER/TRAWLER1376.png
# Processado: TRAWLER1377.png -> DDPM-F64x4/TRAWLER/TRAWLER1377.png
# Processado: TRAWLER1378.png -> DDPM-F64x4/TRAWLER/TRAWLER1378.png
# Processado: TRAWLER1379.png -> DDPM-F64x4/TRAWLER/TRAWLER1379.png
# Processado: TRAWLER138.png -> DDPM-F64x4/TRAWLER/TRAWLER138.png
# Processado: TRAWLER1380.png -> DDPM-F64x4/TRAWLER/TRAWLER1380.png
# Processado: TRAWLER1381.png -> DDPM-F64x4/TRAWLER/TRAWLER1381.png
# Processado: TRAWLER1382.png -> DDPM-F64x4/TRAWLER/TRAWLER1382.png
# Processado: TRAWLER1383.png -> DDPM-F64x4/TRAWLER/TRAWLER1383.png
# Processado: TRAWLER1384.png -> DDPM-F64x4/TRAWLER/TRAWLER1384.png
# Processado: TRAWLER1385.png -> DDPM-F64x4/TRAWLER/TRAWLER1385.png
# Processado: TRAWLER1386.png -> DDPM-F64x4/TRAWLER/TRAWLER1386.png
# Processado: TRAWLER1387.png -> DDPM-F64x4/TRAWLER/TRAWLER1387.png
# Processado: TRAWLER1388.png -> DDPM-F64x4/TRAWLER/TRAWLER1388.png
# Processado: TRAWLER1389.png -> DDPM-F64x4/TRAWLER/TRAWLER1389.png
# Processado: TRAWLER139.png -> DDPM-F64x4/TRAWLER/TRAWLER139.png
# Processado: TRAWLER1390.png -> DDPM-F64x4/TRAWLER/TRAWLER1390.png
# Processado: TRAWLER1391.png -> DDPM-F64x4/TRAWLER/TRAWLER1391.png
# Processado: TRAWLER1392.png -> DDPM-F64x4/TRAWLER/TRAWLER1392.png
# Processado: TRAWLER1393.png -> DDPM-F64x4/TRAWLER/TRAWLER1393.png
# Processado: TRAWLER1394.png -> DDPM-F64x4/TRAWLER/TRAWLER1394.png
# Processado: TRAWLER1395.png -> DDPM-F64x4/TRAWLER/TRAWLER1395.png
# Processado: TRAWLER1396.png -> DDPM-F64x4/TRAWLER/TRAWLER1396.png
# Processado: TRAWLER1397.png -> DDPM-F64x4/TRAWLER/TRAWLER1397.png
# Processado: TRAWLER1398.png -> DDPM-F64x4/TRAWLER/TRAWLER1398.png
# Processado: TRAWLER1399.png -> DDPM-F64x4/TRAWLER/TRAWLER1399.png
# Processado: TRAWLER14.png -> DDPM-F64x4/TRAWLER/TRAWLER14.png
# Processado: TRAWLER140.png -> DDPM-F64x4/TRAWLER/TRAWLER140.png
# Processado: TRAWLER1400.png -> DDPM-F64x4/TRAWLER/TRAWLER1400.png
# Processado: TRAWLER1401.png -> DDPM-F64x4/TRAWLER/TRAWLER1401.png
# Processado: TRAWLER1402.png -> DDPM-F64x4/TRAWLER/TRAWLER1402.png
# Processado: TRAWLER1403.png -> DDPM-F64x4/TRAWLER/TRAWLER1403.png
# Processado: TRAWLER1404.png -> DDPM-F64x4/TRAWLER/TRAWLER1404.png
# Processado: TRAWLER1405.png -> DDPM-F64x4/TRAWLER/TRAWLER1405.png
# Processado: TRAWLER1406.png -> DDPM-F64x4/TRAWLER/TRAWLER1406.png
# Processado: TRAWLER1407.png -> DDPM-F64x4/TRAWLER/TRAWLER1407.png
# Processado: TRAWLER1408.png -> DDPM-F64x4/TRAWLER/TRAWLER1408.png
# Processado: TRAWLER1409.png -> DDPM-F64x4/TRAWLER/TRAWLER1409.png
# Processado: TRAWLER141.png -> DDPM-F64x4/TRAWLER/TRAWLER141.png
# Processado: TRAWLER1410.png -> DDPM-F64x4/TRAWLER/TRAWLER1410.png
# Processado: TRAWLER1411.png -> DDPM-F64x4/TRAWLER/TRAWLER1411.png
# Processado: TRAWLER1412.png -> DDPM-F64x4/TRAWLER/TRAWLER1412.png
# Processado: TRAWLER1413.png -> DDPM-F64x4/TRAWLER/TRAWLER1413.png
# Processado: TRAWLER1414.png -> DDPM-F64x4/TRAWLER/TRAWLER1414.png
# Processado: TRAWLER1415.png -> DDPM-F64x4/TRAWLER/TRAWLER1415.png
# Processado: TRAWLER1416.png -> DDPM-F64x4/TRAWLER/TRAWLER1416.png
# Processado: TRAWLER1417.png -> DDPM-F64x4/TRAWLER/TRAWLER1417.png
# Processado: TRAWLER1418.png -> DDPM-F64x4/TRAWLER/TRAWLER1418.png
# Processado: TRAWLER1419.png -> DDPM-F64x4/TRAWLER/TRAWLER1419.png
# Processado: TRAWLER142.png -> DDPM-F64x4/TRAWLER/TRAWLER142.png
# Processado: TRAWLER1420.png -> DDPM-F64x4/TRAWLER/TRAWLER1420.png
# Processado: TRAWLER1421.png -> DDPM-F64x4/TRAWLER/TRAWLER1421.png
# Processado: TRAWLER1422.png -> DDPM-F64x4/TRAWLER/TRAWLER1422.png
# Processado: TRAWLER1423.png -> DDPM-F64x4/TRAWLER/TRAWLER1423.png
# Processado: TRAWLER1424.png -> DDPM-F64x4/TRAWLER/TRAWLER1424.png
# Processado: TRAWLER1425.png -> DDPM-F64x4/TRAWLER/TRAWLER1425.png
# Processado: TRAWLER1426.png -> DDPM-F64x4/TRAWLER/TRAWLER1426.png
# Processado: TRAWLER1427.png -> DDPM-F64x4/TRAWLER/TRAWLER1427.png
# Processado: TRAWLER1428.png -> DDPM-F64x4/TRAWLER/TRAWLER1428.png
# Processado: TRAWLER1429.png -> DDPM-F64x4/TRAWLER/TRAWLER1429.png
# Processado: TRAWLER143.png -> DDPM-F64x4/TRAWLER/TRAWLER143.png
# Processado: TRAWLER1430.png -> DDPM-F64x4/TRAWLER/TRAWLER1430.png
# Processado: TRAWLER1431.png -> DDPM-F64x4/TRAWLER/TRAWLER1431.png
# Processado: TRAWLER1432.png -> DDPM-F64x4/TRAWLER/TRAWLER1432.png
# Processado: TRAWLER1433.png -> DDPM-F64x4/TRAWLER/TRAWLER1433.png
# Processado: TRAWLER1434.png -> DDPM-F64x4/TRAWLER/TRAWLER1434.png
# Processado: TRAWLER1435.png -> DDPM-F64x4/TRAWLER/TRAWLER1435.png
# Processado: TRAWLER1436.png -> DDPM-F64x4/TRAWLER/TRAWLER1436.png
# Processado: TRAWLER1437.png -> DDPM-F64x4/TRAWLER/TRAWLER1437.png
# Processado: TRAWLER1438.png -> DDPM-F64x4/TRAWLER/TRAWLER1438.png
# Processado: TRAWLER1439.png -> DDPM-F64x4/TRAWLER/TRAWLER1439.png
# Processado: TRAWLER144.png -> DDPM-F64x4/TRAWLER/TRAWLER144.png
# Processado: TRAWLER1440.png -> DDPM-F64x4/TRAWLER/TRAWLER1440.png
# Processado: TRAWLER1441.png -> DDPM-F64x4/TRAWLER/TRAWLER1441.png
# Processado: TRAWLER1442.png -> DDPM-F64x4/TRAWLER/TRAWLER1442.png
# Processado: TRAWLER1443.png -> DDPM-F64x4/TRAWLER/TRAWLER1443.png
# Processado: TRAWLER1444.png -> DDPM-F64x4/TRAWLER/TRAWLER1444.png
# Processado: TRAWLER1445.png -> DDPM-F64x4/TRAWLER/TRAWLER1445.png
# Processado: TRAWLER1446.png -> DDPM-F64x4/TRAWLER/TRAWLER1446.png
# Processado: TRAWLER1447.png -> DDPM-F64x4/TRAWLER/TRAWLER1447.png
# Processado: TRAWLER1448.png -> DDPM-F64x4/TRAWLER/TRAWLER1448.png
# Processado: TRAWLER1449.png -> DDPM-F64x4/TRAWLER/TRAWLER1449.png
# Processado: TRAWLER145.png -> DDPM-F64x4/TRAWLER/TRAWLER145.png
# Processado: TRAWLER1450.png -> DDPM-F64x4/TRAWLER/TRAWLER1450.png
# Processado: TRAWLER1451.png -> DDPM-F64x4/TRAWLER/TRAWLER1451.png
# Processado: TRAWLER1452.png -> DDPM-F64x4/TRAWLER/TRAWLER1452.png
# Processado: TRAWLER1453.png -> DDPM-F64x4/TRAWLER/TRAWLER1453.png
# Processado: TRAWLER1454.png -> DDPM-F64x4/TRAWLER/TRAWLER1454.png
# Processado: TRAWLER1455.png -> DDPM-F64x4/TRAWLER/TRAWLER1455.png
# Processado: TRAWLER1456.png -> DDPM-F64x4/TRAWLER/TRAWLER1456.png
# Processado: TRAWLER1457.png -> DDPM-F64x4/TRAWLER/TRAWLER1457.png
# Processado: TRAWLER1458.png -> DDPM-F64x4/TRAWLER/TRAWLER1458.png
# Processado: TRAWLER1459.png -> DDPM-F64x4/TRAWLER/TRAWLER1459.png
# Processado: TRAWLER146.png -> DDPM-F64x4/TRAWLER/TRAWLER146.png
# Processado: TRAWLER1460.png -> DDPM-F64x4/TRAWLER/TRAWLER1460.png
# Processado: TRAWLER1461.png -> DDPM-F64x4/TRAWLER/TRAWLER1461.png
# Processado: TRAWLER1462.png -> DDPM-F64x4/TRAWLER/TRAWLER1462.png
# Processado: TRAWLER1463.png -> DDPM-F64x4/TRAWLER/TRAWLER1463.png
# Processado: TRAWLER1464.png -> DDPM-F64x4/TRAWLER/TRAWLER1464.png
# Processado: TRAWLER1465.png -> DDPM-F64x4/TRAWLER/TRAWLER1465.png
# Processado: TRAWLER1466.png -> DDPM-F64x4/TRAWLER/TRAWLER1466.png
# Processado: TRAWLER1467.png -> DDPM-F64x4/TRAWLER/TRAWLER1467.png
# Processado: TRAWLER1468.png -> DDPM-F64x4/TRAWLER/TRAWLER1468.png
# Processado: TRAWLER1469.png -> DDPM-F64x4/TRAWLER/TRAWLER1469.png
# Processado: TRAWLER147.png -> DDPM-F64x4/TRAWLER/TRAWLER147.png
# Processado: TRAWLER1470.png -> DDPM-F64x4/TRAWLER/TRAWLER1470.png
# Processado: TRAWLER1471.png -> DDPM-F64x4/TRAWLER/TRAWLER1471.png
# Processado: TRAWLER1472.png -> DDPM-F64x4/TRAWLER/TRAWLER1472.png
# Processado: TRAWLER1473.png -> DDPM-F64x4/TRAWLER/TRAWLER1473.png
# Processado: TRAWLER1474.png -> DDPM-F64x4/TRAWLER/TRAWLER1474.png
# Processado: TRAWLER1475.png -> DDPM-F64x4/TRAWLER/TRAWLER1475.png
# Processado: TRAWLER1476.png -> DDPM-F64x4/TRAWLER/TRAWLER1476.png
# Processado: TRAWLER1477.png -> DDPM-F64x4/TRAWLER/TRAWLER1477.png
# Processado: TRAWLER1478.png -> DDPM-F64x4/TRAWLER/TRAWLER1478.png
# Processado: TRAWLER1479.png -> DDPM-F64x4/TRAWLER/TRAWLER1479.png
# Processado: TRAWLER148.png -> DDPM-F64x4/TRAWLER/TRAWLER148.png
# Processado: TRAWLER1480.png -> DDPM-F64x4/TRAWLER/TRAWLER1480.png
# Processado: TRAWLER1481.png -> DDPM-F64x4/TRAWLER/TRAWLER1481.png
# Processado: TRAWLER1482.png -> DDPM-F64x4/TRAWLER/TRAWLER1482.png
# Processado: TRAWLER1483.png -> DDPM-F64x4/TRAWLER/TRAWLER1483.png
# Processado: TRAWLER1484.png -> DDPM-F64x4/TRAWLER/TRAWLER1484.png
# Processado: TRAWLER1485.png -> DDPM-F64x4/TRAWLER/TRAWLER1485.png
# Processado: TRAWLER1486.png -> DDPM-F64x4/TRAWLER/TRAWLER1486.png
# Processado: TRAWLER1487.png -> DDPM-F64x4/TRAWLER/TRAWLER1487.png
# Processado: TRAWLER1488.png -> DDPM-F64x4/TRAWLER/TRAWLER1488.png
# Processado: TRAWLER1489.png -> DDPM-F64x4/TRAWLER/TRAWLER1489.png
# Processado: TRAWLER149.png -> DDPM-F64x4/TRAWLER/TRAWLER149.png
# Processado: TRAWLER1490.png -> DDPM-F64x4/TRAWLER/TRAWLER1490.png
# Processado: TRAWLER1491.png -> DDPM-F64x4/TRAWLER/TRAWLER1491.png
# Processado: TRAWLER1492.png -> DDPM-F64x4/TRAWLER/TRAWLER1492.png
# Processado: TRAWLER1493.png -> DDPM-F64x4/TRAWLER/TRAWLER1493.png
# Processado: TRAWLER1494.png -> DDPM-F64x4/TRAWLER/TRAWLER1494.png
# Processado: TRAWLER1495.png -> DDPM-F64x4/TRAWLER/TRAWLER1495.png
# Processado: TRAWLER1496.png -> DDPM-F64x4/TRAWLER/TRAWLER1496.png
# Processado: TRAWLER1497.png -> DDPM-F64x4/TRAWLER/TRAWLER1497.png
# Processado: TRAWLER1498.png -> DDPM-F64x4/TRAWLER/TRAWLER1498.png
# Processado: TRAWLER1499.png -> DDPM-F64x4/TRAWLER/TRAWLER1499.png
# Processado: TRAWLER15.png -> DDPM-F64x4/TRAWLER/TRAWLER15.png
# Processado: TRAWLER150.png -> DDPM-F64x4/TRAWLER/TRAWLER150.png
# Processado: TRAWLER1500.png -> DDPM-F64x4/TRAWLER/TRAWLER1500.png
# Processado: TRAWLER1501.png -> DDPM-F64x4/TRAWLER/TRAWLER1501.png
# Processado: TRAWLER1502.png -> DDPM-F64x4/TRAWLER/TRAWLER1502.png
# Processado: TRAWLER1503.png -> DDPM-F64x4/TRAWLER/TRAWLER1503.png
# Processado: TRAWLER1504.png -> DDPM-F64x4/TRAWLER/TRAWLER1504.png
# Processado: TRAWLER1505.png -> DDPM-F64x4/TRAWLER/TRAWLER1505.png
# Processado: TRAWLER1506.png -> DDPM-F64x4/TRAWLER/TRAWLER1506.png
# Processado: TRAWLER1507.png -> DDPM-F64x4/TRAWLER/TRAWLER1507.png
# Processado: TRAWLER1508.png -> DDPM-F64x4/TRAWLER/TRAWLER1508.png
# Processado: TRAWLER1509.png -> DDPM-F64x4/TRAWLER/TRAWLER1509.png
# Processado: TRAWLER151.png -> DDPM-F64x4/TRAWLER/TRAWLER151.png
# Processado: TRAWLER1510.png -> DDPM-F64x4/TRAWLER/TRAWLER1510.png
# Processado: TRAWLER1511.png -> DDPM-F64x4/TRAWLER/TRAWLER1511.png
# Processado: TRAWLER1512.png -> DDPM-F64x4/TRAWLER/TRAWLER1512.png
# Processado: TRAWLER1513.png -> DDPM-F64x4/TRAWLER/TRAWLER1513.png
# Processado: TRAWLER1514.png -> DDPM-F64x4/TRAWLER/TRAWLER1514.png
# Processado: TRAWLER1515.png -> DDPM-F64x4/TRAWLER/TRAWLER1515.png
# Processado: TRAWLER1516.png -> DDPM-F64x4/TRAWLER/TRAWLER1516.png
# Processado: TRAWLER1517.png -> DDPM-F64x4/TRAWLER/TRAWLER1517.png
# Processado: TRAWLER1518.png -> DDPM-F64x4/TRAWLER/TRAWLER1518.png
# Processado: TRAWLER1519.png -> DDPM-F64x4/TRAWLER/TRAWLER1519.png
# Processado: TRAWLER152.png -> DDPM-F64x4/TRAWLER/TRAWLER152.png
# Processado: TRAWLER1520.png -> DDPM-F64x4/TRAWLER/TRAWLER1520.png
# Processado: TRAWLER1521.png -> DDPM-F64x4/TRAWLER/TRAWLER1521.png
# Processado: TRAWLER1522.png -> DDPM-F64x4/TRAWLER/TRAWLER1522.png
# Processado: TRAWLER1523.png -> DDPM-F64x4/TRAWLER/TRAWLER1523.png
# Processado: TRAWLER1524.png -> DDPM-F64x4/TRAWLER/TRAWLER1524.png
# Processado: TRAWLER1525.png -> DDPM-F64x4/TRAWLER/TRAWLER1525.png
# Processado: TRAWLER1526.png -> DDPM-F64x4/TRAWLER/TRAWLER1526.png
# Processado: TRAWLER1527.png -> DDPM-F64x4/TRAWLER/TRAWLER1527.png
# Processado: TRAWLER1528.png -> DDPM-F64x4/TRAWLER/TRAWLER1528.png
# Processado: TRAWLER1529.png -> DDPM-F64x4/TRAWLER/TRAWLER1529.png
# Processado: TRAWLER153.png -> DDPM-F64x4/TRAWLER/TRAWLER153.png
# Processado: TRAWLER1530.png -> DDPM-F64x4/TRAWLER/TRAWLER1530.png
# Processado: TRAWLER1531.png -> DDPM-F64x4/TRAWLER/TRAWLER1531.png
# Processado: TRAWLER1532.png -> DDPM-F64x4/TRAWLER/TRAWLER1532.png
# Processado: TRAWLER1533.png -> DDPM-F64x4/TRAWLER/TRAWLER1533.png
# Processado: TRAWLER1534.png -> DDPM-F64x4/TRAWLER/TRAWLER1534.png
# Processado: TRAWLER1535.png -> DDPM-F64x4/TRAWLER/TRAWLER1535.png
# Processado: TRAWLER1536.png -> DDPM-F64x4/TRAWLER/TRAWLER1536.png
# Processado: TRAWLER1537.png -> DDPM-F64x4/TRAWLER/TRAWLER1537.png
# Processado: TRAWLER1538.png -> DDPM-F64x4/TRAWLER/TRAWLER1538.png
# Processado: TRAWLER1539.png -> DDPM-F64x4/TRAWLER/TRAWLER1539.png
# Processado: TRAWLER154.png -> DDPM-F64x4/TRAWLER/TRAWLER154.png
# Processado: TRAWLER1540.png -> DDPM-F64x4/TRAWLER/TRAWLER1540.png
# Processado: TRAWLER1541.png -> DDPM-F64x4/TRAWLER/TRAWLER1541.png
# Processado: TRAWLER1542.png -> DDPM-F64x4/TRAWLER/TRAWLER1542.png
# Processado: TRAWLER1543.png -> DDPM-F64x4/TRAWLER/TRAWLER1543.png
# Processado: TRAWLER1544.png -> DDPM-F64x4/TRAWLER/TRAWLER1544.png
# Processado: TRAWLER1545.png -> DDPM-F64x4/TRAWLER/TRAWLER1545.png
# Processado: TRAWLER1546.png -> DDPM-F64x4/TRAWLER/TRAWLER1546.png
# Processado: TRAWLER1547.png -> DDPM-F64x4/TRAWLER/TRAWLER1547.png
# Processado: TRAWLER1548.png -> DDPM-F64x4/TRAWLER/TRAWLER1548.png
# Processado: TRAWLER1549.png -> DDPM-F64x4/TRAWLER/TRAWLER1549.png
# Processado: TRAWLER155.png -> DDPM-F64x4/TRAWLER/TRAWLER155.png
# Processado: TRAWLER1550.png -> DDPM-F64x4/TRAWLER/TRAWLER1550.png
# Processado: TRAWLER1551.png -> DDPM-F64x4/TRAWLER/TRAWLER1551.png
# Processado: TRAWLER1552.png -> DDPM-F64x4/TRAWLER/TRAWLER1552.png
# Processado: TRAWLER1553.png -> DDPM-F64x4/TRAWLER/TRAWLER1553.png
# Processado: TRAWLER1554.png -> DDPM-F64x4/TRAWLER/TRAWLER1554.png
# Processado: TRAWLER1555.png -> DDPM-F64x4/TRAWLER/TRAWLER1555.png
# Processado: TRAWLER1556.png -> DDPM-F64x4/TRAWLER/TRAWLER1556.png
# Processado: TRAWLER1557.png -> DDPM-F64x4/TRAWLER/TRAWLER1557.png
# Processado: TRAWLER1558.png -> DDPM-F64x4/TRAWLER/TRAWLER1558.png
# Processado: TRAWLER1559.png -> DDPM-F64x4/TRAWLER/TRAWLER1559.png
# Processado: TRAWLER156.png -> DDPM-F64x4/TRAWLER/TRAWLER156.png
# Processado: TRAWLER1560.png -> DDPM-F64x4/TRAWLER/TRAWLER1560.png
# Processado: TRAWLER1561.png -> DDPM-F64x4/TRAWLER/TRAWLER1561.png
# Processado: TRAWLER1562.png -> DDPM-F64x4/TRAWLER/TRAWLER1562.png
# Processado: TRAWLER1563.png -> DDPM-F64x4/TRAWLER/TRAWLER1563.png
# Processado: TRAWLER1564.png -> DDPM-F64x4/TRAWLER/TRAWLER1564.png
# Processado: TRAWLER1565.png -> DDPM-F64x4/TRAWLER/TRAWLER1565.png
# Processado: TRAWLER1566.png -> DDPM-F64x4/TRAWLER/TRAWLER1566.png
# Processado: TRAWLER1567.png -> DDPM-F64x4/TRAWLER/TRAWLER1567.png
# Processado: TRAWLER1568.png -> DDPM-F64x4/TRAWLER/TRAWLER1568.png
# Processado: TRAWLER1569.png -> DDPM-F64x4/TRAWLER/TRAWLER1569.png
# Processado: TRAWLER157.png -> DDPM-F64x4/TRAWLER/TRAWLER157.png
# Processado: TRAWLER1570.png -> DDPM-F64x4/TRAWLER/TRAWLER1570.png
# Processado: TRAWLER1571.png -> DDPM-F64x4/TRAWLER/TRAWLER1571.png
# Processado: TRAWLER1572.png -> DDPM-F64x4/TRAWLER/TRAWLER1572.png
# Processado: TRAWLER1573.png -> DDPM-F64x4/TRAWLER/TRAWLER1573.png
# Processado: TRAWLER1574.png -> DDPM-F64x4/TRAWLER/TRAWLER1574.png
# Processado: TRAWLER1575.png -> DDPM-F64x4/TRAWLER/TRAWLER1575.png
# Processado: TRAWLER1576.png -> DDPM-F64x4/TRAWLER/TRAWLER1576.png
# Processado: TRAWLER1577.png -> DDPM-F64x4/TRAWLER/TRAWLER1577.png
# Processado: TRAWLER1578.png -> DDPM-F64x4/TRAWLER/TRAWLER1578.png
# Processado: TRAWLER1579.png -> DDPM-F64x4/TRAWLER/TRAWLER1579.png
# Processado: TRAWLER158.png -> DDPM-F64x4/TRAWLER/TRAWLER158.png
# Processado: TRAWLER1580.png -> DDPM-F64x4/TRAWLER/TRAWLER1580.png
# Processado: TRAWLER1581.png -> DDPM-F64x4/TRAWLER/TRAWLER1581.png
# Processado: TRAWLER1582.png -> DDPM-F64x4/TRAWLER/TRAWLER1582.png
# Processado: TRAWLER1583.png -> DDPM-F64x4/TRAWLER/TRAWLER1583.png
# Processado: TRAWLER1584.png -> DDPM-F64x4/TRAWLER/TRAWLER1584.png
# Processado: TRAWLER1585.png -> DDPM-F64x4/TRAWLER/TRAWLER1585.png
# Processado: TRAWLER1586.png -> DDPM-F64x4/TRAWLER/TRAWLER1586.png
# Processado: TRAWLER1587.png -> DDPM-F64x4/TRAWLER/TRAWLER1587.png
# Processado: TRAWLER1588.png -> DDPM-F64x4/TRAWLER/TRAWLER1588.png
# Processado: TRAWLER1589.png -> DDPM-F64x4/TRAWLER/TRAWLER1589.png
# Processado: TRAWLER159.png -> DDPM-F64x4/TRAWLER/TRAWLER159.png
# Processado: TRAWLER1590.png -> DDPM-F64x4/TRAWLER/TRAWLER1590.png
# Processado: TRAWLER1591.png -> DDPM-F64x4/TRAWLER/TRAWLER1591.png
# Processado: TRAWLER1592.png -> DDPM-F64x4/TRAWLER/TRAWLER1592.png
# Processado: TRAWLER1593.png -> DDPM-F64x4/TRAWLER/TRAWLER1593.png
# Processado: TRAWLER1594.png -> DDPM-F64x4/TRAWLER/TRAWLER1594.png
# Processado: TRAWLER1595.png -> DDPM-F64x4/TRAWLER/TRAWLER1595.png
# Processado: TRAWLER1596.png -> DDPM-F64x4/TRAWLER/TRAWLER1596.png
# Processado: TRAWLER1597.png -> DDPM-F64x4/TRAWLER/TRAWLER1597.png
# Processado: TRAWLER1598.png -> DDPM-F64x4/TRAWLER/TRAWLER1598.png
# Processado: TRAWLER1599.png -> DDPM-F64x4/TRAWLER/TRAWLER1599.png
# Processado: TRAWLER16.png -> DDPM-F64x4/TRAWLER/TRAWLER16.png
# Processado: TRAWLER160.png -> DDPM-F64x4/TRAWLER/TRAWLER160.png
# Processado: TRAWLER1600.png -> DDPM-F64x4/TRAWLER/TRAWLER1600.png
# Processado: TRAWLER1601.png -> DDPM-F64x4/TRAWLER/TRAWLER1601.png
# Processado: TRAWLER1602.png -> DDPM-F64x4/TRAWLER/TRAWLER1602.png
# Processado: TRAWLER1603.png -> DDPM-F64x4/TRAWLER/TRAWLER1603.png
# Processado: TRAWLER1604.png -> DDPM-F64x4/TRAWLER/TRAWLER1604.png
# Processado: TRAWLER1605.png -> DDPM-F64x4/TRAWLER/TRAWLER1605.png
# Processado: TRAWLER1606.png -> DDPM-F64x4/TRAWLER/TRAWLER1606.png
# Processado: TRAWLER1607.png -> DDPM-F64x4/TRAWLER/TRAWLER1607.png
# Processado: TRAWLER1608.png -> DDPM-F64x4/TRAWLER/TRAWLER1608.png
# Processado: TRAWLER1609.png -> DDPM-F64x4/TRAWLER/TRAWLER1609.png
# Processado: TRAWLER161.png -> DDPM-F64x4/TRAWLER/TRAWLER161.png
# Processado: TRAWLER1610.png -> DDPM-F64x4/TRAWLER/TRAWLER1610.png
# Processado: TRAWLER1611.png -> DDPM-F64x4/TRAWLER/TRAWLER1611.png
# Processado: TRAWLER1612.png -> DDPM-F64x4/TRAWLER/TRAWLER1612.png
# Processado: TRAWLER1613.png -> DDPM-F64x4/TRAWLER/TRAWLER1613.png
# Processado: TRAWLER1614.png -> DDPM-F64x4/TRAWLER/TRAWLER1614.png
# Processado: TRAWLER1615.png -> DDPM-F64x4/TRAWLER/TRAWLER1615.png
# Processado: TRAWLER1616.png -> DDPM-F64x4/TRAWLER/TRAWLER1616.png
# Processado: TRAWLER1617.png -> DDPM-F64x4/TRAWLER/TRAWLER1617.png
# Processado: TRAWLER1618.png -> DDPM-F64x4/TRAWLER/TRAWLER1618.png
# Processado: TRAWLER1619.png -> DDPM-F64x4/TRAWLER/TRAWLER1619.png
# Processado: TRAWLER162.png -> DDPM-F64x4/TRAWLER/TRAWLER162.png
# Processado: TRAWLER1620.png -> DDPM-F64x4/TRAWLER/TRAWLER1620.png
# Processado: TRAWLER1621.png -> DDPM-F64x4/TRAWLER/TRAWLER1621.png
# Processado: TRAWLER1622.png -> DDPM-F64x4/TRAWLER/TRAWLER1622.png
# Processado: TRAWLER1623.png -> DDPM-F64x4/TRAWLER/TRAWLER1623.png
# Processado: TRAWLER1624.png -> DDPM-F64x4/TRAWLER/TRAWLER1624.png
# Processado: TRAWLER1625.png -> DDPM-F64x4/TRAWLER/TRAWLER1625.png
# Processado: TRAWLER1626.png -> DDPM-F64x4/TRAWLER/TRAWLER1626.png
# Processado: TRAWLER1627.png -> DDPM-F64x4/TRAWLER/TRAWLER1627.png
# Processado: TRAWLER1628.png -> DDPM-F64x4/TRAWLER/TRAWLER1628.png
# Processado: TRAWLER1629.png -> DDPM-F64x4/TRAWLER/TRAWLER1629.png
# Processado: TRAWLER163.png -> DDPM-F64x4/TRAWLER/TRAWLER163.png
# Processado: TRAWLER1630.png -> DDPM-F64x4/TRAWLER/TRAWLER1630.png
# Processado: TRAWLER1631.png -> DDPM-F64x4/TRAWLER/TRAWLER1631.png
# Processado: TRAWLER1632.png -> DDPM-F64x4/TRAWLER/TRAWLER1632.png
# Processado: TRAWLER1633.png -> DDPM-F64x4/TRAWLER/TRAWLER1633.png
# Processado: TRAWLER1634.png -> DDPM-F64x4/TRAWLER/TRAWLER1634.png
# Processado: TRAWLER1635.png -> DDPM-F64x4/TRAWLER/TRAWLER1635.png
# Processado: TRAWLER1636.png -> DDPM-F64x4/TRAWLER/TRAWLER1636.png
# Processado: TRAWLER1637.png -> DDPM-F64x4/TRAWLER/TRAWLER1637.png
# Processado: TRAWLER1638.png -> DDPM-F64x4/TRAWLER/TRAWLER1638.png
# Processado: TRAWLER1639.png -> DDPM-F64x4/TRAWLER/TRAWLER1639.png
# Processado: TRAWLER164.png -> DDPM-F64x4/TRAWLER/TRAWLER164.png
# Processado: TRAWLER1640.png -> DDPM-F64x4/TRAWLER/TRAWLER1640.png
# Processado: TRAWLER1641.png -> DDPM-F64x4/TRAWLER/TRAWLER1641.png
# Processado: TRAWLER1642.png -> DDPM-F64x4/TRAWLER/TRAWLER1642.png
# Processado: TRAWLER1643.png -> DDPM-F64x4/TRAWLER/TRAWLER1643.png
# Processado: TRAWLER1644.png -> DDPM-F64x4/TRAWLER/TRAWLER1644.png
# Processado: TRAWLER1645.png -> DDPM-F64x4/TRAWLER/TRAWLER1645.png
# Processado: TRAWLER1646.png -> DDPM-F64x4/TRAWLER/TRAWLER1646.png
# Processado: TRAWLER1647.png -> DDPM-F64x4/TRAWLER/TRAWLER1647.png
# Processado: TRAWLER1648.png -> DDPM-F64x4/TRAWLER/TRAWLER1648.png
# Processado: TRAWLER1649.png -> DDPM-F64x4/TRAWLER/TRAWLER1649.png
# Processado: TRAWLER165.png -> DDPM-F64x4/TRAWLER/TRAWLER165.png
# Processado: TRAWLER1650.png -> DDPM-F64x4/TRAWLER/TRAWLER1650.png
# Processado: TRAWLER1651.png -> DDPM-F64x4/TRAWLER/TRAWLER1651.png
# Processado: TRAWLER1652.png -> DDPM-F64x4/TRAWLER/TRAWLER1652.png
# Processado: TRAWLER1653.png -> DDPM-F64x4/TRAWLER/TRAWLER1653.png
# ...
# Processado: TRAWLER774.png -> DDPM-F64x4/TRAWLER/TRAWLER774.png
# Processado: TRAWLER775.png -> DDPM-F64x4/TRAWLER/TRAWLER775.png
# Processado: TRAWLER776.png -> DDPM-F64x4/TRAWLER/TRAWLER776.png
# Processado: TRAWLER777.png -> DDPM-F64x4/TRAWLER/TRAWLER777.png
# Processado: TRAWLER778.png -> DDPM-F64x4/TRAWLER/TRAWLER778.png
# Processado: TRAWLER779.png -> DDPM-F64x4/TRAWLER/TRAWLER779.png
# Processado: TRAWLER78.png -> DDPM-F64x4/TRAWLER/TRAWLER78.png
# Processado: TRAWLER780.png -> DDPM-F64x4/TRAWLER/TRAWLER780.png
# Processado: TRAWLER781.png -> DDPM-F64x4/TRAWLER/TRAWLER781.png
# Processado: TRAWLER782.png -> DDPM-F64x4/TRAWLER/TRAWLER782.png
# Processado: TRAWLER783.png -> DDPM-F64x4/TRAWLER/TRAWLER783.png
# Processado: TRAWLER784.png -> DDPM-F64x4/TRAWLER/TRAWLER784.png
# Processado: TRAWLER785.png -> DDPM-F64x4/TRAWLER/TRAWLER785.png
# Processado: TRAWLER786.png -> DDPM-F64x4/TRAWLER/TRAWLER786.png
# Processado: TRAWLER787.png -> DDPM-F64x4/TRAWLER/TRAWLER787.png
# Processado: TRAWLER788.png -> DDPM-F64x4/TRAWLER/TRAWLER788.png
# Processado: TRAWLER789.png -> DDPM-F64x4/TRAWLER/TRAWLER789.png
# Processado: TRAWLER79.png -> DDPM-F64x4/TRAWLER/TRAWLER79.png
# Processado: TRAWLER790.png -> DDPM-F64x4/TRAWLER/TRAWLER790.png
# Processado: TRAWLER791.png -> DDPM-F64x4/TRAWLER/TRAWLER791.png
# Processado: TRAWLER792.png -> DDPM-F64x4/TRAWLER/TRAWLER792.png
# Processado: TRAWLER793.png -> DDPM-F64x4/TRAWLER/TRAWLER793.png
# Processado: TRAWLER794.png -> DDPM-F64x4/TRAWLER/TRAWLER794.png
# Processado: TRAWLER795.png -> DDPM-F64x4/TRAWLER/TRAWLER795.png
# Processado: TRAWLER796.png -> DDPM-F64x4/TRAWLER/TRAWLER796.png
# Processado: TRAWLER797.png -> DDPM-F64x4/TRAWLER/TRAWLER797.png
# Processado: TRAWLER798.png -> DDPM-F64x4/TRAWLER/TRAWLER798.png
# Processado: TRAWLER799.png -> DDPM-F64x4/TRAWLER/TRAWLER799.png
# Processado: TRAWLER8.png -> DDPM-F64x4/TRAWLER/TRAWLER8.png
# Processado: TRAWLER80.png -> DDPM-F64x4/TRAWLER/TRAWLER80.png
# Processado: TRAWLER800.png -> DDPM-F64x4/TRAWLER/TRAWLER800.png
# Processado: TRAWLER801.png -> DDPM-F64x4/TRAWLER/TRAWLER801.png
# Processado: TRAWLER802.png -> DDPM-F64x4/TRAWLER/TRAWLER802.png
# Processado: TRAWLER803.png -> DDPM-F64x4/TRAWLER/TRAWLER803.png
# Processado: TRAWLER804.png -> DDPM-F64x4/TRAWLER/TRAWLER804.png
# Processado: TRAWLER805.png -> DDPM-F64x4/TRAWLER/TRAWLER805.png
# Processado: TRAWLER806.png -> DDPM-F64x4/TRAWLER/TRAWLER806.png
# Processado: TRAWLER807.png -> DDPM-F64x4/TRAWLER/TRAWLER807.png
# Processado: TRAWLER808.png -> DDPM-F64x4/TRAWLER/TRAWLER808.png
# Processado: TRAWLER809.png -> DDPM-F64x4/TRAWLER/TRAWLER809.png
# Processado: TRAWLER81.png -> DDPM-F64x4/TRAWLER/TRAWLER81.png
# Processado: TRAWLER810.png -> DDPM-F64x4/TRAWLER/TRAWLER810.png
# Processado: TRAWLER811.png -> DDPM-F64x4/TRAWLER/TRAWLER811.png
# Processado: TRAWLER812.png -> DDPM-F64x4/TRAWLER/TRAWLER812.png
# Processado: TRAWLER813.png -> DDPM-F64x4/TRAWLER/TRAWLER813.png
# Processado: TRAWLER814.png -> DDPM-F64x4/TRAWLER/TRAWLER814.png
# Processado: TRAWLER815.png -> DDPM-F64x4/TRAWLER/TRAWLER815.png
# Processado: TRAWLER816.png -> DDPM-F64x4/TRAWLER/TRAWLER816.png
# Processado: TRAWLER817.png -> DDPM-F64x4/TRAWLER/TRAWLER817.png
# Processado: TRAWLER818.png -> DDPM-F64x4/TRAWLER/TRAWLER818.png
# Processado: TRAWLER819.png -> DDPM-F64x4/TRAWLER/TRAWLER819.png
# Processado: TRAWLER82.png -> DDPM-F64x4/TRAWLER/TRAWLER82.png
# Processado: TRAWLER820.png -> DDPM-F64x4/TRAWLER/TRAWLER820.png
# Processado: TRAWLER821.png -> DDPM-F64x4/TRAWLER/TRAWLER821.png
# Processado: TRAWLER822.png -> DDPM-F64x4/TRAWLER/TRAWLER822.png
# Processado: TRAWLER823.png -> DDPM-F64x4/TRAWLER/TRAWLER823.png
# Processado: TRAWLER824.png -> DDPM-F64x4/TRAWLER/TRAWLER824.png
# Processado: TRAWLER825.png -> DDPM-F64x4/TRAWLER/TRAWLER825.png
# Processado: TRAWLER826.png -> DDPM-F64x4/TRAWLER/TRAWLER826.png
# Processado: TRAWLER827.png -> DDPM-F64x4/TRAWLER/TRAWLER827.png
# Processado: TRAWLER828.png -> DDPM-F64x4/TRAWLER/TRAWLER828.png
# Processado: TRAWLER829.png -> DDPM-F64x4/TRAWLER/TRAWLER829.png
# Processado: TRAWLER83.png -> DDPM-F64x4/TRAWLER/TRAWLER83.png
# Processado: TRAWLER830.png -> DDPM-F64x4/TRAWLER/TRAWLER830.png
# Processado: TRAWLER831.png -> DDPM-F64x4/TRAWLER/TRAWLER831.png
# Processado: TRAWLER832.png -> DDPM-F64x4/TRAWLER/TRAWLER832.png
# Processado: TRAWLER833.png -> DDPM-F64x4/TRAWLER/TRAWLER833.png
# Processado: TRAWLER834.png -> DDPM-F64x4/TRAWLER/TRAWLER834.png
# Processado: TRAWLER835.png -> DDPM-F64x4/TRAWLER/TRAWLER835.png
# Processado: TRAWLER836.png -> DDPM-F64x4/TRAWLER/TRAWLER836.png
# Processado: TRAWLER837.png -> DDPM-F64x4/TRAWLER/TRAWLER837.png
# Processado: TRAWLER838.png -> DDPM-F64x4/TRAWLER/TRAWLER838.png
# Processado: TRAWLER839.png -> DDPM-F64x4/TRAWLER/TRAWLER839.png
# Processado: TRAWLER84.png -> DDPM-F64x4/TRAWLER/TRAWLER84.png
# Processado: TRAWLER840.png -> DDPM-F64x4/TRAWLER/TRAWLER840.png
# Processado: TRAWLER841.png -> DDPM-F64x4/TRAWLER/TRAWLER841.png
# Processado: TRAWLER842.png -> DDPM-F64x4/TRAWLER/TRAWLER842.png
# Processado: TRAWLER843.png -> DDPM-F64x4/TRAWLER/TRAWLER843.png
# Processado: TRAWLER844.png -> DDPM-F64x4/TRAWLER/TRAWLER844.png
# Processado: TRAWLER845.png -> DDPM-F64x4/TRAWLER/TRAWLER845.png
# Processado: TRAWLER846.png -> DDPM-F64x4/TRAWLER/TRAWLER846.png
# Processado: TRAWLER847.png -> DDPM-F64x4/TRAWLER/TRAWLER847.png
# Processado: TRAWLER848.png -> DDPM-F64x4/TRAWLER/TRAWLER848.png
# Processado: TRAWLER849.png -> DDPM-F64x4/TRAWLER/TRAWLER849.png
# Processado: TRAWLER85.png -> DDPM-F64x4/TRAWLER/TRAWLER85.png
# Processado: TRAWLER850.png -> DDPM-F64x4/TRAWLER/TRAWLER850.png
# Processado: TRAWLER851.png -> DDPM-F64x4/TRAWLER/TRAWLER851.png
# Processado: TRAWLER852.png -> DDPM-F64x4/TRAWLER/TRAWLER852.png
# Processado: TRAWLER853.png -> DDPM-F64x4/TRAWLER/TRAWLER853.png
# Processado: TRAWLER854.png -> DDPM-F64x4/TRAWLER/TRAWLER854.png
# Processado: TRAWLER855.png -> DDPM-F64x4/TRAWLER/TRAWLER855.png
# Processado: TRAWLER856.png -> DDPM-F64x4/TRAWLER/TRAWLER856.png
# Processado: TRAWLER857.png -> DDPM-F64x4/TRAWLER/TRAWLER857.png
# Processado: TRAWLER858.png -> DDPM-F64x4/TRAWLER/TRAWLER858.png
# Processado: TRAWLER859.png -> DDPM-F64x4/TRAWLER/TRAWLER859.png
# Processado: TRAWLER86.png -> DDPM-F64x4/TRAWLER/TRAWLER86.png
# Processado: TRAWLER860.png -> DDPM-F64x4/TRAWLER/TRAWLER860.png
# Processado: TRAWLER861.png -> DDPM-F64x4/TRAWLER/TRAWLER861.png
# Processado: TRAWLER862.png -> DDPM-F64x4/TRAWLER/TRAWLER862.png
# Processado: TRAWLER863.png -> DDPM-F64x4/TRAWLER/TRAWLER863.png
# Processado: TRAWLER864.png -> DDPM-F64x4/TRAWLER/TRAWLER864.png
# Processado: TRAWLER865.png -> DDPM-F64x4/TRAWLER/TRAWLER865.png
# Processado: TRAWLER866.png -> DDPM-F64x4/TRAWLER/TRAWLER866.png
# Processado: TRAWLER867.png -> DDPM-F64x4/TRAWLER/TRAWLER867.png
# Processado: TRAWLER868.png -> DDPM-F64x4/TRAWLER/TRAWLER868.png
# Processado: TRAWLER869.png -> DDPM-F64x4/TRAWLER/TRAWLER869.png
# Processado: TRAWLER87.png -> DDPM-F64x4/TRAWLER/TRAWLER87.png
# Processado: TRAWLER870.png -> DDPM-F64x4/TRAWLER/TRAWLER870.png
# Processado: TRAWLER871.png -> DDPM-F64x4/TRAWLER/TRAWLER871.png
# Processado: TRAWLER872.png -> DDPM-F64x4/TRAWLER/TRAWLER872.png
# Processado: TRAWLER873.png -> DDPM-F64x4/TRAWLER/TRAWLER873.png
# Processado: TRAWLER874.png -> DDPM-F64x4/TRAWLER/TRAWLER874.png
# Processado: TRAWLER875.png -> DDPM-F64x4/TRAWLER/TRAWLER875.png
# Processado: TRAWLER876.png -> DDPM-F64x4/TRAWLER/TRAWLER876.png
# Processado: TRAWLER877.png -> DDPM-F64x4/TRAWLER/TRAWLER877.png
# Processado: TRAWLER878.png -> DDPM-F64x4/TRAWLER/TRAWLER878.png
# Processado: TRAWLER879.png -> DDPM-F64x4/TRAWLER/TRAWLER879.png
# Processado: TRAWLER88.png -> DDPM-F64x4/TRAWLER/TRAWLER88.png
# Processado: TRAWLER880.png -> DDPM-F64x4/TRAWLER/TRAWLER880.png
# Processado: TRAWLER881.png -> DDPM-F64x4/TRAWLER/TRAWLER881.png
# Processado: TRAWLER882.png -> DDPM-F64x4/TRAWLER/TRAWLER882.png
# Processado: TRAWLER883.png -> DDPM-F64x4/TRAWLER/TRAWLER883.png
# Processado: TRAWLER884.png -> DDPM-F64x4/TRAWLER/TRAWLER884.png
# Processado: TRAWLER885.png -> DDPM-F64x4/TRAWLER/TRAWLER885.png
# Processado: TRAWLER886.png -> DDPM-F64x4/TRAWLER/TRAWLER886.png
# Processado: TRAWLER887.png -> DDPM-F64x4/TRAWLER/TRAWLER887.png
# Processado: TRAWLER888.png -> DDPM-F64x4/TRAWLER/TRAWLER888.png
# Processado: TRAWLER889.png -> DDPM-F64x4/TRAWLER/TRAWLER889.png
# Processado: TRAWLER89.png -> DDPM-F64x4/TRAWLER/TRAWLER89.png
# Processado: TRAWLER890.png -> DDPM-F64x4/TRAWLER/TRAWLER890.png
# Processado: TRAWLER891.png -> DDPM-F64x4/TRAWLER/TRAWLER891.png
# Processado: TRAWLER892.png -> DDPM-F64x4/TRAWLER/TRAWLER892.png
# Processado: TRAWLER893.png -> DDPM-F64x4/TRAWLER/TRAWLER893.png
# Processado: TRAWLER894.png -> DDPM-F64x4/TRAWLER/TRAWLER894.png
# Processado: TRAWLER895.png -> DDPM-F64x4/TRAWLER/TRAWLER895.png
# Processado: TRAWLER896.png -> DDPM-F64x4/TRAWLER/TRAWLER896.png
# Processado: TRAWLER897.png -> DDPM-F64x4/TRAWLER/TRAWLER897.png
# Processado: TRAWLER898.png -> DDPM-F64x4/TRAWLER/TRAWLER898.png
# Processado: TRAWLER899.png -> DDPM-F64x4/TRAWLER/TRAWLER899.png
# Processado: TRAWLER9.png -> DDPM-F64x4/TRAWLER/TRAWLER9.png
# Processado: TRAWLER90.png -> DDPM-F64x4/TRAWLER/TRAWLER90.png
# Processado: TRAWLER900.png -> DDPM-F64x4/TRAWLER/TRAWLER900.png
# Processado: TRAWLER901.png -> DDPM-F64x4/TRAWLER/TRAWLER901.png
# Processado: TRAWLER902.png -> DDPM-F64x4/TRAWLER/TRAWLER902.png
# Processado: TRAWLER903.png -> DDPM-F64x4/TRAWLER/TRAWLER903.png
# Processado: TRAWLER904.png -> DDPM-F64x4/TRAWLER/TRAWLER904.png
# Processado: TRAWLER905.png -> DDPM-F64x4/TRAWLER/TRAWLER905.png
# Processado: TRAWLER906.png -> DDPM-F64x4/TRAWLER/TRAWLER906.png
# Processado: TRAWLER907.png -> DDPM-F64x4/TRAWLER/TRAWLER907.png
# Processado: TRAWLER908.png -> DDPM-F64x4/TRAWLER/TRAWLER908.png
# Processado: TRAWLER909.png -> DDPM-F64x4/TRAWLER/TRAWLER909.png
# Processado: TRAWLER91.png -> DDPM-F64x4/TRAWLER/TRAWLER91.png
# Processado: TRAWLER910.png -> DDPM-F64x4/TRAWLER/TRAWLER910.png
# Processado: TRAWLER911.png -> DDPM-F64x4/TRAWLER/TRAWLER911.png
# Processado: TRAWLER912.png -> DDPM-F64x4/TRAWLER/TRAWLER912.png
# Processado: TRAWLER913.png -> DDPM-F64x4/TRAWLER/TRAWLER913.png
# Processado: TRAWLER914.png -> DDPM-F64x4/TRAWLER/TRAWLER914.png
# Processado: TRAWLER915.png -> DDPM-F64x4/TRAWLER/TRAWLER915.png
# Processado: TRAWLER916.png -> DDPM-F64x4/TRAWLER/TRAWLER916.png
# Processado: TRAWLER917.png -> DDPM-F64x4/TRAWLER/TRAWLER917.png
# Processado: TRAWLER918.png -> DDPM-F64x4/TRAWLER/TRAWLER918.png
# Processado: TRAWLER919.png -> DDPM-F64x4/TRAWLER/TRAWLER919.png
# Processado: TRAWLER92.png -> DDPM-F64x4/TRAWLER/TRAWLER92.png
# Processado: TRAWLER920.png -> DDPM-F64x4/TRAWLER/TRAWLER920.png
# Processado: TRAWLER921.png -> DDPM-F64x4/TRAWLER/TRAWLER921.png
# Processado: TRAWLER922.png -> DDPM-F64x4/TRAWLER/TRAWLER922.png
# Processado: TRAWLER923.png -> DDPM-F64x4/TRAWLER/TRAWLER923.png
# Processado: TRAWLER924.png -> DDPM-F64x4/TRAWLER/TRAWLER924.png
# Processado: TRAWLER925.png -> DDPM-F64x4/TRAWLER/TRAWLER925.png
# Processado: TRAWLER926.png -> DDPM-F64x4/TRAWLER/TRAWLER926.png
# Processado: TRAWLER927.png -> DDPM-F64x4/TRAWLER/TRAWLER927.png
# Processado: TRAWLER928.png -> DDPM-F64x4/TRAWLER/TRAWLER928.png
# Processado: TRAWLER929.png -> DDPM-F64x4/TRAWLER/TRAWLER929.png
# Processado: TRAWLER93.png -> DDPM-F64x4/TRAWLER/TRAWLER93.png
# Processado: TRAWLER930.png -> DDPM-F64x4/TRAWLER/TRAWLER930.png
# Processado: TRAWLER931.png -> DDPM-F64x4/TRAWLER/TRAWLER931.png
# Processado: TRAWLER932.png -> DDPM-F64x4/TRAWLER/TRAWLER932.png
# Processado: TRAWLER933.png -> DDPM-F64x4/TRAWLER/TRAWLER933.png
# Processado: TRAWLER934.png -> DDPM-F64x4/TRAWLER/TRAWLER934.png
# Processado: TRAWLER935.png -> DDPM-F64x4/TRAWLER/TRAWLER935.png
# Processado: TRAWLER936.png -> DDPM-F64x4/TRAWLER/TRAWLER936.png
# Processado: TRAWLER937.png -> DDPM-F64x4/TRAWLER/TRAWLER937.png
# Processado: TRAWLER938.png -> DDPM-F64x4/TRAWLER/TRAWLER938.png
# Processado: TRAWLER939.png -> DDPM-F64x4/TRAWLER/TRAWLER939.png
# Processado: TRAWLER94.png -> DDPM-F64x4/TRAWLER/TRAWLER94.png
# Processado: TRAWLER940.png -> DDPM-F64x4/TRAWLER/TRAWLER940.png
# Processado: TRAWLER941.png -> DDPM-F64x4/TRAWLER/TRAWLER941.png
# Processado: TRAWLER942.png -> DDPM-F64x4/TRAWLER/TRAWLER942.png
# Processado: TRAWLER943.png -> DDPM-F64x4/TRAWLER/TRAWLER943.png
# Processado: TRAWLER944.png -> DDPM-F64x4/TRAWLER/TRAWLER944.png
# Processado: TRAWLER945.png -> DDPM-F64x4/TRAWLER/TRAWLER945.png
# Processado: TRAWLER946.png -> DDPM-F64x4/TRAWLER/TRAWLER946.png
# Processado: TRAWLER947.png -> DDPM-F64x4/TRAWLER/TRAWLER947.png
# Processado: TRAWLER948.png -> DDPM-F64x4/TRAWLER/TRAWLER948.png
# Processado: TRAWLER949.png -> DDPM-F64x4/TRAWLER/TRAWLER949.png
# Processado: TRAWLER95.png -> DDPM-F64x4/TRAWLER/TRAWLER95.png
# Processado: TRAWLER950.png -> DDPM-F64x4/TRAWLER/TRAWLER950.png
# Processado: TRAWLER951.png -> DDPM-F64x4/TRAWLER/TRAWLER951.png
# Processado: TRAWLER952.png -> DDPM-F64x4/TRAWLER/TRAWLER952.png
# Processado: TRAWLER953.png -> DDPM-F64x4/TRAWLER/TRAWLER953.png
# Processado: TRAWLER954.png -> DDPM-F64x4/TRAWLER/TRAWLER954.png
# Processado: TRAWLER955.png -> DDPM-F64x4/TRAWLER/TRAWLER955.png
# Processado: TRAWLER956.png -> DDPM-F64x4/TRAWLER/TRAWLER956.png
# Processado: TRAWLER957.png -> DDPM-F64x4/TRAWLER/TRAWLER957.png
# Processado: TRAWLER958.png -> DDPM-F64x4/TRAWLER/TRAWLER958.png
# Processado: TRAWLER959.png -> DDPM-F64x4/TRAWLER/TRAWLER959.png
# Processado: TRAWLER96.png -> DDPM-F64x4/TRAWLER/TRAWLER96.png
# Processado: TRAWLER960.png -> DDPM-F64x4/TRAWLER/TRAWLER960.png
# Processado: TRAWLER961.png -> DDPM-F64x4/TRAWLER/TRAWLER961.png
# Processado: TRAWLER962.png -> DDPM-F64x4/TRAWLER/TRAWLER962.png
# Processado: TRAWLER963.png -> DDPM-F64x4/TRAWLER/TRAWLER963.png
# Processado: TRAWLER964.png -> DDPM-F64x4/TRAWLER/TRAWLER964.png
# Processado: TRAWLER965.png -> DDPM-F64x4/TRAWLER/TRAWLER965.png
# Processado: TRAWLER966.png -> DDPM-F64x4/TRAWLER/TRAWLER966.png
# Processado: TRAWLER967.png -> DDPM-F64x4/TRAWLER/TRAWLER967.png
# Processado: TRAWLER968.png -> DDPM-F64x4/TRAWLER/TRAWLER968.png
# Processado: TRAWLER969.png -> DDPM-F64x4/TRAWLER/TRAWLER969.png
# Processado: TRAWLER97.png -> DDPM-F64x4/TRAWLER/TRAWLER97.png
# Processado: TRAWLER970.png -> DDPM-F64x4/TRAWLER/TRAWLER970.png
# Processado: TRAWLER971.png -> DDPM-F64x4/TRAWLER/TRAWLER971.png
# Processado: TRAWLER972.png -> DDPM-F64x4/TRAWLER/TRAWLER972.png
# Processado: TRAWLER973.png -> DDPM-F64x4/TRAWLER/TRAWLER973.png
# Processado: TRAWLER974.png -> DDPM-F64x4/TRAWLER/TRAWLER974.png
# Processado: TRAWLER975.png -> DDPM-F64x4/TRAWLER/TRAWLER975.png
# Processado: TRAWLER976.png -> DDPM-F64x4/TRAWLER/TRAWLER976.png
# Processado: TRAWLER977.png -> DDPM-F64x4/TRAWLER/TRAWLER977.png
# Processado: TRAWLER978.png -> DDPM-F64x4/TRAWLER/TRAWLER978.png
# Processado: TRAWLER979.png -> DDPM-F64x4/TRAWLER/TRAWLER979.png
# Processado: TRAWLER98.png -> DDPM-F64x4/TRAWLER/TRAWLER98.png
# Processado: TRAWLER980.png -> DDPM-F64x4/TRAWLER/TRAWLER980.png
# Processado: TRAWLER981.png -> DDPM-F64x4/TRAWLER/TRAWLER981.png
# Processado: TRAWLER982.png -> DDPM-F64x4/TRAWLER/TRAWLER982.png
# Processado: TRAWLER983.png -> DDPM-F64x4/TRAWLER/TRAWLER983.png
# Processado: TRAWLER984.png -> DDPM-F64x4/TRAWLER/TRAWLER984.png
# Processado: TRAWLER985.png -> DDPM-F64x4/TRAWLER/TRAWLER985.png
# Processado: TRAWLER986.png -> DDPM-F64x4/TRAWLER/TRAWLER986.png
# Processado: TRAWLER987.png -> DDPM-F64x4/TRAWLER/TRAWLER987.png
# Processado: TRAWLER988.png -> DDPM-F64x4/TRAWLER/TRAWLER988.png
# Processado: TRAWLER989.png -> DDPM-F64x4/TRAWLER/TRAWLER989.png
# Processado: TRAWLER99.png -> DDPM-F64x4/TRAWLER/TRAWLER99.png
# Processado: TRAWLER990.png -> DDPM-F64x4/TRAWLER/TRAWLER990.png
# Processado: TRAWLER991.png -> DDPM-F64x4/TRAWLER/TRAWLER991.png
# Processado: TRAWLER992.png -> DDPM-F64x4/TRAWLER/TRAWLER992.png
# Processado: TRAWLER993.png -> DDPM-F64x4/TRAWLER/TRAWLER993.png
# Processado: TRAWLER994.png -> DDPM-F64x4/TRAWLER/TRAWLER994.png
# Processado: TRAWLER995.png -> DDPM-F64x4/TRAWLER/TRAWLER995.png
# Processado: TRAWLER996.png -> DDPM-F64x4/TRAWLER/TRAWLER996.png
# Processado: TRAWLER997.png -> DDPM-F64x4/TRAWLER/TRAWLER997.png
# Processado: TRAWLER998.png -> DDPM-F64x4/TRAWLER/TRAWLER998.png
# Processado: TRAWLER999.png -> DDPM-F64x4/TRAWLER/TRAWLER999.png
# Processamento concluído!
