# %%
generating_class = 'TANKER'

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(f"Versão do Tensorflow: {tf.__version__}")
# Out:
# 2025-01-31 20:46:44.273103: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-31 20:46:44.293516: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Versão do Tensorflow: 2.16.1

# %%
devices = tf.config.list_physical_devices('GPU')
if devices:
    print(f"GPU disponivel: {devices}")
    print(f"Número de GPUs: {len(devices)}")
else:
    print("GPU não está disponível. Usando CPU")
# Out:
# GPU disponivel: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Número de GPUs: 1
# 2025-01-31 20:46:45.083612: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.086490: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.086507: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
batch_size = 32
num_epochs =  500
total_timesteps = 1000
norm_groups = 8
learning_rate = 2e-4

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2

# %%
dataset_path = str('DATASET54000/' + generating_class + '/images')

def processar_imagem(file_path):  
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=img_channels)
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
   
    return img

ds = tf.data.Dataset.list_files(str(dataset_path + '/*'), shuffle=True)


def augment(img):
    """Flips an image left/right randomly."""
    return tf.image.random_flip_left_right(img)


def resize_and_rescale(img, size):
    """Resize the image to the desired size first and then
    rescale the pixel values in the range [-1.0, 1.0].

    Args:
        img: Image tensor
        size: Desired image size for resizing
    Returns:
        Resized and rescaled image tensor
    """

    height = tf.shape(img)[0]
    width = tf.shape(img)[1]
    crop_size = tf.minimum(height, width)

    img = tf.image.crop_to_bounding_box(
        img,
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # Resize
    img = tf.cast(img, dtype=tf.float32)
    img = tf.image.resize(img, size=size, antialias=True)

    # Rescale the pixel values
    img = img / 127.5 - 1.0
    img = tf.clip_by_value(img, clip_min, clip_max)
    return img


def train_preprocessing(x):
    img = x["image"]
    img = resize_and_rescale(img, size=(img_size, img_size))
    img = augment(img)
    return img

train_ds = (
    ds.map(processar_imagem, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size,drop_remainder=True)
    .shuffle(batch_size * 2)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# 2025-01-31 20:46:45.096479: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.096517: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.096535: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.234568: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.234594: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.234599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-01-31 20:46:45.234613: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-31 20:46:45.234631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
class GaussianDiffusion:
    """Gaussian diffusion utility.

    Args:
        beta_start: Start value of the scheduled variance
        beta_end: End value of the scheduled variance
        timesteps: Number of time steps in the forward process
    """

    def __init__(
        self,
        beta_start=1e-4,
        beta_end=0.02,
        timesteps=1000,
        clip_min=-1.0,
        clip_max=1.0,
    ):
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.timesteps = timesteps
        self.clip_min = clip_min
        self.clip_max = clip_max

        # Define the linear variance schedule
        self.betas = betas = np.linspace(
            beta_start,
            beta_end,
            timesteps,
            dtype=np.float64,  # Using float64 for better precision
        )
        self.num_timesteps = int(timesteps)

        alphas = 1.0 - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1.0, alphas_cumprod[:-1])

        self.betas = tf.constant(betas, dtype=tf.float32)
        self.alphas_cumprod = tf.constant(alphas_cumprod, dtype=tf.float32)
        self.alphas_cumprod_prev = tf.constant(alphas_cumprod_prev, dtype=tf.float32)

        # Calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = tf.constant(
            np.sqrt(alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_one_minus_alphas_cumprod = tf.constant(
            np.sqrt(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.log_one_minus_alphas_cumprod = tf.constant(
            np.log(1.0 - alphas_cumprod), dtype=tf.float32
        )

        self.sqrt_recip_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod), dtype=tf.float32
        )
        self.sqrt_recipm1_alphas_cumprod = tf.constant(
            np.sqrt(1.0 / alphas_cumprod - 1), dtype=tf.float32
        )

        # Calculations for posterior q(x_{t-1} | x_t, x_0)
        posterior_variance = (
            betas * (1.0 - alphas_cumprod_prev) / (1.0 - alphas_cumprod)
        )
        self.posterior_variance = tf.constant(posterior_variance, dtype=tf.float32)

        # Log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = tf.constant(
            np.log(np.maximum(posterior_variance, 1e-20)), dtype=tf.float32
        )

        self.posterior_mean_coef1 = tf.constant(
            betas * np.sqrt(alphas_cumprod_prev) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

        self.posterior_mean_coef2 = tf.constant(
            (1.0 - alphas_cumprod_prev) * np.sqrt(alphas) / (1.0 - alphas_cumprod),
            dtype=tf.float32,
        )

    def _extract(self, a, t, x_shape):
        """Extract some coefficients at specified timesteps,
        then reshape to [batch_size, 1, 1, 1, 1, ...] for broadcasting purposes.

        Args:
            a: Tensor to extract from
            t: Timestep for which the coefficients are to be extracted
            x_shape: Shape of the current batched samples
        """
        batch_size = x_shape[0]
        out = tf.gather(a, t)
        return tf.reshape(out, [batch_size, 1, 1, 1])

    def q_mean_variance(self, x_start, t):
        """Extracts the mean, and the variance at current timestep.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
        """
        x_start_shape = tf.shape(x_start)
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start_shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start_shape)
        log_variance = self._extract(
            self.log_one_minus_alphas_cumprod, t, x_start_shape
        )
        return mean, variance, log_variance

    def q_sample(self, x_start, t, noise):
        """Diffuse the data.

        Args:
            x_start: Initial sample (before the first diffusion step)
            t: Current timestep
            noise: Gaussian noise to be added at the current timestep
        Returns:
            Diffused samples at timestep `t`
        """
        x_start_shape = tf.shape(x_start)
        return (
            self._extract(self.sqrt_alphas_cumprod, t, tf.shape(x_start)) * x_start
            + self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start_shape)
            * noise
        )

    def predict_start_from_noise(self, x_t, t, noise):
        x_t_shape = tf.shape(x_t)
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t_shape) * x_t
            - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t_shape) * noise
        )

    def q_posterior(self, x_start, x_t, t):
        """Compute the mean and variance of the diffusion
        posterior q(x_{t-1} | x_t, x_0).

        Args:
            x_start: Stating point(sample) for the posterior computation
            x_t: Sample at timestep `t`
            t: Current timestep
        Returns:
            Posterior mean and variance at current timestep
        """

        x_t_shape = tf.shape(x_t)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t_shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t_shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t_shape)
        posterior_log_variance_clipped = self._extract(
            self.posterior_log_variance_clipped, t, x_t_shape
        )
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def p_mean_variance(self, pred_noise, x, t, clip_denoised=True):
        x_recon = self.predict_start_from_noise(x, t=t, noise=pred_noise)
        if clip_denoised:
            x_recon = tf.clip_by_value(x_recon, self.clip_min, self.clip_max)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(
            x_start=x_recon, x_t=x, t=t
        )
        return model_mean, posterior_variance, posterior_log_variance

    def p_sample(self, pred_noise, x, t, clip_denoised=True):
        """Sample from the diffusion model.

        Args:
            pred_noise: Noise predicted by the diffusion model
            x: Samples at a given timestep for which the noise was predicted
            t: Current timestep
            clip_denoised (bool): Whether to clip the predicted noise
                within the specified range or not.
        """
        model_mean, _, model_log_variance = self.p_mean_variance(
            pred_noise, x=x, t=t, clip_denoised=clip_denoised
        )
        noise = tf.random.normal(shape=x.shape, dtype=x.dtype)
        # No noise when t == 0
        nonzero_mask = tf.reshape(
            1 - tf.cast(tf.equal(t, 0), tf.float32), [tf.shape(x)[0], 1, 1, 1]
        )
        return model_mean + nonzero_mask * tf.exp(0.5 * model_log_variance) * noise

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(3, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, images):
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]

        # 2. Sample timesteps uniformly
        t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)

            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t], training=True)

            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    def generate_images(self, num_images=16):
        # 1. Randomly sample noise (starting point for reverse process)
        samples = tf.random.normal(
            shape=(num_images, img_size, img_size, img_channels), dtype=tf.float32
        )
        # 2. Sample from the model iteratively
        for t in reversed(range(0, self.timesteps)):
            tt = tf.cast(tf.fill(num_images, t), dtype=tf.int64)
            pred_noise = self.ema_network.predict(
                [samples, tt], verbose=0, batch_size=num_images
            )
            samples = self.gdf_util.p_sample(
                pred_noise, samples, tt, clip_denoised=True
            )
        # 3. Return generated samples
        return samples

    def plot_images(
        self, epoch=None, logs=None, num_rows=2, num_cols=8, figsize=(12, 5)
    ):
        """Utility to plot images using the diffusion model during training."""
        generated_samples = self.generate_images(num_images=num_rows * num_cols)
        generated_samples = (
            tf.clip_by_value(generated_samples * 127.5 + 127.5, 0.0, 255.0)
            .numpy()
            .astype(np.uint8)
        )

        _, ax = plt.subplots(num_rows, num_cols, figsize=figsize)
        for i, image in enumerate(generated_samples):
            if num_rows == 1:
                ax[i].imshow(image)
                ax[i].axis("off")
            else:
                ax[i // num_cols, i % num_cols].imshow(image)
                ax[i // num_cols, i % num_cols].axis("off")

        plt.tight_layout()
        plt.show()


# Build the unet model
network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network = build_model(
    img_size=img_size,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    activation_fn=keras.activations.swish,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same

# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# Compile the model
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
)

# %%
# Train the model
model.fit(
    train_ds,
    epochs=num_epochs,
    batch_size=batch_size,
    #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
)
tf.saved_model.save(model, str('DDPM-GI/' + generating_class + '/GERADOR'))
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738356428.278582     170 service.cc:145] XLA service 0x7fb68803d4d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738356428.278630     170 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-01-31 20:47:09.079155: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1738356429.787389     170 random_ops.cc:105] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform
# 2025-01-31 20:47:11.219993: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738356432.865471     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738356433.183828     345 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738356433.269329     351 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_373', 28 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738356433.352153     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 36 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1738356433.412630     356 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738356433.434837     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 440 bytes spill stores, 580 bytes spill loads
#
# I0000 00:00:1738356433.434853     340 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1738356433.466161     328 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 320 bytes spill stores, 320 bytes spill loads
#
# I0000 00:00:1738356433.466320     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 100 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1738356433.540076     354 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738356433.622766     331 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 552 bytes spill stores, 600 bytes spill loads
#
# I0000 00:00:1738356433.623742     351 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 48 bytes spill stores, 48 bytes spill loads
#
# I0000 00:00:1738356433.699263     335 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 8 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1738356433.809955     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 160 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1738356433.846163     333 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738356433.967900     329 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738356434.001468     351 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_91', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1738356434.337159     340 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 172 bytes spill stores, 172 bytes spill loads
#
# I0000 00:00:1738356434.389856     341 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738356434.389858     336 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_70', 164 bytes spill stores, 164 bytes spill loads
#
# I0000 00:00:1738356434.413450     357 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 128 bytes spill stores, 380 bytes spill loads
#
# I0000 00:00:1738356434.533980     343 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 240 bytes spill stores, 180 bytes spill loads
#
# I0000 00:00:1738356434.590499     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 80 bytes spill stores, 80 bytes spill loads
#
# I0000 00:00:1738356434.661226     352 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_67', 16 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1738356434.841423     334 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1738356434.958037     348 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_362', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738356435.094923     338 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_97', 108 bytes spill stores, 68 bytes spill loads
#
# I0000 00:00:1738356435.211143     355 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_68', 212 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738356435.432272     348 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 140 bytes spill stores, 140 bytes spill loads
#
# I0000 00:00:1738356435.654978     347 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_90', 284 bytes spill stores, 268 bytes spill loads
#
# I0000 00:00:1738356435.960105     329 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1738356435.980762     343 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 332 bytes spill stores, 332 bytes spill loads
#
# I0000 00:00:1738356435.993803     359 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_14', 324 bytes spill stores, 324 bytes spill loads
#
# I0000 00:00:1738356462.949001     170 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_198', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_80', 36 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1738356462.990746     170 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 66s 66ms/step - loss: 0.2355
# Epoch 2/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0259
# Epoch 3/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0212
# Epoch 4/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0176
# Epoch 5/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0174
# Epoch 6/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0168
# Epoch 7/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0159
# Epoch 8/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0154
# Epoch 9/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 10/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0145
# Epoch 11/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0144
# Epoch 12/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0158
# Epoch 13/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0150
# Epoch 14/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0149
# Epoch 15/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0138
# Epoch 16/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0138
# Epoch 17/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0135
# Epoch 18/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0134
# Epoch 19/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0147
# Epoch 20/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0140
# Epoch 21/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0132
# Epoch 22/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0147
# Epoch 23/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0128
# Epoch 24/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0139
# Epoch 25/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0129
# Epoch 26/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0137
# Epoch 27/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0126
# Epoch 28/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0133
# Epoch 29/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0139
# Epoch 30/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0139
# Epoch 31/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0131
# Epoch 32/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0130
# Epoch 33/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0130
# Epoch 34/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 35/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0136
# Epoch 36/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0132
# Epoch 37/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 38/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0127
# Epoch 39/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0130
# Epoch 40/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0128
# Epoch 41/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0128
# Epoch 42/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0129
# Epoch 43/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0128
# Epoch 44/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0122
# Epoch 45/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0127
# Epoch 46/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0127
# Epoch 47/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0121
# Epoch 48/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 49/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0126
# Epoch 50/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 51/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0122
# Epoch 52/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0121
# Epoch 53/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0125
# Epoch 54/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 55/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0125
# Epoch 56/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 57/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0124
# Epoch 58/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 59/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0121
# Epoch 60/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0126
# Epoch 61/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 62/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 63/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 64/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 65/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 66/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0125
# Epoch 67/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0126
# Epoch 68/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0128
# Epoch 69/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 70/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0120
# Epoch 71/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 72/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 73/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 74/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 75/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0121
# Epoch 76/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 77/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 78/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0118
# Epoch 79/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0116
# Epoch 80/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 81/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0127
# Epoch 82/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0115
# Epoch 83/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 84/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0122
# Epoch 85/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0114
# Epoch 86/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0114
# Epoch 87/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0114
# Epoch 88/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 89/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0112
# Epoch 90/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0115
# Epoch 91/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 92/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 93/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 94/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0121
# Epoch 95/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0119
# Epoch 96/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0117
# Epoch 97/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 98/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0115
# Epoch 99/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 100/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0125
# Epoch 101/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0121
# Epoch 102/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0120
# Epoch 103/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0106
# Epoch 104/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 105/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 106/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0121
# Epoch 107/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0120
# Epoch 108/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 109/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 110/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 111/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 112/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 113/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0120
# Epoch 114/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 115/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0122
# Epoch 116/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 117/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 118/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0116
# Epoch 119/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 120/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 121/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 122/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 123/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 124/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 125/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0120
# Epoch 126/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0116
# Epoch 127/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0124
# Epoch 128/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 129/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 130/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0123
# Epoch 131/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 132/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0121
# Epoch 133/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 134/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 135/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0119
# Epoch 136/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 137/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0113
# Epoch 138/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0107
# Epoch 139/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 0.0110
# Epoch 140/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 141/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 142/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0118
# Epoch 143/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 144/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0117
# Epoch 145/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 146/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 147/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 148/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 149/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 150/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 151/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 152/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 153/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 154/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 155/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0116
# Epoch 156/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 157/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0120
# Epoch 158/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0112
# Epoch 159/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 0.0119
# Epoch 160/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 161/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 162/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0101
# Epoch 163/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 164/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 165/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 166/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 167/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 168/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 169/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 170/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 171/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 172/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 173/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 174/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 175/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 176/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 177/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 178/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 179/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 180/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0120
# Epoch 181/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0102
# Epoch 182/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 183/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 184/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 185/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0105
# Epoch 186/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 187/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 188/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0107
# Epoch 189/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 190/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0122
# Epoch 191/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 192/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 193/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 194/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 195/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 196/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 197/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 198/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0103
# Epoch 199/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 200/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 201/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 202/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 203/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 204/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 205/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0117
# Epoch 206/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 207/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 208/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 209/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 210/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 211/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 212/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 213/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 214/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 215/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0107
# Epoch 216/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0102
# Epoch 217/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0107
# Epoch 218/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0105
# Epoch 219/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0116
# Epoch 220/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0116
# Epoch 221/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 222/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 223/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0111
# Epoch 224/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 225/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 226/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0112
# Epoch 227/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0124
# Epoch 228/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 229/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0107
# Epoch 230/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 231/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0104
# Epoch 232/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0107
# Epoch 233/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 234/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 235/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 236/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 237/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 238/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 239/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 240/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 241/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 242/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 243/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 244/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0115
# Epoch 245/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 246/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0105
# Epoch 247/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0103
# Epoch 248/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0103
# Epoch 249/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0116
# Epoch 250/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 251/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0118
# Epoch 252/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 253/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0103
# Epoch 254/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0106
# Epoch 255/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 256/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 257/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 258/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 259/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 260/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0109
# Epoch 261/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0098
# Epoch 262/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 263/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0110
# Epoch 264/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0108
# Epoch 265/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 266/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0113
# Epoch 267/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0114
# Epoch 268/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0107
# Epoch 269/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 270/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0118
# Epoch 271/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0107
# Epoch 272/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0112
# Epoch 273/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 274/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0110
# Epoch 275/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 276/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0104
# Epoch 277/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0112
# Epoch 278/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 279/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0118
# Epoch 280/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 281/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0108
# Epoch 282/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0109
# Epoch 283/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 284/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 285/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 286/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0106
# Epoch 287/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 288/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 289/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 290/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0117
# Epoch 291/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 292/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0115
# Epoch 293/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 294/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 295/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 296/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 297/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 298/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0105
# Epoch 299/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 300/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 301/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 302/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 303/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0107
# Epoch 304/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 305/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 306/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 307/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 308/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 309/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0110
# Epoch 310/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 311/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 312/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0111
# Epoch 313/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 314/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0116
# Epoch 315/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 316/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 317/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 318/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 319/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 320/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 321/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 322/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 323/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 324/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 325/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 326/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 327/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 328/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 329/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 330/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 331/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 332/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 333/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 334/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 335/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 336/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 337/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 338/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 339/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 340/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 341/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 342/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0116
# Epoch 343/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 344/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 345/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 346/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 347/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 348/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 349/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 350/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 351/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 352/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 353/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0113
# Epoch 354/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 355/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 356/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 357/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 358/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 359/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 360/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 361/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 362/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 363/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0119
# Epoch 364/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 365/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 366/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 367/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 368/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 369/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 370/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 371/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 372/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 373/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 374/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 375/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 376/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 377/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 378/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 379/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 380/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 381/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 382/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 383/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 384/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 385/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 386/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 387/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 388/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 389/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0115
# Epoch 390/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 391/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 392/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 393/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 394/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 395/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 396/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 397/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 398/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 399/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0114
# Epoch 400/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 401/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 402/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 403/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 404/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 405/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0112
# Epoch 406/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 407/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 408/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 409/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 410/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 411/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 412/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 413/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 414/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0111
# Epoch 415/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 416/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 417/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 418/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 419/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0117
# Epoch 420/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 421/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 422/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 423/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 424/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 425/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 426/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 427/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 428/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 429/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 430/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 431/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 432/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 433/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 434/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 435/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 436/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 437/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 438/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 439/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 440/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 441/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 442/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 443/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 444/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 445/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 446/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 447/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 448/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# Epoch 449/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 450/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 451/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 452/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 453/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 454/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 455/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 456/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 457/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 458/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 459/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 460/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 461/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 462/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 463/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 464/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 465/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 466/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 467/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0096
# Epoch 468/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 469/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 470/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 471/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 472/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0109
# Epoch 473/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 474/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 475/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 476/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 477/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 478/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 479/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 480/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 481/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0100
# Epoch 482/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0106
# Epoch 483/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 484/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 485/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0099
# Epoch 486/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 487/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0101
# Epoch 488/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 489/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 490/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 491/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 492/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0110
# Epoch 493/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0098
# Epoch 494/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0107
# Epoch 495/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0104
# Epoch 496/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0096
# Epoch 497/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0102
# Epoch 498/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0105
# Epoch 499/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0103
# Epoch 500/500
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0108
# INFO:tensorflow:Assets written to: DDPM-GI/TANKER/GERADOR/assets
# INFO:tensorflow:Assets written to: DDPM-GI/TANKER/GERADOR/assets

# %%
import os
from IPython.display import clear_output
import time

num_img = 5400
output_dir = str("DDPM-F64/" + generating_class + "/")

os.makedirs(output_dir, exist_ok=True)

filename = str(generating_class + "%d.png")

output_path = os.path.join(output_dir, filename)

# 1. Randomly sample noise (starting point for reverse process)
samples = tf.random.normal(shape=(num_img, 64, 64, 3), dtype=tf.float32)
# 2. Sample from the model iteratively
for t in reversed(range(0,1000)):
    ini = time.time()
    tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
    pred_noise = ema_network.predict(
        [samples, tt], verbose=0, batch_size=1
    )
    samples = gdf_util.p_sample(
        pred_noise, samples, tt, clip_denoised=True
    )
    fim = time.time()
    tim = fim - ini
    timt = (tim * t) / 3600
    print("Faltam %d iterações" % (t))
    print("A iteração atual levou %d segundos" % (tim))
    print("Faltam %f horas" % (timt))
    clear_output(wait=True)

for i in range(num_img):
    img = keras.utils.array_to_img(samples[i])
    img.save(output_path % (i))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 20
#      18 ini = time.time()
#      19 tt = tf.cast(tf.fill(num_img, t), dtype=tf.int64)
# ---> 20 pred_noise = ema_network.predict(
#      21     [samples, tt], verbose=0, batch_size=1
#      22 )
#      23 samples = gdf_util.p_sample(
#      24     pred_noise, samples, tt, clip_denoised=True
#      25 )
#      26 fim = time.time()
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:510, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     508 callbacks.on_predict_batch_begin(step)
#     509 data = get_data(iterator)
# --> 510 batch_outputs = self.predict_function(data)
#     511 outputs = append_to_outputs(batch_outputs, outputs)
#     512 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
## GERAÇÃO FINALIZADA ##

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

import torchvision
print(torchvision.__version__)

import cv2
print("OpenCV version:", cv2.__version__)

print(torch.cuda.is_available())  # Deve retornar True se a GPU estiver configurada corretamente
print(torch.cuda.get_device_name(0))  # Nome da GPU
# Out:
# PyTorch version: 2.0.1+cu118
# 0.15.2+cu118
# OpenCV version: 4.11.0
# True
# NVIDIA GeForce RTX 4090

# %%
import os
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet
from PIL import Image
import numpy as np
import requests
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Caminhos para as imagens de entrada e saída
input_dir = str("DDPM-F64/" + generating_class)   # Substitua pelo diretório das imagens de entrada
output_dir = str("DDPM-F64x4/" + generating_class)  # Substitua pelo diretório das imagens de saída

# Certifique-se de que o diretório de saída existe
os.makedirs(output_dir, exist_ok=True)

# %%
weights_path = "RealESRGAN_x4plus.pth"

# Função para baixar os pesos se não existirem
def download_weights():
    if not os.path.exists(weights_path):
        print("Pesos do modelo não encontrados. Fazendo download...")
        url = "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth"
        response = requests.get(url, stream=True)
        with open(weights_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print("Download concluído!")

# %%
# Baixar os pesos, se necessário
download_weights()

def process_images(input_dir, output_dir):
    # Certifique-se de que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    # Inicialize o modelo Real-ESRGAN
    model = RRDBNet(
        num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4
    )
    upscaler = RealESRGANer(
        scale=4,  # Fator de escala
        model_path=weights_path,  # Caminho dos pesos do modelo
        model=model,  # Modelo definido acima
        tile=0,  # Defina um tamanho de tile se tiver limitações de memória
        tile_pad=10,  # Padding ao redor dos tiles
        pre_pad=0,  # Preenchimento adicional antes do processamento
        half=True,  # Utilize FP16 para economizar memória em GPUs compatíveis
    )

    # Iterar sobre todas as imagens no diretório de entrada
    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Abra a imagem de entrada
                with Image.open(input_path) as img:
                    # Converta a imagem para array NumPy
                    input_image = np.array(img)

                    # Aplique a super-resolução
                    sr_image, _ = upscaler.enhance(input_image, outscale=4)

                    # Salve a imagem processada
                    Image.fromarray(sr_image).save(output_path)
                    print(f"Processado: {filename} -> {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# %%
process_images(input_dir, output_dir)
print("Processamento concluído!")
# Out:
# Processado: TANKER0.png -> DDPM-F64x4/TANKER/TANKER0.png
# Processado: TANKER1.png -> DDPM-F64x4/TANKER/TANKER1.png
# Processado: TANKER10.png -> DDPM-F64x4/TANKER/TANKER10.png
# Processado: TANKER100.png -> DDPM-F64x4/TANKER/TANKER100.png
# Processado: TANKER1000.png -> DDPM-F64x4/TANKER/TANKER1000.png
# Processado: TANKER1001.png -> DDPM-F64x4/TANKER/TANKER1001.png
# Processado: TANKER1002.png -> DDPM-F64x4/TANKER/TANKER1002.png
# Processado: TANKER1003.png -> DDPM-F64x4/TANKER/TANKER1003.png
# Processado: TANKER1004.png -> DDPM-F64x4/TANKER/TANKER1004.png
# Processado: TANKER1005.png -> DDPM-F64x4/TANKER/TANKER1005.png
# Processado: TANKER1006.png -> DDPM-F64x4/TANKER/TANKER1006.png
# Processado: TANKER1007.png -> DDPM-F64x4/TANKER/TANKER1007.png
# Processado: TANKER1008.png -> DDPM-F64x4/TANKER/TANKER1008.png
# Processado: TANKER1009.png -> DDPM-F64x4/TANKER/TANKER1009.png
# Processado: TANKER101.png -> DDPM-F64x4/TANKER/TANKER101.png
# Processado: TANKER1010.png -> DDPM-F64x4/TANKER/TANKER1010.png
# Processado: TANKER1011.png -> DDPM-F64x4/TANKER/TANKER1011.png
# Processado: TANKER1012.png -> DDPM-F64x4/TANKER/TANKER1012.png
# Processado: TANKER1013.png -> DDPM-F64x4/TANKER/TANKER1013.png
# Processado: TANKER1014.png -> DDPM-F64x4/TANKER/TANKER1014.png
# Processado: TANKER1015.png -> DDPM-F64x4/TANKER/TANKER1015.png
# Processado: TANKER1016.png -> DDPM-F64x4/TANKER/TANKER1016.png
# Processado: TANKER1017.png -> DDPM-F64x4/TANKER/TANKER1017.png
# Processado: TANKER1018.png -> DDPM-F64x4/TANKER/TANKER1018.png
# Processado: TANKER1019.png -> DDPM-F64x4/TANKER/TANKER1019.png
# Processado: TANKER102.png -> DDPM-F64x4/TANKER/TANKER102.png
# Processado: TANKER1020.png -> DDPM-F64x4/TANKER/TANKER1020.png
# Processado: TANKER1021.png -> DDPM-F64x4/TANKER/TANKER1021.png
# Processado: TANKER1022.png -> DDPM-F64x4/TANKER/TANKER1022.png
# Processado: TANKER1023.png -> DDPM-F64x4/TANKER/TANKER1023.png
# Processado: TANKER1024.png -> DDPM-F64x4/TANKER/TANKER1024.png
# Processado: TANKER1025.png -> DDPM-F64x4/TANKER/TANKER1025.png
# Processado: TANKER1026.png -> DDPM-F64x4/TANKER/TANKER1026.png
# Processado: TANKER1027.png -> DDPM-F64x4/TANKER/TANKER1027.png
# Processado: TANKER1028.png -> DDPM-F64x4/TANKER/TANKER1028.png
# Processado: TANKER1029.png -> DDPM-F64x4/TANKER/TANKER1029.png
# Processado: TANKER103.png -> DDPM-F64x4/TANKER/TANKER103.png
# Processado: TANKER1030.png -> DDPM-F64x4/TANKER/TANKER1030.png
# Processado: TANKER1031.png -> DDPM-F64x4/TANKER/TANKER1031.png
# Processado: TANKER1032.png -> DDPM-F64x4/TANKER/TANKER1032.png
# Processado: TANKER1033.png -> DDPM-F64x4/TANKER/TANKER1033.png
# Processado: TANKER1034.png -> DDPM-F64x4/TANKER/TANKER1034.png
# Processado: TANKER1035.png -> DDPM-F64x4/TANKER/TANKER1035.png
# Processado: TANKER1036.png -> DDPM-F64x4/TANKER/TANKER1036.png
# Processado: TANKER1037.png -> DDPM-F64x4/TANKER/TANKER1037.png
# Processado: TANKER1038.png -> DDPM-F64x4/TANKER/TANKER1038.png
# Processado: TANKER1039.png -> DDPM-F64x4/TANKER/TANKER1039.png
# Processado: TANKER104.png -> DDPM-F64x4/TANKER/TANKER104.png
# Processado: TANKER1040.png -> DDPM-F64x4/TANKER/TANKER1040.png
# Processado: TANKER1041.png -> DDPM-F64x4/TANKER/TANKER1041.png
# Processado: TANKER1042.png -> DDPM-F64x4/TANKER/TANKER1042.png
# Processado: TANKER1043.png -> DDPM-F64x4/TANKER/TANKER1043.png
# Processado: TANKER1044.png -> DDPM-F64x4/TANKER/TANKER1044.png
# Processado: TANKER1045.png -> DDPM-F64x4/TANKER/TANKER1045.png
# Processado: TANKER1046.png -> DDPM-F64x4/TANKER/TANKER1046.png
# Processado: TANKER1047.png -> DDPM-F64x4/TANKER/TANKER1047.png
# Processado: TANKER1048.png -> DDPM-F64x4/TANKER/TANKER1048.png
# Processado: TANKER1049.png -> DDPM-F64x4/TANKER/TANKER1049.png
# Processado: TANKER105.png -> DDPM-F64x4/TANKER/TANKER105.png
# Processado: TANKER1050.png -> DDPM-F64x4/TANKER/TANKER1050.png
# Processado: TANKER1051.png -> DDPM-F64x4/TANKER/TANKER1051.png
# Processado: TANKER1052.png -> DDPM-F64x4/TANKER/TANKER1052.png
# Processado: TANKER1053.png -> DDPM-F64x4/TANKER/TANKER1053.png
# Processado: TANKER1054.png -> DDPM-F64x4/TANKER/TANKER1054.png
# Processado: TANKER1055.png -> DDPM-F64x4/TANKER/TANKER1055.png
# Processado: TANKER1056.png -> DDPM-F64x4/TANKER/TANKER1056.png
# Processado: TANKER1057.png -> DDPM-F64x4/TANKER/TANKER1057.png
# Processado: TANKER1058.png -> DDPM-F64x4/TANKER/TANKER1058.png
# Processado: TANKER1059.png -> DDPM-F64x4/TANKER/TANKER1059.png
# Processado: TANKER106.png -> DDPM-F64x4/TANKER/TANKER106.png
# Processado: TANKER1060.png -> DDPM-F64x4/TANKER/TANKER1060.png
# Processado: TANKER1061.png -> DDPM-F64x4/TANKER/TANKER1061.png
# Processado: TANKER1062.png -> DDPM-F64x4/TANKER/TANKER1062.png
# Processado: TANKER1063.png -> DDPM-F64x4/TANKER/TANKER1063.png
# Processado: TANKER1064.png -> DDPM-F64x4/TANKER/TANKER1064.png
# Processado: TANKER1065.png -> DDPM-F64x4/TANKER/TANKER1065.png
# Processado: TANKER1066.png -> DDPM-F64x4/TANKER/TANKER1066.png
# Processado: TANKER1067.png -> DDPM-F64x4/TANKER/TANKER1067.png
# Processado: TANKER1068.png -> DDPM-F64x4/TANKER/TANKER1068.png
# Processado: TANKER1069.png -> DDPM-F64x4/TANKER/TANKER1069.png
# Processado: TANKER107.png -> DDPM-F64x4/TANKER/TANKER107.png
# Processado: TANKER1070.png -> DDPM-F64x4/TANKER/TANKER1070.png
# Processado: TANKER1071.png -> DDPM-F64x4/TANKER/TANKER1071.png
# Processado: TANKER1072.png -> DDPM-F64x4/TANKER/TANKER1072.png
# Processado: TANKER1073.png -> DDPM-F64x4/TANKER/TANKER1073.png
# Processado: TANKER1074.png -> DDPM-F64x4/TANKER/TANKER1074.png
# Processado: TANKER1075.png -> DDPM-F64x4/TANKER/TANKER1075.png
# Processado: TANKER1076.png -> DDPM-F64x4/TANKER/TANKER1076.png
# Processado: TANKER1077.png -> DDPM-F64x4/TANKER/TANKER1077.png
# Processado: TANKER1078.png -> DDPM-F64x4/TANKER/TANKER1078.png
# Processado: TANKER1079.png -> DDPM-F64x4/TANKER/TANKER1079.png
# Processado: TANKER108.png -> DDPM-F64x4/TANKER/TANKER108.png
# Processado: TANKER1080.png -> DDPM-F64x4/TANKER/TANKER1080.png
# Processado: TANKER1081.png -> DDPM-F64x4/TANKER/TANKER1081.png
# Processado: TANKER1082.png -> DDPM-F64x4/TANKER/TANKER1082.png
# Processado: TANKER1083.png -> DDPM-F64x4/TANKER/TANKER1083.png
# Processado: TANKER1084.png -> DDPM-F64x4/TANKER/TANKER1084.png
# Processado: TANKER1085.png -> DDPM-F64x4/TANKER/TANKER1085.png
# Processado: TANKER1086.png -> DDPM-F64x4/TANKER/TANKER1086.png
# Processado: TANKER1087.png -> DDPM-F64x4/TANKER/TANKER1087.png
# Processado: TANKER1088.png -> DDPM-F64x4/TANKER/TANKER1088.png
# Processado: TANKER1089.png -> DDPM-F64x4/TANKER/TANKER1089.png
# Processado: TANKER109.png -> DDPM-F64x4/TANKER/TANKER109.png
# Processado: TANKER1090.png -> DDPM-F64x4/TANKER/TANKER1090.png
# Processado: TANKER1091.png -> DDPM-F64x4/TANKER/TANKER1091.png
# Processado: TANKER1092.png -> DDPM-F64x4/TANKER/TANKER1092.png
# Processado: TANKER1093.png -> DDPM-F64x4/TANKER/TANKER1093.png
# Processado: TANKER1094.png -> DDPM-F64x4/TANKER/TANKER1094.png
# Processado: TANKER1095.png -> DDPM-F64x4/TANKER/TANKER1095.png
# Processado: TANKER1096.png -> DDPM-F64x4/TANKER/TANKER1096.png
# Processado: TANKER1097.png -> DDPM-F64x4/TANKER/TANKER1097.png
# Processado: TANKER1098.png -> DDPM-F64x4/TANKER/TANKER1098.png
# Processado: TANKER1099.png -> DDPM-F64x4/TANKER/TANKER1099.png
# Processado: TANKER11.png -> DDPM-F64x4/TANKER/TANKER11.png
# Processado: TANKER110.png -> DDPM-F64x4/TANKER/TANKER110.png
# Processado: TANKER1100.png -> DDPM-F64x4/TANKER/TANKER1100.png
# Processado: TANKER1101.png -> DDPM-F64x4/TANKER/TANKER1101.png
# Processado: TANKER1102.png -> DDPM-F64x4/TANKER/TANKER1102.png
# Processado: TANKER1103.png -> DDPM-F64x4/TANKER/TANKER1103.png
# Processado: TANKER1104.png -> DDPM-F64x4/TANKER/TANKER1104.png
# Processado: TANKER1105.png -> DDPM-F64x4/TANKER/TANKER1105.png
# Processado: TANKER1106.png -> DDPM-F64x4/TANKER/TANKER1106.png
# Processado: TANKER1107.png -> DDPM-F64x4/TANKER/TANKER1107.png
# Processado: TANKER1108.png -> DDPM-F64x4/TANKER/TANKER1108.png
# Processado: TANKER1109.png -> DDPM-F64x4/TANKER/TANKER1109.png
# Processado: TANKER111.png -> DDPM-F64x4/TANKER/TANKER111.png
# Processado: TANKER1110.png -> DDPM-F64x4/TANKER/TANKER1110.png
# Processado: TANKER1111.png -> DDPM-F64x4/TANKER/TANKER1111.png
# Processado: TANKER1112.png -> DDPM-F64x4/TANKER/TANKER1112.png
# Processado: TANKER1113.png -> DDPM-F64x4/TANKER/TANKER1113.png
# Processado: TANKER1114.png -> DDPM-F64x4/TANKER/TANKER1114.png
# Processado: TANKER1115.png -> DDPM-F64x4/TANKER/TANKER1115.png
# Processado: TANKER1116.png -> DDPM-F64x4/TANKER/TANKER1116.png
# Processado: TANKER1117.png -> DDPM-F64x4/TANKER/TANKER1117.png
# Processado: TANKER1118.png -> DDPM-F64x4/TANKER/TANKER1118.png
# Processado: TANKER1119.png -> DDPM-F64x4/TANKER/TANKER1119.png
# Processado: TANKER112.png -> DDPM-F64x4/TANKER/TANKER112.png
# Processado: TANKER1120.png -> DDPM-F64x4/TANKER/TANKER1120.png
# Processado: TANKER1121.png -> DDPM-F64x4/TANKER/TANKER1121.png
# Processado: TANKER1122.png -> DDPM-F64x4/TANKER/TANKER1122.png
# Processado: TANKER1123.png -> DDPM-F64x4/TANKER/TANKER1123.png
# Processado: TANKER1124.png -> DDPM-F64x4/TANKER/TANKER1124.png
# Processado: TANKER1125.png -> DDPM-F64x4/TANKER/TANKER1125.png
# Processado: TANKER1126.png -> DDPM-F64x4/TANKER/TANKER1126.png
# Processado: TANKER1127.png -> DDPM-F64x4/TANKER/TANKER1127.png
# Processado: TANKER1128.png -> DDPM-F64x4/TANKER/TANKER1128.png
# Processado: TANKER1129.png -> DDPM-F64x4/TANKER/TANKER1129.png
# Processado: TANKER113.png -> DDPM-F64x4/TANKER/TANKER113.png
# Processado: TANKER1130.png -> DDPM-F64x4/TANKER/TANKER1130.png
# Processado: TANKER1131.png -> DDPM-F64x4/TANKER/TANKER1131.png
# Processado: TANKER1132.png -> DDPM-F64x4/TANKER/TANKER1132.png
# Processado: TANKER1133.png -> DDPM-F64x4/TANKER/TANKER1133.png
# Processado: TANKER1134.png -> DDPM-F64x4/TANKER/TANKER1134.png
# Processado: TANKER1135.png -> DDPM-F64x4/TANKER/TANKER1135.png
# Processado: TANKER1136.png -> DDPM-F64x4/TANKER/TANKER1136.png
# Processado: TANKER1137.png -> DDPM-F64x4/TANKER/TANKER1137.png
# Processado: TANKER1138.png -> DDPM-F64x4/TANKER/TANKER1138.png
# Processado: TANKER1139.png -> DDPM-F64x4/TANKER/TANKER1139.png
# Processado: TANKER114.png -> DDPM-F64x4/TANKER/TANKER114.png
# Processado: TANKER1140.png -> DDPM-F64x4/TANKER/TANKER1140.png
# Processado: TANKER1141.png -> DDPM-F64x4/TANKER/TANKER1141.png
# Processado: TANKER1142.png -> DDPM-F64x4/TANKER/TANKER1142.png
# Processado: TANKER1143.png -> DDPM-F64x4/TANKER/TANKER1143.png
# Processado: TANKER1144.png -> DDPM-F64x4/TANKER/TANKER1144.png
# Processado: TANKER1145.png -> DDPM-F64x4/TANKER/TANKER1145.png
# Processado: TANKER1146.png -> DDPM-F64x4/TANKER/TANKER1146.png
# Processado: TANKER1147.png -> DDPM-F64x4/TANKER/TANKER1147.png
# Processado: TANKER1148.png -> DDPM-F64x4/TANKER/TANKER1148.png
# Processado: TANKER1149.png -> DDPM-F64x4/TANKER/TANKER1149.png
# Processado: TANKER115.png -> DDPM-F64x4/TANKER/TANKER115.png
# Processado: TANKER1150.png -> DDPM-F64x4/TANKER/TANKER1150.png
# Processado: TANKER1151.png -> DDPM-F64x4/TANKER/TANKER1151.png
# Processado: TANKER1152.png -> DDPM-F64x4/TANKER/TANKER1152.png
# Processado: TANKER1153.png -> DDPM-F64x4/TANKER/TANKER1153.png
# Processado: TANKER1154.png -> DDPM-F64x4/TANKER/TANKER1154.png
# Processado: TANKER1155.png -> DDPM-F64x4/TANKER/TANKER1155.png
# Processado: TANKER1156.png -> DDPM-F64x4/TANKER/TANKER1156.png
# Processado: TANKER1157.png -> DDPM-F64x4/TANKER/TANKER1157.png
# Processado: TANKER1158.png -> DDPM-F64x4/TANKER/TANKER1158.png
# Processado: TANKER1159.png -> DDPM-F64x4/TANKER/TANKER1159.png
# Processado: TANKER116.png -> DDPM-F64x4/TANKER/TANKER116.png
# Processado: TANKER1160.png -> DDPM-F64x4/TANKER/TANKER1160.png
# Processado: TANKER1161.png -> DDPM-F64x4/TANKER/TANKER1161.png
# Processado: TANKER1162.png -> DDPM-F64x4/TANKER/TANKER1162.png
# Processado: TANKER1163.png -> DDPM-F64x4/TANKER/TANKER1163.png
# Processado: TANKER1164.png -> DDPM-F64x4/TANKER/TANKER1164.png
# Processado: TANKER1165.png -> DDPM-F64x4/TANKER/TANKER1165.png
# Processado: TANKER1166.png -> DDPM-F64x4/TANKER/TANKER1166.png
# Processado: TANKER1167.png -> DDPM-F64x4/TANKER/TANKER1167.png
# Processado: TANKER1168.png -> DDPM-F64x4/TANKER/TANKER1168.png
# Processado: TANKER1169.png -> DDPM-F64x4/TANKER/TANKER1169.png
# Processado: TANKER117.png -> DDPM-F64x4/TANKER/TANKER117.png
# Processado: TANKER1170.png -> DDPM-F64x4/TANKER/TANKER1170.png
# Processado: TANKER1171.png -> DDPM-F64x4/TANKER/TANKER1171.png
# Processado: TANKER1172.png -> DDPM-F64x4/TANKER/TANKER1172.png
# Processado: TANKER1173.png -> DDPM-F64x4/TANKER/TANKER1173.png
# Processado: TANKER1174.png -> DDPM-F64x4/TANKER/TANKER1174.png
# Processado: TANKER1175.png -> DDPM-F64x4/TANKER/TANKER1175.png
# Processado: TANKER1176.png -> DDPM-F64x4/TANKER/TANKER1176.png
# Processado: TANKER1177.png -> DDPM-F64x4/TANKER/TANKER1177.png
# Processado: TANKER1178.png -> DDPM-F64x4/TANKER/TANKER1178.png
# Processado: TANKER1179.png -> DDPM-F64x4/TANKER/TANKER1179.png
# Processado: TANKER118.png -> DDPM-F64x4/TANKER/TANKER118.png
# Processado: TANKER1180.png -> DDPM-F64x4/TANKER/TANKER1180.png
# Processado: TANKER1181.png -> DDPM-F64x4/TANKER/TANKER1181.png
# Processado: TANKER1182.png -> DDPM-F64x4/TANKER/TANKER1182.png
# Processado: TANKER1183.png -> DDPM-F64x4/TANKER/TANKER1183.png
# Processado: TANKER1184.png -> DDPM-F64x4/TANKER/TANKER1184.png
# Processado: TANKER1185.png -> DDPM-F64x4/TANKER/TANKER1185.png
# Processado: TANKER1186.png -> DDPM-F64x4/TANKER/TANKER1186.png
# Processado: TANKER1187.png -> DDPM-F64x4/TANKER/TANKER1187.png
# Processado: TANKER1188.png -> DDPM-F64x4/TANKER/TANKER1188.png
# Processado: TANKER1189.png -> DDPM-F64x4/TANKER/TANKER1189.png
# Processado: TANKER119.png -> DDPM-F64x4/TANKER/TANKER119.png
# Processado: TANKER1190.png -> DDPM-F64x4/TANKER/TANKER1190.png
# Processado: TANKER1191.png -> DDPM-F64x4/TANKER/TANKER1191.png
# Processado: TANKER1192.png -> DDPM-F64x4/TANKER/TANKER1192.png
# Processado: TANKER1193.png -> DDPM-F64x4/TANKER/TANKER1193.png
# Processado: TANKER1194.png -> DDPM-F64x4/TANKER/TANKER1194.png
# Processado: TANKER1195.png -> DDPM-F64x4/TANKER/TANKER1195.png
# Processado: TANKER1196.png -> DDPM-F64x4/TANKER/TANKER1196.png
# Processado: TANKER1197.png -> DDPM-F64x4/TANKER/TANKER1197.png
# Processado: TANKER1198.png -> DDPM-F64x4/TANKER/TANKER1198.png
# Processado: TANKER1199.png -> DDPM-F64x4/TANKER/TANKER1199.png
# Processado: TANKER12.png -> DDPM-F64x4/TANKER/TANKER12.png
# Processado: TANKER120.png -> DDPM-F64x4/TANKER/TANKER120.png
# Processado: TANKER1200.png -> DDPM-F64x4/TANKER/TANKER1200.png
# Processado: TANKER1201.png -> DDPM-F64x4/TANKER/TANKER1201.png
# Processado: TANKER1202.png -> DDPM-F64x4/TANKER/TANKER1202.png
# Processado: TANKER1203.png -> DDPM-F64x4/TANKER/TANKER1203.png
# Processado: TANKER1204.png -> DDPM-F64x4/TANKER/TANKER1204.png
# Processado: TANKER1205.png -> DDPM-F64x4/TANKER/TANKER1205.png
# Processado: TANKER1206.png -> DDPM-F64x4/TANKER/TANKER1206.png
# Processado: TANKER1207.png -> DDPM-F64x4/TANKER/TANKER1207.png
# Processado: TANKER1208.png -> DDPM-F64x4/TANKER/TANKER1208.png
# Processado: TANKER1209.png -> DDPM-F64x4/TANKER/TANKER1209.png
# Processado: TANKER121.png -> DDPM-F64x4/TANKER/TANKER121.png
# Processado: TANKER1210.png -> DDPM-F64x4/TANKER/TANKER1210.png
# Processado: TANKER1211.png -> DDPM-F64x4/TANKER/TANKER1211.png
# Processado: TANKER1212.png -> DDPM-F64x4/TANKER/TANKER1212.png
# Processado: TANKER1213.png -> DDPM-F64x4/TANKER/TANKER1213.png
# Processado: TANKER1214.png -> DDPM-F64x4/TANKER/TANKER1214.png
# Processado: TANKER1215.png -> DDPM-F64x4/TANKER/TANKER1215.png
# Processado: TANKER1216.png -> DDPM-F64x4/TANKER/TANKER1216.png
# Processado: TANKER1217.png -> DDPM-F64x4/TANKER/TANKER1217.png
# Processado: TANKER1218.png -> DDPM-F64x4/TANKER/TANKER1218.png
# Processado: TANKER1219.png -> DDPM-F64x4/TANKER/TANKER1219.png
# Processado: TANKER122.png -> DDPM-F64x4/TANKER/TANKER122.png
# Processado: TANKER1220.png -> DDPM-F64x4/TANKER/TANKER1220.png
# Processado: TANKER1221.png -> DDPM-F64x4/TANKER/TANKER1221.png
# Processado: TANKER1222.png -> DDPM-F64x4/TANKER/TANKER1222.png
# Processado: TANKER1223.png -> DDPM-F64x4/TANKER/TANKER1223.png
# Processado: TANKER1224.png -> DDPM-F64x4/TANKER/TANKER1224.png
# Processado: TANKER1225.png -> DDPM-F64x4/TANKER/TANKER1225.png
# Processado: TANKER1226.png -> DDPM-F64x4/TANKER/TANKER1226.png
# Processado: TANKER1227.png -> DDPM-F64x4/TANKER/TANKER1227.png
# Processado: TANKER1228.png -> DDPM-F64x4/TANKER/TANKER1228.png
# Processado: TANKER1229.png -> DDPM-F64x4/TANKER/TANKER1229.png
# Processado: TANKER123.png -> DDPM-F64x4/TANKER/TANKER123.png
# Processado: TANKER1230.png -> DDPM-F64x4/TANKER/TANKER1230.png
# Processado: TANKER1231.png -> DDPM-F64x4/TANKER/TANKER1231.png
# Processado: TANKER1232.png -> DDPM-F64x4/TANKER/TANKER1232.png
# Processado: TANKER1233.png -> DDPM-F64x4/TANKER/TANKER1233.png
# Processado: TANKER1234.png -> DDPM-F64x4/TANKER/TANKER1234.png
# Processado: TANKER1235.png -> DDPM-F64x4/TANKER/TANKER1235.png
# Processado: TANKER1236.png -> DDPM-F64x4/TANKER/TANKER1236.png
# Processado: TANKER1237.png -> DDPM-F64x4/TANKER/TANKER1237.png
# Processado: TANKER1238.png -> DDPM-F64x4/TANKER/TANKER1238.png
# Processado: TANKER1239.png -> DDPM-F64x4/TANKER/TANKER1239.png
# Processado: TANKER124.png -> DDPM-F64x4/TANKER/TANKER124.png
# Processado: TANKER1240.png -> DDPM-F64x4/TANKER/TANKER1240.png
# Processado: TANKER1241.png -> DDPM-F64x4/TANKER/TANKER1241.png
# Processado: TANKER1242.png -> DDPM-F64x4/TANKER/TANKER1242.png
# Processado: TANKER1243.png -> DDPM-F64x4/TANKER/TANKER1243.png
# Processado: TANKER1244.png -> DDPM-F64x4/TANKER/TANKER1244.png
# Processado: TANKER1245.png -> DDPM-F64x4/TANKER/TANKER1245.png
# Processado: TANKER1246.png -> DDPM-F64x4/TANKER/TANKER1246.png
# Processado: TANKER1247.png -> DDPM-F64x4/TANKER/TANKER1247.png
# Processado: TANKER1248.png -> DDPM-F64x4/TANKER/TANKER1248.png
# Processado: TANKER1249.png -> DDPM-F64x4/TANKER/TANKER1249.png
# Processado: TANKER125.png -> DDPM-F64x4/TANKER/TANKER125.png
# Processado: TANKER1250.png -> DDPM-F64x4/TANKER/TANKER1250.png
# Processado: TANKER1251.png -> DDPM-F64x4/TANKER/TANKER1251.png
# Processado: TANKER1252.png -> DDPM-F64x4/TANKER/TANKER1252.png
# Processado: TANKER1253.png -> DDPM-F64x4/TANKER/TANKER1253.png
# Processado: TANKER1254.png -> DDPM-F64x4/TANKER/TANKER1254.png
# Processado: TANKER1255.png -> DDPM-F64x4/TANKER/TANKER1255.png
# Processado: TANKER1256.png -> DDPM-F64x4/TANKER/TANKER1256.png
# Processado: TANKER1257.png -> DDPM-F64x4/TANKER/TANKER1257.png
# Processado: TANKER1258.png -> DDPM-F64x4/TANKER/TANKER1258.png
# Processado: TANKER1259.png -> DDPM-F64x4/TANKER/TANKER1259.png
# Processado: TANKER126.png -> DDPM-F64x4/TANKER/TANKER126.png
# Processado: TANKER1260.png -> DDPM-F64x4/TANKER/TANKER1260.png
# Processado: TANKER1261.png -> DDPM-F64x4/TANKER/TANKER1261.png
# Processado: TANKER1262.png -> DDPM-F64x4/TANKER/TANKER1262.png
# Processado: TANKER1263.png -> DDPM-F64x4/TANKER/TANKER1263.png
# Processado: TANKER1264.png -> DDPM-F64x4/TANKER/TANKER1264.png
# Processado: TANKER1265.png -> DDPM-F64x4/TANKER/TANKER1265.png
# Processado: TANKER1266.png -> DDPM-F64x4/TANKER/TANKER1266.png
# Processado: TANKER1267.png -> DDPM-F64x4/TANKER/TANKER1267.png
# Processado: TANKER1268.png -> DDPM-F64x4/TANKER/TANKER1268.png
# Processado: TANKER1269.png -> DDPM-F64x4/TANKER/TANKER1269.png
# Processado: TANKER127.png -> DDPM-F64x4/TANKER/TANKER127.png
# Processado: TANKER1270.png -> DDPM-F64x4/TANKER/TANKER1270.png
# Processado: TANKER1271.png -> DDPM-F64x4/TANKER/TANKER1271.png
# Processado: TANKER1272.png -> DDPM-F64x4/TANKER/TANKER1272.png
# Processado: TANKER1273.png -> DDPM-F64x4/TANKER/TANKER1273.png
# Processado: TANKER1274.png -> DDPM-F64x4/TANKER/TANKER1274.png
# Processado: TANKER1275.png -> DDPM-F64x4/TANKER/TANKER1275.png
# Processado: TANKER1276.png -> DDPM-F64x4/TANKER/TANKER1276.png
# Processado: TANKER1277.png -> DDPM-F64x4/TANKER/TANKER1277.png
# Processado: TANKER1278.png -> DDPM-F64x4/TANKER/TANKER1278.png
# Processado: TANKER1279.png -> DDPM-F64x4/TANKER/TANKER1279.png
# Processado: TANKER128.png -> DDPM-F64x4/TANKER/TANKER128.png
# Processado: TANKER1280.png -> DDPM-F64x4/TANKER/TANKER1280.png
# Processado: TANKER1281.png -> DDPM-F64x4/TANKER/TANKER1281.png
# Processado: TANKER1282.png -> DDPM-F64x4/TANKER/TANKER1282.png
# Processado: TANKER1283.png -> DDPM-F64x4/TANKER/TANKER1283.png
# Processado: TANKER1284.png -> DDPM-F64x4/TANKER/TANKER1284.png
# Processado: TANKER1285.png -> DDPM-F64x4/TANKER/TANKER1285.png
# Processado: TANKER1286.png -> DDPM-F64x4/TANKER/TANKER1286.png
# Processado: TANKER1287.png -> DDPM-F64x4/TANKER/TANKER1287.png
# Processado: TANKER1288.png -> DDPM-F64x4/TANKER/TANKER1288.png
# Processado: TANKER1289.png -> DDPM-F64x4/TANKER/TANKER1289.png
# Processado: TANKER129.png -> DDPM-F64x4/TANKER/TANKER129.png
# Processado: TANKER1290.png -> DDPM-F64x4/TANKER/TANKER1290.png
# Processado: TANKER1291.png -> DDPM-F64x4/TANKER/TANKER1291.png
# Processado: TANKER1292.png -> DDPM-F64x4/TANKER/TANKER1292.png
# Processado: TANKER1293.png -> DDPM-F64x4/TANKER/TANKER1293.png
# Processado: TANKER1294.png -> DDPM-F64x4/TANKER/TANKER1294.png
# Processado: TANKER1295.png -> DDPM-F64x4/TANKER/TANKER1295.png
# Processado: TANKER1296.png -> DDPM-F64x4/TANKER/TANKER1296.png
# Processado: TANKER1297.png -> DDPM-F64x4/TANKER/TANKER1297.png
# Processado: TANKER1298.png -> DDPM-F64x4/TANKER/TANKER1298.png
# Processado: TANKER1299.png -> DDPM-F64x4/TANKER/TANKER1299.png
# Processado: TANKER13.png -> DDPM-F64x4/TANKER/TANKER13.png
# Processado: TANKER130.png -> DDPM-F64x4/TANKER/TANKER130.png
# Processado: TANKER1300.png -> DDPM-F64x4/TANKER/TANKER1300.png
# Processado: TANKER1301.png -> DDPM-F64x4/TANKER/TANKER1301.png
# Processado: TANKER1302.png -> DDPM-F64x4/TANKER/TANKER1302.png
# Processado: TANKER1303.png -> DDPM-F64x4/TANKER/TANKER1303.png
# Processado: TANKER1304.png -> DDPM-F64x4/TANKER/TANKER1304.png
# Processado: TANKER1305.png -> DDPM-F64x4/TANKER/TANKER1305.png
# Processado: TANKER1306.png -> DDPM-F64x4/TANKER/TANKER1306.png
# Processado: TANKER1307.png -> DDPM-F64x4/TANKER/TANKER1307.png
# Processado: TANKER1308.png -> DDPM-F64x4/TANKER/TANKER1308.png
# Processado: TANKER1309.png -> DDPM-F64x4/TANKER/TANKER1309.png
# Processado: TANKER131.png -> DDPM-F64x4/TANKER/TANKER131.png
# Processado: TANKER1310.png -> DDPM-F64x4/TANKER/TANKER1310.png
# Processado: TANKER1311.png -> DDPM-F64x4/TANKER/TANKER1311.png
# Processado: TANKER1312.png -> DDPM-F64x4/TANKER/TANKER1312.png
# Processado: TANKER1313.png -> DDPM-F64x4/TANKER/TANKER1313.png
# Processado: TANKER1314.png -> DDPM-F64x4/TANKER/TANKER1314.png
# Processado: TANKER1315.png -> DDPM-F64x4/TANKER/TANKER1315.png
# Processado: TANKER1316.png -> DDPM-F64x4/TANKER/TANKER1316.png
# Processado: TANKER1317.png -> DDPM-F64x4/TANKER/TANKER1317.png
# Processado: TANKER1318.png -> DDPM-F64x4/TANKER/TANKER1318.png
# Processado: TANKER1319.png -> DDPM-F64x4/TANKER/TANKER1319.png
# Processado: TANKER132.png -> DDPM-F64x4/TANKER/TANKER132.png
# Processado: TANKER1320.png -> DDPM-F64x4/TANKER/TANKER1320.png
# Processado: TANKER1321.png -> DDPM-F64x4/TANKER/TANKER1321.png
# Processado: TANKER1322.png -> DDPM-F64x4/TANKER/TANKER1322.png
# Processado: TANKER1323.png -> DDPM-F64x4/TANKER/TANKER1323.png
# Processado: TANKER1324.png -> DDPM-F64x4/TANKER/TANKER1324.png
# Processado: TANKER1325.png -> DDPM-F64x4/TANKER/TANKER1325.png
# Processado: TANKER1326.png -> DDPM-F64x4/TANKER/TANKER1326.png
# Processado: TANKER1327.png -> DDPM-F64x4/TANKER/TANKER1327.png
# Processado: TANKER1328.png -> DDPM-F64x4/TANKER/TANKER1328.png
# Processado: TANKER1329.png -> DDPM-F64x4/TANKER/TANKER1329.png
# Processado: TANKER133.png -> DDPM-F64x4/TANKER/TANKER133.png
# Processado: TANKER1330.png -> DDPM-F64x4/TANKER/TANKER1330.png
# Processado: TANKER1331.png -> DDPM-F64x4/TANKER/TANKER1331.png
# Processado: TANKER1332.png -> DDPM-F64x4/TANKER/TANKER1332.png
# Processado: TANKER1333.png -> DDPM-F64x4/TANKER/TANKER1333.png
# Processado: TANKER1334.png -> DDPM-F64x4/TANKER/TANKER1334.png
# Processado: TANKER1335.png -> DDPM-F64x4/TANKER/TANKER1335.png
# Processado: TANKER1336.png -> DDPM-F64x4/TANKER/TANKER1336.png
# Processado: TANKER1337.png -> DDPM-F64x4/TANKER/TANKER1337.png
# Processado: TANKER1338.png -> DDPM-F64x4/TANKER/TANKER1338.png
# Processado: TANKER1339.png -> DDPM-F64x4/TANKER/TANKER1339.png
# Processado: TANKER134.png -> DDPM-F64x4/TANKER/TANKER134.png
# Processado: TANKER1340.png -> DDPM-F64x4/TANKER/TANKER1340.png
# Processado: TANKER1341.png -> DDPM-F64x4/TANKER/TANKER1341.png
# Processado: TANKER1342.png -> DDPM-F64x4/TANKER/TANKER1342.png
# Processado: TANKER1343.png -> DDPM-F64x4/TANKER/TANKER1343.png
# Processado: TANKER1344.png -> DDPM-F64x4/TANKER/TANKER1344.png
# Processado: TANKER1345.png -> DDPM-F64x4/TANKER/TANKER1345.png
# Processado: TANKER1346.png -> DDPM-F64x4/TANKER/TANKER1346.png
# Processado: TANKER1347.png -> DDPM-F64x4/TANKER/TANKER1347.png
# Processado: TANKER1348.png -> DDPM-F64x4/TANKER/TANKER1348.png
# Processado: TANKER1349.png -> DDPM-F64x4/TANKER/TANKER1349.png
# Processado: TANKER135.png -> DDPM-F64x4/TANKER/TANKER135.png
# Processado: TANKER1350.png -> DDPM-F64x4/TANKER/TANKER1350.png
# Processado: TANKER1351.png -> DDPM-F64x4/TANKER/TANKER1351.png
# Processado: TANKER1352.png -> DDPM-F64x4/TANKER/TANKER1352.png
# Processado: TANKER1353.png -> DDPM-F64x4/TANKER/TANKER1353.png
# Processado: TANKER1354.png -> DDPM-F64x4/TANKER/TANKER1354.png
# Processado: TANKER1355.png -> DDPM-F64x4/TANKER/TANKER1355.png
# Processado: TANKER1356.png -> DDPM-F64x4/TANKER/TANKER1356.png
# Processado: TANKER1357.png -> DDPM-F64x4/TANKER/TANKER1357.png
# Processado: TANKER1358.png -> DDPM-F64x4/TANKER/TANKER1358.png
# Processado: TANKER1359.png -> DDPM-F64x4/TANKER/TANKER1359.png
# Processado: TANKER136.png -> DDPM-F64x4/TANKER/TANKER136.png
# Processado: TANKER1360.png -> DDPM-F64x4/TANKER/TANKER1360.png
# Processado: TANKER1361.png -> DDPM-F64x4/TANKER/TANKER1361.png
# Processado: TANKER1362.png -> DDPM-F64x4/TANKER/TANKER1362.png
# Processado: TANKER1363.png -> DDPM-F64x4/TANKER/TANKER1363.png
# Processado: TANKER1364.png -> DDPM-F64x4/TANKER/TANKER1364.png
# Processado: TANKER1365.png -> DDPM-F64x4/TANKER/TANKER1365.png
# Processado: TANKER1366.png -> DDPM-F64x4/TANKER/TANKER1366.png
# Processado: TANKER1367.png -> DDPM-F64x4/TANKER/TANKER1367.png
# Processado: TANKER1368.png -> DDPM-F64x4/TANKER/TANKER1368.png
# Processado: TANKER1369.png -> DDPM-F64x4/TANKER/TANKER1369.png
# Processado: TANKER137.png -> DDPM-F64x4/TANKER/TANKER137.png
# Processado: TANKER1370.png -> DDPM-F64x4/TANKER/TANKER1370.png
# Processado: TANKER1371.png -> DDPM-F64x4/TANKER/TANKER1371.png
# Processado: TANKER1372.png -> DDPM-F64x4/TANKER/TANKER1372.png
# Processado: TANKER1373.png -> DDPM-F64x4/TANKER/TANKER1373.png
# Processado: TANKER1374.png -> DDPM-F64x4/TANKER/TANKER1374.png
# Processado: TANKER1375.png -> DDPM-F64x4/TANKER/TANKER1375.png
# Processado: TANKER1376.png -> DDPM-F64x4/TANKER/TANKER1376.png
# Processado: TANKER1377.png -> DDPM-F64x4/TANKER/TANKER1377.png
# Processado: TANKER1378.png -> DDPM-F64x4/TANKER/TANKER1378.png
# Processado: TANKER1379.png -> DDPM-F64x4/TANKER/TANKER1379.png
# Processado: TANKER138.png -> DDPM-F64x4/TANKER/TANKER138.png
# Processado: TANKER1380.png -> DDPM-F64x4/TANKER/TANKER1380.png
# Processado: TANKER1381.png -> DDPM-F64x4/TANKER/TANKER1381.png
# Processado: TANKER1382.png -> DDPM-F64x4/TANKER/TANKER1382.png
# Processado: TANKER1383.png -> DDPM-F64x4/TANKER/TANKER1383.png
# Processado: TANKER1384.png -> DDPM-F64x4/TANKER/TANKER1384.png
# Processado: TANKER1385.png -> DDPM-F64x4/TANKER/TANKER1385.png
# Processado: TANKER1386.png -> DDPM-F64x4/TANKER/TANKER1386.png
# Processado: TANKER1387.png -> DDPM-F64x4/TANKER/TANKER1387.png
# Processado: TANKER1388.png -> DDPM-F64x4/TANKER/TANKER1388.png
# Processado: TANKER1389.png -> DDPM-F64x4/TANKER/TANKER1389.png
# Processado: TANKER139.png -> DDPM-F64x4/TANKER/TANKER139.png
# Processado: TANKER1390.png -> DDPM-F64x4/TANKER/TANKER1390.png
# Processado: TANKER1391.png -> DDPM-F64x4/TANKER/TANKER1391.png
# Processado: TANKER1392.png -> DDPM-F64x4/TANKER/TANKER1392.png
# Processado: TANKER1393.png -> DDPM-F64x4/TANKER/TANKER1393.png
# Processado: TANKER1394.png -> DDPM-F64x4/TANKER/TANKER1394.png
# Processado: TANKER1395.png -> DDPM-F64x4/TANKER/TANKER1395.png
# Processado: TANKER1396.png -> DDPM-F64x4/TANKER/TANKER1396.png
# Processado: TANKER1397.png -> DDPM-F64x4/TANKER/TANKER1397.png
# Processado: TANKER1398.png -> DDPM-F64x4/TANKER/TANKER1398.png
# Processado: TANKER1399.png -> DDPM-F64x4/TANKER/TANKER1399.png
# Processado: TANKER14.png -> DDPM-F64x4/TANKER/TANKER14.png
# Processado: TANKER140.png -> DDPM-F64x4/TANKER/TANKER140.png
# Processado: TANKER1400.png -> DDPM-F64x4/TANKER/TANKER1400.png
# Processado: TANKER1401.png -> DDPM-F64x4/TANKER/TANKER1401.png
# Processado: TANKER1402.png -> DDPM-F64x4/TANKER/TANKER1402.png
# Processado: TANKER1403.png -> DDPM-F64x4/TANKER/TANKER1403.png
# Processado: TANKER1404.png -> DDPM-F64x4/TANKER/TANKER1404.png
# Processado: TANKER1405.png -> DDPM-F64x4/TANKER/TANKER1405.png
# Processado: TANKER1406.png -> DDPM-F64x4/TANKER/TANKER1406.png
# Processado: TANKER1407.png -> DDPM-F64x4/TANKER/TANKER1407.png
# Processado: TANKER1408.png -> DDPM-F64x4/TANKER/TANKER1408.png
# Processado: TANKER1409.png -> DDPM-F64x4/TANKER/TANKER1409.png
# Processado: TANKER141.png -> DDPM-F64x4/TANKER/TANKER141.png
# Processado: TANKER1410.png -> DDPM-F64x4/TANKER/TANKER1410.png
# Processado: TANKER1411.png -> DDPM-F64x4/TANKER/TANKER1411.png
# Processado: TANKER1412.png -> DDPM-F64x4/TANKER/TANKER1412.png
# Processado: TANKER1413.png -> DDPM-F64x4/TANKER/TANKER1413.png
# Processado: TANKER1414.png -> DDPM-F64x4/TANKER/TANKER1414.png
# Processado: TANKER1415.png -> DDPM-F64x4/TANKER/TANKER1415.png
# Processado: TANKER1416.png -> DDPM-F64x4/TANKER/TANKER1416.png
# Processado: TANKER1417.png -> DDPM-F64x4/TANKER/TANKER1417.png
# Processado: TANKER1418.png -> DDPM-F64x4/TANKER/TANKER1418.png
# Processado: TANKER1419.png -> DDPM-F64x4/TANKER/TANKER1419.png
# Processado: TANKER142.png -> DDPM-F64x4/TANKER/TANKER142.png
# Processado: TANKER1420.png -> DDPM-F64x4/TANKER/TANKER1420.png
# Processado: TANKER1421.png -> DDPM-F64x4/TANKER/TANKER1421.png
# Processado: TANKER1422.png -> DDPM-F64x4/TANKER/TANKER1422.png
# Processado: TANKER1423.png -> DDPM-F64x4/TANKER/TANKER1423.png
# Processado: TANKER1424.png -> DDPM-F64x4/TANKER/TANKER1424.png
# Processado: TANKER1425.png -> DDPM-F64x4/TANKER/TANKER1425.png
# Processado: TANKER1426.png -> DDPM-F64x4/TANKER/TANKER1426.png
# Processado: TANKER1427.png -> DDPM-F64x4/TANKER/TANKER1427.png
# Processado: TANKER1428.png -> DDPM-F64x4/TANKER/TANKER1428.png
# Processado: TANKER1429.png -> DDPM-F64x4/TANKER/TANKER1429.png
# Processado: TANKER143.png -> DDPM-F64x4/TANKER/TANKER143.png
# Processado: TANKER1430.png -> DDPM-F64x4/TANKER/TANKER1430.png
# Processado: TANKER1431.png -> DDPM-F64x4/TANKER/TANKER1431.png
# Processado: TANKER1432.png -> DDPM-F64x4/TANKER/TANKER1432.png
# Processado: TANKER1433.png -> DDPM-F64x4/TANKER/TANKER1433.png
# Processado: TANKER1434.png -> DDPM-F64x4/TANKER/TANKER1434.png
# Processado: TANKER1435.png -> DDPM-F64x4/TANKER/TANKER1435.png
# Processado: TANKER1436.png -> DDPM-F64x4/TANKER/TANKER1436.png
# Processado: TANKER1437.png -> DDPM-F64x4/TANKER/TANKER1437.png
# Processado: TANKER1438.png -> DDPM-F64x4/TANKER/TANKER1438.png
# Processado: TANKER1439.png -> DDPM-F64x4/TANKER/TANKER1439.png
# Processado: TANKER144.png -> DDPM-F64x4/TANKER/TANKER144.png
# Processado: TANKER1440.png -> DDPM-F64x4/TANKER/TANKER1440.png
# Processado: TANKER1441.png -> DDPM-F64x4/TANKER/TANKER1441.png
# Processado: TANKER1442.png -> DDPM-F64x4/TANKER/TANKER1442.png
# Processado: TANKER1443.png -> DDPM-F64x4/TANKER/TANKER1443.png
# Processado: TANKER1444.png -> DDPM-F64x4/TANKER/TANKER1444.png
# Processado: TANKER1445.png -> DDPM-F64x4/TANKER/TANKER1445.png
# Processado: TANKER1446.png -> DDPM-F64x4/TANKER/TANKER1446.png
# Processado: TANKER1447.png -> DDPM-F64x4/TANKER/TANKER1447.png
# Processado: TANKER1448.png -> DDPM-F64x4/TANKER/TANKER1448.png
# Processado: TANKER1449.png -> DDPM-F64x4/TANKER/TANKER1449.png
# Processado: TANKER145.png -> DDPM-F64x4/TANKER/TANKER145.png
# Processado: TANKER1450.png -> DDPM-F64x4/TANKER/TANKER1450.png
# Processado: TANKER1451.png -> DDPM-F64x4/TANKER/TANKER1451.png
# Processado: TANKER1452.png -> DDPM-F64x4/TANKER/TANKER1452.png
# Processado: TANKER1453.png -> DDPM-F64x4/TANKER/TANKER1453.png
# Processado: TANKER1454.png -> DDPM-F64x4/TANKER/TANKER1454.png
# Processado: TANKER1455.png -> DDPM-F64x4/TANKER/TANKER1455.png
# Processado: TANKER1456.png -> DDPM-F64x4/TANKER/TANKER1456.png
# Processado: TANKER1457.png -> DDPM-F64x4/TANKER/TANKER1457.png
# Processado: TANKER1458.png -> DDPM-F64x4/TANKER/TANKER1458.png
# Processado: TANKER1459.png -> DDPM-F64x4/TANKER/TANKER1459.png
# Processado: TANKER146.png -> DDPM-F64x4/TANKER/TANKER146.png
# Processado: TANKER1460.png -> DDPM-F64x4/TANKER/TANKER1460.png
# Processado: TANKER1461.png -> DDPM-F64x4/TANKER/TANKER1461.png
# Processado: TANKER1462.png -> DDPM-F64x4/TANKER/TANKER1462.png
# Processado: TANKER1463.png -> DDPM-F64x4/TANKER/TANKER1463.png
# Processado: TANKER1464.png -> DDPM-F64x4/TANKER/TANKER1464.png
# Processado: TANKER1465.png -> DDPM-F64x4/TANKER/TANKER1465.png
# Processado: TANKER1466.png -> DDPM-F64x4/TANKER/TANKER1466.png
# Processado: TANKER1467.png -> DDPM-F64x4/TANKER/TANKER1467.png
# Processado: TANKER1468.png -> DDPM-F64x4/TANKER/TANKER1468.png
# Processado: TANKER1469.png -> DDPM-F64x4/TANKER/TANKER1469.png
# Processado: TANKER147.png -> DDPM-F64x4/TANKER/TANKER147.png
# Processado: TANKER1470.png -> DDPM-F64x4/TANKER/TANKER1470.png
# Processado: TANKER1471.png -> DDPM-F64x4/TANKER/TANKER1471.png
# Processado: TANKER1472.png -> DDPM-F64x4/TANKER/TANKER1472.png
# Processado: TANKER1473.png -> DDPM-F64x4/TANKER/TANKER1473.png
# Processado: TANKER1474.png -> DDPM-F64x4/TANKER/TANKER1474.png
# Processado: TANKER1475.png -> DDPM-F64x4/TANKER/TANKER1475.png
# Processado: TANKER1476.png -> DDPM-F64x4/TANKER/TANKER1476.png
# Processado: TANKER1477.png -> DDPM-F64x4/TANKER/TANKER1477.png
# Processado: TANKER1478.png -> DDPM-F64x4/TANKER/TANKER1478.png
# Processado: TANKER1479.png -> DDPM-F64x4/TANKER/TANKER1479.png
# Processado: TANKER148.png -> DDPM-F64x4/TANKER/TANKER148.png
# Processado: TANKER1480.png -> DDPM-F64x4/TANKER/TANKER1480.png
# Processado: TANKER1481.png -> DDPM-F64x4/TANKER/TANKER1481.png
# Processado: TANKER1482.png -> DDPM-F64x4/TANKER/TANKER1482.png
# Processado: TANKER1483.png -> DDPM-F64x4/TANKER/TANKER1483.png
# Processado: TANKER1484.png -> DDPM-F64x4/TANKER/TANKER1484.png
# Processado: TANKER1485.png -> DDPM-F64x4/TANKER/TANKER1485.png
# Processado: TANKER1486.png -> DDPM-F64x4/TANKER/TANKER1486.png
# Processado: TANKER1487.png -> DDPM-F64x4/TANKER/TANKER1487.png
# Processado: TANKER1488.png -> DDPM-F64x4/TANKER/TANKER1488.png
# Processado: TANKER1489.png -> DDPM-F64x4/TANKER/TANKER1489.png
# Processado: TANKER149.png -> DDPM-F64x4/TANKER/TANKER149.png
# Processado: TANKER1490.png -> DDPM-F64x4/TANKER/TANKER1490.png
# Processado: TANKER1491.png -> DDPM-F64x4/TANKER/TANKER1491.png
# Processado: TANKER1492.png -> DDPM-F64x4/TANKER/TANKER1492.png
# Processado: TANKER1493.png -> DDPM-F64x4/TANKER/TANKER1493.png
# Processado: TANKER1494.png -> DDPM-F64x4/TANKER/TANKER1494.png
# Processado: TANKER1495.png -> DDPM-F64x4/TANKER/TANKER1495.png
# Processado: TANKER1496.png -> DDPM-F64x4/TANKER/TANKER1496.png
# Processado: TANKER1497.png -> DDPM-F64x4/TANKER/TANKER1497.png
# Processado: TANKER1498.png -> DDPM-F64x4/TANKER/TANKER1498.png
# Processado: TANKER1499.png -> DDPM-F64x4/TANKER/TANKER1499.png
# Processado: TANKER15.png -> DDPM-F64x4/TANKER/TANKER15.png
# Processado: TANKER150.png -> DDPM-F64x4/TANKER/TANKER150.png
# Processado: TANKER1500.png -> DDPM-F64x4/TANKER/TANKER1500.png
# Processado: TANKER1501.png -> DDPM-F64x4/TANKER/TANKER1501.png
# Processado: TANKER1502.png -> DDPM-F64x4/TANKER/TANKER1502.png
# Processado: TANKER1503.png -> DDPM-F64x4/TANKER/TANKER1503.png
# Processado: TANKER1504.png -> DDPM-F64x4/TANKER/TANKER1504.png
# Processado: TANKER1505.png -> DDPM-F64x4/TANKER/TANKER1505.png
# Processado: TANKER1506.png -> DDPM-F64x4/TANKER/TANKER1506.png
# Processado: TANKER1507.png -> DDPM-F64x4/TANKER/TANKER1507.png
# Processado: TANKER1508.png -> DDPM-F64x4/TANKER/TANKER1508.png
# Processado: TANKER1509.png -> DDPM-F64x4/TANKER/TANKER1509.png
# Processado: TANKER151.png -> DDPM-F64x4/TANKER/TANKER151.png
# Processado: TANKER1510.png -> DDPM-F64x4/TANKER/TANKER1510.png
# Processado: TANKER1511.png -> DDPM-F64x4/TANKER/TANKER1511.png
# Processado: TANKER1512.png -> DDPM-F64x4/TANKER/TANKER1512.png
# Processado: TANKER1513.png -> DDPM-F64x4/TANKER/TANKER1513.png
# Processado: TANKER1514.png -> DDPM-F64x4/TANKER/TANKER1514.png
# Processado: TANKER1515.png -> DDPM-F64x4/TANKER/TANKER1515.png
# Processado: TANKER1516.png -> DDPM-F64x4/TANKER/TANKER1516.png
# Processado: TANKER1517.png -> DDPM-F64x4/TANKER/TANKER1517.png
# Processado: TANKER1518.png -> DDPM-F64x4/TANKER/TANKER1518.png
# Processado: TANKER1519.png -> DDPM-F64x4/TANKER/TANKER1519.png
# Processado: TANKER152.png -> DDPM-F64x4/TANKER/TANKER152.png
# Processado: TANKER1520.png -> DDPM-F64x4/TANKER/TANKER1520.png
# Processado: TANKER1521.png -> DDPM-F64x4/TANKER/TANKER1521.png
# Processado: TANKER1522.png -> DDPM-F64x4/TANKER/TANKER1522.png
# Processado: TANKER1523.png -> DDPM-F64x4/TANKER/TANKER1523.png
# Processado: TANKER1524.png -> DDPM-F64x4/TANKER/TANKER1524.png
# Processado: TANKER1525.png -> DDPM-F64x4/TANKER/TANKER1525.png
# Processado: TANKER1526.png -> DDPM-F64x4/TANKER/TANKER1526.png
# Processado: TANKER1527.png -> DDPM-F64x4/TANKER/TANKER1527.png
# Processado: TANKER1528.png -> DDPM-F64x4/TANKER/TANKER1528.png
# Processado: TANKER1529.png -> DDPM-F64x4/TANKER/TANKER1529.png
# Processado: TANKER153.png -> DDPM-F64x4/TANKER/TANKER153.png
# Processado: TANKER1530.png -> DDPM-F64x4/TANKER/TANKER1530.png
# Processado: TANKER1531.png -> DDPM-F64x4/TANKER/TANKER1531.png
# Processado: TANKER1532.png -> DDPM-F64x4/TANKER/TANKER1532.png
# Processado: TANKER1533.png -> DDPM-F64x4/TANKER/TANKER1533.png
# Processado: TANKER1534.png -> DDPM-F64x4/TANKER/TANKER1534.png
# Processado: TANKER1535.png -> DDPM-F64x4/TANKER/TANKER1535.png
# Processado: TANKER1536.png -> DDPM-F64x4/TANKER/TANKER1536.png
# Processado: TANKER1537.png -> DDPM-F64x4/TANKER/TANKER1537.png
# Processado: TANKER1538.png -> DDPM-F64x4/TANKER/TANKER1538.png
# Processado: TANKER1539.png -> DDPM-F64x4/TANKER/TANKER1539.png
# Processado: TANKER154.png -> DDPM-F64x4/TANKER/TANKER154.png
# Processado: TANKER1540.png -> DDPM-F64x4/TANKER/TANKER1540.png
# Processado: TANKER1541.png -> DDPM-F64x4/TANKER/TANKER1541.png
# Processado: TANKER1542.png -> DDPM-F64x4/TANKER/TANKER1542.png
# Processado: TANKER1543.png -> DDPM-F64x4/TANKER/TANKER1543.png
# Processado: TANKER1544.png -> DDPM-F64x4/TANKER/TANKER1544.png
# Processado: TANKER1545.png -> DDPM-F64x4/TANKER/TANKER1545.png
# Processado: TANKER1546.png -> DDPM-F64x4/TANKER/TANKER1546.png
# Processado: TANKER1547.png -> DDPM-F64x4/TANKER/TANKER1547.png
# Processado: TANKER1548.png -> DDPM-F64x4/TANKER/TANKER1548.png
# Processado: TANKER1549.png -> DDPM-F64x4/TANKER/TANKER1549.png
# Processado: TANKER155.png -> DDPM-F64x4/TANKER/TANKER155.png
# Processado: TANKER1550.png -> DDPM-F64x4/TANKER/TANKER1550.png
# Processado: TANKER1551.png -> DDPM-F64x4/TANKER/TANKER1551.png
# Processado: TANKER1552.png -> DDPM-F64x4/TANKER/TANKER1552.png
# Processado: TANKER1553.png -> DDPM-F64x4/TANKER/TANKER1553.png
# Processado: TANKER1554.png -> DDPM-F64x4/TANKER/TANKER1554.png
# Processado: TANKER1555.png -> DDPM-F64x4/TANKER/TANKER1555.png
# Processado: TANKER1556.png -> DDPM-F64x4/TANKER/TANKER1556.png
# Processado: TANKER1557.png -> DDPM-F64x4/TANKER/TANKER1557.png
# Processado: TANKER1558.png -> DDPM-F64x4/TANKER/TANKER1558.png
# Processado: TANKER1559.png -> DDPM-F64x4/TANKER/TANKER1559.png
# Processado: TANKER156.png -> DDPM-F64x4/TANKER/TANKER156.png
# Processado: TANKER1560.png -> DDPM-F64x4/TANKER/TANKER1560.png
# Processado: TANKER1561.png -> DDPM-F64x4/TANKER/TANKER1561.png
# Processado: TANKER1562.png -> DDPM-F64x4/TANKER/TANKER1562.png
# Processado: TANKER1563.png -> DDPM-F64x4/TANKER/TANKER1563.png
# Processado: TANKER1564.png -> DDPM-F64x4/TANKER/TANKER1564.png
# Processado: TANKER1565.png -> DDPM-F64x4/TANKER/TANKER1565.png
# Processado: TANKER1566.png -> DDPM-F64x4/TANKER/TANKER1566.png
# Processado: TANKER1567.png -> DDPM-F64x4/TANKER/TANKER1567.png
# Processado: TANKER1568.png -> DDPM-F64x4/TANKER/TANKER1568.png
# Processado: TANKER1569.png -> DDPM-F64x4/TANKER/TANKER1569.png
# Processado: TANKER157.png -> DDPM-F64x4/TANKER/TANKER157.png
# Processado: TANKER1570.png -> DDPM-F64x4/TANKER/TANKER1570.png
# Processado: TANKER1571.png -> DDPM-F64x4/TANKER/TANKER1571.png
# Processado: TANKER1572.png -> DDPM-F64x4/TANKER/TANKER1572.png
# Processado: TANKER1573.png -> DDPM-F64x4/TANKER/TANKER1573.png
# Processado: TANKER1574.png -> DDPM-F64x4/TANKER/TANKER1574.png
# Processado: TANKER1575.png -> DDPM-F64x4/TANKER/TANKER1575.png
# Processado: TANKER1576.png -> DDPM-F64x4/TANKER/TANKER1576.png
# Processado: TANKER1577.png -> DDPM-F64x4/TANKER/TANKER1577.png
# Processado: TANKER1578.png -> DDPM-F64x4/TANKER/TANKER1578.png
# Processado: TANKER1579.png -> DDPM-F64x4/TANKER/TANKER1579.png
# Processado: TANKER158.png -> DDPM-F64x4/TANKER/TANKER158.png
# Processado: TANKER1580.png -> DDPM-F64x4/TANKER/TANKER1580.png
# Processado: TANKER1581.png -> DDPM-F64x4/TANKER/TANKER1581.png
# Processado: TANKER1582.png -> DDPM-F64x4/TANKER/TANKER1582.png
# Processado: TANKER1583.png -> DDPM-F64x4/TANKER/TANKER1583.png
# Processado: TANKER1584.png -> DDPM-F64x4/TANKER/TANKER1584.png
# Processado: TANKER1585.png -> DDPM-F64x4/TANKER/TANKER1585.png
# Processado: TANKER1586.png -> DDPM-F64x4/TANKER/TANKER1586.png
# Processado: TANKER1587.png -> DDPM-F64x4/TANKER/TANKER1587.png
# Processado: TANKER1588.png -> DDPM-F64x4/TANKER/TANKER1588.png
# Processado: TANKER1589.png -> DDPM-F64x4/TANKER/TANKER1589.png
# Processado: TANKER159.png -> DDPM-F64x4/TANKER/TANKER159.png
# Processado: TANKER1590.png -> DDPM-F64x4/TANKER/TANKER1590.png
# Processado: TANKER1591.png -> DDPM-F64x4/TANKER/TANKER1591.png
# Processado: TANKER1592.png -> DDPM-F64x4/TANKER/TANKER1592.png
# Processado: TANKER1593.png -> DDPM-F64x4/TANKER/TANKER1593.png
# Processado: TANKER1594.png -> DDPM-F64x4/TANKER/TANKER1594.png
# Processado: TANKER1595.png -> DDPM-F64x4/TANKER/TANKER1595.png
# Processado: TANKER1596.png -> DDPM-F64x4/TANKER/TANKER1596.png
# Processado: TANKER1597.png -> DDPM-F64x4/TANKER/TANKER1597.png
# Processado: TANKER1598.png -> DDPM-F64x4/TANKER/TANKER1598.png
# Processado: TANKER1599.png -> DDPM-F64x4/TANKER/TANKER1599.png
# Processado: TANKER16.png -> DDPM-F64x4/TANKER/TANKER16.png
# Processado: TANKER160.png -> DDPM-F64x4/TANKER/TANKER160.png
# Processado: TANKER1600.png -> DDPM-F64x4/TANKER/TANKER1600.png
# Processado: TANKER1601.png -> DDPM-F64x4/TANKER/TANKER1601.png
# Processado: TANKER1602.png -> DDPM-F64x4/TANKER/TANKER1602.png
# Processado: TANKER1603.png -> DDPM-F64x4/TANKER/TANKER1603.png
# Processado: TANKER1604.png -> DDPM-F64x4/TANKER/TANKER1604.png
# Processado: TANKER1605.png -> DDPM-F64x4/TANKER/TANKER1605.png
# Processado: TANKER1606.png -> DDPM-F64x4/TANKER/TANKER1606.png
# Processado: TANKER1607.png -> DDPM-F64x4/TANKER/TANKER1607.png
# Processado: TANKER1608.png -> DDPM-F64x4/TANKER/TANKER1608.png
# Processado: TANKER1609.png -> DDPM-F64x4/TANKER/TANKER1609.png
# Processado: TANKER161.png -> DDPM-F64x4/TANKER/TANKER161.png
# Processado: TANKER1610.png -> DDPM-F64x4/TANKER/TANKER1610.png
# Processado: TANKER1611.png -> DDPM-F64x4/TANKER/TANKER1611.png
# Processado: TANKER1612.png -> DDPM-F64x4/TANKER/TANKER1612.png
# Processado: TANKER1613.png -> DDPM-F64x4/TANKER/TANKER1613.png
# Processado: TANKER1614.png -> DDPM-F64x4/TANKER/TANKER1614.png
# Processado: TANKER1615.png -> DDPM-F64x4/TANKER/TANKER1615.png
# Processado: TANKER1616.png -> DDPM-F64x4/TANKER/TANKER1616.png
# Processado: TANKER1617.png -> DDPM-F64x4/TANKER/TANKER1617.png
# Processado: TANKER1618.png -> DDPM-F64x4/TANKER/TANKER1618.png
# Processado: TANKER1619.png -> DDPM-F64x4/TANKER/TANKER1619.png
# Processado: TANKER162.png -> DDPM-F64x4/TANKER/TANKER162.png
# Processado: TANKER1620.png -> DDPM-F64x4/TANKER/TANKER1620.png
# Processado: TANKER1621.png -> DDPM-F64x4/TANKER/TANKER1621.png
# Processado: TANKER1622.png -> DDPM-F64x4/TANKER/TANKER1622.png
# Processado: TANKER1623.png -> DDPM-F64x4/TANKER/TANKER1623.png
# Processado: TANKER1624.png -> DDPM-F64x4/TANKER/TANKER1624.png
# Processado: TANKER1625.png -> DDPM-F64x4/TANKER/TANKER1625.png
# Processado: TANKER1626.png -> DDPM-F64x4/TANKER/TANKER1626.png
# Processado: TANKER1627.png -> DDPM-F64x4/TANKER/TANKER1627.png
# Processado: TANKER1628.png -> DDPM-F64x4/TANKER/TANKER1628.png
# Processado: TANKER1629.png -> DDPM-F64x4/TANKER/TANKER1629.png
# Processado: TANKER163.png -> DDPM-F64x4/TANKER/TANKER163.png
# Processado: TANKER1630.png -> DDPM-F64x4/TANKER/TANKER1630.png
# Processado: TANKER1631.png -> DDPM-F64x4/TANKER/TANKER1631.png
# Processado: TANKER1632.png -> DDPM-F64x4/TANKER/TANKER1632.png
# Processado: TANKER1633.png -> DDPM-F64x4/TANKER/TANKER1633.png
# Processado: TANKER1634.png -> DDPM-F64x4/TANKER/TANKER1634.png
# Processado: TANKER1635.png -> DDPM-F64x4/TANKER/TANKER1635.png
# Processado: TANKER1636.png -> DDPM-F64x4/TANKER/TANKER1636.png
# Processado: TANKER1637.png -> DDPM-F64x4/TANKER/TANKER1637.png
# Processado: TANKER1638.png -> DDPM-F64x4/TANKER/TANKER1638.png
# Processado: TANKER1639.png -> DDPM-F64x4/TANKER/TANKER1639.png
# Processado: TANKER164.png -> DDPM-F64x4/TANKER/TANKER164.png
# Processado: TANKER1640.png -> DDPM-F64x4/TANKER/TANKER1640.png
# Processado: TANKER1641.png -> DDPM-F64x4/TANKER/TANKER1641.png
# Processado: TANKER1642.png -> DDPM-F64x4/TANKER/TANKER1642.png
# Processado: TANKER1643.png -> DDPM-F64x4/TANKER/TANKER1643.png
# Processado: TANKER1644.png -> DDPM-F64x4/TANKER/TANKER1644.png
# Processado: TANKER1645.png -> DDPM-F64x4/TANKER/TANKER1645.png
# Processado: TANKER1646.png -> DDPM-F64x4/TANKER/TANKER1646.png
# Processado: TANKER1647.png -> DDPM-F64x4/TANKER/TANKER1647.png
# Processado: TANKER1648.png -> DDPM-F64x4/TANKER/TANKER1648.png
# Processado: TANKER1649.png -> DDPM-F64x4/TANKER/TANKER1649.png
# Processado: TANKER165.png -> DDPM-F64x4/TANKER/TANKER165.png
# Processado: TANKER1650.png -> DDPM-F64x4/TANKER/TANKER1650.png
# Processado: TANKER1651.png -> DDPM-F64x4/TANKER/TANKER1651.png
# Processado: TANKER1652.png -> DDPM-F64x4/TANKER/TANKER1652.png
# Processado: TANKER1653.png -> DDPM-F64x4/TANKER/TANKER1653.png
# Processado: TANKER1654.png -> DDPM-F64x4/TANKER/TANKER1654.png
# Processado: TANKER1655.png -> DDPM-F64x4/TANKER/TANKER1655.png
# Processado: TANKER1656.png -> DDPM-F64x4/TANKER/TANKER1656.png
# Processado: TANKER1657.png -> DDPM-F64x4/TANKER/TANKER1657.png
# Processado: TANKER1658.png -> DDPM-F64x4/TANKER/TANKER1658.png
# Processado: TANKER1659.png -> DDPM-F64x4/TANKER/TANKER1659.png
# Processado: TANKER166.png -> DDPM-F64x4/TANKER/TANKER166.png
# Processado: TANKER1660.png -> DDPM-F64x4/TANKER/TANKER1660.png
# Processado: TANKER1661.png -> DDPM-F64x4/TANKER/TANKER1661.png
# Processado: TANKER1662.png -> DDPM-F64x4/TANKER/TANKER1662.png
# Processado: TANKER1663.png -> DDPM-F64x4/TANKER/TANKER1663.png
# Processado: TANKER1664.png -> DDPM-F64x4/TANKER/TANKER1664.png
# Processado: TANKER1665.png -> DDPM-F64x4/TANKER/TANKER1665.png
# Processado: TANKER1666.png -> DDPM-F64x4/TANKER/TANKER1666.png
# Processado: TANKER1667.png -> DDPM-F64x4/TANKER/TANKER1667.png
# Processado: TANKER1668.png -> DDPM-F64x4/TANKER/TANKER1668.png
# Processado: TANKER1669.png -> DDPM-F64x4/TANKER/TANKER1669.png
# Processado: TANKER167.png -> DDPM-F64x4/TANKER/TANKER167.png
# Processado: TANKER1670.png -> DDPM-F64x4/TANKER/TANKER1670.png
# Processado: TANKER1671.png -> DDPM-F64x4/TANKER/TANKER1671.png
# Processado: TANKER1672.png -> DDPM-F64x4/TANKER/TANKER1672.png
# Processado: TANKER1673.png -> DDPM-F64x4/TANKER/TANKER1673.png
# Processado: TANKER1674.png -> DDPM-F64x4/TANKER/TANKER1674.png
# Processado: TANKER1675.png -> DDPM-F64x4/TANKER/TANKER1675.png
# Processado: TANKER1676.png -> DDPM-F64x4/TANKER/TANKER1676.png
# Processado: TANKER1677.png -> DDPM-F64x4/TANKER/TANKER1677.png
# Processado: TANKER1678.png -> DDPM-F64x4/TANKER/TANKER1678.png
# Processado: TANKER1679.png -> DDPM-F64x4/TANKER/TANKER1679.png
# Processado: TANKER168.png -> DDPM-F64x4/TANKER/TANKER168.png
# Processado: TANKER1680.png -> DDPM-F64x4/TANKER/TANKER1680.png
# Processado: TANKER1681.png -> DDPM-F64x4/TANKER/TANKER1681.png
# Processado: TANKER1682.png -> DDPM-F64x4/TANKER/TANKER1682.png
# Processado: TANKER1683.png -> DDPM-F64x4/TANKER/TANKER1683.png
# Processado: TANKER1684.png -> DDPM-F64x4/TANKER/TANKER1684.png
# Processado: TANKER1685.png -> DDPM-F64x4/TANKER/TANKER1685.png
# ...
# Processado: TANKER763.png -> DDPM-F64x4/TANKER/TANKER763.png
# Processado: TANKER764.png -> DDPM-F64x4/TANKER/TANKER764.png
# Processado: TANKER765.png -> DDPM-F64x4/TANKER/TANKER765.png
# Processado: TANKER766.png -> DDPM-F64x4/TANKER/TANKER766.png
# Processado: TANKER767.png -> DDPM-F64x4/TANKER/TANKER767.png
# Processado: TANKER768.png -> DDPM-F64x4/TANKER/TANKER768.png
# Processado: TANKER769.png -> DDPM-F64x4/TANKER/TANKER769.png
# Processado: TANKER77.png -> DDPM-F64x4/TANKER/TANKER77.png
# Processado: TANKER770.png -> DDPM-F64x4/TANKER/TANKER770.png
# Processado: TANKER771.png -> DDPM-F64x4/TANKER/TANKER771.png
# Processado: TANKER772.png -> DDPM-F64x4/TANKER/TANKER772.png
# Processado: TANKER773.png -> DDPM-F64x4/TANKER/TANKER773.png
# Processado: TANKER774.png -> DDPM-F64x4/TANKER/TANKER774.png
# Processado: TANKER775.png -> DDPM-F64x4/TANKER/TANKER775.png
# Processado: TANKER776.png -> DDPM-F64x4/TANKER/TANKER776.png
# Processado: TANKER777.png -> DDPM-F64x4/TANKER/TANKER777.png
# Processado: TANKER778.png -> DDPM-F64x4/TANKER/TANKER778.png
# Processado: TANKER779.png -> DDPM-F64x4/TANKER/TANKER779.png
# Processado: TANKER78.png -> DDPM-F64x4/TANKER/TANKER78.png
# Processado: TANKER780.png -> DDPM-F64x4/TANKER/TANKER780.png
# Processado: TANKER781.png -> DDPM-F64x4/TANKER/TANKER781.png
# Processado: TANKER782.png -> DDPM-F64x4/TANKER/TANKER782.png
# Processado: TANKER783.png -> DDPM-F64x4/TANKER/TANKER783.png
# Processado: TANKER784.png -> DDPM-F64x4/TANKER/TANKER784.png
# Processado: TANKER785.png -> DDPM-F64x4/TANKER/TANKER785.png
# Processado: TANKER786.png -> DDPM-F64x4/TANKER/TANKER786.png
# Processado: TANKER787.png -> DDPM-F64x4/TANKER/TANKER787.png
# Processado: TANKER788.png -> DDPM-F64x4/TANKER/TANKER788.png
# Processado: TANKER789.png -> DDPM-F64x4/TANKER/TANKER789.png
# Processado: TANKER79.png -> DDPM-F64x4/TANKER/TANKER79.png
# Processado: TANKER790.png -> DDPM-F64x4/TANKER/TANKER790.png
# Processado: TANKER791.png -> DDPM-F64x4/TANKER/TANKER791.png
# Processado: TANKER792.png -> DDPM-F64x4/TANKER/TANKER792.png
# Processado: TANKER793.png -> DDPM-F64x4/TANKER/TANKER793.png
# Processado: TANKER794.png -> DDPM-F64x4/TANKER/TANKER794.png
# Processado: TANKER795.png -> DDPM-F64x4/TANKER/TANKER795.png
# Processado: TANKER796.png -> DDPM-F64x4/TANKER/TANKER796.png
# Processado: TANKER797.png -> DDPM-F64x4/TANKER/TANKER797.png
# Processado: TANKER798.png -> DDPM-F64x4/TANKER/TANKER798.png
# Processado: TANKER799.png -> DDPM-F64x4/TANKER/TANKER799.png
# Processado: TANKER8.png -> DDPM-F64x4/TANKER/TANKER8.png
# Processado: TANKER80.png -> DDPM-F64x4/TANKER/TANKER80.png
# Processado: TANKER800.png -> DDPM-F64x4/TANKER/TANKER800.png
# Processado: TANKER801.png -> DDPM-F64x4/TANKER/TANKER801.png
# Processado: TANKER802.png -> DDPM-F64x4/TANKER/TANKER802.png
# Processado: TANKER803.png -> DDPM-F64x4/TANKER/TANKER803.png
# Processado: TANKER804.png -> DDPM-F64x4/TANKER/TANKER804.png
# Processado: TANKER805.png -> DDPM-F64x4/TANKER/TANKER805.png
# Processado: TANKER806.png -> DDPM-F64x4/TANKER/TANKER806.png
# Processado: TANKER807.png -> DDPM-F64x4/TANKER/TANKER807.png
# Processado: TANKER808.png -> DDPM-F64x4/TANKER/TANKER808.png
# Processado: TANKER809.png -> DDPM-F64x4/TANKER/TANKER809.png
# Processado: TANKER81.png -> DDPM-F64x4/TANKER/TANKER81.png
# Processado: TANKER810.png -> DDPM-F64x4/TANKER/TANKER810.png
# Processado: TANKER811.png -> DDPM-F64x4/TANKER/TANKER811.png
# Processado: TANKER812.png -> DDPM-F64x4/TANKER/TANKER812.png
# Processado: TANKER813.png -> DDPM-F64x4/TANKER/TANKER813.png
# Processado: TANKER814.png -> DDPM-F64x4/TANKER/TANKER814.png
# Processado: TANKER815.png -> DDPM-F64x4/TANKER/TANKER815.png
# Processado: TANKER816.png -> DDPM-F64x4/TANKER/TANKER816.png
# Processado: TANKER817.png -> DDPM-F64x4/TANKER/TANKER817.png
# Processado: TANKER818.png -> DDPM-F64x4/TANKER/TANKER818.png
# Processado: TANKER819.png -> DDPM-F64x4/TANKER/TANKER819.png
# Processado: TANKER82.png -> DDPM-F64x4/TANKER/TANKER82.png
# Processado: TANKER820.png -> DDPM-F64x4/TANKER/TANKER820.png
# Processado: TANKER821.png -> DDPM-F64x4/TANKER/TANKER821.png
# Processado: TANKER822.png -> DDPM-F64x4/TANKER/TANKER822.png
# Processado: TANKER823.png -> DDPM-F64x4/TANKER/TANKER823.png
# Processado: TANKER824.png -> DDPM-F64x4/TANKER/TANKER824.png
# Processado: TANKER825.png -> DDPM-F64x4/TANKER/TANKER825.png
# Processado: TANKER826.png -> DDPM-F64x4/TANKER/TANKER826.png
# Processado: TANKER827.png -> DDPM-F64x4/TANKER/TANKER827.png
# Processado: TANKER828.png -> DDPM-F64x4/TANKER/TANKER828.png
# Processado: TANKER829.png -> DDPM-F64x4/TANKER/TANKER829.png
# Processado: TANKER83.png -> DDPM-F64x4/TANKER/TANKER83.png
# Processado: TANKER830.png -> DDPM-F64x4/TANKER/TANKER830.png
# Processado: TANKER831.png -> DDPM-F64x4/TANKER/TANKER831.png
# Processado: TANKER832.png -> DDPM-F64x4/TANKER/TANKER832.png
# Processado: TANKER833.png -> DDPM-F64x4/TANKER/TANKER833.png
# Processado: TANKER834.png -> DDPM-F64x4/TANKER/TANKER834.png
# Processado: TANKER835.png -> DDPM-F64x4/TANKER/TANKER835.png
# Processado: TANKER836.png -> DDPM-F64x4/TANKER/TANKER836.png
# Processado: TANKER837.png -> DDPM-F64x4/TANKER/TANKER837.png
# Processado: TANKER838.png -> DDPM-F64x4/TANKER/TANKER838.png
# Processado: TANKER839.png -> DDPM-F64x4/TANKER/TANKER839.png
# Processado: TANKER84.png -> DDPM-F64x4/TANKER/TANKER84.png
# Processado: TANKER840.png -> DDPM-F64x4/TANKER/TANKER840.png
# Processado: TANKER841.png -> DDPM-F64x4/TANKER/TANKER841.png
# Processado: TANKER842.png -> DDPM-F64x4/TANKER/TANKER842.png
# Processado: TANKER843.png -> DDPM-F64x4/TANKER/TANKER843.png
# Processado: TANKER844.png -> DDPM-F64x4/TANKER/TANKER844.png
# Processado: TANKER845.png -> DDPM-F64x4/TANKER/TANKER845.png
# Processado: TANKER846.png -> DDPM-F64x4/TANKER/TANKER846.png
# Processado: TANKER847.png -> DDPM-F64x4/TANKER/TANKER847.png
# Processado: TANKER848.png -> DDPM-F64x4/TANKER/TANKER848.png
# Processado: TANKER849.png -> DDPM-F64x4/TANKER/TANKER849.png
# Processado: TANKER85.png -> DDPM-F64x4/TANKER/TANKER85.png
# Processado: TANKER850.png -> DDPM-F64x4/TANKER/TANKER850.png
# Processado: TANKER851.png -> DDPM-F64x4/TANKER/TANKER851.png
# Processado: TANKER852.png -> DDPM-F64x4/TANKER/TANKER852.png
# Processado: TANKER853.png -> DDPM-F64x4/TANKER/TANKER853.png
# Processado: TANKER854.png -> DDPM-F64x4/TANKER/TANKER854.png
# Processado: TANKER855.png -> DDPM-F64x4/TANKER/TANKER855.png
# Processado: TANKER856.png -> DDPM-F64x4/TANKER/TANKER856.png
# Processado: TANKER857.png -> DDPM-F64x4/TANKER/TANKER857.png
# Processado: TANKER858.png -> DDPM-F64x4/TANKER/TANKER858.png
# Processado: TANKER859.png -> DDPM-F64x4/TANKER/TANKER859.png
# Processado: TANKER86.png -> DDPM-F64x4/TANKER/TANKER86.png
# Processado: TANKER860.png -> DDPM-F64x4/TANKER/TANKER860.png
# Processado: TANKER861.png -> DDPM-F64x4/TANKER/TANKER861.png
# Processado: TANKER862.png -> DDPM-F64x4/TANKER/TANKER862.png
# Processado: TANKER863.png -> DDPM-F64x4/TANKER/TANKER863.png
# Processado: TANKER864.png -> DDPM-F64x4/TANKER/TANKER864.png
# Processado: TANKER865.png -> DDPM-F64x4/TANKER/TANKER865.png
# Processado: TANKER866.png -> DDPM-F64x4/TANKER/TANKER866.png
# Processado: TANKER867.png -> DDPM-F64x4/TANKER/TANKER867.png
# Processado: TANKER868.png -> DDPM-F64x4/TANKER/TANKER868.png
# Processado: TANKER869.png -> DDPM-F64x4/TANKER/TANKER869.png
# Processado: TANKER87.png -> DDPM-F64x4/TANKER/TANKER87.png
# Processado: TANKER870.png -> DDPM-F64x4/TANKER/TANKER870.png
# Processado: TANKER871.png -> DDPM-F64x4/TANKER/TANKER871.png
# Processado: TANKER872.png -> DDPM-F64x4/TANKER/TANKER872.png
# Processado: TANKER873.png -> DDPM-F64x4/TANKER/TANKER873.png
# Processado: TANKER874.png -> DDPM-F64x4/TANKER/TANKER874.png
# Processado: TANKER875.png -> DDPM-F64x4/TANKER/TANKER875.png
# Processado: TANKER876.png -> DDPM-F64x4/TANKER/TANKER876.png
# Processado: TANKER877.png -> DDPM-F64x4/TANKER/TANKER877.png
# Processado: TANKER878.png -> DDPM-F64x4/TANKER/TANKER878.png
# Processado: TANKER879.png -> DDPM-F64x4/TANKER/TANKER879.png
# Processado: TANKER88.png -> DDPM-F64x4/TANKER/TANKER88.png
# Processado: TANKER880.png -> DDPM-F64x4/TANKER/TANKER880.png
# Processado: TANKER881.png -> DDPM-F64x4/TANKER/TANKER881.png
# Processado: TANKER882.png -> DDPM-F64x4/TANKER/TANKER882.png
# Processado: TANKER883.png -> DDPM-F64x4/TANKER/TANKER883.png
# Processado: TANKER884.png -> DDPM-F64x4/TANKER/TANKER884.png
# Processado: TANKER885.png -> DDPM-F64x4/TANKER/TANKER885.png
# Processado: TANKER886.png -> DDPM-F64x4/TANKER/TANKER886.png
# Processado: TANKER887.png -> DDPM-F64x4/TANKER/TANKER887.png
# Processado: TANKER888.png -> DDPM-F64x4/TANKER/TANKER888.png
# Processado: TANKER889.png -> DDPM-F64x4/TANKER/TANKER889.png
# Processado: TANKER89.png -> DDPM-F64x4/TANKER/TANKER89.png
# Processado: TANKER890.png -> DDPM-F64x4/TANKER/TANKER890.png
# Processado: TANKER891.png -> DDPM-F64x4/TANKER/TANKER891.png
# Processado: TANKER892.png -> DDPM-F64x4/TANKER/TANKER892.png
# Processado: TANKER893.png -> DDPM-F64x4/TANKER/TANKER893.png
# Processado: TANKER894.png -> DDPM-F64x4/TANKER/TANKER894.png
# Processado: TANKER895.png -> DDPM-F64x4/TANKER/TANKER895.png
# Processado: TANKER896.png -> DDPM-F64x4/TANKER/TANKER896.png
# Processado: TANKER897.png -> DDPM-F64x4/TANKER/TANKER897.png
# Processado: TANKER898.png -> DDPM-F64x4/TANKER/TANKER898.png
# Processado: TANKER899.png -> DDPM-F64x4/TANKER/TANKER899.png
# Processado: TANKER9.png -> DDPM-F64x4/TANKER/TANKER9.png
# Processado: TANKER90.png -> DDPM-F64x4/TANKER/TANKER90.png
# Processado: TANKER900.png -> DDPM-F64x4/TANKER/TANKER900.png
# Processado: TANKER901.png -> DDPM-F64x4/TANKER/TANKER901.png
# Processado: TANKER902.png -> DDPM-F64x4/TANKER/TANKER902.png
# Processado: TANKER903.png -> DDPM-F64x4/TANKER/TANKER903.png
# Processado: TANKER904.png -> DDPM-F64x4/TANKER/TANKER904.png
# Processado: TANKER905.png -> DDPM-F64x4/TANKER/TANKER905.png
# Processado: TANKER906.png -> DDPM-F64x4/TANKER/TANKER906.png
# Processado: TANKER907.png -> DDPM-F64x4/TANKER/TANKER907.png
# Processado: TANKER908.png -> DDPM-F64x4/TANKER/TANKER908.png
# Processado: TANKER909.png -> DDPM-F64x4/TANKER/TANKER909.png
# Processado: TANKER91.png -> DDPM-F64x4/TANKER/TANKER91.png
# Processado: TANKER910.png -> DDPM-F64x4/TANKER/TANKER910.png
# Processado: TANKER911.png -> DDPM-F64x4/TANKER/TANKER911.png
# Processado: TANKER912.png -> DDPM-F64x4/TANKER/TANKER912.png
# Processado: TANKER913.png -> DDPM-F64x4/TANKER/TANKER913.png
# Processado: TANKER914.png -> DDPM-F64x4/TANKER/TANKER914.png
# Processado: TANKER915.png -> DDPM-F64x4/TANKER/TANKER915.png
# Processado: TANKER916.png -> DDPM-F64x4/TANKER/TANKER916.png
# Processado: TANKER917.png -> DDPM-F64x4/TANKER/TANKER917.png
# Processado: TANKER918.png -> DDPM-F64x4/TANKER/TANKER918.png
# Processado: TANKER919.png -> DDPM-F64x4/TANKER/TANKER919.png
# Processado: TANKER92.png -> DDPM-F64x4/TANKER/TANKER92.png
# Processado: TANKER920.png -> DDPM-F64x4/TANKER/TANKER920.png
# Processado: TANKER921.png -> DDPM-F64x4/TANKER/TANKER921.png
# Processado: TANKER922.png -> DDPM-F64x4/TANKER/TANKER922.png
# Processado: TANKER923.png -> DDPM-F64x4/TANKER/TANKER923.png
# Processado: TANKER924.png -> DDPM-F64x4/TANKER/TANKER924.png
# Processado: TANKER925.png -> DDPM-F64x4/TANKER/TANKER925.png
# Processado: TANKER926.png -> DDPM-F64x4/TANKER/TANKER926.png
# Processado: TANKER927.png -> DDPM-F64x4/TANKER/TANKER927.png
# Processado: TANKER928.png -> DDPM-F64x4/TANKER/TANKER928.png
# Processado: TANKER929.png -> DDPM-F64x4/TANKER/TANKER929.png
# Processado: TANKER93.png -> DDPM-F64x4/TANKER/TANKER93.png
# Processado: TANKER930.png -> DDPM-F64x4/TANKER/TANKER930.png
# Processado: TANKER931.png -> DDPM-F64x4/TANKER/TANKER931.png
# Processado: TANKER932.png -> DDPM-F64x4/TANKER/TANKER932.png
# Processado: TANKER933.png -> DDPM-F64x4/TANKER/TANKER933.png
# Processado: TANKER934.png -> DDPM-F64x4/TANKER/TANKER934.png
# Processado: TANKER935.png -> DDPM-F64x4/TANKER/TANKER935.png
# Processado: TANKER936.png -> DDPM-F64x4/TANKER/TANKER936.png
# Processado: TANKER937.png -> DDPM-F64x4/TANKER/TANKER937.png
# Processado: TANKER938.png -> DDPM-F64x4/TANKER/TANKER938.png
# Processado: TANKER939.png -> DDPM-F64x4/TANKER/TANKER939.png
# Processado: TANKER94.png -> DDPM-F64x4/TANKER/TANKER94.png
# Processado: TANKER940.png -> DDPM-F64x4/TANKER/TANKER940.png
# Processado: TANKER941.png -> DDPM-F64x4/TANKER/TANKER941.png
# Processado: TANKER942.png -> DDPM-F64x4/TANKER/TANKER942.png
# Processado: TANKER943.png -> DDPM-F64x4/TANKER/TANKER943.png
# Processado: TANKER944.png -> DDPM-F64x4/TANKER/TANKER944.png
# Processado: TANKER945.png -> DDPM-F64x4/TANKER/TANKER945.png
# Processado: TANKER946.png -> DDPM-F64x4/TANKER/TANKER946.png
# Processado: TANKER947.png -> DDPM-F64x4/TANKER/TANKER947.png
# Processado: TANKER948.png -> DDPM-F64x4/TANKER/TANKER948.png
# Processado: TANKER949.png -> DDPM-F64x4/TANKER/TANKER949.png
# Processado: TANKER95.png -> DDPM-F64x4/TANKER/TANKER95.png
# Processado: TANKER950.png -> DDPM-F64x4/TANKER/TANKER950.png
# Processado: TANKER951.png -> DDPM-F64x4/TANKER/TANKER951.png
# Processado: TANKER952.png -> DDPM-F64x4/TANKER/TANKER952.png
# Processado: TANKER953.png -> DDPM-F64x4/TANKER/TANKER953.png
# Processado: TANKER954.png -> DDPM-F64x4/TANKER/TANKER954.png
# Processado: TANKER955.png -> DDPM-F64x4/TANKER/TANKER955.png
# Processado: TANKER956.png -> DDPM-F64x4/TANKER/TANKER956.png
# Processado: TANKER957.png -> DDPM-F64x4/TANKER/TANKER957.png
# Processado: TANKER958.png -> DDPM-F64x4/TANKER/TANKER958.png
# Processado: TANKER959.png -> DDPM-F64x4/TANKER/TANKER959.png
# Processado: TANKER96.png -> DDPM-F64x4/TANKER/TANKER96.png
# Processado: TANKER960.png -> DDPM-F64x4/TANKER/TANKER960.png
# Processado: TANKER961.png -> DDPM-F64x4/TANKER/TANKER961.png
# Processado: TANKER962.png -> DDPM-F64x4/TANKER/TANKER962.png
# Processado: TANKER963.png -> DDPM-F64x4/TANKER/TANKER963.png
# Processado: TANKER964.png -> DDPM-F64x4/TANKER/TANKER964.png
# Processado: TANKER965.png -> DDPM-F64x4/TANKER/TANKER965.png
# Processado: TANKER966.png -> DDPM-F64x4/TANKER/TANKER966.png
# Processado: TANKER967.png -> DDPM-F64x4/TANKER/TANKER967.png
# Processado: TANKER968.png -> DDPM-F64x4/TANKER/TANKER968.png
# Processado: TANKER969.png -> DDPM-F64x4/TANKER/TANKER969.png
# Processado: TANKER97.png -> DDPM-F64x4/TANKER/TANKER97.png
# Processado: TANKER970.png -> DDPM-F64x4/TANKER/TANKER970.png
# Processado: TANKER971.png -> DDPM-F64x4/TANKER/TANKER971.png
# Processado: TANKER972.png -> DDPM-F64x4/TANKER/TANKER972.png
# Processado: TANKER973.png -> DDPM-F64x4/TANKER/TANKER973.png
# Processado: TANKER974.png -> DDPM-F64x4/TANKER/TANKER974.png
# Processado: TANKER975.png -> DDPM-F64x4/TANKER/TANKER975.png
# Processado: TANKER976.png -> DDPM-F64x4/TANKER/TANKER976.png
# Processado: TANKER977.png -> DDPM-F64x4/TANKER/TANKER977.png
# Processado: TANKER978.png -> DDPM-F64x4/TANKER/TANKER978.png
# Processado: TANKER979.png -> DDPM-F64x4/TANKER/TANKER979.png
# Processado: TANKER98.png -> DDPM-F64x4/TANKER/TANKER98.png
# Processado: TANKER980.png -> DDPM-F64x4/TANKER/TANKER980.png
# Processado: TANKER981.png -> DDPM-F64x4/TANKER/TANKER981.png
# Processado: TANKER982.png -> DDPM-F64x4/TANKER/TANKER982.png
# Processado: TANKER983.png -> DDPM-F64x4/TANKER/TANKER983.png
# Processado: TANKER984.png -> DDPM-F64x4/TANKER/TANKER984.png
# Processado: TANKER985.png -> DDPM-F64x4/TANKER/TANKER985.png
# Processado: TANKER986.png -> DDPM-F64x4/TANKER/TANKER986.png
# Processado: TANKER987.png -> DDPM-F64x4/TANKER/TANKER987.png
# Processado: TANKER988.png -> DDPM-F64x4/TANKER/TANKER988.png
# Processado: TANKER989.png -> DDPM-F64x4/TANKER/TANKER989.png
# Processado: TANKER99.png -> DDPM-F64x4/TANKER/TANKER99.png
# Processado: TANKER990.png -> DDPM-F64x4/TANKER/TANKER990.png
# Processado: TANKER991.png -> DDPM-F64x4/TANKER/TANKER991.png
# Processado: TANKER992.png -> DDPM-F64x4/TANKER/TANKER992.png
# Processado: TANKER993.png -> DDPM-F64x4/TANKER/TANKER993.png
# Processado: TANKER994.png -> DDPM-F64x4/TANKER/TANKER994.png
# Processado: TANKER995.png -> DDPM-F64x4/TANKER/TANKER995.png
# Processado: TANKER996.png -> DDPM-F64x4/TANKER/TANKER996.png
# Processado: TANKER997.png -> DDPM-F64x4/TANKER/TANKER997.png
# Processado: TANKER998.png -> DDPM-F64x4/TANKER/TANKER998.png
# Processado: TANKER999.png -> DDPM-F64x4/TANKER/TANKER999.png
# Processamento concluído!
